# %% [markdown]
# ## Dependencies

# %%
import re
import warnings
from joblib import dump
import tensorflow_hub as hub
from sklearn.preprocessing import OneHotEncoder, MinMaxScaler
from tensorflow.keras import Model, optimizers
from tensorflow.keras.layers import Lambda, Input, Dense, Dropout, Concatenate, BatchNormalization, Activation, Average
from tensorflow.keras.callbacks import ReduceLROnPlateau
from googleqa_utilityscript import *


SEED = 0
seed_everything(SEED)
warnings.filterwarnings("ignore")

# %% [markdown]
# ## Load data

# %%
module_url = '/kaggle/input/universalsentenceencodermodels/universal-sentence-encoder-models/use-qa'
model_path = '/kaggle/working/use.h5'
category_encoder_path = '/kaggle/working/category_encoder.joblib'
scaler_path = '/kaggle/working/scaler.joblib'

hold_out = pd.read_csv('/kaggle/input/googleqa-mldataset/hold-out.csv')
train = hold_out[hold_out['set'] == 'train']
validation = hold_out[hold_out['set'] == 'validation']

print('Train samples: %s' % len(train))
print('Validation samples: %s' % len(validation))
display(train.head())
# Out:
# Train samples: 4863
# Validation samples: 1216
#    qa_id                                     question_title  \
# 0   3895  Magento (1.7) Bundled Product with FREE Produc...
# 1   3131                             Find router on network
# 2   1507  Negatively curved metrics minimizing the lengt...
# 3   6784               Isn’t the FAQ label obsolete by now?
# 4   2135  Changing background image one time on responsi...
#
#                                        question_body question_user_name  \
# 0  I'm looking to create a bundle offer where cus...                Joe
# 1  I've just bought a Belkin N+ Wireless Router. ...                Guy
# 2  Good afternoon everyone !\n\nI have the follow...            Selim G
# 3  Don’t get me wrong in the beginning of reading...     Benny Skogberg
# 4  The code I'm using is this one \n\nbackground:...        user2141649
#
#                               question_user_page  \
# 0  https://magento.stackexchange.com/users/16572
# 1               https://superuser.com/users/3248
# 2           https://mathoverflow.net/users/25511
# 3        https://ux.stackexchange.com/users/4679
# 4        https://stackoverflow.com/users/2141649
#
#                                               answer   answer_user_name  \
# 0  Since the third item is fixed, you can use sho...  Fabian Schmengler
# 1  You likely have the router plugged in to the m...             John T
# 2  A very partial answer: by the results of Richa...         Igor Rivin
# 3  Isn’t the FAQ label obsolete by now? \n\nI'd s...        Solracnapod
# 4  &lt;!DOCTYPE html&gt;\n&lt;html&gt;\n&lt;head&...           akkimads
#
#                               answer_user_page  \
# 0  https://magento.stackexchange.com/users/243
# 1             https://superuser.com/users/1931
# 2         https://mathoverflow.net/users/11142
# 3     https://ux.stackexchange.com/users/13153
# 4      https://stackoverflow.com/users/2375373
#
#                                                  url       category  ...  \
# 0  http://magento.stackexchange.com/questions/668...     TECHNOLOGY  ...
# 1               http://superuser.com/questions/87212     TECHNOLOGY  ...
# 2           http://mathoverflow.net/questions/203422        SCIENCE  ...
# 3  http://ux.stackexchange.com/questions/18600/is...     TECHNOLOGY  ...
# 4  http://stackoverflow.com/questions/16359492/ch...  STACKOVERFLOW  ...
#
#   answer_helpful  answer_level_of_information  answer_plausible  \
# 0       0.888889                     0.666667               1.0
# 1       1.000000                     0.666667               1.0
# 2       0.888889                     0.333333               1.0
# 3       0.888889                     0.666667               1.0
# 4       0.888889                     0.500000               1.0
#
#    answer_relevance  answer_satisfaction  answer_type_instructions  \
# 0               1.0             0.933333                  1.000000
# 1               1.0             0.866667                  0.666667
# 2               1.0             0.700000                  0.333333
# 3               1.0             0.933333                  0.000000
# 4               1.0             0.800000                  1.000000
#
#    answer_type_procedure  answer_type_reason_explanation  answer_well_written  \
# 0               0.000000                        0.333333             0.888889
# 1               0.000000                        1.000000             1.000000
# 2               0.333333                        1.000000             0.888889
# 3               0.000000                        0.666667             1.000000
# 4               0.000000                        0.000000             0.777778
#
#      set
# 0  train
# 1  train
# 2  train
# 3  train
# 4  train
#
# [5 rows x 42 columns]

# %%
question_target_cols = ['question_asker_intent_understanding','question_body_critical', 'question_conversational', 
                        'question_expect_short_answer', 'question_fact_seeking', 'question_has_commonly_accepted_answer',
                        'question_interestingness_others', 'question_interestingness_self', 'question_multi_intent', 
                        'question_not_really_a_question', 'question_opinion_seeking', 'question_type_choice',
                        'question_type_compare', 'question_type_consequence', 'question_type_definition', 
                        'question_type_entity', 'question_type_instructions', 'question_type_procedure',
                        'question_type_reason_explanation', 'question_type_spelling', 'question_well_written']
answer_target_cols = ['answer_helpful', 'answer_level_of_information', 'answer_plausible', 'answer_relevance',
                      'answer_satisfaction', 'answer_type_instructions', 'answer_type_procedure', 
                      'answer_type_reason_explanation', 'answer_well_written']
target_cols = question_target_cols + answer_target_cols

# %% [markdown]
# ## Pre-process data

# %%
text_features = ['question_title', 'question_body', 'answer']

for feature in text_features:
    # Lower
    train[feature] = train[feature].apply(lambda x: x.lower())
    validation[feature] = validation[feature].apply(lambda x: x.lower())
    # Map misspellings
#     train[feature] = train[feature].apply(lambda x: map_misspellings(x))
#     validation[feature] = validation[feature].apply(lambda x: map_misspellings(x))
    # Map contractions
    train[feature] = train[feature].apply(lambda x: map_contraction(x))
    validation[feature] = validation[feature].apply(lambda x: map_contraction(x))
    # Trim text
    train[feature] = train[feature].apply(lambda x: x.strip())
    validation[feature] = validation[feature].apply(lambda x: x.strip())


# Text length
train['question_title_len'] = train['question_title'].apply(lambda x : len(x))
validation['question_title_len'] = validation['question_title'].apply(lambda x : len(x))
train['question_body_len'] = train['question_body'].apply(lambda x : len(x))
validation['question_body_len'] = validation['question_body'].apply(lambda x : len(x))
train['answer_len'] = train['answer'].apply(lambda x : len(x))
validation['answer_len'] = validation['answer'].apply(lambda x : len(x))

# Word count
train['question_title_word_cnt'] = train['question_title'].apply(lambda x : len(x.split(' ')))
validation['question_title_word_cnt'] = validation['question_title'].apply(lambda x : len(x.split(' ')))
train['question_body_word_cnt'] = train['question_body'].apply(lambda x : len(x.split(' ')))
validation['question_body_word_cnt'] = validation['question_body'].apply(lambda x : len(x.split(' ')))
train['answer_word_cnt'] = train['answer'].apply(lambda x : len(x.split(' ')))
validation['answer_word_cnt'] = validation['answer'].apply(lambda x : len(x.split(' ')))

# Unique word count
train['question_title_unique_word_cnt'] = train['question_title'].apply(lambda x : len(set(x.split(' '))))
validation['question_title_unique_word_cnt'] = validation['question_title'].apply(lambda x : len(set(x.split(' '))))
train['question_body_unique_word_cnt'] = train['question_body'].apply(lambda x : len(set(x.split(' '))))
validation['question_body_unique_word_cnt'] = validation['question_body'].apply(lambda x : len(set(x.split(' '))))
train['answer_unique_word_cnt'] = train['answer'].apply(lambda x : len(set(x.split(' '))))
validation['answer_unique_word_cnt'] = validation['answer'].apply(lambda x : len(set(x.split(' '))))

# Misspelings count
misspelling_mapping_set = set(misspelling_mapping.keys())
train['question_title_misspelings_cnt'] = train['question_title'].apply(lambda x : len(set(x.split(' ')) & misspelling_mapping_set))
validation['question_title_misspelings_cnt'] = validation['question_title'].apply(lambda x : len(set(x.split(' ')) & misspelling_mapping_set))
train['question_body_misspelings_cnt'] = train['question_body'].apply(lambda x : len(set(x.split(' ')) & misspelling_mapping_set))
validation['question_body_misspelings_cnt'] = validation['question_body'].apply(lambda x : len(set(x.split(' ')) & misspelling_mapping_set))
train['answer_misspelings_cnt'] = train['answer'].apply(lambda x : len(set(x.split(' ')) & misspelling_mapping_set))
validation['answer_misspelings_cnt'] = validation['answer'].apply(lambda x : len(set(x.split(' ')) & misspelling_mapping_set))

# %% [markdown]
# ## Train/validation sets

# %%
ohe_category = OneHotEncoder(handle_unknown='ignore')
scaler = MinMaxScaler()

ohe_category.fit(train[['category']])


# Train features
X_train_title = train['question_title']
X_train_body = train['question_body']
X_train_answer = train['answer']
X_train_category = ohe_category.transform(train[['category']]).toarray()
X_train_dense = train[['question_title_len', 'question_title_word_cnt', 'question_title_unique_word_cnt', 'question_title_misspelings_cnt', 
                       'question_body_len', 'question_body_word_cnt', 'question_body_unique_word_cnt', 'question_body_misspelings_cnt', 
                       'answer_len', 'answer_word_cnt', 'answer_unique_word_cnt', 'answer_misspelings_cnt']]

scaler.fit(X_train_dense)

X_train_dense = scaler.transform(X_train_dense)
X_train = [X_train_title, X_train_body, X_train_answer, X_train_category, X_train_dense]
Y_train = train[target_cols].values

# Validation features
X_valid_title = validation['question_title']
X_valid_body = validation['question_body']
X_valid_answer = validation['answer']
X_valid_category = ohe_category.transform(validation[['category']]).toarray()
X_valid_dense = validation[['question_title_len', 'question_title_word_cnt', 'question_title_unique_word_cnt', 'question_title_misspelings_cnt', 
                            'question_body_len', 'question_body_word_cnt', 'question_body_unique_word_cnt', 'question_body_misspelings_cnt', 
                            'answer_len', 'answer_word_cnt', 'answer_unique_word_cnt', 'answer_misspelings_cnt']]

X_valid_dense = scaler.transform(X_valid_dense)
X_valid = [X_valid_title, X_valid_body, X_valid_answer, X_valid_category, X_valid_dense]
Y_valid = validation[target_cols].values

print('Train samples: %d' % len(Y_train))
print('Validation samples: %d' % len(Y_valid))
# Out:
# Train samples: 4863
# Validation samples: 1216

# %% [markdown]
# # Model parameters

# %%
EPOCHS = 50
BATCH_SIZE = 32
LEARNING_RATE = 3e-4
EMBEDDDING_SIZE = 512
N_CLASS = len(target_cols)
ES_PATIENCE = 5
RLROP_PATIENCE = 2
DECAY_DROP = 0.3

# %% [markdown]
# # Model

# %%
use_embed = hub.load(module_url)

def USEEmbedding(x):
    return use_embed(tf.squeeze(tf.cast(x, tf.string)))

def encoder_block(input_layer):
    encoder = Lambda(USEEmbedding, output_shape=(EMBEDDDING_SIZE,))(input_layer)
    
    return encoder

# %%
# Title
input_title = Input(shape=(1,), dtype=tf.string, name='input_title')
encoded_title = encoder_block(input_title)

# Body
input_body = Input(shape=(1,), dtype=tf.string, name='input_body')
encoded_body = encoder_block(input_body)

# Answer
input_answer = Input(shape=(1,), dtype=tf.string, name='input_answer')
encoded_answer = encoder_block(input_answer)

# Category
input_category = Input(shape=(X_train_category.shape[1],), dtype=tf.float32, name='input_category')

# Dense features
input_dense = Input(shape=(X_train_dense.shape[1],), dtype=tf.float32, name='input_dense')


# Output
dense = Concatenate()([input_dense, input_category])
dense = Dropout(0.2)(dense)
dense = Dense(32, kernel_initializer='glorot_uniform')(dense)
dense = BatchNormalization()(dense)
dense = Activation('relu')(dense)
dense = Dropout(0.2)(dense)
dense = Dense(16, kernel_initializer='glorot_uniform')(dense)
dense = BatchNormalization()(dense)
dense = Activation('relu')(dense)
dense = Dropout(0.2)(dense)

title = Dropout(0.2)(encoded_title)
title = Dense(128, kernel_initializer='glorot_uniform')(encoded_title)
title = BatchNormalization()(title)
title = Activation('relu')(title)
title = Dropout(0.2)(title)

body = Dropout(0.2)(encoded_body)
body = Dense(128, kernel_initializer='glorot_uniform')(encoded_body)
body = BatchNormalization()(body)
body = Activation('relu')(body)
body = Dropout(0.2)(body)

answer = Dropout(0.2)(encoded_answer)
answer = Dense(128, kernel_initializer='glorot_uniform')(encoded_answer)
answer = BatchNormalization()(answer)
answer = Activation('relu')(answer)
answer = Dropout(0.2)(answer)

question = Concatenate()([title, body])
question = Dropout(0.2)(question)
question = Dense(128, kernel_initializer='glorot_uniform')(question)
question = BatchNormalization()(question)
question = Activation('relu')(question)
question = Dropout(0.2)(question)

x = Concatenate()([question, answer, dense, encoded_title, encoded_body, encoded_answer])
x = Dense(512, kernel_initializer='glorot_uniform')(x)
x = BatchNormalization()(x)
x = Activation('relu')(x)
x = Dropout(0.5)(x)

output = Dense(N_CLASS, activation='sigmoid', kernel_initializer='glorot_uniform', name='output')(x)
model = Model(inputs=[input_title, input_body, input_answer, input_category, input_dense], outputs=[output])

model.summary()
# Out:
# Model: "model"
# __________________________________________________________________________________________________
# Layer (type)                    Output Shape         Param #     Connected to
# ==================================================================================================
# input_title (InputLayer)        [(None, 1)]          0
# __________________________________________________________________________________________________
# input_body (InputLayer)         [(None, 1)]          0
# __________________________________________________________________________________________________
# lambda (Lambda)                 (None, 512)          0           input_title[0][0]
# __________________________________________________________________________________________________
# lambda_1 (Lambda)               (None, 512)          0           input_body[0][0]
# __________________________________________________________________________________________________
# input_dense (InputLayer)        [(None, 12)]         0
# __________________________________________________________________________________________________
# input_category (InputLayer)     [(None, 5)]          0
# __________________________________________________________________________________________________
# dense_2 (Dense)                 (None, 128)          65664       lambda[0][0]
# __________________________________________________________________________________________________
# dense_3 (Dense)                 (None, 128)          65664       lambda_1[0][0]
# __________________________________________________________________________________________________
# concatenate (Concatenate)       (None, 17)           0           input_dense[0][0]
#                                                                  input_category[0][0]
# __________________________________________________________________________________________________
# batch_normalization_2 (BatchNor (None, 128)          512         dense_2[0][0]
# __________________________________________________________________________________________________
# batch_normalization_3 (BatchNor (None, 128)          512         dense_3[0][0]
# __________________________________________________________________________________________________
# dropout (Dropout)               (None, 17)           0           concatenate[0][0]
# __________________________________________________________________________________________________
# activation_2 (Activation)       (None, 128)          0           batch_normalization_2[0][0]
# __________________________________________________________________________________________________
# activation_3 (Activation)       (None, 128)          0           batch_normalization_3[0][0]
# __________________________________________________________________________________________________
# dense (Dense)                   (None, 32)           576         dropout[0][0]
# __________________________________________________________________________________________________
# dropout_4 (Dropout)             (None, 128)          0           activation_2[0][0]
# __________________________________________________________________________________________________
# dropout_6 (Dropout)             (None, 128)          0           activation_3[0][0]
# __________________________________________________________________________________________________
# batch_normalization (BatchNorma (None, 32)           128         dense[0][0]
# __________________________________________________________________________________________________
# concatenate_1 (Concatenate)     (None, 256)          0           dropout_4[0][0]
#                                                                  dropout_6[0][0]
# __________________________________________________________________________________________________
# input_answer (InputLayer)       [(None, 1)]          0
# __________________________________________________________________________________________________
# activation (Activation)         (None, 32)           0           batch_normalization[0][0]
# __________________________________________________________________________________________________
# dropout_9 (Dropout)             (None, 256)          0           concatenate_1[0][0]
# __________________________________________________________________________________________________
# lambda_2 (Lambda)               (None, 512)          0           input_answer[0][0]
# __________________________________________________________________________________________________
# dropout_1 (Dropout)             (None, 32)           0           activation[0][0]
# __________________________________________________________________________________________________
# dense_5 (Dense)                 (None, 128)          32896       dropout_9[0][0]
# __________________________________________________________________________________________________
# dense_4 (Dense)                 (None, 128)          65664       lambda_2[0][0]
# __________________________________________________________________________________________________
# dense_1 (Dense)                 (None, 16)           528         dropout_1[0][0]
# __________________________________________________________________________________________________
# batch_normalization_5 (BatchNor (None, 128)          512         dense_5[0][0]
# __________________________________________________________________________________________________
# batch_normalization_4 (BatchNor (None, 128)          512         dense_4[0][0]
# __________________________________________________________________________________________________
# batch_normalization_1 (BatchNor (None, 16)           64          dense_1[0][0]
# __________________________________________________________________________________________________
# activation_5 (Activation)       (None, 128)          0           batch_normalization_5[0][0]
# __________________________________________________________________________________________________
# activation_4 (Activation)       (None, 128)          0           batch_normalization_4[0][0]
# __________________________________________________________________________________________________
# activation_1 (Activation)       (None, 16)           0           batch_normalization_1[0][0]
# __________________________________________________________________________________________________
# dropout_10 (Dropout)            (None, 128)          0           activation_5[0][0]
# __________________________________________________________________________________________________
# dropout_8 (Dropout)             (None, 128)          0           activation_4[0][0]
# __________________________________________________________________________________________________
# dropout_2 (Dropout)             (None, 16)           0           activation_1[0][0]
# __________________________________________________________________________________________________
# concatenate_2 (Concatenate)     (None, 1808)         0           dropout_10[0][0]
#                                                                  dropout_8[0][0]
#                                                                  dropout_2[0][0]
#                                                                  lambda[0][0]
#                                                                  lambda_1[0][0]
#                                                                  lambda_2[0][0]
# __________________________________________________________________________________________________
# dense_6 (Dense)                 (None, 512)          926208      concatenate_2[0][0]
# __________________________________________________________________________________________________
# batch_normalization_6 (BatchNor (None, 512)          2048        dense_6[0][0]
# __________________________________________________________________________________________________
# activation_6 (Activation)       (None, 512)          0           batch_normalization_6[0][0]
# __________________________________________________________________________________________________
# dropout_11 (Dropout)            (None, 512)          0           activation_6[0][0]
# __________________________________________________________________________________________________
# output (Dense)                  (None, 30)           15390       dropout_11[0][0]
# ==================================================================================================
# Total params: 1,176,878
# Trainable params: 1,174,734
# Non-trainable params: 2,144
# __________________________________________________________________________________________________

# %% [markdown]
# # Train model

# %%
rlrop = ReduceLROnPlateau(monitor='val_loss', mode='min', patience=RLROP_PATIENCE, factor=DECAY_DROP, min_lr=1e-7, verbose=1)
spearmanCallback = SpearmanRhoCallback(training_data=(X_train, Y_train), validation_data=(X_valid, Y_valid), monitor='val_loss', mode='min', patience=ES_PATIENCE)
callback_list = [rlrop, spearmanCallback]

optimizer = optimizers.Adam(LEARNING_RATE)
model.compile(optimizer=optimizer, loss='binary_crossentropy')

history = model.fit(X_train, Y_train, 
                    validation_data=(X_valid, Y_valid), 
                    callbacks=callback_list, 
                    batch_size=BATCH_SIZE, 
                    epochs=EPOCHS, 
                    verbose=2).history
# Out:
# Train on 4863 samples, validate on 1216 samples
# Epoch 1/50
# spearman-rho: 0.2973 val_spearman-rho: 0.2689
# 4863/4863 - 254s - loss: 0.5308 - val_loss: 0.5090
# Epoch 2/50
# spearman-rho: 0.3506 val_spearman-rho: 0.2991
# 4863/4863 - 124s - loss: 0.4406 - val_loss: 0.4266
# Epoch 3/50
# spearman-rho: 0.3942 val_spearman-rho: 0.3164
# 4863/4863 - 123s - loss: 0.4211 - val_loss: 0.4001
# Epoch 4/50
# spearman-rho: 0.4281 val_spearman-rho: 0.3297
# 4863/4863 - 124s - loss: 0.4085 - val_loss: 0.3875
# Epoch 5/50
# spearman-rho: 0.4493 val_spearman-rho: 0.3360
# 4863/4863 - 124s - loss: 0.3971 - val_loss: 0.3831
# Epoch 6/50
# spearman-rho: 0.4667 val_spearman-rho: 0.3421
# 4863/4863 - 124s - loss: 0.3899 - val_loss: 0.3814
# Epoch 7/50
# spearman-rho: 0.4807 val_spearman-rho: 0.3497
# 4863/4863 - 123s - loss: 0.3830 - val_loss: 0.3799
# Epoch 8/50
# spearman-rho: 0.4935 val_spearman-rho: 0.3527
# 4863/4863 - 122s - loss: 0.3775 - val_loss: 0.3789
# Epoch 9/50
# spearman-rho: 0.5032 val_spearman-rho: 0.3565
# 4863/4863 - 123s - loss: 0.3738 - val_loss: 0.3788
# Epoch 10/50
# spearman-rho: 0.5141 val_spearman-rho: 0.3577
# 4863/4863 - 123s - loss: 0.3699 - val_loss: 0.3778
# Epoch 11/50
# spearman-rho: 0.5229 val_spearman-rho: 0.3590
# 4863/4863 - 123s - loss: 0.3662 - val_loss: 0.3786
# Epoch 12/50
# spearman-rho: 0.5314 val_spearman-rho: 0.3630
# 4863/4863 - 124s - loss: 0.3632 - val_loss: 0.3776
# Epoch 13/50
# spearman-rho: 0.5380 val_spearman-rho: 0.3645
# 4863/4863 - 123s - loss: 0.3600 - val_loss: 0.3776
# Epoch 14/50
#
# Epoch 00014: ReduceLROnPlateau reducing learning rate to 9.000000427477062e-05.
# spearman-rho: 0.5451 val_spearman-rho: 0.3649
# 4863/4863 - 123s - loss: 0.3570 - val_loss: 0.3777
# Epoch 15/50
# spearman-rho: 0.5482 val_spearman-rho: 0.3664
# 4863/4863 - 123s - loss: 0.3530 - val_loss: 0.3775
# Epoch 16/50
# spearman-rho: 0.5512 val_spearman-rho: 0.3669
# 4863/4863 - 123s - loss: 0.3518 - val_loss: 0.3775
# Epoch 17/50
#
# Epoch 00017: ReduceLROnPlateau reducing learning rate to 2.700000040931627e-05.
# spearman-rho: 0.5535 val_spearman-rho: 0.3678
# 4863/4863 - 123s - loss: 0.3508 - val_loss: 0.3777
# Epoch 18/50
# spearman-rho: 0.5546 val_spearman-rho: 0.3681
# Epoch 00017: early stopping
# 4863/4863 - 122s - loss: 0.3496 - val_loss: 0.3776

# %% [markdown]
# ## Model loss graph

# %%
sns.set(style="whitegrid")
plot_metrics(history, metric_list=['loss', 'spearman'])

# %% [markdown]
# # Evaluation

# %%
preds_train = model.predict(X_train)
preds_val = model.predict(X_valid)

display(get_metrics(Y_train, preds_train, Y_valid, preds_val, target_cols))
# Out:
#                                     Label  Train  Validation
# 0                                Averaged  0.555       0.368
# 1     question_asker_intent_understanding  0.514       0.376
# 2                  question_body_critical  0.725       0.595
# 3                 question_conversational  0.490       0.410
# 4            question_expect_short_answer  0.633       0.224
# 5                   question_fact_seeking  0.668       0.343
# 6   question_has_commonly_accepted_answer  0.664       0.414
# 7         question_interestingness_others  0.445       0.388
# 8           question_interestingness_self  0.590       0.519
# 9                   question_multi_intent  0.698       0.392
# 10         question_not_really_a_question  0.165       0.078
# 11               question_opinion_seeking  0.748       0.444
# 12                   question_type_choice  0.801       0.617
# 13                  question_type_compare  0.421       0.309
# 14              question_type_consequence  0.231       0.180
# 15               question_type_definition  0.394       0.324
# 16                   question_type_entity  0.513       0.429
# 17             question_type_instructions  0.868       0.752
# 18                question_type_procedure  0.630       0.296
# 19       question_type_reason_explanation  0.800       0.635
# 20                 question_type_spelling  0.074       0.070
# 21                  question_well_written  0.635       0.476
# 22                         answer_helpful  0.480       0.193
# 23            answer_level_of_information  0.494       0.368
# 24                       answer_plausible  0.402       0.110
# 25                       answer_relevance  0.371       0.128
# 26                    answer_satisfaction  0.521       0.245
# 27               answer_type_instructions  0.866       0.709
# 28                  answer_type_procedure  0.590       0.252
# 29         answer_type_reason_explanation  0.825       0.648
# 30                    answer_well_written  0.383       0.120

# %% [markdown]
# ## By category

# %%
target_cols_preds = [col+'_pred' for col in target_cols]
for col in target_cols_preds:
    train[col] = 0
    validation[col] = 0
    
train[target_cols_preds] = preds_train
validation[target_cols_preds] = preds_val
    
display(get_metrics_category(train, validation, target_cols, target_cols_preds, 'category'))
# Out:
#       Label Train (TECHNOLOGY) Validation (TECHNOLOGY) Train (SCIENCE)  \
# 0  Averaged              0.532                   0.321           0.564
#
#   Validation (SCIENCE) Train (STACKOVERFLOW) Validation (STACKOVERFLOW)  \
# 0                0.377                  0.49                      0.203
#
#   Train (LIFE_ARTS) Validation (LIFE_ARTS) Train (CULTURE)  \
# 0             0.566                  0.422            0.57
#
#   Validation (CULTURE)
# 0                0.364

# %% [markdown]
# #### Save model weights and ecoders

# %%
model.save_weights(model_path)
dump(ohe_category, category_encoder_path)
dump(scaler, scaler_path)
# Out:
# ['/kaggle/working/scaler.joblib']
