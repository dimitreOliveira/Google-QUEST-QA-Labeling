# %% [markdown]
# ## Dependencies

# %%
import glob
import warnings
from tensorflow_hub import KerasLayer
from tensorflow.keras import Model, optimizers
from tensorflow.keras.callbacks import ReduceLROnPlateau
from tensorflow.keras.layers import Input, Dense, Dropout, GlobalAveragePooling1D, SpatialDropout1D, Concatenate
from googleqa_utilityscript import *
from googleqa_map_utilityscript import *
from script_lr_schedulers import WarmUpLearningRateScheduler
import bert_tokenization as tokenization


SEED = 0
seed_everything(SEED)
warnings.filterwarnings("ignore")
# Out:
# Using TensorFlow backend.

# %% [markdown]
# ## Load data

# %%
BERT_PATH = '/kaggle/input/tf-hub-bert-base/bert_base_uncased'
VOCAB_PATH = BERT_PATH + '/assets/vocab.txt'

k_fold = pd.read_csv('/kaggle/input/googleqa-mldataset/5-fold.csv')
N_FOLDS = 1

print('Samples: %s' % len(k_fold))
display(k_fold.head())
# Out:
# Samples: 6079
#    qa_id                                     question_title  \
# 0      0  What am I losing when using extension tubes in...
# 1      1  What is the distinction between a city and a s...
# 2      2  Maximum protusion length for through-hole comp...
# 3      3              Can an affidavit be used in Beit Din?
# 4      5       How do you make a binary image in Photoshop?
#
#                                        question_body question_user_name  \
# 0  After playing around with macro photography on...               ysap
# 1  I am trying to understand what kinds of places...      russellpierce
# 2  I'm working on a PCB that has through-hole com...          Joe Baker
# 3  An affidavit, from what i understand, is basic...         Scimonster
# 4  I am trying to make a binary image. I want mor...            leigero
#
#                                   question_user_page  \
# 0         https://photo.stackexchange.com/users/1024
# 1           https://rpg.stackexchange.com/users/8774
# 2  https://electronics.stackexchange.com/users/10157
# 3       https://judaism.stackexchange.com/users/5151
# 4  https://graphicdesign.stackexchange.com/users/...
#
#                                               answer answer_user_name  \
# 0  I just got extension tubes, so here's the skin...           rfusca
# 1  It might be helpful to look into the definitio...     Erik Schmidt
# 2  Do you even need grooves?  We make several pro...      Dwayne Reid
# 3  Sending an "affidavit" it is a dispute between...    Y     e     z
# 4  Check out Image Trace in Adobe Illustrator. \n...             q2ra
#
#                                     answer_user_page  \
# 0         https://photo.stackexchange.com/users/1917
# 1           https://rpg.stackexchange.com/users/1871
# 2  https://electronics.stackexchange.com/users/64754
# 3       https://judaism.stackexchange.com/users/4794
# 4  https://graphicdesign.stackexchange.com/users/...
#
#                                                  url   category  ...  \
# 0  http://photo.stackexchange.com/questions/9169/...  LIFE_ARTS  ...
# 1  http://rpg.stackexchange.com/questions/47820/w...    CULTURE  ...
# 2  http://electronics.stackexchange.com/questions...    SCIENCE  ...
# 3  http://judaism.stackexchange.com/questions/551...    CULTURE  ...
# 4  http://graphicdesign.stackexchange.com/questio...  LIFE_ARTS  ...
#
#   answer_satisfaction  answer_type_instructions  answer_type_procedure  \
# 0            0.800000                       1.0               0.000000
# 1            0.666667                       0.0               0.000000
# 2            0.666667                       0.0               0.333333
# 3            0.800000                       0.0               0.000000
# 4            0.800000                       1.0               0.000000
#
#    answer_type_reason_explanation  answer_well_written      fold_1  fold_2  \
# 0                        0.000000             1.000000       train   train
# 1                        0.666667             0.888889  validation   train
# 2                        1.000000             0.888889       train   train
# 3                        1.000000             1.000000       train   train
# 4                        1.000000             1.000000  validation   train
#
#        fold_3      fold_4      fold_5
# 0       train  validation       train
# 1       train       train       train
# 2  validation       train       train
# 3       train       train  validation
# 4       train       train       train
#
# [5 rows x 46 columns]

# %%
question_target_cols = ['question_asker_intent_understanding','question_body_critical', 'question_conversational', 
                        'question_expect_short_answer', 'question_fact_seeking', 'question_has_commonly_accepted_answer',
                        'question_interestingness_others', 'question_interestingness_self', 'question_multi_intent', 
                        'question_not_really_a_question', 'question_opinion_seeking', 'question_type_choice',
                        'question_type_compare', 'question_type_consequence', 'question_type_definition', 
                        'question_type_entity', 'question_type_instructions', 'question_type_procedure',
                        'question_type_reason_explanation', 'question_type_spelling', 'question_well_written']
answer_target_cols = ['answer_helpful', 'answer_level_of_information', 'answer_plausible', 'answer_relevance',
                      'answer_satisfaction', 'answer_type_instructions', 'answer_type_procedure', 
                      'answer_type_reason_explanation', 'answer_well_written']
target_cols = question_target_cols + answer_target_cols

# %% [markdown]
# # Pre-process data

# %%
text_features = ['question_title', 'question_body', 'answer']
text_features_question = ['question_title', 'question_body']
text_features_answer = ['question_title', 'answer']

# for feature in text_features:
#     # Lower
#     k_fold[feature] = k_fold[feature].apply(lambda x: x.lower())
#     # Map misspellings
#     k_fold[feature] = k_fold[feature].apply(lambda x: map_misspellings(x))
#     # Map contractions
#     k_fold[feature] = k_fold[feature].apply(lambda x: map_contraction(x))
#     # Trim text
#     k_fold[feature] = k_fold[feature].apply(lambda x: x.strip())

# %% [markdown]
# # Model parameters

# %%
EPOCHS = 8
BATCH_SIZE = 4
LEARNING_RATE = 3e-5
N_CLASS = len(target_cols)
ES_PATIENCE = 3
MAX_SEQUENCE_LENGTH = 512
RLROP_PATIENCE = 1
DECAY_DROP = 0.1
LR_WARMUP_EPOCHS = 1

# %% [markdown]
# # Model

# %%
def model_fn():
    input_word_ids_question = Input((MAX_SEQUENCE_LENGTH,), dtype=tf.int32, name='input_word_ids_question')
    input_masks_question = Input((MAX_SEQUENCE_LENGTH,), dtype=tf.int32, name='input_masks_question')
    segment_ids_question = Input((MAX_SEQUENCE_LENGTH,), dtype=tf.int32, name='segment_ids_question')

    input_word_ids_answer = Input((MAX_SEQUENCE_LENGTH,), dtype=tf.int32, name='input_word_ids_answer')
    input_masks_answer = Input((MAX_SEQUENCE_LENGTH,), dtype=tf.int32, name='input_masks_answer')
    segment_ids_answer = Input((MAX_SEQUENCE_LENGTH,), dtype=tf.int32, name='segment_ids_answer')

    bert_layer_question = KerasLayer(BERT_PATH, trainable=True)
    bert_layer_answer = KerasLayer(BERT_PATH, trainable=True)
    pooled_output_question, sequence_output_question = bert_layer_question([input_word_ids_question, input_masks_question, segment_ids_question])
    pooled_output_answer, sequence_output_answer = bert_layer_answer([input_word_ids_answer, input_masks_answer, segment_ids_answer])

    x_question = GlobalAveragePooling1D()(sequence_output_question)
    x_question = Dropout(0.2)(x_question)
    
    x_answer = GlobalAveragePooling1D()(sequence_output_answer)
    x_answer = Dropout(0.2)(x_answer)
    
    x = Concatenate()([x_question, x_answer])
    output = Dense(N_CLASS, kernel_initializer='glorot_uniform', activation="sigmoid", name="output")(x)

    model = Model(inputs=[input_word_ids_question, input_masks_question, segment_ids_question, 
                          input_word_ids_answer, input_masks_answer, segment_ids_answer], outputs=output)

    return model

# %% [markdown]
# # Train model

# %%
rlrop = ReduceLROnPlateau(monitor='val_loss', mode='min', patience=RLROP_PATIENCE, 
                          factor=DECAY_DROP, min_lr=1e-7, verbose=1)    
tokenizer = tokenization.FullTokenizer(VOCAB_PATH, True)

history_list = []
metric_list = []
category_metric_list = []
target_cols_preds = [col+'_pred' for col in target_cols]

for n_fold in range(N_FOLDS):
    ### Data
    train = k_fold[k_fold['fold_%d' % (n_fold+1)] == 'train']
    validation = k_fold[k_fold['fold_%d' % (n_fold+1)] == 'validation']
    
    ### Create features
    # Train features
    X_train = compute_input_arays_2(train, text_features_question, tokenizer, MAX_SEQUENCE_LENGTH, ignore_first_sep=False)\
        + compute_input_arays_2(train, text_features_answer, tokenizer, MAX_SEQUENCE_LENGTH, ignore_first_sep=False)
    Y_train = train[target_cols].values

    # Validation features
    X_valid = compute_input_arays_2(validation, text_features_question, tokenizer, MAX_SEQUENCE_LENGTH, ignore_first_sep=False)\
                + compute_input_arays_2(validation, text_features_answer, tokenizer, MAX_SEQUENCE_LENGTH, ignore_first_sep=False)
    Y_valid = validation[target_cols].values

    ### Train model
    model_path = '/kaggle/working/model_fold_%d' % (n_fold+1)
    spearmanCallback = SpearmanRhoCallback(training_data=(X_train, Y_train), 
                                           validation_data=(X_valid, Y_valid), 
                                           model_path=model_path, 
                                           monitor='val_loss', mode='min', 
                                           patience=ES_PATIENCE, checkpoint=True)
    LR_WARMUP_EPOCHS = 1
    WARMUP_BATCHES = LR_WARMUP_EPOCHS * len(train) // BATCH_SIZE
    warmup_lr = WarmUpLearningRateScheduler(WARMUP_BATCHES, LEARNING_RATE)

    callback_list = [spearmanCallback, rlrop, warmup_lr]
    optimizer = optimizers.Adam(lr=LEARNING_RATE)
    model = model_fn()
    model.compile(optimizer=optimizer, loss='binary_crossentropy')

    history = model.fit(X_train, Y_train, 
                        validation_data=(X_valid, Y_valid), 
                        callbacks=callback_list, 
                        batch_size=BATCH_SIZE, 
                        epochs=EPOCHS, 
                        verbose=2).history
    history_list.append(history)
    
    ### Evaluation - Label metrics
    model.load_weights(model_path+'.h5')
    preds_train = model.predict(X_train)
    preds_val = model.predict(X_valid)
    metric_list.append(get_metrics(Y_train, preds_train, Y_valid, preds_val, target_cols))
    
    ### Evaluation - Category metrics
    for col in target_cols_preds:
        train[col] = 0
        validation[col] = 0

    train[target_cols_preds] = preds_train
    validation[target_cols_preds] = preds_val
    category_metric_list.append(get_metrics_category(train, validation, target_cols, target_cols_preds, 'category'))
# Out:
# Train on 4864 samples, validate on 1215 samples
# Epoch 1/8
# spearman-rho: 0.4071 val_spearman-rho: 0.3685
# Saved model weights at "/kaggle/working/model_fold_1.h5"
# 4864/4864 - 1066s - loss: 0.4193 - val_loss: 0.3751
# Epoch 2/8
# spearman-rho: 0.4991 val_spearman-rho: 0.4020
# Saved model weights at "/kaggle/working/model_fold_1.h5"
# 4864/4864 - 989s - loss: 0.3677 - val_loss: 0.3669
# Epoch 3/8
# spearman-rho: 0.5795 val_spearman-rho: 0.4040
#
# Epoch 00003: ReduceLROnPlateau reducing learning rate to 2.9999999242136257e-06.
# 4864/4864 - 987s - loss: 0.3440 - val_loss: 0.3754
# Epoch 4/8
# spearman-rho: 0.6354 val_spearman-rho: 0.4029
#
# Epoch 00004: ReduceLROnPlateau reducing learning rate to 2.9999998787388907e-07.
# 4864/4864 - 987s - loss: 0.3074 - val_loss: 0.3736
# Epoch 5/8
# spearman-rho: 0.6383 val_spearman-rho: 0.4008
# Epoch 00004: early stopping
#
# Epoch 00005: ReduceLROnPlateau reducing learning rate to 1e-07.
# 4864/4864 - 987s - loss: 0.2937 - val_loss: 0.3768

# %% [markdown]
# ## Model loss graph

# %%
for n_fold in range(N_FOLDS):
    print('Fold: %d' % n_fold)
    sns.set(style="whitegrid")
    plot_metrics(history_list[n_fold], metric_list=['loss', 'spearman'])
# Out:
# Fold: 0

# %% [markdown]
# # Evaluation

# %%
metrics_df = metric_list[0][['Label', 'Train', 'Validation']].copy()
metrics_df.columns = ['Label', 'Train_fold_0', 'Valid_fold_0']

for n_fold in range(1, N_FOLDS):
    metrics_df_idx = metric_list[n_fold][['Train', 'Validation']].copy()
    metrics_df_idx.columns = ['Train_fold_%d' % n_fold, 'Valid_fold_%d' % n_fold]
    metrics_df = pd.concat([metrics_df, metrics_df_idx], axis=1)

metrics_df['Train'] = 0
metrics_df['Validation'] = 0
for n_fold in range(N_FOLDS):
    metrics_df['Train'] += metrics_df['Train_fold_%d' % n_fold] / N_FOLDS
    metrics_df['Validation'] += metrics_df['Valid_fold_%d' % n_fold] / N_FOLDS

metrics_df['Var'] = metrics_df['Train'] - metrics_df['Validation']
display(metrics_df.style.applymap(color_map))
# Out:
# <style  type="text/css" >
#     #T_a33b3346_3a4f_11ea_90cf_db827a44644arow0_col0 {
#             color:  black;
#         }    #T_a33b3346_3a4f_11ea_90cf_db827a44644arow0_col1 {
#             color:  black;
#         }    #T_a33b3346_3a4f_11ea_90cf_db827a44644arow0_col2 {
#             color:  black;
#         }    #T_a33b3346_3a4f_11ea_90cf_db827a44644arow0_col3 {
#             color:  black;
#         }    #T_a33b3346_3a4f_11ea_90cf_db827a44644arow0_col4 {
#             color:  black;
#         }    #T_a33b3346_3a4f_11ea_90cf_db827a44644arow0_col5 {
#             color:  purple;
#         }    #T_a33b3346_3a4f_11ea_90cf_db827a44644arow1_col0 {
#             color:  black;
#         }    #T_a33b3346_3a4f_11ea_90cf_db827a44644arow1_col1 {
#             color:  black;
#         }    #T_a33b3346_3a4f_11ea_90cf_db827a44644arow1_col2 {
#             color:  black;
#         }    #T_a33b3346_3a4f_11ea_90cf_db827a44644arow1_col3 {
#             color:  black;
#         }    #T_a33b3346_3a4f_11ea_90cf_db827a44644arow1_col4 {
#             color:  black;
#         }    #T_a33b3346_3a4f_11ea_90cf_db827a44644arow1_col5 {
#             color:  purple;
#         }    #T_a33b3346_3a4f_11ea_90cf_db827a44644arow2_col0 {
#             color:  black;
#         }    #T_a33b3346_3a4f_11ea_90cf_db827a44644arow2_col1 {
#             color:  black;
#         }    #T_a33b3346_3a4f_11ea_90cf_db827a44644arow2_col2 {
#             color:  black;
#         }    #T_a33b3346_3a4f_11ea_90cf_db827a44644arow2_col3 {
#             color:  black;
#         }    #T_a33b3346_3a4f_11ea_90cf_db827a44644arow2_col4 {
#             color:  black;
#         }    #T_a33b3346_3a4f_11ea_90cf_db827a44644arow2_col5 {
#             color:  orange;
#         }    #T_a33b3346_3a4f_11ea_90cf_db827a44644arow3_col0 {
#             color:  black;
#         }    #T_a33b3346_3a4f_11ea_90cf_db827a44644arow3_col1 {
#             color:  black;
#         }    #T_a33b3346_3a4f_11ea_90cf_db827a44644arow3_col2 {
#             color:  black;
#         }    #T_a33b3346_3a4f_11ea_90cf_db827a44644arow3_col3 {
#             color:  black;
#         }    #T_a33b3346_3a4f_11ea_90cf_db827a44644arow3_col4 {
#             color:  black;
#         }    #T_a33b3346_3a4f_11ea_90cf_db827a44644arow3_col5 {
#             color:  purple;
#         }    #T_a33b3346_3a4f_11ea_90cf_db827a44644arow4_col0 {
#             color:  black;
#         }    #T_a33b3346_3a4f_11ea_90cf_db827a44644arow4_col1 {
#             color:  black;
#         }    #T_a33b3346_3a4f_11ea_90cf_db827a44644arow4_col2 {
#             color:  black;
#         }    #T_a33b3346_3a4f_11ea_90cf_db827a44644arow4_col3 {
#             color:  black;
#         }    #T_a33b3346_3a4f_11ea_90cf_db827a44644arow4_col4 {
#             color:  black;
#         }    #T_a33b3346_3a4f_11ea_90cf_db827a44644arow4_col5 {
#             color:  purple;
#         }    #T_a33b3346_3a4f_11ea_90cf_db827a44644arow5_col0 {
#             color:  black;
#         }    #T_a33b3346_3a4f_11ea_90cf_db827a44644arow5_col1 {
#             color:  black;
#         }    #T_a33b3346_3a4f_11ea_90cf_db827a44644arow5_col2 {
#             color:  black;
#         }    #T_a33b3346_3a4f_11ea_90cf_db827a44644arow5_col3 {
#             color:  black;
#         }    #T_a33b3346_3a4f_11ea_90cf_db827a44644arow5_col4 {
#             color:  black;
#         }    #T_a33b3346_3a4f_11ea_90cf_db827a44644arow5_col5 {
#             color:  purple;
#         }    #T_a33b3346_3a4f_11ea_90cf_db827a44644arow6_col0 {
#             color:  black;
#         }    #T_a33b3346_3a4f_11ea_90cf_db827a44644arow6_col1 {
#             color:  black;
#         }    #T_a33b3346_3a4f_11ea_90cf_db827a44644arow6_col2 {
#             color:  black;
#         }    #T_a33b3346_3a4f_11ea_90cf_db827a44644arow6_col3 {
#             color:  black;
#         }    #T_a33b3346_3a4f_11ea_90cf_db827a44644arow6_col4 {
#             color:  black;
#         }    #T_a33b3346_3a4f_11ea_90cf_db827a44644arow6_col5 {
#             color:  orange;
#         }    #T_a33b3346_3a4f_11ea_90cf_db827a44644arow7_col0 {
#             color:  black;
#         }    #T_a33b3346_3a4f_11ea_90cf_db827a44644arow7_col1 {
#             color:  black;
#         }    #T_a33b3346_3a4f_11ea_90cf_db827a44644arow7_col2 {
#             color:  black;
#         }    #T_a33b3346_3a4f_11ea_90cf_db827a44644arow7_col3 {
#             color:  black;
#         }    #T_a33b3346_3a4f_11ea_90cf_db827a44644arow7_col4 {
#             color:  black;
#         }    #T_a33b3346_3a4f_11ea_90cf_db827a44644arow7_col5 {
#             color:  orange;
#         }    #T_a33b3346_3a4f_11ea_90cf_db827a44644arow8_col0 {
#             color:  black;
#         }    #T_a33b3346_3a4f_11ea_90cf_db827a44644arow8_col1 {
#             color:  black;
#         }    #T_a33b3346_3a4f_11ea_90cf_db827a44644arow8_col2 {
#             color:  black;
#         }    #T_a33b3346_3a4f_11ea_90cf_db827a44644arow8_col3 {
#             color:  black;
#         }    #T_a33b3346_3a4f_11ea_90cf_db827a44644arow8_col4 {
#             color:  black;
#         }    #T_a33b3346_3a4f_11ea_90cf_db827a44644arow8_col5 {
#             color:  orange;
#         }    #T_a33b3346_3a4f_11ea_90cf_db827a44644arow9_col0 {
#             color:  black;
#         }    #T_a33b3346_3a4f_11ea_90cf_db827a44644arow9_col1 {
#             color:  black;
#         }    #T_a33b3346_3a4f_11ea_90cf_db827a44644arow9_col2 {
#             color:  black;
#         }    #T_a33b3346_3a4f_11ea_90cf_db827a44644arow9_col3 {
#             color:  black;
#         }    #T_a33b3346_3a4f_11ea_90cf_db827a44644arow9_col4 {
#             color:  black;
#         }    #T_a33b3346_3a4f_11ea_90cf_db827a44644arow9_col5 {
#             color:  purple;
#         }    #T_a33b3346_3a4f_11ea_90cf_db827a44644arow10_col0 {
#             color:  black;
#         }    #T_a33b3346_3a4f_11ea_90cf_db827a44644arow10_col1 {
#             color:  black;
#         }    #T_a33b3346_3a4f_11ea_90cf_db827a44644arow10_col2 {
#             color:  black;
#         }    #T_a33b3346_3a4f_11ea_90cf_db827a44644arow10_col3 {
#             color:  black;
#         }    #T_a33b3346_3a4f_11ea_90cf_db827a44644arow10_col4 {
#             color:  black;
#         }    #T_a33b3346_3a4f_11ea_90cf_db827a44644arow10_col5 {
#             color:  orange;
#         }    #T_a33b3346_3a4f_11ea_90cf_db827a44644arow11_col0 {
#             color:  black;
#         }    #T_a33b3346_3a4f_11ea_90cf_db827a44644arow11_col1 {
#             color:  black;
#         }    #T_a33b3346_3a4f_11ea_90cf_db827a44644arow11_col2 {
#             color:  black;
#         }    #T_a33b3346_3a4f_11ea_90cf_db827a44644arow11_col3 {
#             color:  black;
#         }    #T_a33b3346_3a4f_11ea_90cf_db827a44644arow11_col4 {
#             color:  black;
#         }    #T_a33b3346_3a4f_11ea_90cf_db827a44644arow11_col5 {
#             color:  orange;
#         }    #T_a33b3346_3a4f_11ea_90cf_db827a44644arow12_col0 {
#             color:  black;
#         }    #T_a33b3346_3a4f_11ea_90cf_db827a44644arow12_col1 {
#             color:  orange;
#         }    #T_a33b3346_3a4f_11ea_90cf_db827a44644arow12_col2 {
#             color:  purple;
#         }    #T_a33b3346_3a4f_11ea_90cf_db827a44644arow12_col3 {
#             color:  orange;
#         }    #T_a33b3346_3a4f_11ea_90cf_db827a44644arow12_col4 {
#             color:  purple;
#         }    #T_a33b3346_3a4f_11ea_90cf_db827a44644arow12_col5 {
#             color:  purple;
#         }    #T_a33b3346_3a4f_11ea_90cf_db827a44644arow13_col0 {
#             color:  black;
#         }    #T_a33b3346_3a4f_11ea_90cf_db827a44644arow13_col1 {
#             color:  black;
#         }    #T_a33b3346_3a4f_11ea_90cf_db827a44644arow13_col2 {
#             color:  black;
#         }    #T_a33b3346_3a4f_11ea_90cf_db827a44644arow13_col3 {
#             color:  black;
#         }    #T_a33b3346_3a4f_11ea_90cf_db827a44644arow13_col4 {
#             color:  black;
#         }    #T_a33b3346_3a4f_11ea_90cf_db827a44644arow13_col5 {
#             color:  orange;
#         }    #T_a33b3346_3a4f_11ea_90cf_db827a44644arow14_col0 {
#             color:  black;
#         }    #T_a33b3346_3a4f_11ea_90cf_db827a44644arow14_col1 {
#             color:  green;
#         }    #T_a33b3346_3a4f_11ea_90cf_db827a44644arow14_col2 {
#             color:  black;
#         }    #T_a33b3

# %% [markdown]
# ## By category

# %%
category_metrics_df = category_metric_list[0][['Label', 'Train', 'Validation']].copy()
category_metrics_df.columns = ['Label', 'Train_fold_0', 'Valid_fold_0']

for n_fold in range(1, N_FOLDS):
    category_metrics_df_idx = category_metric_list[n_fold][['Train', 'Validation']].copy()
    category_metrics_df_idx.columns = ['Train_fold_%d' % n_fold, 'Valid_fold_%d' % n_fold]
    category_metrics_df = pd.concat([category_metrics_df, category_metrics_df_idx], axis=1)
    
category_metrics_df['Train'] = 0
category_metrics_df['Validation'] = 0
for n_fold in range(N_FOLDS):
    category_metrics_df['Train'] += category_metrics_df['Train_fold_%d' % n_fold] / N_FOLDS
    category_metrics_df['Validation'] += category_metrics_df['Valid_fold_%d' % n_fold] / N_FOLDS
    
category_metrics_df['Var'] = category_metrics_df['Train'] - category_metrics_df['Validation']
display(category_metrics_df.style.applymap(color_map))
# Out:
# <style  type="text/css" >
#     #T_a345ef34_3a4f_11ea_90cf_db827a44644arow0_col0 {
#             color:  black;
#         }    #T_a345ef34_3a4f_11ea_90cf_db827a44644arow0_col1 {
#             color:  black;
#         }    #T_a345ef34_3a4f_11ea_90cf_db827a44644arow0_col2 {
#             color:  black;
#         }    #T_a345ef34_3a4f_11ea_90cf_db827a44644arow0_col3 {
#             color:  black;
#         }    #T_a345ef34_3a4f_11ea_90cf_db827a44644arow0_col4 {
#             color:  black;
#         }    #T_a345ef34_3a4f_11ea_90cf_db827a44644arow0_col5 {
#             color:  purple;
#         }    #T_a345ef34_3a4f_11ea_90cf_db827a44644arow1_col0 {
#             color:  black;
#         }    #T_a345ef34_3a4f_11ea_90cf_db827a44644arow1_col1 {
#             color:  black;
#         }    #T_a345ef34_3a4f_11ea_90cf_db827a44644arow1_col2 {
#             color:  black;
#         }    #T_a345ef34_3a4f_11ea_90cf_db827a44644arow1_col3 {
#             color:  black;
#         }    #T_a345ef34_3a4f_11ea_90cf_db827a44644arow1_col4 {
#             color:  black;
#         }    #T_a345ef34_3a4f_11ea_90cf_db827a44644arow1_col5 {
#             color:  purple;
#         }    #T_a345ef34_3a4f_11ea_90cf_db827a44644arow2_col0 {
#             color:  black;
#         }    #T_a345ef34_3a4f_11ea_90cf_db827a44644arow2_col1 {
#             color:  black;
#         }    #T_a345ef34_3a4f_11ea_90cf_db827a44644arow2_col2 {
#             color:  black;
#         }    #T_a345ef34_3a4f_11ea_90cf_db827a44644arow2_col3 {
#             color:  black;
#         }    #T_a345ef34_3a4f_11ea_90cf_db827a44644arow2_col4 {
#             color:  black;
#         }    #T_a345ef34_3a4f_11ea_90cf_db827a44644arow2_col5 {
#             color:  orange;
#         }    #T_a345ef34_3a4f_11ea_90cf_db827a44644arow3_col0 {
#             color:  black;
#         }    #T_a345ef34_3a4f_11ea_90cf_db827a44644arow3_col1 {
#             color:  black;
#         }    #T_a345ef34_3a4f_11ea_90cf_db827a44644arow3_col2 {
#             color:  orange;
#         }    #T_a345ef34_3a4f_11ea_90cf_db827a44644arow3_col3 {
#             color:  black;
#         }    #T_a345ef34_3a4f_11ea_90cf_db827a44644arow3_col4 {
#             color:  orange;
#         }    #T_a345ef34_3a4f_11ea_90cf_db827a44644arow3_col5 {
#             color:  orange;
#         }    #T_a345ef34_3a4f_11ea_90cf_db827a44644arow4_col0 {
#             color:  black;
#         }    #T_a345ef34_3a4f_11ea_90cf_db827a44644arow4_col1 {
#             color:  black;
#         }    #T_a345ef34_3a4f_11ea_90cf_db827a44644arow4_col2 {
#             color:  black;
#         }    #T_a345ef34_3a4f_11ea_90cf_db827a44644arow4_col3 {
#             color:  black;
#         }    #T_a345ef34_3a4f_11ea_90cf_db827a44644arow4_col4 {
#             color:  black;
#         }    #T_a345ef34_3a4f_11ea_90cf_db827a44644arow4_col5 {
#             color:  orange;
#         }</style><table id="T_a345ef34_3a4f_11ea_90cf_db827a44644a" ><thead>    <tr>        <th class="blank level0" ></th>        <th class="col_heading level0 col0" >Label</th>        <th class="col_heading level0 col1" >Train_fold_0</th>        <th class="col_heading level0 col2" >Valid_fold_0</th>        <th class="col_heading level0 col3" >Train</th>        <th class="col_heading level0 col4" >Validation</th>        <th class="col_heading level0 col5" >Var</th>    </tr></thead><tbody>
#                 <tr>
#                         <th id="T_a345ef34_3a4f_11ea_90cf_db827a44644alevel0_row0" class="row_heading level0 row0" >0</th>
#                         <td id="T_a345ef34_3a4f_11ea_90cf_db827a44644arow0_col0" class="data row0 col0" >LIFE_ARTS</td>
#                         <td id="T_a345ef34_3a4f_11ea_90cf_db827a44644arow0_col1" class="data row0 col1" >0.535</td>
#                         <td id="T_a345ef34_3a4f_11ea_90cf_db827a44644arow0_col2" class="data row0 col2" >0.439</td>
#                         <td id="T_a345ef34_3a4f_11ea_90cf_db827a44644arow0_col3" class="data row0 col3" >0.535</td>
#                         <td id="T_a345ef34_3a4f_11ea_90cf_db827a44644arow0_col4" class="data row0 col4" >0.439</td>
#                         <td id="T_a345ef34_3a4f_11ea_90cf_db827a44644arow0_col5" class="data row0 col5" >0.096</td>
#             </tr>
#             <tr>
#                         <th id="T_a345ef34_3a4f_11ea_90cf_db827a44644alevel0_row1" class="row_heading level0 row1" >1</th>
#                         <td id="T_a345ef34_3a4f_11ea_90cf_db827a44644arow1_col0" class="data row1 col0" >SCIENCE</td>
#                         <td id="T_a345ef34_3a4f_11ea_90cf_db827a44644arow1_col1" class="data row1 col1" >0.516</td>
#                         <td id="T_a345ef34_3a4f_11ea_90cf_db827a44644arow1_col2" class="data row1 col2" >0.417</td>
#                         <td id="T_a345ef34_3a4f_11ea_90cf_db827a44644arow1_col3" class="data row1 col3" >0.516</td>
#                         <td id="T_a345ef34_3a4f_11ea_90cf_db827a44644arow1_col4" class="data row1 col4" >0.417</td>
#                         <td id="T_a345ef34_3a4f_11ea_90cf_db827a44644arow1_col5" class="data row1 col5" >0.099</td>
#             </tr>
#             <tr>
#                         <th id="T_a345ef34_3a4f_11ea_90cf_db827a44644alevel0_row2" class="row_heading level0 row2" >2</th>
#                         <td id="T_a345ef34_3a4f_11ea_90cf_db827a44644arow2_col0" class="data row2 col0" >CULTURE</td>
#                         <td id="T_a345ef34_3a4f_11ea_90cf_db827a44644arow2_col1" class="data row2 col1" >0.531</td>
#                         <td id="T_a345ef34_3a4f_11ea_90cf_db827a44644arow2_col2" class="data row2 col2" >0.415</td>
#                         <td id="T_a345ef34_3a4f_11ea_90cf_db827a44644arow2_col3" class="data row2 col3" >0.531</td>
#                         <td id="T_a345ef34_3a4f_11ea_90cf_db827a44644arow2_col4" class="data row2 col4" >0.415</td>
#                         <td id="T_a345ef34_3a4f_11ea_90cf_db827a44644arow2_col5" class="data row2 col5" >0.116</td>
#             </tr>
#             <tr>
#                         <th id="T_a345ef34_3a4f_11ea_90cf_db827a44644alevel0_row3" class="row_heading level0 row3" >3</th>
#                         <td id="T_a345ef34_3a4f_11ea_90cf_db827a44644arow3_col0" class="data row3 col0" >STACKOVERFLOW</td>
#                         <td id="T_a345ef34_3a4f_11ea_90cf_db827a44644arow3_col1" class="data row3 col1" >0.392</td>
#                         <td id="T_a345ef34_3a4f_11ea_90cf_db827a44644arow3_col2" class="data row3 col2" >0.268</td>
#                         <td id="T_a345ef34_3a4f_11ea_90cf_db827a44644arow3_col3" class="data row3 col3" >0.392</td>
#                         <td id="T_a345ef34_3a4f_11ea_90cf_db827a44644arow3_col4" class="data row3 col4" >0.268</td>
#                         <td id="T_a345ef34_3a4f_11ea_90cf_db827a44644arow3_col5" class="data row3 col5" >0.124</td>
#             </tr>
#             <tr>
#                         <th id="T_a345ef34_3a4f_11ea_90cf_db827a44644alevel0_row4" class="row_heading level0 row4" >4</th>
#                         <td id="T_a345ef34_3a4f_11ea_90cf_db827a44644arow4_col0" class="data row4 col0" >TECHNOLOGY</td>
#                         <td id="T_a345ef34_3a4f_11ea_90cf_db827a44644arow4_col1" class="data row4 col1" >0.468</td>
#                         <td id="T_a345ef34_3a4f_11ea_90cf_db827a44644arow4_col2" class="data row4 col2" >0.359</td>
#                         <td id="T_a345ef34_3a4f_11ea_90cf_db827a44644arow4_col3" class="data row4 col3" >0.468</td>
#                         <td id="T_a345ef34_3a4f_11ea_90cf_db827a44644arow4_col4" class="data row4 col4" >0.359</td>
#                         <td id="T_a345ef34_3a4f_11ea_90cf_db827a44644arow4_col5" class="data row4 col5" >0.109</td>
#             </tr>
#     </tbody></table>
