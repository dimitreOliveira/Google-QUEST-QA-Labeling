# %% [markdown]
# ## Dependencies

# %%
import gc
import re
import warnings
from joblib import dump
import tensorflow_hub as hub
from sklearn.preprocessing import OneHotEncoder, MinMaxScaler
from tensorflow.keras import Model, optimizers
from tensorflow.keras.callbacks import ReduceLROnPlateau
from tensorflow.keras.preprocessing.text import Tokenizer
from tensorflow.keras.preprocessing.sequence import pad_sequences
from tensorflow.keras.layers import Lambda, Input, Dense, Dropout, Concatenate, BatchNormalization, Activation, Average, Add, Reshape, Attention
from tensorflow.keras.layers import GlobalAveragePooling1D, Embedding, LSTM, Conv1D, SpatialDropout1D, Bidirectional, Flatten, Bidirectional
from googleqa_utilityscript import *


SEED = 0
seed_everything(SEED)
warnings.filterwarnings("ignore")

# %% [markdown]
# ## Load data

# %%
module_url = '/kaggle/input/universalsentenceencodermodels/universal-sentence-encoder-models/use'
model_path = '/kaggle/working/model.h5'
tokenizer_path = '/kaggle/working/tokenizer.joblib'
encoder_path = '/kaggle/input/pickled-glove840b300d-for-10sec-loading/glove.840B.300d.pkl'
category_encoder_path = '/kaggle/working/category_encoder.joblib'
host_encoder_path = '/kaggle/working/host_encoder.joblib'
scaler_path = '/kaggle/working/scaler.joblib'

hold_out = pd.read_csv('/kaggle/input/googleqa-mldataset/hold-out.csv')
test = pd.read_csv('/kaggle/input/google-quest-challenge/test.csv')
train = hold_out[hold_out['set'] == 'train']
validation = hold_out[hold_out['set'] == 'validation']

print('Train samples: %s' % len(train))
print('Validation samples: %s' % len(validation))
display(train.head())
# Out:
# Train samples: 4863
# Validation samples: 1216
#    qa_id                                     question_title  \
# 0   3895  Magento (1.7) Bundled Product with FREE Produc...
# 1   3131                             Find router on network
# 2   1507  Negatively curved metrics minimizing the lengt...
# 3   6784               Isn’t the FAQ label obsolete by now?
# 4   2135  Changing background image one time on responsi...
#
#                                        question_body question_user_name  \
# 0  I'm looking to create a bundle offer where cus...                Joe
# 1  I've just bought a Belkin N+ Wireless Router. ...                Guy
# 2  Good afternoon everyone !\n\nI have the follow...            Selim G
# 3  Don’t get me wrong in the beginning of reading...     Benny Skogberg
# 4  The code I'm using is this one \n\nbackground:...        user2141649
#
#                               question_user_page  \
# 0  https://magento.stackexchange.com/users/16572
# 1               https://superuser.com/users/3248
# 2           https://mathoverflow.net/users/25511
# 3        https://ux.stackexchange.com/users/4679
# 4        https://stackoverflow.com/users/2141649
#
#                                               answer   answer_user_name  \
# 0  Since the third item is fixed, you can use sho...  Fabian Schmengler
# 1  You likely have the router plugged in to the m...             John T
# 2  A very partial answer: by the results of Richa...         Igor Rivin
# 3  Isn’t the FAQ label obsolete by now? \n\nI'd s...        Solracnapod
# 4  &lt;!DOCTYPE html&gt;\n&lt;html&gt;\n&lt;head&...           akkimads
#
#                               answer_user_page  \
# 0  https://magento.stackexchange.com/users/243
# 1             https://superuser.com/users/1931
# 2         https://mathoverflow.net/users/11142
# 3     https://ux.stackexchange.com/users/13153
# 4      https://stackoverflow.com/users/2375373
#
#                                                  url       category  ...  \
# 0  http://magento.stackexchange.com/questions/668...     TECHNOLOGY  ...
# 1               http://superuser.com/questions/87212     TECHNOLOGY  ...
# 2           http://mathoverflow.net/questions/203422        SCIENCE  ...
# 3  http://ux.stackexchange.com/questions/18600/is...     TECHNOLOGY  ...
# 4  http://stackoverflow.com/questions/16359492/ch...  STACKOVERFLOW  ...
#
#   answer_helpful  answer_level_of_information  answer_plausible  \
# 0       0.888889                     0.666667               1.0
# 1       1.000000                     0.666667               1.0
# 2       0.888889                     0.333333               1.0
# 3       0.888889                     0.666667               1.0
# 4       0.888889                     0.500000               1.0
#
#    answer_relevance  answer_satisfaction  answer_type_instructions  \
# 0               1.0             0.933333                  1.000000
# 1               1.0             0.866667                  0.666667
# 2               1.0             0.700000                  0.333333
# 3               1.0             0.933333                  0.000000
# 4               1.0             0.800000                  1.000000
#
#    answer_type_procedure  answer_type_reason_explanation  answer_well_written  \
# 0               0.000000                        0.333333             0.888889
# 1               0.000000                        1.000000             1.000000
# 2               0.333333                        1.000000             0.888889
# 3               0.000000                        0.666667             1.000000
# 4               0.000000                        0.000000             0.777778
#
#      set
# 0  train
# 1  train
# 2  train
# 3  train
# 4  train
#
# [5 rows x 42 columns]

# %%
question_target_cols = ['question_asker_intent_understanding','question_body_critical', 'question_conversational', 
                        'question_expect_short_answer', 'question_fact_seeking', 'question_has_commonly_accepted_answer',
                        'question_interestingness_others', 'question_interestingness_self', 'question_multi_intent', 
                        'question_not_really_a_question', 'question_opinion_seeking', 'question_type_choice',
                        'question_type_compare', 'question_type_consequence', 'question_type_definition', 
                        'question_type_entity', 'question_type_instructions', 'question_type_procedure',
                        'question_type_reason_explanation', 'question_type_spelling', 'question_well_written']
answer_target_cols = ['answer_helpful', 'answer_level_of_information', 'answer_plausible', 'answer_relevance',
                      'answer_satisfaction', 'answer_type_instructions', 'answer_type_procedure', 
                      'answer_type_reason_explanation', 'answer_well_written']
target_cols = question_target_cols + answer_target_cols

# %% [markdown]
# ## Pre-process data

# %%
text_features = ['question_title', 'question_body', 'answer']

for feature in text_features:
    # Lower
    train[feature] = train[feature].apply(lambda x: x.lower())
    validation[feature] = validation[feature].apply(lambda x: x.lower())
    test[feature] = test[feature].apply(lambda x: x.lower())


# Text length
train['question_title_len'] = train['question_title'].apply(lambda x : len(x))
validation['question_title_len'] = validation['question_title'].apply(lambda x : len(x))
train['question_body_len'] = train['question_body'].apply(lambda x : len(x))
validation['question_body_len'] = validation['question_body'].apply(lambda x : len(x))
train['answer_len'] = train['answer'].apply(lambda x : len(x))
validation['answer_len'] = validation['answer'].apply(lambda x : len(x))

# Word count
train['question_title_word_cnt'] = train['question_title'].apply(lambda x : len(x.split(' ')))
validation['question_title_word_cnt'] = validation['question_title'].apply(lambda x : len(x.split(' ')))
train['question_body_word_cnt'] = train['question_body'].apply(lambda x : len(x.split(' ')))
validation['question_body_word_cnt'] = validation['question_body'].apply(lambda x : len(x.split(' ')))
train['answer_word_cnt'] = train['answer'].apply(lambda x : len(x.split(' ')))
validation['answer_word_cnt'] = validation['answer'].apply(lambda x : len(x.split(' ')))

# Unique word count
train['question_title_unique_word_cnt'] = train['question_title'].apply(lambda x : len(set(x.split(' '))))
validation['question_title_unique_word_cnt'] = validation['question_title'].apply(lambda x : len(set(x.split(' '))))
train['question_body_unique_word_cnt'] = train['question_body'].apply(lambda x : len(set(x.split(' '))))
validation['question_body_unique_word_cnt'] = validation['question_body'].apply(lambda x : len(set(x.split(' '))))
train['answer_unique_word_cnt'] = train['answer'].apply(lambda x : len(set(x.split(' '))))
validation['answer_unique_word_cnt'] = validation['answer'].apply(lambda x : len(set(x.split(' '))))

# Misspelings count
misspelling_mapping_set = set(misspelling_mapping.keys())
train['question_title_misspelings_cnt'] = train['question_title'].apply(lambda x : len(set(x.split(' ')) & misspelling_mapping_set))
validation['question_title_misspelings_cnt'] = validation['question_title'].apply(lambda x : len(set(x.split(' ')) & misspelling_mapping_set))
train['question_body_misspelings_cnt'] = train['question_body'].apply(lambda x : len(set(x.split(' ')) & misspelling_mapping_set))
validation['question_body_misspelings_cnt'] = validation['question_body'].apply(lambda x : len(set(x.split(' ')) & misspelling_mapping_set))
train['answer_misspelings_cnt'] = train['answer'].apply(lambda x : len(set(x.split(' ')) & misspelling_mapping_set))
validation['answer_misspelings_cnt'] = validation['answer'].apply(lambda x : len(set(x.split(' ')) & misspelling_mapping_set))

# Meta features
train['question_title_count'] = train['question_title'].apply(lambda x : x.count('?'))
validation['question_title_count'] = validation['question_title'].apply(lambda x : x.count('?'))
train['question_body_count'] = train['question_body'].apply(lambda x : x.count('?'))
validation['question_body_count'] = validation['question_body'].apply(lambda x : x.count('?'))
train['title_exp_count'] = train['question_title'].apply(lambda x : x.count('why'))
validation['title_exp_count'] = validation['question_title'].apply(lambda x : x.count('why'))
train['body_exp_count'] = train['question_body'].apply(lambda x : x.count('why'))
validation['body_exp_count'] = validation['question_body'].apply(lambda x : x.count('why'))
train['title_choice_count'] = train['question_title'].apply(lambda x : x.count('or'))
validation['title_choice_count'] = validation['question_title'].apply(lambda x : x.count('or'))
train['body_choice_count'] = train['question_body'].apply(lambda x : x.count('or'))
validation['body_choice_count'] = validation['question_body'].apply(lambda x : x.count('or'))
train['question_aswer_ratio'] = train['question_title_word_cnt'] / train['answer_word_cnt']
validation['question_aswer_ratio'] = validation['question_title_word_cnt'] / validation['answer_word_cnt']
train['same_author'] = train['question_user_page'] == train['answer_user_page']
validation['same_author'] = validation['question_user_page'] == validation['answer_user_page']


for feature in text_features:
    # Map contractions
    train[feature] = train[feature].apply(lambda x: map_contraction(x))
    validation[feature] = validation[feature].apply(lambda x: map_contraction(x))
    test[feature] = test[feature].apply(lambda x: map_contraction(x))
    # Trim text
    train[feature] = train[feature].apply(lambda x: x.strip())
    validation[feature] = validation[feature].apply(lambda x: x.strip())
    test[feature] = test[feature].apply(lambda x: x.strip())

for feature in text_features:
    train[feature + '_uncased'] = train[feature]
    validation[feature + '_uncased'] = validation[feature]
    test[feature + '_uncased'] = test[feature]

# %% [markdown]
# # Model parameters

# %%
EPOCHS = 50
BATCH_SIZE = 64
LEARNING_RATE = 1e-3
EMBEDDDING_SIZE = 512
N_CLASS = len(target_cols)
ES_PATIENCE = 8
RLROP_PATIENCE = 3
DECAY_DROP = 0.1
MAX_FEATURES = 100000
TITLE_MAX_LEN = 30
BODY_MAX_LEN = 100
ANSWER_MAX_LEN = 100

# %%
tokenizer = Tokenizer(num_words=MAX_FEATURES, lower=True)

tokenizer.fit_on_texts(list(train['question_title_uncased']) + list(validation['question_title_uncased']) + list(test['question_title_uncased']) +
                       list(train['question_body_uncased']) + list(validation['question_body_uncased']) + list(test['question_body_uncased']) +
                       list(train['answer_uncased']) + list(validation['answer_uncased']) + list(test['answer_uncased']))

# %% [markdown]
# ## Train/validation sets

# %%
ohe_category = OneHotEncoder(handle_unknown='ignore')
ohe_host = OneHotEncoder(handle_unknown='ignore')
ohe_category = ohe_category.fit(train[['category']])
ohe_host = ohe_host.fit(train[['host']])
scaler = MinMaxScaler()


# Train features
# X_train_title = train['question_title']
# X_train_body = train['question_body']
# X_train_answer = train['answer']
X_train_title_seq = train['question_title_uncased']
X_train_body_seq = train['question_body_uncased']
X_train_answer_seq = train['answer_uncased']
X_train_category = ohe_category.transform(train[['category']]).toarray()
X_train_host = ohe_host.transform(train[['host']]).toarray()
X_train_dense = train[['question_title_len', 'question_title_word_cnt', 'question_title_unique_word_cnt', 'question_title_misspelings_cnt', 
                       'question_body_len', 'question_body_word_cnt', 'question_body_unique_word_cnt', 'question_body_misspelings_cnt', 
                       'answer_len', 'answer_word_cnt', 'answer_unique_word_cnt', 'answer_misspelings_cnt', 
                       'question_title_count', 'question_body_count', 'title_exp_count', 'body_exp_count', 'title_choice_count', 
                       'body_choice_count', 'body_choice_count', 'question_aswer_ratio', 'same_author']]


# Tokenize the sentences
X_train_title_seq = tokenizer.texts_to_sequences(X_train_title_seq)
X_train_body_seq = tokenizer.texts_to_sequences(X_train_body_seq)
X_train_answer_seq = tokenizer.texts_to_sequences(X_train_answer_seq)

# Pad the sentences
X_train_title_seq = pad_sequences(X_train_title_seq, maxlen=TITLE_MAX_LEN)
X_train_body_seq = pad_sequences(X_train_body_seq, maxlen=BODY_MAX_LEN)
X_train_answer_seq = pad_sequences(X_train_answer_seq, maxlen=ANSWER_MAX_LEN)

scaler.fit(X_train_dense)
X_train_dense = scaler.transform(X_train_dense)

X_train = [X_train_title_seq, X_train_body_seq, X_train_answer_seq, X_train_category, X_train_host, X_train_dense]
Y_train = train[target_cols].values

# Validation features
# X_valid_title = validation['question_title']
# X_valid_body = validation['question_body']
# X_valid_answer = validation['answer']
X_valid_title_seq = validation['question_title_uncased']
X_valid_body_seq = validation['question_body_uncased']
X_valid_answer_seq = validation['answer_uncased']
X_valid_category = ohe_category.transform(validation[['category']]).toarray()
X_valid_host = ohe_host.transform(validation[['host']]).toarray()
X_valid_dense = validation[['question_title_len', 'question_title_word_cnt', 'question_title_unique_word_cnt', 'question_title_misspelings_cnt', 
                            'question_body_len', 'question_body_word_cnt', 'question_body_unique_word_cnt', 'question_body_misspelings_cnt', 
                            'answer_len', 'answer_word_cnt', 'answer_unique_word_cnt', 'answer_misspelings_cnt', 
                            'question_title_count', 'question_body_count', 'title_exp_count', 'body_exp_count', 'title_choice_count', 
                            'body_choice_count', 'body_choice_count', 'question_aswer_ratio', 'same_author']]

# Tokenize the sentences
X_valid_title_seq = tokenizer.texts_to_sequences(X_valid_title_seq)
X_valid_body_seq = tokenizer.texts_to_sequences(X_valid_body_seq)
X_valid_answer_seq = tokenizer.texts_to_sequences(X_valid_answer_seq)

# Pad the sentences
X_valid_title_seq = pad_sequences(X_valid_title_seq, maxlen=TITLE_MAX_LEN)
X_valid_body_seq = pad_sequences(X_valid_body_seq, maxlen=BODY_MAX_LEN)
X_valid_answer_seq = pad_sequences(X_valid_answer_seq, maxlen=ANSWER_MAX_LEN)

X_valid_dense = scaler.transform(X_valid_dense)

X_valid = [X_valid_title_seq, X_valid_body_seq, X_valid_answer_seq, X_valid_category, X_valid_host, X_valid_dense]
Y_valid = validation[target_cols].values


print('Train samples: %d' % len(Y_train))
print('Validation samples: %d' % len(Y_valid))
# Out:
# Train samples: 4863
# Validation samples: 1216

# %% [markdown]
# # Model

# %%
# use_embed = hub.load(module_url)

# def USEEmbedding(x):
#     return use_embed(tf.squeeze(tf.cast(x, tf.string)))

# def encoder_block(input_layer):
#     encoder = Lambda(USEEmbedding, output_shape=(EMBEDDDING_SIZE,))(input_layer)
    
#     return encoder

# %% [markdown]
# ## Load embedding

# %%
glove_embedding_matrix, glove_unknown_words = build_matrix(tokenizer.word_index, encoder_path, MAX_FEATURES)
print('n unknown words (GloVe): ', len(glove_unknown_words))
# Out:
# n unknown words (GloVe):  19913

# %%
# Title sequence
input_title_seq = Input(shape=(TITLE_MAX_LEN,), dtype=tf.float32, name='input_title_seq')
title = Embedding(*glove_embedding_matrix.shape, weights=[glove_embedding_matrix], trainable=False)(input_title_seq)
title = SpatialDropout1D(0.3)(title)
title = Bidirectional(LSTM(128, kernel_initializer='glorot_uniform'))(title)
title = Dropout(0.5)(title)
title = Dense(512, kernel_initializer='glorot_uniform')(title)
title = BatchNormalization()(title)
title_out = Activation('relu')(title)

# Body sequence
input_body_seq = Input(shape=(BODY_MAX_LEN,), dtype=tf.float32, name='input_body_seq')
body = Embedding(*glove_embedding_matrix.shape, weights=[glove_embedding_matrix], trainable=False)(input_body_seq)
body = SpatialDropout1D(0.3)(body)
body = Bidirectional(LSTM(256, return_sequences=True, kernel_initializer='glorot_uniform'))(body)
body = Bidirectional(LSTM(128, kernel_initializer='glorot_uniform'))(body)
body = Dropout(0.5)(body)
body = Dense(512, kernel_initializer='glorot_uniform')(body)
body = BatchNormalization()(body)
body_out = Activation('relu')(body)

# Answer sequence
input_answer_seq = Input(shape=(ANSWER_MAX_LEN,), dtype=tf.float32, name='input_answer_seq')
answer = Embedding(*glove_embedding_matrix.shape, weights=[glove_embedding_matrix], trainable=False)(input_answer_seq)
answer = SpatialDropout1D(0.3)(answer)
answer = Bidirectional(LSTM(256, return_sequences=True, kernel_initializer='glorot_uniform'))(answer)
answer = Bidirectional(LSTM(128, kernel_initializer='glorot_uniform'))(answer)
answer = Dropout(0.5)(answer)
answer = Dense(512, kernel_initializer='glorot_uniform')(answer)
answer = BatchNormalization()(answer)
answer_out = Activation('relu')(answer)

# Category
input_category = Input(shape=(X_train_category.shape[1],), dtype=tf.float32, name='input_category')
category = Embedding(X_train_category.shape[1], X_train_category.shape[1]//2)(input_category)
category_out = GlobalAveragePooling1D()(category)

# Host
input_host = Input(shape=(X_train_host.shape[1],), dtype=tf.float32, name='input_host')
host = Embedding(X_train_host.shape[1], X_train_host.shape[1]//2)(input_host)
host_out = GlobalAveragePooling1D()(host)

# Dense features
input_dense = Input(shape=(X_train_dense.shape[1],), dtype=tf.float32, name='input_dense')

# Output
output = Concatenate()([title_out, body_out, answer_out, category_out, host_out, input_dense])
output = Dropout(0.5)(output)
output = Dense(512, kernel_initializer='glorot_uniform')(output)
output = BatchNormalization()(output)
output = Activation('relu')(output)
output = Dropout(0.5)(output)
output = Dense(512, kernel_initializer='glorot_uniform')(output)
output = BatchNormalization()(output)
output = Activation('relu')(output)
output = Dense(N_CLASS, activation='sigmoid', kernel_initializer='glorot_uniform')(output)

model = Model(inputs=[input_title_seq, input_body_seq, input_answer_seq, input_category, input_host, input_dense], outputs=[output])

model.summary()
# Out:
# Model: "model"
# __________________________________________________________________________________________________
# Layer (type)                    Output Shape         Param #     Connected to
# ==================================================================================================
# input_body_seq (InputLayer)     [(None, 100)]        0
# __________________________________________________________________________________________________
# input_answer_seq (InputLayer)   [(None, 100)]        0
# __________________________________________________________________________________________________
# input_title_seq (InputLayer)    [(None, 30)]         0
# __________________________________________________________________________________________________
# embedding_1 (Embedding)         (None, 100, 300)     17402100    input_body_seq[0][0]
# __________________________________________________________________________________________________
# embedding_2 (Embedding)         (None, 100, 300)     17402100    input_answer_seq[0][0]
# __________________________________________________________________________________________________
# embedding (Embedding)           (None, 30, 300)      17402100    input_title_seq[0][0]
# __________________________________________________________________________________________________
# spatial_dropout1d_1 (SpatialDro (None, 100, 300)     0           embedding_1[0][0]
# __________________________________________________________________________________________________
# spatial_dropout1d_2 (SpatialDro (None, 100, 300)     0           embedding_2[0][0]
# __________________________________________________________________________________________________
# spatial_dropout1d (SpatialDropo (None, 30, 300)      0           embedding[0][0]
# __________________________________________________________________________________________________
# bidirectional_1 (Bidirectional) (None, 100, 512)     1140736     spatial_dropout1d_1[0][0]
# __________________________________________________________________________________________________
# bidirectional_3 (Bidirectional) (None, 100, 512)     1140736     spatial_dropout1d_2[0][0]
# __________________________________________________________________________________________________
# bidirectional (Bidirectional)   (None, 256)          439296      spatial_dropout1d[0][0]
# __________________________________________________________________________________________________
# bidirectional_2 (Bidirectional) (None, 256)          656384      bidirectional_1[0][0]
# __________________________________________________________________________________________________
# bidirectional_4 (Bidirectional) (None, 256)          656384      bidirectional_3[0][0]
# __________________________________________________________________________________________________
# dropout (Dropout)               (None, 256)          0           bidirectional[0][0]
# __________________________________________________________________________________________________
# dropout_1 (Dropout)             (None, 256)          0           bidirectional_2[0][0]
# __________________________________________________________________________________________________
# dropout_2 (Dropout)             (None, 256)          0           bidirectional_4[0][0]
# __________________________________________________________________________________________________
# dense (Dense)                   (None, 512)          131584      dropout[0][0]
# __________________________________________________________________________________________________
# dense_1 (Dense)                 (None, 512)          131584      dropout_1[0][0]
# __________________________________________________________________________________________________
# dense_2 (Dense)                 (None, 512)          131584      dropout_2[0][0]
# __________________________________________________________________________________________________
# input_category (InputLayer)     [(None, 5)]          0
# __________________________________________________________________________________________________
# input_host (InputLayer)         [(None, 62)]         0
# __________________________________________________________________________________________________
# batch_normalization (BatchNorma (None, 512)          2048        dense[0][0]
# __________________________________________________________________________________________________
# batch_normalization_1 (BatchNor (None, 512)          2048        dense_1[0][0]
# __________________________________________________________________________________________________
# batch_normalization_2 (BatchNor (None, 512)          2048        dense_2[0][0]
# __________________________________________________________________________________________________
# embedding_3 (Embedding)         (None, 5, 2)         10          input_category[0][0]
# __________________________________________________________________________________________________
# embedding_4 (Embedding)         (None, 62, 31)       1922        input_host[0][0]
# __________________________________________________________________________________________________
# activation (Activation)         (None, 512)          0           batch_normalization[0][0]
# __________________________________________________________________________________________________
# activation_1 (Activation)       (None, 512)          0           batch_normalization_1[0][0]
# __________________________________________________________________________________________________
# activation_2 (Activation)       (None, 512)          0           batch_normalization_2[0][0]
# __________________________________________________________________________________________________
# global_average_pooling1d (Globa (None, 2)            0           embedding_3[0][0]
# __________________________________________________________________________________________________
# global_average_pooling1d_1 (Glo (None, 31)           0           embedding_4[0][0]
# __________________________________________________________________________________________________
# input_dense (InputLayer)        [(None, 21)]         0
# __________________________________________________________________________________________________
# concatenate (Concatenate)       (None, 1590)         0           activation[0][0]
#                                                                  activation_1[0][0]
#                                                                  activation_2[0][0]
#                                                                  global_average_pooling1d[0][0]
#                                                                  global_average_pooling1d_1[0][0]
#                                                                  input_dense[0][0]
# __________________________________________________________________________________________________
# dropout_3 (Dropout)             (None, 1590)         0           concatenate[0][0]
# __________________________________________________________________________________________________
# dense_3 (Dense)                 (None, 512)          814592      dropout_3[0][0]
# __________________________________________________________________________________________________
# batch_normalization_3 (BatchNor (None, 512)          2048        dense_3[0][0]
# __________________________________________________________________________________________________
# activation_3 (Activation)       (None, 512)          0           batch_normalization_3[0][0]
# __________________________________________________________________________________________________
# dropout_4 (Dropout)             (None, 512)          0           activation_3[0][0]
# __________________________________________________________________________________________________
# dense_4 (Dense)                 (None, 512)          262656      dropout_4[0][0]
# __________________________________________________________________________________________________
# batch_normalization_4 (BatchNor (None, 512)          2048        dense_4[0][0]
# __________________________________________________________________________________________________
# activation_4 (Activation)       (None, 512)          0           batch_normalization_4[0][0]
# __________________________________________________________________________________________________
# dense_5 (Dense)                 (None, 30)           15390       activation_4[0][0]
# ==================================================================================================
# Total params: 57,739,398
# Trainable params: 5,527,978
# Non-trainable params: 52,211,420
# __________________________________________________________________________________________________

# %% [markdown]
# # Train model

# %%
rlrop = ReduceLROnPlateau(monitor='val_loss', mode='min', patience=RLROP_PATIENCE, factor=DECAY_DROP, min_lr=1e-7, verbose=1)
spearmanCallback = SpearmanRhoCallback(training_data=(X_train, Y_train), validation_data=(X_valid, Y_valid), monitor='val_loss', mode='min', patience=ES_PATIENCE)
callback_list = [rlrop, spearmanCallback]

optimizer = optimizers.Adam(LEARNING_RATE)
model.compile(optimizer=optimizer, loss='binary_crossentropy')

history = model.fit(X_train, Y_train, 
                    validation_data=(X_valid, Y_valid), 
                    callbacks=callback_list, 
                    batch_size=BATCH_SIZE, 
                    epochs=EPOCHS, 
                    verbose=2).history
# Out:
# Train on 4863 samples, validate on 1216 samples
# Epoch 1/50
# spearman-rho: 0.2107 val_spearman-rho: 0.2038
# 4863/4863 - 327s - loss: 0.4634 - val_loss: 0.5086
# Epoch 2/50
# spearman-rho: 0.2480 val_spearman-rho: 0.2402
# 4863/4863 - 296s - loss: 0.4192 - val_loss: 0.4631
# Epoch 3/50
# spearman-rho: 0.2707 val_spearman-rho: 0.2614
# 4863/4863 - 300s - loss: 0.4103 - val_loss: 0.4281
# Epoch 4/50
# spearman-rho: 0.2910 val_spearman-rho: 0.2746
# 4863/4863 - 300s - loss: 0.4022 - val_loss: 0.4155
# Epoch 5/50
# spearman-rho: 0.3085 val_spearman-rho: 0.2897
# 4863/4863 - 297s - loss: 0.3989 - val_loss: 0.4001
# Epoch 6/50
# spearman-rho: 0.3144 val_spearman-rho: 0.2973
# 4863/4863 - 299s - loss: 0.3957 - val_loss: 0.3982
# Epoch 7/50
# spearman-rho: 0.3284 val_spearman-rho: 0.3083
# 4863/4863 - 297s - loss: 0.3946 - val_loss: 0.3963
# Epoch 8/50
# spearman-rho: 0.3332 val_spearman-rho: 0.3033
# 4863/4863 - 298s - loss: 0.3908 - val_loss: 0.3941
# Epoch 9/50
# spearman-rho: 0.3511 val_spearman-rho: 0.3157
# 4863/4863 - 299s - loss: 0.3882 - val_loss: 0.3927
# Epoch 10/50
# spearman-rho: 0.3552 val_spearman-rho: 0.3166
# 4863/4863 - 297s - loss: 0.3852 - val_loss: 0.3923
# Epoch 11/50
# spearman-rho: 0.3674 val_spearman-rho: 0.3185
# 4863/4863 - 297s - loss: 0.3836 - val_loss: 0.3907
# Epoch 12/50
# spearman-rho: 0.3658 val_spearman-rho: 0.3219
# 4863/4863 - 302s - loss: 0.3811 - val_loss: 0.3887
# Epoch 13/50
# spearman-rho: 0.3891 val_spearman-rho: 0.3306
# 4863/4863 - 297s - loss: 0.3791 - val_loss: 0.3856
# Epoch 14/50
# spearman-rho: 0.3931 val_spearman-rho: 0.3271
# 4863/4863 - 297s - loss: 0.3765 - val_loss: 0.3880
# Epoch 15/50
# spearman-rho: 0.4058 val_spearman-rho: 0.3367
# 4863/4863 - 301s - loss: 0.3756 - val_loss: 0.3859
# Epoch 16/50
#
# Epoch 00016: ReduceLROnPlateau reducing learning rate to 0.00010000000474974513.
# spearman-rho: 0.4108 val_spearman-rho: 0.3355
# 4863/4863 - 299s - loss: 0.3731 - val_loss: 0.3870
# Epoch 17/50
# spearman-rho: 0.4242 val_spearman-rho: 0.3477
# 4863/4863 - 301s - loss: 0.3677 - val_loss: 0.3825
# Epoch 18/50
# spearman-rho: 0.4271 val_spearman-rho: 0.3483
# 4863/4863 - 303s - loss: 0.3663 - val_loss: 0.3822
# Epoch 19/50
# spearman-rho: 0.4295 val_spearman-rho: 0.3482
# 4863/4863 - 301s - loss: 0.3660 - val_loss: 0.3820
# Epoch 20/50
# spearman-rho: 0.4321 val_spearman-rho: 0.3493
# 4863/4863 - 298s - loss: 0.3652 - val_loss: 0.3816
# Epoch 21/50
# spearman-rho: 0.4340 val_spearman-rho: 0.3492
# 4863/4863 - 300s - loss: 0.3644 - val_loss: 0.3820
# Epoch 22/50
# spearman-rho: 0.4368 val_spearman-rho: 0.3488
# 4863/4863 - 298s - loss: 0.3634 - val_loss: 0.3822
# Epoch 23/50
#
# Epoch 00023: ReduceLROnPlateau reducing learning rate to 1.0000000474974514e-05.
# spearman-rho: 0.4390 val_spearman-rho: 0.3486
# 4863/4863 - 298s - loss: 0.3626 - val_loss: 0.3825
# Epoch 24/50
# spearman-rho: 0.4397 val_spearman-rho: 0.3488
# 4863/4863 - 298s - loss: 0.3623 - val_loss: 0.3823
# Epoch 25/50
# spearman-rho: 0.4402 val_spearman-rho: 0.3494
# Epoch 00024: early stopping
# 4863/4863 - 299s - loss: 0.3620 - val_loss: 0.3821

# %% [markdown]
# ## Model loss graph

# %%
sns.set(style="whitegrid")
plot_metrics(history, metric_list=['loss', 'spearman'])

# %% [markdown]
# # Evaluation

# %%
preds_train = model.predict(X_train)
preds_val = model.predict(X_valid)

display(get_metrics(Y_train, preds_train, Y_valid, preds_val, target_cols).style.applymap(color_map))
# Out:
# <style  type="text/css" >
#     #T_cdb09d88_2de2_11ea_b3ae_679ee520b2a6row0_col0 {
#             color:  black;
#         }    #T_cdb09d88_2de2_11ea_b3ae_679ee520b2a6row0_col1 {
#             color:  black;
#         }    #T_cdb09d88_2de2_11ea_b3ae_679ee520b2a6row0_col2 {
#             color:  black;
#         }    #T_cdb09d88_2de2_11ea_b3ae_679ee520b2a6row1_col0 {
#             color:  black;
#         }    #T_cdb09d88_2de2_11ea_b3ae_679ee520b2a6row1_col1 {
#             color:  black;
#         }    #T_cdb09d88_2de2_11ea_b3ae_679ee520b2a6row1_col2 {
#             color:  black;
#         }    #T_cdb09d88_2de2_11ea_b3ae_679ee520b2a6row2_col0 {
#             color:  black;
#         }    #T_cdb09d88_2de2_11ea_b3ae_679ee520b2a6row2_col1 {
#             color:  black;
#         }    #T_cdb09d88_2de2_11ea_b3ae_679ee520b2a6row2_col2 {
#             color:  black;
#         }    #T_cdb09d88_2de2_11ea_b3ae_679ee520b2a6row3_col0 {
#             color:  black;
#         }    #T_cdb09d88_2de2_11ea_b3ae_679ee520b2a6row3_col1 {
#             color:  black;
#         }    #T_cdb09d88_2de2_11ea_b3ae_679ee520b2a6row3_col2 {
#             color:  black;
#         }    #T_cdb09d88_2de2_11ea_b3ae_679ee520b2a6row4_col0 {
#             color:  black;
#         }    #T_cdb09d88_2de2_11ea_b3ae_679ee520b2a6row4_col1 {
#             color:  black;
#         }    #T_cdb09d88_2de2_11ea_b3ae_679ee520b2a6row4_col2 {
#             color:  orange;
#         }    #T_cdb09d88_2de2_11ea_b3ae_679ee520b2a6row5_col0 {
#             color:  black;
#         }    #T_cdb09d88_2de2_11ea_b3ae_679ee520b2a6row5_col1 {
#             color:  black;
#         }    #T_cdb09d88_2de2_11ea_b3ae_679ee520b2a6row5_col2 {
#             color:  black;
#         }    #T_cdb09d88_2de2_11ea_b3ae_679ee520b2a6row6_col0 {
#             color:  black;
#         }    #T_cdb09d88_2de2_11ea_b3ae_679ee520b2a6row6_col1 {
#             color:  black;
#         }    #T_cdb09d88_2de2_11ea_b3ae_679ee520b2a6row6_col2 {
#             color:  black;
#         }    #T_cdb09d88_2de2_11ea_b3ae_679ee520b2a6row7_col0 {
#             color:  black;
#         }    #T_cdb09d88_2de2_11ea_b3ae_679ee520b2a6row7_col1 {
#             color:  black;
#         }    #T_cdb09d88_2de2_11ea_b3ae_679ee520b2a6row7_col2 {
#             color:  black;
#         }    #T_cdb09d88_2de2_11ea_b3ae_679ee520b2a6row8_col0 {
#             color:  black;
#         }    #T_cdb09d88_2de2_11ea_b3ae_679ee520b2a6row8_col1 {
#             color:  black;
#         }    #T_cdb09d88_2de2_11ea_b3ae_679ee520b2a6row8_col2 {
#             color:  black;
#         }    #T_cdb09d88_2de2_11ea_b3ae_679ee520b2a6row9_col0 {
#             color:  black;
#         }    #T_cdb09d88_2de2_11ea_b3ae_679ee520b2a6row9_col1 {
#             color:  black;
#         }    #T_cdb09d88_2de2_11ea_b3ae_679ee520b2a6row9_col2 {
#             color:  black;
#         }    #T_cdb09d88_2de2_11ea_b3ae_679ee520b2a6row10_col0 {
#             color:  black;
#         }    #T_cdb09d88_2de2_11ea_b3ae_679ee520b2a6row10_col1 {
#             color:  orange;
#         }    #T_cdb09d88_2de2_11ea_b3ae_679ee520b2a6row10_col2 {
#             color:  purple;
#         }    #T_cdb09d88_2de2_11ea_b3ae_679ee520b2a6row11_col0 {
#             color:  black;
#         }    #T_cdb09d88_2de2_11ea_b3ae_679ee520b2a6row11_col1 {
#             color:  black;
#         }    #T_cdb09d88_2de2_11ea_b3ae_679ee520b2a6row11_col2 {
#             color:  black;
#         }    #T_cdb09d88_2de2_11ea_b3ae_679ee520b2a6row12_col0 {
#             color:  black;
#         }    #T_cdb09d88_2de2_11ea_b3ae_679ee520b2a6row12_col1 {
#             color:  black;
#         }    #T_cdb09d88_2de2_11ea_b3ae_679ee520b2a6row12_col2 {
#             color:  black;
#         }    #T_cdb09d88_2de2_11ea_b3ae_679ee520b2a6row13_col0 {
#             color:  black;
#         }    #T_cdb09d88_2de2_11ea_b3ae_679ee520b2a6row13_col1 {
#             color:  black;
#         }    #T_cdb09d88_2de2_11ea_b3ae_679ee520b2a6row13_col2 {
#             color:  orange;
#         }    #T_cdb09d88_2de2_11ea_b3ae_679ee520b2a6row14_col0 {
#             color:  black;
#         }    #T_cdb09d88_2de2_11ea_b3ae_679ee520b2a6row14_col1 {
#             color:  orange;
#         }    #T_cdb09d88_2de2_11ea_b3ae_679ee520b2a6row14_col2 {
#             color:  orange;
#         }    #T_cdb09d88_2de2_11ea_b3ae_679ee520b2a6row15_col0 {
#             color:  black;
#         }    #T_cdb09d88_2de2_11ea_b3ae_679ee520b2a6row15_col1 {
#             color:  black;
#         }    #T_cdb09d88_2de2_11ea_b3ae_679ee520b2a6row15_col2 {
#             color:  black;
#         }    #T_cdb09d88_2de2_11ea_b3ae_679ee520b2a6row16_col0 {
#             color:  black;
#         }    #T_cdb09d88_2de2_11ea_b3ae_679ee520b2a6row16_col1 {
#             color:  black;
#         }    #T_cdb09d88_2de2_11ea_b3ae_679ee520b2a6row16_col2 {
#             color:  black;
#         }    #T_cdb09d88_2de2_11ea_b3ae_679ee520b2a6row17_col0 {
#             color:  black;
#         }    #T_cdb09d88_2de2_11ea_b3ae_679ee520b2a6row17_col1 {
#             color:  green;
#         }    #T_cdb09d88_2de2_11ea_b3ae_679ee520b2a6row17_col2 {
#             color:  black;
#         }    #T_cdb09d88_2de2_11ea_b3ae_679ee520b2a6row18_col0 {
#             color:  black;
#         }    #T_cdb09d88_2de2_11ea_b3ae_679ee520b2a6row18_col1 {
#             color:  black;
#         }    #T_cdb09d88_2de2_11ea_b3ae_679ee520b2a6row18_col2 {
#             color:  orange;
#         }    #T_cdb09d88_2de2_11ea_b3ae_679ee520b2a6row19_col0 {
#             color:  black;
#         }    #T_cdb09d88_2de2_11ea_b3ae_679ee520b2a6row19_col1 {
#             color:  black;
#         }    #T_cdb09d88_2de2_11ea_b3ae_679ee520b2a6row19_col2 {
#             color:  black;
#         }    #T_cdb09d88_2de2_11ea_b3ae_679ee520b2a6row20_col0 {
#             color:  black;
#         }    #T_cdb09d88_2de2_11ea_b3ae_679ee520b2a6row20_col1 {
#             color:  purple;
#         }    #T_cdb09d88_2de2_11ea_b3ae_679ee520b2a6row20_col2 {
#             color:  purple;
#         }    #T_cdb09d88_2de2_11ea_b3ae_679ee520b2a6row21_col0 {
#             color:  black;
#         }    #T_cdb09d88_2de2_11ea_b3ae_679ee520b2a6row21_col1 {
#             color:  black;
#         }    #T_cdb09d88_2de2_11ea_b3ae_679ee520b2a6row21_col2 {
#             color:  black;
#         }    #T_cdb09d88_2de2_11ea_b3ae_679ee520b2a6row22_col0 {
#             color:  black;
#         }    #T_cdb09d88_2de2_11ea_b3ae_679ee520b2a6row22_col1 {
#             color:  orange;
#         }    #T_cdb09d88_2de2_11ea_b3ae_679ee520b2a6row22_col2 {
#             color:  orange;
#         }    #T_cdb09d88_2de2_11ea_b3ae_679ee520b2a6row23_col0 {
#             color:  black;
#         }    #T_cdb09d88_2de2_11ea_b3ae_679ee520b2a6row23_col1 {
#             color:  black;
#         }    #T_cdb09d88_2de2_11ea_b3ae_679ee520b2a6row23_col2 {
#             color:  black;
#         }    #T_cdb09d88_2de2_11ea_b3ae_679ee520b2a6row24_col0 {
#             color:  black;
#         }    #T_cdb09d88_2de2_11ea_b3ae_679ee520b2a6row24_col1 {
#             color:  orange;
#         }    #T_cdb09d88_2de2_11ea_b3ae_679ee520b2a6row24_col2 {
#             color:  orange;
#         }    #T_cdb09d88_2de2_11ea_b3ae_679ee520b2a6row25_col0 {
#             color:  black;
#         }    #T_cdb09d88_2de2_11ea_b3ae_679ee520b2a6row25_col1 {
#             color:  orange;
#         }    #T_cdb09d88_2de2_11ea_b3ae_679ee520b2a6row25_col2 {
#             color:  orange;
#         }    #T_cdb09d88_2de2_11ea_b3ae_679ee520b2a6row26_col0 {
#             color:  black;
#         }    #T_cdb09d88_2de2_11ea_b3ae_679ee520b2a6row26_col1 {
#             color:  black;
#         }    #T_cdb09d88_2de2_11ea_b3ae_679ee520b2a6row26_col2 {
#             color:  orange;
#         }    #T_cdb09d88_2de2_11ea_b3ae_679ee520b2a6row27_col0 {
#             color:  black;
#         }    #T_cdb09d88_2de2_11ea_b3ae_679ee520b2a6row27_col1 {
#             color:  green;
#         }    #T_cdb09d88_2de2_11ea_b3ae_679ee520b2a6row27_col2 {
#             color:  black;
#         }    #T_cdb09d88_2de2_11ea_b3ae_679ee520b2a6row28_col0 {
#             color:  black;
#         }    #T_cdb09d88_2de2_11ea_b3ae_679ee520b2a6row28_col1 {
#             color:  black;
#         }    #T_cdb09d88_2de2_11ea_b3ae_679ee520b2a6row28_col2 {
#             color:

# %% [markdown]
# ## By category

# %%
target_cols_preds = [col+'_pred' for col in target_cols]
for col in target_cols_preds:
    train[col] = 0
    validation[col] = 0
    
train[target_cols_preds] = preds_train
validation[target_cols_preds] = preds_val
    
display(get_metrics_category(train, validation, target_cols, target_cols_preds, 'category').style.applymap(color_map))
# Out:
# <style  type="text/css" >
#     #T_ce119b92_2de2_11ea_b3ae_679ee520b2a6row0_col0 {
#             color:  black;
#         }    #T_ce119b92_2de2_11ea_b3ae_679ee520b2a6row0_col1 {
#             color:  black;
#         }    #T_ce119b92_2de2_11ea_b3ae_679ee520b2a6row0_col2 {
#             color:  black;
#         }    #T_ce119b92_2de2_11ea_b3ae_679ee520b2a6row0_col3 {
#             color:  black;
#         }    #T_ce119b92_2de2_11ea_b3ae_679ee520b2a6row0_col4 {
#             color:  black;
#         }    #T_ce119b92_2de2_11ea_b3ae_679ee520b2a6row0_col5 {
#             color:  black;
#         }    #T_ce119b92_2de2_11ea_b3ae_679ee520b2a6row0_col6 {
#             color:  orange;
#         }    #T_ce119b92_2de2_11ea_b3ae_679ee520b2a6row0_col7 {
#             color:  black;
#         }    #T_ce119b92_2de2_11ea_b3ae_679ee520b2a6row0_col8 {
#             color:  black;
#         }    #T_ce119b92_2de2_11ea_b3ae_679ee520b2a6row0_col9 {
#             color:  black;
#         }    #T_ce119b92_2de2_11ea_b3ae_679ee520b2a6row0_col10 {
#             color:  black;
#         }</style><table id="T_ce119b92_2de2_11ea_b3ae_679ee520b2a6" ><thead>    <tr>        <th class="blank level0" ></th>        <th class="col_heading level0 col0" >Label</th>        <th class="col_heading level0 col1" >Train (TECHNOLOGY)</th>        <th class="col_heading level0 col2" >Validation (TECHNOLOGY)</th>        <th class="col_heading level0 col3" >Train (SCIENCE)</th>        <th class="col_heading level0 col4" >Validation (SCIENCE)</th>        <th class="col_heading level0 col5" >Train (STACKOVERFLOW)</th>        <th class="col_heading level0 col6" >Validation (STACKOVERFLOW)</th>        <th class="col_heading level0 col7" >Train (LIFE_ARTS)</th>        <th class="col_heading level0 col8" >Validation (LIFE_ARTS)</th>        <th class="col_heading level0 col9" >Train (CULTURE)</th>        <th class="col_heading level0 col10" >Validation (CULTURE)</th>    </tr></thead><tbody>
#                 <tr>
#                         <th id="T_ce119b92_2de2_11ea_b3ae_679ee520b2a6level0_row0" class="row_heading level0 row0" >0</th>
#                         <td id="T_ce119b92_2de2_11ea_b3ae_679ee520b2a6row0_col0" class="data row0 col0" >Averaged</td>
#                         <td id="T_ce119b92_2de2_11ea_b3ae_679ee520b2a6row0_col1" class="data row0 col1" >0.405</td>
#                         <td id="T_ce119b92_2de2_11ea_b3ae_679ee520b2a6row0_col2" class="data row0 col2" >0.316</td>
#                         <td id="T_ce119b92_2de2_11ea_b3ae_679ee520b2a6row0_col3" class="data row0 col3" >0.459</td>
#                         <td id="T_ce119b92_2de2_11ea_b3ae_679ee520b2a6row0_col4" class="data row0 col4" >0.323</td>
#                         <td id="T_ce119b92_2de2_11ea_b3ae_679ee520b2a6row0_col5" class="data row0 col5" >0.337</td>
#                         <td id="T_ce119b92_2de2_11ea_b3ae_679ee520b2a6row0_col6" class="data row0 col6" >0.211</td>
#                         <td id="T_ce119b92_2de2_11ea_b3ae_679ee520b2a6row0_col7" class="data row0 col7" >0.448</td>
#                         <td id="T_ce119b92_2de2_11ea_b3ae_679ee520b2a6row0_col8" class="data row0 col8" >0.362</td>
#                         <td id="T_ce119b92_2de2_11ea_b3ae_679ee520b2a6row0_col9" class="data row0 col9" >0.434</td>
#                         <td id="T_ce119b92_2de2_11ea_b3ae_679ee520b2a6row0_col10" class="data row0 col10" >0.332</td>
#             </tr>
#     </tbody></table>

# %% [markdown]
# #### Save model weights and ecoders

# %%
model.save_weights(model_path)
dump(tokenizer, tokenizer_path)
dump(ohe_category, category_encoder_path)
dump(ohe_host, host_encoder_path)
dump(scaler, scaler_path)
# Out:
# ['/kaggle/working/scaler.joblib']
