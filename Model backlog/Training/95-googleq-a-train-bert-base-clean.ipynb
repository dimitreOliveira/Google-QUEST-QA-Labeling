# %% [markdown]
# ## Dependencies

# %%
import warnings
from tensorflow_hub import KerasLayer
from tensorflow.keras import Model, optimizers
from tensorflow.keras.layers import Input, Dense, Dropout, GlobalAveragePooling1D
from googleqa_utilityscript import *
import bert_tokenization as tokenization


SEED = 0
seed_everything(SEED)
warnings.filterwarnings("ignore")

# %% [markdown]
# ## Load data

# %%
model_path = '/kaggle/working/model.h5'
BERT_PATH = '/kaggle/input/bert-base-from-tfhub/bert_en_uncased_L-12_H-768_A-12'
TOKENIZER_PATH = BERT_PATH+'/assets/vocab.txt'

hold_out = pd.read_csv('/kaggle/input/googleqa-mldataset/hold-out.csv')
train = hold_out[hold_out['set'] == 'train']
validation = hold_out[hold_out['set'] == 'validation']

print('Train samples: %s' % len(train))
print('Validation samples: %s' % len(validation))
display(train.head())
# Out:
# Train samples: 4863
# Validation samples: 1216
#    qa_id                                     question_title  \
# 0   3895  Magento (1.7) Bundled Product with FREE Produc...
# 1   3131                             Find router on network
# 2   1507  Negatively curved metrics minimizing the lengt...
# 3   6784               Isn’t the FAQ label obsolete by now?
# 4   2135  Changing background image one time on responsi...
#
#                                        question_body question_user_name  \
# 0  I'm looking to create a bundle offer where cus...                Joe
# 1  I've just bought a Belkin N+ Wireless Router. ...                Guy
# 2  Good afternoon everyone !\n\nI have the follow...            Selim G
# 3  Don’t get me wrong in the beginning of reading...     Benny Skogberg
# 4  The code I'm using is this one \n\nbackground:...        user2141649
#
#                               question_user_page  \
# 0  https://magento.stackexchange.com/users/16572
# 1               https://superuser.com/users/3248
# 2           https://mathoverflow.net/users/25511
# 3        https://ux.stackexchange.com/users/4679
# 4        https://stackoverflow.com/users/2141649
#
#                                               answer   answer_user_name  \
# 0  Since the third item is fixed, you can use sho...  Fabian Schmengler
# 1  You likely have the router plugged in to the m...             John T
# 2  A very partial answer: by the results of Richa...         Igor Rivin
# 3  Isn’t the FAQ label obsolete by now? \n\nI'd s...        Solracnapod
# 4  &lt;!DOCTYPE html&gt;\n&lt;html&gt;\n&lt;head&...           akkimads
#
#                               answer_user_page  \
# 0  https://magento.stackexchange.com/users/243
# 1             https://superuser.com/users/1931
# 2         https://mathoverflow.net/users/11142
# 3     https://ux.stackexchange.com/users/13153
# 4      https://stackoverflow.com/users/2375373
#
#                                                  url       category  ...  \
# 0  http://magento.stackexchange.com/questions/668...     TECHNOLOGY  ...
# 1               http://superuser.com/questions/87212     TECHNOLOGY  ...
# 2           http://mathoverflow.net/questions/203422        SCIENCE  ...
# 3  http://ux.stackexchange.com/questions/18600/is...     TECHNOLOGY  ...
# 4  http://stackoverflow.com/questions/16359492/ch...  STACKOVERFLOW  ...
#
#   answer_helpful  answer_level_of_information  answer_plausible  \
# 0       0.888889                     0.666667               1.0
# 1       1.000000                     0.666667               1.0
# 2       0.888889                     0.333333               1.0
# 3       0.888889                     0.666667               1.0
# 4       0.888889                     0.500000               1.0
#
#    answer_relevance  answer_satisfaction  answer_type_instructions  \
# 0               1.0             0.933333                  1.000000
# 1               1.0             0.866667                  0.666667
# 2               1.0             0.700000                  0.333333
# 3               1.0             0.933333                  0.000000
# 4               1.0             0.800000                  1.000000
#
#    answer_type_procedure  answer_type_reason_explanation  answer_well_written  \
# 0               0.000000                        0.333333             0.888889
# 1               0.000000                        1.000000             1.000000
# 2               0.333333                        1.000000             0.888889
# 3               0.000000                        0.666667             1.000000
# 4               0.000000                        0.000000             0.777778
#
#      set
# 0  train
# 1  train
# 2  train
# 3  train
# 4  train
#
# [5 rows x 42 columns]

# %%
question_target_cols = ['question_asker_intent_understanding','question_body_critical', 'question_conversational', 
                        'question_expect_short_answer', 'question_fact_seeking', 'question_has_commonly_accepted_answer',
                        'question_interestingness_others', 'question_interestingness_self', 'question_multi_intent', 
                        'question_not_really_a_question', 'question_opinion_seeking', 'question_type_choice',
                        'question_type_compare', 'question_type_consequence', 'question_type_definition', 
                        'question_type_entity', 'question_type_instructions', 'question_type_procedure',
                        'question_type_reason_explanation', 'question_type_spelling', 'question_well_written']
answer_target_cols = ['answer_helpful', 'answer_level_of_information', 'answer_plausible', 'answer_relevance',
                      'answer_satisfaction', 'answer_type_instructions', 'answer_type_procedure', 
                      'answer_type_reason_explanation', 'answer_well_written']
target_cols = question_target_cols + answer_target_cols

# %% [markdown]
# # Pre-process data

# %%
text_features = ['question_title', 'question_body', 'answer']

# for feature in text_features:
#     # Trim text
#     train[feature] = train[feature].apply(lambda x: x.strip())
#     validation[feature] = validation[feature].apply(lambda x: x.strip())

# %% [markdown]
# # Model parameters

# %%
EPOCHS = 5
BATCH_SIZE = 8
LEARNING_RATE = 3e-5
N_CLASS = len(target_cols)
ES_PATIENCE = 3
MAX_SEQUENCE_LENGTH = 512

# %% [markdown]
# ## Train/validation sets

# %%
tokenizer = tokenization.FullTokenizer(TOKENIZER_PATH, True)

# Train features
X_train = compute_input_arays(train, text_features, tokenizer, MAX_SEQUENCE_LENGTH)
Y_train = train[target_cols].values

# Validation features
X_valid = compute_input_arays(validation, text_features, tokenizer, MAX_SEQUENCE_LENGTH)
Y_valid = validation[target_cols].values


print('Train samples: %d' % len(Y_train))
print('Validation samples: %d' % len(Y_valid))
# Out:
# Train samples: 4863
# Validation samples: 1216

# %% [markdown]
# # Model

# %%
input_word_ids = Input((MAX_SEQUENCE_LENGTH,), dtype=tf.int32, name='input_word_ids')
input_masks = Input((MAX_SEQUENCE_LENGTH,), dtype=tf.int32, name='input_masks')
segment_ids = Input((MAX_SEQUENCE_LENGTH,), dtype=tf.int32, name='segment_ids')

bert_layer = KerasLayer(BERT_PATH, trainable=True)
pooled_output, sequence_output = bert_layer([input_word_ids, input_masks, segment_ids])

x = GlobalAveragePooling1D()(sequence_output)
x = Dropout(0.2)(x)
output = Dense(N_CLASS, activation="sigmoid", name="output")(x)

model = Model(inputs=[input_word_ids, input_masks, segment_ids], outputs=output)

model.summary()
# Out:
# Model: "model"
# __________________________________________________________________________________________________
# Layer (type)                    Output Shape         Param #     Connected to
# ==================================================================================================
# input_word_ids (InputLayer)     [(None, 512)]        0
# __________________________________________________________________________________________________
# input_masks (InputLayer)        [(None, 512)]        0
# __________________________________________________________________________________________________
# segment_ids (InputLayer)        [(None, 512)]        0
# __________________________________________________________________________________________________
# keras_layer (KerasLayer)        [(None, 768), (None, 109482241   input_word_ids[0][0]
#                                                                  input_masks[0][0]
#                                                                  segment_ids[0][0]
# __________________________________________________________________________________________________
# global_average_pooling1d (Globa (None, 768)          0           keras_layer[0][1]
# __________________________________________________________________________________________________
# dropout (Dropout)               (None, 768)          0           global_average_pooling1d[0][0]
# __________________________________________________________________________________________________
# output (Dense)                  (None, 30)           23070       dropout[0][0]
# ==================================================================================================
# Total params: 109,505,311
# Trainable params: 109,505,310
# Non-trainable params: 1
# __________________________________________________________________________________________________

# %% [markdown]
# # Train model

# %%
spearmanCallback = SpearmanRhoCallback(training_data=(X_train, Y_train), 
                                       validation_data=(X_valid, Y_valid), 
                                       model_path=model_path, 
                                       monitor='val_loss', mode='min', 
                                       patience=ES_PATIENCE, checkpoint=True)

callback_list = [spearmanCallback]

optimizer = optimizers.Adam(learning_rate=LEARNING_RATE)
model.compile(optimizer=optimizer, loss='binary_crossentropy')

history = model.fit(X_train, Y_train, 
                    validation_data=(X_valid, Y_valid), 
                    callbacks=callback_list, 
                    batch_size=BATCH_SIZE, 
                    epochs=EPOCHS, 
                    verbose=2).history
# Out:
# Train on 4863 samples, validate on 1216 samples
# Epoch 1/5
# spearman-rho: 0.3984 val_spearman-rho: 0.3675
# Saved model weights at "/kaggle/working/model.h5"
# 4863/4863 - 507s - loss: 0.3993 - val_loss: 0.3821
# Epoch 2/5
# spearman-rho: 0.4700 val_spearman-rho: 0.3874
# Saved model weights at "/kaggle/working/model.h5"
# 4863/4863 - 475s - loss: 0.3669 - val_loss: 0.3720
# Epoch 3/5
# spearman-rho: 0.5370 val_spearman-rho: 0.3896
# Saved model weights at "/kaggle/working/model.h5"
# 4863/4863 - 474s - loss: 0.3487 - val_loss: 0.3711
# Epoch 4/5
# spearman-rho: 0.6011 val_spearman-rho: 0.3907
# 4863/4863 - 473s - loss: 0.3292 - val_loss: 0.3792
# Epoch 5/5
# spearman-rho: 0.6511 val_spearman-rho: 0.3886
# 4863/4863 - 473s - loss: 0.3081 - val_loss: 0.3853

# %% [markdown]
# ## Model loss graph

# %%
sns.set(style="whitegrid")
plot_metrics(history, metric_list=['loss', 'spearman'])

# %% [markdown]
# # Evaluation

# %%
preds_train = model.predict(X_train)
preds_val = model.predict(X_valid)

display(get_metrics(Y_train, preds_train, Y_valid, preds_val, target_cols).style.applymap(color_map))
# Out:
# <style  type="text/css" >
#     #T_cfd5317a_2f6b_11ea_9d3a_154b61f1e030row0_col0 {
#             color:  black;
#         }    #T_cfd5317a_2f6b_11ea_9d3a_154b61f1e030row0_col1 {
#             color:  black;
#         }    #T_cfd5317a_2f6b_11ea_9d3a_154b61f1e030row0_col2 {
#             color:  black;
#         }    #T_cfd5317a_2f6b_11ea_9d3a_154b61f1e030row1_col0 {
#             color:  black;
#         }    #T_cfd5317a_2f6b_11ea_9d3a_154b61f1e030row1_col1 {
#             color:  black;
#         }    #T_cfd5317a_2f6b_11ea_9d3a_154b61f1e030row1_col2 {
#             color:  black;
#         }    #T_cfd5317a_2f6b_11ea_9d3a_154b61f1e030row2_col0 {
#             color:  black;
#         }    #T_cfd5317a_2f6b_11ea_9d3a_154b61f1e030row2_col1 {
#             color:  green;
#         }    #T_cfd5317a_2f6b_11ea_9d3a_154b61f1e030row2_col2 {
#             color:  black;
#         }    #T_cfd5317a_2f6b_11ea_9d3a_154b61f1e030row3_col0 {
#             color:  black;
#         }    #T_cfd5317a_2f6b_11ea_9d3a_154b61f1e030row3_col1 {
#             color:  black;
#         }    #T_cfd5317a_2f6b_11ea_9d3a_154b61f1e030row3_col2 {
#             color:  black;
#         }    #T_cfd5317a_2f6b_11ea_9d3a_154b61f1e030row4_col0 {
#             color:  black;
#         }    #T_cfd5317a_2f6b_11ea_9d3a_154b61f1e030row4_col1 {
#             color:  green;
#         }    #T_cfd5317a_2f6b_11ea_9d3a_154b61f1e030row4_col2 {
#             color:  orange;
#         }    #T_cfd5317a_2f6b_11ea_9d3a_154b61f1e030row5_col0 {
#             color:  black;
#         }    #T_cfd5317a_2f6b_11ea_9d3a_154b61f1e030row5_col1 {
#             color:  green;
#         }    #T_cfd5317a_2f6b_11ea_9d3a_154b61f1e030row5_col2 {
#             color:  black;
#         }    #T_cfd5317a_2f6b_11ea_9d3a_154b61f1e030row6_col0 {
#             color:  black;
#         }    #T_cfd5317a_2f6b_11ea_9d3a_154b61f1e030row6_col1 {
#             color:  black;
#         }    #T_cfd5317a_2f6b_11ea_9d3a_154b61f1e030row6_col2 {
#             color:  black;
#         }    #T_cfd5317a_2f6b_11ea_9d3a_154b61f1e030row7_col0 {
#             color:  black;
#         }    #T_cfd5317a_2f6b_11ea_9d3a_154b61f1e030row7_col1 {
#             color:  black;
#         }    #T_cfd5317a_2f6b_11ea_9d3a_154b61f1e030row7_col2 {
#             color:  black;
#         }    #T_cfd5317a_2f6b_11ea_9d3a_154b61f1e030row8_col0 {
#             color:  black;
#         }    #T_cfd5317a_2f6b_11ea_9d3a_154b61f1e030row8_col1 {
#             color:  black;
#         }    #T_cfd5317a_2f6b_11ea_9d3a_154b61f1e030row8_col2 {
#             color:  black;
#         }    #T_cfd5317a_2f6b_11ea_9d3a_154b61f1e030row9_col0 {
#             color:  black;
#         }    #T_cfd5317a_2f6b_11ea_9d3a_154b61f1e030row9_col1 {
#             color:  green;
#         }    #T_cfd5317a_2f6b_11ea_9d3a_154b61f1e030row9_col2 {
#             color:  black;
#         }    #T_cfd5317a_2f6b_11ea_9d3a_154b61f1e030row10_col0 {
#             color:  black;
#         }    #T_cfd5317a_2f6b_11ea_9d3a_154b61f1e030row10_col1 {
#             color:  orange;
#         }    #T_cfd5317a_2f6b_11ea_9d3a_154b61f1e030row10_col2 {
#             color:  purple;
#         }    #T_cfd5317a_2f6b_11ea_9d3a_154b61f1e030row11_col0 {
#             color:  black;
#         }    #T_cfd5317a_2f6b_11ea_9d3a_154b61f1e030row11_col1 {
#             color:  green;
#         }    #T_cfd5317a_2f6b_11ea_9d3a_154b61f1e030row11_col2 {
#             color:  black;
#         }    #T_cfd5317a_2f6b_11ea_9d3a_154b61f1e030row12_col0 {
#             color:  black;
#         }    #T_cfd5317a_2f6b_11ea_9d3a_154b61f1e030row12_col1 {
#             color:  green;
#         }    #T_cfd5317a_2f6b_11ea_9d3a_154b61f1e030row12_col2 {
#             color:  black;
#         }    #T_cfd5317a_2f6b_11ea_9d3a_154b61f1e030row13_col0 {
#             color:  black;
#         }    #T_cfd5317a_2f6b_11ea_9d3a_154b61f1e030row13_col1 {
#             color:  black;
#         }    #T_cfd5317a_2f6b_11ea_9d3a_154b61f1e030row13_col2 {
#             color:  black;
#         }    #T_cfd5317a_2f6b_11ea_9d3a_154b61f1e030row14_col0 {
#             color:  black;
#         }    #T_cfd5317a_2f6b_11ea_9d3a_154b61f1e030row14_col1 {
#             color:  orange;
#         }    #T_cfd5317a_2f6b_11ea_9d3a_154b61f1e030row14_col2 {
#             color:  orange;
#         }    #T_cfd5317a_2f6b_11ea_9d3a_154b61f1e030row15_col0 {
#             color:  black;
#         }    #T_cfd5317a_2f6b_11ea_9d3a_154b61f1e030row15_col1 {
#             color:  black;
#         }    #T_cfd5317a_2f6b_11ea_9d3a_154b61f1e030row15_col2 {
#             color:  black;
#         }    #T_cfd5317a_2f6b_11ea_9d3a_154b61f1e030row16_col0 {
#             color:  black;
#         }    #T_cfd5317a_2f6b_11ea_9d3a_154b61f1e030row16_col1 {
#             color:  black;
#         }    #T_cfd5317a_2f6b_11ea_9d3a_154b61f1e030row16_col2 {
#             color:  black;
#         }    #T_cfd5317a_2f6b_11ea_9d3a_154b61f1e030row17_col0 {
#             color:  black;
#         }    #T_cfd5317a_2f6b_11ea_9d3a_154b61f1e030row17_col1 {
#             color:  green;
#         }    #T_cfd5317a_2f6b_11ea_9d3a_154b61f1e030row17_col2 {
#             color:  black;
#         }    #T_cfd5317a_2f6b_11ea_9d3a_154b61f1e030row18_col0 {
#             color:  black;
#         }    #T_cfd5317a_2f6b_11ea_9d3a_154b61f1e030row18_col1 {
#             color:  black;
#         }    #T_cfd5317a_2f6b_11ea_9d3a_154b61f1e030row18_col2 {
#             color:  black;
#         }    #T_cfd5317a_2f6b_11ea_9d3a_154b61f1e030row19_col0 {
#             color:  black;
#         }    #T_cfd5317a_2f6b_11ea_9d3a_154b61f1e030row19_col1 {
#             color:  green;
#         }    #T_cfd5317a_2f6b_11ea_9d3a_154b61f1e030row19_col2 {
#             color:  black;
#         }    #T_cfd5317a_2f6b_11ea_9d3a_154b61f1e030row20_col0 {
#             color:  black;
#         }    #T_cfd5317a_2f6b_11ea_9d3a_154b61f1e030row20_col1 {
#             color:  purple;
#         }    #T_cfd5317a_2f6b_11ea_9d3a_154b61f1e030row20_col2 {
#             color:  purple;
#         }    #T_cfd5317a_2f6b_11ea_9d3a_154b61f1e030row21_col0 {
#             color:  black;
#         }    #T_cfd5317a_2f6b_11ea_9d3a_154b61f1e030row21_col1 {
#             color:  black;
#         }    #T_cfd5317a_2f6b_11ea_9d3a_154b61f1e030row21_col2 {
#             color:  black;
#         }    #T_cfd5317a_2f6b_11ea_9d3a_154b61f1e030row22_col0 {
#             color:  black;
#         }    #T_cfd5317a_2f6b_11ea_9d3a_154b61f1e030row22_col1 {
#             color:  black;
#         }    #T_cfd5317a_2f6b_11ea_9d3a_154b61f1e030row22_col2 {
#             color:  orange;
#         }    #T_cfd5317a_2f6b_11ea_9d3a_154b61f1e030row23_col0 {
#             color:  black;
#         }    #T_cfd5317a_2f6b_11ea_9d3a_154b61f1e030row23_col1 {
#             color:  black;
#         }    #T_cfd5317a_2f6b_11ea_9d3a_154b61f1e030row23_col2 {
#             color:  black;
#         }    #T_cfd5317a_2f6b_11ea_9d3a_154b61f1e030row24_col0 {
#             color:  black;
#         }    #T_cfd5317a_2f6b_11ea_9d3a_154b61f1e030row24_col1 {
#             color:  black;
#         }    #T_cfd5317a_2f6b_11ea_9d3a_154b61f1e030row24_col2 {
#             color:  orange;
#         }    #T_cfd5317a_2f6b_11ea_9d3a_154b61f1e030row25_col0 {
#             color:  black;
#         }    #T_cfd5317a_2f6b_11ea_9d3a_154b61f1e030row25_col1 {
#             color:  black;
#         }    #T_cfd5317a_2f6b_11ea_9d3a_154b61f1e030row25_col2 {
#             color:  orange;
#         }    #T_cfd5317a_2f6b_11ea_9d3a_154b61f1e030row26_col0 {
#             color:  black;
#         }    #T_cfd5317a_2f6b_11ea_9d3a_154b61f1e030row26_col1 {
#             color:  black;
#         }    #T_cfd5317a_2f6b_11ea_9d3a_154b61f1e030row26_col2 {
#             color:  black;
#         }    #T_cfd5317a_2f6b_11ea_9d3a_154b61f1e030row27_col0 {
#             color:  black;
#         }    #T_cfd5317a_2f6b_11ea_9d3a_154b61f1e030row27_col1 {
#             color:  green;
#         }    #T_cfd5317a_2f6b_11ea_9d3a_154b61f1e030row27_col2 {
#             color:  black;
#         }    #T_cfd5317a_2f6b_11ea_9d3a_154b61f1e030row28_col0 {
#             color:  black;
#         }    #T_cfd5317a_2f6b_11ea_9d3a_154b61f1e030row28_col1 {
#             color:  black;
#         }    #T_cfd5317a_2f6b_11ea_9d3a_154b61f1e030row28_col2 {
#             color:  orange

# %% [markdown]
# ## By category

# %%
target_cols_preds = [col+'_pred' for col in target_cols]
for col in target_cols_preds:
    train[col] = 0
    validation[col] = 0
    
train[target_cols_preds] = preds_train
validation[target_cols_preds] = preds_val
    
display(get_metrics_category(train, validation, target_cols, target_cols_preds, 'category').style.applymap(color_map))
# Out:
# <style  type="text/css" >
#     #T_d013eb2c_2f6b_11ea_9d3a_154b61f1e030row0_col0 {
#             color:  black;
#         }    #T_d013eb2c_2f6b_11ea_9d3a_154b61f1e030row0_col1 {
#             color:  black;
#         }    #T_d013eb2c_2f6b_11ea_9d3a_154b61f1e030row0_col2 {
#             color:  black;
#         }    #T_d013eb2c_2f6b_11ea_9d3a_154b61f1e030row0_col3 {
#             color:  black;
#         }    #T_d013eb2c_2f6b_11ea_9d3a_154b61f1e030row0_col4 {
#             color:  black;
#         }    #T_d013eb2c_2f6b_11ea_9d3a_154b61f1e030row0_col5 {
#             color:  black;
#         }    #T_d013eb2c_2f6b_11ea_9d3a_154b61f1e030row0_col6 {
#             color:  orange;
#         }    #T_d013eb2c_2f6b_11ea_9d3a_154b61f1e030row0_col7 {
#             color:  black;
#         }    #T_d013eb2c_2f6b_11ea_9d3a_154b61f1e030row0_col8 {
#             color:  black;
#         }    #T_d013eb2c_2f6b_11ea_9d3a_154b61f1e030row0_col9 {
#             color:  black;
#         }    #T_d013eb2c_2f6b_11ea_9d3a_154b61f1e030row0_col10 {
#             color:  black;
#         }</style><table id="T_d013eb2c_2f6b_11ea_9d3a_154b61f1e030" ><thead>    <tr>        <th class="blank level0" ></th>        <th class="col_heading level0 col0" >Label</th>        <th class="col_heading level0 col1" >Train (TECHNOLOGY)</th>        <th class="col_heading level0 col2" >Validation (TECHNOLOGY)</th>        <th class="col_heading level0 col3" >Train (SCIENCE)</th>        <th class="col_heading level0 col4" >Validation (SCIENCE)</th>        <th class="col_heading level0 col5" >Train (STACKOVERFLOW)</th>        <th class="col_heading level0 col6" >Validation (STACKOVERFLOW)</th>        <th class="col_heading level0 col7" >Train (LIFE_ARTS)</th>        <th class="col_heading level0 col8" >Validation (LIFE_ARTS)</th>        <th class="col_heading level0 col9" >Train (CULTURE)</th>        <th class="col_heading level0 col10" >Validation (CULTURE)</th>    </tr></thead><tbody>
#                 <tr>
#                         <th id="T_d013eb2c_2f6b_11ea_9d3a_154b61f1e030level0_row0" class="row_heading level0 row0" >0</th>
#                         <td id="T_d013eb2c_2f6b_11ea_9d3a_154b61f1e030row0_col0" class="data row0 col0" >Averaged</td>
#                         <td id="T_d013eb2c_2f6b_11ea_9d3a_154b61f1e030row0_col1" class="data row0 col1" >0.642</td>
#                         <td id="T_d013eb2c_2f6b_11ea_9d3a_154b61f1e030row0_col2" class="data row0 col2" >0.345</td>
#                         <td id="T_d013eb2c_2f6b_11ea_9d3a_154b61f1e030row0_col3" class="data row0 col3" >0.673</td>
#                         <td id="T_d013eb2c_2f6b_11ea_9d3a_154b61f1e030row0_col4" class="data row0 col4" >0.394</td>
#                         <td id="T_d013eb2c_2f6b_11ea_9d3a_154b61f1e030row0_col5" class="data row0 col5" >0.589</td>
#                         <td id="T_d013eb2c_2f6b_11ea_9d3a_154b61f1e030row0_col6" class="data row0 col6" >0.255</td>
#                         <td id="T_d013eb2c_2f6b_11ea_9d3a_154b61f1e030row0_col7" class="data row0 col7" >0.678</td>
#                         <td id="T_d013eb2c_2f6b_11ea_9d3a_154b61f1e030row0_col8" class="data row0 col8" >0.421</td>
#                         <td id="T_d013eb2c_2f6b_11ea_9d3a_154b61f1e030row0_col9" class="data row0 col9" >0.68</td>
#                         <td id="T_d013eb2c_2f6b_11ea_9d3a_154b61f1e030row0_col10" class="data row0 col10" >0.403</td>
#             </tr>
#     </tbody></table>
