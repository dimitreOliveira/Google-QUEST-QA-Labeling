# %% [markdown]
# ## Dependencies

# %%
import re
import warnings
from joblib import dump
import tensorflow_hub as hub
from tensorflow.keras import Model, optimizers
from tensorflow.keras.layers import Lambda, Input, Dense, Dropout, Concatenate, BatchNormalization, Activation, Average, Add
from tensorflow.keras.callbacks import ReduceLROnPlateau
from googleqa_utilityscript import *


SEED = 0
seed_everything(SEED)
warnings.filterwarnings("ignore")

# %% [markdown]
# ## Load data

# %%
module_url = '/kaggle/input/universalsentenceencodermodels/universal-sentence-encoder-models/use'
model_path = '/kaggle/working/use.h5'

hold_out = pd.read_csv('/kaggle/input/googleqa-mldataset/hold-out.csv')
train = hold_out[hold_out['set'] == 'train']
validation = hold_out[hold_out['set'] == 'validation']

print('Train samples: %s' % len(train))
print('Validation samples: %s' % len(validation))
display(train.head())
# Out:
# Train samples: 4863
# Validation samples: 1216
#    qa_id                                     question_title  \
# 0   3895  Magento (1.7) Bundled Product with FREE Produc...
# 1   3131                             Find router on network
# 2   1507  Negatively curved metrics minimizing the lengt...
# 3   6784               Isn’t the FAQ label obsolete by now?
# 4   2135  Changing background image one time on responsi...
#
#                                        question_body question_user_name  \
# 0  I'm looking to create a bundle offer where cus...                Joe
# 1  I've just bought a Belkin N+ Wireless Router. ...                Guy
# 2  Good afternoon everyone !\n\nI have the follow...            Selim G
# 3  Don’t get me wrong in the beginning of reading...     Benny Skogberg
# 4  The code I'm using is this one \n\nbackground:...        user2141649
#
#                               question_user_page  \
# 0  https://magento.stackexchange.com/users/16572
# 1               https://superuser.com/users/3248
# 2           https://mathoverflow.net/users/25511
# 3        https://ux.stackexchange.com/users/4679
# 4        https://stackoverflow.com/users/2141649
#
#                                               answer   answer_user_name  \
# 0  Since the third item is fixed, you can use sho...  Fabian Schmengler
# 1  You likely have the router plugged in to the m...             John T
# 2  A very partial answer: by the results of Richa...         Igor Rivin
# 3  Isn’t the FAQ label obsolete by now? \n\nI'd s...        Solracnapod
# 4  &lt;!DOCTYPE html&gt;\n&lt;html&gt;\n&lt;head&...           akkimads
#
#                               answer_user_page  \
# 0  https://magento.stackexchange.com/users/243
# 1             https://superuser.com/users/1931
# 2         https://mathoverflow.net/users/11142
# 3     https://ux.stackexchange.com/users/13153
# 4      https://stackoverflow.com/users/2375373
#
#                                                  url       category  ...  \
# 0  http://magento.stackexchange.com/questions/668...     TECHNOLOGY  ...
# 1               http://superuser.com/questions/87212     TECHNOLOGY  ...
# 2           http://mathoverflow.net/questions/203422        SCIENCE  ...
# 3  http://ux.stackexchange.com/questions/18600/is...     TECHNOLOGY  ...
# 4  http://stackoverflow.com/questions/16359492/ch...  STACKOVERFLOW  ...
#
#   answer_helpful  answer_level_of_information  answer_plausible  \
# 0       0.888889                     0.666667               1.0
# 1       1.000000                     0.666667               1.0
# 2       0.888889                     0.333333               1.0
# 3       0.888889                     0.666667               1.0
# 4       0.888889                     0.500000               1.0
#
#    answer_relevance  answer_satisfaction  answer_type_instructions  \
# 0               1.0             0.933333                  1.000000
# 1               1.0             0.866667                  0.666667
# 2               1.0             0.700000                  0.333333
# 3               1.0             0.933333                  0.000000
# 4               1.0             0.800000                  1.000000
#
#    answer_type_procedure  answer_type_reason_explanation  answer_well_written  \
# 0               0.000000                        0.333333             0.888889
# 1               0.000000                        1.000000             1.000000
# 2               0.333333                        1.000000             0.888889
# 3               0.000000                        0.666667             1.000000
# 4               0.000000                        0.000000             0.777778
#
#      set
# 0  train
# 1  train
# 2  train
# 3  train
# 4  train
#
# [5 rows x 42 columns]

# %%
question_target_cols = ['question_asker_intent_understanding','question_body_critical', 'question_conversational', 
                        'question_expect_short_answer', 'question_fact_seeking', 'question_has_commonly_accepted_answer',
                        'question_interestingness_others', 'question_interestingness_self', 'question_multi_intent', 
                        'question_not_really_a_question', 'question_opinion_seeking', 'question_type_choice',
                        'question_type_compare', 'question_type_consequence', 'question_type_definition', 
                        'question_type_entity', 'question_type_instructions', 'question_type_procedure',
                        'question_type_reason_explanation', 'question_type_spelling', 'question_well_written']
answer_target_cols = ['answer_helpful', 'answer_level_of_information', 'answer_plausible', 'answer_relevance',
                      'answer_satisfaction', 'answer_type_instructions', 'answer_type_procedure', 
                      'answer_type_reason_explanation', 'answer_well_written']
target_cols = question_target_cols + answer_target_cols

# %% [markdown]
# ## Pre-process data

# %%
text_features = ['question_title', 'question_body', 'answer']

for feature in text_features:
    # Lower
    train[feature] = train[feature].apply(lambda x: x.lower())
    validation[feature] = validation[feature].apply(lambda x: x.lower())
    # Map misspellings
#     train[feature] = train[feature].apply(lambda x: map_misspellings(x))
#     validation[feature] = validation[feature].apply(lambda x: map_misspellings(x))
    # Map contractions
    train[feature] = train[feature].apply(lambda x: map_contraction(x))
    validation[feature] = validation[feature].apply(lambda x: map_contraction(x))
    # Trim text
    train[feature] = train[feature].apply(lambda x: x.strip())
    validation[feature] = validation[feature].apply(lambda x: x.strip())

# %% [markdown]
# ## Train/validation sets

# %%
# Train features
X_train_title = train['question_title']
X_train_body = train['question_body']
X_train_answer = train['answer']


X_train = [X_train_title, X_train_body, X_train_answer]
Y_train = train[target_cols].values

# Validation features
X_valid_title = validation['question_title']
X_valid_body = validation['question_body']
X_valid_answer = validation['answer']

X_valid = [X_valid_title, X_valid_body, X_valid_answer]
Y_valid = validation[target_cols].values

print('Train samples: %d' % len(Y_train))
print('Validation samples: %d' % len(Y_valid))
# Out:
# Train samples: 4863
# Validation samples: 1216

# %% [markdown]
# # Model parameters

# %%
EPOCHS = 50
BATCH_SIZE = 32
LEARNING_RATE = 3e-4
EMBEDDDING_SIZE = 512
N_CLASS = len(target_cols)
ES_PATIENCE = 5
RLROP_PATIENCE = 2
DECAY_DROP = 0.3

# %% [markdown]
# # Model

# %%
use_embed = hub.load(module_url)

def USEEmbedding(x):
    return use_embed(tf.squeeze(tf.cast(x, tf.string)))

def encoder_block(input_layer):
    encoder = Lambda(USEEmbedding, output_shape=(EMBEDDDING_SIZE,))(input_layer)
    
    return encoder

# %%
# Title
input_title = Input(shape=(1,), dtype=tf.string, name='input_title')
encoded_title = encoder_block(input_title)

# Body
input_body = Input(shape=(1,), dtype=tf.string, name='input_body')
encoded_body = encoder_block(input_body)

# Answer
input_answer = Input(shape=(1,), dtype=tf.string, name='input_answer')
encoded_answer = encoder_block(input_answer)


# Output
title = Dense(256, kernel_initializer='glorot_uniform')(encoded_title)
title = BatchNormalization()(title)
title = Activation('relu')(title)
title = Dropout(0.5)(title)
title = Dense(128, kernel_initializer='glorot_uniform')(title)
title = BatchNormalization()(title)
title_out = Activation('relu')(title)

body = Dense(256, kernel_initializer='glorot_uniform')(encoded_body)
body = BatchNormalization()(body)
body = Activation('relu')(body)
body = Dropout(0.5)(body)
body = Dense(128, kernel_initializer='glorot_uniform')(body)
body = BatchNormalization()(body)
body_out = Activation('relu')(body)

answer = Dense(512, kernel_initializer='glorot_uniform')(encoded_answer)
answer = BatchNormalization()(answer)
answer_out = Activation('relu')(answer)

question = Add()([title_out, body_out])
question = Dense(512, kernel_initializer='glorot_uniform')(question)
question = BatchNormalization()(question)
question_out = Activation('relu')(question)

x = Add()([question_out, answer_out, encoded_title, encoded_body, encoded_answer])
x = Dropout(0.5)(x)
x = Dense(512, kernel_initializer='glorot_uniform')(x)
x = BatchNormalization()(x)
x = Activation('relu')(x)
x = Dropout(0.5)(x)
x = Add()([x, encoded_title, encoded_body, encoded_answer])
x = Dense(512, kernel_initializer='glorot_uniform')(x)
x = BatchNormalization()(x)
x = Activation('relu')(x)
x = Dropout(0.5)(x)

output = Dense(N_CLASS, activation='sigmoid', kernel_initializer='glorot_uniform', name='output')(x)
model = Model(inputs=[input_title, input_body, input_answer], outputs=[output])

model.summary()
# Out:
# Model: "model"
# __________________________________________________________________________________________________
# Layer (type)                    Output Shape         Param #     Connected to
# ==================================================================================================
# input_title (InputLayer)        [(None, 1)]          0
# __________________________________________________________________________________________________
# input_body (InputLayer)         [(None, 1)]          0
# __________________________________________________________________________________________________
# lambda (Lambda)                 (None, 512)          0           input_title[0][0]
# __________________________________________________________________________________________________
# lambda_1 (Lambda)               (None, 512)          0           input_body[0][0]
# __________________________________________________________________________________________________
# dense (Dense)                   (None, 256)          131328      lambda[0][0]
# __________________________________________________________________________________________________
# dense_2 (Dense)                 (None, 256)          131328      lambda_1[0][0]
# __________________________________________________________________________________________________
# batch_normalization (BatchNorma (None, 256)          1024        dense[0][0]
# __________________________________________________________________________________________________
# batch_normalization_2 (BatchNor (None, 256)          1024        dense_2[0][0]
# __________________________________________________________________________________________________
# activation (Activation)         (None, 256)          0           batch_normalization[0][0]
# __________________________________________________________________________________________________
# activation_2 (Activation)       (None, 256)          0           batch_normalization_2[0][0]
# __________________________________________________________________________________________________
# dropout (Dropout)               (None, 256)          0           activation[0][0]
# __________________________________________________________________________________________________
# dropout_1 (Dropout)             (None, 256)          0           activation_2[0][0]
# __________________________________________________________________________________________________
# dense_1 (Dense)                 (None, 128)          32896       dropout[0][0]
# __________________________________________________________________________________________________
# dense_3 (Dense)                 (None, 128)          32896       dropout_1[0][0]
# __________________________________________________________________________________________________
# batch_normalization_1 (BatchNor (None, 128)          512         dense_1[0][0]
# __________________________________________________________________________________________________
# batch_normalization_3 (BatchNor (None, 128)          512         dense_3[0][0]
# __________________________________________________________________________________________________
# activation_1 (Activation)       (None, 128)          0           batch_normalization_1[0][0]
# __________________________________________________________________________________________________
# activation_3 (Activation)       (None, 128)          0           batch_normalization_3[0][0]
# __________________________________________________________________________________________________
# input_answer (InputLayer)       [(None, 1)]          0
# __________________________________________________________________________________________________
# add (Add)                       (None, 128)          0           activation_1[0][0]
#                                                                  activation_3[0][0]
# __________________________________________________________________________________________________
# lambda_2 (Lambda)               (None, 512)          0           input_answer[0][0]
# __________________________________________________________________________________________________
# dense_5 (Dense)                 (None, 512)          66048       add[0][0]
# __________________________________________________________________________________________________
# dense_4 (Dense)                 (None, 512)          262656      lambda_2[0][0]
# __________________________________________________________________________________________________
# batch_normalization_5 (BatchNor (None, 512)          2048        dense_5[0][0]
# __________________________________________________________________________________________________
# batch_normalization_4 (BatchNor (None, 512)          2048        dense_4[0][0]
# __________________________________________________________________________________________________
# activation_5 (Activation)       (None, 512)          0           batch_normalization_5[0][0]
# __________________________________________________________________________________________________
# activation_4 (Activation)       (None, 512)          0           batch_normalization_4[0][0]
# __________________________________________________________________________________________________
# add_1 (Add)                     (None, 512)          0           activation_5[0][0]
#                                                                  activation_4[0][0]
#                                                                  lambda[0][0]
#                                                                  lambda_1[0][0]
#                                                                  lambda_2[0][0]
# __________________________________________________________________________________________________
# dropout_2 (Dropout)             (None, 512)          0           add_1[0][0]
# __________________________________________________________________________________________________
# dense_6 (Dense)                 (None, 512)          262656      dropout_2[0][0]
# __________________________________________________________________________________________________
# batch_normalization_6 (BatchNor (None, 512)          2048        dense_6[0][0]
# __________________________________________________________________________________________________
# activation_6 (Activation)       (None, 512)          0           batch_normalization_6[0][0]
# __________________________________________________________________________________________________
# dropout_3 (Dropout)             (None, 512)          0           activation_6[0][0]
# __________________________________________________________________________________________________
# add_2 (Add)                     (None, 512)          0           dropout_3[0][0]
#                                                                  lambda[0][0]
#                                                                  lambda_1[0][0]
#                                                                  lambda_2[0][0]
# __________________________________________________________________________________________________
# dense_7 (Dense)                 (None, 512)          262656      add_2[0][0]
# __________________________________________________________________________________________________
# batch_normalization_7 (BatchNor (None, 512)          2048        dense_7[0][0]
# __________________________________________________________________________________________________
# activation_7 (Activation)       (None, 512)          0           batch_normalization_7[0][0]
# __________________________________________________________________________________________________
# dropout_4 (Dropout)             (None, 512)          0           activation_7[0][0]
# __________________________________________________________________________________________________
# output (Dense)                  (None, 30)           15390       dropout_4[0][0]
# ==================================================================================================
# Total params: 1,209,118
# Trainable params: 1,203,486
# Non-trainable params: 5,632
# __________________________________________________________________________________________________

# %% [markdown]
# # Train model

# %%
rlrop = ReduceLROnPlateau(monitor='val_loss', mode='min', patience=RLROP_PATIENCE, factor=DECAY_DROP, min_lr=1e-7, verbose=1)
spearmanCallback = SpearmanRhoCallback(training_data=(X_train, Y_train), validation_data=(X_valid, Y_valid), monitor='val_loss', mode='min', patience=ES_PATIENCE)
callback_list = [rlrop, spearmanCallback]

optimizer = optimizers.Adam(LEARNING_RATE)
model.compile(optimizer=optimizer, loss='binary_crossentropy')

history = model.fit(X_train, Y_train, 
                    validation_data=(X_valid, Y_valid), 
                    callbacks=callback_list, 
                    batch_size=BATCH_SIZE, 
                    epochs=EPOCHS, 
                    verbose=2).history
# Out:
# Train on 4863 samples, validate on 1216 samples
# Epoch 1/50
# spearman-rho: 0.1209 val_spearman-rho: 0.1065
# 4863/4863 - 32s - loss: 0.5595 - val_loss: 0.4860
# Epoch 2/50
# spearman-rho: 0.2156 val_spearman-rho: 0.1954
# 4863/4863 - 21s - loss: 0.4710 - val_loss: 0.4452
# Epoch 3/50
# spearman-rho: 0.2479 val_spearman-rho: 0.2261
# 4863/4863 - 20s - loss: 0.4504 - val_loss: 0.4281
# Epoch 4/50
# spearman-rho: 0.2791 val_spearman-rho: 0.2493
# 4863/4863 - 20s - loss: 0.4356 - val_loss: 0.4140
# Epoch 5/50
# spearman-rho: 0.3027 val_spearman-rho: 0.2671
# 4863/4863 - 20s - loss: 0.4261 - val_loss: 0.4075
# Epoch 6/50
# spearman-rho: 0.3214 val_spearman-rho: 0.2823
# 4863/4863 - 21s - loss: 0.4175 - val_loss: 0.4025
# Epoch 7/50
# spearman-rho: 0.3325 val_spearman-rho: 0.2923
# 4863/4863 - 21s - loss: 0.4109 - val_loss: 0.3977
# Epoch 8/50
# spearman-rho: 0.3447 val_spearman-rho: 0.3036
# 4863/4863 - 20s - loss: 0.4054 - val_loss: 0.3955
# Epoch 9/50
# spearman-rho: 0.3546 val_spearman-rho: 0.3115
# 4863/4863 - 20s - loss: 0.3997 - val_loss: 0.3926
# Epoch 10/50
# spearman-rho: 0.3660 val_spearman-rho: 0.3188
# 4863/4863 - 20s - loss: 0.3964 - val_loss: 0.3891
# Epoch 11/50
# spearman-rho: 0.3715 val_spearman-rho: 0.3213
# 4863/4863 - 20s - loss: 0.3929 - val_loss: 0.3882
# Epoch 12/50
# spearman-rho: 0.3779 val_spearman-rho: 0.3249
# 4863/4863 - 20s - loss: 0.3897 - val_loss: 0.3866
# Epoch 13/50
# spearman-rho: 0.3880 val_spearman-rho: 0.3299
# 4863/4863 - 21s - loss: 0.3872 - val_loss: 0.3855
# Epoch 14/50
# spearman-rho: 0.3933 val_spearman-rho: 0.3315
# 4863/4863 - 20s - loss: 0.3843 - val_loss: 0.3832
# Epoch 15/50
# spearman-rho: 0.3990 val_spearman-rho: 0.3340
# 4863/4863 - 20s - loss: 0.3816 - val_loss: 0.3830
# Epoch 16/50
# spearman-rho: 0.4032 val_spearman-rho: 0.3360
# 4863/4863 - 20s - loss: 0.3795 - val_loss: 0.3818
# Epoch 17/50
# spearman-rho: 0.4089 val_spearman-rho: 0.3374
# 4863/4863 - 20s - loss: 0.3781 - val_loss: 0.3811
# Epoch 18/50
# spearman-rho: 0.4141 val_spearman-rho: 0.3393
# 4863/4863 - 20s - loss: 0.3762 - val_loss: 0.3810
# Epoch 19/50
# spearman-rho: 0.4215 val_spearman-rho: 0.3411
# 4863/4863 - 20s - loss: 0.3760 - val_loss: 0.3802
# Epoch 20/50
# spearman-rho: 0.4240 val_spearman-rho: 0.3439
# 4863/4863 - 20s - loss: 0.3738 - val_loss: 0.3802
# Epoch 21/50
#
# Epoch 00021: ReduceLROnPlateau reducing learning rate to 9.000000427477062e-05.
# spearman-rho: 0.4308 val_spearman-rho: 0.3439
# 4863/4863 - 20s - loss: 0.3726 - val_loss: 0.3801
# Epoch 22/50
# spearman-rho: 0.4342 val_spearman-rho: 0.3451
# 4863/4863 - 21s - loss: 0.3700 - val_loss: 0.3795
# Epoch 23/50
# spearman-rho: 0.4361 val_spearman-rho: 0.3462
# 4863/4863 - 20s - loss: 0.3691 - val_loss: 0.3795
# Epoch 24/50
# spearman-rho: 0.4389 val_spearman-rho: 0.3457
# 4863/4863 - 20s - loss: 0.3697 - val_loss: 0.3793
# Epoch 25/50
# spearman-rho: 0.4412 val_spearman-rho: 0.3471
# 4863/4863 - 20s - loss: 0.3694 - val_loss: 0.3792
# Epoch 26/50
# spearman-rho: 0.4433 val_spearman-rho: 0.3477
# 4863/4863 - 20s - loss: 0.3677 - val_loss: 0.3794
# Epoch 27/50
#
# Epoch 00027: ReduceLROnPlateau reducing learning rate to 2.700000040931627e-05.
# spearman-rho: 0.4450 val_spearman-rho: 0.3466
# 4863/4863 - 20s - loss: 0.3672 - val_loss: 0.3795
# Epoch 28/50
# spearman-rho: 0.4463 val_spearman-rho: 0.3473
# 4863/4863 - 20s - loss: 0.3676 - val_loss: 0.3794
# Epoch 29/50
#
# Epoch 00029: ReduceLROnPlateau reducing learning rate to 8.100000013655517e-06.
# spearman-rho: 0.4473 val_spearman-rho: 0.3474
# Epoch 00028: early stopping
# 4863/4863 - 21s - loss: 0.3666 - val_loss: 0.3794

# %% [markdown]
# ## Model loss graph

# %%
sns.set(style="whitegrid")
plot_metrics(history, metric_list=['loss', 'spearman'])

# %% [markdown]
# # Evaluation

# %%
preds_train = model.predict(X_train)
preds_val = model.predict(X_valid)

display(get_metrics(Y_train, preds_train, Y_valid, preds_val, target_cols))
# Out:
#                                     Label  Train  Validation
# 0                                Averaged  0.447       0.347
# 1     question_asker_intent_understanding  0.385       0.341
# 2                  question_body_critical  0.600       0.513
# 3                 question_conversational  0.464       0.404
# 4            question_expect_short_answer  0.448       0.244
# 5                   question_fact_seeking  0.533       0.319
# 6   question_has_commonly_accepted_answer  0.576       0.437
# 7         question_interestingness_others  0.353       0.344
# 8           question_interestingness_self  0.482       0.478
# 9                   question_multi_intent  0.507       0.394
# 10         question_not_really_a_question  0.120       0.063
# 11               question_opinion_seeking  0.644       0.448
# 12                   question_type_choice  0.746       0.576
# 13                  question_type_compare  0.380       0.294
# 14              question_type_consequence  0.184       0.164
# 15               question_type_definition  0.374       0.311
# 16                   question_type_entity  0.448       0.407
# 17             question_type_instructions  0.846       0.754
# 18                question_type_procedure  0.450       0.271
# 19       question_type_reason_explanation  0.748       0.644
# 20                 question_type_spelling  0.072       0.069
# 21                  question_well_written  0.493       0.426
# 22                         answer_helpful  0.273       0.157
# 23            answer_level_of_information  0.329       0.273
# 24                       answer_plausible  0.227       0.128
# 25                       answer_relevance  0.235       0.123
# 26                    answer_satisfaction  0.306       0.161
# 27               answer_type_instructions  0.834       0.711
# 28                  answer_type_procedure  0.412       0.214
# 29         answer_type_reason_explanation  0.763       0.641
# 30                    answer_well_written  0.185       0.113

# %% [markdown]
# ## By category

# %%
target_cols_preds = [col+'_pred' for col in target_cols]
for col in target_cols_preds:
    train[col] = 0
    validation[col] = 0
    
train[target_cols_preds] = preds_train
validation[target_cols_preds] = preds_val
    
display(get_metrics_category(train, validation, target_cols, target_cols_preds, 'category'))
# Out:
#       Label Train (TECHNOLOGY) Validation (TECHNOLOGY) Train (SCIENCE)  \
# 0  Averaged               0.41                   0.309           0.453
#
#   Validation (SCIENCE) Train (STACKOVERFLOW) Validation (STACKOVERFLOW)  \
# 0                0.335                 0.366                      0.197
#
#   Train (LIFE_ARTS) Validation (LIFE_ARTS) Train (CULTURE)  \
# 0             0.454                  0.374           0.451
#
#   Validation (CULTURE)
# 0                0.334

# %% [markdown]
# #### Save model weights and ecoders

# %%
model.save_weights(model_path)
