# %% [markdown]
# ## Dependencies

# %%
import glob
import warnings
from tensorflow_hub import KerasLayer
from tensorflow.keras import Model, optimizers
from tensorflow.keras.callbacks import ReduceLROnPlateau
from tensorflow.keras.layers import Input, Dense, Dropout, GlobalAveragePooling1D, SpatialDropout1D, Concatenate
from googleqa_utilityscript import *
from googleqa_map_utilityscript import *
from script_lr_schedulers import WarmUpLearningRateScheduler
import bert_tokenization as tokenization
from transformers import BertConfig, BertTokenizer, TFBertModel


SEED = 0
seed_everything(SEED)
warnings.filterwarnings("ignore")
# Out:
# Using TensorFlow backend.

# %% [markdown]
# ## Load data

# %%
BERT_PATH = '/kaggle/input/bert-base-uncased-huggingface-transformer/bert-base-uncased-tf_model.h5'
VOCAB_PATH = '/kaggle/input/bert-base-uncased-huggingface-transformer/bert-base-uncased-vocab.txt'

k_fold = pd.read_csv('/kaggle/input/googleqa-mldataset/5-fold.csv')
N_FOLDS = 3

print('Samples: %s' % len(k_fold))
display(k_fold.head())
# Out:
# Samples: 6079
#    qa_id                                     question_title  \
# 0      0  What am I losing when using extension tubes in...
# 1      1  What is the distinction between a city and a s...
# 2      2  Maximum protusion length for through-hole comp...
# 3      3              Can an affidavit be used in Beit Din?
# 4      5       How do you make a binary image in Photoshop?
#
#                                        question_body question_user_name  \
# 0  After playing around with macro photography on...               ysap
# 1  I am trying to understand what kinds of places...      russellpierce
# 2  I'm working on a PCB that has through-hole com...          Joe Baker
# 3  An affidavit, from what i understand, is basic...         Scimonster
# 4  I am trying to make a binary image. I want mor...            leigero
#
#                                   question_user_page  \
# 0         https://photo.stackexchange.com/users/1024
# 1           https://rpg.stackexchange.com/users/8774
# 2  https://electronics.stackexchange.com/users/10157
# 3       https://judaism.stackexchange.com/users/5151
# 4  https://graphicdesign.stackexchange.com/users/...
#
#                                               answer answer_user_name  \
# 0  I just got extension tubes, so here's the skin...           rfusca
# 1  It might be helpful to look into the definitio...     Erik Schmidt
# 2  Do you even need grooves?  We make several pro...      Dwayne Reid
# 3  Sending an "affidavit" it is a dispute between...    Y     e     z
# 4  Check out Image Trace in Adobe Illustrator. \n...             q2ra
#
#                                     answer_user_page  \
# 0         https://photo.stackexchange.com/users/1917
# 1           https://rpg.stackexchange.com/users/1871
# 2  https://electronics.stackexchange.com/users/64754
# 3       https://judaism.stackexchange.com/users/4794
# 4  https://graphicdesign.stackexchange.com/users/...
#
#                                                  url   category  ...  \
# 0  http://photo.stackexchange.com/questions/9169/...  LIFE_ARTS  ...
# 1  http://rpg.stackexchange.com/questions/47820/w...    CULTURE  ...
# 2  http://electronics.stackexchange.com/questions...    SCIENCE  ...
# 3  http://judaism.stackexchange.com/questions/551...    CULTURE  ...
# 4  http://graphicdesign.stackexchange.com/questio...  LIFE_ARTS  ...
#
#   answer_satisfaction  answer_type_instructions  answer_type_procedure  \
# 0            0.800000                       1.0               0.000000
# 1            0.666667                       0.0               0.000000
# 2            0.666667                       0.0               0.333333
# 3            0.800000                       0.0               0.000000
# 4            0.800000                       1.0               0.000000
#
#    answer_type_reason_explanation  answer_well_written      fold_1  fold_2  \
# 0                        0.000000             1.000000       train   train
# 1                        0.666667             0.888889  validation   train
# 2                        1.000000             0.888889       train   train
# 3                        1.000000             1.000000       train   train
# 4                        1.000000             1.000000  validation   train
#
#        fold_3      fold_4      fold_5
# 0       train  validation       train
# 1       train       train       train
# 2  validation       train       train
# 3       train       train  validation
# 4       train       train       train
#
# [5 rows x 46 columns]

# %%
question_target_cols = ['question_asker_intent_understanding','question_body_critical', 'question_conversational', 
                        'question_expect_short_answer', 'question_fact_seeking', 'question_has_commonly_accepted_answer',
                        'question_interestingness_others', 'question_interestingness_self', 'question_multi_intent', 
                        'question_not_really_a_question', 'question_opinion_seeking', 'question_type_choice',
                        'question_type_compare', 'question_type_consequence', 'question_type_definition', 
                        'question_type_entity', 'question_type_instructions', 'question_type_procedure',
                        'question_type_reason_explanation', 'question_type_spelling', 'question_well_written']
answer_target_cols = ['answer_helpful', 'answer_level_of_information', 'answer_plausible', 'answer_relevance',
                      'answer_satisfaction', 'answer_type_instructions', 'answer_type_procedure', 
                      'answer_type_reason_explanation', 'answer_well_written']
target_cols = question_target_cols + answer_target_cols

# %% [markdown]
# # Pre-process data

# %%
text_features = ['question_title', 'question_body', 'answer']

# for feature in text_features:
#     # Lower
#     k_fold[feature] = k_fold[feature].apply(lambda x: x.lower())
#     # Map misspellings
#     k_fold[feature] = k_fold[feature].apply(lambda x: map_misspellings(x))
#     # Map contractions
#     k_fold[feature] = k_fold[feature].apply(lambda x: map_contraction(x))
#     # Trim text
#     k_fold[feature] = k_fold[feature].apply(lambda x: x.strip())

# %% [markdown]
# # Model parameters

# %%
EPOCHS = 8
BATCH_SIZE = 8
LEARNING_RATE = 3e-5
N_CLASS = len(target_cols)
ES_PATIENCE = 1
MAX_SEQUENCE_LENGTH = 512
LR_WARMUP_EPOCHS = 2

# %% [markdown]
# # Model

# %%
bert_config = BertConfig()
bert_config.output_hidden_states=True

def model_fn():
    input_word_ids = Input((MAX_SEQUENCE_LENGTH,), dtype=tf.int32, name='input_word_ids')
    input_masks = Input((MAX_SEQUENCE_LENGTH,), dtype=tf.int32, name='input_masks')
    segment_ids = Input((MAX_SEQUENCE_LENGTH,), dtype=tf.int32, name='segment_ids')

    bert_model = TFBertModel.from_pretrained(BERT_PATH, config=bert_config)
    sequence_output, pooled_output, hidden_states = bert_model([input_word_ids, input_masks, segment_ids])
    
#     h12 = tf.reshape(hidden_states[-1][:,0],(-1,1,768))
    h11 = tf.reshape(hidden_states[-2][:,0],(-1,1,768))
#     h10 = tf.reshape(hidden_states[-3][:,0],(-1,1,768))
#     h09 = tf.reshape(hidden_states[-4][:,0],(-1,1,768))

    x = GlobalAveragePooling1D()(h11)
    x = Dropout(0.2)(x)
    output = Dense(N_CLASS, activation="sigmoid", name="output")(x)

    model = Model(inputs=[input_word_ids, input_masks, segment_ids], outputs=output)
    
    return model

# %% [markdown]
# # Train model

# %%
tokenizer = BertTokenizer.from_pretrained(VOCAB_PATH, do_lower_case=True)

history_list = []
metric_list = []
category_metric_list = []
target_cols_preds = [col+'_pred' for col in target_cols]

for n_fold in range(N_FOLDS):
    ### Data
    train = k_fold[k_fold['fold_%d' % (n_fold+1)] == 'train']
    validation = k_fold[k_fold['fold_%d' % (n_fold+1)] == 'validation']
    
    ### Create features
    # Train features
    X_train = compute_input_arays(train, text_features, tokenizer, MAX_SEQUENCE_LENGTH)
    Y_train = train[target_cols].values

    # Validation features
    X_valid = compute_input_arays(validation, text_features, tokenizer, MAX_SEQUENCE_LENGTH)
    Y_valid = validation[target_cols].values

    # Train model
    model_path = '/kaggle/working/model_fold_%d' % (n_fold+1)
    spearmanCallback = SpearmanRhoCallback(training_data=(X_train, Y_train), 
                                           validation_data=(X_valid, Y_valid), 
                                           model_path=model_path, 
                                           monitor='val_loss', mode='min', 
                                           patience=ES_PATIENCE, checkpoint=True)
    WARMUP_BATCHES = LR_WARMUP_EPOCHS * len(train) // BATCH_SIZE
    warmup_lr = WarmUpLearningRateScheduler(WARMUP_BATCHES, LEARNING_RATE)

    callback_list = [spearmanCallback, warmup_lr]
    optimizer = optimizers.Adam(lr=LEARNING_RATE)
    model = model_fn()
    model.compile(optimizer=optimizer, loss='binary_crossentropy')

    history = model.fit(X_train, Y_train, 
                        validation_data=(X_valid, Y_valid), 
                        callbacks=callback_list, 
                        batch_size=BATCH_SIZE, 
                        epochs=EPOCHS, 
                        verbose=2).history
    history_list.append(history)

    # Save last epoch weights
    model.save_weights('/kaggle/working/model_fold_%d_last_epoch.h5' % (n_fold+1))
    
    ### Evaluation - Label metrics
    model.load_weights(model_path+'.h5')
    preds_train = model.predict(X_train)
    preds_val = model.predict(X_valid)
    metric_list.append(get_metrics(Y_train, preds_train, Y_valid, preds_val, target_cols))
    
    ### Evaluation - Category metrics
    for col in target_cols_preds:
        train[col] = 0
        validation[col] = 0

    train[target_cols_preds] = preds_train
    validation[target_cols_preds] = preds_val
    category_metric_list.append(get_metrics_category(train, validation, target_cols, target_cols_preds, 'category'))
# Out:
# Train on 4864 samples, validate on 1215 samples
# Epoch 1/8
# spearman-rho: 0.3169 val_spearman-rho: 0.3031
# Saved model weights at "/kaggle/working/model_fold_1.h5"
# 4864/4864 - 454s - loss: 0.4663 - val_loss: 0.3892
# Epoch 2/8
# spearman-rho: 0.4083 val_spearman-rho: 0.3686
# Saved model weights at "/kaggle/working/model_fold_1.h5"
# 4864/4864 - 436s - loss: 0.3889 - val_loss: 0.3718
# Epoch 3/8
# spearman-rho: 0.4613 val_spearman-rho: 0.3868
# Saved model weights at "/kaggle/working/model_fold_1.h5"
# 4864/4864 - 436s - loss: 0.3722 - val_loss: 0.3670
# Epoch 4/8
# spearman-rho: 0.5069 val_spearman-rho: 0.3941
# Epoch 00003: early stopping
# 4864/4864 - 434s - loss: 0.3582 - val_loss: 0.3692
# Train on 4864 samples, validate on 1215 samples
# Epoch 1/8
# spearman-rho: 0.3185 val_spearman-rho: 0.2991
# Saved model weights at "/kaggle/working/model_fold_2.h5"
# 4864/4864 - 455s - loss: 0.4703 - val_loss: 0.3926
# Epoch 2/8
# spearman-rho: 0.4028 val_spearman-rho: 0.3619
# Saved model weights at "/kaggle/working/model_fold_2.h5"
# 4864/4864 - 436s - loss: 0.3896 - val_loss: 0.3776
# Epoch 3/8
# spearman-rho: 0.4616 val_spearman-rho: 0.3888
# Saved model weights at "/kaggle/working/model_fold_2.h5"
# 4864/4864 - 436s - loss: 0.3723 - val_loss: 0.3720
# Epoch 4/8
# spearman-rho: 0.5146 val_spearman-rho: 0.3926
# Saved model weights at "/kaggle/working/model_fold_2.h5"
# 4864/4864 - 436s - loss: 0.3577 - val_loss: 0.3689
# Epoch 5/8
# spearman-rho: 0.5636 val_spearman-rho: 0.3896
# Epoch 00004: early stopping
# 4864/4864 - 435s - loss: 0.3449 - val_loss: 0.3696
# Train on 4859 samples, validate on 1220 samples
# Epoch 1/8
# spearman-rho: 0.3053 val_spearman-rho: 0.2955
# Saved model weights at "/kaggle/working/model_fold_3.h5"
# 4859/4859 - 478s - loss: 0.4744 - val_loss: 0.3935
# Epoch 2/8
# spearman-rho: 0.3838 val_spearman-rho: 0.3487
# Saved model weights at "/kaggle/working/model_fold_3.h5"
# 4859/4859 - 455s - loss: 0.3898 - val_loss: 0.3788
# Epoch 3/8
# spearman-rho: 0.4619 val_spearman-rho: 0.3851
# Saved model weights at "/kaggle/working/model_fold_3.h5"
# 4859/4859 - 454s - loss: 0.3725 - val_loss: 0.3703
# Epoch 4/8
# spearman-rho: 0.5089 val_spearman-rho: 0.3949
# Saved model weights at "/kaggle/working/model_fold_3.h5"
# 4859/4859 - 455s - loss: 0.3586 - val_loss: 0.3692
# Epoch 5/8
# spearman-rho: 0.5589 val_spearman-rho: 0.3869
# Epoch 00004: early stopping
# 4859/4859 - 453s - loss: 0.3460 - val_loss: 0.3732

# %% [markdown]
# ## Model loss graph

# %%
for n_fold in range(N_FOLDS):
    print('Fold: %d' % n_fold)
    sns.set(style="whitegrid")
    plot_metrics(history_list[n_fold], metric_list=['loss', 'spearman'])
# Out:
# Fold: 0
# Fold: 1
# Fold: 2

# %% [markdown]
# # Evaluation

# %%
metrics_df = metric_list[0][['Label', 'Train', 'Validation']].copy()
metrics_df.columns = ['Label', 'Train_fold_0', 'Valid_fold_0']

for n_fold in range(1, N_FOLDS):
    metrics_df_idx = metric_list[n_fold][['Train', 'Validation']].copy()
    metrics_df_idx.columns = ['Train_fold_%d' % n_fold, 'Valid_fold_%d' % n_fold]
    metrics_df = pd.concat([metrics_df, metrics_df_idx], axis=1)

metrics_df['Train'] = 0
metrics_df['Validation'] = 0
for n_fold in range(N_FOLDS):
    metrics_df['Train'] += metrics_df['Train_fold_%d' % n_fold] / N_FOLDS
    metrics_df['Validation'] += metrics_df['Valid_fold_%d' % n_fold] / N_FOLDS

metrics_df['Var'] = metrics_df['Train'] - metrics_df['Validation']
display(metrics_df.style.applymap(color_map))
# Out:
# <style  type="text/css" >
#     #T_aa789c6c_446c_11ea_bd06_7dd3728c617frow0_col0 {
#             color:  black;
#         }    #T_aa789c6c_446c_11ea_bd06_7dd3728c617frow0_col1 {
#             color:  black;
#         }    #T_aa789c6c_446c_11ea_bd06_7dd3728c617frow0_col2 {
#             color:  black;
#         }    #T_aa789c6c_446c_11ea_bd06_7dd3728c617frow0_col3 {
#             color:  black;
#         }    #T_aa789c6c_446c_11ea_bd06_7dd3728c617frow0_col4 {
#             color:  black;
#         }    #T_aa789c6c_446c_11ea_bd06_7dd3728c617frow0_col5 {
#             color:  black;
#         }    #T_aa789c6c_446c_11ea_bd06_7dd3728c617frow0_col6 {
#             color:  black;
#         }    #T_aa789c6c_446c_11ea_bd06_7dd3728c617frow0_col7 {
#             color:  black;
#         }    #T_aa789c6c_446c_11ea_bd06_7dd3728c617frow0_col8 {
#             color:  black;
#         }    #T_aa789c6c_446c_11ea_bd06_7dd3728c617frow0_col9 {
#             color:  orange;
#         }    #T_aa789c6c_446c_11ea_bd06_7dd3728c617frow1_col0 {
#             color:  black;
#         }    #T_aa789c6c_446c_11ea_bd06_7dd3728c617frow1_col1 {
#             color:  black;
#         }    #T_aa789c6c_446c_11ea_bd06_7dd3728c617frow1_col2 {
#             color:  black;
#         }    #T_aa789c6c_446c_11ea_bd06_7dd3728c617frow1_col3 {
#             color:  black;
#         }    #T_aa789c6c_446c_11ea_bd06_7dd3728c617frow1_col4 {
#             color:  black;
#         }    #T_aa789c6c_446c_11ea_bd06_7dd3728c617frow1_col5 {
#             color:  black;
#         }    #T_aa789c6c_446c_11ea_bd06_7dd3728c617frow1_col6 {
#             color:  black;
#         }    #T_aa789c6c_446c_11ea_bd06_7dd3728c617frow1_col7 {
#             color:  black;
#         }    #T_aa789c6c_446c_11ea_bd06_7dd3728c617frow1_col8 {
#             color:  black;
#         }    #T_aa789c6c_446c_11ea_bd06_7dd3728c617frow1_col9 {
#             color:  purple;
#         }    #T_aa789c6c_446c_11ea_bd06_7dd3728c617frow2_col0 {
#             color:  black;
#         }    #T_aa789c6c_446c_11ea_bd06_7dd3728c617frow2_col1 {
#             color:  black;
#         }    #T_aa789c6c_446c_11ea_bd06_7dd3728c617frow2_col2 {
#             color:  black;
#         }    #T_aa789c6c_446c_11ea_bd06_7dd3728c617frow2_col3 {
#             color:  black;
#         }    #T_aa789c6c_446c_11ea_bd06_7dd3728c617frow2_col4 {
#             color:  black;
#         }    #T_aa789c6c_446c_11ea_bd06_7dd3728c617frow2_col5 {
#             color:  black;
#         }    #T_aa789c6c_446c_11ea_bd06_7dd3728c617frow2_col6 {
#             color:  black;
#         }    #T_aa789c6c_446c_11ea_bd06_7dd3728c617frow2_col7 {
#             color:  black;
#         }    #T_aa789c6c_446c_11ea_bd06_7dd3728c617frow2_col8 {
#             color:  black;
#         }    #T_aa789c6c_446c_11ea_bd06_7dd3728c617frow2_col9 {
#             color:  orange;
#         }    #T_aa789c6c_446c_11ea_bd06_7dd3728c617frow3_col0 {
#             color:  black;
#         }    #T_aa789c6c_446c_11ea_bd06_7dd3728c617frow3_col1 {
#             color:  black;
#         }    #T_aa789c6c_446c_11ea_bd06_7dd3728c617frow3_col2 {
#             color:  black;
#         }    #T_aa789c6c_446c_11ea_bd06_7dd3728c617frow3_col3 {
#             color:  black;
#         }    #T_aa789c6c_446c_11ea_bd06_7dd3728c617frow3_col4 {
#             color:  black;
#         }    #T_aa789c6c_446c_11ea_bd06_7dd3728c617frow3_col5 {
#             color:  black;
#         }    #T_aa789c6c_446c_11ea_bd06_7dd3728c617frow3_col6 {
#             color:  black;
#         }    #T_aa789c6c_446c_11ea_bd06_7dd3728c617frow3_col7 {
#             color:  black;
#         }    #T_aa789c6c_446c_11ea_bd06_7dd3728c617frow3_col8 {
#             color:  black;
#         }    #T_aa789c6c_446c_11ea_bd06_7dd3728c617frow3_col9 {
#             color:  orange;
#         }    #T_aa789c6c_446c_11ea_bd06_7dd3728c617frow4_col0 {
#             color:  black;
#         }    #T_aa789c6c_446c_11ea_bd06_7dd3728c617frow4_col1 {
#             color:  black;
#         }    #T_aa789c6c_446c_11ea_bd06_7dd3728c617frow4_col2 {
#             color:  black;
#         }    #T_aa789c6c_446c_11ea_bd06_7dd3728c617frow4_col3 {
#             color:  black;
#         }    #T_aa789c6c_446c_11ea_bd06_7dd3728c617frow4_col4 {
#             color:  black;
#         }    #T_aa789c6c_446c_11ea_bd06_7dd3728c617frow4_col5 {
#             color:  black;
#         }    #T_aa789c6c_446c_11ea_bd06_7dd3728c617frow4_col6 {
#             color:  black;
#         }    #T_aa789c6c_446c_11ea_bd06_7dd3728c617frow4_col7 {
#             color:  black;
#         }    #T_aa789c6c_446c_11ea_bd06_7dd3728c617frow4_col8 {
#             color:  black;
#         }    #T_aa789c6c_446c_11ea_bd06_7dd3728c617frow4_col9 {
#             color:  purple;
#         }    #T_aa789c6c_446c_11ea_bd06_7dd3728c617frow5_col0 {
#             color:  black;
#         }    #T_aa789c6c_446c_11ea_bd06_7dd3728c617frow5_col1 {
#             color:  black;
#         }    #T_aa789c6c_446c_11ea_bd06_7dd3728c617frow5_col2 {
#             color:  black;
#         }    #T_aa789c6c_446c_11ea_bd06_7dd3728c617frow5_col3 {
#             color:  black;
#         }    #T_aa789c6c_446c_11ea_bd06_7dd3728c617frow5_col4 {
#             color:  black;
#         }    #T_aa789c6c_446c_11ea_bd06_7dd3728c617frow5_col5 {
#             color:  black;
#         }    #T_aa789c6c_446c_11ea_bd06_7dd3728c617frow5_col6 {
#             color:  black;
#         }    #T_aa789c6c_446c_11ea_bd06_7dd3728c617frow5_col7 {
#             color:  black;
#         }    #T_aa789c6c_446c_11ea_bd06_7dd3728c617frow5_col8 {
#             color:  black;
#         }    #T_aa789c6c_446c_11ea_bd06_7dd3728c617frow5_col9 {
#             color:  purple;
#         }    #T_aa789c6c_446c_11ea_bd06_7dd3728c617frow6_col0 {
#             color:  black;
#         }    #T_aa789c6c_446c_11ea_bd06_7dd3728c617frow6_col1 {
#             color:  black;
#         }    #T_aa789c6c_446c_11ea_bd06_7dd3728c617frow6_col2 {
#             color:  black;
#         }    #T_aa789c6c_446c_11ea_bd06_7dd3728c617frow6_col3 {
#             color:  black;
#         }    #T_aa789c6c_446c_11ea_bd06_7dd3728c617frow6_col4 {
#             color:  orange;
#         }    #T_aa789c6c_446c_11ea_bd06_7dd3728c617frow6_col5 {
#             color:  black;
#         }    #T_aa789c6c_446c_11ea_bd06_7dd3728c617frow6_col6 {
#             color:  orange;
#         }    #T_aa789c6c_446c_11ea_bd06_7dd3728c617frow6_col7 {
#             color:  black;
#         }    #T_aa789c6c_446c_11ea_bd06_7dd3728c617frow6_col8 {
#             color:  orange;
#         }    #T_aa789c6c_446c_11ea_bd06_7dd3728c617frow6_col9 {
#             color:  orange;
#         }    #T_aa789c6c_446c_11ea_bd06_7dd3728c617frow7_col0 {
#             color:  black;
#         }    #T_aa789c6c_446c_11ea_bd06_7dd3728c617frow7_col1 {
#             color:  black;
#         }    #T_aa789c6c_446c_11ea_bd06_7dd3728c617frow7_col2 {
#             color:  black;
#         }    #T_aa789c6c_446c_11ea_bd06_7dd3728c617frow7_col3 {
#             color:  black;
#         }    #T_aa789c6c_446c_11ea_bd06_7dd3728c617frow7_col4 {
#             color:  black;
#         }    #T_aa789c6c_446c_11ea_bd06_7dd3728c617frow7_col5 {
#             color:  black;
#         }    #T_aa789c6c_446c_11ea_bd06_7dd3728c617frow7_col6 {
#             color:  black;
#         }    #T_aa789c6c_446c_11ea_bd06_7dd3728c617frow7_col7 {
#             color:  black;
#         }    #T_aa789c6c_446c_11ea_bd06_7dd3728c617frow7_col8 {
#             color:  black;
#         }    #T_aa789c6c_446c_11ea_bd06_7dd3728c617frow7_col9 {
#             color:  orange;
#         }    #T_aa789c6c_446c_11ea_bd06_7dd3728c617frow8_col0 {
#             color:  black;
#         }    #T_aa789c6c_446c_11ea_bd06_7dd3728c617frow8_col1 {
#             color:  black;
#         }    #T_aa789c6c_446c_11ea_bd06_7dd3728c617frow8_col2 {
#             color:  black;
#         }    #T_aa789c6c_446c_11ea_bd06_7dd3728c617frow8_col3 {
#             color:  black;
#         }    #T_aa789c6c_446c_11ea_bd06_7dd3728c617frow8_col4 {
#             color:  black;
#         }    #T_aa789c6c_446c_11ea_bd06_7dd3728c617frow8_col5 {
#             color:  black;
#         }    #T_aa789c6c_446c_11ea_bd06_7dd3728c617frow8_col6 {
#             color:  black;
#         }    #T_aa789c6c_446c_11ea_bd06_7dd3728c617frow

# %% [markdown]
# ## By category

# %%
category_metrics_df = category_metric_list[0][['Label', 'Train', 'Validation']].copy()
category_metrics_df.columns = ['Label', 'Train_fold_0', 'Valid_fold_0']

for n_fold in range(1, N_FOLDS):
    category_metrics_df_idx = category_metric_list[n_fold][['Train', 'Validation']].copy()
    category_metrics_df_idx.columns = ['Train_fold_%d' % n_fold, 'Valid_fold_%d' % n_fold]
    category_metrics_df = pd.concat([category_metrics_df, category_metrics_df_idx], axis=1)
    
category_metrics_df['Train'] = 0
category_metrics_df['Validation'] = 0
for n_fold in range(N_FOLDS):
    category_metrics_df['Train'] += category_metrics_df['Train_fold_%d' % n_fold] / N_FOLDS
    category_metrics_df['Validation'] += category_metrics_df['Valid_fold_%d' % n_fold] / N_FOLDS
    
category_metrics_df['Var'] = category_metrics_df['Train'] - category_metrics_df['Validation']
display(category_metrics_df.style.applymap(color_map))
# Out:
# <style  type="text/css" >
#     #T_aa83dc12_446c_11ea_bd06_7dd3728c617frow0_col0 {
#             color:  black;
#         }    #T_aa83dc12_446c_11ea_bd06_7dd3728c617frow0_col1 {
#             color:  black;
#         }    #T_aa83dc12_446c_11ea_bd06_7dd3728c617frow0_col2 {
#             color:  black;
#         }    #T_aa83dc12_446c_11ea_bd06_7dd3728c617frow0_col3 {
#             color:  black;
#         }    #T_aa83dc12_446c_11ea_bd06_7dd3728c617frow0_col4 {
#             color:  black;
#         }    #T_aa83dc12_446c_11ea_bd06_7dd3728c617frow0_col5 {
#             color:  black;
#         }    #T_aa83dc12_446c_11ea_bd06_7dd3728c617frow0_col6 {
#             color:  black;
#         }    #T_aa83dc12_446c_11ea_bd06_7dd3728c617frow0_col7 {
#             color:  black;
#         }    #T_aa83dc12_446c_11ea_bd06_7dd3728c617frow0_col8 {
#             color:  black;
#         }    #T_aa83dc12_446c_11ea_bd06_7dd3728c617frow0_col9 {
#             color:  orange;
#         }    #T_aa83dc12_446c_11ea_bd06_7dd3728c617frow1_col0 {
#             color:  black;
#         }    #T_aa83dc12_446c_11ea_bd06_7dd3728c617frow1_col1 {
#             color:  black;
#         }    #T_aa83dc12_446c_11ea_bd06_7dd3728c617frow1_col2 {
#             color:  black;
#         }    #T_aa83dc12_446c_11ea_bd06_7dd3728c617frow1_col3 {
#             color:  black;
#         }    #T_aa83dc12_446c_11ea_bd06_7dd3728c617frow1_col4 {
#             color:  black;
#         }    #T_aa83dc12_446c_11ea_bd06_7dd3728c617frow1_col5 {
#             color:  black;
#         }    #T_aa83dc12_446c_11ea_bd06_7dd3728c617frow1_col6 {
#             color:  black;
#         }    #T_aa83dc12_446c_11ea_bd06_7dd3728c617frow1_col7 {
#             color:  black;
#         }    #T_aa83dc12_446c_11ea_bd06_7dd3728c617frow1_col8 {
#             color:  black;
#         }    #T_aa83dc12_446c_11ea_bd06_7dd3728c617frow1_col9 {
#             color:  orange;
#         }    #T_aa83dc12_446c_11ea_bd06_7dd3728c617frow2_col0 {
#             color:  black;
#         }    #T_aa83dc12_446c_11ea_bd06_7dd3728c617frow2_col1 {
#             color:  black;
#         }    #T_aa83dc12_446c_11ea_bd06_7dd3728c617frow2_col2 {
#             color:  black;
#         }    #T_aa83dc12_446c_11ea_bd06_7dd3728c617frow2_col3 {
#             color:  black;
#         }    #T_aa83dc12_446c_11ea_bd06_7dd3728c617frow2_col4 {
#             color:  black;
#         }    #T_aa83dc12_446c_11ea_bd06_7dd3728c617frow2_col5 {
#             color:  black;
#         }    #T_aa83dc12_446c_11ea_bd06_7dd3728c617frow2_col6 {
#             color:  black;
#         }    #T_aa83dc12_446c_11ea_bd06_7dd3728c617frow2_col7 {
#             color:  black;
#         }    #T_aa83dc12_446c_11ea_bd06_7dd3728c617frow2_col8 {
#             color:  black;
#         }    #T_aa83dc12_446c_11ea_bd06_7dd3728c617frow2_col9 {
#             color:  orange;
#         }    #T_aa83dc12_446c_11ea_bd06_7dd3728c617frow3_col0 {
#             color:  black;
#         }    #T_aa83dc12_446c_11ea_bd06_7dd3728c617frow3_col1 {
#             color:  black;
#         }    #T_aa83dc12_446c_11ea_bd06_7dd3728c617frow3_col2 {
#             color:  orange;
#         }    #T_aa83dc12_446c_11ea_bd06_7dd3728c617frow3_col3 {
#             color:  black;
#         }    #T_aa83dc12_446c_11ea_bd06_7dd3728c617frow3_col4 {
#             color:  orange;
#         }    #T_aa83dc12_446c_11ea_bd06_7dd3728c617frow3_col5 {
#             color:  black;
#         }    #T_aa83dc12_446c_11ea_bd06_7dd3728c617frow3_col6 {
#             color:  black;
#         }    #T_aa83dc12_446c_11ea_bd06_7dd3728c617frow3_col7 {
#             color:  black;
#         }    #T_aa83dc12_446c_11ea_bd06_7dd3728c617frow3_col8 {
#             color:  black;
#         }    #T_aa83dc12_446c_11ea_bd06_7dd3728c617frow3_col9 {
#             color:  orange;
#         }    #T_aa83dc12_446c_11ea_bd06_7dd3728c617frow4_col0 {
#             color:  black;
#         }    #T_aa83dc12_446c_11ea_bd06_7dd3728c617frow4_col1 {
#             color:  black;
#         }    #T_aa83dc12_446c_11ea_bd06_7dd3728c617frow4_col2 {
#             color:  black;
#         }    #T_aa83dc12_446c_11ea_bd06_7dd3728c617frow4_col3 {
#             color:  black;
#         }    #T_aa83dc12_446c_11ea_bd06_7dd3728c617frow4_col4 {
#             color:  black;
#         }    #T_aa83dc12_446c_11ea_bd06_7dd3728c617frow4_col5 {
#             color:  black;
#         }    #T_aa83dc12_446c_11ea_bd06_7dd3728c617frow4_col6 {
#             color:  orange;
#         }    #T_aa83dc12_446c_11ea_bd06_7dd3728c617frow4_col7 {
#             color:  black;
#         }    #T_aa83dc12_446c_11ea_bd06_7dd3728c617frow4_col8 {
#             color:  black;
#         }    #T_aa83dc12_446c_11ea_bd06_7dd3728c617frow4_col9 {
#             color:  orange;
#         }</style><table id="T_aa83dc12_446c_11ea_bd06_7dd3728c617f" ><thead>    <tr>        <th class="blank level0" ></th>        <th class="col_heading level0 col0" >Label</th>        <th class="col_heading level0 col1" >Train_fold_0</th>        <th class="col_heading level0 col2" >Valid_fold_0</th>        <th class="col_heading level0 col3" >Train_fold_1</th>        <th class="col_heading level0 col4" >Valid_fold_1</th>        <th class="col_heading level0 col5" >Train_fold_2</th>        <th class="col_heading level0 col6" >Valid_fold_2</th>        <th class="col_heading level0 col7" >Train</th>        <th class="col_heading level0 col8" >Validation</th>        <th class="col_heading level0 col9" >Var</th>    </tr></thead><tbody>
#                 <tr>
#                         <th id="T_aa83dc12_446c_11ea_bd06_7dd3728c617flevel0_row0" class="row_heading level0 row0" >0</th>
#                         <td id="T_aa83dc12_446c_11ea_bd06_7dd3728c617frow0_col0" class="data row0 col0" >LIFE_ARTS</td>
#                         <td id="T_aa83dc12_446c_11ea_bd06_7dd3728c617frow0_col1" class="data row0 col1" >0.491</td>
#                         <td id="T_aa83dc12_446c_11ea_bd06_7dd3728c617frow0_col2" class="data row0 col2" >0.404</td>
#                         <td id="T_aa83dc12_446c_11ea_bd06_7dd3728c617frow0_col3" class="data row0 col3" >0.56</td>
#                         <td id="T_aa83dc12_446c_11ea_bd06_7dd3728c617frow0_col4" class="data row0 col4" >0.418</td>
#                         <td id="T_aa83dc12_446c_11ea_bd06_7dd3728c617frow0_col5" class="data row0 col5" >0.543</td>
#                         <td id="T_aa83dc12_446c_11ea_bd06_7dd3728c617frow0_col6" class="data row0 col6" >0.434</td>
#                         <td id="T_aa83dc12_446c_11ea_bd06_7dd3728c617frow0_col7" class="data row0 col7" >0.531333</td>
#                         <td id="T_aa83dc12_446c_11ea_bd06_7dd3728c617frow0_col8" class="data row0 col8" >0.418667</td>
#                         <td id="T_aa83dc12_446c_11ea_bd06_7dd3728c617frow0_col9" class="data row0 col9" >0.112667</td>
#             </tr>
#             <tr>
#                         <th id="T_aa83dc12_446c_11ea_bd06_7dd3728c617flevel0_row1" class="row_heading level0 row1" >1</th>
#                         <td id="T_aa83dc12_446c_11ea_bd06_7dd3728c617frow1_col0" class="data row1 col0" >SCIENCE</td>
#                         <td id="T_aa83dc12_446c_11ea_bd06_7dd3728c617frow1_col1" class="data row1 col1" >0.484</td>
#                         <td id="T_aa83dc12_446c_11ea_bd06_7dd3728c617frow1_col2" class="data row1 col2" >0.394</td>
#                         <td id="T_aa83dc12_446c_11ea_bd06_7dd3728c617frow1_col3" class="data row1 col3" >0.561</td>
#                         <td id="T_aa83dc12_446c_11ea_bd06_7dd3728c617frow1_col4" class="data row1 col4" >0.358</td>
#                         <td id="T_aa83dc12_446c_11ea_bd06_7dd3728c617frow1_col5" class="data row1 col5" >0.538</td>
#                         <td id="T_aa83dc12_446c_11ea_bd06_7dd3728c617frow1_col6" class="data row1 col6" >0.409</td>
#                         <td id="T_aa83dc12_446c_11ea_bd06_7dd3728c617frow1_col7" class="data row1 col7" >0.527667</td>
#                         <td id="T_aa83dc12_446c_11ea_bd06_7dd3728c617frow1_col8" class="data row1 col8" >0.387</td>
#                         <td id="T_aa83dc12_446c_11ea_bd06_7dd3728c617frow1_col9" class="data row1 col9" >0.140667</td>
#             </tr>
#             <tr>
