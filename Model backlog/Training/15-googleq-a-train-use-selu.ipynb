# %% [markdown]
# ## Dependencies

# %%
import warnings
import tensorflow_hub as hub
from tensorflow.keras import Model, optimizers
from tensorflow.keras.layers import Lambda, Input, Dense, Dropout, Concatenate, BatchNormalization, Activation
from tensorflow.keras.callbacks import EarlyStopping, ReduceLROnPlateau
from googleqa_utilityscript import *


SEED = 0
seed_everything(SEED)
warnings.filterwarnings("ignore")

# %% [markdown]
# ## Load data

# %%
hold_out = pd.read_csv('/kaggle/input/googleqa-mldataset/hold-out.csv')
train = hold_out[hold_out['set'] == 'train']
validation = hold_out[hold_out['set'] == 'validation']

print('Train samples: %s' % len(train))
print('Validation samples: %s' % len(validation))
display(train.head())
# Out:
# Train samples: 4863
# Validation samples: 1216
#    qa_id                                     question_title  \
# 0   3895  Magento (1.7) Bundled Product with FREE Produc...
# 1   3131                             Find router on network
# 2   1507  Negatively curved metrics minimizing the lengt...
# 3   6784               Isn’t the FAQ label obsolete by now?
# 4   2135  Changing background image one time on responsi...
#
#                                        question_body question_user_name  \
# 0  I'm looking to create a bundle offer where cus...                Joe
# 1  I've just bought a Belkin N+ Wireless Router. ...                Guy
# 2  Good afternoon everyone !\n\nI have the follow...            Selim G
# 3  Don’t get me wrong in the beginning of reading...     Benny Skogberg
# 4  The code I'm using is this one \n\nbackground:...        user2141649
#
#                               question_user_page  \
# 0  https://magento.stackexchange.com/users/16572
# 1               https://superuser.com/users/3248
# 2           https://mathoverflow.net/users/25511
# 3        https://ux.stackexchange.com/users/4679
# 4        https://stackoverflow.com/users/2141649
#
#                                               answer   answer_user_name  \
# 0  Since the third item is fixed, you can use sho...  Fabian Schmengler
# 1  You likely have the router plugged in to the m...             John T
# 2  A very partial answer: by the results of Richa...         Igor Rivin
# 3  Isn’t the FAQ label obsolete by now? \n\nI'd s...        Solracnapod
# 4  &lt;!DOCTYPE html&gt;\n&lt;html&gt;\n&lt;head&...           akkimads
#
#                               answer_user_page  \
# 0  https://magento.stackexchange.com/users/243
# 1             https://superuser.com/users/1931
# 2         https://mathoverflow.net/users/11142
# 3     https://ux.stackexchange.com/users/13153
# 4      https://stackoverflow.com/users/2375373
#
#                                                  url       category  ...  \
# 0  http://magento.stackexchange.com/questions/668...     TECHNOLOGY  ...
# 1               http://superuser.com/questions/87212     TECHNOLOGY  ...
# 2           http://mathoverflow.net/questions/203422        SCIENCE  ...
# 3  http://ux.stackexchange.com/questions/18600/is...     TECHNOLOGY  ...
# 4  http://stackoverflow.com/questions/16359492/ch...  STACKOVERFLOW  ...
#
#   answer_helpful  answer_level_of_information  answer_plausible  \
# 0       0.888889                     0.666667               1.0
# 1       1.000000                     0.666667               1.0
# 2       0.888889                     0.333333               1.0
# 3       0.888889                     0.666667               1.0
# 4       0.888889                     0.500000               1.0
#
#    answer_relevance  answer_satisfaction  answer_type_instructions  \
# 0               1.0             0.933333                  1.000000
# 1               1.0             0.866667                  0.666667
# 2               1.0             0.700000                  0.333333
# 3               1.0             0.933333                  0.000000
# 4               1.0             0.800000                  1.000000
#
#    answer_type_procedure  answer_type_reason_explanation  answer_well_written  \
# 0               0.000000                        0.333333             0.888889
# 1               0.000000                        1.000000             1.000000
# 2               0.333333                        1.000000             0.888889
# 3               0.000000                        0.666667             1.000000
# 4               0.000000                        0.000000             0.777778
#
#      set
# 0  train
# 1  train
# 2  train
# 3  train
# 4  train
#
# [5 rows x 42 columns]

# %%
question_target_cols = ['question_asker_intent_understanding','question_body_critical', 'question_conversational', 
                        'question_expect_short_answer', 'question_fact_seeking', 'question_has_commonly_accepted_answer',
                        'question_interestingness_others', 'question_interestingness_self', 'question_multi_intent', 
                        'question_not_really_a_question', 'question_opinion_seeking', 'question_type_choice',
                        'question_type_compare', 'question_type_consequence', 'question_type_definition', 
                        'question_type_entity', 'question_type_instructions', 'question_type_procedure',
                        'question_type_reason_explanation', 'question_type_spelling', 'question_well_written']
answer_target_cols = ['answer_helpful', 'answer_level_of_information', 'answer_plausible', 'answer_relevance',
                      'answer_satisfaction', 'answer_type_instructions', 'answer_type_procedure', 
                      'answer_type_reason_explanation', 'answer_well_written']
target_cols = question_target_cols + answer_target_cols

# %% [markdown]
# ## Pre-process data

# %%
text_features = ['question_title', 'question_body', 'answer']

for feature in text_features:
    # Trim text
    train[feature] = train[feature].apply(lambda x: x.strip())
    validation[feature] = validation[feature].apply(lambda x: x.strip())

# %% [markdown]
# ## Train/validation sets

# %%
# Train features
X_train_title = train['question_title']
X_train_body = train['question_body']
X_train_answer = train['answer']

X_train = [X_train_title, X_train_body, X_train_answer]
Y_train = train[target_cols].values

# Validation features
X_valid_title = validation['question_title']
X_valid_body = validation['question_body']
X_valid_answer = validation['answer']

X_valid = [X_valid_title, X_valid_body, X_valid_answer]
Y_valid = validation[target_cols].values

print('Train samples: %d' % len(Y_train))
print('Validation samples: %d' % len(Y_valid))
# Out:
# Train samples: 4863
# Validation samples: 1216

# %% [markdown]
# # Model parameters

# %%
EPOCHS = 40
BATCH_SIZE = 32
LEARNING_RATE = 3e-4
EMBEDDDING_SIZE = 512
N_CLASS = len(target_cols)
ES_PATIENCE = 3
RLROP_PATIENCE = 2
DECAY_DROP = 0.3
module_url = '/kaggle/input/universalsentenceencodermodels/universal-sentence-encoder-models/use'
model_path = '/kaggle/working/use.h5'

# %% [markdown]
# # Model

# %%
es = EarlyStopping(monitor='val_loss', mode='min', patience=ES_PATIENCE, restore_best_weights=True, verbose=1)
rlrop = ReduceLROnPlateau(monitor='val_loss', mode='min', patience=RLROP_PATIENCE, factor=DECAY_DROP, min_lr=1e-6, verbose=1)
use_embed = hub.load(module_url)

def USEEmbedding(x):
    return use_embed(tf.squeeze(tf.cast(x, tf.string)))

# %%
input_title = Input(shape=(1,), dtype=tf.string, name='input_title')
embedding_title = Lambda(USEEmbedding, output_shape=(EMBEDDDING_SIZE,))(input_title)

input_body = Input(shape=(1,), dtype=tf.string, name='input_body')
embedding_body = Lambda(USEEmbedding, output_shape=(EMBEDDDING_SIZE,))(input_body)

input_answer = Input(shape=(1,), dtype=tf.string, name='input_answer')
embedding_answer = Lambda(USEEmbedding, output_shape=(EMBEDDDING_SIZE,))(input_answer)

x = Concatenate()([embedding_title, embedding_body, embedding_answer])
x = Dropout(0.5)(x)
x = Dense(512, activation='selu')(x)
x = Dropout(0.5)(x)
output = Dense(N_CLASS, activation='sigmoid', name='output')(x)
model = Model(inputs=[input_title, input_body, input_answer], outputs=[output])

model.summary()
# Out:
# Model: "model"
# __________________________________________________________________________________________________
# Layer (type)                    Output Shape         Param #     Connected to
# ==================================================================================================
# input_title (InputLayer)        [(None, 1)]          0
# __________________________________________________________________________________________________
# input_body (InputLayer)         [(None, 1)]          0
# __________________________________________________________________________________________________
# input_answer (InputLayer)       [(None, 1)]          0
# __________________________________________________________________________________________________
# lambda (Lambda)                 (None, 512)          0           input_title[0][0]
# __________________________________________________________________________________________________
# lambda_1 (Lambda)               (None, 512)          0           input_body[0][0]
# __________________________________________________________________________________________________
# lambda_2 (Lambda)               (None, 512)          0           input_answer[0][0]
# __________________________________________________________________________________________________
# concatenate (Concatenate)       (None, 1536)         0           lambda[0][0]
#                                                                  lambda_1[0][0]
#                                                                  lambda_2[0][0]
# __________________________________________________________________________________________________
# dropout (Dropout)               (None, 1536)         0           concatenate[0][0]
# __________________________________________________________________________________________________
# dense (Dense)                   (None, 512)          786944      dropout[0][0]
# __________________________________________________________________________________________________
# dropout_1 (Dropout)             (None, 512)          0           dense[0][0]
# __________________________________________________________________________________________________
# output (Dense)                  (None, 30)           15390       dropout_1[0][0]
# ==================================================================================================
# Total params: 802,334
# Trainable params: 802,334
# Non-trainable params: 0
# __________________________________________________________________________________________________

# %% [markdown]
# # Train model

# %%
optimizer = optimizers.Adam(LEARNING_RATE)
spearmanCallback = SpearmanRhoCallback(training_data=(X_train, Y_train), validation_data=(X_valid, Y_valid))
callback_list = [es, rlrop, spearmanCallback]
model.compile(optimizer=optimizer, loss='binary_crossentropy')

history = model.fit(X_train, Y_train, 
                    validation_data=(X_valid, Y_valid), 
                    callbacks=callback_list, 
                    batch_size=BATCH_SIZE,
                    epochs=EPOCHS, 
                    verbose=2).history
# Out:
# Train on 4863 samples, validate on 1216 samples
# Epoch 1/40
# Train spearman-rho: 0.2579 Validation spearman-rho: 0.2420
# 4863/4863 - 33s - loss: 0.4633 - val_loss: 0.4053
# Epoch 2/40
# Train spearman-rho: 0.3215 Validation spearman-rho: 0.3003
# 4863/4863 - 24s - loss: 0.4011 - val_loss: 0.3935
# Epoch 3/40
# Train spearman-rho: 0.3553 Validation spearman-rho: 0.3251
# 4863/4863 - 24s - loss: 0.3918 - val_loss: 0.3877
# Epoch 4/40
# Train spearman-rho: 0.3745 Validation spearman-rho: 0.3356
# 4863/4863 - 24s - loss: 0.3863 - val_loss: 0.3848
# Epoch 5/40
# Train spearman-rho: 0.3895 Validation spearman-rho: 0.3424
# 4863/4863 - 24s - loss: 0.3834 - val_loss: 0.3831
# Epoch 6/40
# Train spearman-rho: 0.4005 Validation spearman-rho: 0.3469
# 4863/4863 - 24s - loss: 0.3804 - val_loss: 0.3815
# Epoch 7/40
# Train spearman-rho: 0.4094 Validation spearman-rho: 0.3502
# 4863/4863 - 23s - loss: 0.3787 - val_loss: 0.3806
# Epoch 8/40
# Train spearman-rho: 0.4169 Validation spearman-rho: 0.3515
# 4863/4863 - 23s - loss: 0.3767 - val_loss: 0.3802
# Epoch 9/40
# Train spearman-rho: 0.4244 Validation spearman-rho: 0.3548
# 4863/4863 - 23s - loss: 0.3753 - val_loss: 0.3796
# Epoch 10/40
# Train spearman-rho: 0.4286 Validation spearman-rho: 0.3547
# 4863/4863 - 24s - loss: 0.3746 - val_loss: 0.3794
# Epoch 11/40
# Train spearman-rho: 0.4348 Validation spearman-rho: 0.3556
# 4863/4863 - 23s - loss: 0.3736 - val_loss: 0.3792
# Epoch 12/40
# Train spearman-rho: 0.4379 Validation spearman-rho: 0.3563
# 4863/4863 - 23s - loss: 0.3728 - val_loss: 0.3791
# Epoch 13/40
# Train spearman-rho: 0.4415 Validation spearman-rho: 0.3570
# 4863/4863 - 23s - loss: 0.3721 - val_loss: 0.3788
# Epoch 14/40
# Train spearman-rho: 0.4442 Validation spearman-rho: 0.3578
# 4863/4863 - 23s - loss: 0.3712 - val_loss: 0.3786
# Epoch 15/40
# Train spearman-rho: 0.4474 Validation spearman-rho: 0.3586
# 4863/4863 - 23s - loss: 0.3714 - val_loss: 0.3787
# Epoch 16/40
#
# Epoch 00016: ReduceLROnPlateau reducing learning rate to 9.000000427477062e-05.
# Train spearman-rho: 0.4496 Validation spearman-rho: 0.3598
# 4863/4863 - 23s - loss: 0.3705 - val_loss: 0.3786
# Epoch 17/40
# Train spearman-rho: 0.4511 Validation spearman-rho: 0.3606
# 4863/4863 - 23s - loss: 0.3696 - val_loss: 0.3781
# Epoch 18/40
# Train spearman-rho: 0.4517 Validation spearman-rho: 0.3610
# 4863/4863 - 24s - loss: 0.3693 - val_loss: 0.3781
# Epoch 19/40
#
# Epoch 00019: ReduceLROnPlateau reducing learning rate to 2.700000040931627e-05.
# Train spearman-rho: 0.4525 Validation spearman-rho: 0.3612
# 4863/4863 - 24s - loss: 0.3690 - val_loss: 0.3782
# Epoch 20/40
# Restoring model weights from the end of the best epoch.
# Train spearman-rho: 0.4511 Validation spearman-rho: 0.3606
# 4863/4863 - 24s - loss: 0.3686 - val_loss: 0.3781
# Epoch 21/40
#
# Epoch 00021: ReduceLROnPlateau reducing learning rate to 8.100000013655517e-06.
# Train spearman-rho: 0.4514 Validation spearman-rho: 0.3607
# 4863/4863 - 24s - loss: 0.3690 - val_loss: 0.3781
# Epoch 22/40
# Train spearman-rho: 0.4515 Validation spearman-rho: 0.3607
# 4863/4863 - 24s - loss: 0.3690 - val_loss: 0.3781
# Epoch 23/40
#
# Epoch 00023: ReduceLROnPlateau reducing learning rate to 2.429999949526973e-06.
# Train spearman-rho: 0.4516 Validation spearman-rho: 0.3608
# 4863/4863 - 24s - loss: 0.3686 - val_loss: 0.3781
# Epoch 24/40
# Train spearman-rho: 0.4517 Validation spearman-rho: 0.3608
# 4863/4863 - 24s - loss: 0.3690 - val_loss: 0.3781
# Epoch 25/40
#
# Epoch 00025: ReduceLROnPlateau reducing learning rate to 1e-06.
# Train spearman-rho: 0.4517 Validation spearman-rho: 0.3608
# 4863/4863 - 24s - loss: 0.3691 - val_loss: 0.3781
# Epoch 26/40
# Train spearman-rho: 0.4517 Validation spearman-rho: 0.3608
# 4863/4863 - 23s - loss: 0.3689 - val_loss: 0.3781
# Epoch 27/40
# Train spearman-rho: 0.4517 Validation spearman-rho: 0.3608
# 4863/4863 - 23s - loss: 0.3690 - val_loss: 0.3781
# Epoch 28/40
# Train spearman-rho: 0.4517 Validation spearman-rho: 0.3608
# 4863/4863 - 23s - loss: 0.3688 - val_loss: 0.3781
# Epoch 29/40
# Train spearman-rho: 0.4517 Validation spearman-rho: 0.3608
# 4863/4863 - 23s - loss: 0.3691 - val_loss: 0.3781
# Epoch 30/40
# Train spearman-rho: 0.4517 Validation spearman-rho: 0.3609
# 4863/4863 - 23s - loss: 0.3691 - val_loss: 0.3781
# Epoch 31/40
# Train spearman-rho: 0.4518 Validation spearman-rho: 0.3608
# 4863/4863 - 23s - loss: 0.3689 - val_loss: 0.3781
# Epoch 32/40
# Train spearman-rho: 0.4518 Validation spearman-rho: 0.3609
# 4863/4863 - 22s - loss: 0.3685 - val_loss: 0.3781
# Epoch 33/40
# Train spearman-rho: 0.4518 Validation spearman-rho: 0.3609
# 4863/4863 - 23s - loss: 0.3689 - val_loss: 0.3781
# Epoch 34/40
# Train spearman-rho: 0.4518 Validation spearman-rho: 0.3609
# 4863/4863 - 23s - loss: 0.3692 - val_loss: 0.3781
# Epoch 35/40
# Train spearman-rho: 0.4518 Validation spearman-rho: 0.3609
# 4863/4863 - 23s - loss: 0.3694 - val_loss: 0.3781
# Epoch 36/40
# Train spearman-rho: 0.4518 Validation spearman-rho: 0.3609
# 4863/4863 - 23s - loss: 0.3675 - val_loss: 0.3781
# Epoch 37/40
# Train spearman-rho: 0.4518 Validation spearman-rho: 0.3609
# 4863/4863 - 23s - loss: 0.3693 - val_loss: 0.3781
# Epoch 38/40
# Train spearman-rho: 0.4518 Validation spearman-rho: 0.3609
# 4863/4863 - 22s - loss: 0.3682 - val_loss: 0.3780
# Epoch 39/40
# Train spearman-rho: 0.4518 Validation spearman-rho: 0.3609
# 4863/4863 - 22s - loss: 0.3687 - val_loss: 0.3780
# Epoch 40/40
# Train spearman-rho: 0.4518 Validation spearman-rho: 0.3609
# 4863/4863 - 22s - loss: 0.3687 - val_loss: 0.3781
# Epoch 00020: early stopping

# %% [markdown]
# ## Model loss graph

# %%
sns.set(style="whitegrid")
for key in spearmanCallback.history.keys():
    history[key] = spearmanCallback.history[key]

plot_metrics(history, metric_list=['loss', 'spearman'])

# %% [markdown]
# # Evaluation

# %%
preds_train = model.predict(X_train)
preds_val = model.predict(X_valid)

metrics_df = get_metrics(Y_train, preds_train, Y_valid, preds_val, target_cols)
display(metrics_df)
# Out:
#                                     Label     Train  Validation
# 0                                Averaged  0.451843    0.360901
# 1     question_asker_intent_understanding  0.443504    0.400664
# 2                  question_body_critical  0.686870    0.612204
# 3                 question_conversational  0.441097    0.397943
# 4            question_expect_short_answer  0.408637    0.239428
# 5                   question_fact_seeking  0.433932    0.296373
# 6   question_has_commonly_accepted_answer  0.507133    0.412574
# 7         question_interestingness_others  0.440052    0.396954
# 8           question_interestingness_self  0.565799    0.530412
# 9                   question_multi_intent  0.510737    0.412468
# 10         question_not_really_a_question  0.125695    0.045614
# 11               question_opinion_seeking  0.539186    0.408941
# 12                   question_type_choice  0.661960    0.559945
# 13                  question_type_compare  0.377609    0.301321
# 14              question_type_consequence  0.205162    0.152119
# 15               question_type_definition  0.377009    0.305832
# 16                   question_type_entity  0.451178    0.423907
# 17             question_type_instructions  0.788206    0.728245
# 18                question_type_procedure  0.440646    0.266877
# 19       question_type_reason_explanation  0.665552    0.627654
# 20                 question_type_spelling  0.071143    0.068742
# 21                  question_well_written  0.565360    0.481022
# 22                         answer_helpful  0.326480    0.187056
# 23            answer_level_of_information  0.459509    0.358067
# 24                       answer_plausible  0.261228    0.130676
# 25                       answer_relevance  0.233670    0.149492
# 26                    answer_satisfaction  0.388022    0.238084
# 27               answer_type_instructions  0.788124    0.692752
# 28                  answer_type_procedure  0.404429    0.239424
# 29         answer_type_reason_explanation  0.698144    0.623198
# 30                    answer_well_written  0.289223    0.139038

# %% [markdown]
# #### Save model weights

# %%
model.save_weights(model_path)
