# %%
import sys
if 'google.colab' in sys.modules: # Colab-only Tensorflow version selector
  # %tensorflow_version 2.x

import tensorflow as tf
print("Tensorflow version " + tf.__version__)
# Out:
# TensorFlow 2.x selected.
# Tensorflow version 2.1.0-rc1

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Go to this URL in a browser: https://accounts.google.com/o/oauth2/auth?client_id=947318989803-6bn6qk8qdgf4n4g3pfee6491hc0brc4i.apps.googleusercontent.com&redirect_uri=urn%3aietf%3awg%3aoauth%3a2.0%3aoob&response_type=code&scope=email%20https%3a%2f%2fwww.googleapis.com%2fauth%2fdocs.test%20https%3a%2f%2fwww.googleapis.com%2fauth%2fdrive%20https%3a%2f%2fwww.googleapis.com%2fauth%2fdrive.photos.readonly%20https%3a%2f%2fwww.googleapis.com%2fauth%2fpeopleapi.readonly
#
# Enter your authorization code:
# ··········
# Mounted at /content/drive

# %%
# !cp -r '/content/drive/My Drive/Colab Notebooks/Google QUEST Q&A Labeling/Scripts/.' .

# %%
MODEL_BASE_PATH = '/content/drive/My Drive/Colab Notebooks/Google QUEST Q&A Labeling/Model backlog/Files/'
MODEL_NAME = '135-BERT_base_uncased'

# %% [markdown]
# ## Dependencies

# %%
import glob
import warnings
from tensorflow_hub import KerasLayer
from tensorflow.keras import Model, optimizers
from tensorflow.keras.callbacks import ReduceLROnPlateau
from tensorflow.keras.layers import Input, Dense, Dropout, GlobalAveragePooling1D, SpatialDropout1D, Concatenate
from googleqa_utilityscript import *
from googleqa_map_utilityscript import *
from script_lr_schedulers import WarmUpLearningRateScheduler
import bert_tokenization as tokenization


SEED = 0
seed_everything(SEED)
warnings.filterwarnings("ignore")
# Out:
# Using TensorFlow backend.

# %% [markdown]
# ## Load data

# %%
BERT_PATH = '/content/drive/My Drive/Colab Notebooks/Google QUEST Q&A Labeling/Modules/bert_base_uncased'
VOCAB_PATH = BERT_PATH + '/assets/vocab.txt'

k_fold = pd.read_csv('/content/drive/My Drive/Colab Notebooks/Google QUEST Q&A Labeling/Data/5-fold.csv')
N_FOLDS = 5

print('Samples: %s' % len(k_fold))
display(k_fold.head())
# Out:
# Samples: 6079
#    qa_id  ...      fold_5
# 0      0  ...       train
# 1      1  ...       train
# 2      2  ...       train
# 3      3  ...  validation
# 4      5  ...       train
#
# [5 rows x 46 columns]

# %%
question_target_cols = ['question_asker_intent_understanding','question_body_critical', 'question_conversational', 
                        'question_expect_short_answer', 'question_fact_seeking', 'question_has_commonly_accepted_answer',
                        'question_interestingness_others', 'question_interestingness_self', 'question_multi_intent', 
                        'question_not_really_a_question', 'question_opinion_seeking', 'question_type_choice',
                        'question_type_compare', 'question_type_consequence', 'question_type_definition', 
                        'question_type_entity', 'question_type_instructions', 'question_type_procedure',
                        'question_type_reason_explanation', 'question_type_spelling', 'question_well_written']
answer_target_cols = ['answer_helpful', 'answer_level_of_information', 'answer_plausible', 'answer_relevance',
                      'answer_satisfaction', 'answer_type_instructions', 'answer_type_procedure', 
                      'answer_type_reason_explanation', 'answer_well_written']
target_cols = question_target_cols + answer_target_cols

# %% [markdown]
# # Pre-process data

# %%
text_features = ['question_title', 'question_body', 'answer']

# for feature in text_features:
#     # Lower
#     k_fold[feature] = k_fold[feature].apply(lambda x: x.lower())
#     # Map misspellings
#     k_fold[feature] = k_fold[feature].apply(lambda x: map_misspellings(x))
#     # Map contractions
#     k_fold[feature] = k_fold[feature].apply(lambda x: map_contraction(x))
#     # Trim text
#     k_fold[feature] = k_fold[feature].apply(lambda x: x.strip())

# %% [markdown]
# # Model parameters

# %%
EPOCHS = 8
BATCH_SIZE = 8
LEARNING_RATE = 3e-5
N_CLASS = len(target_cols)
ES_PATIENCE = 1
MAX_SEQUENCE_LENGTH = 512
LR_WARMUP_EPOCHS = 2
WARMUP_EPOCHS = 1
WARMUP_LEARNING_RATE = 3e-4

# %% [markdown]
# # Model

# %%
def model_fn():
    input_word_ids = Input((MAX_SEQUENCE_LENGTH,), dtype=tf.int32, name='input_word_ids')
    input_masks = Input((MAX_SEQUENCE_LENGTH,), dtype=tf.int32, name='input_masks')
    segment_ids = Input((MAX_SEQUENCE_LENGTH,), dtype=tf.int32, name='segment_ids')

    bert_layer = KerasLayer(BERT_PATH, trainable=False)
    pooled_output, sequence_output = bert_layer([input_word_ids, input_masks, segment_ids])

    x = GlobalAveragePooling1D()(sequence_output)
    x = Dropout(0.2)(x)
    output = Dense(N_CLASS, activation="sigmoid", name="output")(x)

    model = Model(inputs=[input_word_ids, input_masks, segment_ids], outputs=output)
    
    return model

# %% [markdown]
# # Train model

# %%
tokenizer = tokenization.FullTokenizer(VOCAB_PATH, do_lower_case=True)

history_list = []
metric_list = []
category_metric_list = []
target_cols_preds = [col+'_pred' for col in target_cols]

for n_fold in range(N_FOLDS):
    ### Data
    train = k_fold[k_fold['fold_%d' % (n_fold+1)] == 'train']
    validation = k_fold[k_fold['fold_%d' % (n_fold+1)] == 'validation']
    
    ### Create features
    # Train features
    X_train = compute_input_arays(train, text_features, tokenizer, MAX_SEQUENCE_LENGTH)
    Y_train = train[target_cols].values

    # Validation features
    X_valid = compute_input_arays(validation, text_features, tokenizer, MAX_SEQUENCE_LENGTH)
    Y_valid = validation[target_cols].values

    ## Train model
    # Warmup
    model = model_fn()
    optimizer = optimizers.Adam(lr=WARMUP_LEARNING_RATE)
    model.compile(optimizer=optimizer, loss='binary_crossentropy')

    model.fit(X_train, Y_train, 
              validation_data=(X_valid, Y_valid), 
              batch_size=BATCH_SIZE, 
              epochs=WARMUP_EPOCHS, 
              verbose=2)

    # Fine-tune
    for layer in model.layers:
        layer.trainable = True

    model_path = MODEL_BASE_PATH + MODEL_NAME + '_model_fold_%d' % (n_fold+1)
    spearmanCallback = SpearmanRhoCallback(training_data=(X_train, Y_train), 
                                           validation_data=(X_valid, Y_valid), 
                                           model_path=model_path, 
                                           monitor='val_loss', mode='min', 
                                           patience=ES_PATIENCE, checkpoint=True)
    WARMUP_BATCHES = LR_WARMUP_EPOCHS * len(train) // BATCH_SIZE
    warmup_lr = WarmUpLearningRateScheduler(WARMUP_BATCHES, LEARNING_RATE)

    callback_list = [spearmanCallback, warmup_lr]
    
    optimizer = optimizers.Adam(lr=LEARNING_RATE)
    model.compile(optimizer=optimizer, loss='binary_crossentropy')

    history = model.fit(X_train, Y_train, 
                        validation_data=(X_valid, Y_valid), 
                        callbacks=callback_list, 
                        batch_size=BATCH_SIZE, 
                        epochs=EPOCHS, 
                        verbose=2).history
    
    history_list.append(history)

    # Save last epoch weights
    model.save_weights(MODEL_BASE_PATH + MODEL_NAME + '_model_fold_%d_last_epoch.h5' % (n_fold+1))
    
    ### Evaluation - Label metrics
    model.load_weights(model_path+'.h5')
    preds_train = model.predict(X_train)
    preds_val = model.predict(X_valid)
    metric_list.append(get_metrics(Y_train, preds_train, Y_valid, preds_val, target_cols))
    
    ### Evaluation - Category metrics
    for col in target_cols_preds:
        train[col] = 0
        validation[col] = 0

    train[target_cols_preds] = preds_train
    validation[target_cols_preds] = preds_val
    category_metric_list.append(get_metrics_category(train, validation, target_cols, target_cols_preds, 'category'))
# Out:
# Train on 4864 samples, validate on 1215 samples
# 4864/4864 - 291s - loss: 0.4305 - val_loss: 0.4029
# Train on 4864 samples, validate on 1215 samples
# Epoch 1/8
# spearman-rho: 0.3748 val_spearman-rho: 0.3532
# Saved model weights at "/content/drive/My Drive/Colab Notebooks/Google QUEST Q&A Labeling/Model backlog/Files/135-BERT_base_uncased_model_fold_1.h5"
# 4864/4864 - 973s - loss: 0.3947 - val_loss: 0.3772
# Epoch 2/8
# spearman-rho: 0.4507 val_spearman-rho: 0.3861
# Saved model weights at "/content/drive/My Drive/Colab Notebooks/Google QUEST Q&A Labeling/Model backlog/Files/135-BERT_base_uncased_model_fold_1.h5"
# 4864/4864 - 954s - loss: 0.3720 - val_loss: 0.3690
# Epoch 3/8
# spearman-rho: 0.5122 val_spearman-rho: 0.3949
# Saved model weights at "/content/drive/My Drive/Colab Notebooks/Google QUEST Q&A Labeling/Model backlog/Files/135-BERT_base_uncased_model_fold_1.h5"
# 4864/4864 - 954s - loss: 0.3556 - val_loss: 0.3674
# Epoch 4/8
# spearman-rho: 0.5758 val_spearman-rho: 0.3888
# Epoch 00003: early stopping
# 4864/4864 - 952s - loss: 0.3371 - val_loss: 0.3750
# Train on 4864 samples, validate on 1215 samples
# 4864/4864 - 290s - loss: 0.4287 - val_loss: 0.4044
# Train on 4864 samples, validate on 1215 samples
# Epoch 1/8
# spearman-rho: 0.3771 val_spearman-rho: 0.3455
# Saved model weights at "/content/drive/My Drive/Colab Notebooks/Google QUEST Q&A Labeling/Model backlog/Files/135-BERT_base_uncased_model_fold_2.h5"
# 4864/4864 - 971s - loss: 0.3945 - val_loss: 0.3800
# Epoch 2/8
# spearman-rho: 0.4441 val_spearman-rho: 0.3820
# Saved model weights at "/content/drive/My Drive/Colab Notebooks/Google QUEST Q&A Labeling/Model backlog/Files/135-BERT_base_uncased_model_fold_2.h5"
# 4864/4864 - 962s - loss: 0.3723 - val_loss: 0.3744
# Epoch 3/8
# spearman-rho: 0.5103 val_spearman-rho: 0.3881
# Saved model weights at "/content/drive/My Drive/Colab Notebooks/Google QUEST Q&A Labeling/Model backlog/Files/135-BERT_base_uncased_model_fold_2.h5"
# 4864/4864 - 952s - loss: 0.3561 - val_loss: 0.3734
# Epoch 4/8
# spearman-rho: 0.5749 val_spearman-rho: 0.3956
# Saved model weights at "/content/drive/My Drive/Colab Notebooks/Google QUEST Q&A Labeling/Model backlog/Files/135-BERT_base_uncased_model_fold_2.h5"
# 4864/4864 - 950s - loss: 0.3368 - val_loss: 0.3713
# Epoch 5/8
# spearman-rho: 0.6264 val_spearman-rho: 0.3747
# Epoch 00004: early stopping
# 4864/4864 - 945s - loss: 0.3166 - val_loss: 0.3856
# Train on 4859 samples, validate on 1220 samples
# 4859/4859 - 283s - loss: 0.4296 - val_loss: 0.4045
# Train on 4859 samples, validate on 1220 samples
# Epoch 1/8
# spearman-rho: 0.3724 val_spearman-rho: 0.3398
# Saved model weights at "/content/drive/My Drive/Colab Notebooks/Google QUEST Q&A Labeling/Model backlog/Files/135-BERT_base_uncased_model_fold_3.h5"
# 4859/4859 - 964s - loss: 0.3941 - val_loss: 0.3796
# Epoch 2/8
# spearman-rho: 0.4466 val_spearman-rho: 0.3723
# Saved model weights at "/content/drive/My Drive/Colab Notebooks/Google QUEST Q&A Labeling/Model backlog/Files/135-BERT_base_uncased_model_fold_3.h5"
# 4859/4859 - 954s - loss: 0.3726 - val_loss: 0.3754
# Epoch 3/8
# spearman-rho: 0.5104 val_spearman-rho: 0.3823
# Saved model weights at "/content/drive/My Drive/Colab Notebooks/Google QUEST Q&A Labeling/Model backlog/Files/135-BERT_base_uncased_model_fold_3.h5"
# 4859/4859 - 955s - loss: 0.3559 - val_loss: 0.3702
# Epoch 4/8
# spearman-rho: 0.5733 val_spearman-rho: 0.3858
# Epoch 00003: early stopping
# 4859/4859 - 953s - loss: 0.3374 - val_loss: 0.3707
# Train on 4865 samples, validate on 1214 samples
# 4865/4865 - 284s - loss: 0.4282 - val_loss: 0.4027
# Train on 4865 samples, validate on 1214 samples
# Epoch 1/8
# spearman-rho: 0.3746 val_spearman-rho: 0.3505
# Saved model weights at "/content/drive/My Drive/Colab Notebooks/Google QUEST Q&A Labeling/Model backlog/Files/135-BERT_base_uncased_model_fold_4.h5"
# 4865/4865 - 964s - loss: 0.3954 - val_loss: 0.3779
# Epoch 2/8
# spearman-rho: 0.4478 val_spearman-rho: 0.3870
# Saved model weights at "/content/drive/My Drive/Colab Notebooks/Google QUEST Q&A Labeling/Model backlog/Files/135-BERT_base_uncased_model_fold_4.h5"
# 4865/4865 - 954s - loss: 0.3726 - val_loss: 0.3686
# Epoch 3/8
# spearman-rho: 0.5123 val_spearman-rho: 0.3992
# Epoch 00002: early stopping
# 4865/4865 - 953s - loss: 0.3568 - val_loss: 0.3702
# Train on 4864 samples, validate on 1215 samples
# 4864/4864 - 284s - loss: 0.4299 - val_loss: 0.4035
# Train on 4864 samples, validate on 1215 samples
# Epoch 1/8
# spearman-rho: 0.3771 val_spearman-rho: 0.3489
# Saved model weights at "/content/drive/My Drive/Colab Notebooks/Google QUEST Q&A Labeling/Model backlog/Files/135-BERT_base_uncased_model_fold_5.h5"
# 4864/4864 - 958s - loss: 0.3941 - val_loss: 0.3785
# Epoch 2/8
# spearman-rho: 0.4463 val_spearman-rho: 0.3764
# Saved model weights at "/content/drive/My Drive/Colab Notebooks/Google QUEST Q&A Labeling/Model backlog/Files/135-BERT_base_uncased_model_fold_5.h5"
# 4864/4864 - 948s - loss: 0.3716 - val_loss: 0.3751
# Epoch 3/8
# spearman-rho: 0.5105 val_spearman-rho: 0.3922
# Saved model weights at "/content/drive/My Drive/Colab Notebooks/Google QUEST Q&A Labeling/Model backlog/Files/135-BERT_base_uncased_model_fold_5.h5"
# 4864/4864 - 947s - loss: 0.3560 - val_loss: 0.3693
# Epoch 4/8
# spearman-rho: 0.5733 val_spearman-rho: 0.3902
# Epoch 00003: early stopping
# 4864/4864 - 945s - loss: 0.3368 - val_loss: 0.3732

# %% [markdown]
# ## Model loss graph

# %%
for n_fold in range(N_FOLDS):
    print('Fold: %d' % n_fold)
    sns.set(style="whitegrid")
    plot_metrics(history_list[n_fold], metric_list=['loss', 'spearman'])
# Out:
# Fold: 0
# Fold: 1
# Fold: 2
# Fold: 3
# Fold: 4

# %% [markdown]
# # Evaluation

# %%
metrics_df = metric_list[0][['Label', 'Train', 'Validation']].copy()
metrics_df.columns = ['Label', 'Train_fold_0', 'Valid_fold_0']

for n_fold in range(1, N_FOLDS):
    metrics_df_idx = metric_list[n_fold][['Train', 'Validation']].copy()
    metrics_df_idx.columns = ['Train_fold_%d' % n_fold, 'Valid_fold_%d' % n_fold]
    metrics_df = pd.concat([metrics_df, metrics_df_idx], axis=1)

metrics_df['Train'] = 0
metrics_df['Validation'] = 0
for n_fold in range(N_FOLDS):
    metrics_df['Train'] += metrics_df['Train_fold_%d' % n_fold] / N_FOLDS
    metrics_df['Validation'] += metrics_df['Valid_fold_%d' % n_fold] / N_FOLDS

metrics_df['Var'] = metrics_df['Train'] - metrics_df['Validation']
display(metrics_df.style.applymap(color_map))
# Out:
# <style  type="text/css" >
#     #T_4dade91c_414f_11ea_8699_0242ac1c0002row0_col0 {
#             color:  black;
#         }    #T_4dade91c_414f_11ea_8699_0242ac1c0002row0_col1 {
#             color:  black;
#         }    #T_4dade91c_414f_11ea_8699_0242ac1c0002row0_col2 {
#             color:  black;
#         }    #T_4dade91c_414f_11ea_8699_0242ac1c0002row0_col3 {
#             color:  black;
#         }    #T_4dade91c_414f_11ea_8699_0242ac1c0002row0_col4 {
#             color:  black;
#         }    #T_4dade91c_414f_11ea_8699_0242ac1c0002row0_col5 {
#             color:  black;
#         }    #T_4dade91c_414f_11ea_8699_0242ac1c0002row0_col6 {
#             color:  black;
#         }    #T_4dade91c_414f_11ea_8699_0242ac1c0002row0_col7 {
#             color:  black;
#         }    #T_4dade91c_414f_11ea_8699_0242ac1c0002row0_col8 {
#             color:  black;
#         }    #T_4dade91c_414f_11ea_8699_0242ac1c0002row0_col9 {
#             color:  black;
#         }    #T_4dade91c_414f_11ea_8699_0242ac1c0002row0_col10 {
#             color:  black;
#         }    #T_4dade91c_414f_11ea_8699_0242ac1c0002row0_col11 {
#             color:  black;
#         }    #T_4dade91c_414f_11ea_8699_0242ac1c0002row0_col12 {
#             color:  black;
#         }    #T_4dade91c_414f_11ea_8699_0242ac1c0002row0_col13 {
#             color:  orange;
#         }    #T_4dade91c_414f_11ea_8699_0242ac1c0002row1_col0 {
#             color:  black;
#         }    #T_4dade91c_414f_11ea_8699_0242ac1c0002row1_col1 {
#             color:  black;
#         }    #T_4dade91c_414f_11ea_8699_0242ac1c0002row1_col2 {
#             color:  black;
#         }    #T_4dade91c_414f_11ea_8699_0242ac1c0002row1_col3 {
#             color:  black;
#         }    #T_4dade91c_414f_11ea_8699_0242ac1c0002row1_col4 {
#             color:  black;
#         }    #T_4dade91c_414f_11ea_8699_0242ac1c0002row1_col5 {
#             color:  black;
#         }    #T_4dade91c_414f_11ea_8699_0242ac1c0002row1_col6 {
#             color:  black;
#         }    #T_4dade91c_414f_11ea_8699_0242ac1c0002row1_col7 {
#             color:  black;
#         }    #T_4dade91c_414f_11ea_8699_0242ac1c0002row1_col8 {
#             color:  black;
#         }    #T_4dade91c_414f_11ea_8699_0242ac1c0002row1_col9 {
#             color:  black;
#         }    #T_4dade91c_414f_11ea_8699_0242ac1c0002row1_col10 {
#             color:  black;
#         }    #T_4dade91c_414f_11ea_8699_0242ac1c0002row1_col11 {
#             color:  black;
#         }    #T_4dade91c_414f_11ea_8699_0242ac1c0002row1_col12 {
#             color:  black;
#         }    #T_4dade91c_414f_11ea_8699_0242ac1c0002row1_col13 {
#             color:  orange;
#         }    #T_4dade91c_414f_11ea_8699_0242ac1c0002row2_col0 {
#             color:  black;
#         }    #T_4dade91c_414f_11ea_8699_0242ac1c0002row2_col1 {
#             color:  black;
#         }    #T_4dade91c_414f_11ea_8699_0242ac1c0002row2_col2 {
#             color:  black;
#         }    #T_4dade91c_414f_11ea_8699_0242ac1c0002row2_col3 {
#             color:  black;
#         }    #T_4dade91c_414f_11ea_8699_0242ac1c0002row2_col4 {
#             color:  black;
#         }    #T_4dade91c_414f_11ea_8699_0242ac1c0002row2_col5 {
#             color:  black;
#         }    #T_4dade91c_414f_11ea_8699_0242ac1c0002row2_col6 {
#             color:  black;
#         }    #T_4dade91c_414f_11ea_8699_0242ac1c0002row2_col7 {
#             color:  black;
#         }    #T_4dade91c_414f_11ea_8699_0242ac1c0002row2_col8 {
#             color:  black;
#         }    #T_4dade91c_414f_11ea_8699_0242ac1c0002row2_col9 {
#             color:  black;
#         }    #T_4dade91c_414f_11ea_8699_0242ac1c0002row2_col10 {
#             color:  black;
#         }    #T_4dade91c_414f_11ea_8699_0242ac1c0002row2_col11 {
#             color:  black;
#         }    #T_4dade91c_414f_11ea_8699_0242ac1c0002row2_col12 {
#             color:  black;
#         }    #T_4dade91c_414f_11ea_8699_0242ac1c0002row2_col13 {
#             color:  orange;
#         }    #T_4dade91c_414f_11ea_8699_0242ac1c0002row3_col0 {
#             color:  black;
#         }    #T_4dade91c_414f_11ea_8699_0242ac1c0002row3_col1 {
#             color:  black;
#         }    #T_4dade91c_414f_11ea_8699_0242ac1c0002row3_col2 {
#             color:  black;
#         }    #T_4dade91c_414f_11ea_8699_0242ac1c0002row3_col3 {
#             color:  black;
#         }    #T_4dade91c_414f_11ea_8699_0242ac1c0002row3_col4 {
#             color:  black;
#         }    #T_4dade91c_414f_11ea_8699_0242ac1c0002row3_col5 {
#             color:  black;
#         }    #T_4dade91c_414f_11ea_8699_0242ac1c0002row3_col6 {
#             color:  orange;
#         }    #T_4dade91c_414f_11ea_8699_0242ac1c0002row3_col7 {
#             color:  black;
#         }    #T_4dade91c_414f_11ea_8699_0242ac1c0002row3_col8 {
#             color:  black;
#         }    #T_4dade91c_414f_11ea_8699_0242ac1c0002row3_col9 {
#             color:  black;
#         }    #T_4dade91c_414f_11ea_8699_0242ac1c0002row3_col10 {
#             color:  black;
#         }    #T_4dade91c_414f_11ea_8699_0242ac1c0002row3_col11 {
#             color:  black;
#         }    #T_4dade91c_414f_11ea_8699_0242ac1c0002row3_col12 {
#             color:  black;
#         }    #T_4dade91c_414f_11ea_8699_0242ac1c0002row3_col13 {
#             color:  orange;
#         }    #T_4dade91c_414f_11ea_8699_0242ac1c0002row4_col0 {
#             color:  black;
#         }    #T_4dade91c_414f_11ea_8699_0242ac1c0002row4_col1 {
#             color:  black;
#         }    #T_4dade91c_414f_11ea_8699_0242ac1c0002row4_col2 {
#             color:  black;
#         }    #T_4dade91c_414f_11ea_8699_0242ac1c0002row4_col3 {
#             color:  black;
#         }    #T_4dade91c_414f_11ea_8699_0242ac1c0002row4_col4 {
#             color:  black;
#         }    #T_4dade91c_414f_11ea_8699_0242ac1c0002row4_col5 {
#             color:  black;
#         }    #T_4dade91c_414f_11ea_8699_0242ac1c0002row4_col6 {
#             color:  black;
#         }    #T_4dade91c_414f_11ea_8699_0242ac1c0002row4_col7 {
#             color:  black;
#         }    #T_4dade91c_414f_11ea_8699_0242ac1c0002row4_col8 {
#             color:  black;
#         }    #T_4dade91c_414f_11ea_8699_0242ac1c0002row4_col9 {
#             color:  black;
#         }    #T_4dade91c_414f_11ea_8699_0242ac1c0002row4_col10 {
#             color:  black;
#         }    #T_4dade91c_414f_11ea_8699_0242ac1c0002row4_col11 {
#             color:  black;
#         }    #T_4dade91c_414f_11ea_8699_0242ac1c0002row4_col12 {
#             color:  black;
#         }    #T_4dade91c_414f_11ea_8699_0242ac1c0002row4_col13 {
#             color:  orange;
#         }    #T_4dade91c_414f_11ea_8699_0242ac1c0002row5_col0 {
#             color:  black;
#         }    #T_4dade91c_414f_11ea_8699_0242ac1c0002row5_col1 {
#             color:  black;
#         }    #T_4dade91c_414f_11ea_8699_0242ac1c0002row5_col2 {
#             color:  black;
#         }    #T_4dade91c_414f_11ea_8699_0242ac1c0002row5_col3 {
#             color:  black;
#         }    #T_4dade91c_414f_11ea_8699_0242ac1c0002row5_col4 {
#             color:  black;
#         }    #T_4dade91c_414f_11ea_8699_0242ac1c0002row5_col5 {
#             color:  black;
#         }    #T_4dade91c_414f_11ea_8699_0242ac1c0002row5_col6 {
#             color:  black;
#         }    #T_4dade91c_414f_11ea_8699_0242ac1c0002row5_col7 {
#             color:  black;
#         }    #T_4dade91c_414f_11ea_8699_0242ac1c0002row5_col8 {
#             color:  black;
#         }    #T_4dade91c_414f_11ea_8699_0242ac1c0002row5_col9 {
#             color:  black;
#         }    #T_4dade91c_414f_11ea_8699_0242ac1c0002row5_col10 {
#             color:  black;
#         }    #T_4dade91c_414f_11ea_8699_0242ac1c0002row5_col11 {
#             color:  black;
#         }    #T_4dade91c_414f_11ea_8699_0242ac1c0002row5_col12 {
#             color:  black;
#         }    #T_4dade91c_414f_11ea_8699_0242ac1c0002row5_col13 {
#             color:  purple;
#         }    #T_4dade91c_414f_11ea_8699_0242ac1c0002row6_col0 {
#             color:  black;
#         }    #T_4dade91c_414f_11ea_8699_0242ac1c0002row6_col1 {
#             color:  black;
#         }    #T_4dade91c_414f_11ea_8699_0242ac1c0002row6_col2 {
#             color:  black;
#         }    #T_4dade91c_414f_11ea_

# %% [markdown]
# ## By category

# %%
category_metrics_df = category_metric_list[0][['Label', 'Train', 'Validation']].copy()
category_metrics_df.columns = ['Label', 'Train_fold_0', 'Valid_fold_0']

for n_fold in range(1, N_FOLDS):
    category_metrics_df_idx = category_metric_list[n_fold][['Train', 'Validation']].copy()
    category_metrics_df_idx.columns = ['Train_fold_%d' % n_fold, 'Valid_fold_%d' % n_fold]
    category_metrics_df = pd.concat([category_metrics_df, category_metrics_df_idx], axis=1)
    
category_metrics_df['Train'] = 0
category_metrics_df['Validation'] = 0
for n_fold in range(N_FOLDS):
    category_metrics_df['Train'] += category_metrics_df['Train_fold_%d' % n_fold] / N_FOLDS
    category_metrics_df['Validation'] += category_metrics_df['Valid_fold_%d' % n_fold] / N_FOLDS
    
category_metrics_df['Var'] = category_metrics_df['Train'] - category_metrics_df['Validation']
display(category_metrics_df.style.applymap(color_map))
# Out:
# <style  type="text/css" >
#     #T_4dc1c3ba_414f_11ea_8699_0242ac1c0002row0_col0 {
#             color:  black;
#         }    #T_4dc1c3ba_414f_11ea_8699_0242ac1c0002row0_col1 {
#             color:  black;
#         }    #T_4dc1c3ba_414f_11ea_8699_0242ac1c0002row0_col2 {
#             color:  black;
#         }    #T_4dc1c3ba_414f_11ea_8699_0242ac1c0002row0_col3 {
#             color:  black;
#         }    #T_4dc1c3ba_414f_11ea_8699_0242ac1c0002row0_col4 {
#             color:  black;
#         }    #T_4dc1c3ba_414f_11ea_8699_0242ac1c0002row0_col5 {
#             color:  black;
#         }    #T_4dc1c3ba_414f_11ea_8699_0242ac1c0002row0_col6 {
#             color:  black;
#         }    #T_4dc1c3ba_414f_11ea_8699_0242ac1c0002row0_col7 {
#             color:  black;
#         }    #T_4dc1c3ba_414f_11ea_8699_0242ac1c0002row0_col8 {
#             color:  black;
#         }    #T_4dc1c3ba_414f_11ea_8699_0242ac1c0002row0_col9 {
#             color:  black;
#         }    #T_4dc1c3ba_414f_11ea_8699_0242ac1c0002row0_col10 {
#             color:  black;
#         }    #T_4dc1c3ba_414f_11ea_8699_0242ac1c0002row0_col11 {
#             color:  black;
#         }    #T_4dc1c3ba_414f_11ea_8699_0242ac1c0002row0_col12 {
#             color:  black;
#         }    #T_4dc1c3ba_414f_11ea_8699_0242ac1c0002row0_col13 {
#             color:  orange;
#         }    #T_4dc1c3ba_414f_11ea_8699_0242ac1c0002row1_col0 {
#             color:  black;
#         }    #T_4dc1c3ba_414f_11ea_8699_0242ac1c0002row1_col1 {
#             color:  black;
#         }    #T_4dc1c3ba_414f_11ea_8699_0242ac1c0002row1_col2 {
#             color:  black;
#         }    #T_4dc1c3ba_414f_11ea_8699_0242ac1c0002row1_col3 {
#             color:  black;
#         }    #T_4dc1c3ba_414f_11ea_8699_0242ac1c0002row1_col4 {
#             color:  black;
#         }    #T_4dc1c3ba_414f_11ea_8699_0242ac1c0002row1_col5 {
#             color:  black;
#         }    #T_4dc1c3ba_414f_11ea_8699_0242ac1c0002row1_col6 {
#             color:  black;
#         }    #T_4dc1c3ba_414f_11ea_8699_0242ac1c0002row1_col7 {
#             color:  black;
#         }    #T_4dc1c3ba_414f_11ea_8699_0242ac1c0002row1_col8 {
#             color:  black;
#         }    #T_4dc1c3ba_414f_11ea_8699_0242ac1c0002row1_col9 {
#             color:  black;
#         }    #T_4dc1c3ba_414f_11ea_8699_0242ac1c0002row1_col10 {
#             color:  black;
#         }    #T_4dc1c3ba_414f_11ea_8699_0242ac1c0002row1_col11 {
#             color:  black;
#         }    #T_4dc1c3ba_414f_11ea_8699_0242ac1c0002row1_col12 {
#             color:  black;
#         }    #T_4dc1c3ba_414f_11ea_8699_0242ac1c0002row1_col13 {
#             color:  orange;
#         }    #T_4dc1c3ba_414f_11ea_8699_0242ac1c0002row2_col0 {
#             color:  black;
#         }    #T_4dc1c3ba_414f_11ea_8699_0242ac1c0002row2_col1 {
#             color:  black;
#         }    #T_4dc1c3ba_414f_11ea_8699_0242ac1c0002row2_col2 {
#             color:  black;
#         }    #T_4dc1c3ba_414f_11ea_8699_0242ac1c0002row2_col3 {
#             color:  black;
#         }    #T_4dc1c3ba_414f_11ea_8699_0242ac1c0002row2_col4 {
#             color:  black;
#         }    #T_4dc1c3ba_414f_11ea_8699_0242ac1c0002row2_col5 {
#             color:  black;
#         }    #T_4dc1c3ba_414f_11ea_8699_0242ac1c0002row2_col6 {
#             color:  black;
#         }    #T_4dc1c3ba_414f_11ea_8699_0242ac1c0002row2_col7 {
#             color:  black;
#         }    #T_4dc1c3ba_414f_11ea_8699_0242ac1c0002row2_col8 {
#             color:  black;
#         }    #T_4dc1c3ba_414f_11ea_8699_0242ac1c0002row2_col9 {
#             color:  black;
#         }    #T_4dc1c3ba_414f_11ea_8699_0242ac1c0002row2_col10 {
#             color:  black;
#         }    #T_4dc1c3ba_414f_11ea_8699_0242ac1c0002row2_col11 {
#             color:  black;
#         }    #T_4dc1c3ba_414f_11ea_8699_0242ac1c0002row2_col12 {
#             color:  black;
#         }    #T_4dc1c3ba_414f_11ea_8699_0242ac1c0002row2_col13 {
#             color:  orange;
#         }    #T_4dc1c3ba_414f_11ea_8699_0242ac1c0002row3_col0 {
#             color:  black;
#         }    #T_4dc1c3ba_414f_11ea_8699_0242ac1c0002row3_col1 {
#             color:  black;
#         }    #T_4dc1c3ba_414f_11ea_8699_0242ac1c0002row3_col2 {
#             color:  orange;
#         }    #T_4dc1c3ba_414f_11ea_8699_0242ac1c0002row3_col3 {
#             color:  black;
#         }    #T_4dc1c3ba_414f_11ea_8699_0242ac1c0002row3_col4 {
#             color:  orange;
#         }    #T_4dc1c3ba_414f_11ea_8699_0242ac1c0002row3_col5 {
#             color:  black;
#         }    #T_4dc1c3ba_414f_11ea_8699_0242ac1c0002row3_col6 {
#             color:  black;
#         }    #T_4dc1c3ba_414f_11ea_8699_0242ac1c0002row3_col7 {
#             color:  black;
#         }    #T_4dc1c3ba_414f_11ea_8699_0242ac1c0002row3_col8 {
#             color:  orange;
#         }    #T_4dc1c3ba_414f_11ea_8699_0242ac1c0002row3_col9 {
#             color:  black;
#         }    #T_4dc1c3ba_414f_11ea_8699_0242ac1c0002row3_col10 {
#             color:  orange;
#         }    #T_4dc1c3ba_414f_11ea_8699_0242ac1c0002row3_col11 {
#             color:  black;
#         }    #T_4dc1c3ba_414f_11ea_8699_0242ac1c0002row3_col12 {
#             color:  orange;
#         }    #T_4dc1c3ba_414f_11ea_8699_0242ac1c0002row3_col13 {
#             color:  orange;
#         }    #T_4dc1c3ba_414f_11ea_8699_0242ac1c0002row4_col0 {
#             color:  black;
#         }    #T_4dc1c3ba_414f_11ea_8699_0242ac1c0002row4_col1 {
#             color:  black;
#         }    #T_4dc1c3ba_414f_11ea_8699_0242ac1c0002row4_col2 {
#             color:  black;
#         }    #T_4dc1c3ba_414f_11ea_8699_0242ac1c0002row4_col3 {
#             color:  black;
#         }    #T_4dc1c3ba_414f_11ea_8699_0242ac1c0002row4_col4 {
#             color:  black;
#         }    #T_4dc1c3ba_414f_11ea_8699_0242ac1c0002row4_col5 {
#             color:  black;
#         }    #T_4dc1c3ba_414f_11ea_8699_0242ac1c0002row4_col6 {
#             color:  orange;
#         }    #T_4dc1c3ba_414f_11ea_8699_0242ac1c0002row4_col7 {
#             color:  black;
#         }    #T_4dc1c3ba_414f_11ea_8699_0242ac1c0002row4_col8 {
#             color:  black;
#         }    #T_4dc1c3ba_414f_11ea_8699_0242ac1c0002row4_col9 {
#             color:  black;
#         }    #T_4dc1c3ba_414f_11ea_8699_0242ac1c0002row4_col10 {
#             color:  black;
#         }    #T_4dc1c3ba_414f_11ea_8699_0242ac1c0002row4_col11 {
#             color:  black;
#         }    #T_4dc1c3ba_414f_11ea_8699_0242ac1c0002row4_col12 {
#             color:  black;
#         }    #T_4dc1c3ba_414f_11ea_8699_0242ac1c0002row4_col13 {
#             color:  orange;
#         }</style><table id="T_4dc1c3ba_414f_11ea_8699_0242ac1c0002" ><thead>    <tr>        <th class="blank level0" ></th>        <th class="col_heading level0 col0" >Label</th>        <th class="col_heading level0 col1" >Train_fold_0</th>        <th class="col_heading level0 col2" >Valid_fold_0</th>        <th class="col_heading level0 col3" >Train_fold_1</th>        <th class="col_heading level0 col4" >Valid_fold_1</th>        <th class="col_heading level0 col5" >Train_fold_2</th>        <th class="col_heading level0 col6" >Valid_fold_2</th>        <th class="col_heading level0 col7" >Train_fold_3</th>        <th class="col_heading level0 col8" >Valid_fold_3</th>        <th class="col_heading level0 col9" >Train_fold_4</th>        <th class="col_heading level0 col10" >Valid_fold_4</th>        <th class="col_heading level0 col11" >Train</th>        <th class="col_heading level0 col12" >Validation</th>        <th class="col_heading level0 col13" >Var</th>    </tr></thead><tbody>
#                 <tr>
#                         <th id="T_4dc1c3ba_414f_11ea_8699_0242ac1c0002level0_row0" class="row_heading level0 row0" >0</th>
#                         <td id="T_4dc1c3ba_414f_11ea_8699_0242ac1c0002row0_col0" class="data row0 col0" >LIFE_ARTS</td>
#                         <td id="T_4dc1c3ba_414f_11ea_8699_0242ac1c0002row0_col1" class="data row0 col1" >0.547</td>
#                         <td id="T_4dc1c3ba_414f_11ea_8699_0242ac1c0002row0_col2" class="data row0 col2" >0.424</td>
#                         <td id="T_4dc1c3ba_414f_11ea_8699_0242ac1c0002row0_col3" class="dat
