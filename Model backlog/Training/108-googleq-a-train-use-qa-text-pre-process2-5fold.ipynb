# %% [markdown]
# ## Dependencies

# %%
import warnings
import tensorflow_hub as hub
import tensorflow.keras.backend as K
from tensorflow.keras import Model, optimizers
from tensorflow.keras.layers import Lambda, Input, Dense, Dropout, Concatenate
from tensorflow.keras.callbacks import EarlyStopping, ReduceLROnPlateau
from googleqa_utilityscript import *
from googleqa_map_utilityscript import *

SEED = 0
seed_everything(SEED)
warnings.filterwarnings("ignore")

# %% [markdown]
# ## Load data

# %%
module_url = '/kaggle/input/universalsentenceencodermodels/universal-sentence-encoder-models/use-qa'

k_fold = pd.read_csv('/kaggle/input/googleqa-mldataset/5-fold.csv')
N_FOLDS = 5

print('Samples: %s' % len(k_fold))
display(k_fold.head())
# Out:
# Samples: 6079
#    qa_id                                     question_title  \
# 0      0  What am I losing when using extension tubes in...
# 1      1  What is the distinction between a city and a s...
# 2      2  Maximum protusion length for through-hole comp...
# 3      3              Can an affidavit be used in Beit Din?
# 4      5       How do you make a binary image in Photoshop?
#
#                                        question_body question_user_name  \
# 0  After playing around with macro photography on...               ysap
# 1  I am trying to understand what kinds of places...      russellpierce
# 2  I'm working on a PCB that has through-hole com...          Joe Baker
# 3  An affidavit, from what i understand, is basic...         Scimonster
# 4  I am trying to make a binary image. I want mor...            leigero
#
#                                   question_user_page  \
# 0         https://photo.stackexchange.com/users/1024
# 1           https://rpg.stackexchange.com/users/8774
# 2  https://electronics.stackexchange.com/users/10157
# 3       https://judaism.stackexchange.com/users/5151
# 4  https://graphicdesign.stackexchange.com/users/...
#
#                                               answer answer_user_name  \
# 0  I just got extension tubes, so here's the skin...           rfusca
# 1  It might be helpful to look into the definitio...     Erik Schmidt
# 2  Do you even need grooves?  We make several pro...      Dwayne Reid
# 3  Sending an "affidavit" it is a dispute between...    Y     e     z
# 4  Check out Image Trace in Adobe Illustrator. \n...             q2ra
#
#                                     answer_user_page  \
# 0         https://photo.stackexchange.com/users/1917
# 1           https://rpg.stackexchange.com/users/1871
# 2  https://electronics.stackexchange.com/users/64754
# 3       https://judaism.stackexchange.com/users/4794
# 4  https://graphicdesign.stackexchange.com/users/...
#
#                                                  url   category  ...  \
# 0  http://photo.stackexchange.com/questions/9169/...  LIFE_ARTS  ...
# 1  http://rpg.stackexchange.com/questions/47820/w...    CULTURE  ...
# 2  http://electronics.stackexchange.com/questions...    SCIENCE  ...
# 3  http://judaism.stackexchange.com/questions/551...    CULTURE  ...
# 4  http://graphicdesign.stackexchange.com/questio...  LIFE_ARTS  ...
#
#   answer_satisfaction  answer_type_instructions  answer_type_procedure  \
# 0            0.800000                       1.0               0.000000
# 1            0.666667                       0.0               0.000000
# 2            0.666667                       0.0               0.333333
# 3            0.800000                       0.0               0.000000
# 4            0.800000                       1.0               0.000000
#
#    answer_type_reason_explanation  answer_well_written      fold_1  fold_2  \
# 0                        0.000000             1.000000       train   train
# 1                        0.666667             0.888889  validation   train
# 2                        1.000000             0.888889       train   train
# 3                        1.000000             1.000000       train   train
# 4                        1.000000             1.000000  validation   train
#
#        fold_3      fold_4      fold_5
# 0       train  validation       train
# 1       train       train       train
# 2  validation       train       train
# 3       train       train  validation
# 4       train       train       train
#
# [5 rows x 46 columns]

# %%
question_target_cols = ['question_asker_intent_understanding','question_body_critical', 'question_conversational', 
                        'question_expect_short_answer', 'question_fact_seeking', 'question_has_commonly_accepted_answer',
                        'question_interestingness_others', 'question_interestingness_self', 'question_multi_intent', 
                        'question_not_really_a_question', 'question_opinion_seeking', 'question_type_choice',
                        'question_type_compare', 'question_type_consequence', 'question_type_definition', 
                        'question_type_entity', 'question_type_instructions', 'question_type_procedure',
                        'question_type_reason_explanation', 'question_type_spelling', 'question_well_written']
answer_target_cols = ['answer_helpful', 'answer_level_of_information', 'answer_plausible', 'answer_relevance',
                      'answer_satisfaction', 'answer_type_instructions', 'answer_type_procedure', 
                      'answer_type_reason_explanation', 'answer_well_written']
target_cols = question_target_cols + answer_target_cols

# %% [markdown]
# # Pre-process data

# %%
text_features = ['question_title', 'question_body', 'answer']

for feature in text_features:
    # Lower
    k_fold[feature] = k_fold[feature].apply(lambda x: x.lower())
    # Map misspellings
    k_fold[feature] = k_fold[feature].apply(lambda x: map_misspellings(x))
    # Map contractions
    k_fold[feature] = k_fold[feature].apply(lambda x: map_contraction(x))
    # Trim text
    k_fold[feature] = k_fold[feature].apply(lambda x: x.strip())

# %% [markdown]
# # Model parameters

# %%
EPOCHS = 40
BATCH_SIZE = 32
LEARNING_RATE = 3e-4
EMBEDDDING_SIZE = 512
N_CLASS = len(target_cols)
ES_PATIENCE = 3
RLROP_PATIENCE = 2
DECAY_DROP = 0.3

# %% [markdown]
# # Model

# %%
es = EarlyStopping(monitor='val_loss', mode='min', patience=ES_PATIENCE, restore_best_weights=True, verbose=1)
rlrop = ReduceLROnPlateau(monitor='val_loss', mode='min', patience=RLROP_PATIENCE, factor=DECAY_DROP, min_lr=1e-6, verbose=1)
use_embed = hub.load(module_url)

def USEEmbedding(x):
    return use_embed(tf.squeeze(tf.cast(x, tf.string)))

# %%
def model_fn():
    input_title = Input(shape=(1,), dtype=tf.string, name='input_title')
    embedding_title = Lambda(USEEmbedding, output_shape=(EMBEDDDING_SIZE,))(input_title)

    input_body = Input(shape=(1,), dtype=tf.string, name='input_body')
    embedding_body = Lambda(USEEmbedding, output_shape=(EMBEDDDING_SIZE,))(input_body)

    input_answer = Input(shape=(1,), dtype=tf.string, name='input_answer')
    embedding_answer = Lambda(USEEmbedding, output_shape=(EMBEDDDING_SIZE,))(input_answer)

    x = Concatenate()([embedding_title, embedding_body, embedding_answer])
    x = Dropout(0.5)(x)
    x = Dense(512, activation='relu')(x)
    x = Dropout(0.5)(x)
    output = Dense(N_CLASS, activation='sigmoid', name='output')(x)
    model = Model(inputs=[input_title, input_body, input_answer], outputs=[output])
    
    return model

# %% [markdown]
# # Train model

# %%
history_list = []
metric_list = []
category_metric_list = []
target_cols_preds = [col+'_pred' for col in target_cols]

for n_fold in range(N_FOLDS):
    K.clear_session()
    model_path = '/kaggle/working/model_fold_%d.h5' % (n_fold+1)
    train = k_fold[k_fold['fold_%d' % (n_fold+1)] == 'train']
    validation = k_fold[k_fold['fold_%d' % (n_fold+1)] == 'validation']
    ### Create features
    # Train features
    X_train = [train['question_title'], train['question_body'], train['answer']]
    Y_train = train[target_cols].values
    # Validation features
    X_valid = [validation['question_title'], validation['question_body'], validation['answer']]
    Y_valid = validation[target_cols].values

    ### Train model
    spearmanCallback = SpearmanRhoCallback(training_data=(X_train, Y_train), 
                                           validation_data=(X_valid, Y_valid), 
                                           model_path=model_path, 
                                           monitor='val_loss', mode='min', 
                                           patience=ES_PATIENCE, checkpoint=True)

    callback_list = [spearmanCallback]
    optimizer = optimizers.Adam(lr=LEARNING_RATE)
    model = model_fn()
    model.compile(optimizer=optimizer, loss='binary_crossentropy')

    history = model.fit(X_train, Y_train, 
                        validation_data=(X_valid, Y_valid), 
                        callbacks=callback_list, 
                        batch_size=BATCH_SIZE, 
                        epochs=EPOCHS, 
                        verbose=2).history
    history_list.append(history)
    
    ### Evaluation - Label metrics
    model.load_weights(model_path)
    preds_train = model.predict(X_train)
    preds_val = model.predict(X_valid)
    metric_list.append(get_metrics(Y_train, preds_train, Y_valid, preds_val, target_cols))
    
    ### Evaluation - Category metrics
    for col in target_cols_preds:
        train[col] = 0
        validation[col] = 0

    train[target_cols_preds] = preds_train
    validation[target_cols_preds] = preds_val
    category_metric_list.append(get_metrics_category(train, validation, target_cols, target_cols_preds, 'category'))
# Out:
# Train on 4864 samples, validate on 1215 samples
# Epoch 1/40
# spearman-rho: 0.2287 val_spearman-rho: 0.2121
# Saved model weights at "/kaggle/working/model_fold_1.h5"
# 4864/4864 - 208s - loss: 0.4944 - val_loss: 0.4093
# Epoch 2/40
# spearman-rho: 0.3096 val_spearman-rho: 0.2886
# Saved model weights at "/kaggle/working/model_fold_1.h5"
# 4864/4864 - 124s - loss: 0.4068 - val_loss: 0.3925
# Epoch 3/40
# spearman-rho: 0.3500 val_spearman-rho: 0.3259
# Saved model weights at "/kaggle/working/model_fold_1.h5"
# 4864/4864 - 124s - loss: 0.3948 - val_loss: 0.3848
# Epoch 4/40
# spearman-rho: 0.3735 val_spearman-rho: 0.3461
# Saved model weights at "/kaggle/working/model_fold_1.h5"
# 4864/4864 - 125s - loss: 0.3886 - val_loss: 0.3803
# Epoch 5/40
# spearman-rho: 0.3887 val_spearman-rho: 0.3564
# Saved model weights at "/kaggle/working/model_fold_1.h5"
# 4864/4864 - 124s - loss: 0.3841 - val_loss: 0.3779
# Epoch 6/40
# spearman-rho: 0.4007 val_spearman-rho: 0.3640
# Saved model weights at "/kaggle/working/model_fold_1.h5"
# 4864/4864 - 124s - loss: 0.3809 - val_loss: 0.3757
# Epoch 7/40
# spearman-rho: 0.4112 val_spearman-rho: 0.3697
# Saved model weights at "/kaggle/working/model_fold_1.h5"
# 4864/4864 - 124s - loss: 0.3786 - val_loss: 0.3741
# Epoch 8/40
# spearman-rho: 0.4188 val_spearman-rho: 0.3732
# Saved model weights at "/kaggle/working/model_fold_1.h5"
# 4864/4864 - 123s - loss: 0.3765 - val_loss: 0.3729
# Epoch 9/40
# spearman-rho: 0.4265 val_spearman-rho: 0.3760
# Saved model weights at "/kaggle/working/model_fold_1.h5"
# 4864/4864 - 123s - loss: 0.3754 - val_loss: 0.3722
# Epoch 10/40
# spearman-rho: 0.4328 val_spearman-rho: 0.3787
# Saved model weights at "/kaggle/working/model_fold_1.h5"
# 4864/4864 - 124s - loss: 0.3730 - val_loss: 0.3716
# Epoch 11/40
# spearman-rho: 0.4380 val_spearman-rho: 0.3805
# Saved model weights at "/kaggle/working/model_fold_1.h5"
# 4864/4864 - 124s - loss: 0.3725 - val_loss: 0.3709
# Epoch 12/40
# spearman-rho: 0.4431 val_spearman-rho: 0.3822
# Saved model weights at "/kaggle/working/model_fold_1.h5"
# 4864/4864 - 123s - loss: 0.3713 - val_loss: 0.3706
# Epoch 13/40
# spearman-rho: 0.4474 val_spearman-rho: 0.3837
# Saved model weights at "/kaggle/working/model_fold_1.h5"
# 4864/4864 - 122s - loss: 0.3697 - val_loss: 0.3699
# Epoch 14/40
# spearman-rho: 0.4528 val_spearman-rho: 0.3849
# Saved model weights at "/kaggle/working/model_fold_1.h5"
# 4864/4864 - 123s - loss: 0.3692 - val_loss: 0.3699
# Epoch 15/40
# spearman-rho: 0.4566 val_spearman-rho: 0.3861
# Saved model weights at "/kaggle/working/model_fold_1.h5"
# 4864/4864 - 123s - loss: 0.3682 - val_loss: 0.3697
# Epoch 16/40
# spearman-rho: 0.4604 val_spearman-rho: 0.3869
# Saved model weights at "/kaggle/working/model_fold_1.h5"
# 4864/4864 - 123s - loss: 0.3674 - val_loss: 0.3694
# Epoch 17/40
# spearman-rho: 0.4635 val_spearman-rho: 0.3878
# Saved model weights at "/kaggle/working/model_fold_1.h5"
# 4864/4864 - 124s - loss: 0.3668 - val_loss: 0.3690
# Epoch 18/40
# spearman-rho: 0.4666 val_spearman-rho: 0.3887
# Saved model weights at "/kaggle/working/model_fold_1.h5"
# 4864/4864 - 123s - loss: 0.3659 - val_loss: 0.3689
# Epoch 19/40
# spearman-rho: 0.4699 val_spearman-rho: 0.3885
# Saved model weights at "/kaggle/working/model_fold_1.h5"
# 4864/4864 - 123s - loss: 0.3648 - val_loss: 0.3687
# Epoch 20/40
# spearman-rho: 0.4736 val_spearman-rho: 0.3891
# 4864/4864 - 123s - loss: 0.3645 - val_loss: 0.3688
# Epoch 21/40
# spearman-rho: 0.4771 val_spearman-rho: 0.3894
# Saved model weights at "/kaggle/working/model_fold_1.h5"
# 4864/4864 - 123s - loss: 0.3642 - val_loss: 0.3685
# Epoch 22/40
# spearman-rho: 0.4795 val_spearman-rho: 0.3896
# 4864/4864 - 122s - loss: 0.3634 - val_loss: 0.3690
# Epoch 23/40
# spearman-rho: 0.4823 val_spearman-rho: 0.3896
# Saved model weights at "/kaggle/working/model_fold_1.h5"
# 4864/4864 - 123s - loss: 0.3628 - val_loss: 0.3683
# Epoch 24/40
# spearman-rho: 0.4850 val_spearman-rho: 0.3897
# Epoch 00023: early stopping
# 4864/4864 - 123s - loss: 0.3622 - val_loss: 0.3683
# Train on 4864 samples, validate on 1215 samples
# Epoch 1/40
# spearman-rho: 0.2349 val_spearman-rho: 0.2060
# Saved model weights at "/kaggle/working/model_fold_2.h5"
# 4864/4864 - 201s - loss: 0.4925 - val_loss: 0.4099
# Epoch 2/40
# spearman-rho: 0.3125 val_spearman-rho: 0.2776
# Saved model weights at "/kaggle/working/model_fold_2.h5"
# 4864/4864 - 124s - loss: 0.4055 - val_loss: 0.3943
# Epoch 3/40
# spearman-rho: 0.3546 val_spearman-rho: 0.3131
# Saved model weights at "/kaggle/working/model_fold_2.h5"
# 4864/4864 - 123s - loss: 0.3942 - val_loss: 0.3871
# Epoch 4/40
# spearman-rho: 0.3785 val_spearman-rho: 0.3310
# Saved model weights at "/kaggle/working/model_fold_2.h5"
# 4864/4864 - 122s - loss: 0.3878 - val_loss: 0.3830
# Epoch 5/40
# spearman-rho: 0.3932 val_spearman-rho: 0.3402
# Saved model weights at "/kaggle/working/model_fold_2.h5"
# 4864/4864 - 122s - loss: 0.3833 - val_loss: 0.3805
# Epoch 6/40
# spearman-rho: 0.4050 val_spearman-rho: 0.3471
# Saved model weights at "/kaggle/working/model_fold_2.h5"
# 4864/4864 - 123s - loss: 0.3805 - val_loss: 0.3784
# Epoch 7/40
# spearman-rho: 0.4144 val_spearman-rho: 0.3519
# Saved model weights at "/kaggle/working/model_fold_2.h5"
# 4864/4864 - 124s - loss: 0.3777 - val_loss: 0.3771
# Epoch 8/40
# spearman-rho: 0.4220 val_spearman-rho: 0.3554
# Saved model weights at "/kaggle/working/model_fold_2.h5"
# 4864/4864 - 123s - loss: 0.3763 - val_loss: 0.3763
# Epoch 9/40
# spearman-rho: 0.4299 val_spearman-rho: 0.3574
# Saved model weights at "/kaggle/working/model_fold_2.h5"
# 4864/4864 - 123s - loss: 0.3746 - val_loss: 0.3755
# Epoch 10/40
# spearman-rho: 0.4362 val_spearman-rho: 0.3602
# Saved model weights at "/kaggle/working/model_fold_2.h5"
# 4864/4864 - 123s - loss: 0.3734 - val_loss: 0.3747
# Epoch 11/40
# spearman-rho: 0.4418 val_spearman-rho: 0.3632
# Saved model weights at "/kaggle/working/model_fold_2.h5"
# 4864/4864 - 123s - loss: 0.3716 - val_loss: 0.3743
# Epoch 12/40
# spearman-rho: 0.4465 val_spearman-rho: 0.3646
# Saved model weights at "/kaggle/working/model_fold_2.h5"
# 4864/4864 - 124s - loss: 0.3701 - val_loss: 0.3736
# Epoch 13/40
# spearman-rho: 0.4514 val_spearman-rho: 0.3661
# Saved model weights at "/kaggle/working/model_fold_2.h5"
# 4864/4864 - 123s - loss: 0.3690 - val_loss: 0.3731
# Epoch 14/40
# spearman-rho: 0.4557 val_spearman-rho: 0.3669
# Saved model weights at "/kaggle/working/model_fold_2.h5"
# 4864/4864 - 124s - loss: 0.3687 - val_loss: 0.3728
# Epoch 15/40
# spearman-rho: 0.4597 val_spearman-rho: 0.3678
# 4864/4864 - 125s - loss: 0.3673 - val_loss: 0.3728
# Epoch 16/40
# spearman-rho: 0.4634 val_spearman-rho: 0.3688
# Saved model weights at "/kaggle/working/model_fold_2.h5"
# 4864/4864 - 124s - loss: 0.3662 - val_loss: 0.3725
# Epoch 17/40
# spearman-rho: 0.4670 val_spearman-rho: 0.3700
# Saved model weights at "/kaggle/working/model_fold_2.h5"
# 4864/4864 - 123s - loss: 0.3659 - val_loss: 0.3722
# Epoch 18/40
# spearman-rho: 0.4701 val_spearman-rho: 0.3714
# Saved model weights at "/kaggle/working/model_fold_2.h5"
# 4864/4864 - 123s - loss: 0.3650 - val_loss: 0.3720
# Epoch 19/40
# spearman-rho: 0.4736 val_spearman-rho: 0.3723
# 4864/4864 - 123s - loss: 0.3646 - val_loss: 0.3721
# Epoch 20/40
# spearman-rho: 0.4769 val_spearman-rho: 0.3726
# Epoch 00019: early stopping
# 4864/4864 - 123s - loss: 0.3638 - val_loss: 0.3720
# Train on 4859 samples, validate on 1220 samples
# Epoch 1/40
# spearman-rho: 0.2224 val_spearman-rho: 0.2195
# Saved model weights at "/kaggle/working/model_fold_3.h5"
# 4859/4859 - 198s - loss: 0.4913 - val_loss: 0.4112
# Epoch 2/40
# spearman-rho: 0.3105 val_spearman-rho: 0.2926
# Saved model weights at "/kaggle/working/model_fold_3.h5"
# 4859/4859 - 123s - loss: 0.4067 - val_loss: 0.3938
# Epoch 3/40
# spearman-rho: 0.3519 val_spearman-rho: 0.3235
# Saved model weights at "/kaggle/working/model_fold_3.h5"
# 4859/4859 - 123s - loss: 0.3948 - val_loss: 0.3864
# Epoch 4/40
# spearman-rho: 0.3734 val_spearman-rho: 0.3380
# Saved model weights at "/kaggle/working/model_fold_3.h5"
# 4859/4859 - 124s - loss: 0.3879 - val_loss: 0.3822
# Epoch 5/40
# spearman-rho: 0.3907 val_spearman-rho: 0.3472
# Saved model weights at "/kaggle/working/model_fold_3.h5"
# 4859/4859 - 123s - loss: 0.3837 - val_loss: 0.3794
# Epoch 6/40
# spearman-rho: 0.4021 val_spearman-rho: 0.3520
# Saved model weights at "/kaggle/working/model_fold_3.h5"
# 4859/4859 - 123s - loss: 0.3805 - val_loss: 0.3775
# Epoch 7/40
# spearman-rho: 0.4127 val_spearman-rho: 0.3566
# Saved model weights at "/kaggle/working/model_fold_3.h5"
# 4859/4859 - 122s - loss: 0.3784 - val_loss: 0.3763
# Epoch 8/40
# spearman-rho: 0.4217 val_spearman-rho: 0.3594
# Saved model weights at "/kaggle/working/model_fold_3.h5"
# 4859/4859 - 123s - loss: 0.3762 - val_loss: 0.3753
# Epoch 9/40
# spearman-rho: 0.4290 val_spearman-rho: 0.3620
# Saved model weights at "/kaggle/working/model_fold_3.h5"
# 4859/4859 - 123s - loss: 0.3747 - val_loss: 0.3744
# Epoch 10/40
# spearman-rho: 0.4356 val_spearman-rho: 0.3640
# Saved model weights at "/kaggle/working/model_fold_3.h5"
# 4859/4859 - 123s - loss: 0.3729 - val_loss: 0.3736
# Epoch 11/40
# spearman-rho: 0.4414 val_spearman-rho: 0.3655
# Saved model weights at "/kaggle/working/model_fold_3.h5"
# 4859/4859 - 123s - loss: 0.3711 - val_loss: 0.3730
# Epoch 12/40
# spearman-rho: 0.4470 val_spearman-rho: 0.3672
# Saved model weights at "/kaggle/working/model_fold_3.h5"
# 4859/4859 - 122s - loss: 0.3706 - val_loss: 0.3726
# Epoch 13/40
# spearman-rho: 0.4514 val_spearman-rho: 0.3670
# Saved model weights at "/kaggle/working/model_fold_3.h5"
# 4859/4859 - 124s - loss: 0.3692 - val_loss: 0.3722
# Epoch 14/40
# spearman-rho: 0.4561 val_spearman-rho: 0.3684
# Saved model weights at "/kaggle/working/model_fold_3.h5"
# 4859/4859 - 124s - loss: 0.3683 - val_loss: 0.3720
# Epoch 15/40
# spearman-rho: 0.4603 val_spearman-rho: 0.3683
# Saved model weights at "/kaggle/working/model_fold_3.h5"
# 4859/4859 - 123s - loss: 0.3678 - val_loss: 0.3720
# Epoch 16/40
# spearman-rho: 0.4640 val_spearman-rho: 0.3696
# Saved model weights at "/kaggle/working/model_fold_3.h5"
# 4859/4859 - 123s - loss: 0.3665 - val_loss: 0.3716
# Epoch 17/40
# spearman-rho: 0.4673 val_spearman-rho: 0.3695
# Saved model weights at "/kaggle/working/model_fold_3.h5"
# 4859/4859 - 123s - loss: 0.3660 - val_loss: 0.3715
# Epoch 18/40
# spearman-rho: 0.4711 val_spearman-rho: 0.3705
# Saved model weights at "/kaggle/working/model_fold_3.h5"
# 4859/4859 - 123s - loss: 0.3648 - val_loss: 0.3714
# Epoch 19/40
# spearman-rho: 0.4745 val_spearman-rho: 0.3708
# Saved model weights at "/kaggle/working/model_fold_3.h5"
# 4859/4859 - 124s - loss: 0.3645 - val_loss: 0.3711
# Epoch 20/40
# spearman-rho: 0.4771 val_spearman-rho: 0.3712
# Saved model weights at "/kaggle/working/model_fold_3.h5"
# 4859/4859 - 124s - loss: 0.3637 - val_loss: 0.3710
# Epoch 21/40
# spearman-rho: 0.4808 val_spearman-rho: 0.3712
# Saved model weights at "/kaggle/working/model_fold_3.h5"
# 4859/4859 - 124s - loss: 0.3629 - val_loss: 0.3710
# Epoch 22/40
# spearman-rho: 0.4841 val_spearman-rho: 0.3720
# Saved model weights at "/kaggle/working/model_fold_3.h5"
# 4859/4859 - 124s - loss: 0.3621 - val_loss: 0.3710
# Epoch 23/40
# spearman-rho: 0.4860 val_spearman-rho: 0.3718
# Saved model weights at "/kaggle/working/model_fold_3.h5"
# 4859/4859 - 124s - loss: 0.3616 - val_loss: 0.3710
# Epoch 24/40
# spearman-rho: 0.4891 val_spearman-rho: 0.3725
# Saved model weights at "/kaggle/working/model_fold_3.h5"
# 4859/4859 - 122s - loss: 0.3619 - val_loss: 0.3707
# Epoch 25/40
# spearman-rho: 0.4920 val_spearman-rho: 0.3727
# 4859/4859 - 123s - loss: 0.3612 - val_loss: 0.3709
# Epoch 26/40
# spearman-rho: 0.4941 val_spearman-rho: 0.3733
# 4859/4859 - 124s - loss: 0.3606 - val_loss: 0.3707
# Epoch 27/40
# spearman-rho: 0.4963 val_spearman-rho: 0.3734
# Saved model weights at "/kaggle/working/model_fold_3.h5"
# 4859/4859 - 123s - loss: 0.3600 - val_loss: 0.3706
# Epoch 28/40
# spearman-rho: 0.4996 val_spearman-rho: 0.3736
# Saved model weights at "/kaggle/working/model_fold_3.h5"
# 4859/4859 - 123s - loss: 0.3594 - val_loss: 0.3706
# Epoch 29/40
# spearman-rho: 0.5023 val_spearman-rho: 0.3733
# Saved model weights at "/kaggle/working/model_fold_3.h5"
# 4859/4859 - 123s - loss: 0.3586 - val_loss: 0.3706
# Epoch 30/40
# spearman-rho: 0.5043 val_spearman-rho: 0.3740
# Saved model weights at "/kaggle/working/model_fold_3.h5"
# 4859/4859 - 122s - loss: 0.3576 - val_loss: 0.3703
# Epoch 31/40
# spearman-rho: 0.5067 val_spearman-rho: 0.3739
# Epoch 00030: early stopping
# 4859/4859 - 123s - loss: 0.3576 - val_loss: 0.3705
# Train on 4865 samples, validate on 1214 samples
# Epoch 1/40
# ---------------------------------------------------------------------------
# InvalidArgumentError                      Traceback (most recent call last)
# <ipython-input-8-80ac6dc8096e> in <module>
#      34                         batch_size=BATCH_SIZE,
#      35                         epochs=EPOCHS,
# ---> 36                         verbose=2).history
#      37     history_list.append(history)
#      38
#
# /opt/conda/lib/python3.6/site-packages/tensorflow_core/python/keras/engine/training.py in fit(self, x, y, batch_size, epochs, verbose, callbacks, validation_split, validation_data, shuffle, class_weight, sample_weight, initial_epoch, steps_per_epoch, validation_steps, validation_freq, max_queue_size, workers, use_multiprocessing, **kwargs)
#     726         max_queue_size=max_queue_size,
#     727         workers=workers,
# --> 728         use_multiprocessing=use_multiprocessing)
#     729
#     730   def evaluate(self,
#
# /opt/conda/lib/python3.6/site-packages/tensorflow_core/python/keras/engine/training_arrays.py in fit(self, model, x, y, batch_size, epochs, verbose, callbacks, validation_split, validation_data, shuffle, class_weight, sample_weight, initial_epoch, steps_per_epoch, validation_steps, validation_freq, **kwargs)
#     672         validation_steps=validation_steps,
#     673         validation_freq=validation_freq,
# --> 674         steps_name='steps_per_epoch')
#     675
#     676   def evaluate(self,
#
# /opt/conda/lib/python3.6/site-packages/tensorflow_core/python/keras/engine/training_arrays.py in model_iteration(model, inputs, targets, sample_weights, batch_size, epochs, verbose, callbacks, val_inputs, val_targets, val_sample_weights, shuffle, initial_epoch, steps_per_epoch, validation_steps, validation_freq, mode, validation_in_fit, prepared_feed_values_from_dataset, steps_name, **kwargs)
#     391
#     392         # Get outputs.
# --> 393         batch_outs = f(ins_batch)
#     394         if not isinstance(batch_outs, list):
#     395           batch_outs = [batch_outs]
#
# /opt/conda/lib/python3.6/site-packages/tensorflow_core/python/keras/backend.py in __call__(self, inputs)
#    3738         value = math_ops.cast(value, tensor.dtype)
#    3739       converted_inputs.append(value)
# -> 3740     outputs = self._graph_fn(*converted_inputs)
#    3741
#    3742     # EagerTensor.numpy() will often make a copy to ensure memory safety.
#
# /opt/conda/lib/python3.6/site-packages/tensorflow_core/python/eager/function.py in __call__(self, *args, **kwargs)
#    1079       TypeError: For invalid positional/keyword argument combinations.
#    1080     """
# -> 1081     return self._call_impl(args, kwargs)
#    1082
#    1083   def _call_impl(self, args, kwargs, cancellation_manager=None):
#
# /opt/conda/lib/python3.6/site-packages/tensorflow_core/python/eager/function.py in _call_impl(self, args, kwargs, cancellation_manager)
#    1119       raise TypeError("Keyword arguments {} unknown. Expected {}.".format(
#    1120           list(kwargs.keys()), list(self._arg_keywords)))
# -> 1121     return self._call_flat(args, self.captured_inputs, cancellation_manager)
#    1122
#    1123   def _filtered_call(self, args, kwargs):
#
# /opt/conda/lib/python3.6/site-packages/tensorflow_core/python/eager/function.py in _call_flat(self, args, captured_inputs, cancellation_manager)
#    1222     if executing_eagerly:
#    1223       flat_outputs = forward_function.call(
# -> 1224           ctx, args, cancellation_manager=cancellation_manager)
#    1225     else:
#    1226       gradient_name = self._delayed_rewrite_functions.register()
#
# /opt/conda/lib/python3.6/site-packages/tensorflow_core/python/eager/function.py in call(self, ctx, args, cancellation_manager)
#     509               inputs=args,
#     510               attrs=("executor_type", executor_type, "config_proto", config),
# --> 511               ctx=ctx)
#     512         else:
#     513           outputs = execute.execute_with_cancellation(
#
# /opt/conda/lib/python3.6/site-packages/tensorflow_core/python/eager/execute.py in quick_execute(op_name, num_outputs, inputs, attrs, ctx, name)
#      65     else:
#      66       message = e.message
# ---> 67     six.raise_from(core._status_to_exception(e.code, message), None)
#      68   except TypeError as e:
#      69     keras_symbolic_tensors = [
#
# /opt/conda/lib/python3.6/site-packages/six.py in raise_from(value, from_value)
#
# InvalidArgumentError:  input must be a vector, got shape: []
# 	 [[{{node lambda_2/StatefulPartitionedCall/StatefulPartitionedCall/StatefulPartitionedCall/text_preprocessor/tokenize/StringSplit/StringSplit}}]] [Op:__inference_keras_scratch_graph_303939]
#
# Function call stack:
# keras_scratch_graph

# %% [markdown]
# ## Model loss graph

# %%
for n_fold in range(N_FOLDS):
    print('Fold: %d' % n_fold)
    sns.set(style="whitegrid")
    plot_metrics(history_list[n_fold], metric_list=['loss', 'spearman'])
# Out:
# Fold: 0
# Fold: 1
# Fold: 2
# Fold: 3
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# <ipython-input-9-efe72449ff86> in <module>
#       2     print('Fold: %d' % n_fold)
#       3     sns.set(style="whitegrid")
# ----> 4     plot_metrics(history_list[n_fold], metric_list=['loss', 'spearman'])
#
# IndexError: list index out of range

# %% [markdown]
# # Evaluation

# %%
metrics_df = metric_list[0][['Label', 'Train', 'Validation']].copy()
metrics_df.columns = ['Label', 'Train_fold_0', 'Valid_fold_0']

for n_fold in range(1, N_FOLDS):
    metrics_df_idx = metric_list[n_fold][['Train', 'Validation']].copy()
    metrics_df_idx.columns = ['Train_fold_%d' % n_fold, 'Valid_fold_%d' % n_fold]
    metrics_df = pd.concat([metrics_df, metrics_df_idx], axis=1)

metrics_df['Train'] = 0
metrics_df['Validation'] = 0
for n_fold in range(N_FOLDS):
    metrics_df['Train'] += metrics_df['Train_fold_%d' % n_fold] / N_FOLDS
    metrics_df['Validation'] += metrics_df['Valid_fold_%d' % n_fold] / N_FOLDS

metrics_df['Var'] = metrics_df['Train'] - metrics_df['Validation']
display(metrics_df.style.applymap(color_map))
# Out:
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# <ipython-input-10-b7928548fd15> in <module>
#       3
#       4 for n_fold in range(1, N_FOLDS):
# ----> 5     metrics_df_idx = metric_list[n_fold][['Train', 'Validation']].copy()
#       6     metrics_df_idx.columns = ['Train_fold_%d' % n_fold, 'Valid_fold_%d' % n_fold]
#       7     metrics_df = pd.concat([metrics_df, metrics_df_idx], axis=1)
#
# IndexError: list index out of range

# %% [markdown]
# ## By category

# %%
category_metrics_df = category_metric_list[0][['Label', 'Train', 'Validation']].copy()
category_metrics_df.columns = ['Label', 'Train_fold_0', 'Valid_fold_0']

for n_fold in range(1, N_FOLDS):
    category_metrics_df_idx = category_metric_list[n_fold][['Train', 'Validation']].copy()
    category_metrics_df_idx.columns = ['Train_fold_%d' % n_fold, 'Valid_fold_%d' % n_fold]
    category_metrics_df = pd.concat([category_metrics_df, category_metrics_df_idx], axis=1)
    
category_metrics_df['Train'] = 0
category_metrics_df['Validation'] = 0
for n_fold in range(N_FOLDS):
    category_metrics_df['Train'] += category_metrics_df['Train_fold_%d' % n_fold] / N_FOLDS
    category_metrics_df['Validation'] += category_metrics_df['Valid_fold_%d' % n_fold] / N_FOLDS
    
category_metrics_df['Var'] = category_metrics_df['Train'] - category_metrics_df['Validation']
display(category_metrics_df.style.applymap(color_map))
# Out:
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# <ipython-input-11-318b96f2ea6d> in <module>
#       3
#       4 for n_fold in range(1, N_FOLDS):
# ----> 5     category_metrics_df_idx = category_metric_list[n_fold][['Train', 'Validation']].copy()
#       6     category_metrics_df_idx.columns = ['Train_fold_%d' % n_fold, 'Valid_fold_%d' % n_fold]
#       7     category_metrics_df = pd.concat([category_metrics_df, category_metrics_df_idx], axis=1)
#
# IndexError: list index out of range
