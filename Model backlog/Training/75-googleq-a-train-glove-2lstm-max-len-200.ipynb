# %% [markdown]
# ## Dependencies

# %%
import gc
import re
import warnings
from joblib import dump
import tensorflow_hub as hub
from tensorflow.keras import Model, optimizers
from tensorflow.keras.callbacks import ReduceLROnPlateau
from tensorflow.keras.preprocessing.text import Tokenizer
from tensorflow.keras.preprocessing.sequence import pad_sequences
from tensorflow.keras.layers import Lambda, Input, Dense, Dropout, Concatenate, BatchNormalization, Activation, Average, Add, Reshape
from tensorflow.keras.layers import GlobalAveragePooling1D, Embedding, LSTM, Conv1D, SpatialDropout1D, Bidirectional, Flatten
from googleqa_utilityscript import *


SEED = 0
seed_everything(SEED)
warnings.filterwarnings("ignore")

# %% [markdown]
# ## Load data

# %%
module_url = '/kaggle/input/universalsentenceencodermodels/universal-sentence-encoder-models/use'
model_path = '/kaggle/working/model.h5'
tokenizer_path = '/kaggle/working/tokenizer.joblib'
encoder_path = '/kaggle/input/pickled-glove840b300d-for-10sec-loading/glove.840B.300d.pkl'

hold_out = pd.read_csv('/kaggle/input/googleqa-mldataset/hold-out.csv')
test = pd.read_csv('/kaggle/input/google-quest-challenge/test.csv')
train = hold_out[hold_out['set'] == 'train']
validation = hold_out[hold_out['set'] == 'validation']

print('Train samples: %s' % len(train))
print('Validation samples: %s' % len(validation))
display(train.head())
# Out:
# Train samples: 4863
# Validation samples: 1216
#    qa_id                                     question_title  \
# 0   3895  Magento (1.7) Bundled Product with FREE Produc...
# 1   3131                             Find router on network
# 2   1507  Negatively curved metrics minimizing the lengt...
# 3   6784               Isn’t the FAQ label obsolete by now?
# 4   2135  Changing background image one time on responsi...
#
#                                        question_body question_user_name  \
# 0  I'm looking to create a bundle offer where cus...                Joe
# 1  I've just bought a Belkin N+ Wireless Router. ...                Guy
# 2  Good afternoon everyone !\n\nI have the follow...            Selim G
# 3  Don’t get me wrong in the beginning of reading...     Benny Skogberg
# 4  The code I'm using is this one \n\nbackground:...        user2141649
#
#                               question_user_page  \
# 0  https://magento.stackexchange.com/users/16572
# 1               https://superuser.com/users/3248
# 2           https://mathoverflow.net/users/25511
# 3        https://ux.stackexchange.com/users/4679
# 4        https://stackoverflow.com/users/2141649
#
#                                               answer   answer_user_name  \
# 0  Since the third item is fixed, you can use sho...  Fabian Schmengler
# 1  You likely have the router plugged in to the m...             John T
# 2  A very partial answer: by the results of Richa...         Igor Rivin
# 3  Isn’t the FAQ label obsolete by now? \n\nI'd s...        Solracnapod
# 4  &lt;!DOCTYPE html&gt;\n&lt;html&gt;\n&lt;head&...           akkimads
#
#                               answer_user_page  \
# 0  https://magento.stackexchange.com/users/243
# 1             https://superuser.com/users/1931
# 2         https://mathoverflow.net/users/11142
# 3     https://ux.stackexchange.com/users/13153
# 4      https://stackoverflow.com/users/2375373
#
#                                                  url       category  ...  \
# 0  http://magento.stackexchange.com/questions/668...     TECHNOLOGY  ...
# 1               http://superuser.com/questions/87212     TECHNOLOGY  ...
# 2           http://mathoverflow.net/questions/203422        SCIENCE  ...
# 3  http://ux.stackexchange.com/questions/18600/is...     TECHNOLOGY  ...
# 4  http://stackoverflow.com/questions/16359492/ch...  STACKOVERFLOW  ...
#
#   answer_helpful  answer_level_of_information  answer_plausible  \
# 0       0.888889                     0.666667               1.0
# 1       1.000000                     0.666667               1.0
# 2       0.888889                     0.333333               1.0
# 3       0.888889                     0.666667               1.0
# 4       0.888889                     0.500000               1.0
#
#    answer_relevance  answer_satisfaction  answer_type_instructions  \
# 0               1.0             0.933333                  1.000000
# 1               1.0             0.866667                  0.666667
# 2               1.0             0.700000                  0.333333
# 3               1.0             0.933333                  0.000000
# 4               1.0             0.800000                  1.000000
#
#    answer_type_procedure  answer_type_reason_explanation  answer_well_written  \
# 0               0.000000                        0.333333             0.888889
# 1               0.000000                        1.000000             1.000000
# 2               0.333333                        1.000000             0.888889
# 3               0.000000                        0.666667             1.000000
# 4               0.000000                        0.000000             0.777778
#
#      set
# 0  train
# 1  train
# 2  train
# 3  train
# 4  train
#
# [5 rows x 42 columns]

# %%
question_target_cols = ['question_asker_intent_understanding','question_body_critical', 'question_conversational', 
                        'question_expect_short_answer', 'question_fact_seeking', 'question_has_commonly_accepted_answer',
                        'question_interestingness_others', 'question_interestingness_self', 'question_multi_intent', 
                        'question_not_really_a_question', 'question_opinion_seeking', 'question_type_choice',
                        'question_type_compare', 'question_type_consequence', 'question_type_definition', 
                        'question_type_entity', 'question_type_instructions', 'question_type_procedure',
                        'question_type_reason_explanation', 'question_type_spelling', 'question_well_written']
answer_target_cols = ['answer_helpful', 'answer_level_of_information', 'answer_plausible', 'answer_relevance',
                      'answer_satisfaction', 'answer_type_instructions', 'answer_type_procedure', 
                      'answer_type_reason_explanation', 'answer_well_written']
target_cols = question_target_cols + answer_target_cols

# %% [markdown]
# ## Pre-process data

# %%
text_features = ['question_title', 'question_body', 'answer']
text_features_uncased = ['question_title_uncased', 'question_body_uncased', 'answer_uncased']


for feature in text_features:
    # Map contractions
    train[feature] = train[feature].apply(lambda x: map_contraction(x))
    validation[feature] = validation[feature].apply(lambda x: map_contraction(x))
    test[feature] = test[feature].apply(lambda x: map_contraction(x))
    # Trim text
    train[feature] = train[feature].apply(lambda x: x.strip())
    validation[feature] = validation[feature].apply(lambda x: x.strip())
    test[feature] = test[feature].apply(lambda x: x.strip())

for feature in text_features:
    train[feature + '_uncased'] = train[feature]
    validation[feature + '_uncased'] = validation[feature]
    test[feature + '_uncased'] = test[feature]

for feature in text_features:
    # Lower
    train[feature] = train[feature].apply(lambda x: x.lower())
    validation[feature] = validation[feature].apply(lambda x: x.lower())
    test[feature] = test[feature].apply(lambda x: x.lower())

# %% [markdown]
# # Model parameters

# %%
EPOCHS = 50
BATCH_SIZE = 32
LEARNING_RATE = 3e-4
EMBEDDDING_SIZE = 512
N_CLASS = len(target_cols)
ES_PATIENCE = 5
RLROP_PATIENCE = 2
DECAY_DROP = 0.3
MAX_FEATURES = 10000
TITLE_MAX_LEN = 30
BODY_MAX_LEN = 200
ANSWER_MAX_LEN = 200

# %%
tokenizer = Tokenizer(num_words=MAX_FEATURES)

tokenizer.fit_on_texts(list(train['question_title_uncased']) + list(validation['question_title_uncased']) + list(test['question_title_uncased']) +
                       list(train['question_body_uncased']) + list(validation['question_body_uncased']) + list(test['question_body_uncased']) +
                       list(train['answer_uncased']) + list(validation['answer_uncased']) + list(test['answer_uncased']))

# %% [markdown]
# ## Train/validation sets

# %%
# Train features
# X_train_title = train['question_title']
# X_train_body = train['question_body']
# X_train_answer = train['answer']
X_train_title_seq = train['question_title_uncased']
X_train_body_seq = train['question_body_uncased']
X_train_answer_seq = train['answer_uncased']

# Tokenize the sentences
X_train_title_seq = tokenizer.texts_to_sequences(X_train_title_seq)
X_train_body_seq = tokenizer.texts_to_sequences(X_train_body_seq)
X_train_answer_seq = tokenizer.texts_to_sequences(X_train_answer_seq)

# Pad the sentences
X_train_title_seq = pad_sequences(X_train_title_seq, maxlen=TITLE_MAX_LEN)
X_train_body_seq = pad_sequences(X_train_body_seq, maxlen=BODY_MAX_LEN)
X_train_answer_seq = pad_sequences(X_train_answer_seq, maxlen=ANSWER_MAX_LEN)


X_train = [X_train_title_seq, X_train_body_seq, X_train_answer_seq]
Y_train = train[target_cols].values

# Validation features
# X_valid_title = validation['question_title']
# X_valid_body = validation['question_body']
# X_valid_answer = validation['answer']
X_valid_title_seq = validation['question_title_uncased']
X_valid_body_seq = validation['question_body_uncased']
X_valid_answer_seq = validation['answer_uncased']

# Tokenize the sentences
X_valid_title_seq = tokenizer.texts_to_sequences(X_valid_title_seq)
X_valid_body_seq = tokenizer.texts_to_sequences(X_valid_body_seq)
X_valid_answer_seq = tokenizer.texts_to_sequences(X_valid_answer_seq)

# Pad the sentences
X_valid_title_seq = pad_sequences(X_valid_title_seq, maxlen=TITLE_MAX_LEN)
X_valid_body_seq = pad_sequences(X_valid_body_seq, maxlen=BODY_MAX_LEN)
X_valid_answer_seq = pad_sequences(X_valid_answer_seq, maxlen=ANSWER_MAX_LEN)

X_valid = [X_valid_title_seq, X_valid_body_seq, X_valid_answer_seq]
Y_valid = validation[target_cols].values


print('Train samples: %d' % len(Y_train))
print('Validation samples: %d' % len(Y_valid))
# Out:
# Train samples: 4863
# Validation samples: 1216

# %% [markdown]
# # Model

# %%
use_embed = hub.load(module_url)

def USEEmbedding(x):
    return use_embed(tf.squeeze(tf.cast(x, tf.string)))

def encoder_block(input_layer):
    encoder = Lambda(USEEmbedding, output_shape=(EMBEDDDING_SIZE,))(input_layer)
    
    return encoder

# %% [markdown]
# ## Load embedding

# %%
glove_embedding_matrix, glove_unknown_words = build_matrix(tokenizer.word_index, encoder_path, MAX_FEATURES)
print('n unknown words (GloVe): ', len(glove_unknown_words))
# Out:
# n unknown words (GloVe):  685

# %%
# Title sequence
input_title_seq = Input(shape=(TITLE_MAX_LEN,), dtype=tf.float32, name='input_title_seq')
title = Embedding(*glove_embedding_matrix.shape, weights=[glove_embedding_matrix], trainable=False)(input_title_seq)
title = LSTM(128, kernel_initializer='lecun_normal', recurrent_dropout=0.5, return_sequences=True)(title)
title_out = LSTM(64, kernel_initializer='lecun_normal', recurrent_dropout=0.5, return_sequences=False)(title)
# title_out = GlobalAveragePooling1D()(title)

# Body sequence
input_body_seq = Input(shape=(BODY_MAX_LEN,), dtype=tf.float32, name='input_body_seq')
body = Embedding(*glove_embedding_matrix.shape, weights=[glove_embedding_matrix], trainable=False)(input_body_seq)
body = LSTM(128, kernel_initializer='lecun_normal', recurrent_dropout=0.5, return_sequences=True)(body)
body_out = LSTM(64, kernel_initializer='lecun_normal', recurrent_dropout=0.5, return_sequences=False)(body)
# body_out = GlobalAveragePooling1D()(body)

# Answer sequence
input_answer_seq = Input(shape=(ANSWER_MAX_LEN,), dtype=tf.float32, name='input_answer_seq')
answer = Embedding(*glove_embedding_matrix.shape, weights=[glove_embedding_matrix], trainable=False)(input_answer_seq)
answer = LSTM(128, kernel_initializer='lecun_normal', recurrent_dropout=0.5, return_sequences=True)(answer)
answer_out = LSTM(64, kernel_initializer='lecun_normal', recurrent_dropout=0.5, return_sequences=False)(answer)
# answer_out = GlobalAveragePooling1D()(answer)


# Output
x = Concatenate()([title_out, body_out, answer_out])
x = Dropout(0.5)(x)
x = Dense(512, activation='relu', kernel_initializer='lecun_normal')(x)
x = Dropout(0.5)(x)
output = Dense(N_CLASS, activation='sigmoid', kernel_initializer='lecun_normal', name='output')(x)
model = Model(inputs=[input_title_seq, input_body_seq, input_answer_seq], outputs=[output])

model.summary()
# Out:
# Model: "model"
# __________________________________________________________________________________________________
# Layer (type)                    Output Shape         Param #     Connected to
# ==================================================================================================
# input_title_seq (InputLayer)    [(None, 30)]         0
# __________________________________________________________________________________________________
# input_body_seq (InputLayer)     [(None, 200)]        0
# __________________________________________________________________________________________________
# input_answer_seq (InputLayer)   [(None, 200)]        0
# __________________________________________________________________________________________________
# embedding (Embedding)           (None, 30, 300)      17424600    input_title_seq[0][0]
# __________________________________________________________________________________________________
# embedding_1 (Embedding)         (None, 200, 300)     17424600    input_body_seq[0][0]
# __________________________________________________________________________________________________
# embedding_2 (Embedding)         (None, 200, 300)     17424600    input_answer_seq[0][0]
# __________________________________________________________________________________________________
# lstm (LSTM)                     (None, 30, 128)      219648      embedding[0][0]
# __________________________________________________________________________________________________
# lstm_2 (LSTM)                   (None, 200, 128)     219648      embedding_1[0][0]
# __________________________________________________________________________________________________
# lstm_4 (LSTM)                   (None, 200, 128)     219648      embedding_2[0][0]
# __________________________________________________________________________________________________
# lstm_1 (LSTM)                   (None, 64)           49408       lstm[0][0]
# __________________________________________________________________________________________________
# lstm_3 (LSTM)                   (None, 64)           49408       lstm_2[0][0]
# __________________________________________________________________________________________________
# lstm_5 (LSTM)                   (None, 64)           49408       lstm_4[0][0]
# __________________________________________________________________________________________________
# concatenate (Concatenate)       (None, 192)          0           lstm_1[0][0]
#                                                                  lstm_3[0][0]
#                                                                  lstm_5[0][0]
# __________________________________________________________________________________________________
# dropout (Dropout)               (None, 192)          0           concatenate[0][0]
# __________________________________________________________________________________________________
# dense (Dense)                   (None, 512)          98816       dropout[0][0]
# __________________________________________________________________________________________________
# dropout_1 (Dropout)             (None, 512)          0           dense[0][0]
# __________________________________________________________________________________________________
# output (Dense)                  (None, 30)           15390       dropout_1[0][0]
# ==================================================================================================
# Total params: 53,195,174
# Trainable params: 921,374
# Non-trainable params: 52,273,800
# __________________________________________________________________________________________________

# %% [markdown]
# # Train model

# %%
rlrop = ReduceLROnPlateau(monitor='val_loss', mode='min', patience=RLROP_PATIENCE, factor=DECAY_DROP, min_lr=1e-7, verbose=1)
spearmanCallback = SpearmanRhoCallback(training_data=(X_train, Y_train), validation_data=(X_valid, Y_valid), monitor='val_loss', mode='min', patience=ES_PATIENCE)
callback_list = [rlrop, spearmanCallback]

optimizer = optimizers.Adam(LEARNING_RATE)
model.compile(optimizer=optimizer, loss='binary_crossentropy')

history = model.fit(X_train, Y_train, 
                    validation_data=(X_valid, Y_valid), 
                    callbacks=callback_list, 
                    batch_size=BATCH_SIZE, 
                    epochs=EPOCHS, 
                    verbose=2).history
# Out:
# Train on 4863 samples, validate on 1216 samples
# Epoch 1/50
# spearman-rho: 0.1785 val_spearman-rho: 0.1685
# 4863/4863 - 245s - loss: 0.4676 - val_loss: 0.4195
# Epoch 2/50
# spearman-rho: 0.2329 val_spearman-rho: 0.2191
# 4863/4863 - 226s - loss: 0.4200 - val_loss: 0.4080
# Epoch 3/50
# spearman-rho: 0.2591 val_spearman-rho: 0.2393
# 4863/4863 - 228s - loss: 0.4105 - val_loss: 0.4044
# Epoch 4/50
# spearman-rho: 0.2769 val_spearman-rho: 0.2534
# 4863/4863 - 222s - loss: 0.4055 - val_loss: 0.4017
# Epoch 5/50
# spearman-rho: 0.2898 val_spearman-rho: 0.2613
# 4863/4863 - 228s - loss: 0.4015 - val_loss: 0.3989
# Epoch 6/50
# spearman-rho: 0.3019 val_spearman-rho: 0.2660
# 4863/4863 - 227s - loss: 0.3987 - val_loss: 0.3972
# Epoch 7/50
# spearman-rho: 0.3105 val_spearman-rho: 0.2710
# 4863/4863 - 222s - loss: 0.3956 - val_loss: 0.3963
# Epoch 8/50
# spearman-rho: 0.3209 val_spearman-rho: 0.2757
# 4863/4863 - 216s - loss: 0.3935 - val_loss: 0.3945
# Epoch 9/50
# spearman-rho: 0.3311 val_spearman-rho: 0.2817
# 4863/4863 - 219s - loss: 0.3910 - val_loss: 0.3937
# Epoch 10/50
# spearman-rho: 0.3389 val_spearman-rho: 0.2851
# 4863/4863 - 223s - loss: 0.3887 - val_loss: 0.3919
# Epoch 11/50
# spearman-rho: 0.3457 val_spearman-rho: 0.2860
# 4863/4863 - 224s - loss: 0.3868 - val_loss: 0.3916
# Epoch 12/50
# spearman-rho: 0.3573 val_spearman-rho: 0.2906
# 4863/4863 - 215s - loss: 0.3847 - val_loss: 0.3934
# Epoch 13/50
# spearman-rho: 0.3655 val_spearman-rho: 0.2955
# 4863/4863 - 218s - loss: 0.3826 - val_loss: 0.3912
# Epoch 14/50
# spearman-rho: 0.3744 val_spearman-rho: 0.3015
# 4863/4863 - 225s - loss: 0.3807 - val_loss: 0.3891
# Epoch 15/50
# spearman-rho: 0.3836 val_spearman-rho: 0.3012
# 4863/4863 - 229s - loss: 0.3784 - val_loss: 0.3888
# Epoch 16/50
# spearman-rho: 0.3915 val_spearman-rho: 0.3063
# 4863/4863 - 229s - loss: 0.3768 - val_loss: 0.3883
# Epoch 17/50
# spearman-rho: 0.3992 val_spearman-rho: 0.3093
# 4863/4863 - 226s - loss: 0.3748 - val_loss: 0.3866
# Epoch 18/50
# spearman-rho: 0.4069 val_spearman-rho: 0.3149
# 4863/4863 - 221s - loss: 0.3730 - val_loss: 0.3861
# Epoch 19/50
# spearman-rho: 0.4145 val_spearman-rho: 0.3140
# 4863/4863 - 223s - loss: 0.3714 - val_loss: 0.3875
# Epoch 20/50
#
# Epoch 00020: ReduceLROnPlateau reducing learning rate to 9.000000427477062e-05.
# spearman-rho: 0.4190 val_spearman-rho: 0.3173
# 4863/4863 - 227s - loss: 0.3701 - val_loss: 0.3868
# Epoch 21/50
# spearman-rho: 0.4247 val_spearman-rho: 0.3199
# 4863/4863 - 228s - loss: 0.3670 - val_loss: 0.3858
# Epoch 22/50
# spearman-rho: 0.4264 val_spearman-rho: 0.3183
# 4863/4863 - 225s - loss: 0.3663 - val_loss: 0.3864
# Epoch 23/50
#
# Epoch 00023: ReduceLROnPlateau reducing learning rate to 2.700000040931627e-05.
# spearman-rho: 0.4290 val_spearman-rho: 0.3200
# Epoch 00022: early stopping
# 4863/4863 - 225s - loss: 0.3653 - val_loss: 0.3861

# %% [markdown]
# ## Model loss graph

# %%
sns.set(style="whitegrid")
plot_metrics(history, metric_list=['loss', 'spearman'])

# %% [markdown]
# # Evaluation

# %%
preds_train = model.predict(X_train)
preds_val = model.predict(X_valid)

display(get_metrics(Y_train, preds_train, Y_valid, preds_val, target_cols).style.applymap(color_map))
# Out:
# <style  type="text/css" >
#     #T_6c7f9cd0_29cd_11ea_8676_7f7bd7d19863row0_col0 {
#             color:  black;
#         }    #T_6c7f9cd0_29cd_11ea_8676_7f7bd7d19863row0_col1 {
#             color:  black;
#         }    #T_6c7f9cd0_29cd_11ea_8676_7f7bd7d19863row0_col2 {
#             color:  black;
#         }    #T_6c7f9cd0_29cd_11ea_8676_7f7bd7d19863row1_col0 {
#             color:  black;
#         }    #T_6c7f9cd0_29cd_11ea_8676_7f7bd7d19863row1_col1 {
#             color:  black;
#         }    #T_6c7f9cd0_29cd_11ea_8676_7f7bd7d19863row1_col2 {
#             color:  black;
#         }    #T_6c7f9cd0_29cd_11ea_8676_7f7bd7d19863row2_col0 {
#             color:  black;
#         }    #T_6c7f9cd0_29cd_11ea_8676_7f7bd7d19863row2_col1 {
#             color:  black;
#         }    #T_6c7f9cd0_29cd_11ea_8676_7f7bd7d19863row2_col2 {
#             color:  black;
#         }    #T_6c7f9cd0_29cd_11ea_8676_7f7bd7d19863row3_col0 {
#             color:  black;
#         }    #T_6c7f9cd0_29cd_11ea_8676_7f7bd7d19863row3_col1 {
#             color:  black;
#         }    #T_6c7f9cd0_29cd_11ea_8676_7f7bd7d19863row3_col2 {
#             color:  black;
#         }    #T_6c7f9cd0_29cd_11ea_8676_7f7bd7d19863row4_col0 {
#             color:  black;
#         }    #T_6c7f9cd0_29cd_11ea_8676_7f7bd7d19863row4_col1 {
#             color:  black;
#         }    #T_6c7f9cd0_29cd_11ea_8676_7f7bd7d19863row4_col2 {
#             color:  orange;
#         }    #T_6c7f9cd0_29cd_11ea_8676_7f7bd7d19863row5_col0 {
#             color:  black;
#         }    #T_6c7f9cd0_29cd_11ea_8676_7f7bd7d19863row5_col1 {
#             color:  black;
#         }    #T_6c7f9cd0_29cd_11ea_8676_7f7bd7d19863row5_col2 {
#             color:  orange;
#         }    #T_6c7f9cd0_29cd_11ea_8676_7f7bd7d19863row6_col0 {
#             color:  black;
#         }    #T_6c7f9cd0_29cd_11ea_8676_7f7bd7d19863row6_col1 {
#             color:  black;
#         }    #T_6c7f9cd0_29cd_11ea_8676_7f7bd7d19863row6_col2 {
#             color:  black;
#         }    #T_6c7f9cd0_29cd_11ea_8676_7f7bd7d19863row7_col0 {
#             color:  black;
#         }    #T_6c7f9cd0_29cd_11ea_8676_7f7bd7d19863row7_col1 {
#             color:  black;
#         }    #T_6c7f9cd0_29cd_11ea_8676_7f7bd7d19863row7_col2 {
#             color:  black;
#         }    #T_6c7f9cd0_29cd_11ea_8676_7f7bd7d19863row8_col0 {
#             color:  black;
#         }    #T_6c7f9cd0_29cd_11ea_8676_7f7bd7d19863row8_col1 {
#             color:  black;
#         }    #T_6c7f9cd0_29cd_11ea_8676_7f7bd7d19863row8_col2 {
#             color:  black;
#         }    #T_6c7f9cd0_29cd_11ea_8676_7f7bd7d19863row9_col0 {
#             color:  black;
#         }    #T_6c7f9cd0_29cd_11ea_8676_7f7bd7d19863row9_col1 {
#             color:  black;
#         }    #T_6c7f9cd0_29cd_11ea_8676_7f7bd7d19863row9_col2 {
#             color:  black;
#         }    #T_6c7f9cd0_29cd_11ea_8676_7f7bd7d19863row10_col0 {
#             color:  black;
#         }    #T_6c7f9cd0_29cd_11ea_8676_7f7bd7d19863row10_col1 {
#             color:  orange;
#         }    #T_6c7f9cd0_29cd_11ea_8676_7f7bd7d19863row10_col2 {
#             color:  purple;
#         }    #T_6c7f9cd0_29cd_11ea_8676_7f7bd7d19863row11_col0 {
#             color:  black;
#         }    #T_6c7f9cd0_29cd_11ea_8676_7f7bd7d19863row11_col1 {
#             color:  black;
#         }    #T_6c7f9cd0_29cd_11ea_8676_7f7bd7d19863row11_col2 {
#             color:  black;
#         }    #T_6c7f9cd0_29cd_11ea_8676_7f7bd7d19863row12_col0 {
#             color:  black;
#         }    #T_6c7f9cd0_29cd_11ea_8676_7f7bd7d19863row12_col1 {
#             color:  black;
#         }    #T_6c7f9cd0_29cd_11ea_8676_7f7bd7d19863row12_col2 {
#             color:  black;
#         }    #T_6c7f9cd0_29cd_11ea_8676_7f7bd7d19863row13_col0 {
#             color:  black;
#         }    #T_6c7f9cd0_29cd_11ea_8676_7f7bd7d19863row13_col1 {
#             color:  black;
#         }    #T_6c7f9cd0_29cd_11ea_8676_7f7bd7d19863row13_col2 {
#             color:  orange;
#         }    #T_6c7f9cd0_29cd_11ea_8676_7f7bd7d19863row14_col0 {
#             color:  black;
#         }    #T_6c7f9cd0_29cd_11ea_8676_7f7bd7d19863row14_col1 {
#             color:  orange;
#         }    #T_6c7f9cd0_29cd_11ea_8676_7f7bd7d19863row14_col2 {
#             color:  orange;
#         }    #T_6c7f9cd0_29cd_11ea_8676_7f7bd7d19863row15_col0 {
#             color:  black;
#         }    #T_6c7f9cd0_29cd_11ea_8676_7f7bd7d19863row15_col1 {
#             color:  black;
#         }    #T_6c7f9cd0_29cd_11ea_8676_7f7bd7d19863row15_col2 {
#             color:  orange;
#         }    #T_6c7f9cd0_29cd_11ea_8676_7f7bd7d19863row16_col0 {
#             color:  black;
#         }    #T_6c7f9cd0_29cd_11ea_8676_7f7bd7d19863row16_col1 {
#             color:  black;
#         }    #T_6c7f9cd0_29cd_11ea_8676_7f7bd7d19863row16_col2 {
#             color:  black;
#         }    #T_6c7f9cd0_29cd_11ea_8676_7f7bd7d19863row17_col0 {
#             color:  black;
#         }    #T_6c7f9cd0_29cd_11ea_8676_7f7bd7d19863row17_col1 {
#             color:  green;
#         }    #T_6c7f9cd0_29cd_11ea_8676_7f7bd7d19863row17_col2 {
#             color:  black;
#         }    #T_6c7f9cd0_29cd_11ea_8676_7f7bd7d19863row18_col0 {
#             color:  black;
#         }    #T_6c7f9cd0_29cd_11ea_8676_7f7bd7d19863row18_col1 {
#             color:  black;
#         }    #T_6c7f9cd0_29cd_11ea_8676_7f7bd7d19863row18_col2 {
#             color:  orange;
#         }    #T_6c7f9cd0_29cd_11ea_8676_7f7bd7d19863row19_col0 {
#             color:  black;
#         }    #T_6c7f9cd0_29cd_11ea_8676_7f7bd7d19863row19_col1 {
#             color:  black;
#         }    #T_6c7f9cd0_29cd_11ea_8676_7f7bd7d19863row19_col2 {
#             color:  black;
#         }    #T_6c7f9cd0_29cd_11ea_8676_7f7bd7d19863row20_col0 {
#             color:  black;
#         }    #T_6c7f9cd0_29cd_11ea_8676_7f7bd7d19863row20_col1 {
#             color:  purple;
#         }    #T_6c7f9cd0_29cd_11ea_8676_7f7bd7d19863row20_col2 {
#             color:  purple;
#         }    #T_6c7f9cd0_29cd_11ea_8676_7f7bd7d19863row21_col0 {
#             color:  black;
#         }    #T_6c7f9cd0_29cd_11ea_8676_7f7bd7d19863row21_col1 {
#             color:  black;
#         }    #T_6c7f9cd0_29cd_11ea_8676_7f7bd7d19863row21_col2 {
#             color:  black;
#         }    #T_6c7f9cd0_29cd_11ea_8676_7f7bd7d19863row22_col0 {
#             color:  black;
#         }    #T_6c7f9cd0_29cd_11ea_8676_7f7bd7d19863row22_col1 {
#             color:  orange;
#         }    #T_6c7f9cd0_29cd_11ea_8676_7f7bd7d19863row22_col2 {
#             color:  purple;
#         }    #T_6c7f9cd0_29cd_11ea_8676_7f7bd7d19863row23_col0 {
#             color:  black;
#         }    #T_6c7f9cd0_29cd_11ea_8676_7f7bd7d19863row23_col1 {
#             color:  orange;
#         }    #T_6c7f9cd0_29cd_11ea_8676_7f7bd7d19863row23_col2 {
#             color:  orange;
#         }    #T_6c7f9cd0_29cd_11ea_8676_7f7bd7d19863row24_col0 {
#             color:  black;
#         }    #T_6c7f9cd0_29cd_11ea_8676_7f7bd7d19863row24_col1 {
#             color:  orange;
#         }    #T_6c7f9cd0_29cd_11ea_8676_7f7bd7d19863row24_col2 {
#             color:  purple;
#         }    #T_6c7f9cd0_29cd_11ea_8676_7f7bd7d19863row25_col0 {
#             color:  black;
#         }    #T_6c7f9cd0_29cd_11ea_8676_7f7bd7d19863row25_col1 {
#             color:  orange;
#         }    #T_6c7f9cd0_29cd_11ea_8676_7f7bd7d19863row25_col2 {
#             color:  purple;
#         }    #T_6c7f9cd0_29cd_11ea_8676_7f7bd7d19863row26_col0 {
#             color:  black;
#         }    #T_6c7f9cd0_29cd_11ea_8676_7f7bd7d19863row26_col1 {
#             color:  orange;
#         }    #T_6c7f9cd0_29cd_11ea_8676_7f7bd7d19863row26_col2 {
#             color:  orange;
#         }    #T_6c7f9cd0_29cd_11ea_8676_7f7bd7d19863row27_col0 {
#             color:  black;
#         }    #T_6c7f9cd0_29cd_11ea_8676_7f7bd7d19863row27_col1 {
#             color:  green;
#         }    #T_6c7f9cd0_29cd_11ea_8676_7f7bd7d19863row27_col2 {
#             color:  black;
#         }    #T_6c7f9cd0_29cd_11ea_8676_7f7bd7d19863row28_col0 {
#             color:  black;
#         }    #T_6c7f9cd0_29cd_11ea_8676_7f7bd7d19863row28_col1 {
#             color:  black;
#         }    #T_6c7f9cd0_29cd_11ea_8676_7f7bd7d19863row28_col2 {
#             col

# %% [markdown]
# ## By category

# %%
target_cols_preds = [col+'_pred' for col in target_cols]
for col in target_cols_preds:
    train[col] = 0
    validation[col] = 0
    
train[target_cols_preds] = preds_train
validation[target_cols_preds] = preds_val
    
display(get_metrics_category(train, validation, target_cols, target_cols_preds, 'category').style.applymap(color_map))
# Out:
# <style  type="text/css" >
#     #T_6cdd06e0_29cd_11ea_8676_7f7bd7d19863row0_col0 {
#             color:  black;
#         }    #T_6cdd06e0_29cd_11ea_8676_7f7bd7d19863row0_col1 {
#             color:  black;
#         }    #T_6cdd06e0_29cd_11ea_8676_7f7bd7d19863row0_col2 {
#             color:  orange;
#         }    #T_6cdd06e0_29cd_11ea_8676_7f7bd7d19863row0_col3 {
#             color:  black;
#         }    #T_6cdd06e0_29cd_11ea_8676_7f7bd7d19863row0_col4 {
#             color:  orange;
#         }    #T_6cdd06e0_29cd_11ea_8676_7f7bd7d19863row0_col5 {
#             color:  black;
#         }    #T_6cdd06e0_29cd_11ea_8676_7f7bd7d19863row0_col6 {
#             color:  orange;
#         }    #T_6cdd06e0_29cd_11ea_8676_7f7bd7d19863row0_col7 {
#             color:  black;
#         }    #T_6cdd06e0_29cd_11ea_8676_7f7bd7d19863row0_col8 {
#             color:  black;
#         }    #T_6cdd06e0_29cd_11ea_8676_7f7bd7d19863row0_col9 {
#             color:  black;
#         }    #T_6cdd06e0_29cd_11ea_8676_7f7bd7d19863row0_col10 {
#             color:  black;
#         }</style><table id="T_6cdd06e0_29cd_11ea_8676_7f7bd7d19863" ><thead>    <tr>        <th class="blank level0" ></th>        <th class="col_heading level0 col0" >Label</th>        <th class="col_heading level0 col1" >Train (TECHNOLOGY)</th>        <th class="col_heading level0 col2" >Validation (TECHNOLOGY)</th>        <th class="col_heading level0 col3" >Train (SCIENCE)</th>        <th class="col_heading level0 col4" >Validation (SCIENCE)</th>        <th class="col_heading level0 col5" >Train (STACKOVERFLOW)</th>        <th class="col_heading level0 col6" >Validation (STACKOVERFLOW)</th>        <th class="col_heading level0 col7" >Train (LIFE_ARTS)</th>        <th class="col_heading level0 col8" >Validation (LIFE_ARTS)</th>        <th class="col_heading level0 col9" >Train (CULTURE)</th>        <th class="col_heading level0 col10" >Validation (CULTURE)</th>    </tr></thead><tbody>
#                 <tr>
#                         <th id="T_6cdd06e0_29cd_11ea_8676_7f7bd7d19863level0_row0" class="row_heading level0 row0" >0</th>
#                         <td id="T_6cdd06e0_29cd_11ea_8676_7f7bd7d19863row0_col0" class="data row0 col0" >Averaged</td>
#                         <td id="T_6cdd06e0_29cd_11ea_8676_7f7bd7d19863row0_col1" class="data row0 col1" >0.396</td>
#                         <td id="T_6cdd06e0_29cd_11ea_8676_7f7bd7d19863row0_col2" class="data row0 col2" >0.281</td>
#                         <td id="T_6cdd06e0_29cd_11ea_8676_7f7bd7d19863row0_col3" class="data row0 col3" >0.446</td>
#                         <td id="T_6cdd06e0_29cd_11ea_8676_7f7bd7d19863row0_col4" class="data row0 col4" >0.287</td>
#                         <td id="T_6cdd06e0_29cd_11ea_8676_7f7bd7d19863row0_col5" class="data row0 col5" >0.325</td>
#                         <td id="T_6cdd06e0_29cd_11ea_8676_7f7bd7d19863row0_col6" class="data row0 col6" >0.165</td>
#                         <td id="T_6cdd06e0_29cd_11ea_8676_7f7bd7d19863row0_col7" class="data row0 col7" >0.427</td>
#                         <td id="T_6cdd06e0_29cd_11ea_8676_7f7bd7d19863row0_col8" class="data row0 col8" >0.33</td>
#                         <td id="T_6cdd06e0_29cd_11ea_8676_7f7bd7d19863row0_col9" class="data row0 col9" >0.421</td>
#                         <td id="T_6cdd06e0_29cd_11ea_8676_7f7bd7d19863row0_col10" class="data row0 col10" >0.315</td>
#             </tr>
#     </tbody></table>

# %% [markdown]
# #### Save model weights and ecoders

# %%
model.save_weights(model_path)
dump(tokenizer, tokenizer_path)
# Out:
# ['/kaggle/working/tokenizer.joblib']
