# %% [markdown]
# ## Dependencies

# %%
import re
import warnings
from joblib import dump
import tensorflow_hub as hub
from tensorflow.keras import Model, optimizers
from tensorflow.keras.callbacks import ReduceLROnPlateau
from tensorflow.keras.layers import Lambda, Input, Dense, Dropout, Concatenate, BatchNormalization, Activation, Average, Add, Reshape, GlobalAveragePooling1D, Embedding, LSTM, Conv1D, SpatialDropout1D, Bidirectional
from googleqa_utilityscript import *


SEED = 0
seed_everything(SEED)
warnings.filterwarnings("ignore")

# %% [markdown]
# ## Load data

# %%
module_url = '/kaggle/input/universalsentenceencodermodels/universal-sentence-encoder-models/use'
encoder_url = '/kaggle/input/tf2-ecoder-models/Wiki-words-500'
model_path = '/kaggle/working/use.h5'

hold_out = pd.read_csv('/kaggle/input/googleqa-mldataset/hold-out.csv')
test = pd.read_csv('/kaggle/input/google-quest-challenge/test.csv')
train = hold_out[hold_out['set'] == 'train']
validation = hold_out[hold_out['set'] == 'validation']

print('Train samples: %s' % len(train))
print('Validation samples: %s' % len(validation))
display(train.head())
# Out:
# Train samples: 4863
# Validation samples: 1216
#    qa_id                                     question_title  \
# 0   3895  Magento (1.7) Bundled Product with FREE Produc...
# 1   3131                             Find router on network
# 2   1507  Negatively curved metrics minimizing the lengt...
# 3   6784               Isn’t the FAQ label obsolete by now?
# 4   2135  Changing background image one time on responsi...
#
#                                        question_body question_user_name  \
# 0  I'm looking to create a bundle offer where cus...                Joe
# 1  I've just bought a Belkin N+ Wireless Router. ...                Guy
# 2  Good afternoon everyone !\n\nI have the follow...            Selim G
# 3  Don’t get me wrong in the beginning of reading...     Benny Skogberg
# 4  The code I'm using is this one \n\nbackground:...        user2141649
#
#                               question_user_page  \
# 0  https://magento.stackexchange.com/users/16572
# 1               https://superuser.com/users/3248
# 2           https://mathoverflow.net/users/25511
# 3        https://ux.stackexchange.com/users/4679
# 4        https://stackoverflow.com/users/2141649
#
#                                               answer   answer_user_name  \
# 0  Since the third item is fixed, you can use sho...  Fabian Schmengler
# 1  You likely have the router plugged in to the m...             John T
# 2  A very partial answer: by the results of Richa...         Igor Rivin
# 3  Isn’t the FAQ label obsolete by now? \n\nI'd s...        Solracnapod
# 4  &lt;!DOCTYPE html&gt;\n&lt;html&gt;\n&lt;head&...           akkimads
#
#                               answer_user_page  \
# 0  https://magento.stackexchange.com/users/243
# 1             https://superuser.com/users/1931
# 2         https://mathoverflow.net/users/11142
# 3     https://ux.stackexchange.com/users/13153
# 4      https://stackoverflow.com/users/2375373
#
#                                                  url       category  ...  \
# 0  http://magento.stackexchange.com/questions/668...     TECHNOLOGY  ...
# 1               http://superuser.com/questions/87212     TECHNOLOGY  ...
# 2           http://mathoverflow.net/questions/203422        SCIENCE  ...
# 3  http://ux.stackexchange.com/questions/18600/is...     TECHNOLOGY  ...
# 4  http://stackoverflow.com/questions/16359492/ch...  STACKOVERFLOW  ...
#
#   answer_helpful  answer_level_of_information  answer_plausible  \
# 0       0.888889                     0.666667               1.0
# 1       1.000000                     0.666667               1.0
# 2       0.888889                     0.333333               1.0
# 3       0.888889                     0.666667               1.0
# 4       0.888889                     0.500000               1.0
#
#    answer_relevance  answer_satisfaction  answer_type_instructions  \
# 0               1.0             0.933333                  1.000000
# 1               1.0             0.866667                  0.666667
# 2               1.0             0.700000                  0.333333
# 3               1.0             0.933333                  0.000000
# 4               1.0             0.800000                  1.000000
#
#    answer_type_procedure  answer_type_reason_explanation  answer_well_written  \
# 0               0.000000                        0.333333             0.888889
# 1               0.000000                        1.000000             1.000000
# 2               0.333333                        1.000000             0.888889
# 3               0.000000                        0.666667             1.000000
# 4               0.000000                        0.000000             0.777778
#
#      set
# 0  train
# 1  train
# 2  train
# 3  train
# 4  train
#
# [5 rows x 42 columns]

# %%
question_target_cols = ['question_asker_intent_understanding','question_body_critical', 'question_conversational', 
                        'question_expect_short_answer', 'question_fact_seeking', 'question_has_commonly_accepted_answer',
                        'question_interestingness_others', 'question_interestingness_self', 'question_multi_intent', 
                        'question_not_really_a_question', 'question_opinion_seeking', 'question_type_choice',
                        'question_type_compare', 'question_type_consequence', 'question_type_definition', 
                        'question_type_entity', 'question_type_instructions', 'question_type_procedure',
                        'question_type_reason_explanation', 'question_type_spelling', 'question_well_written']
answer_target_cols = ['answer_helpful', 'answer_level_of_information', 'answer_plausible', 'answer_relevance',
                      'answer_satisfaction', 'answer_type_instructions', 'answer_type_procedure', 
                      'answer_type_reason_explanation', 'answer_well_written']
target_cols = question_target_cols + answer_target_cols

# %% [markdown]
# ## Pre-process data

# %%
text_features = ['question_title', 'question_body', 'answer']

for feature in text_features:
    # Lower
    train[feature] = train[feature].apply(lambda x: x.lower())
    validation[feature] = validation[feature].apply(lambda x: x.lower())
    # Map contractions
    train[feature] = train[feature].apply(lambda x: map_contraction(x))
    validation[feature] = validation[feature].apply(lambda x: map_contraction(x))
    # Trim text
    train[feature] = train[feature].apply(lambda x: x.strip())
    validation[feature] = validation[feature].apply(lambda x: x.strip())

# %% [markdown]
# # Model parameters

# %%
EPOCHS = 50
BATCH_SIZE = 32
LEARNING_RATE = 3e-4
EMBEDDDING_SIZE = 512
N_CLASS = len(target_cols)
ES_PATIENCE = 5
RLROP_PATIENCE = 2
DECAY_DROP = 0.3

# %% [markdown]
# ## Train/validation sets

# %%
# Train features
X_train_title = train['question_title']
X_train_body = train['question_body']
X_train_answer = train['answer']

X_train = [X_train_title, X_train_body, X_train_answer, X_train_title, X_train_body, X_train_answer]
Y_train = train[target_cols].values

# Validation features
X_valid_title = validation['question_title']
X_valid_body = validation['question_body']
X_valid_answer = validation['answer']

X_valid = [X_valid_title, X_valid_body, X_valid_answer, X_valid_title, X_valid_body, X_valid_answer]
Y_valid = validation[target_cols].values


print('Train samples: %d' % len(Y_train))
print('Validation samples: %d' % len(Y_valid))
# Out:
# Train samples: 4863
# Validation samples: 1216

# %% [markdown]
# # Model

# %%
use_embed = hub.load(module_url)
enc_embed = hub.load(encoder_url)

def USEEmbedding(x):
    return use_embed(tf.squeeze(tf.cast(x, tf.string)))

def encoder_block(input_layer):
    encoder = Lambda(USEEmbedding, output_shape=(EMBEDDDING_SIZE,))(input_layer)
    
    return encoder

# %%
# Title
input_title = Input(shape=(1,), dtype=tf.string, name='input_title')
encoded_title = encoder_block(input_title)

# Body
input_body = Input(shape=(1,), dtype=tf.string, name='input_body')
encoded_body = encoder_block(input_body)

# Answer
input_answer = Input(shape=(1,), dtype=tf.string, name='input_answer')
encoded_answer = encoder_block(input_answer)

# Title sequence
input_title_enc = Input(shape=(), dtype=tf.string, name='input_enc_title')
title_out = hub.KerasLayer(encoder_url, input_shape=[], dtype=tf.string)(input_title_enc)

# Body sequence
input_body_enc = Input(shape=(), dtype=tf.string, name='input_enc_body')
body_out = hub.KerasLayer(encoder_url, input_shape=[], dtype=tf.string)(input_body_enc)

# Answer sequence
input_answer_enc = Input(shape=(), dtype=tf.string, name='input_enc_answer')
answer_out = hub.KerasLayer(encoder_url, input_shape=[], dtype=tf.string)(input_answer_enc)


# Output
x = Concatenate()([encoded_title, encoded_body, encoded_answer, answer_out, answer_out, answer_out])
x = Dropout(0.5)(x)
x = Dense(512, activation='relu', kernel_initializer='lecun_normal')(x)
x = Dropout(0.5)(x)

output = Dense(N_CLASS, activation='sigmoid', kernel_initializer='lecun_normal', name='output')(x)
model = Model(inputs=[input_title, input_body, input_answer, input_title_enc, input_body_enc, input_answer_enc], outputs=[output])

model.summary()
# Out:
# Model: "model"
# __________________________________________________________________________________________________
# Layer (type)                    Output Shape         Param #     Connected to
# ==================================================================================================
# input_title (InputLayer)        [(None, 1)]          0
# __________________________________________________________________________________________________
# input_body (InputLayer)         [(None, 1)]          0
# __________________________________________________________________________________________________
# input_answer (InputLayer)       [(None, 1)]          0
# __________________________________________________________________________________________________
# input_enc_answer (InputLayer)   [(None,)]            0
# __________________________________________________________________________________________________
# lambda (Lambda)                 (None, 512)          0           input_title[0][0]
# __________________________________________________________________________________________________
# lambda_1 (Lambda)               (None, 512)          0           input_body[0][0]
# __________________________________________________________________________________________________
# lambda_2 (Lambda)               (None, 512)          0           input_answer[0][0]
# __________________________________________________________________________________________________
# keras_layer_2 (KerasLayer)      (None, 500)          504687500   input_enc_answer[0][0]
# __________________________________________________________________________________________________
# concatenate (Concatenate)       (None, 3036)         0           lambda[0][0]
#                                                                  lambda_1[0][0]
#                                                                  lambda_2[0][0]
#                                                                  keras_layer_2[0][0]
#                                                                  keras_layer_2[0][0]
#                                                                  keras_layer_2[0][0]
# __________________________________________________________________________________________________
# dropout (Dropout)               (None, 3036)         0           concatenate[0][0]
# __________________________________________________________________________________________________
# dense (Dense)                   (None, 512)          1554944     dropout[0][0]
# __________________________________________________________________________________________________
# dropout_1 (Dropout)             (None, 512)          0           dense[0][0]
# __________________________________________________________________________________________________
# input_enc_title (InputLayer)    [(None,)]            0
# __________________________________________________________________________________________________
# input_enc_body (InputLayer)     [(None,)]            0
# __________________________________________________________________________________________________
# output (Dense)                  (None, 30)           15390       dropout_1[0][0]
# ==================================================================================================
# Total params: 506,257,834
# Trainable params: 1,570,334
# Non-trainable params: 504,687,500
# __________________________________________________________________________________________________

# %% [markdown]
# # Train model

# %%
rlrop = ReduceLROnPlateau(monitor='val_loss', mode='min', patience=RLROP_PATIENCE, factor=DECAY_DROP, min_lr=1e-7, verbose=1)
spearmanCallback = SpearmanRhoCallback(training_data=(X_train, Y_train), validation_data=(X_valid, Y_valid), monitor='val_loss', mode='min', patience=ES_PATIENCE)
callback_list = [rlrop, spearmanCallback]

optimizer = optimizers.Adam(LEARNING_RATE)
model.compile(optimizer=optimizer, loss='binary_crossentropy')

history = model.fit(X_train, Y_train, 
                    validation_data=(X_valid, Y_valid), 
                    callbacks=callback_list, 
                    batch_size=BATCH_SIZE, 
                    epochs=EPOCHS, 
                    verbose=2).history
# Out:
# Train on 4863 samples, validate on 1216 samples
# Epoch 1/50
# spearman-rho: 0.1950 val_spearman-rho: 0.1833
# 4863/4863 - 27s - loss: 0.4593 - val_loss: 0.4192
# Epoch 2/50
# spearman-rho: 0.2593 val_spearman-rho: 0.2441
# 4863/4863 - 19s - loss: 0.4152 - val_loss: 0.4060
# Epoch 3/50
# spearman-rho: 0.2974 val_spearman-rho: 0.2812
# 4863/4863 - 19s - loss: 0.4037 - val_loss: 0.3999
# Epoch 4/50
# spearman-rho: 0.3209 val_spearman-rho: 0.3004
# 4863/4863 - 19s - loss: 0.3985 - val_loss: 0.3952
# Epoch 5/50
# spearman-rho: 0.3361 val_spearman-rho: 0.3122
# 4863/4863 - 19s - loss: 0.3939 - val_loss: 0.3938
# Epoch 6/50
# spearman-rho: 0.3485 val_spearman-rho: 0.3218
# 4863/4863 - 19s - loss: 0.3914 - val_loss: 0.3902
# Epoch 7/50
# spearman-rho: 0.3589 val_spearman-rho: 0.3308
# 4863/4863 - 19s - loss: 0.3888 - val_loss: 0.3880
# Epoch 8/50
# spearman-rho: 0.3672 val_spearman-rho: 0.3332
# 4863/4863 - 19s - loss: 0.3869 - val_loss: 0.3880
# Epoch 9/50
# spearman-rho: 0.3747 val_spearman-rho: 0.3371
# 4863/4863 - 20s - loss: 0.3851 - val_loss: 0.3870
# Epoch 10/50
# spearman-rho: 0.3806 val_spearman-rho: 0.3418
# 4863/4863 - 19s - loss: 0.3836 - val_loss: 0.3849
# Epoch 11/50
# spearman-rho: 0.3842 val_spearman-rho: 0.3413
# 4863/4863 - 19s - loss: 0.3823 - val_loss: 0.3849
# Epoch 12/50
# spearman-rho: 0.3922 val_spearman-rho: 0.3455
# 4863/4863 - 19s - loss: 0.3818 - val_loss: 0.3837
# Epoch 13/50
# spearman-rho: 0.3971 val_spearman-rho: 0.3494
# 4863/4863 - 19s - loss: 0.3804 - val_loss: 0.3828
# Epoch 14/50
# spearman-rho: 0.4014 val_spearman-rho: 0.3492
# 4863/4863 - 19s - loss: 0.3792 - val_loss: 0.3825
# Epoch 15/50
# spearman-rho: 0.4035 val_spearman-rho: 0.3491
# 4863/4863 - 19s - loss: 0.3786 - val_loss: 0.3822
# Epoch 16/50
# spearman-rho: 0.4075 val_spearman-rho: 0.3502
# 4863/4863 - 19s - loss: 0.3781 - val_loss: 0.3818
# Epoch 17/50
# spearman-rho: 0.4124 val_spearman-rho: 0.3513
# 4863/4863 - 19s - loss: 0.3765 - val_loss: 0.3817
# Epoch 18/50
# spearman-rho: 0.4166 val_spearman-rho: 0.3537
# 4863/4863 - 19s - loss: 0.3761 - val_loss: 0.3809
# Epoch 19/50
# spearman-rho: 0.4191 val_spearman-rho: 0.3548
# 4863/4863 - 20s - loss: 0.3746 - val_loss: 0.3806
# Epoch 20/50
# spearman-rho: 0.4203 val_spearman-rho: 0.3521
# 4863/4863 - 19s - loss: 0.3744 - val_loss: 0.3822
# Epoch 21/50
#
# Epoch 00021: ReduceLROnPlateau reducing learning rate to 9.000000427477062e-05.
# spearman-rho: 0.4256 val_spearman-rho: 0.3565
# 4863/4863 - 19s - loss: 0.3738 - val_loss: 0.3819
# Epoch 22/50
# spearman-rho: 0.4277 val_spearman-rho: 0.3563
# 4863/4863 - 19s - loss: 0.3720 - val_loss: 0.3800
# Epoch 23/50
# spearman-rho: 0.4297 val_spearman-rho: 0.3565
# 4863/4863 - 19s - loss: 0.3717 - val_loss: 0.3796
# Epoch 24/50
# spearman-rho: 0.4327 val_spearman-rho: 0.3588
# 4863/4863 - 19s - loss: 0.3708 - val_loss: 0.3790
# Epoch 25/50
# spearman-rho: 0.4325 val_spearman-rho: 0.3579
# 4863/4863 - 19s - loss: 0.3702 - val_loss: 0.3794
# Epoch 26/50
#
# Epoch 00026: ReduceLROnPlateau reducing learning rate to 2.700000040931627e-05.
# spearman-rho: 0.4333 val_spearman-rho: 0.3578
# 4863/4863 - 19s - loss: 0.3701 - val_loss: 0.3795
# Epoch 27/50
# spearman-rho: 0.4348 val_spearman-rho: 0.3587
# 4863/4863 - 19s - loss: 0.3697 - val_loss: 0.3789
# Epoch 28/50
# spearman-rho: 0.4355 val_spearman-rho: 0.3585
# 4863/4863 - 19s - loss: 0.3699 - val_loss: 0.3788
# Epoch 29/50
# spearman-rho: 0.4361 val_spearman-rho: 0.3585
# 4863/4863 - 19s - loss: 0.3697 - val_loss: 0.3787
# Epoch 30/50
# spearman-rho: 0.4359 val_spearman-rho: 0.3582
# Epoch 00029: early stopping
# 4863/4863 - 19s - loss: 0.3695 - val_loss: 0.3789

# %% [markdown]
# ## Model loss graph

# %%
sns.set(style='whitegrid')
plot_metrics(history, metric_list=['loss', 'spearman'])

# %% [markdown]
# # Evaluation

# %%
preds_train = model.predict(X_train)
preds_val = model.predict(X_valid)

display(get_metrics(Y_train, preds_train, Y_valid, preds_val, target_cols).style.applymap(color_map))
# Out:
# <style  type="text/css" >
#     #T_ddad5e52_2792_11ea_b761_95f9bbba5664row0_col0 {
#             color:  black;
#         }    #T_ddad5e52_2792_11ea_b761_95f9bbba5664row0_col1 {
#             color:  black;
#         }    #T_ddad5e52_2792_11ea_b761_95f9bbba5664row0_col2 {
#             color:  black;
#         }    #T_ddad5e52_2792_11ea_b761_95f9bbba5664row1_col0 {
#             color:  black;
#         }    #T_ddad5e52_2792_11ea_b761_95f9bbba5664row1_col1 {
#             color:  black;
#         }    #T_ddad5e52_2792_11ea_b761_95f9bbba5664row1_col2 {
#             color:  black;
#         }    #T_ddad5e52_2792_11ea_b761_95f9bbba5664row2_col0 {
#             color:  black;
#         }    #T_ddad5e52_2792_11ea_b761_95f9bbba5664row2_col1 {
#             color:  black;
#         }    #T_ddad5e52_2792_11ea_b761_95f9bbba5664row2_col2 {
#             color:  black;
#         }    #T_ddad5e52_2792_11ea_b761_95f9bbba5664row3_col0 {
#             color:  black;
#         }    #T_ddad5e52_2792_11ea_b761_95f9bbba5664row3_col1 {
#             color:  black;
#         }    #T_ddad5e52_2792_11ea_b761_95f9bbba5664row3_col2 {
#             color:  black;
#         }    #T_ddad5e52_2792_11ea_b761_95f9bbba5664row4_col0 {
#             color:  black;
#         }    #T_ddad5e52_2792_11ea_b761_95f9bbba5664row4_col1 {
#             color:  black;
#         }    #T_ddad5e52_2792_11ea_b761_95f9bbba5664row4_col2 {
#             color:  orange;
#         }    #T_ddad5e52_2792_11ea_b761_95f9bbba5664row5_col0 {
#             color:  black;
#         }    #T_ddad5e52_2792_11ea_b761_95f9bbba5664row5_col1 {
#             color:  black;
#         }    #T_ddad5e52_2792_11ea_b761_95f9bbba5664row5_col2 {
#             color:  black;
#         }    #T_ddad5e52_2792_11ea_b761_95f9bbba5664row6_col0 {
#             color:  black;
#         }    #T_ddad5e52_2792_11ea_b761_95f9bbba5664row6_col1 {
#             color:  black;
#         }    #T_ddad5e52_2792_11ea_b761_95f9bbba5664row6_col2 {
#             color:  black;
#         }    #T_ddad5e52_2792_11ea_b761_95f9bbba5664row7_col0 {
#             color:  black;
#         }    #T_ddad5e52_2792_11ea_b761_95f9bbba5664row7_col1 {
#             color:  black;
#         }    #T_ddad5e52_2792_11ea_b761_95f9bbba5664row7_col2 {
#             color:  black;
#         }    #T_ddad5e52_2792_11ea_b761_95f9bbba5664row8_col0 {
#             color:  black;
#         }    #T_ddad5e52_2792_11ea_b761_95f9bbba5664row8_col1 {
#             color:  black;
#         }    #T_ddad5e52_2792_11ea_b761_95f9bbba5664row8_col2 {
#             color:  black;
#         }    #T_ddad5e52_2792_11ea_b761_95f9bbba5664row9_col0 {
#             color:  black;
#         }    #T_ddad5e52_2792_11ea_b761_95f9bbba5664row9_col1 {
#             color:  black;
#         }    #T_ddad5e52_2792_11ea_b761_95f9bbba5664row9_col2 {
#             color:  black;
#         }    #T_ddad5e52_2792_11ea_b761_95f9bbba5664row10_col0 {
#             color:  black;
#         }    #T_ddad5e52_2792_11ea_b761_95f9bbba5664row10_col1 {
#             color:  orange;
#         }    #T_ddad5e52_2792_11ea_b761_95f9bbba5664row10_col2 {
#             color:  orange;
#         }    #T_ddad5e52_2792_11ea_b761_95f9bbba5664row11_col0 {
#             color:  black;
#         }    #T_ddad5e52_2792_11ea_b761_95f9bbba5664row11_col1 {
#             color:  black;
#         }    #T_ddad5e52_2792_11ea_b761_95f9bbba5664row11_col2 {
#             color:  black;
#         }    #T_ddad5e52_2792_11ea_b761_95f9bbba5664row12_col0 {
#             color:  black;
#         }    #T_ddad5e52_2792_11ea_b761_95f9bbba5664row12_col1 {
#             color:  black;
#         }    #T_ddad5e52_2792_11ea_b761_95f9bbba5664row12_col2 {
#             color:  black;
#         }    #T_ddad5e52_2792_11ea_b761_95f9bbba5664row13_col0 {
#             color:  black;
#         }    #T_ddad5e52_2792_11ea_b761_95f9bbba5664row13_col1 {
#             color:  black;
#         }    #T_ddad5e52_2792_11ea_b761_95f9bbba5664row13_col2 {
#             color:  orange;
#         }    #T_ddad5e52_2792_11ea_b761_95f9bbba5664row14_col0 {
#             color:  black;
#         }    #T_ddad5e52_2792_11ea_b761_95f9bbba5664row14_col1 {
#             color:  orange;
#         }    #T_ddad5e52_2792_11ea_b761_95f9bbba5664row14_col2 {
#             color:  orange;
#         }    #T_ddad5e52_2792_11ea_b761_95f9bbba5664row15_col0 {
#             color:  black;
#         }    #T_ddad5e52_2792_11ea_b761_95f9bbba5664row15_col1 {
#             color:  black;
#         }    #T_ddad5e52_2792_11ea_b761_95f9bbba5664row15_col2 {
#             color:  black;
#         }    #T_ddad5e52_2792_11ea_b761_95f9bbba5664row16_col0 {
#             color:  black;
#         }    #T_ddad5e52_2792_11ea_b761_95f9bbba5664row16_col1 {
#             color:  black;
#         }    #T_ddad5e52_2792_11ea_b761_95f9bbba5664row16_col2 {
#             color:  black;
#         }    #T_ddad5e52_2792_11ea_b761_95f9bbba5664row17_col0 {
#             color:  black;
#         }    #T_ddad5e52_2792_11ea_b761_95f9bbba5664row17_col1 {
#             color:  black;
#         }    #T_ddad5e52_2792_11ea_b761_95f9bbba5664row17_col2 {
#             color:  black;
#         }    #T_ddad5e52_2792_11ea_b761_95f9bbba5664row18_col0 {
#             color:  black;
#         }    #T_ddad5e52_2792_11ea_b761_95f9bbba5664row18_col1 {
#             color:  black;
#         }    #T_ddad5e52_2792_11ea_b761_95f9bbba5664row18_col2 {
#             color:  orange;
#         }    #T_ddad5e52_2792_11ea_b761_95f9bbba5664row19_col0 {
#             color:  black;
#         }    #T_ddad5e52_2792_11ea_b761_95f9bbba5664row19_col1 {
#             color:  black;
#         }    #T_ddad5e52_2792_11ea_b761_95f9bbba5664row19_col2 {
#             color:  black;
#         }    #T_ddad5e52_2792_11ea_b761_95f9bbba5664row20_col0 {
#             color:  black;
#         }    #T_ddad5e52_2792_11ea_b761_95f9bbba5664row20_col1 {
#             color:  orange;
#         }    #T_ddad5e52_2792_11ea_b761_95f9bbba5664row20_col2 {
#             color:  orange;
#         }    #T_ddad5e52_2792_11ea_b761_95f9bbba5664row21_col0 {
#             color:  black;
#         }    #T_ddad5e52_2792_11ea_b761_95f9bbba5664row21_col1 {
#             color:  black;
#         }    #T_ddad5e52_2792_11ea_b761_95f9bbba5664row21_col2 {
#             color:  black;
#         }    #T_ddad5e52_2792_11ea_b761_95f9bbba5664row22_col0 {
#             color:  black;
#         }    #T_ddad5e52_2792_11ea_b761_95f9bbba5664row22_col1 {
#             color:  black;
#         }    #T_ddad5e52_2792_11ea_b761_95f9bbba5664row22_col2 {
#             color:  orange;
#         }    #T_ddad5e52_2792_11ea_b761_95f9bbba5664row23_col0 {
#             color:  black;
#         }    #T_ddad5e52_2792_11ea_b761_95f9bbba5664row23_col1 {
#             color:  black;
#         }    #T_ddad5e52_2792_11ea_b761_95f9bbba5664row23_col2 {
#             color:  black;
#         }    #T_ddad5e52_2792_11ea_b761_95f9bbba5664row24_col0 {
#             color:  black;
#         }    #T_ddad5e52_2792_11ea_b761_95f9bbba5664row24_col1 {
#             color:  orange;
#         }    #T_ddad5e52_2792_11ea_b761_95f9bbba5664row24_col2 {
#             color:  orange;
#         }    #T_ddad5e52_2792_11ea_b761_95f9bbba5664row25_col0 {
#             color:  black;
#         }    #T_ddad5e52_2792_11ea_b761_95f9bbba5664row25_col1 {
#             color:  orange;
#         }    #T_ddad5e52_2792_11ea_b761_95f9bbba5664row25_col2 {
#             color:  orange;
#         }    #T_ddad5e52_2792_11ea_b761_95f9bbba5664row26_col0 {
#             color:  black;
#         }    #T_ddad5e52_2792_11ea_b761_95f9bbba5664row26_col1 {
#             color:  black;
#         }    #T_ddad5e52_2792_11ea_b761_95f9bbba5664row26_col2 {
#             color:  orange;
#         }    #T_ddad5e52_2792_11ea_b761_95f9bbba5664row27_col0 {
#             color:  black;
#         }    #T_ddad5e52_2792_11ea_b761_95f9bbba5664row27_col1 {
#             color:  black;
#         }    #T_ddad5e52_2792_11ea_b761_95f9bbba5664row27_col2 {
#             color:  black;
#         }    #T_ddad5e52_2792_11ea_b761_95f9bbba5664row28_col0 {
#             color:  black;
#         }    #T_ddad5e52_2792_11ea_b761_95f9bbba5664row28_col1 {
#             color:  black;
#         }    #T_ddad5e52_2792_11ea_b761_95f9bbba5664row28_col2 {
#             color:  o

# %% [markdown]
# ## By category

# %%
target_cols_preds = [col+'_pred' for col in target_cols]
for col in target_cols_preds:
    train[col] = 0
    validation[col] = 0
    
train[target_cols_preds] = preds_train
validation[target_cols_preds] = preds_val
    
display(get_metrics_category(train, validation, target_cols, target_cols_preds, 'category').style.applymap(color_map))
# Out:
# <style  type="text/css" >
#     #T_de0974a8_2792_11ea_b761_95f9bbba5664row0_col0 {
#             color:  black;
#         }    #T_de0974a8_2792_11ea_b761_95f9bbba5664row0_col1 {
#             color:  black;
#         }    #T_de0974a8_2792_11ea_b761_95f9bbba5664row0_col2 {
#             color:  black;
#         }    #T_de0974a8_2792_11ea_b761_95f9bbba5664row0_col3 {
#             color:  black;
#         }    #T_de0974a8_2792_11ea_b761_95f9bbba5664row0_col4 {
#             color:  black;
#         }    #T_de0974a8_2792_11ea_b761_95f9bbba5664row0_col5 {
#             color:  black;
#         }    #T_de0974a8_2792_11ea_b761_95f9bbba5664row0_col6 {
#             color:  orange;
#         }    #T_de0974a8_2792_11ea_b761_95f9bbba5664row0_col7 {
#             color:  black;
#         }    #T_de0974a8_2792_11ea_b761_95f9bbba5664row0_col8 {
#             color:  black;
#         }    #T_de0974a8_2792_11ea_b761_95f9bbba5664row0_col9 {
#             color:  black;
#         }    #T_de0974a8_2792_11ea_b761_95f9bbba5664row0_col10 {
#             color:  black;
#         }</style><table id="T_de0974a8_2792_11ea_b761_95f9bbba5664" ><thead>    <tr>        <th class="blank level0" ></th>        <th class="col_heading level0 col0" >Label</th>        <th class="col_heading level0 col1" >Train (TECHNOLOGY)</th>        <th class="col_heading level0 col2" >Validation (TECHNOLOGY)</th>        <th class="col_heading level0 col3" >Train (SCIENCE)</th>        <th class="col_heading level0 col4" >Validation (SCIENCE)</th>        <th class="col_heading level0 col5" >Train (STACKOVERFLOW)</th>        <th class="col_heading level0 col6" >Validation (STACKOVERFLOW)</th>        <th class="col_heading level0 col7" >Train (LIFE_ARTS)</th>        <th class="col_heading level0 col8" >Validation (LIFE_ARTS)</th>        <th class="col_heading level0 col9" >Train (CULTURE)</th>        <th class="col_heading level0 col10" >Validation (CULTURE)</th>    </tr></thead><tbody>
#                 <tr>
#                         <th id="T_de0974a8_2792_11ea_b761_95f9bbba5664level0_row0" class="row_heading level0 row0" >0</th>
#                         <td id="T_de0974a8_2792_11ea_b761_95f9bbba5664row0_col0" class="data row0 col0" >Averaged</td>
#                         <td id="T_de0974a8_2792_11ea_b761_95f9bbba5664row0_col1" class="data row0 col1" >0.396</td>
#                         <td id="T_de0974a8_2792_11ea_b761_95f9bbba5664row0_col2" class="data row0 col2" >0.321</td>
#                         <td id="T_de0974a8_2792_11ea_b761_95f9bbba5664row0_col3" class="data row0 col3" >0.435</td>
#                         <td id="T_de0974a8_2792_11ea_b761_95f9bbba5664row0_col4" class="data row0 col4" >0.356</td>
#                         <td id="T_de0974a8_2792_11ea_b761_95f9bbba5664row0_col5" class="data row0 col5" >0.355</td>
#                         <td id="T_de0974a8_2792_11ea_b761_95f9bbba5664row0_col6" class="data row0 col6" >0.198</td>
#                         <td id="T_de0974a8_2792_11ea_b761_95f9bbba5664row0_col7" class="data row0 col7" >0.442</td>
#                         <td id="T_de0974a8_2792_11ea_b761_95f9bbba5664row0_col8" class="data row0 col8" >0.376</td>
#                         <td id="T_de0974a8_2792_11ea_b761_95f9bbba5664row0_col9" class="data row0 col9" >0.44</td>
#                         <td id="T_de0974a8_2792_11ea_b761_95f9bbba5664row0_col10" class="data row0 col10" >0.358</td>
#             </tr>
#     </tbody></table>

# %% [markdown]
# #### Save model weights and ecoders

# %%
model.save_weights(model_path)
