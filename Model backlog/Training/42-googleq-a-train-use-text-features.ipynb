# %% [markdown]
# ## Dependencies

# %%
import re
import warnings
from joblib import dump
import tensorflow_hub as hub
from sklearn.preprocessing import OneHotEncoder
from tensorflow.keras import Model, optimizers
from tensorflow.keras.layers import Lambda, Input, Dense, Dropout, Concatenate, BatchNormalization, Activation, Average
from tensorflow.keras.callbacks import ReduceLROnPlateau
from googleqa_utilityscript import *


SEED = 0
seed_everything(SEED)
warnings.filterwarnings("ignore")

# %% [markdown]
# ## Load data

# %%
module_url = '/kaggle/input/universalsentenceencodermodels/universal-sentence-encoder-models/use'
model_path = '/kaggle/working/use.h5'
category_encoder_path = '/kaggle/working/category_encoder.joblib'

hold_out = pd.read_csv('/kaggle/input/googleqa-mldataset/hold-out.csv')
train = hold_out[hold_out['set'] == 'train']
validation = hold_out[hold_out['set'] == 'validation']

print('Train samples: %s' % len(train))
print('Validation samples: %s' % len(validation))
display(train.head())
# Out:
# Train samples: 4863
# Validation samples: 1216
#    qa_id                                     question_title  \
# 0   3895  Magento (1.7) Bundled Product with FREE Produc...
# 1   3131                             Find router on network
# 2   1507  Negatively curved metrics minimizing the lengt...
# 3   6784               Isn’t the FAQ label obsolete by now?
# 4   2135  Changing background image one time on responsi...
#
#                                        question_body question_user_name  \
# 0  I'm looking to create a bundle offer where cus...                Joe
# 1  I've just bought a Belkin N+ Wireless Router. ...                Guy
# 2  Good afternoon everyone !\n\nI have the follow...            Selim G
# 3  Don’t get me wrong in the beginning of reading...     Benny Skogberg
# 4  The code I'm using is this one \n\nbackground:...        user2141649
#
#                               question_user_page  \
# 0  https://magento.stackexchange.com/users/16572
# 1               https://superuser.com/users/3248
# 2           https://mathoverflow.net/users/25511
# 3        https://ux.stackexchange.com/users/4679
# 4        https://stackoverflow.com/users/2141649
#
#                                               answer   answer_user_name  \
# 0  Since the third item is fixed, you can use sho...  Fabian Schmengler
# 1  You likely have the router plugged in to the m...             John T
# 2  A very partial answer: by the results of Richa...         Igor Rivin
# 3  Isn’t the FAQ label obsolete by now? \n\nI'd s...        Solracnapod
# 4  &lt;!DOCTYPE html&gt;\n&lt;html&gt;\n&lt;head&...           akkimads
#
#                               answer_user_page  \
# 0  https://magento.stackexchange.com/users/243
# 1             https://superuser.com/users/1931
# 2         https://mathoverflow.net/users/11142
# 3     https://ux.stackexchange.com/users/13153
# 4      https://stackoverflow.com/users/2375373
#
#                                                  url       category  ...  \
# 0  http://magento.stackexchange.com/questions/668...     TECHNOLOGY  ...
# 1               http://superuser.com/questions/87212     TECHNOLOGY  ...
# 2           http://mathoverflow.net/questions/203422        SCIENCE  ...
# 3  http://ux.stackexchange.com/questions/18600/is...     TECHNOLOGY  ...
# 4  http://stackoverflow.com/questions/16359492/ch...  STACKOVERFLOW  ...
#
#   answer_helpful  answer_level_of_information  answer_plausible  \
# 0       0.888889                     0.666667               1.0
# 1       1.000000                     0.666667               1.0
# 2       0.888889                     0.333333               1.0
# 3       0.888889                     0.666667               1.0
# 4       0.888889                     0.500000               1.0
#
#    answer_relevance  answer_satisfaction  answer_type_instructions  \
# 0               1.0             0.933333                  1.000000
# 1               1.0             0.866667                  0.666667
# 2               1.0             0.700000                  0.333333
# 3               1.0             0.933333                  0.000000
# 4               1.0             0.800000                  1.000000
#
#    answer_type_procedure  answer_type_reason_explanation  answer_well_written  \
# 0               0.000000                        0.333333             0.888889
# 1               0.000000                        1.000000             1.000000
# 2               0.333333                        1.000000             0.888889
# 3               0.000000                        0.666667             1.000000
# 4               0.000000                        0.000000             0.777778
#
#      set
# 0  train
# 1  train
# 2  train
# 3  train
# 4  train
#
# [5 rows x 42 columns]

# %%
question_target_cols = ['question_asker_intent_understanding','question_body_critical', 'question_conversational', 
                        'question_expect_short_answer', 'question_fact_seeking', 'question_has_commonly_accepted_answer',
                        'question_interestingness_others', 'question_interestingness_self', 'question_multi_intent', 
                        'question_not_really_a_question', 'question_opinion_seeking', 'question_type_choice',
                        'question_type_compare', 'question_type_consequence', 'question_type_definition', 
                        'question_type_entity', 'question_type_instructions', 'question_type_procedure',
                        'question_type_reason_explanation', 'question_type_spelling', 'question_well_written']
answer_target_cols = ['answer_helpful', 'answer_level_of_information', 'answer_plausible', 'answer_relevance',
                      'answer_satisfaction', 'answer_type_instructions', 'answer_type_procedure', 
                      'answer_type_reason_explanation', 'answer_well_written']
target_cols = question_target_cols + answer_target_cols

# %% [markdown]
# ## Pre-process data

# %%
text_features = ['question_title', 'question_body', 'answer']

for feature in text_features:
    # Lower
    train[feature] = train[feature].apply(lambda x: x.lower())
    validation[feature] = validation[feature].apply(lambda x: x.lower())
    # Map misspellings
#     train[feature] = train[feature].apply(lambda x: map_misspellings(x))
#     validation[feature] = validation[feature].apply(lambda x: map_misspellings(x))
    # Map contractions
    train[feature] = train[feature].apply(lambda x: map_contraction(x))
    validation[feature] = validation[feature].apply(lambda x: map_contraction(x))
    # Trim text
    train[feature] = train[feature].apply(lambda x: x.strip())
    validation[feature] = validation[feature].apply(lambda x: x.strip())


# Text length
train['question_title_len'] = train['question_title'].apply(lambda x : len(x))
validation['question_title_len'] = validation['question_title'].apply(lambda x : len(x))
train['question_body_len'] = train['question_body'].apply(lambda x : len(x))
validation['question_body_len'] = validation['question_body'].apply(lambda x : len(x))
train['answer_len'] = train['answer'].apply(lambda x : len(x))
validation['answer_len'] = validation['answer'].apply(lambda x : len(x))

# Word count
train['question_title_wordCnt'] = train['question_title'].apply(lambda x : len(x.split(' ')))
validation['question_title_wordCnt'] = validation['question_title'].apply(lambda x : len(x.split(' ')))
train['question_body_wordCnt'] = train['question_body'].apply(lambda x : len(x.split(' ')))
validation['question_body_wordCnt'] = validation['question_body'].apply(lambda x : len(x.split(' ')))
train['answer_wordCnt'] = train['answer'].apply(lambda x : len(x.split(' ')))
validation['answer_wordCnt'] = validation['answer'].apply(lambda x : len(x.split(' ')))

# %% [markdown]
# ## Train/validation sets

# %%
ohe_category = OneHotEncoder(handle_unknown='ignore')
ohe_category.fit(train[['category']])

# Train features
X_train_title = train['question_title']
X_train_body = train['question_body']
X_train_answer = train['answer']
X_train_dense = train[['question_title_len', 'question_title_wordCnt', 'question_body_len', 'question_body_wordCnt', 'answer_len', 'answer_wordCnt']]
X_train_category = ohe_category.transform(train[['category']]).toarray()

X_train = [X_train_title, X_train_body, X_train_answer, X_train_dense, X_train_category]
Y_train = train[target_cols].values

# Validation features
X_valid_title = validation['question_title']
X_valid_body = validation['question_body']
X_valid_answer = validation['answer']
X_valid_dense = validation[['question_title_len', 'question_title_wordCnt', 'question_body_len', 'question_body_wordCnt', 'answer_len', 'answer_wordCnt']]
X_valid_category = ohe_category.transform(validation[['category']]).toarray()

X_valid = [X_valid_title, X_valid_body, X_valid_answer, X_valid_dense, X_valid_category]
Y_valid = validation[target_cols].values

print('Train samples: %d' % len(Y_train))
print('Validation samples: %d' % len(Y_valid))
# Out:
# Train samples: 4863
# Validation samples: 1216

# %% [markdown]
# # Model parameters

# %%
EPOCHS = 50
BATCH_SIZE = 32
LEARNING_RATE = 3e-4
EMBEDDDING_SIZE = 512
N_CLASS = len(target_cols)
ES_PATIENCE = 5
RLROP_PATIENCE = 2
DECAY_DROP = 0.3

# %% [markdown]
# # Model

# %%
use_embed = hub.load(module_url)

def USEEmbedding(x):
    return use_embed(tf.squeeze(tf.cast(x, tf.string)))

def encoder_block(input_layer):
    encoder = Lambda(USEEmbedding, output_shape=(EMBEDDDING_SIZE,))(input_layer)
    encoder = Dropout(0.2)(encoder)
    encoder = Dense(512, activation='relu', kernel_initializer='glorot_uniform')(encoder)
    
    return encoder

# %%
# Title
input_title = Input(shape=(1,), dtype=tf.string, name='input_title')
encoded_title = encoder_block(input_title)

# Body
input_body = Input(shape=(1,), dtype=tf.string, name='input_body')
encoded_body = encoder_block(input_body)

# Answer
input_answer = Input(shape=(1,), dtype=tf.string, name='input_answer')
encoded_answer = encoder_block(input_answer)

# Dense features
input_dense = Input(shape=(X_train_dense.shape[1],), dtype=tf.float32, name='input_dense')

# Category
input_category = Input(shape=(X_valid_category.shape[1],), dtype=tf.float32, name='input_category')

# Output
x = Concatenate()([input_dense, input_category])
x = Dense(64, activation='relu', kernel_initializer='glorot_uniform')(x)
x = Dense(16, activation='relu', kernel_initializer='glorot_uniform')(x)

x = Concatenate()([encoded_title, encoded_body, encoded_answer, x])
x = Dropout(0.5)(x)
x = Dense(512, activation='relu', kernel_initializer='glorot_uniform')(x)
x = Dropout(0.5)(x)

output = Dense(N_CLASS, activation='sigmoid', kernel_initializer='glorot_uniform', name='output')(x)
model = Model(inputs=[input_title, input_body, input_answer, input_dense, input_category], outputs=[output])

model.summary()
# Out:
# Model: "model"
# __________________________________________________________________________________________________
# Layer (type)                    Output Shape         Param #     Connected to
# ==================================================================================================
# input_title (InputLayer)        [(None, 1)]          0
# __________________________________________________________________________________________________
# input_body (InputLayer)         [(None, 1)]          0
# __________________________________________________________________________________________________
# input_answer (InputLayer)       [(None, 1)]          0
# __________________________________________________________________________________________________
# input_dense (InputLayer)        [(None, 6)]          0
# __________________________________________________________________________________________________
# input_category (InputLayer)     [(None, 5)]          0
# __________________________________________________________________________________________________
# lambda (Lambda)                 (None, 512)          0           input_title[0][0]
# __________________________________________________________________________________________________
# lambda_1 (Lambda)               (None, 512)          0           input_body[0][0]
# __________________________________________________________________________________________________
# lambda_2 (Lambda)               (None, 512)          0           input_answer[0][0]
# __________________________________________________________________________________________________
# concatenate (Concatenate)       (None, 11)           0           input_dense[0][0]
#                                                                  input_category[0][0]
# __________________________________________________________________________________________________
# dropout (Dropout)               (None, 512)          0           lambda[0][0]
# __________________________________________________________________________________________________
# dropout_1 (Dropout)             (None, 512)          0           lambda_1[0][0]
# __________________________________________________________________________________________________
# dropout_2 (Dropout)             (None, 512)          0           lambda_2[0][0]
# __________________________________________________________________________________________________
# dense_3 (Dense)                 (None, 64)           768         concatenate[0][0]
# __________________________________________________________________________________________________
# dense (Dense)                   (None, 512)          262656      dropout[0][0]
# __________________________________________________________________________________________________
# dense_1 (Dense)                 (None, 512)          262656      dropout_1[0][0]
# __________________________________________________________________________________________________
# dense_2 (Dense)                 (None, 512)          262656      dropout_2[0][0]
# __________________________________________________________________________________________________
# dense_4 (Dense)                 (None, 16)           1040        dense_3[0][0]
# __________________________________________________________________________________________________
# concatenate_1 (Concatenate)     (None, 1552)         0           dense[0][0]
#                                                                  dense_1[0][0]
#                                                                  dense_2[0][0]
#                                                                  dense_4[0][0]
# __________________________________________________________________________________________________
# dropout_3 (Dropout)             (None, 1552)         0           concatenate_1[0][0]
# __________________________________________________________________________________________________
# dense_5 (Dense)                 (None, 512)          795136      dropout_3[0][0]
# __________________________________________________________________________________________________
# dropout_4 (Dropout)             (None, 512)          0           dense_5[0][0]
# __________________________________________________________________________________________________
# output (Dense)                  (None, 30)           15390       dropout_4[0][0]
# ==================================================================================================
# Total params: 1,600,302
# Trainable params: 1,600,302
# Non-trainable params: 0
# __________________________________________________________________________________________________

# %% [markdown]
# # Train model

# %%
rlrop = ReduceLROnPlateau(monitor='val_loss', mode='min', patience=RLROP_PATIENCE, factor=DECAY_DROP, min_lr=1e-7, verbose=1)
spearmanCallback = SpearmanRhoCallback(training_data=(X_train, Y_train), validation_data=(X_valid, Y_valid), monitor='val_loss', mode='min', patience=ES_PATIENCE)
callback_list = [rlrop, spearmanCallback]

optimizer = optimizers.Adam(LEARNING_RATE)
model.compile(optimizer=optimizer, loss='binary_crossentropy')

history = model.fit(X_train, Y_train, 
                    validation_data=(X_valid, Y_valid), 
                    callbacks=callback_list, 
                    batch_size=BATCH_SIZE,
                    epochs=EPOCHS, 
                    verbose=2).history
# Out:
# Train on 4863 samples, validate on 1216 samples
# Epoch 1/50
# spearman-rho: 0.0706 val_spearman-rho: 0.0691
# 4863/4863 - 29s - loss: 3.3460 - val_loss: 0.4507
# Epoch 2/50
# spearman-rho: 0.2404 val_spearman-rho: 0.2297
# 4863/4863 - 20s - loss: 0.4517 - val_loss: 0.4093
# Epoch 3/50
# spearman-rho: 0.2903 val_spearman-rho: 0.2762
# 4863/4863 - 20s - loss: 0.4181 - val_loss: 0.3997
# Epoch 4/50
# spearman-rho: 0.3184 val_spearman-rho: 0.2984
# 4863/4863 - 20s - loss: 0.4089 - val_loss: 0.3939
# Epoch 5/50
# spearman-rho: 0.3411 val_spearman-rho: 0.3142
# 4863/4863 - 20s - loss: 0.4011 - val_loss: 0.3906
# Epoch 6/50
# spearman-rho: 0.3541 val_spearman-rho: 0.3226
# 4863/4863 - 20s - loss: 0.3970 - val_loss: 0.3870
# Epoch 7/50
# spearman-rho: 0.3669 val_spearman-rho: 0.3307
# 4863/4863 - 20s - loss: 0.3925 - val_loss: 0.3849
# Epoch 8/50
# spearman-rho: 0.3753 val_spearman-rho: 0.3343
# 4863/4863 - 20s - loss: 0.3887 - val_loss: 0.3833
# Epoch 9/50
# spearman-rho: 0.3827 val_spearman-rho: 0.3384
# 4863/4863 - 20s - loss: 0.3858 - val_loss: 0.3819
# Epoch 10/50
# spearman-rho: 0.3898 val_spearman-rho: 0.3419
# 4863/4863 - 21s - loss: 0.3839 - val_loss: 0.3809
# Epoch 11/50
# spearman-rho: 0.3947 val_spearman-rho: 0.3424
# 4863/4863 - 19s - loss: 0.3822 - val_loss: 0.3804
# Epoch 12/50
# spearman-rho: 0.4002 val_spearman-rho: 0.3448
# 4863/4863 - 19s - loss: 0.3799 - val_loss: 0.3797
# Epoch 13/50
# spearman-rho: 0.4074 val_spearman-rho: 0.3486
# 4863/4863 - 20s - loss: 0.3787 - val_loss: 0.3786
# Epoch 14/50
# spearman-rho: 0.4116 val_spearman-rho: 0.3508
# 4863/4863 - 20s - loss: 0.3774 - val_loss: 0.3782
# Epoch 15/50
# spearman-rho: 0.4169 val_spearman-rho: 0.3524
# 4863/4863 - 20s - loss: 0.3768 - val_loss: 0.3780
# Epoch 16/50
# spearman-rho: 0.4211 val_spearman-rho: 0.3527
# 4863/4863 - 20s - loss: 0.3747 - val_loss: 0.3775
# Epoch 17/50
# spearman-rho: 0.4247 val_spearman-rho: 0.3538
# 4863/4863 - 20s - loss: 0.3737 - val_loss: 0.3769
# Epoch 18/50
# spearman-rho: 0.4292 val_spearman-rho: 0.3549
# 4863/4863 - 20s - loss: 0.3729 - val_loss: 0.3766
# Epoch 19/50
# spearman-rho: 0.4345 val_spearman-rho: 0.3560
# 4863/4863 - 20s - loss: 0.3712 - val_loss: 0.3765
# Epoch 20/50
#
# Epoch 00020: ReduceLROnPlateau reducing learning rate to 9.000000427477062e-05.
# spearman-rho: 0.4388 val_spearman-rho: 0.3573
# 4863/4863 - 19s - loss: 0.3709 - val_loss: 0.3766
# Epoch 21/50
# spearman-rho: 0.4406 val_spearman-rho: 0.3580
# 4863/4863 - 20s - loss: 0.3685 - val_loss: 0.3758
# Epoch 22/50
# spearman-rho: 0.4424 val_spearman-rho: 0.3580
# 4863/4863 - 19s - loss: 0.3683 - val_loss: 0.3756
# Epoch 23/50
# spearman-rho: 0.4442 val_spearman-rho: 0.3587
# 4863/4863 - 20s - loss: 0.3674 - val_loss: 0.3756
# Epoch 24/50
# spearman-rho: 0.4453 val_spearman-rho: 0.3592
# 4863/4863 - 20s - loss: 0.3674 - val_loss: 0.3754
# Epoch 25/50
# spearman-rho: 0.4464 val_spearman-rho: 0.3591
# 4863/4863 - 20s - loss: 0.3670 - val_loss: 0.3753
# Epoch 26/50
#
# Epoch 00026: ReduceLROnPlateau reducing learning rate to 2.700000040931627e-05.
# spearman-rho: 0.4479 val_spearman-rho: 0.3592
# 4863/4863 - 20s - loss: 0.3670 - val_loss: 0.3753
# Epoch 27/50
# spearman-rho: 0.4486 val_spearman-rho: 0.3596
# 4863/4863 - 20s - loss: 0.3662 - val_loss: 0.3752
# Epoch 28/50
# spearman-rho: 0.4491 val_spearman-rho: 0.3598
# 4863/4863 - 20s - loss: 0.3662 - val_loss: 0.3752
# Epoch 29/50
#
# Epoch 00029: ReduceLROnPlateau reducing learning rate to 8.100000013655517e-06.
# spearman-rho: 0.4495 val_spearman-rho: 0.3596
# 4863/4863 - 20s - loss: 0.3659 - val_loss: 0.3752
# Epoch 30/50
# spearman-rho: 0.4497 val_spearman-rho: 0.3597
# 4863/4863 - 20s - loss: 0.3656 - val_loss: 0.3751
# Epoch 31/50
#
# Epoch 00031: ReduceLROnPlateau reducing learning rate to 2.429999949526973e-06.
# spearman-rho: 0.4498 val_spearman-rho: 0.3597
# 4863/4863 - 20s - loss: 0.3661 - val_loss: 0.3751
# Epoch 32/50
# spearman-rho: 0.4499 val_spearman-rho: 0.3597
# 4863/4863 - 20s - loss: 0.3657 - val_loss: 0.3751
# Epoch 33/50
#
# Epoch 00033: ReduceLROnPlateau reducing learning rate to 7.289999985005124e-07.
# spearman-rho: 0.4499 val_spearman-rho: 0.3598
# 4863/4863 - 20s - loss: 0.3653 - val_loss: 0.3751
# Epoch 34/50
# spearman-rho: 0.4499 val_spearman-rho: 0.3598
# 4863/4863 - 20s - loss: 0.3658 - val_loss: 0.3751
# Epoch 35/50
#
# Epoch 00035: ReduceLROnPlateau reducing learning rate to 2.1870000637136398e-07.
# spearman-rho: 0.4500 val_spearman-rho: 0.3598
# 4863/4863 - 20s - loss: 0.3657 - val_loss: 0.3751
# Epoch 36/50
# spearman-rho: 0.4500 val_spearman-rho: 0.3598
# 4863/4863 - 20s - loss: 0.3657 - val_loss: 0.3751
# Epoch 37/50
#
# Epoch 00037: ReduceLROnPlateau reducing learning rate to 1e-07.
# spearman-rho: 0.4500 val_spearman-rho: 0.3598
# 4863/4863 - 19s - loss: 0.3661 - val_loss: 0.3751
# Epoch 38/50
# spearman-rho: 0.4500 val_spearman-rho: 0.3598
# 4863/4863 - 20s - loss: 0.3656 - val_loss: 0.3751
# Epoch 39/50
#
# Epoch 00039: ReduceLROnPlateau reducing learning rate to 1e-07.
# spearman-rho: 0.4500 val_spearman-rho: 0.3598
# 4863/4863 - 20s - loss: 0.3656 - val_loss: 0.3751
# Epoch 40/50
# spearman-rho: 0.4500 val_spearman-rho: 0.3598
# 4863/4863 - 20s - loss: 0.3651 - val_loss: 0.3751
# Epoch 41/50
#
# Epoch 00041: ReduceLROnPlateau reducing learning rate to 1e-07.
# spearman-rho: 0.4500 val_spearman-rho: 0.3598
# 4863/4863 - 20s - loss: 0.3654 - val_loss: 0.3751
# Epoch 42/50
# spearman-rho: 0.4500 val_spearman-rho: 0.3598
# 4863/4863 - 20s - loss: 0.3659 - val_loss: 0.3751
# Epoch 43/50
#
# Epoch 00043: ReduceLROnPlateau reducing learning rate to 1e-07.
# spearman-rho: 0.4500 val_spearman-rho: 0.3598
# 4863/4863 - 20s - loss: 0.3659 - val_loss: 0.3751
# Epoch 44/50
# spearman-rho: 0.4500 val_spearman-rho: 0.3598
# 4863/4863 - 20s - loss: 0.3657 - val_loss: 0.3751
# Epoch 45/50
#
# Epoch 00045: ReduceLROnPlateau reducing learning rate to 1e-07.
# spearman-rho: 0.4500 val_spearman-rho: 0.3598
# 4863/4863 - 20s - loss: 0.3657 - val_loss: 0.3751
# Epoch 46/50
# spearman-rho: 0.4500 val_spearman-rho: 0.3598
# 4863/4863 - 20s - loss: 0.3660 - val_loss: 0.3751
# Epoch 47/50
#
# Epoch 00047: ReduceLROnPlateau reducing learning rate to 1e-07.
# spearman-rho: 0.4500 val_spearman-rho: 0.3598
# 4863/4863 - 20s - loss: 0.3656 - val_loss: 0.3751
# Epoch 48/50
# spearman-rho: 0.4500 val_spearman-rho: 0.3598
# 4863/4863 - 20s - loss: 0.3660 - val_loss: 0.3751
# Epoch 49/50
# spearman-rho: 0.4500 val_spearman-rho: 0.3598
# 4863/4863 - 20s - loss: 0.3661 - val_loss: 0.3751
# Epoch 50/50
# spearman-rho: 0.4500 val_spearman-rho: 0.3598
# 4863/4863 - 20s - loss: 0.3654 - val_loss: 0.3751

# %% [markdown]
# ## Model loss graph

# %%
sns.set(style="whitegrid")
plot_metrics(history, metric_list=['loss', 'spearman'])

# %% [markdown]
# # Evaluation

# %%
preds_train = model.predict(X_train)
preds_val = model.predict(X_valid)

display(get_metrics(Y_train, preds_train, Y_valid, preds_val, target_cols))
# Out:
#                                     Label  Train  Validation
# 0                                Averaged  0.450       0.360
# 1     question_asker_intent_understanding  0.417       0.392
# 2                  question_body_critical  0.672       0.612
# 3                 question_conversational  0.447       0.400
# 4            question_expect_short_answer  0.446       0.263
# 5                   question_fact_seeking  0.485       0.344
# 6   question_has_commonly_accepted_answer  0.546       0.433
# 7         question_interestingness_others  0.389       0.364
# 8           question_interestingness_self  0.532       0.512
# 9                   question_multi_intent  0.545       0.435
# 10         question_not_really_a_question  0.060       0.028
# 11               question_opinion_seeking  0.610       0.445
# 12                   question_type_choice  0.709       0.586
# 13                  question_type_compare  0.367       0.301
# 14              question_type_consequence  0.180       0.141
# 15               question_type_definition  0.369       0.306
# 16                   question_type_entity  0.444       0.419
# 17             question_type_instructions  0.819       0.751
# 18                question_type_procedure  0.440       0.267
# 19       question_type_reason_explanation  0.712       0.643
# 20                 question_type_spelling  0.065       0.061
# 21                  question_well_written  0.544       0.488
# 22                         answer_helpful  0.291       0.156
# 23            answer_level_of_information  0.405       0.308
# 24                       answer_plausible  0.235       0.140
# 25                       answer_relevance  0.231       0.127
# 26                    answer_satisfaction  0.375       0.239
# 27               answer_type_instructions  0.814       0.707
# 28                  answer_type_procedure  0.392       0.226
# 29         answer_type_reason_explanation  0.737       0.638
# 30                    answer_well_written  0.222       0.060

# %% [markdown]
# ## By category

# %%
target_cols_preds = [col+'_pred' for col in target_cols]
for col in target_cols_preds:
    train[col] = 0
    validation[col] = 0
    
train[target_cols_preds] = preds_train
validation[target_cols_preds] = preds_val
    
display(get_metrics_category(train, validation, target_cols, target_cols_preds, 'category'))
# Out:
#       Label Train (TECHNOLOGY) Validation (TECHNOLOGY) Train (SCIENCE)  \
# 0  Averaged              0.414                   0.325           0.458
#
#   Validation (SCIENCE) Train (STACKOVERFLOW) Validation (STACKOVERFLOW)  \
# 0                0.348                 0.345                      0.188
#
#   Train (LIFE_ARTS) Validation (LIFE_ARTS) Train (CULTURE)  \
# 0             0.464                  0.391           0.463
#
#   Validation (CULTURE)
# 0                 0.36

# %% [markdown]
# #### Save model weights and ecoders

# %%
model.save_weights(model_path)
dump(ohe_category, category_encoder_path)
# Out:
# ['/kaggle/working/category_encoder.joblib']
