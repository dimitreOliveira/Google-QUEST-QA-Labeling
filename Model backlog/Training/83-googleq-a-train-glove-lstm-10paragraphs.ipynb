# %% [markdown]
# ## Dependencies

# %%
import gc
import re
import warnings
from joblib import dump
import tensorflow_hub as hub
from tensorflow.keras import Model, optimizers
from tensorflow.keras.callbacks import ReduceLROnPlateau
from tensorflow.keras.preprocessing.text import Tokenizer
from tensorflow.keras.preprocessing.sequence import pad_sequences
from tensorflow.keras.layers import Lambda, Input, Dense, Dropout, Concatenate, BatchNormalization, Activation, Average, Add, Reshape
from tensorflow.keras.layers import GlobalAveragePooling1D, Embedding, LSTM, Conv1D, SpatialDropout1D, Bidirectional, Flatten, Bidirectional
from googleqa_utilityscript import *


SEED = 0
seed_everything(SEED)
warnings.filterwarnings("ignore")

# %% [markdown]
# ## Load data

# %%
module_url = '/kaggle/input/universalsentenceencodermodels/universal-sentence-encoder-models/use'
model_path = '/kaggle/working/model.h5'
tokenizer_path = '/kaggle/working/tokenizer.joblib'
encoder_path = '/kaggle/input/pickled-glove840b300d-for-10sec-loading/glove.840B.300d.pkl'

hold_out = pd.read_csv('/kaggle/input/googleqa-mldataset/hold-out.csv')
test = pd.read_csv('/kaggle/input/google-quest-challenge/test.csv')
train = hold_out[hold_out['set'] == 'train']
validation = hold_out[hold_out['set'] == 'validation']

print('Train samples: %s' % len(train))
print('Validation samples: %s' % len(validation))
display(train.head())
# Out:
# Train samples: 4863
# Validation samples: 1216
#    qa_id                                     question_title  \
# 0   3895  Magento (1.7) Bundled Product with FREE Produc...
# 1   3131                             Find router on network
# 2   1507  Negatively curved metrics minimizing the lengt...
# 3   6784               Isn’t the FAQ label obsolete by now?
# 4   2135  Changing background image one time on responsi...
#
#                                        question_body question_user_name  \
# 0  I'm looking to create a bundle offer where cus...                Joe
# 1  I've just bought a Belkin N+ Wireless Router. ...                Guy
# 2  Good afternoon everyone !\n\nI have the follow...            Selim G
# 3  Don’t get me wrong in the beginning of reading...     Benny Skogberg
# 4  The code I'm using is this one \n\nbackground:...        user2141649
#
#                               question_user_page  \
# 0  https://magento.stackexchange.com/users/16572
# 1               https://superuser.com/users/3248
# 2           https://mathoverflow.net/users/25511
# 3        https://ux.stackexchange.com/users/4679
# 4        https://stackoverflow.com/users/2141649
#
#                                               answer   answer_user_name  \
# 0  Since the third item is fixed, you can use sho...  Fabian Schmengler
# 1  You likely have the router plugged in to the m...             John T
# 2  A very partial answer: by the results of Richa...         Igor Rivin
# 3  Isn’t the FAQ label obsolete by now? \n\nI'd s...        Solracnapod
# 4  &lt;!DOCTYPE html&gt;\n&lt;html&gt;\n&lt;head&...           akkimads
#
#                               answer_user_page  \
# 0  https://magento.stackexchange.com/users/243
# 1             https://superuser.com/users/1931
# 2         https://mathoverflow.net/users/11142
# 3     https://ux.stackexchange.com/users/13153
# 4      https://stackoverflow.com/users/2375373
#
#                                                  url       category  ...  \
# 0  http://magento.stackexchange.com/questions/668...     TECHNOLOGY  ...
# 1               http://superuser.com/questions/87212     TECHNOLOGY  ...
# 2           http://mathoverflow.net/questions/203422        SCIENCE  ...
# 3  http://ux.stackexchange.com/questions/18600/is...     TECHNOLOGY  ...
# 4  http://stackoverflow.com/questions/16359492/ch...  STACKOVERFLOW  ...
#
#   answer_helpful  answer_level_of_information  answer_plausible  \
# 0       0.888889                     0.666667               1.0
# 1       1.000000                     0.666667               1.0
# 2       0.888889                     0.333333               1.0
# 3       0.888889                     0.666667               1.0
# 4       0.888889                     0.500000               1.0
#
#    answer_relevance  answer_satisfaction  answer_type_instructions  \
# 0               1.0             0.933333                  1.000000
# 1               1.0             0.866667                  0.666667
# 2               1.0             0.700000                  0.333333
# 3               1.0             0.933333                  0.000000
# 4               1.0             0.800000                  1.000000
#
#    answer_type_procedure  answer_type_reason_explanation  answer_well_written  \
# 0               0.000000                        0.333333             0.888889
# 1               0.000000                        1.000000             1.000000
# 2               0.333333                        1.000000             0.888889
# 3               0.000000                        0.666667             1.000000
# 4               0.000000                        0.000000             0.777778
#
#      set
# 0  train
# 1  train
# 2  train
# 3  train
# 4  train
#
# [5 rows x 42 columns]

# %%
question_target_cols = ['question_asker_intent_understanding','question_body_critical', 'question_conversational', 
                        'question_expect_short_answer', 'question_fact_seeking', 'question_has_commonly_accepted_answer',
                        'question_interestingness_others', 'question_interestingness_self', 'question_multi_intent', 
                        'question_not_really_a_question', 'question_opinion_seeking', 'question_type_choice',
                        'question_type_compare', 'question_type_consequence', 'question_type_definition', 
                        'question_type_entity', 'question_type_instructions', 'question_type_procedure',
                        'question_type_reason_explanation', 'question_type_spelling', 'question_well_written']
answer_target_cols = ['answer_helpful', 'answer_level_of_information', 'answer_plausible', 'answer_relevance',
                      'answer_satisfaction', 'answer_type_instructions', 'answer_type_procedure', 
                      'answer_type_reason_explanation', 'answer_well_written']
target_cols = question_target_cols + answer_target_cols

# %% [markdown]
# ## Pre-process data

# %%
text_features = ['question_title', 'question_body', 'answer']

for feature in text_features:
    # Lower
    train[feature] = train[feature].apply(lambda x: x.lower())
    validation[feature] = validation[feature].apply(lambda x: x.lower())
    test[feature] = test[feature].apply(lambda x: x.lower())
    # Map contractions
    train[feature] = train[feature].apply(lambda x: map_contraction(x))
    validation[feature] = validation[feature].apply(lambda x: map_contraction(x))
    test[feature] = test[feature].apply(lambda x: map_contraction(x))
    # Trim text
    train[feature] = train[feature].apply(lambda x: x.strip())
    validation[feature] = validation[feature].apply(lambda x: x.strip())
    test[feature] = test[feature].apply(lambda x: x.strip())

for feature in text_features:
    train[feature + '_uncased'] = train[feature]
    validation[feature + '_uncased'] = validation[feature]
    test[feature + '_uncased'] = test[feature]

# %%
def split_paragraphs(row):
    splited_body = re.split('\n\n\n\n\n|\n\n\n\n|\n\n\n|\n\n', row['question_body_uncased'])
    splited_answer = re.split('\n\n\n\n\n|\n\n\n\n|\n\n\n|\n\n', row['answer_uncased'])
    for i in range(len(splited_body))[:10]:
        row['body_paragraph_%s' % (i+1)] = splited_body[i]
    for i in range(len(splited_answer))[:10]:
        row['answer_paragraph_%s' % (i+1)] = splited_answer[i]
    return row

train = train.apply(split_paragraphs, axis=1)
validation = validation.apply(split_paragraphs, axis=1)

# %% [markdown]
# # Model parameters

# %%
EPOCHS = 50
BATCH_SIZE = 32
LEARNING_RATE = 3e-4
EMBEDDDING_SIZE = 512
N_CLASS = len(target_cols)
ES_PATIENCE = 5
RLROP_PATIENCE = 2
DECAY_DROP = 0.3
MAX_FEATURES = 100000
TITLE_MAX_LEN = 30
BODY_MAX_LEN = 30
ANSWER_MAX_LEN = 30

# %%
tokenizer = Tokenizer(num_words=MAX_FEATURES, lower=True)

tokenizer.fit_on_texts(list(train['question_title_uncased']) + list(validation['question_title_uncased']) + list(test['question_title_uncased']) +
                       list(train['question_body_uncased']) + list(validation['question_body_uncased']) + list(test['question_body_uncased']) +
                       list(train['answer_uncased']) + list(validation['answer_uncased']) + list(test['answer_uncased']))

# %% [markdown]
# ## Train/validation sets

# %%
body_ft = ['body_paragraph_1', 'body_paragraph_2', 'body_paragraph_3', 'body_paragraph_4', 'body_paragraph_5', 
           'body_paragraph_6', 'body_paragraph_7', 'body_paragraph_8', 'body_paragraph_9', 'body_paragraph_10']
answer_ft = ['answer_paragraph_1', 'answer_paragraph_2', 'answer_paragraph_3', 'answer_paragraph_4', 'answer_paragraph_5', 
             'answer_paragraph_6', 'answer_paragraph_7', 'answer_paragraph_8', 'answer_paragraph_9', 'answer_paragraph_10']

# Train features
X_train_title_seq = train['question_title_uncased']
X_train_body_fts = train[body_ft].astype(str)
X_train_answer_fts = train[answer_ft].astype(str)

# Tokenize the sentences
X_train_title_seq = tokenizer.texts_to_sequences(X_train_title_seq)
for ft in body_ft:
    X_train_body_fts[ft] = tokenizer.texts_to_sequences(X_train_body_fts[ft])
for ft in answer_ft:
    X_train_answer_fts[ft] = tokenizer.texts_to_sequences(X_train_answer_fts[ft])

X_train_body_seq = np.empty((X_train_body_fts.shape[0], BODY_MAX_LEN, X_train_body_fts.shape[1]))
X_train_answer_seq = np.empty((X_train_answer_fts.shape[0], ANSWER_MAX_LEN, X_train_answer_fts.shape[1]))

# Pad the sentences
X_train_title_seq = pad_sequences(X_train_title_seq, maxlen=TITLE_MAX_LEN)
for index, ft in enumerate(body_ft):
    X_train_body_seq[...,index] = pad_sequences(X_train_body_fts[ft], maxlen=BODY_MAX_LEN)
for index, ft in enumerate(answer_ft):
    X_train_answer_seq[...,index] = pad_sequences(X_train_answer_fts[ft], maxlen=ANSWER_MAX_LEN)
    
X_train = [X_train_title_seq, X_train_body_seq, X_train_answer_seq]
Y_train = train[target_cols].values

# Validation features
X_valid_title_seq = validation['question_title_uncased']
X_valid_body_fts = validation[body_ft].astype(str)
X_valid_answer_fts = validation[answer_ft].astype(str)

# Tokenize the sentences
X_valid_title_seq = tokenizer.texts_to_sequences(X_valid_title_seq)
for ft in body_ft:
    X_valid_body_fts[ft] = tokenizer.texts_to_sequences(X_valid_body_fts[ft])
for ft in answer_ft:
    X_valid_answer_fts[ft] = tokenizer.texts_to_sequences(X_valid_answer_fts[ft])

X_valid_body_seq = np.empty((X_valid_body_fts.shape[0], BODY_MAX_LEN, X_valid_body_fts.shape[1]))
X_valid_answer_seq = np.empty((X_valid_answer_fts.shape[0], ANSWER_MAX_LEN, X_valid_answer_fts.shape[1]))

# Pad the sentences
X_valid_title_seq = pad_sequences(X_valid_title_seq, maxlen=TITLE_MAX_LEN)
for index, ft in enumerate(body_ft):
    X_valid_body_seq[...,index] = pad_sequences(X_valid_body_fts[ft], maxlen=BODY_MAX_LEN)
for index, ft in enumerate(answer_ft):
    X_valid_answer_seq[...,index] = pad_sequences(X_valid_answer_fts[ft], maxlen=ANSWER_MAX_LEN)

X_valid = [X_valid_title_seq, X_valid_body_seq, X_valid_answer_seq]
Y_valid = validation[target_cols].values


print('Train samples: %d' % len(Y_train))
print('Validation samples: %d' % len(Y_valid))
# Out:
# Train samples: 4863
# Validation samples: 1216

# %% [markdown]
# # Model

# %%
# use_embed = hub.load(module_url)

# def USEEmbedding(x):
#     return use_embed(tf.squeeze(tf.cast(x, tf.string)))

def encoder_block(input_layer):
    encoder = Lambda(USEEmbedding, output_shape=(EMBEDDDING_SIZE,))(input_layer)
    
    return encoder

def encoder_block_parag(input_layer, index, name_pre):
    name = '%s_parag_%d' % (name_pre, index)
    encoder = Embedding(*glove_embedding_matrix.shape, weights=[glove_embedding_matrix], trainable=False, name='enc_'+name)(input_layer[...,index])
    encoder = SpatialDropout1D(0.2)(encoder)
    encoder = LSTM(64, kernel_initializer='lecun_normal', recurrent_dropout=0.5, return_sequences=True)(encoder)

    return encoder

# %% [markdown]
# ## Load embedding

# %%
glove_embedding_matrix, glove_unknown_words = build_matrix(tokenizer.word_index, encoder_path, MAX_FEATURES)
embedding_name = 'GloVe'
print('n unknown words "%s": %d' % (embedding_name, len(glove_unknown_words)))
print('"%s" embedding shape: %s' % (embedding_name, glove_embedding_matrix.shape))
# Out:
# n unknown words "GloVe": 19913
# "GloVe" embedding shape: (58007, 300)

# %%
# Title sequence
input_title_seq = Input(shape=(TITLE_MAX_LEN,), dtype=tf.float32, name='input_title_seq')
title = Embedding(*glove_embedding_matrix.shape, weights=[glove_embedding_matrix], trainable=False)(input_title_seq)
title = SpatialDropout1D(0.2)(title)
title = LSTM(128, kernel_initializer='lecun_normal', recurrent_dropout=0.5, return_sequences=True)(title)
title_out = GlobalAveragePooling1D()(title)

# Body sequence
input_body_seq = Input(shape=(*X_train_body_seq.shape[1:], ), dtype=tf.float32, name='input_body_seq')

body1_out = encoder_block_parag(input_body_seq, 0, 'body')
body2_out = encoder_block_parag(input_body_seq, 1, 'body')
body3_out = encoder_block_parag(input_body_seq, 2, 'body')
body4_out = encoder_block_parag(input_body_seq, 3, 'body')
body5_out = encoder_block_parag(input_body_seq, 4, 'body')
body6_out = encoder_block_parag(input_body_seq, 5, 'body')
body7_out = encoder_block_parag(input_body_seq, 6, 'body')
body8_out = encoder_block_parag(input_body_seq, 7, 'body')
body9_out = encoder_block_parag(input_body_seq, 8, 'body')
body10_out = encoder_block_parag(input_body_seq, 9, 'body')

body_out = Concatenate()([body1_out, body2_out, body3_out, body4_out, body5_out, body6_out, body7_out, body8_out, body9_out, body10_out])
body_out = SpatialDropout1D(0.5)(body_out)
body_out = LSTM(256, kernel_initializer='lecun_normal', recurrent_dropout=0.5, return_sequences=False)(body_out)

# Answer sequence
input_answer_seq = Input(shape=(*X_train_body_seq.shape[1:], ), dtype=tf.float32, name='input_answer_seq')

answer1_out = encoder_block_parag(input_answer_seq, 0, 'answer')
answer2_out = encoder_block_parag(input_answer_seq, 1, 'answer')
answer3_out = encoder_block_parag(input_answer_seq, 2, 'answer')
answer4_out = encoder_block_parag(input_answer_seq, 3, 'answer')
answer5_out = encoder_block_parag(input_answer_seq, 4, 'answer')
answer6_out = encoder_block_parag(input_answer_seq, 5, 'answer')
answer7_out = encoder_block_parag(input_answer_seq, 6, 'answer')
answer8_out = encoder_block_parag(input_answer_seq, 7, 'answer')
answer9_out = encoder_block_parag(input_answer_seq, 8, 'answer')
answer10_out = encoder_block_parag(input_answer_seq, 9, 'answer')

answer_out = Concatenate()([answer1_out, answer2_out, answer3_out, answer4_out, answer5_out, answer6_out, answer7_out, answer8_out, answer9_out, answer10_out])
answer_out = SpatialDropout1D(0.5)(answer_out)
answer_out = LSTM(256, kernel_initializer='lecun_normal', recurrent_dropout=0.5, return_sequences=False)(answer_out)


# Output
x = Concatenate()([title_out, body_out, answer_out])
x = Dropout(0.5)(x)
x = Dense(512, activation='relu', kernel_initializer='lecun_normal')(x)
x = Dropout(0.5)(x)

output = Dense(N_CLASS, activation='sigmoid', kernel_initializer='lecun_normal', name='output')(x)
model = Model(inputs=[input_title_seq, input_body_seq, input_answer_seq], outputs=[output])

model.summary()
# Out:
# Model: "model"
# __________________________________________________________________________________________________
# Layer (type)                    Output Shape         Param #     Connected to
# ==================================================================================================
# input_body_seq (InputLayer)     [(None, 30, 10)]     0
# __________________________________________________________________________________________________
# input_answer_seq (InputLayer)   [(None, 30, 10)]     0
# __________________________________________________________________________________________________
# tf_op_layer_strided_slice (Tens [(None, 30)]         0           input_body_seq[0][0]
# __________________________________________________________________________________________________
# tf_op_layer_strided_slice_1 (Te [(None, 30)]         0           input_body_seq[0][0]
# __________________________________________________________________________________________________
# tf_op_layer_strided_slice_2 (Te [(None, 30)]         0           input_body_seq[0][0]
# __________________________________________________________________________________________________
# tf_op_layer_strided_slice_3 (Te [(None, 30)]         0           input_body_seq[0][0]
# __________________________________________________________________________________________________
# tf_op_layer_strided_slice_4 (Te [(None, 30)]         0           input_body_seq[0][0]
# __________________________________________________________________________________________________
# tf_op_layer_strided_slice_5 (Te [(None, 30)]         0           input_body_seq[0][0]
# __________________________________________________________________________________________________
# tf_op_layer_strided_slice_6 (Te [(None, 30)]         0           input_body_seq[0][0]
# __________________________________________________________________________________________________
# tf_op_layer_strided_slice_7 (Te [(None, 30)]         0           input_body_seq[0][0]
# __________________________________________________________________________________________________
# tf_op_layer_strided_slice_8 (Te [(None, 30)]         0           input_body_seq[0][0]
# __________________________________________________________________________________________________
# tf_op_layer_strided_slice_9 (Te [(None, 30)]         0           input_body_seq[0][0]
# __________________________________________________________________________________________________
# tf_op_layer_strided_slice_10 (T [(None, 30)]         0           input_answer_seq[0][0]
# __________________________________________________________________________________________________
# tf_op_layer_strided_slice_11 (T [(None, 30)]         0           input_answer_seq[0][0]
# __________________________________________________________________________________________________
# tf_op_layer_strided_slice_12 (T [(None, 30)]         0           input_answer_seq[0][0]
# __________________________________________________________________________________________________
# tf_op_layer_strided_slice_13 (T [(None, 30)]         0           input_answer_seq[0][0]
# __________________________________________________________________________________________________
# tf_op_layer_strided_slice_14 (T [(None, 30)]         0           input_answer_seq[0][0]
# __________________________________________________________________________________________________
# tf_op_layer_strided_slice_15 (T [(None, 30)]         0           input_answer_seq[0][0]
# __________________________________________________________________________________________________
# tf_op_layer_strided_slice_16 (T [(None, 30)]         0           input_answer_seq[0][0]
# __________________________________________________________________________________________________
# tf_op_layer_strided_slice_17 (T [(None, 30)]         0           input_answer_seq[0][0]
# __________________________________________________________________________________________________
# tf_op_layer_strided_slice_18 (T [(None, 30)]         0           input_answer_seq[0][0]
# __________________________________________________________________________________________________
# tf_op_layer_strided_slice_19 (T [(None, 30)]         0           input_answer_seq[0][0]
# __________________________________________________________________________________________________
# enc_body_parag_0 (Embedding)    (None, 30, 300)      17402100    tf_op_layer_strided_slice[0][0]
# __________________________________________________________________________________________________
# enc_body_parag_1 (Embedding)    (None, 30, 300)      17402100    tf_op_layer_strided_slice_1[0][0]
# __________________________________________________________________________________________________
# enc_body_parag_2 (Embedding)    (None, 30, 300)      17402100    tf_op_layer_strided_slice_2[0][0]
# __________________________________________________________________________________________________
# enc_body_parag_3 (Embedding)    (None, 30, 300)      17402100    tf_op_layer_strided_slice_3[0][0]
# __________________________________________________________________________________________________
# enc_body_parag_4 (Embedding)    (None, 30, 300)      17402100    tf_op_layer_strided_slice_4[0][0]
# __________________________________________________________________________________________________
# enc_body_parag_5 (Embedding)    (None, 30, 300)      17402100    tf_op_layer_strided_slice_5[0][0]
# __________________________________________________________________________________________________
# enc_body_parag_6 (Embedding)    (None, 30, 300)      17402100    tf_op_layer_strided_slice_6[0][0]
# __________________________________________________________________________________________________
# enc_body_parag_7 (Embedding)    (None, 30, 300)      17402100    tf_op_layer_strided_slice_7[0][0]
# __________________________________________________________________________________________________
# enc_body_parag_8 (Embedding)    (None, 30, 300)      17402100    tf_op_layer_strided_slice_8[0][0]
# __________________________________________________________________________________________________
# enc_body_parag_9 (Embedding)    (None, 30, 300)      17402100    tf_op_layer_strided_slice_9[0][0]
# __________________________________________________________________________________________________
# enc_answer_parag_0 (Embedding)  (None, 30, 300)      17402100    tf_op_layer_strided_slice_10[0][0
# __________________________________________________________________________________________________
# enc_answer_parag_1 (Embedding)  (None, 30, 300)      17402100    tf_op_layer_strided_slice_11[0][0
# __________________________________________________________________________________________________
# enc_answer_parag_2 (Embedding)  (None, 30, 300)      17402100    tf_op_layer_strided_slice_12[0][0
# __________________________________________________________________________________________________
# enc_answer_parag_3 (Embedding)  (None, 30, 300)      17402100    tf_op_layer_strided_slice_13[0][0
# __________________________________________________________________________________________________
# enc_answer_parag_4 (Embedding)  (None, 30, 300)      17402100    tf_op_layer_strided_slice_14[0][0
# __________________________________________________________________________________________________
# enc_answer_parag_5 (Embedding)  (None, 30, 300)      17402100    tf_op_layer_strided_slice_15[0][0
# __________________________________________________________________________________________________
# enc_answer_parag_6 (Embedding)  (None, 30, 300)      17402100    tf_op_layer_strided_slice_16[0][0
# __________________________________________________________________________________________________
# enc_answer_parag_7 (Embedding)  (None, 30, 300)      17402100    tf_op_layer_strided_slice_17[0][0
# __________________________________________________________________________________________________
# enc_answer_parag_8 (Embedding)  (None, 30, 300)      17402100    tf_op_layer_strided_slice_18[0][0
# __________________________________________________________________________________________________
# enc_answer_parag_9 (Embedding)  (None, 30, 300)      17402100    tf_op_layer_strided_slice_19[0][0
# __________________________________________________________________________________________________
# input_title_seq (InputLayer)    [(None, 30)]         0
# __________________________________________________________________________________________________
# spatial_dropout1d_1 (SpatialDro (None, 30, 300)      0           enc_body_parag_0[0][0]
# __________________________________________________________________________________________________
# spatial_dropout1d_2 (SpatialDro (None, 30, 300)      0           enc_body_parag_1[0][0]
# __________________________________________________________________________________________________
# spatial_dropout1d_3 (SpatialDro (None, 30, 300)      0           enc_body_parag_2[0][0]
# __________________________________________________________________________________________________
# spatial_dropout1d_4 (SpatialDro (None, 30, 300)      0           enc_body_parag_3[0][0]
# __________________________________________________________________________________________________
# spatial_dropout1d_5 (SpatialDro (None, 30, 300)      0           enc_body_parag_4[0][0]
# __________________________________________________________________________________________________
# spatial_dropout1d_6 (SpatialDro (None, 30, 300)      0           enc_body_parag_5[0][0]
# __________________________________________________________________________________________________
# spatial_dropout1d_7 (SpatialDro (None, 30, 300)      0           enc_body_parag_6[0][0]
# __________________________________________________________________________________________________
# spatial_dropout1d_8 (SpatialDro (None, 30, 300)      0           enc_body_parag_7[0][0]
# __________________________________________________________________________________________________
# spatial_dropout1d_9 (SpatialDro (None, 30, 300)      0           enc_body_parag_8[0][0]
# __________________________________________________________________________________________________
# spatial_dropout1d_10 (SpatialDr (None, 30, 300)      0           enc_body_parag_9[0][0]
# __________________________________________________________________________________________________
# spatial_dropout1d_12 (SpatialDr (None, 30, 300)      0           enc_answer_parag_0[0][0]
# __________________________________________________________________________________________________
# spatial_dropout1d_13 (SpatialDr (None, 30, 300)      0           enc_answer_parag_1[0][0]
# __________________________________________________________________________________________________
# spatial_dropout1d_14 (SpatialDr (None, 30, 300)      0           enc_answer_parag_2[0][0]
# __________________________________________________________________________________________________
# spatial_dropout1d_15 (SpatialDr (None, 30, 300)      0           enc_answer_parag_3[0][0]
# __________________________________________________________________________________________________
# spatial_dropout1d_16 (SpatialDr (None, 30, 300)      0           enc_answer_parag_4[0][0]
# __________________________________________________________________________________________________
# spatial_dropout1d_17 (SpatialDr (None, 30, 300)      0           enc_answer_parag_5[0][0]
# __________________________________________________________________________________________________
# spatial_dropout1d_18 (SpatialDr (None, 30, 300)      0           enc_answer_parag_6[0][0]
# __________________________________________________________________________________________________
# spatial_dropout1d_19 (SpatialDr (None, 30, 300)      0           enc_answer_parag_7[0][0]
# __________________________________________________________________________________________________
# spatial_dropout1d_20 (SpatialDr (None, 30, 300)      0           enc_answer_parag_8[0][0]
# __________________________________________________________________________________________________
# spatial_dropout1d_21 (SpatialDr (None, 30, 300)      0           enc_answer_parag_9[0][0]
# __________________________________________________________________________________________________
# embedding (Embedding)           (None, 30, 300)      17402100    input_title_seq[0][0]
# __________________________________________________________________________________________________
# lstm_1 (LSTM)                   (None, 30, 64)       93440       spatial_dropout1d_1[0][0]
# __________________________________________________________________________________________________
# lstm_2 (LSTM)                   (None, 30, 64)       93440       spatial_dropout1d_2[0][0]
# __________________________________________________________________________________________________
# lstm_3 (LSTM)                   (None, 30, 64)       93440       spatial_dropout1d_3[0][0]
# __________________________________________________________________________________________________
# lstm_4 (LSTM)                   (None, 30, 64)       93440       spatial_dropout1d_4[0][0]
# __________________________________________________________________________________________________
# lstm_5 (LSTM)                   (None, 30, 64)       93440       spatial_dropout1d_5[0][0]
# __________________________________________________________________________________________________
# lstm_6 (LSTM)                   (None, 30, 64)       93440       spatial_dropout1d_6[0][0]
# __________________________________________________________________________________________________
# lstm_7 (LSTM)                   (None, 30, 64)       93440       spatial_dropout1d_7[0][0]
# __________________________________________________________________________________________________
# lstm_8 (LSTM)                   (None, 30, 64)       93440       spatial_dropout1d_8[0][0]
# __________________________________________________________________________________________________
# lstm_9 (LSTM)                   (None, 30, 64)       93440       spatial_dropout1d_9[0][0]
# __________________________________________________________________________________________________
# lstm_10 (LSTM)                  (None, 30, 64)       93440       spatial_dropout1d_10[0][0]
# __________________________________________________________________________________________________
# lstm_12 (LSTM)                  (None, 30, 64)       93440       spatial_dropout1d_12[0][0]
# __________________________________________________________________________________________________
# lstm_13 (LSTM)                  (None, 30, 64)       93440       spatial_dropout1d_13[0][0]
# __________________________________________________________________________________________________
# lstm_14 (LSTM)                  (None, 30, 64)       93440       spatial_dropout1d_14[0][0]
# __________________________________________________________________________________________________
# lstm_15 (LSTM)                  (None, 30, 64)       93440       spatial_dropout1d_15[0][0]
# __________________________________________________________________________________________________
# lstm_16 (LSTM)                  (None, 30, 64)       93440       spatial_dropout1d_16[0][0]
# __________________________________________________________________________________________________
# lstm_17 (LSTM)                  (None, 30, 64)       93440       spatial_dropout1d_17[0][0]
# __________________________________________________________________________________________________
# lstm_18 (LSTM)                  (None, 30, 64)       93440       spatial_dropout1d_18[0][0]
# __________________________________________________________________________________________________
# lstm_19 (LSTM)                  (None, 30, 64)       93440       spatial_dropout1d_19[0][0]
# __________________________________________________________________________________________________
# lstm_20 (LSTM)                  (None, 30, 64)       93440       spatial_dropout1d_20[0][0]
# __________________________________________________________________________________________________
# lstm_21 (LSTM)                  (None, 30, 64)       93440       spatial_dropout1d_21[0][0]
# __________________________________________________________________________________________________
# spatial_dropout1d (SpatialDropo (None, 30, 300)      0           embedding[0][0]
# __________________________________________________________________________________________________
# concatenate (Concatenate)       (None, 30, 640)      0           lstm_1[0][0]
#                                                                  lstm_2[0][0]
#                                                                  lstm_3[0][0]
#                                                                  lstm_4[0][0]
#                                                                  lstm_5[0][0]
#                                                                  lstm_6[0][0]
#                                                                  lstm_7[0][0]
#                                                                  lstm_8[0][0]
#                                                                  lstm_9[0][0]
#                                                                  lstm_10[0][0]
# __________________________________________________________________________________________________
# concatenate_1 (Concatenate)     (None, 30, 640)      0           lstm_12[0][0]
#                                                                  lstm_13[0][0]
#                                                                  lstm_14[0][0]
#                                                                  lstm_15[0][0]
#                                                                  lstm_16[0][0]
#                                                                  lstm_17[0][0]
#                                                                  lstm_18[0][0]
#                                                                  lstm_19[0][0]
#                                                                  lstm_20[0][0]
#                                                                  lstm_21[0][0]
# __________________________________________________________________________________________________
# lstm (LSTM)                     (None, 30, 128)      219648      spatial_dropout1d[0][0]
# __________________________________________________________________________________________________
# spatial_dropout1d_11 (SpatialDr (None, 30, 640)      0           concatenate[0][0]
# __________________________________________________________________________________________________
# spatial_dropout1d_22 (SpatialDr (None, 30, 640)      0           concatenate_1[0][0]
# __________________________________________________________________________________________________
# global_average_pooling1d (Globa (None, 128)          0           lstm[0][0]
# __________________________________________________________________________________________________
# lstm_11 (LSTM)                  (None, 256)          918528      spatial_dropout1d_11[0][0]
# __________________________________________________________________________________________________
# lstm_22 (LSTM)                  (None, 256)          918528      spatial_dropout1d_22[0][0]
# __________________________________________________________________________________________________
# concatenate_2 (Concatenate)     (None, 640)          0           global_average_pooling1d[0][0]
#                                                                  lstm_11[0][0]
#                                                                  lstm_22[0][0]
# __________________________________________________________________________________________________
# dropout (Dropout)               (None, 640)          0           concatenate_2[0][0]
# __________________________________________________________________________________________________
# dense (Dense)                   (None, 512)          328192      dropout[0][0]
# __________________________________________________________________________________________________
# dropout_1 (Dropout)             (None, 512)          0           dense[0][0]
# __________________________________________________________________________________________________
# output (Dense)                  (None, 30)           15390       dropout_1[0][0]
# ==================================================================================================
# Total params: 369,713,186
# Trainable params: 4,269,086
# Non-trainable params: 365,444,100
# __________________________________________________________________________________________________

# %% [markdown]
# # Train model

# %%
rlrop = ReduceLROnPlateau(monitor='val_loss', mode='min', patience=RLROP_PATIENCE, factor=DECAY_DROP, min_lr=1e-7, verbose=1)
spearmanCallback = SpearmanRhoCallback(training_data=(X_train, Y_train), validation_data=(X_valid, Y_valid), monitor='val_loss', mode='min', patience=ES_PATIENCE)
callback_list = [rlrop, spearmanCallback]

optimizer = optimizers.Adam(LEARNING_RATE)
model.compile(optimizer=optimizer, loss='binary_crossentropy')

history = model.fit(X_train, Y_train, 
                    validation_data=(X_valid, Y_valid), 
                    callbacks=callback_list, 
                    batch_size=BATCH_SIZE, 
                    epochs=EPOCHS, 
                    verbose=2).history
# Out:
# Train on 4863 samples, validate on 1216 samples
# Epoch 1/50
# spearman-rho: 0.2084 val_spearman-rho: 0.2030
# 4863/4863 - 285s - loss: 0.4636 - val_loss: 0.4187
# Epoch 2/50
# spearman-rho: 0.2590 val_spearman-rho: 0.2502
# 4863/4863 - 211s - loss: 0.4195 - val_loss: 0.4065
# Epoch 3/50
# spearman-rho: 0.2833 val_spearman-rho: 0.2670
# 4863/4863 - 213s - loss: 0.4100 - val_loss: 0.4025
# Epoch 4/50
# spearman-rho: 0.3027 val_spearman-rho: 0.2812
# 4863/4863 - 212s - loss: 0.4050 - val_loss: 0.3997
# Epoch 5/50
# spearman-rho: 0.3202 val_spearman-rho: 0.2933
# 4863/4863 - 210s - loss: 0.4007 - val_loss: 0.3978
# Epoch 6/50
# spearman-rho: 0.3338 val_spearman-rho: 0.3000
# 4863/4863 - 208s - loss: 0.3971 - val_loss: 0.3955
# Epoch 7/50
# spearman-rho: 0.3430 val_spearman-rho: 0.3063
# 4863/4863 - 207s - loss: 0.3944 - val_loss: 0.3932
# Epoch 8/50
# spearman-rho: 0.3561 val_spearman-rho: 0.3107
# 4863/4863 - 212s - loss: 0.3919 - val_loss: 0.3915
# Epoch 9/50
# spearman-rho: 0.3644 val_spearman-rho: 0.3131
# 4863/4863 - 212s - loss: 0.3893 - val_loss: 0.3910
# Epoch 10/50
# spearman-rho: 0.3735 val_spearman-rho: 0.3183
# 4863/4863 - 208s - loss: 0.3869 - val_loss: 0.3898
# Epoch 11/50
# spearman-rho: 0.3844 val_spearman-rho: 0.3203
# 4863/4863 - 207s - loss: 0.3852 - val_loss: 0.3888
# Epoch 12/50
# spearman-rho: 0.3908 val_spearman-rho: 0.3224
# 4863/4863 - 211s - loss: 0.3828 - val_loss: 0.3904
# Epoch 13/50
# spearman-rho: 0.4011 val_spearman-rho: 0.3258
# 4863/4863 - 211s - loss: 0.3816 - val_loss: 0.3884
# Epoch 14/50
# spearman-rho: 0.4049 val_spearman-rho: 0.3248
# 4863/4863 - 210s - loss: 0.3794 - val_loss: 0.3892
# Epoch 15/50
# spearman-rho: 0.4151 val_spearman-rho: 0.3288
# 4863/4863 - 212s - loss: 0.3770 - val_loss: 0.3878
# Epoch 16/50
# spearman-rho: 0.4202 val_spearman-rho: 0.3271
# 4863/4863 - 212s - loss: 0.3757 - val_loss: 0.3874
# Epoch 17/50
# spearman-rho: 0.4286 val_spearman-rho: 0.3302
# 4863/4863 - 209s - loss: 0.3743 - val_loss: 0.3868
# Epoch 18/50
# spearman-rho: 0.4329 val_spearman-rho: 0.3264
# 4863/4863 - 210s - loss: 0.3727 - val_loss: 0.3880
# Epoch 19/50
#
# Epoch 00019: ReduceLROnPlateau reducing learning rate to 9.000000427477062e-05.
# spearman-rho: 0.4390 val_spearman-rho: 0.3287
# 4863/4863 - 210s - loss: 0.3706 - val_loss: 0.3882
# Epoch 20/50
# spearman-rho: 0.4463 val_spearman-rho: 0.3322
# 4863/4863 - 210s - loss: 0.3684 - val_loss: 0.3864
# Epoch 21/50
# spearman-rho: 0.4486 val_spearman-rho: 0.3337
# Epoch 00020: early stopping
# 4863/4863 - 210s - loss: 0.3674 - val_loss: 0.3865

# %% [markdown]
# ## Model loss graph

# %%
sns.set(style="whitegrid")
plot_metrics(history, metric_list=['loss', 'spearman'])

# %% [markdown]
# # Evaluation

# %%
preds_train = model.predict(X_train)
preds_val = model.predict(X_valid)

display(get_metrics(Y_train, preds_train, Y_valid, preds_val, target_cols).style.applymap(color_map))
# Out:
# <style  type="text/css" >
#     #T_4f4ec8fe_2c1e_11ea_a22b_3713c7c5edaarow0_col0 {
#             color:  black;
#         }    #T_4f4ec8fe_2c1e_11ea_a22b_3713c7c5edaarow0_col1 {
#             color:  black;
#         }    #T_4f4ec8fe_2c1e_11ea_a22b_3713c7c5edaarow0_col2 {
#             color:  black;
#         }    #T_4f4ec8fe_2c1e_11ea_a22b_3713c7c5edaarow1_col0 {
#             color:  black;
#         }    #T_4f4ec8fe_2c1e_11ea_a22b_3713c7c5edaarow1_col1 {
#             color:  black;
#         }    #T_4f4ec8fe_2c1e_11ea_a22b_3713c7c5edaarow1_col2 {
#             color:  black;
#         }    #T_4f4ec8fe_2c1e_11ea_a22b_3713c7c5edaarow2_col0 {
#             color:  black;
#         }    #T_4f4ec8fe_2c1e_11ea_a22b_3713c7c5edaarow2_col1 {
#             color:  black;
#         }    #T_4f4ec8fe_2c1e_11ea_a22b_3713c7c5edaarow2_col2 {
#             color:  black;
#         }    #T_4f4ec8fe_2c1e_11ea_a22b_3713c7c5edaarow3_col0 {
#             color:  black;
#         }    #T_4f4ec8fe_2c1e_11ea_a22b_3713c7c5edaarow3_col1 {
#             color:  black;
#         }    #T_4f4ec8fe_2c1e_11ea_a22b_3713c7c5edaarow3_col2 {
#             color:  black;
#         }    #T_4f4ec8fe_2c1e_11ea_a22b_3713c7c5edaarow4_col0 {
#             color:  black;
#         }    #T_4f4ec8fe_2c1e_11ea_a22b_3713c7c5edaarow4_col1 {
#             color:  black;
#         }    #T_4f4ec8fe_2c1e_11ea_a22b_3713c7c5edaarow4_col2 {
#             color:  orange;
#         }    #T_4f4ec8fe_2c1e_11ea_a22b_3713c7c5edaarow5_col0 {
#             color:  black;
#         }    #T_4f4ec8fe_2c1e_11ea_a22b_3713c7c5edaarow5_col1 {
#             color:  black;
#         }    #T_4f4ec8fe_2c1e_11ea_a22b_3713c7c5edaarow5_col2 {
#             color:  black;
#         }    #T_4f4ec8fe_2c1e_11ea_a22b_3713c7c5edaarow6_col0 {
#             color:  black;
#         }    #T_4f4ec8fe_2c1e_11ea_a22b_3713c7c5edaarow6_col1 {
#             color:  black;
#         }    #T_4f4ec8fe_2c1e_11ea_a22b_3713c7c5edaarow6_col2 {
#             color:  black;
#         }    #T_4f4ec8fe_2c1e_11ea_a22b_3713c7c5edaarow7_col0 {
#             color:  black;
#         }    #T_4f4ec8fe_2c1e_11ea_a22b_3713c7c5edaarow7_col1 {
#             color:  black;
#         }    #T_4f4ec8fe_2c1e_11ea_a22b_3713c7c5edaarow7_col2 {
#             color:  black;
#         }    #T_4f4ec8fe_2c1e_11ea_a22b_3713c7c5edaarow8_col0 {
#             color:  black;
#         }    #T_4f4ec8fe_2c1e_11ea_a22b_3713c7c5edaarow8_col1 {
#             color:  black;
#         }    #T_4f4ec8fe_2c1e_11ea_a22b_3713c7c5edaarow8_col2 {
#             color:  black;
#         }    #T_4f4ec8fe_2c1e_11ea_a22b_3713c7c5edaarow9_col0 {
#             color:  black;
#         }    #T_4f4ec8fe_2c1e_11ea_a22b_3713c7c5edaarow9_col1 {
#             color:  black;
#         }    #T_4f4ec8fe_2c1e_11ea_a22b_3713c7c5edaarow9_col2 {
#             color:  black;
#         }    #T_4f4ec8fe_2c1e_11ea_a22b_3713c7c5edaarow10_col0 {
#             color:  black;
#         }    #T_4f4ec8fe_2c1e_11ea_a22b_3713c7c5edaarow10_col1 {
#             color:  orange;
#         }    #T_4f4ec8fe_2c1e_11ea_a22b_3713c7c5edaarow10_col2 {
#             color:  purple;
#         }    #T_4f4ec8fe_2c1e_11ea_a22b_3713c7c5edaarow11_col0 {
#             color:  black;
#         }    #T_4f4ec8fe_2c1e_11ea_a22b_3713c7c5edaarow11_col1 {
#             color:  black;
#         }    #T_4f4ec8fe_2c1e_11ea_a22b_3713c7c5edaarow11_col2 {
#             color:  black;
#         }    #T_4f4ec8fe_2c1e_11ea_a22b_3713c7c5edaarow12_col0 {
#             color:  black;
#         }    #T_4f4ec8fe_2c1e_11ea_a22b_3713c7c5edaarow12_col1 {
#             color:  black;
#         }    #T_4f4ec8fe_2c1e_11ea_a22b_3713c7c5edaarow12_col2 {
#             color:  black;
#         }    #T_4f4ec8fe_2c1e_11ea_a22b_3713c7c5edaarow13_col0 {
#             color:  black;
#         }    #T_4f4ec8fe_2c1e_11ea_a22b_3713c7c5edaarow13_col1 {
#             color:  black;
#         }    #T_4f4ec8fe_2c1e_11ea_a22b_3713c7c5edaarow13_col2 {
#             color:  orange;
#         }    #T_4f4ec8fe_2c1e_11ea_a22b_3713c7c5edaarow14_col0 {
#             color:  black;
#         }    #T_4f4ec8fe_2c1e_11ea_a22b_3713c7c5edaarow14_col1 {
#             color:  orange;
#         }    #T_4f4ec8fe_2c1e_11ea_a22b_3713c7c5edaarow14_col2 {
#             color:  orange;
#         }    #T_4f4ec8fe_2c1e_11ea_a22b_3713c7c5edaarow15_col0 {
#             color:  black;
#         }    #T_4f4ec8fe_2c1e_11ea_a22b_3713c7c5edaarow15_col1 {
#             color:  black;
#         }    #T_4f4ec8fe_2c1e_11ea_a22b_3713c7c5edaarow15_col2 {
#             color:  orange;
#         }    #T_4f4ec8fe_2c1e_11ea_a22b_3713c7c5edaarow16_col0 {
#             color:  black;
#         }    #T_4f4ec8fe_2c1e_11ea_a22b_3713c7c5edaarow16_col1 {
#             color:  black;
#         }    #T_4f4ec8fe_2c1e_11ea_a22b_3713c7c5edaarow16_col2 {
#             color:  black;
#         }    #T_4f4ec8fe_2c1e_11ea_a22b_3713c7c5edaarow17_col0 {
#             color:  black;
#         }    #T_4f4ec8fe_2c1e_11ea_a22b_3713c7c5edaarow17_col1 {
#             color:  green;
#         }    #T_4f4ec8fe_2c1e_11ea_a22b_3713c7c5edaarow17_col2 {
#             color:  black;
#         }    #T_4f4ec8fe_2c1e_11ea_a22b_3713c7c5edaarow18_col0 {
#             color:  black;
#         }    #T_4f4ec8fe_2c1e_11ea_a22b_3713c7c5edaarow18_col1 {
#             color:  black;
#         }    #T_4f4ec8fe_2c1e_11ea_a22b_3713c7c5edaarow18_col2 {
#             color:  orange;
#         }    #T_4f4ec8fe_2c1e_11ea_a22b_3713c7c5edaarow19_col0 {
#             color:  black;
#         }    #T_4f4ec8fe_2c1e_11ea_a22b_3713c7c5edaarow19_col1 {
#             color:  black;
#         }    #T_4f4ec8fe_2c1e_11ea_a22b_3713c7c5edaarow19_col2 {
#             color:  black;
#         }    #T_4f4ec8fe_2c1e_11ea_a22b_3713c7c5edaarow20_col0 {
#             color:  black;
#         }    #T_4f4ec8fe_2c1e_11ea_a22b_3713c7c5edaarow20_col1 {
#             color:  purple;
#         }    #T_4f4ec8fe_2c1e_11ea_a22b_3713c7c5edaarow20_col2 {
#             color:  purple;
#         }    #T_4f4ec8fe_2c1e_11ea_a22b_3713c7c5edaarow21_col0 {
#             color:  black;
#         }    #T_4f4ec8fe_2c1e_11ea_a22b_3713c7c5edaarow21_col1 {
#             color:  black;
#         }    #T_4f4ec8fe_2c1e_11ea_a22b_3713c7c5edaarow21_col2 {
#             color:  black;
#         }    #T_4f4ec8fe_2c1e_11ea_a22b_3713c7c5edaarow22_col0 {
#             color:  black;
#         }    #T_4f4ec8fe_2c1e_11ea_a22b_3713c7c5edaarow22_col1 {
#             color:  black;
#         }    #T_4f4ec8fe_2c1e_11ea_a22b_3713c7c5edaarow22_col2 {
#             color:  orange;
#         }    #T_4f4ec8fe_2c1e_11ea_a22b_3713c7c5edaarow23_col0 {
#             color:  black;
#         }    #T_4f4ec8fe_2c1e_11ea_a22b_3713c7c5edaarow23_col1 {
#             color:  black;
#         }    #T_4f4ec8fe_2c1e_11ea_a22b_3713c7c5edaarow23_col2 {
#             color:  black;
#         }    #T_4f4ec8fe_2c1e_11ea_a22b_3713c7c5edaarow24_col0 {
#             color:  black;
#         }    #T_4f4ec8fe_2c1e_11ea_a22b_3713c7c5edaarow24_col1 {
#             color:  orange;
#         }    #T_4f4ec8fe_2c1e_11ea_a22b_3713c7c5edaarow24_col2 {
#             color:  purple;
#         }    #T_4f4ec8fe_2c1e_11ea_a22b_3713c7c5edaarow25_col0 {
#             color:  black;
#         }    #T_4f4ec8fe_2c1e_11ea_a22b_3713c7c5edaarow25_col1 {
#             color:  orange;
#         }    #T_4f4ec8fe_2c1e_11ea_a22b_3713c7c5edaarow25_col2 {
#             color:  purple;
#         }    #T_4f4ec8fe_2c1e_11ea_a22b_3713c7c5edaarow26_col0 {
#             color:  black;
#         }    #T_4f4ec8fe_2c1e_11ea_a22b_3713c7c5edaarow26_col1 {
#             color:  black;
#         }    #T_4f4ec8fe_2c1e_11ea_a22b_3713c7c5edaarow26_col2 {
#             color:  orange;
#         }    #T_4f4ec8fe_2c1e_11ea_a22b_3713c7c5edaarow27_col0 {
#             color:  black;
#         }    #T_4f4ec8fe_2c1e_11ea_a22b_3713c7c5edaarow27_col1 {
#             color:  green;
#         }    #T_4f4ec8fe_2c1e_11ea_a22b_3713c7c5edaarow27_col2 {
#             color:  black;
#         }    #T_4f4ec8fe_2c1e_11ea_a22b_3713c7c5edaarow28_col0 {
#             color:  black;
#         }    #T_4f4ec8fe_2c1e_11ea_a22b_3713c7c5edaarow28_col1 {
#             color:  black;
#         }    #T_4f4ec8fe_2c1e_11ea_a22b_3713c7c5edaarow28_col2 {
#             color:

# %% [markdown]
# ## By category

# %%
target_cols_preds = [col+'_pred' for col in target_cols]
for col in target_cols_preds:
    train[col] = 0
    validation[col] = 0
    
train[target_cols_preds] = preds_train
validation[target_cols_preds] = preds_val
    
display(get_metrics_category(train, validation, target_cols, target_cols_preds, 'category').style.applymap(color_map))
# Out:
# <style  type="text/css" >
#     #T_4fa82890_2c1e_11ea_a22b_3713c7c5edaarow0_col0 {
#             color:  black;
#         }    #T_4fa82890_2c1e_11ea_a22b_3713c7c5edaarow0_col1 {
#             color:  black;
#         }    #T_4fa82890_2c1e_11ea_a22b_3713c7c5edaarow0_col2 {
#             color:  orange;
#         }    #T_4fa82890_2c1e_11ea_a22b_3713c7c5edaarow0_col3 {
#             color:  black;
#         }    #T_4fa82890_2c1e_11ea_a22b_3713c7c5edaarow0_col4 {
#             color:  black;
#         }    #T_4fa82890_2c1e_11ea_a22b_3713c7c5edaarow0_col5 {
#             color:  black;
#         }    #T_4fa82890_2c1e_11ea_a22b_3713c7c5edaarow0_col6 {
#             color:  orange;
#         }    #T_4fa82890_2c1e_11ea_a22b_3713c7c5edaarow0_col7 {
#             color:  black;
#         }    #T_4fa82890_2c1e_11ea_a22b_3713c7c5edaarow0_col8 {
#             color:  black;
#         }    #T_4fa82890_2c1e_11ea_a22b_3713c7c5edaarow0_col9 {
#             color:  black;
#         }    #T_4fa82890_2c1e_11ea_a22b_3713c7c5edaarow0_col10 {
#             color:  black;
#         }</style><table id="T_4fa82890_2c1e_11ea_a22b_3713c7c5edaa" ><thead>    <tr>        <th class="blank level0" ></th>        <th class="col_heading level0 col0" >Label</th>        <th class="col_heading level0 col1" >Train (TECHNOLOGY)</th>        <th class="col_heading level0 col2" >Validation (TECHNOLOGY)</th>        <th class="col_heading level0 col3" >Train (SCIENCE)</th>        <th class="col_heading level0 col4" >Validation (SCIENCE)</th>        <th class="col_heading level0 col5" >Train (STACKOVERFLOW)</th>        <th class="col_heading level0 col6" >Validation (STACKOVERFLOW)</th>        <th class="col_heading level0 col7" >Train (LIFE_ARTS)</th>        <th class="col_heading level0 col8" >Validation (LIFE_ARTS)</th>        <th class="col_heading level0 col9" >Train (CULTURE)</th>        <th class="col_heading level0 col10" >Validation (CULTURE)</th>    </tr></thead><tbody>
#                 <tr>
#                         <th id="T_4fa82890_2c1e_11ea_a22b_3713c7c5edaalevel0_row0" class="row_heading level0 row0" >0</th>
#                         <td id="T_4fa82890_2c1e_11ea_a22b_3713c7c5edaarow0_col0" class="data row0 col0" >Averaged</td>
#                         <td id="T_4fa82890_2c1e_11ea_a22b_3713c7c5edaarow0_col1" class="data row0 col1" >0.421</td>
#                         <td id="T_4fa82890_2c1e_11ea_a22b_3713c7c5edaarow0_col2" class="data row0 col2" >0.294</td>
#                         <td id="T_4fa82890_2c1e_11ea_a22b_3713c7c5edaarow0_col3" class="data row0 col3" >0.459</td>
#                         <td id="T_4fa82890_2c1e_11ea_a22b_3713c7c5edaarow0_col4" class="data row0 col4" >0.308</td>
#                         <td id="T_4fa82890_2c1e_11ea_a22b_3713c7c5edaarow0_col5" class="data row0 col5" >0.371</td>
#                         <td id="T_4fa82890_2c1e_11ea_a22b_3713c7c5edaarow0_col6" class="data row0 col6" >0.203</td>
#                         <td id="T_4fa82890_2c1e_11ea_a22b_3713c7c5edaarow0_col7" class="data row0 col7" >0.438</td>
#                         <td id="T_4fa82890_2c1e_11ea_a22b_3713c7c5edaarow0_col8" class="data row0 col8" >0.341</td>
#                         <td id="T_4fa82890_2c1e_11ea_a22b_3713c7c5edaarow0_col9" class="data row0 col9" >0.422</td>
#                         <td id="T_4fa82890_2c1e_11ea_a22b_3713c7c5edaarow0_col10" class="data row0 col10" >0.325</td>
#             </tr>
#     </tbody></table>

# %% [markdown]
# #### Save model weights and ecoders

# %%
model.save_weights(model_path)
dump(tokenizer, tokenizer_path)
# Out:
# ['/kaggle/working/tokenizer.joblib']
