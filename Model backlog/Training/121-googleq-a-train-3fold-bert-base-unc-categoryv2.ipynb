# %% [markdown]
# ## Dependencies

# %%
import glob
import warnings
from joblib import dump
from tensorflow_hub import KerasLayer
from sklearn.preprocessing import OneHotEncoder
from tensorflow.keras import Model, optimizers
from tensorflow.keras.callbacks import ReduceLROnPlateau
from tensorflow.keras.layers import Input, Dense, Dropout, GlobalAveragePooling1D, SpatialDropout1D, Concatenate
from googleqa_utilityscript import *
from googleqa_map_utilityscript import *
from script_lr_schedulers import WarmUpLearningRateScheduler
import bert_tokenization as tokenization


SEED = 0
seed_everything(SEED)
warnings.filterwarnings("ignore")
# Out:
# Using TensorFlow backend.

# %% [markdown]
# ## Load data

# %%
BERT_PATH = '/kaggle/input/tf-hub-bert-base/bert_base_uncased'
VOCAB_PATH = BERT_PATH + '/assets/vocab.txt'
category_encoder_path = '/kaggle/working/category_encoder.joblib'

k_fold = pd.read_csv('/kaggle/input/googleqa-mldataset/5-fold.csv')
N_FOLDS = 3

print('Samples: %s' % len(k_fold))
display(k_fold.head())
# Out:
# Samples: 6079
#    qa_id                                     question_title  \
# 0      0  What am I losing when using extension tubes in...
# 1      1  What is the distinction between a city and a s...
# 2      2  Maximum protusion length for through-hole comp...
# 3      3              Can an affidavit be used in Beit Din?
# 4      5       How do you make a binary image in Photoshop?
#
#                                        question_body question_user_name  \
# 0  After playing around with macro photography on...               ysap
# 1  I am trying to understand what kinds of places...      russellpierce
# 2  I'm working on a PCB that has through-hole com...          Joe Baker
# 3  An affidavit, from what i understand, is basic...         Scimonster
# 4  I am trying to make a binary image. I want mor...            leigero
#
#                                   question_user_page  \
# 0         https://photo.stackexchange.com/users/1024
# 1           https://rpg.stackexchange.com/users/8774
# 2  https://electronics.stackexchange.com/users/10157
# 3       https://judaism.stackexchange.com/users/5151
# 4  https://graphicdesign.stackexchange.com/users/...
#
#                                               answer answer_user_name  \
# 0  I just got extension tubes, so here's the skin...           rfusca
# 1  It might be helpful to look into the definitio...     Erik Schmidt
# 2  Do you even need grooves?  We make several pro...      Dwayne Reid
# 3  Sending an "affidavit" it is a dispute between...    Y     e     z
# 4  Check out Image Trace in Adobe Illustrator. \n...             q2ra
#
#                                     answer_user_page  \
# 0         https://photo.stackexchange.com/users/1917
# 1           https://rpg.stackexchange.com/users/1871
# 2  https://electronics.stackexchange.com/users/64754
# 3       https://judaism.stackexchange.com/users/4794
# 4  https://graphicdesign.stackexchange.com/users/...
#
#                                                  url   category  ...  \
# 0  http://photo.stackexchange.com/questions/9169/...  LIFE_ARTS  ...
# 1  http://rpg.stackexchange.com/questions/47820/w...    CULTURE  ...
# 2  http://electronics.stackexchange.com/questions...    SCIENCE  ...
# 3  http://judaism.stackexchange.com/questions/551...    CULTURE  ...
# 4  http://graphicdesign.stackexchange.com/questio...  LIFE_ARTS  ...
#
#   answer_satisfaction  answer_type_instructions  answer_type_procedure  \
# 0            0.800000                       1.0               0.000000
# 1            0.666667                       0.0               0.000000
# 2            0.666667                       0.0               0.333333
# 3            0.800000                       0.0               0.000000
# 4            0.800000                       1.0               0.000000
#
#    answer_type_reason_explanation  answer_well_written      fold_1  fold_2  \
# 0                        0.000000             1.000000       train   train
# 1                        0.666667             0.888889  validation   train
# 2                        1.000000             0.888889       train   train
# 3                        1.000000             1.000000       train   train
# 4                        1.000000             1.000000  validation   train
#
#        fold_3      fold_4      fold_5
# 0       train  validation       train
# 1       train       train       train
# 2  validation       train       train
# 3       train       train  validation
# 4       train       train       train
#
# [5 rows x 46 columns]

# %%
question_target_cols = ['question_asker_intent_understanding','question_body_critical', 'question_conversational', 
                        'question_expect_short_answer', 'question_fact_seeking', 'question_has_commonly_accepted_answer',
                        'question_interestingness_others', 'question_interestingness_self', 'question_multi_intent', 
                        'question_not_really_a_question', 'question_opinion_seeking', 'question_type_choice',
                        'question_type_compare', 'question_type_consequence', 'question_type_definition', 
                        'question_type_entity', 'question_type_instructions', 'question_type_procedure',
                        'question_type_reason_explanation', 'question_type_spelling', 'question_well_written']
answer_target_cols = ['answer_helpful', 'answer_level_of_information', 'answer_plausible', 'answer_relevance',
                      'answer_satisfaction', 'answer_type_instructions', 'answer_type_procedure', 
                      'answer_type_reason_explanation', 'answer_well_written']
target_cols = question_target_cols + answer_target_cols

# %% [markdown]
# # Pre-process data

# %%
text_features = ['question_title', 'question_body', 'answer']

for feature in text_features:
    # Lower
    k_fold[feature] = k_fold[feature].apply(lambda x: x.lower())
    # Map misspellings
    k_fold[feature] = k_fold[feature].apply(lambda x: map_misspellings(x))
    # Map contractions
    k_fold[feature] = k_fold[feature].apply(lambda x: map_contraction(x))
    # Trim text
    k_fold[feature] = k_fold[feature].apply(lambda x: x.strip())
    
ohe_category = OneHotEncoder(handle_unknown='ignore')
ohe_category = ohe_category.fit(k_fold[['category']])
# Save encoder
dump(ohe_category, category_encoder_path)
# Out:
# ['/kaggle/working/category_encoder.joblib']

# %% [markdown]
# # Model parameters

# %%
EPOCHS = 8
BATCH_SIZE = 8
LEARNING_RATE = 3e-5
N_CLASS = len(target_cols)
ES_PATIENCE = 2
MAX_SEQUENCE_LENGTH = 512
RLROP_PATIENCE = 1
DECAY_DROP = 0.1
N_CLASS_CAT = k_fold['category'].nunique()

# %% [markdown]
# # Model

# %%
def model_fn():
    input_word_ids = Input((MAX_SEQUENCE_LENGTH,), dtype=tf.int32, name='input_word_ids')
    input_masks = Input((MAX_SEQUENCE_LENGTH,), dtype=tf.int32, name='input_masks')
    segment_ids = Input((MAX_SEQUENCE_LENGTH,), dtype=tf.int32, name='segment_ids')

    bert_layer = KerasLayer(BERT_PATH, trainable=True)
    pooled_output, sequence_output = bert_layer([input_word_ids, input_masks, segment_ids])

    x = GlobalAveragePooling1D()(sequence_output)
    x = Dropout(0.2)(x)
    output_seq = Dense(N_CLASS, activation="sigmoid", name="output_seq")(x)
    output_class = Dense(N_CLASS_CAT, activation="softmax", name="output_class")(pooled_output)

    model = Model(inputs=[input_word_ids, input_masks, segment_ids], outputs=[output_seq, output_class])
    
    return model

# %% [markdown]
# # Train model

# %%
rlrop = ReduceLROnPlateau(monitor='val_loss', mode='min', patience=RLROP_PATIENCE, 
                          factor=DECAY_DROP, min_lr=1e-7, verbose=1)    
tokenizer = tokenization.FullTokenizer(VOCAB_PATH, True)

history_list = []
metric_list = []
category_metric_list = []
target_cols_preds = [col+'_pred' for col in target_cols]

for n_fold in range(N_FOLDS):
    ### Data
    train = k_fold[k_fold['fold_%d' % (n_fold+1)] == 'train']
    validation = k_fold[k_fold['fold_%d' % (n_fold+1)] == 'validation']
    
    ### Create features
    # Train features
    X_train = compute_input_arays(train, text_features, tokenizer, MAX_SEQUENCE_LENGTH)
    Y_train_category = ohe_category.transform(train[['category']]).toarray()
    Y_train = [train[target_cols].values, Y_train_category]
    
    # Validation features
    X_valid = compute_input_arays(validation, text_features, tokenizer, MAX_SEQUENCE_LENGTH)
    Y_valid_category = ohe_category.transform(validation[['category']]).toarray()
    Y_valid = [validation[target_cols].values, Y_valid_category]

    ### Train model
    model_path = '/kaggle/working/model_fold_%d' % (n_fold+1)
    spearmanCallback = SpearmanRhoCallback_multi(training_data=(X_train, Y_train), 
                                                 validation_data=(X_valid, Y_valid), 
                                                 model_path=model_path, 
                                                 monitor='val_loss', mode='min', 
                                                 patience=ES_PATIENCE, checkpoint=True)
    LR_WARMUP_EPOCHS = 2
    WARMUP_BATCHES = LR_WARMUP_EPOCHS * len(train) // BATCH_SIZE
    warmup_lr = WarmUpLearningRateScheduler(WARMUP_BATCHES, LEARNING_RATE)

    callback_list = [spearmanCallback, rlrop, warmup_lr]
    optimizer = optimizers.Adam(lr=LEARNING_RATE)
    model = model_fn()
    model.compile(optimizer=optimizer, loss=['binary_crossentropy', 'categorical_crossentropy'])

    history = model.fit(X_train, Y_train, 
                        validation_data=(X_valid, Y_valid), 
                        callbacks=callback_list, 
                        batch_size=BATCH_SIZE, 
                        epochs=EPOCHS, 
                        verbose=2).history
    history_list.append(history)
    
    ### Evaluation - Label metrics
    model.load_weights(model_path+'.h5')
    preds_train = model.predict(X_train)[0][: ,:N_CLASS]
    preds_val = model.predict(X_valid)[0][: ,:N_CLASS]
    metric_list.append(get_metrics(Y_train[0], preds_train, Y_valid[0], preds_val, target_cols))
    
    ### Evaluation - Category metrics
    for col in target_cols_preds:
        train[col] = 0
        validation[col] = 0

    train[target_cols_preds] = preds_train
    validation[target_cols_preds] = preds_val
    category_metric_list.append(get_metrics_category(train, validation, target_cols, target_cols_preds, 'category'))
# Out:
# Train on 4864 samples, validate on 1215 samples
# Epoch 1/8
# spearman-rho: 0.1946 val_spearman-rho: 0.1856
# Saved model weights at "/kaggle/working/model_fold_1.h5"
# 4864/4864 - 508s - loss: 1.4295 - output_seq_loss: 0.5004 - output_class_loss: 0.9290 - val_loss: 0.8371 - val_output_seq_loss: 0.4113 - val_output_class_loss: 0.4259
# Epoch 2/8
# spearman-rho: 0.2630 val_spearman-rho: 0.2524
# Saved model weights at "/kaggle/working/model_fold_1.h5"
# 4864/4864 - 476s - loss: 0.7479 - output_seq_loss: 0.4126 - output_class_loss: 0.3353 - val_loss: 0.7296 - val_output_seq_loss: 0.4003 - val_output_class_loss: 0.3293
# Epoch 3/8
# spearman-rho: 0.3125 val_spearman-rho: 0.3000
# Saved model weights at "/kaggle/working/model_fold_1.h5"
# 4864/4864 - 476s - loss: 0.5842 - output_seq_loss: 0.4009 - output_class_loss: 0.1833 - val_loss: 0.7053 - val_output_seq_loss: 0.3925 - val_output_class_loss: 0.3128
# Epoch 4/8
# spearman-rho: 0.3511 val_spearman-rho: 0.3302
#
# Epoch 00004: ReduceLROnPlateau reducing learning rate to 2.9999999242136257e-06.
# 4864/4864 - 475s - loss: 0.4644 - output_seq_loss: 0.3892 - output_class_loss: 0.0753 - val_loss: 0.7085 - val_output_seq_loss: 0.3813 - val_output_class_loss: 0.3274
# Epoch 5/8
# spearman-rho: 0.3679 val_spearman-rho: 0.3446
# Saved model weights at "/kaggle/working/model_fold_1.h5"
# 4864/4864 - 476s - loss: 0.4035 - output_seq_loss: 0.3790 - output_class_loss: 0.0245 - val_loss: 0.6518 - val_output_seq_loss: 0.3769 - val_output_class_loss: 0.2750
# Epoch 6/8
# spearman-rho: 0.3767 val_spearman-rho: 0.3508
# Epoch 00005: early stopping
#
# Epoch 00006: ReduceLROnPlateau reducing learning rate to 2.9999998787388907e-07.
# 4864/4864 - 475s - loss: 0.3813 - output_seq_loss: 0.3757 - output_class_loss: 0.0056 - val_loss: 0.6635 - val_output_seq_loss: 0.3762 - val_output_class_loss: 0.2875
# Train on 4864 samples, validate on 1215 samples
# Epoch 1/8
# spearman-rho: 0.1887 val_spearman-rho: 0.1792
# Saved model weights at "/kaggle/working/model_fold_2.h5"
# 4864/4864 - 506s - loss: 1.4680 - output_seq_loss: 0.5062 - output_class_loss: 0.9618 - val_loss: 1.0008 - val_output_seq_loss: 0.4163 - val_output_class_loss: 0.5845
# Epoch 2/8
# spearman-rho: 0.2636 val_spearman-rho: 0.2511
# Saved model weights at "/kaggle/working/model_fold_2.h5"
# 4864/4864 - 476s - loss: 0.7911 - output_seq_loss: 0.4134 - output_class_loss: 0.3777 - val_loss: 0.7277 - val_output_seq_loss: 0.4010 - val_output_class_loss: 0.3266
# Epoch 3/8
# spearman-rho: 0.3168 val_spearman-rho: 0.2952
# Saved model weights at "/kaggle/working/model_fold_2.h5"
# 4864/4864 - 476s - loss: 0.6036 - output_seq_loss: 0.4006 - output_class_loss: 0.2030 - val_loss: 0.7069 - val_output_seq_loss: 0.3892 - val_output_class_loss: 0.3175
# Epoch 4/8
# spearman-rho: 0.3653 val_spearman-rho: 0.3319
# Saved model weights at "/kaggle/working/model_fold_2.h5"
# 4864/4864 - 476s - loss: 0.4702 - output_seq_loss: 0.3869 - output_class_loss: 0.0833 - val_loss: 0.6618 - val_output_seq_loss: 0.3802 - val_output_class_loss: 0.2814
# Epoch 5/8
# spearman-rho: 0.3974 val_spearman-rho: 0.3562
#
# Epoch 00005: ReduceLROnPlateau reducing learning rate to 2.9999999242136257e-06.
# 4864/4864 - 475s - loss: 0.4299 - output_seq_loss: 0.3776 - output_class_loss: 0.0523 - val_loss: 0.6759 - val_output_seq_loss: 0.3748 - val_output_class_loss: 0.3009
# Epoch 6/8
# spearman-rho: 0.4052 val_spearman-rho: 0.3599
# Saved model weights at "/kaggle/working/model_fold_2.h5"
# 4864/4864 - 476s - loss: 0.3750 - output_seq_loss: 0.3675 - output_class_loss: 0.0075 - val_loss: 0.6471 - val_output_seq_loss: 0.3730 - val_output_class_loss: 0.2739
# Epoch 7/8
# spearman-rho: 0.4114 val_spearman-rho: 0.3614
# Epoch 00006: early stopping
#
# Epoch 00007: ReduceLROnPlateau reducing learning rate to 2.9999998787388907e-07.
# 4864/4864 - 475s - loss: 0.3681 - output_seq_loss: 0.3663 - output_class_loss: 0.0018 - val_loss: 0.6606 - val_output_seq_loss: 0.3728 - val_output_class_loss: 0.2876
# Train on 4859 samples, validate on 1220 samples
# Epoch 1/8
# spearman-rho: 0.1861 val_spearman-rho: 0.1787
# Saved model weights at "/kaggle/working/model_fold_3.h5"
# 4859/4859 - 508s - loss: 1.3820 - output_seq_loss: 0.4920 - output_class_loss: 0.8895 - val_loss: 0.9227 - val_output_seq_loss: 0.4141 - val_output_class_loss: 0.5102
# Epoch 2/8
# spearman-rho: 0.2537 val_spearman-rho: 0.2433
# Saved model weights at "/kaggle/working/model_fold_3.h5"
# 4859/4859 - 478s - loss: 0.7668 - output_seq_loss: 0.4137 - output_class_loss: 0.3526 - val_loss: 0.7005 - val_output_seq_loss: 0.4034 - val_output_class_loss: 0.2979
# Epoch 3/8
# spearman-rho: 0.3064 val_spearman-rho: 0.2927
# Saved model weights at "/kaggle/working/model_fold_3.h5"
# 4859/4859 - 478s - loss: 0.5702 - output_seq_loss: 0.4026 - output_class_loss: 0.1675 - val_loss: 0.6563 - val_output_seq_loss: 0.3907 - val_output_class_loss: 0.2646
# Epoch 4/8
# spearman-rho: 0.3471 val_spearman-rho: 0.3252
# Saved model weights at "/kaggle/working/model_fold_3.h5"
# 4859/4859 - 478s - loss: 0.4680 - output_seq_loss: 0.3896 - output_class_loss: 0.0783 - val_loss: 0.6229 - val_output_seq_loss: 0.3813 - val_output_class_loss: 0.2410
# Epoch 5/8
# spearman-rho: 0.3806 val_spearman-rho: 0.3470
#
# Epoch 00005: ReduceLROnPlateau reducing learning rate to 2.9999999242136257e-06.
# 4859/4859 - 477s - loss: 0.4285 - output_seq_loss: 0.3789 - output_class_loss: 0.0495 - val_loss: 0.7675 - val_output_seq_loss: 0.3788 - val_output_class_loss: 0.3874
# Epoch 6/8
# spearman-rho: 0.3943 val_spearman-rho: 0.3594
# Epoch 00005: early stopping
#
# Epoch 00006: ReduceLROnPlateau reducing learning rate to 2.9999998787388907e-07.
# 4859/4859 - 477s - loss: 0.3866 - output_seq_loss: 0.3708 - output_class_loss: 0.0158 - val_loss: 0.6663 - val_output_seq_loss: 0.3727 - val_output_class_loss: 0.2925

# %% [markdown]
# ## Model loss graph

# %%
for n_fold in range(N_FOLDS):
    print('Fold: %d' % n_fold)
    sns.set(style="whitegrid")
    plot_metrics(history_list[n_fold], metric_list=['loss', 'spearman'])
# Out:
# Fold: 0
# Fold: 1
# Fold: 2

# %% [markdown]
# # Evaluation

# %%
metrics_df = metric_list[0][['Label', 'Train', 'Validation']].copy()
metrics_df.columns = ['Label', 'Train_fold_0', 'Valid_fold_0']

for n_fold in range(1, N_FOLDS):
    metrics_df_idx = metric_list[n_fold][['Train', 'Validation']].copy()
    metrics_df_idx.columns = ['Train_fold_%d' % n_fold, 'Valid_fold_%d' % n_fold]
    metrics_df = pd.concat([metrics_df, metrics_df_idx], axis=1)

metrics_df['Train'] = 0
metrics_df['Validation'] = 0
for n_fold in range(N_FOLDS):
    metrics_df['Train'] += metrics_df['Train_fold_%d' % n_fold] / N_FOLDS
    metrics_df['Validation'] += metrics_df['Valid_fold_%d' % n_fold] / N_FOLDS

metrics_df['Var'] = metrics_df['Train'] - metrics_df['Validation']
display(metrics_df.style.applymap(color_map))
# Out:
# <style  type="text/css" >
#     #T_784d8a6c_3815_11ea_80f2_4149ab65b6fdrow0_col0 {
#             color:  black;
#         }    #T_784d8a6c_3815_11ea_80f2_4149ab65b6fdrow0_col1 {
#             color:  black;
#         }    #T_784d8a6c_3815_11ea_80f2_4149ab65b6fdrow0_col2 {
#             color:  black;
#         }    #T_784d8a6c_3815_11ea_80f2_4149ab65b6fdrow0_col3 {
#             color:  black;
#         }    #T_784d8a6c_3815_11ea_80f2_4149ab65b6fdrow0_col4 {
#             color:  black;
#         }    #T_784d8a6c_3815_11ea_80f2_4149ab65b6fdrow0_col5 {
#             color:  black;
#         }    #T_784d8a6c_3815_11ea_80f2_4149ab65b6fdrow0_col6 {
#             color:  black;
#         }    #T_784d8a6c_3815_11ea_80f2_4149ab65b6fdrow0_col7 {
#             color:  black;
#         }    #T_784d8a6c_3815_11ea_80f2_4149ab65b6fdrow0_col8 {
#             color:  black;
#         }    #T_784d8a6c_3815_11ea_80f2_4149ab65b6fdrow0_col9 {
#             color:  purple;
#         }    #T_784d8a6c_3815_11ea_80f2_4149ab65b6fdrow1_col0 {
#             color:  black;
#         }    #T_784d8a6c_3815_11ea_80f2_4149ab65b6fdrow1_col1 {
#             color:  black;
#         }    #T_784d8a6c_3815_11ea_80f2_4149ab65b6fdrow1_col2 {
#             color:  black;
#         }    #T_784d8a6c_3815_11ea_80f2_4149ab65b6fdrow1_col3 {
#             color:  black;
#         }    #T_784d8a6c_3815_11ea_80f2_4149ab65b6fdrow1_col4 {
#             color:  black;
#         }    #T_784d8a6c_3815_11ea_80f2_4149ab65b6fdrow1_col5 {
#             color:  black;
#         }    #T_784d8a6c_3815_11ea_80f2_4149ab65b6fdrow1_col6 {
#             color:  black;
#         }    #T_784d8a6c_3815_11ea_80f2_4149ab65b6fdrow1_col7 {
#             color:  black;
#         }    #T_784d8a6c_3815_11ea_80f2_4149ab65b6fdrow1_col8 {
#             color:  black;
#         }    #T_784d8a6c_3815_11ea_80f2_4149ab65b6fdrow1_col9 {
#             color:  purple;
#         }    #T_784d8a6c_3815_11ea_80f2_4149ab65b6fdrow2_col0 {
#             color:  black;
#         }    #T_784d8a6c_3815_11ea_80f2_4149ab65b6fdrow2_col1 {
#             color:  black;
#         }    #T_784d8a6c_3815_11ea_80f2_4149ab65b6fdrow2_col2 {
#             color:  orange;
#         }    #T_784d8a6c_3815_11ea_80f2_4149ab65b6fdrow2_col3 {
#             color:  black;
#         }    #T_784d8a6c_3815_11ea_80f2_4149ab65b6fdrow2_col4 {
#             color:  orange;
#         }    #T_784d8a6c_3815_11ea_80f2_4149ab65b6fdrow2_col5 {
#             color:  orange;
#         }    #T_784d8a6c_3815_11ea_80f2_4149ab65b6fdrow2_col6 {
#             color:  orange;
#         }    #T_784d8a6c_3815_11ea_80f2_4149ab65b6fdrow2_col7 {
#             color:  black;
#         }    #T_784d8a6c_3815_11ea_80f2_4149ab65b6fdrow2_col8 {
#             color:  orange;
#         }    #T_784d8a6c_3815_11ea_80f2_4149ab65b6fdrow2_col9 {
#             color:  purple;
#         }    #T_784d8a6c_3815_11ea_80f2_4149ab65b6fdrow3_col0 {
#             color:  black;
#         }    #T_784d8a6c_3815_11ea_80f2_4149ab65b6fdrow3_col1 {
#             color:  black;
#         }    #T_784d8a6c_3815_11ea_80f2_4149ab65b6fdrow3_col2 {
#             color:  black;
#         }    #T_784d8a6c_3815_11ea_80f2_4149ab65b6fdrow3_col3 {
#             color:  black;
#         }    #T_784d8a6c_3815_11ea_80f2_4149ab65b6fdrow3_col4 {
#             color:  black;
#         }    #T_784d8a6c_3815_11ea_80f2_4149ab65b6fdrow3_col5 {
#             color:  black;
#         }    #T_784d8a6c_3815_11ea_80f2_4149ab65b6fdrow3_col6 {
#             color:  orange;
#         }    #T_784d8a6c_3815_11ea_80f2_4149ab65b6fdrow3_col7 {
#             color:  black;
#         }    #T_784d8a6c_3815_11ea_80f2_4149ab65b6fdrow3_col8 {
#             color:  black;
#         }    #T_784d8a6c_3815_11ea_80f2_4149ab65b6fdrow3_col9 {
#             color:  purple;
#         }    #T_784d8a6c_3815_11ea_80f2_4149ab65b6fdrow4_col0 {
#             color:  black;
#         }    #T_784d8a6c_3815_11ea_80f2_4149ab65b6fdrow4_col1 {
#             color:  black;
#         }    #T_784d8a6c_3815_11ea_80f2_4149ab65b6fdrow4_col2 {
#             color:  black;
#         }    #T_784d8a6c_3815_11ea_80f2_4149ab65b6fdrow4_col3 {
#             color:  black;
#         }    #T_784d8a6c_3815_11ea_80f2_4149ab65b6fdrow4_col4 {
#             color:  black;
#         }    #T_784d8a6c_3815_11ea_80f2_4149ab65b6fdrow4_col5 {
#             color:  black;
#         }    #T_784d8a6c_3815_11ea_80f2_4149ab65b6fdrow4_col6 {
#             color:  black;
#         }    #T_784d8a6c_3815_11ea_80f2_4149ab65b6fdrow4_col7 {
#             color:  black;
#         }    #T_784d8a6c_3815_11ea_80f2_4149ab65b6fdrow4_col8 {
#             color:  black;
#         }    #T_784d8a6c_3815_11ea_80f2_4149ab65b6fdrow4_col9 {
#             color:  purple;
#         }    #T_784d8a6c_3815_11ea_80f2_4149ab65b6fdrow5_col0 {
#             color:  black;
#         }    #T_784d8a6c_3815_11ea_80f2_4149ab65b6fdrow5_col1 {
#             color:  black;
#         }    #T_784d8a6c_3815_11ea_80f2_4149ab65b6fdrow5_col2 {
#             color:  black;
#         }    #T_784d8a6c_3815_11ea_80f2_4149ab65b6fdrow5_col3 {
#             color:  black;
#         }    #T_784d8a6c_3815_11ea_80f2_4149ab65b6fdrow5_col4 {
#             color:  black;
#         }    #T_784d8a6c_3815_11ea_80f2_4149ab65b6fdrow5_col5 {
#             color:  black;
#         }    #T_784d8a6c_3815_11ea_80f2_4149ab65b6fdrow5_col6 {
#             color:  black;
#         }    #T_784d8a6c_3815_11ea_80f2_4149ab65b6fdrow5_col7 {
#             color:  black;
#         }    #T_784d8a6c_3815_11ea_80f2_4149ab65b6fdrow5_col8 {
#             color:  black;
#         }    #T_784d8a6c_3815_11ea_80f2_4149ab65b6fdrow5_col9 {
#             color:  purple;
#         }    #T_784d8a6c_3815_11ea_80f2_4149ab65b6fdrow6_col0 {
#             color:  black;
#         }    #T_784d8a6c_3815_11ea_80f2_4149ab65b6fdrow6_col1 {
#             color:  black;
#         }    #T_784d8a6c_3815_11ea_80f2_4149ab65b6fdrow6_col2 {
#             color:  black;
#         }    #T_784d8a6c_3815_11ea_80f2_4149ab65b6fdrow6_col3 {
#             color:  black;
#         }    #T_784d8a6c_3815_11ea_80f2_4149ab65b6fdrow6_col4 {
#             color:  orange;
#         }    #T_784d8a6c_3815_11ea_80f2_4149ab65b6fdrow6_col5 {
#             color:  orange;
#         }    #T_784d8a6c_3815_11ea_80f2_4149ab65b6fdrow6_col6 {
#             color:  orange;
#         }    #T_784d8a6c_3815_11ea_80f2_4149ab65b6fdrow6_col7 {
#             color:  black;
#         }    #T_784d8a6c_3815_11ea_80f2_4149ab65b6fdrow6_col8 {
#             color:  orange;
#         }    #T_784d8a6c_3815_11ea_80f2_4149ab65b6fdrow6_col9 {
#             color:  purple;
#         }    #T_784d8a6c_3815_11ea_80f2_4149ab65b6fdrow7_col0 {
#             color:  black;
#         }    #T_784d8a6c_3815_11ea_80f2_4149ab65b6fdrow7_col1 {
#             color:  black;
#         }    #T_784d8a6c_3815_11ea_80f2_4149ab65b6fdrow7_col2 {
#             color:  black;
#         }    #T_784d8a6c_3815_11ea_80f2_4149ab65b6fdrow7_col3 {
#             color:  black;
#         }    #T_784d8a6c_3815_11ea_80f2_4149ab65b6fdrow7_col4 {
#             color:  black;
#         }    #T_784d8a6c_3815_11ea_80f2_4149ab65b6fdrow7_col5 {
#             color:  black;
#         }    #T_784d8a6c_3815_11ea_80f2_4149ab65b6fdrow7_col6 {
#             color:  black;
#         }    #T_784d8a6c_3815_11ea_80f2_4149ab65b6fdrow7_col7 {
#             color:  black;
#         }    #T_784d8a6c_3815_11ea_80f2_4149ab65b6fdrow7_col8 {
#             color:  black;
#         }    #T_784d8a6c_3815_11ea_80f2_4149ab65b6fdrow7_col9 {
#             color:  purple;
#         }    #T_784d8a6c_3815_11ea_80f2_4149ab65b6fdrow8_col0 {
#             color:  black;
#         }    #T_784d8a6c_3815_11ea_80f2_4149ab65b6fdrow8_col1 {
#             color:  black;
#         }    #T_784d8a6c_3815_11ea_80f2_4149ab65b6fdrow8_col2 {
#             color:  black;
#         }    #T_784d8a6c_3815_11ea_80f2_4149ab65b6fdrow8_col3 {
#             color:  black;
#         }    #T_784d8a6c_3815_11ea_80f2_4149ab65b6fdrow8_col4 {
#             color:  black;
#         }    #T_784d8a6c_3815_11ea_80f2_4149ab65b6fdrow8_col5 {
#             color:  black;
#         }    #T_784d8a6c_3815_11ea_80f2_4149ab65b6fdrow8_col6 {
#             color:  black;
#         }    #T_784d8a6c_3815_11ea_80f2_4149ab65

# %% [markdown]
# ## By category

# %%
category_metrics_df = category_metric_list[0][['Label', 'Train', 'Validation']].copy()
category_metrics_df.columns = ['Label', 'Train_fold_0', 'Valid_fold_0']

for n_fold in range(1, N_FOLDS):
    category_metrics_df_idx = category_metric_list[n_fold][['Train', 'Validation']].copy()
    category_metrics_df_idx.columns = ['Train_fold_%d' % n_fold, 'Valid_fold_%d' % n_fold]
    category_metrics_df = pd.concat([category_metrics_df, category_metrics_df_idx], axis=1)
    
category_metrics_df['Train'] = 0
category_metrics_df['Validation'] = 0
for n_fold in range(N_FOLDS):
    category_metrics_df['Train'] += category_metrics_df['Train_fold_%d' % n_fold] / N_FOLDS
    category_metrics_df['Validation'] += category_metrics_df['Valid_fold_%d' % n_fold] / N_FOLDS
    
category_metrics_df['Var'] = category_metrics_df['Train'] - category_metrics_df['Validation']
display(category_metrics_df.style.applymap(color_map))
# Out:
# <style  type="text/css" >
#     #T_785998e8_3815_11ea_80f2_4149ab65b6fdrow0_col0 {
#             color:  black;
#         }    #T_785998e8_3815_11ea_80f2_4149ab65b6fdrow0_col1 {
#             color:  black;
#         }    #T_785998e8_3815_11ea_80f2_4149ab65b6fdrow0_col2 {
#             color:  black;
#         }    #T_785998e8_3815_11ea_80f2_4149ab65b6fdrow0_col3 {
#             color:  black;
#         }    #T_785998e8_3815_11ea_80f2_4149ab65b6fdrow0_col4 {
#             color:  black;
#         }    #T_785998e8_3815_11ea_80f2_4149ab65b6fdrow0_col5 {
#             color:  black;
#         }    #T_785998e8_3815_11ea_80f2_4149ab65b6fdrow0_col6 {
#             color:  black;
#         }    #T_785998e8_3815_11ea_80f2_4149ab65b6fdrow0_col7 {
#             color:  black;
#         }    #T_785998e8_3815_11ea_80f2_4149ab65b6fdrow0_col8 {
#             color:  black;
#         }    #T_785998e8_3815_11ea_80f2_4149ab65b6fdrow0_col9 {
#             color:  purple;
#         }    #T_785998e8_3815_11ea_80f2_4149ab65b6fdrow1_col0 {
#             color:  black;
#         }    #T_785998e8_3815_11ea_80f2_4149ab65b6fdrow1_col1 {
#             color:  black;
#         }    #T_785998e8_3815_11ea_80f2_4149ab65b6fdrow1_col2 {
#             color:  black;
#         }    #T_785998e8_3815_11ea_80f2_4149ab65b6fdrow1_col3 {
#             color:  black;
#         }    #T_785998e8_3815_11ea_80f2_4149ab65b6fdrow1_col4 {
#             color:  black;
#         }    #T_785998e8_3815_11ea_80f2_4149ab65b6fdrow1_col5 {
#             color:  black;
#         }    #T_785998e8_3815_11ea_80f2_4149ab65b6fdrow1_col6 {
#             color:  black;
#         }    #T_785998e8_3815_11ea_80f2_4149ab65b6fdrow1_col7 {
#             color:  black;
#         }    #T_785998e8_3815_11ea_80f2_4149ab65b6fdrow1_col8 {
#             color:  black;
#         }    #T_785998e8_3815_11ea_80f2_4149ab65b6fdrow1_col9 {
#             color:  purple;
#         }    #T_785998e8_3815_11ea_80f2_4149ab65b6fdrow2_col0 {
#             color:  black;
#         }    #T_785998e8_3815_11ea_80f2_4149ab65b6fdrow2_col1 {
#             color:  black;
#         }    #T_785998e8_3815_11ea_80f2_4149ab65b6fdrow2_col2 {
#             color:  black;
#         }    #T_785998e8_3815_11ea_80f2_4149ab65b6fdrow2_col3 {
#             color:  black;
#         }    #T_785998e8_3815_11ea_80f2_4149ab65b6fdrow2_col4 {
#             color:  black;
#         }    #T_785998e8_3815_11ea_80f2_4149ab65b6fdrow2_col5 {
#             color:  orange;
#         }    #T_785998e8_3815_11ea_80f2_4149ab65b6fdrow2_col6 {
#             color:  orange;
#         }    #T_785998e8_3815_11ea_80f2_4149ab65b6fdrow2_col7 {
#             color:  black;
#         }    #T_785998e8_3815_11ea_80f2_4149ab65b6fdrow2_col8 {
#             color:  black;
#         }    #T_785998e8_3815_11ea_80f2_4149ab65b6fdrow2_col9 {
#             color:  purple;
#         }    #T_785998e8_3815_11ea_80f2_4149ab65b6fdrow3_col0 {
#             color:  black;
#         }    #T_785998e8_3815_11ea_80f2_4149ab65b6fdrow3_col1 {
#             color:  orange;
#         }    #T_785998e8_3815_11ea_80f2_4149ab65b6fdrow3_col2 {
#             color:  orange;
#         }    #T_785998e8_3815_11ea_80f2_4149ab65b6fdrow3_col3 {
#             color:  orange;
#         }    #T_785998e8_3815_11ea_80f2_4149ab65b6fdrow3_col4 {
#             color:  orange;
#         }    #T_785998e8_3815_11ea_80f2_4149ab65b6fdrow3_col5 {
#             color:  black;
#         }    #T_785998e8_3815_11ea_80f2_4149ab65b6fdrow3_col6 {
#             color:  black;
#         }    #T_785998e8_3815_11ea_80f2_4149ab65b6fdrow3_col7 {
#             color:  orange;
#         }    #T_785998e8_3815_11ea_80f2_4149ab65b6fdrow3_col8 {
#             color:  orange;
#         }    #T_785998e8_3815_11ea_80f2_4149ab65b6fdrow3_col9 {
#             color:  purple;
#         }    #T_785998e8_3815_11ea_80f2_4149ab65b6fdrow4_col0 {
#             color:  black;
#         }    #T_785998e8_3815_11ea_80f2_4149ab65b6fdrow4_col1 {
#             color:  black;
#         }    #T_785998e8_3815_11ea_80f2_4149ab65b6fdrow4_col2 {
#             color:  orange;
#         }    #T_785998e8_3815_11ea_80f2_4149ab65b6fdrow4_col3 {
#             color:  black;
#         }    #T_785998e8_3815_11ea_80f2_4149ab65b6fdrow4_col4 {
#             color:  black;
#         }    #T_785998e8_3815_11ea_80f2_4149ab65b6fdrow4_col5 {
#             color:  orange;
#         }    #T_785998e8_3815_11ea_80f2_4149ab65b6fdrow4_col6 {
#             color:  orange;
#         }    #T_785998e8_3815_11ea_80f2_4149ab65b6fdrow4_col7 {
#             color:  orange;
#         }    #T_785998e8_3815_11ea_80f2_4149ab65b6fdrow4_col8 {
#             color:  orange;
#         }    #T_785998e8_3815_11ea_80f2_4149ab65b6fdrow4_col9 {
#             color:  purple;
#         }</style><table id="T_785998e8_3815_11ea_80f2_4149ab65b6fd" ><thead>    <tr>        <th class="blank level0" ></th>        <th class="col_heading level0 col0" >Label</th>        <th class="col_heading level0 col1" >Train_fold_0</th>        <th class="col_heading level0 col2" >Valid_fold_0</th>        <th class="col_heading level0 col3" >Train_fold_1</th>        <th class="col_heading level0 col4" >Valid_fold_1</th>        <th class="col_heading level0 col5" >Train_fold_2</th>        <th class="col_heading level0 col6" >Valid_fold_2</th>        <th class="col_heading level0 col7" >Train</th>        <th class="col_heading level0 col8" >Validation</th>        <th class="col_heading level0 col9" >Var</th>    </tr></thead><tbody>
#                 <tr>
#                         <th id="T_785998e8_3815_11ea_80f2_4149ab65b6fdlevel0_row0" class="row_heading level0 row0" >0</th>
#                         <td id="T_785998e8_3815_11ea_80f2_4149ab65b6fdrow0_col0" class="data row0 col0" >LIFE_ARTS</td>
#                         <td id="T_785998e8_3815_11ea_80f2_4149ab65b6fdrow0_col1" class="data row0 col1" >0.392</td>
#                         <td id="T_785998e8_3815_11ea_80f2_4149ab65b6fdrow0_col2" class="data row0 col2" >0.356</td>
#                         <td id="T_785998e8_3815_11ea_80f2_4149ab65b6fdrow0_col3" class="data row0 col3" >0.433</td>
#                         <td id="T_785998e8_3815_11ea_80f2_4149ab65b6fdrow0_col4" class="data row0 col4" >0.369</td>
#                         <td id="T_785998e8_3815_11ea_80f2_4149ab65b6fdrow0_col5" class="data row0 col5" >0.354</td>
#                         <td id="T_785998e8_3815_11ea_80f2_4149ab65b6fdrow0_col6" class="data row0 col6" >0.337</td>
#                         <td id="T_785998e8_3815_11ea_80f2_4149ab65b6fdrow0_col7" class="data row0 col7" >0.393</td>
#                         <td id="T_785998e8_3815_11ea_80f2_4149ab65b6fdrow0_col8" class="data row0 col8" >0.354</td>
#                         <td id="T_785998e8_3815_11ea_80f2_4149ab65b6fdrow0_col9" class="data row0 col9" >0.039</td>
#             </tr>
#             <tr>
#                         <th id="T_785998e8_3815_11ea_80f2_4149ab65b6fdlevel0_row1" class="row_heading level0 row1" >1</th>
#                         <td id="T_785998e8_3815_11ea_80f2_4149ab65b6fdrow1_col0" class="data row1 col0" >SCIENCE</td>
#                         <td id="T_785998e8_3815_11ea_80f2_4149ab65b6fdrow1_col1" class="data row1 col1" >0.367</td>
#                         <td id="T_785998e8_3815_11ea_80f2_4149ab65b6fdrow1_col2" class="data row1 col2" >0.352</td>
#                         <td id="T_785998e8_3815_11ea_80f2_4149ab65b6fdrow1_col3" class="data row1 col3" >0.423</td>
#                         <td id="T_785998e8_3815_11ea_80f2_4149ab65b6fdrow1_col4" class="data row1 col4" >0.319</td>
#                         <td id="T_785998e8_3815_11ea_80f2_4149ab65b6fdrow1_col5" class="data row1 col5" >0.342</td>
#                         <td id="T_785998e8_3815_11ea_80f2_4149ab65b6fdrow1_col6" class="data row1 col6" >0.313</td>
#                         <td id="T_785998e8_3815_11ea_80f2_4149ab65b6fdrow1_col7" class="data row1 col7" >0.377333</td>
#                         <td id="T_785998e8_3815_11ea_80f2_4149ab65b6fdrow1_col8" class="data row1 col8" >0.328</td>
#                         <td id="T_785998e8_3815_11ea_80f2_4149ab65b6fdrow1_col9" class="data row1 col9" >0.0493333</td>
#             </tr>
#             <tr>
