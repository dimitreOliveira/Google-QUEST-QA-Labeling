# %%
import sys
if 'google.colab' in sys.modules: # Colab-only Tensorflow version selector
  # %tensorflow_version 2.x

import tensorflow as tf
print("Tensorflow version " + tf.__version__)
# Out:
# TensorFlow 2.x selected.
# Tensorflow version 2.1.0-rc1

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Go to this URL in a browser: https://accounts.google.com/o/oauth2/auth?client_id=947318989803-6bn6qk8qdgf4n4g3pfee6491hc0brc4i.apps.googleusercontent.com&redirect_uri=urn%3aietf%3awg%3aoauth%3a2.0%3aoob&response_type=code&scope=email%20https%3a%2f%2fwww.googleapis.com%2fauth%2fdocs.test%20https%3a%2f%2fwww.googleapis.com%2fauth%2fdrive%20https%3a%2f%2fwww.googleapis.com%2fauth%2fdrive.photos.readonly%20https%3a%2f%2fwww.googleapis.com%2fauth%2fpeopleapi.readonly
#
# Enter your authorization code:
# ··········
# Mounted at /content/drive

# %%
# !cp -r '/content/drive/My Drive/Colab Notebooks/Google QUEST Q&A Labeling/Scripts/.' .

# %%
MODEL_BASE_PATH = '/content/drive/My Drive/Colab Notebooks/Google QUEST Q&A Labeling/Model backlog/Files/'
MODEL_NAME = '134-BERT_base_unc raw'

# %% [markdown]
# ## Dependencies

# %%
import glob
import warnings
from tensorflow_hub import KerasLayer
from tensorflow.keras import Model, optimizers
from tensorflow.keras.callbacks import ReduceLROnPlateau
from tensorflow.keras.layers import Input, Dense, Dropout, GlobalAveragePooling1D, SpatialDropout1D, Concatenate
from googleqa_utilityscript import *
from googleqa_map_utilityscript import *
from script_lr_schedulers import WarmUpLearningRateScheduler
import bert_tokenization as tokenization


SEED = 0
seed_everything(SEED)
warnings.filterwarnings("ignore")
# Out:
# Using TensorFlow backend.

# %% [markdown]
# ## Load data

# %%
BERT_PATH = '/content/drive/My Drive/Colab Notebooks/Google QUEST Q&A Labeling/Modules/bert_base_uncased'
VOCAB_PATH = BERT_PATH + '/assets/vocab.txt'

k_fold = pd.read_csv('/content/drive/My Drive/Colab Notebooks/Google QUEST Q&A Labeling/Data/5-fold.csv')
N_FOLDS = 5

print('Samples: %s' % len(k_fold))
display(k_fold.head())
# Out:
# Samples: 6079
#    qa_id  ...      fold_5
# 0      0  ...       train
# 1      1  ...       train
# 2      2  ...       train
# 3      3  ...  validation
# 4      5  ...       train
#
# [5 rows x 46 columns]

# %%
question_target_cols = ['question_asker_intent_understanding','question_body_critical', 'question_conversational', 
                        'question_expect_short_answer', 'question_fact_seeking', 'question_has_commonly_accepted_answer',
                        'question_interestingness_others', 'question_interestingness_self', 'question_multi_intent', 
                        'question_not_really_a_question', 'question_opinion_seeking', 'question_type_choice',
                        'question_type_compare', 'question_type_consequence', 'question_type_definition', 
                        'question_type_entity', 'question_type_instructions', 'question_type_procedure',
                        'question_type_reason_explanation', 'question_type_spelling', 'question_well_written']
answer_target_cols = ['answer_helpful', 'answer_level_of_information', 'answer_plausible', 'answer_relevance',
                      'answer_satisfaction', 'answer_type_instructions', 'answer_type_procedure', 
                      'answer_type_reason_explanation', 'answer_well_written']
target_cols = question_target_cols + answer_target_cols

# %% [markdown]
# # Pre-process data

# %%
text_features = ['question_title', 'question_body', 'answer']

# for feature in text_features:
#     # Lower
#     k_fold[feature] = k_fold[feature].apply(lambda x: x.lower())
#     # Map misspellings
#     k_fold[feature] = k_fold[feature].apply(lambda x: map_misspellings(x))
#     # Map contractions
#     k_fold[feature] = k_fold[feature].apply(lambda x: map_contraction(x))
#     # Trim text
#     k_fold[feature] = k_fold[feature].apply(lambda x: x.strip())

# %% [markdown]
# # Model parameters

# %%
EPOCHS = 8
BATCH_SIZE = 8
LEARNING_RATE = 3e-5
N_CLASS = len(target_cols)
ES_PATIENCE = 2
MAX_SEQUENCE_LENGTH = 512
RLROP_PATIENCE = 1
DECAY_DROP = 0.5
LR_WARMUP_EPOCHS = 2

# %% [markdown]
# # Model

# %%
def model_fn():
    input_word_ids = Input((MAX_SEQUENCE_LENGTH,), dtype=tf.int32, name='input_word_ids')
    input_masks = Input((MAX_SEQUENCE_LENGTH,), dtype=tf.int32, name='input_masks')
    segment_ids = Input((MAX_SEQUENCE_LENGTH,), dtype=tf.int32, name='segment_ids')

    bert_layer = KerasLayer(BERT_PATH, trainable=True)
    pooled_output, sequence_output = bert_layer([input_word_ids, input_masks, segment_ids])

    x = GlobalAveragePooling1D()(sequence_output)
    x = Dropout(0.2)(x)
    output = Dense(N_CLASS, activation="sigmoid", name="output")(x)

    model = Model(inputs=[input_word_ids, input_masks, segment_ids], outputs=output)
    
    return model

# %% [markdown]
# # Train model

# %%
rlrop = ReduceLROnPlateau(monitor='val_loss', mode='min', patience=RLROP_PATIENCE, factor=DECAY_DROP, min_lr=1e-7, verbose=1)    
tokenizer = tokenization.FullTokenizer(VOCAB_PATH, True)

history_list = []
metric_list = []
category_metric_list = []
target_cols_preds = [col+'_pred' for col in target_cols]

for n_fold in range(N_FOLDS):
    ### Data
    train = k_fold[k_fold['fold_%d' % (n_fold+1)] == 'train']
    validation = k_fold[k_fold['fold_%d' % (n_fold+1)] == 'validation']
    
    ### Create features
    # Train features
    X_train = compute_input_arays(train, text_features, tokenizer, MAX_SEQUENCE_LENGTH)
    Y_train = train[target_cols].values

    # Validation features
    X_valid = compute_input_arays(validation, text_features, tokenizer, MAX_SEQUENCE_LENGTH)
    Y_valid = validation[target_cols].values

    ## Train model
    model_path = MODEL_BASE_PATH + MODEL_NAME + '_model_fold_%d' % (n_fold+1)
    spearmanCallback = SpearmanRhoCallback(training_data=(X_train, Y_train), 
                                           validation_data=(X_valid, Y_valid), 
                                           model_path=model_path, 
                                           monitor='val_loss', mode='min', 
                                           patience=ES_PATIENCE, checkpoint=True)
    WARMUP_BATCHES = LR_WARMUP_EPOCHS * len(train) // BATCH_SIZE
    warmup_lr = WarmUpLearningRateScheduler(WARMUP_BATCHES, LEARNING_RATE)

    callback_list = [spearmanCallback, rlrop, warmup_lr]
    optimizer = optimizers.Adam(lr=LEARNING_RATE)
    model = model_fn()
    model.compile(optimizer=optimizer, loss='binary_crossentropy')

    history = model.fit(X_train, Y_train, 
                        validation_data=(X_valid, Y_valid), 
                        callbacks=callback_list, 
                        batch_size=BATCH_SIZE, 
                        epochs=EPOCHS, 
                        verbose=2).history
    history_list.append(history)

    # Save last epoch weights
    model.save_weights(MODEL_BASE_PATH + MODEL_NAME + '_model_fold_%d_last_epoch.h5' % (n_fold+1))
    
    ### Evaluation - Label metrics
    model.load_weights(model_path+'.h5')
    preds_train = model.predict(X_train)
    preds_val = model.predict(X_valid)
    metric_list.append(get_metrics(Y_train, preds_train, Y_valid, preds_val, target_cols))
    
    ### Evaluation - Category metrics
    for col in target_cols_preds:
        train[col] = 0
        validation[col] = 0

    train[target_cols_preds] = preds_train
    validation[target_cols_preds] = preds_val 
    category_metric_list.append(get_metrics_category(train, validation, target_cols, target_cols_preds, 'category'))
# Out:
# Train on 4864 samples, validate on 1215 samples
# Epoch 1/8
# spearman-rho: 0.3185 val_spearman-rho: 0.3001
# Saved model weights at "/content/drive/My Drive/Colab Notebooks/Google QUEST Q&A Labeling/Model backlog/Files/134-BERT_base_unc raw_model_fold_1.h5"
# 4864/4864 - 935s - loss: 0.4578 - val_loss: 0.3897
# Epoch 2/8
# spearman-rho: 0.4148 val_spearman-rho: 0.3707
# Saved model weights at "/content/drive/My Drive/Colab Notebooks/Google QUEST Q&A Labeling/Model backlog/Files/134-BERT_base_unc raw_model_fold_1.h5"
# 4864/4864 - 922s - loss: 0.3861 - val_loss: 0.3735
# Epoch 3/8
# spearman-rho: 0.4795 val_spearman-rho: 0.3872
# Saved model weights at "/content/drive/My Drive/Colab Notebooks/Google QUEST Q&A Labeling/Model backlog/Files/134-BERT_base_unc raw_model_fold_1.h5"
# 4864/4864 - 923s - loss: 0.3673 - val_loss: 0.3681
# Epoch 4/8
# spearman-rho: 0.5384 val_spearman-rho: 0.3848
#
# Epoch 00004: ReduceLROnPlateau reducing learning rate to 1.4999999621068127e-05.
# 4864/4864 - 922s - loss: 0.3493 - val_loss: 0.3720
# Epoch 5/8
# spearman-rho: 0.6114 val_spearman-rho: 0.3854
# Epoch 00004: early stopping
#
# Epoch 00005: ReduceLROnPlateau reducing learning rate to 7.499999810534064e-06.
# 4864/4864 - 923s - loss: 0.3233 - val_loss: 0.3768
# Train on 4864 samples, validate on 1215 samples
# Epoch 1/8
# spearman-rho: 0.3483 val_spearman-rho: 0.3163
# Saved model weights at "/content/drive/My Drive/Colab Notebooks/Google QUEST Q&A Labeling/Model backlog/Files/134-BERT_base_unc raw_model_fold_2.h5"
# 4864/4864 - 939s - loss: 0.4480 - val_loss: 0.3860
# Epoch 2/8
# spearman-rho: 0.4299 val_spearman-rho: 0.3704
# Saved model weights at "/content/drive/My Drive/Colab Notebooks/Google QUEST Q&A Labeling/Model backlog/Files/134-BERT_base_unc raw_model_fold_2.h5"
# 4864/4864 - 923s - loss: 0.3811 - val_loss: 0.3750
# Epoch 3/8
# spearman-rho: 0.4934 val_spearman-rho: 0.3875
# Saved model weights at "/content/drive/My Drive/Colab Notebooks/Google QUEST Q&A Labeling/Model backlog/Files/134-BERT_base_unc raw_model_fold_2.h5"
# 4864/4864 - 923s - loss: 0.3630 - val_loss: 0.3728
# Epoch 4/8
# spearman-rho: 0.5616 val_spearman-rho: 0.3900
#
# Epoch 00004: ReduceLROnPlateau reducing learning rate to 1.4999999621068127e-05.
# 4864/4864 - 922s - loss: 0.3440 - val_loss: 0.3740
# Epoch 5/8
# spearman-rho: 0.6374 val_spearman-rho: 0.3847
# Epoch 00004: early stopping
#
# Epoch 00005: ReduceLROnPlateau reducing learning rate to 7.499999810534064e-06.
# 4864/4864 - 923s - loss: 0.3155 - val_loss: 0.3772
# Train on 4859 samples, validate on 1220 samples
# Epoch 1/8
# spearman-rho: 0.3323 val_spearman-rho: 0.3132
# Saved model weights at "/content/drive/My Drive/Colab Notebooks/Google QUEST Q&A Labeling/Model backlog/Files/134-BERT_base_unc raw_model_fold_3.h5"
# 4859/4859 - 939s - loss: 0.4539 - val_loss: 0.3909
# Epoch 2/8
# spearman-rho: 0.4286 val_spearman-rho: 0.3686
# Saved model weights at "/content/drive/My Drive/Colab Notebooks/Google QUEST Q&A Labeling/Model backlog/Files/134-BERT_base_unc raw_model_fold_3.h5"
# 4859/4859 - 930s - loss: 0.3831 - val_loss: 0.3745
# Epoch 3/8
# spearman-rho: 0.4942 val_spearman-rho: 0.3805
# Saved model weights at "/content/drive/My Drive/Colab Notebooks/Google QUEST Q&A Labeling/Model backlog/Files/134-BERT_base_unc raw_model_fold_3.h5"
# 4859/4859 - 929s - loss: 0.3640 - val_loss: 0.3702
# Epoch 4/8
# spearman-rho: 0.5659 val_spearman-rho: 0.3806
#
# Epoch 00004: ReduceLROnPlateau reducing learning rate to 1.4999999621068127e-05.
# 4859/4859 - 928s - loss: 0.3453 - val_loss: 0.3720
# Epoch 5/8
# spearman-rho: 0.6354 val_spearman-rho: 0.3720
# Epoch 00004: early stopping
#
# Epoch 00005: ReduceLROnPlateau reducing learning rate to 7.499999810534064e-06.
# 4859/4859 - 925s - loss: 0.3164 - val_loss: 0.3803
# Train on 4865 samples, validate on 1214 samples
# Epoch 1/8
# spearman-rho: 0.3147 val_spearman-rho: 0.3031
# Saved model weights at "/content/drive/My Drive/Colab Notebooks/Google QUEST Q&A Labeling/Model backlog/Files/134-BERT_base_unc raw_model_fold_4.h5"
# 4865/4865 - 941s - loss: 0.4498 - val_loss: 0.3902
# Epoch 2/8
# spearman-rho: 0.4203 val_spearman-rho: 0.3695
# Saved model weights at "/content/drive/My Drive/Colab Notebooks/Google QUEST Q&A Labeling/Model backlog/Files/134-BERT_base_unc raw_model_fold_4.h5"
# 4865/4865 - 931s - loss: 0.3846 - val_loss: 0.3712
# Epoch 3/8
# spearman-rho: 0.4825 val_spearman-rho: 0.3883
# Saved model weights at "/content/drive/My Drive/Colab Notebooks/Google QUEST Q&A Labeling/Model backlog/Files/134-BERT_base_unc raw_model_fold_4.h5"
# 4865/4865 - 929s - loss: 0.3653 - val_loss: 0.3684
# Epoch 4/8
# spearman-rho: 0.5497 val_spearman-rho: 0.3932
#
# Epoch 00004: ReduceLROnPlateau reducing learning rate to 1.4999999621068127e-05.
# 4865/4865 - 928s - loss: 0.3469 - val_loss: 0.3711
# Epoch 5/8
# spearman-rho: 0.6218 val_spearman-rho: 0.3905
# Epoch 00004: early stopping
#
# Epoch 00005: ReduceLROnPlateau reducing learning rate to 7.499999810534064e-06.
# 4865/4865 - 930s - loss: 0.3194 - val_loss: 0.3728
# Train on 4864 samples, validate on 1215 samples
# Epoch 1/8
# spearman-rho: 0.3221 val_spearman-rho: 0.3005
# Saved model weights at "/content/drive/My Drive/Colab Notebooks/Google QUEST Q&A Labeling/Model backlog/Files/134-BERT_base_unc raw_model_fold_5.h5"
# 4864/4864 - 938s - loss: 0.4542 - val_loss: 0.3910
# Epoch 2/8
# spearman-rho: 0.4177 val_spearman-rho: 0.3615
# Saved model weights at "/content/drive/My Drive/Colab Notebooks/Google QUEST Q&A Labeling/Model backlog/Files/134-BERT_base_unc raw_model_fold_5.h5"
# 4864/4864 - 926s - loss: 0.3845 - val_loss: 0.3795
# Epoch 3/8
# spearman-rho: 0.4867 val_spearman-rho: 0.3866
# Saved model weights at "/content/drive/My Drive/Colab Notebooks/Google QUEST Q&A Labeling/Model backlog/Files/134-BERT_base_unc raw_model_fold_5.h5"
# 4864/4864 - 925s - loss: 0.3656 - val_loss: 0.3711
# Epoch 4/8
# spearman-rho: 0.5541 val_spearman-rho: 0.3865
#
# Epoch 00004: ReduceLROnPlateau reducing learning rate to 1.4999999621068127e-05.
# 4864/4864 - 924s - loss: 0.3464 - val_loss: 0.3727
# Epoch 5/8
# spearman-rho: 0.6275 val_spearman-rho: 0.3799
# Epoch 00004: early stopping
#
# Epoch 00005: ReduceLROnPlateau reducing learning rate to 7.499999810534064e-06.
# 4864/4864 - 924s - loss: 0.3181 - val_loss: 0.3787

# %% [markdown]
# ## Model loss graph

# %%
for n_fold in range(N_FOLDS):
    print('Fold: %d' % n_fold)
    sns.set(style="whitegrid")
    plot_metrics(history_list[n_fold], metric_list=['loss', 'spearman'])
# Out:
# Fold: 0
# Fold: 1
# Fold: 2
# Fold: 3
# Fold: 4

# %% [markdown]
# # Evaluation

# %%
metrics_df = metric_list[0][['Label', 'Train', 'Validation']].copy()
metrics_df.columns = ['Label', 'Train_fold_0', 'Valid_fold_0']

for n_fold in range(1, N_FOLDS):
    metrics_df_idx = metric_list[n_fold][['Train', 'Validation']].copy()
    metrics_df_idx.columns = ['Train_fold_%d' % n_fold, 'Valid_fold_%d' % n_fold]
    metrics_df = pd.concat([metrics_df, metrics_df_idx], axis=1)

metrics_df['Train'] = 0
metrics_df['Validation'] = 0
for n_fold in range(N_FOLDS):
    metrics_df['Train'] += metrics_df['Train_fold_%d' % n_fold] / N_FOLDS
    metrics_df['Validation'] += metrics_df['Valid_fold_%d' % n_fold] / N_FOLDS

metrics_df['Var'] = metrics_df['Train'] - metrics_df['Validation']
display(metrics_df.style.applymap(color_map))
# Out:
# <style  type="text/css" >
#     #T_c32950de_408f_11ea_8297_0242ac1c0002row0_col0 {
#             color:  black;
#         }    #T_c32950de_408f_11ea_8297_0242ac1c0002row0_col1 {
#             color:  black;
#         }    #T_c32950de_408f_11ea_8297_0242ac1c0002row0_col2 {
#             color:  black;
#         }    #T_c32950de_408f_11ea_8297_0242ac1c0002row0_col3 {
#             color:  black;
#         }    #T_c32950de_408f_11ea_8297_0242ac1c0002row0_col4 {
#             color:  black;
#         }    #T_c32950de_408f_11ea_8297_0242ac1c0002row0_col5 {
#             color:  black;
#         }    #T_c32950de_408f_11ea_8297_0242ac1c0002row0_col6 {
#             color:  black;
#         }    #T_c32950de_408f_11ea_8297_0242ac1c0002row0_col7 {
#             color:  black;
#         }    #T_c32950de_408f_11ea_8297_0242ac1c0002row0_col8 {
#             color:  black;
#         }    #T_c32950de_408f_11ea_8297_0242ac1c0002row0_col9 {
#             color:  black;
#         }    #T_c32950de_408f_11ea_8297_0242ac1c0002row0_col10 {
#             color:  black;
#         }    #T_c32950de_408f_11ea_8297_0242ac1c0002row0_col11 {
#             color:  black;
#         }    #T_c32950de_408f_11ea_8297_0242ac1c0002row0_col12 {
#             color:  black;
#         }    #T_c32950de_408f_11ea_8297_0242ac1c0002row0_col13 {
#             color:  orange;
#         }    #T_c32950de_408f_11ea_8297_0242ac1c0002row1_col0 {
#             color:  black;
#         }    #T_c32950de_408f_11ea_8297_0242ac1c0002row1_col1 {
#             color:  black;
#         }    #T_c32950de_408f_11ea_8297_0242ac1c0002row1_col2 {
#             color:  black;
#         }    #T_c32950de_408f_11ea_8297_0242ac1c0002row1_col3 {
#             color:  black;
#         }    #T_c32950de_408f_11ea_8297_0242ac1c0002row1_col4 {
#             color:  black;
#         }    #T_c32950de_408f_11ea_8297_0242ac1c0002row1_col5 {
#             color:  black;
#         }    #T_c32950de_408f_11ea_8297_0242ac1c0002row1_col6 {
#             color:  black;
#         }    #T_c32950de_408f_11ea_8297_0242ac1c0002row1_col7 {
#             color:  black;
#         }    #T_c32950de_408f_11ea_8297_0242ac1c0002row1_col8 {
#             color:  black;
#         }    #T_c32950de_408f_11ea_8297_0242ac1c0002row1_col9 {
#             color:  black;
#         }    #T_c32950de_408f_11ea_8297_0242ac1c0002row1_col10 {
#             color:  black;
#         }    #T_c32950de_408f_11ea_8297_0242ac1c0002row1_col11 {
#             color:  black;
#         }    #T_c32950de_408f_11ea_8297_0242ac1c0002row1_col12 {
#             color:  black;
#         }    #T_c32950de_408f_11ea_8297_0242ac1c0002row1_col13 {
#             color:  purple;
#         }    #T_c32950de_408f_11ea_8297_0242ac1c0002row2_col0 {
#             color:  black;
#         }    #T_c32950de_408f_11ea_8297_0242ac1c0002row2_col1 {
#             color:  black;
#         }    #T_c32950de_408f_11ea_8297_0242ac1c0002row2_col2 {
#             color:  black;
#         }    #T_c32950de_408f_11ea_8297_0242ac1c0002row2_col3 {
#             color:  black;
#         }    #T_c32950de_408f_11ea_8297_0242ac1c0002row2_col4 {
#             color:  black;
#         }    #T_c32950de_408f_11ea_8297_0242ac1c0002row2_col5 {
#             color:  black;
#         }    #T_c32950de_408f_11ea_8297_0242ac1c0002row2_col6 {
#             color:  black;
#         }    #T_c32950de_408f_11ea_8297_0242ac1c0002row2_col7 {
#             color:  black;
#         }    #T_c32950de_408f_11ea_8297_0242ac1c0002row2_col8 {
#             color:  black;
#         }    #T_c32950de_408f_11ea_8297_0242ac1c0002row2_col9 {
#             color:  black;
#         }    #T_c32950de_408f_11ea_8297_0242ac1c0002row2_col10 {
#             color:  black;
#         }    #T_c32950de_408f_11ea_8297_0242ac1c0002row2_col11 {
#             color:  black;
#         }    #T_c32950de_408f_11ea_8297_0242ac1c0002row2_col12 {
#             color:  black;
#         }    #T_c32950de_408f_11ea_8297_0242ac1c0002row2_col13 {
#             color:  orange;
#         }    #T_c32950de_408f_11ea_8297_0242ac1c0002row3_col0 {
#             color:  black;
#         }    #T_c32950de_408f_11ea_8297_0242ac1c0002row3_col1 {
#             color:  black;
#         }    #T_c32950de_408f_11ea_8297_0242ac1c0002row3_col2 {
#             color:  black;
#         }    #T_c32950de_408f_11ea_8297_0242ac1c0002row3_col3 {
#             color:  black;
#         }    #T_c32950de_408f_11ea_8297_0242ac1c0002row3_col4 {
#             color:  black;
#         }    #T_c32950de_408f_11ea_8297_0242ac1c0002row3_col5 {
#             color:  black;
#         }    #T_c32950de_408f_11ea_8297_0242ac1c0002row3_col6 {
#             color:  black;
#         }    #T_c32950de_408f_11ea_8297_0242ac1c0002row3_col7 {
#             color:  black;
#         }    #T_c32950de_408f_11ea_8297_0242ac1c0002row3_col8 {
#             color:  black;
#         }    #T_c32950de_408f_11ea_8297_0242ac1c0002row3_col9 {
#             color:  black;
#         }    #T_c32950de_408f_11ea_8297_0242ac1c0002row3_col10 {
#             color:  black;
#         }    #T_c32950de_408f_11ea_8297_0242ac1c0002row3_col11 {
#             color:  black;
#         }    #T_c32950de_408f_11ea_8297_0242ac1c0002row3_col12 {
#             color:  black;
#         }    #T_c32950de_408f_11ea_8297_0242ac1c0002row3_col13 {
#             color:  purple;
#         }    #T_c32950de_408f_11ea_8297_0242ac1c0002row4_col0 {
#             color:  black;
#         }    #T_c32950de_408f_11ea_8297_0242ac1c0002row4_col1 {
#             color:  black;
#         }    #T_c32950de_408f_11ea_8297_0242ac1c0002row4_col2 {
#             color:  black;
#         }    #T_c32950de_408f_11ea_8297_0242ac1c0002row4_col3 {
#             color:  black;
#         }    #T_c32950de_408f_11ea_8297_0242ac1c0002row4_col4 {
#             color:  black;
#         }    #T_c32950de_408f_11ea_8297_0242ac1c0002row4_col5 {
#             color:  black;
#         }    #T_c32950de_408f_11ea_8297_0242ac1c0002row4_col6 {
#             color:  black;
#         }    #T_c32950de_408f_11ea_8297_0242ac1c0002row4_col7 {
#             color:  black;
#         }    #T_c32950de_408f_11ea_8297_0242ac1c0002row4_col8 {
#             color:  black;
#         }    #T_c32950de_408f_11ea_8297_0242ac1c0002row4_col9 {
#             color:  black;
#         }    #T_c32950de_408f_11ea_8297_0242ac1c0002row4_col10 {
#             color:  black;
#         }    #T_c32950de_408f_11ea_8297_0242ac1c0002row4_col11 {
#             color:  black;
#         }    #T_c32950de_408f_11ea_8297_0242ac1c0002row4_col12 {
#             color:  black;
#         }    #T_c32950de_408f_11ea_8297_0242ac1c0002row4_col13 {
#             color:  purple;
#         }    #T_c32950de_408f_11ea_8297_0242ac1c0002row5_col0 {
#             color:  black;
#         }    #T_c32950de_408f_11ea_8297_0242ac1c0002row5_col1 {
#             color:  black;
#         }    #T_c32950de_408f_11ea_8297_0242ac1c0002row5_col2 {
#             color:  black;
#         }    #T_c32950de_408f_11ea_8297_0242ac1c0002row5_col3 {
#             color:  black;
#         }    #T_c32950de_408f_11ea_8297_0242ac1c0002row5_col4 {
#             color:  black;
#         }    #T_c32950de_408f_11ea_8297_0242ac1c0002row5_col5 {
#             color:  black;
#         }    #T_c32950de_408f_11ea_8297_0242ac1c0002row5_col6 {
#             color:  black;
#         }    #T_c32950de_408f_11ea_8297_0242ac1c0002row5_col7 {
#             color:  black;
#         }    #T_c32950de_408f_11ea_8297_0242ac1c0002row5_col8 {
#             color:  black;
#         }    #T_c32950de_408f_11ea_8297_0242ac1c0002row5_col9 {
#             color:  black;
#         }    #T_c32950de_408f_11ea_8297_0242ac1c0002row5_col10 {
#             color:  black;
#         }    #T_c32950de_408f_11ea_8297_0242ac1c0002row5_col11 {
#             color:  black;
#         }    #T_c32950de_408f_11ea_8297_0242ac1c0002row5_col12 {
#             color:  black;
#         }    #T_c32950de_408f_11ea_8297_0242ac1c0002row5_col13 {
#             color:  purple;
#         }    #T_c32950de_408f_11ea_8297_0242ac1c0002row6_col0 {
#             color:  black;
#         }    #T_c32950de_408f_11ea_8297_0242ac1c0002row6_col1 {
#             color:  black;
#         }    #T_c32950de_408f_11ea_8297_0242ac1c0002row6_col2 {
#             color:  black;
#         }    #T_c32950de_408f_11ea_8

# %% [markdown]
# ## By category

# %%
category_metrics_df = category_metric_list[0][['Label', 'Train', 'Validation']].copy()
category_metrics_df.columns = ['Label', 'Train_fold_0', 'Valid_fold_0']

for n_fold in range(1, N_FOLDS):
    category_metrics_df_idx = category_metric_list[n_fold][['Train', 'Validation']].copy()
    category_metrics_df_idx.columns = ['Train_fold_%d' % n_fold, 'Valid_fold_%d' % n_fold]
    category_metrics_df = pd.concat([category_metrics_df, category_metrics_df_idx], axis=1)
    
category_metrics_df['Train'] = 0
category_metrics_df['Validation'] = 0
for n_fold in range(N_FOLDS):
    category_metrics_df['Train'] += category_metrics_df['Train_fold_%d' % n_fold] / N_FOLDS
    category_metrics_df['Validation'] += category_metrics_df['Valid_fold_%d' % n_fold] / N_FOLDS
    
category_metrics_df['Var'] = category_metrics_df['Train'] - category_metrics_df['Validation']
display(category_metrics_df.style.applymap(color_map))
# Out:
# <style  type="text/css" >
#     #T_c3345d6c_408f_11ea_8297_0242ac1c0002row0_col0 {
#             color:  black;
#         }    #T_c3345d6c_408f_11ea_8297_0242ac1c0002row0_col1 {
#             color:  black;
#         }    #T_c3345d6c_408f_11ea_8297_0242ac1c0002row0_col2 {
#             color:  black;
#         }    #T_c3345d6c_408f_11ea_8297_0242ac1c0002row0_col3 {
#             color:  black;
#         }    #T_c3345d6c_408f_11ea_8297_0242ac1c0002row0_col4 {
#             color:  black;
#         }    #T_c3345d6c_408f_11ea_8297_0242ac1c0002row0_col5 {
#             color:  black;
#         }    #T_c3345d6c_408f_11ea_8297_0242ac1c0002row0_col6 {
#             color:  black;
#         }    #T_c3345d6c_408f_11ea_8297_0242ac1c0002row0_col7 {
#             color:  black;
#         }    #T_c3345d6c_408f_11ea_8297_0242ac1c0002row0_col8 {
#             color:  black;
#         }    #T_c3345d6c_408f_11ea_8297_0242ac1c0002row0_col9 {
#             color:  black;
#         }    #T_c3345d6c_408f_11ea_8297_0242ac1c0002row0_col10 {
#             color:  black;
#         }    #T_c3345d6c_408f_11ea_8297_0242ac1c0002row0_col11 {
#             color:  black;
#         }    #T_c3345d6c_408f_11ea_8297_0242ac1c0002row0_col12 {
#             color:  black;
#         }    #T_c3345d6c_408f_11ea_8297_0242ac1c0002row0_col13 {
#             color:  orange;
#         }    #T_c3345d6c_408f_11ea_8297_0242ac1c0002row1_col0 {
#             color:  black;
#         }    #T_c3345d6c_408f_11ea_8297_0242ac1c0002row1_col1 {
#             color:  black;
#         }    #T_c3345d6c_408f_11ea_8297_0242ac1c0002row1_col2 {
#             color:  black;
#         }    #T_c3345d6c_408f_11ea_8297_0242ac1c0002row1_col3 {
#             color:  black;
#         }    #T_c3345d6c_408f_11ea_8297_0242ac1c0002row1_col4 {
#             color:  black;
#         }    #T_c3345d6c_408f_11ea_8297_0242ac1c0002row1_col5 {
#             color:  black;
#         }    #T_c3345d6c_408f_11ea_8297_0242ac1c0002row1_col6 {
#             color:  black;
#         }    #T_c3345d6c_408f_11ea_8297_0242ac1c0002row1_col7 {
#             color:  black;
#         }    #T_c3345d6c_408f_11ea_8297_0242ac1c0002row1_col8 {
#             color:  black;
#         }    #T_c3345d6c_408f_11ea_8297_0242ac1c0002row1_col9 {
#             color:  black;
#         }    #T_c3345d6c_408f_11ea_8297_0242ac1c0002row1_col10 {
#             color:  black;
#         }    #T_c3345d6c_408f_11ea_8297_0242ac1c0002row1_col11 {
#             color:  black;
#         }    #T_c3345d6c_408f_11ea_8297_0242ac1c0002row1_col12 {
#             color:  black;
#         }    #T_c3345d6c_408f_11ea_8297_0242ac1c0002row1_col13 {
#             color:  orange;
#         }    #T_c3345d6c_408f_11ea_8297_0242ac1c0002row2_col0 {
#             color:  black;
#         }    #T_c3345d6c_408f_11ea_8297_0242ac1c0002row2_col1 {
#             color:  black;
#         }    #T_c3345d6c_408f_11ea_8297_0242ac1c0002row2_col2 {
#             color:  black;
#         }    #T_c3345d6c_408f_11ea_8297_0242ac1c0002row2_col3 {
#             color:  black;
#         }    #T_c3345d6c_408f_11ea_8297_0242ac1c0002row2_col4 {
#             color:  black;
#         }    #T_c3345d6c_408f_11ea_8297_0242ac1c0002row2_col5 {
#             color:  black;
#         }    #T_c3345d6c_408f_11ea_8297_0242ac1c0002row2_col6 {
#             color:  black;
#         }    #T_c3345d6c_408f_11ea_8297_0242ac1c0002row2_col7 {
#             color:  black;
#         }    #T_c3345d6c_408f_11ea_8297_0242ac1c0002row2_col8 {
#             color:  black;
#         }    #T_c3345d6c_408f_11ea_8297_0242ac1c0002row2_col9 {
#             color:  black;
#         }    #T_c3345d6c_408f_11ea_8297_0242ac1c0002row2_col10 {
#             color:  black;
#         }    #T_c3345d6c_408f_11ea_8297_0242ac1c0002row2_col11 {
#             color:  black;
#         }    #T_c3345d6c_408f_11ea_8297_0242ac1c0002row2_col12 {
#             color:  black;
#         }    #T_c3345d6c_408f_11ea_8297_0242ac1c0002row2_col13 {
#             color:  orange;
#         }    #T_c3345d6c_408f_11ea_8297_0242ac1c0002row3_col0 {
#             color:  black;
#         }    #T_c3345d6c_408f_11ea_8297_0242ac1c0002row3_col1 {
#             color:  black;
#         }    #T_c3345d6c_408f_11ea_8297_0242ac1c0002row3_col2 {
#             color:  orange;
#         }    #T_c3345d6c_408f_11ea_8297_0242ac1c0002row3_col3 {
#             color:  black;
#         }    #T_c3345d6c_408f_11ea_8297_0242ac1c0002row3_col4 {
#             color:  orange;
#         }    #T_c3345d6c_408f_11ea_8297_0242ac1c0002row3_col5 {
#             color:  black;
#         }    #T_c3345d6c_408f_11ea_8297_0242ac1c0002row3_col6 {
#             color:  black;
#         }    #T_c3345d6c_408f_11ea_8297_0242ac1c0002row3_col7 {
#             color:  black;
#         }    #T_c3345d6c_408f_11ea_8297_0242ac1c0002row3_col8 {
#             color:  orange;
#         }    #T_c3345d6c_408f_11ea_8297_0242ac1c0002row3_col9 {
#             color:  black;
#         }    #T_c3345d6c_408f_11ea_8297_0242ac1c0002row3_col10 {
#             color:  orange;
#         }    #T_c3345d6c_408f_11ea_8297_0242ac1c0002row3_col11 {
#             color:  black;
#         }    #T_c3345d6c_408f_11ea_8297_0242ac1c0002row3_col12 {
#             color:  orange;
#         }    #T_c3345d6c_408f_11ea_8297_0242ac1c0002row3_col13 {
#             color:  orange;
#         }    #T_c3345d6c_408f_11ea_8297_0242ac1c0002row4_col0 {
#             color:  black;
#         }    #T_c3345d6c_408f_11ea_8297_0242ac1c0002row4_col1 {
#             color:  black;
#         }    #T_c3345d6c_408f_11ea_8297_0242ac1c0002row4_col2 {
#             color:  black;
#         }    #T_c3345d6c_408f_11ea_8297_0242ac1c0002row4_col3 {
#             color:  black;
#         }    #T_c3345d6c_408f_11ea_8297_0242ac1c0002row4_col4 {
#             color:  black;
#         }    #T_c3345d6c_408f_11ea_8297_0242ac1c0002row4_col5 {
#             color:  black;
#         }    #T_c3345d6c_408f_11ea_8297_0242ac1c0002row4_col6 {
#             color:  orange;
#         }    #T_c3345d6c_408f_11ea_8297_0242ac1c0002row4_col7 {
#             color:  black;
#         }    #T_c3345d6c_408f_11ea_8297_0242ac1c0002row4_col8 {
#             color:  black;
#         }    #T_c3345d6c_408f_11ea_8297_0242ac1c0002row4_col9 {
#             color:  black;
#         }    #T_c3345d6c_408f_11ea_8297_0242ac1c0002row4_col10 {
#             color:  black;
#         }    #T_c3345d6c_408f_11ea_8297_0242ac1c0002row4_col11 {
#             color:  black;
#         }    #T_c3345d6c_408f_11ea_8297_0242ac1c0002row4_col12 {
#             color:  black;
#         }    #T_c3345d6c_408f_11ea_8297_0242ac1c0002row4_col13 {
#             color:  orange;
#         }</style><table id="T_c3345d6c_408f_11ea_8297_0242ac1c0002" ><thead>    <tr>        <th class="blank level0" ></th>        <th class="col_heading level0 col0" >Label</th>        <th class="col_heading level0 col1" >Train_fold_0</th>        <th class="col_heading level0 col2" >Valid_fold_0</th>        <th class="col_heading level0 col3" >Train_fold_1</th>        <th class="col_heading level0 col4" >Valid_fold_1</th>        <th class="col_heading level0 col5" >Train_fold_2</th>        <th class="col_heading level0 col6" >Valid_fold_2</th>        <th class="col_heading level0 col7" >Train_fold_3</th>        <th class="col_heading level0 col8" >Valid_fold_3</th>        <th class="col_heading level0 col9" >Train_fold_4</th>        <th class="col_heading level0 col10" >Valid_fold_4</th>        <th class="col_heading level0 col11" >Train</th>        <th class="col_heading level0 col12" >Validation</th>        <th class="col_heading level0 col13" >Var</th>    </tr></thead><tbody>
#                 <tr>
#                         <th id="T_c3345d6c_408f_11ea_8297_0242ac1c0002level0_row0" class="row_heading level0 row0" >0</th>
#                         <td id="T_c3345d6c_408f_11ea_8297_0242ac1c0002row0_col0" class="data row0 col0" >LIFE_ARTS</td>
#                         <td id="T_c3345d6c_408f_11ea_8297_0242ac1c0002row0_col1" class="data row0 col1" >0.516</td>
#                         <td id="T_c3345d6c_408f_11ea_8297_0242ac1c0002row0_col2" class="data row0 col2" >0.405</td>
#                         <td id="T_c3345d6c_408f_11ea_8297_0242ac1c0002row0_col3" class="dat
