# %% [markdown]
# ## Dependencies

# %%
import warnings
import tensorflow_hub as hub
from tensorflow.keras import Model, optimizers
from tensorflow.keras.layers import Lambda, Input, Dense, Dropout, Concatenate
from tensorflow.keras.callbacks import EarlyStopping, ReduceLROnPlateau
from googleqa_utilityscript import *
from googleqa_map_utilityscript import *

SEED = 0
seed_everything(SEED)
warnings.filterwarnings("ignore")

# %% [markdown]
# ## Load data

# %%
module_url = '/kaggle/input/universalsentenceencodermodels/universal-sentence-encoder-models/use-qa'

k_fold = pd.read_csv('/kaggle/input/googleqa-mldataset/3-fold.csv')
N_FOLDS = 3

print('Samples: %s' % len(k_fold))
display(k_fold.head())
# Out:
# Samples: 6079
#    qa_id                                     question_title  \
# 0      0  What am I losing when using extension tubes in...
# 1      1  What is the distinction between a city and a s...
# 2      2  Maximum protusion length for through-hole comp...
# 3      3              Can an affidavit be used in Beit Din?
# 4      5       How do you make a binary image in Photoshop?
#
#                                        question_body question_user_name  \
# 0  After playing around with macro photography on...               ysap
# 1  I am trying to understand what kinds of places...      russellpierce
# 2  I'm working on a PCB that has through-hole com...          Joe Baker
# 3  An affidavit, from what i understand, is basic...         Scimonster
# 4  I am trying to make a binary image. I want mor...            leigero
#
#                                   question_user_page  \
# 0         https://photo.stackexchange.com/users/1024
# 1           https://rpg.stackexchange.com/users/8774
# 2  https://electronics.stackexchange.com/users/10157
# 3       https://judaism.stackexchange.com/users/5151
# 4  https://graphicdesign.stackexchange.com/users/...
#
#                                               answer answer_user_name  \
# 0  I just got extension tubes, so here's the skin...           rfusca
# 1  It might be helpful to look into the definitio...     Erik Schmidt
# 2  Do you even need grooves?  We make several pro...      Dwayne Reid
# 3  Sending an "affidavit" it is a dispute between...    Y     e     z
# 4  Check out Image Trace in Adobe Illustrator. \n...             q2ra
#
#                                     answer_user_page  \
# 0         https://photo.stackexchange.com/users/1917
# 1           https://rpg.stackexchange.com/users/1871
# 2  https://electronics.stackexchange.com/users/64754
# 3       https://judaism.stackexchange.com/users/4794
# 4  https://graphicdesign.stackexchange.com/users/...
#
#                                                  url   category  ...  \
# 0  http://photo.stackexchange.com/questions/9169/...  LIFE_ARTS  ...
# 1  http://rpg.stackexchange.com/questions/47820/w...    CULTURE  ...
# 2  http://electronics.stackexchange.com/questions...    SCIENCE  ...
# 3  http://judaism.stackexchange.com/questions/551...    CULTURE  ...
# 4  http://graphicdesign.stackexchange.com/questio...  LIFE_ARTS  ...
#
#   answer_plausible  answer_relevance  answer_satisfaction  \
# 0         1.000000          1.000000             0.800000
# 1         0.888889          0.888889             0.666667
# 2         1.000000          1.000000             0.666667
# 3         0.833333          1.000000             0.800000
# 4         1.000000          1.000000             0.800000
#
#    answer_type_instructions  answer_type_procedure  \
# 0                       1.0               0.000000
# 1                       0.0               0.000000
# 2                       0.0               0.333333
# 3                       0.0               0.000000
# 4                       1.0               0.000000
#
#    answer_type_reason_explanation  answer_well_written      fold_1  \
# 0                        0.000000             1.000000       train
# 1                        0.666667             0.888889       train
# 2                        1.000000             0.888889  validation
# 3                        1.000000             1.000000       train
# 4                        1.000000             1.000000       train
#
#        fold_2      fold_3
# 0       train  validation
# 1  validation       train
# 2       train       train
# 3       train  validation
# 4  validation       train
#
# [5 rows x 44 columns]

# %%
question_target_cols = ['question_asker_intent_understanding','question_body_critical', 'question_conversational', 
                        'question_expect_short_answer', 'question_fact_seeking', 'question_has_commonly_accepted_answer',
                        'question_interestingness_others', 'question_interestingness_self', 'question_multi_intent', 
                        'question_not_really_a_question', 'question_opinion_seeking', 'question_type_choice',
                        'question_type_compare', 'question_type_consequence', 'question_type_definition', 
                        'question_type_entity', 'question_type_instructions', 'question_type_procedure',
                        'question_type_reason_explanation', 'question_type_spelling', 'question_well_written']
answer_target_cols = ['answer_helpful', 'answer_level_of_information', 'answer_plausible', 'answer_relevance',
                      'answer_satisfaction', 'answer_type_instructions', 'answer_type_procedure', 
                      'answer_type_reason_explanation', 'answer_well_written']
target_cols = question_target_cols + answer_target_cols

# %% [markdown]
# # Pre-process data

# %%
text_features = ['question_title', 'question_body', 'answer']

for feature in text_features:
    # Lower
    k_fold[feature] = k_fold[feature].apply(lambda x: x.lower())
    # Map misspellings
    k_fold[feature] = k_fold[feature].apply(lambda x: map_misspellings(x))
    # Map contractions
    k_fold[feature] = k_fold[feature].apply(lambda x: map_contraction(x))
    # Trim text
    k_fold[feature] = k_fold[feature].apply(lambda x: x.strip())

# %% [markdown]
# # Model parameters

# %%
EPOCHS = 40
BATCH_SIZE = 32
LEARNING_RATE = 3e-4
EMBEDDDING_SIZE = 512
N_CLASS = len(target_cols)
ES_PATIENCE = 3
RLROP_PATIENCE = 2
DECAY_DROP = 0.3

# %% [markdown]
# # Model

# %%
es = EarlyStopping(monitor='val_loss', mode='min', patience=ES_PATIENCE, restore_best_weights=True, verbose=1)
rlrop = ReduceLROnPlateau(monitor='val_loss', mode='min', patience=RLROP_PATIENCE, factor=DECAY_DROP, min_lr=1e-6, verbose=1)
use_embed = hub.load(module_url)

def USEEmbedding(x):
    return use_embed(tf.squeeze(tf.cast(x, tf.string)))

# %%
def model_fn():
    input_title = Input(shape=(1,), dtype=tf.string, name='input_title')
    embedding_title = Lambda(USEEmbedding, output_shape=(EMBEDDDING_SIZE,))(input_title)

    input_body = Input(shape=(1,), dtype=tf.string, name='input_body')
    embedding_body = Lambda(USEEmbedding, output_shape=(EMBEDDDING_SIZE,))(input_body)

    input_answer = Input(shape=(1,), dtype=tf.string, name='input_answer')
    embedding_answer = Lambda(USEEmbedding, output_shape=(EMBEDDDING_SIZE,))(input_answer)

    x = Concatenate()([embedding_title, embedding_body, embedding_answer])
    x = Dropout(0.5)(x)
    x = Dense(512, activation='relu')(x)
    x = Dropout(0.5)(x)
    output = Dense(N_CLASS, activation='sigmoid', name='output')(x)
    model = Model(inputs=[input_title, input_body, input_answer], outputs=[output])
    
    return model

# %% [markdown]
# # Train model

# %%
history_list = []
metric_list = []
category_metric_list = []
target_cols_preds = [col+'_pred' for col in target_cols]

for n_fold in range(N_FOLDS):
    model_path = '/kaggle/working/model_fold_%d.h5' % (n_fold+1)
    train = k_fold[k_fold['fold_%d' % (n_fold+1)] == 'train']
    validation = k_fold[k_fold['fold_%d' % (n_fold+1)] == 'validation']
    ### Create features
    # Train features
    X_train = [train['question_title'], train['question_body'], train['answer']]
    Y_train = train[target_cols].values
    # Validation features
    X_valid = [validation['question_title'], validation['question_body'], validation['answer']]
    Y_valid = validation[target_cols].values

    ### Train model
    spearmanCallback = SpearmanRhoCallback(training_data=(X_train, Y_train), 
                                           validation_data=(X_valid, Y_valid), 
                                           model_path=model_path, 
                                           monitor='val_loss', mode='min', 
                                           patience=ES_PATIENCE, checkpoint=True)

    callback_list = [spearmanCallback]
    optimizer = optimizers.Adam(lr=LEARNING_RATE)
    model = model_fn()
    model.compile(optimizer=optimizer, loss='binary_crossentropy')

    history = model.fit(X_train, Y_train, 
                        validation_data=(X_valid, Y_valid), 
                        callbacks=callback_list, 
                        batch_size=BATCH_SIZE, 
                        epochs=EPOCHS, 
                        verbose=2).history
    history_list.append(history)
    
    ### Evaluation - Label metrics
    model.load_weights(model_path)
    preds_train = model.predict(X_train)
    preds_val = model.predict(X_valid)
    metric_list.append(get_metrics(Y_train, preds_train, Y_valid, preds_val, target_cols))
    
    ### Evaluation - Category metrics
    for col in target_cols_preds:
        train[col] = 0
        validation[col] = 0

    train[target_cols_preds] = preds_train
    validation[target_cols_preds] = preds_val
    category_metric_list.append(get_metrics_category(train, validation, target_cols, target_cols_preds, 'category'))
# Out:
# Train on 4051 samples, validate on 2028 samples
# Epoch 1/40
# spearman-rho: 0.2031 val_spearman-rho: 0.1899
# Saved model weights at "/kaggle/working/model_fold_1.h5"
# 4051/4051 - 212s - loss: 0.5087 - val_loss: 0.4154
# Epoch 2/40
# spearman-rho: 0.2919 val_spearman-rho: 0.2718
# Saved model weights at "/kaggle/working/model_fold_1.h5"
# 4051/4051 - 125s - loss: 0.4104 - val_loss: 0.3972
# Epoch 3/40
# spearman-rho: 0.3376 val_spearman-rho: 0.3099
# Saved model weights at "/kaggle/working/model_fold_1.h5"
# 4051/4051 - 124s - loss: 0.3984 - val_loss: 0.3887
# Epoch 4/40
# spearman-rho: 0.3657 val_spearman-rho: 0.3310
# Saved model weights at "/kaggle/working/model_fold_1.h5"
# 4051/4051 - 124s - loss: 0.3911 - val_loss: 0.3841
# Epoch 5/40
# spearman-rho: 0.3830 val_spearman-rho: 0.3429
# Saved model weights at "/kaggle/working/model_fold_1.h5"
# 4051/4051 - 124s - loss: 0.3864 - val_loss: 0.3807
# Epoch 6/40
# spearman-rho: 0.3964 val_spearman-rho: 0.3507
# Saved model weights at "/kaggle/working/model_fold_1.h5"
# 4051/4051 - 125s - loss: 0.3827 - val_loss: 0.3785
# Epoch 7/40
# spearman-rho: 0.4078 val_spearman-rho: 0.3568
# Saved model weights at "/kaggle/working/model_fold_1.h5"
# 4051/4051 - 125s - loss: 0.3799 - val_loss: 0.3770
# Epoch 8/40
# spearman-rho: 0.4169 val_spearman-rho: 0.3607
# Saved model weights at "/kaggle/working/model_fold_1.h5"
# 4051/4051 - 124s - loss: 0.3779 - val_loss: 0.3759
# Epoch 9/40
# spearman-rho: 0.4247 val_spearman-rho: 0.3640
# Saved model weights at "/kaggle/working/model_fold_1.h5"
# 4051/4051 - 124s - loss: 0.3757 - val_loss: 0.3748
# Epoch 10/40
# spearman-rho: 0.4318 val_spearman-rho: 0.3665
# Saved model weights at "/kaggle/working/model_fold_1.h5"
# 4051/4051 - 124s - loss: 0.3746 - val_loss: 0.3743
# Epoch 11/40
# spearman-rho: 0.4374 val_spearman-rho: 0.3678
# Saved model weights at "/kaggle/working/model_fold_1.h5"
# 4051/4051 - 125s - loss: 0.3736 - val_loss: 0.3735
# Epoch 12/40
# spearman-rho: 0.4436 val_spearman-rho: 0.3694
# Saved model weights at "/kaggle/working/model_fold_1.h5"
# 4051/4051 - 124s - loss: 0.3724 - val_loss: 0.3732
# Epoch 13/40
# spearman-rho: 0.4488 val_spearman-rho: 0.3706
# Saved model weights at "/kaggle/working/model_fold_1.h5"
# 4051/4051 - 124s - loss: 0.3712 - val_loss: 0.3723
# Epoch 14/40
# spearman-rho: 0.4540 val_spearman-rho: 0.3720
# Saved model weights at "/kaggle/working/model_fold_1.h5"
# 4051/4051 - 124s - loss: 0.3694 - val_loss: 0.3721
# Epoch 15/40
# spearman-rho: 0.4583 val_spearman-rho: 0.3723
# Saved model weights at "/kaggle/working/model_fold_1.h5"
# 4051/4051 - 125s - loss: 0.3686 - val_loss: 0.3717
# Epoch 16/40
# spearman-rho: 0.4617 val_spearman-rho: 0.3732
# Saved model weights at "/kaggle/working/model_fold_1.h5"
# 4051/4051 - 125s - loss: 0.3676 - val_loss: 0.3715
# Epoch 17/40
# spearman-rho: 0.4663 val_spearman-rho: 0.3747
# Saved model weights at "/kaggle/working/model_fold_1.h5"
# 4051/4051 - 124s - loss: 0.3671 - val_loss: 0.3714
# Epoch 18/40
# spearman-rho: 0.4700 val_spearman-rho: 0.3746
# Saved model weights at "/kaggle/working/model_fold_1.h5"
# 4051/4051 - 123s - loss: 0.3659 - val_loss: 0.3712
# Epoch 19/40
# spearman-rho: 0.4734 val_spearman-rho: 0.3756
# Saved model weights at "/kaggle/working/model_fold_1.h5"
# 4051/4051 - 124s - loss: 0.3650 - val_loss: 0.3708
# Epoch 20/40
# spearman-rho: 0.4775 val_spearman-rho: 0.3754
# Saved model weights at "/kaggle/working/model_fold_1.h5"
# 4051/4051 - 124s - loss: 0.3638 - val_loss: 0.3708
# Epoch 21/40
# spearman-rho: 0.4799 val_spearman-rho: 0.3762
# Saved model weights at "/kaggle/working/model_fold_1.h5"
# 4051/4051 - 124s - loss: 0.3637 - val_loss: 0.3705
# Epoch 22/40
# spearman-rho: 0.4831 val_spearman-rho: 0.3765
# 4051/4051 - 125s - loss: 0.3626 - val_loss: 0.3705
# Epoch 23/40
# spearman-rho: 0.4861 val_spearman-rho: 0.3772
# Saved model weights at "/kaggle/working/model_fold_1.h5"
# 4051/4051 - 124s - loss: 0.3629 - val_loss: 0.3704
# Epoch 24/40
# spearman-rho: 0.4893 val_spearman-rho: 0.3772
# Saved model weights at "/kaggle/working/model_fold_1.h5"
# 4051/4051 - 124s - loss: 0.3619 - val_loss: 0.3703
# Epoch 25/40
# spearman-rho: 0.4922 val_spearman-rho: 0.3777
# Saved model weights at "/kaggle/working/model_fold_1.h5"
# 4051/4051 - 124s - loss: 0.3617 - val_loss: 0.3702
# Epoch 26/40
# spearman-rho: 0.4950 val_spearman-rho: 0.3785
# Saved model weights at "/kaggle/working/model_fold_1.h5"
# 4051/4051 - 124s - loss: 0.3611 - val_loss: 0.3701
# Epoch 27/40
# spearman-rho: 0.4977 val_spearman-rho: 0.3791
# Saved model weights at "/kaggle/working/model_fold_1.h5"
# 4051/4051 - 124s - loss: 0.3597 - val_loss: 0.3697
# Epoch 28/40
# spearman-rho: 0.5000 val_spearman-rho: 0.3783
# 4051/4051 - 123s - loss: 0.3595 - val_loss: 0.3701
# Epoch 29/40
# spearman-rho: 0.5024 val_spearman-rho: 0.3789
# Epoch 00028: early stopping
# 4051/4051 - 124s - loss: 0.3598 - val_loss: 0.3699
# Train on 4063 samples, validate on 2016 samples
# Epoch 1/40
# spearman-rho: 0.2069 val_spearman-rho: 0.2031
# Saved model weights at "/kaggle/working/model_fold_2.h5"
# 4063/4063 - 200s - loss: 0.5073 - val_loss: 0.4135
# Epoch 2/40
# spearman-rho: 0.2907 val_spearman-rho: 0.2765
# Saved model weights at "/kaggle/working/model_fold_2.h5"
# 4063/4063 - 123s - loss: 0.4107 - val_loss: 0.3957
# Epoch 3/40
# spearman-rho: 0.3376 val_spearman-rho: 0.3139
# Saved model weights at "/kaggle/working/model_fold_2.h5"
# 4063/4063 - 124s - loss: 0.3982 - val_loss: 0.3881
# Epoch 4/40
# spearman-rho: 0.3658 val_spearman-rho: 0.3339
# Saved model weights at "/kaggle/working/model_fold_2.h5"
# 4063/4063 - 122s - loss: 0.3914 - val_loss: 0.3834
# Epoch 5/40
# spearman-rho: 0.3847 val_spearman-rho: 0.3451
# Saved model weights at "/kaggle/working/model_fold_2.h5"
# 4063/4063 - 122s - loss: 0.3860 - val_loss: 0.3806
# Epoch 6/40
# spearman-rho: 0.3977 val_spearman-rho: 0.3516
# Saved model weights at "/kaggle/working/model_fold_2.h5"
# 4063/4063 - 123s - loss: 0.3829 - val_loss: 0.3787
# Epoch 7/40
# spearman-rho: 0.4077 val_spearman-rho: 0.3564
# Saved model weights at "/kaggle/working/model_fold_2.h5"
# 4063/4063 - 123s - loss: 0.3800 - val_loss: 0.3772
# Epoch 8/40
# spearman-rho: 0.4177 val_spearman-rho: 0.3600
# Saved model weights at "/kaggle/working/model_fold_2.h5"
# 4063/4063 - 122s - loss: 0.3776 - val_loss: 0.3760
# Epoch 9/40
# spearman-rho: 0.4260 val_spearman-rho: 0.3627
# Saved model weights at "/kaggle/working/model_fold_2.h5"
# 4063/4063 - 122s - loss: 0.3757 - val_loss: 0.3751
# Epoch 10/40
# spearman-rho: 0.4330 val_spearman-rho: 0.3652
# Saved model weights at "/kaggle/working/model_fold_2.h5"
# 4063/4063 - 123s - loss: 0.3745 - val_loss: 0.3744
# Epoch 11/40
# spearman-rho: 0.4398 val_spearman-rho: 0.3667
# Saved model weights at "/kaggle/working/model_fold_2.h5"
# 4063/4063 - 123s - loss: 0.3733 - val_loss: 0.3738
# Epoch 12/40
# spearman-rho: 0.4456 val_spearman-rho: 0.3677
# Saved model weights at "/kaggle/working/model_fold_2.h5"
# 4063/4063 - 122s - loss: 0.3718 - val_loss: 0.3735
# Epoch 13/40
# spearman-rho: 0.4500 val_spearman-rho: 0.3687
# Saved model weights at "/kaggle/working/model_fold_2.h5"
# 4063/4063 - 122s - loss: 0.3705 - val_loss: 0.3730
# Epoch 14/40
# spearman-rho: 0.4551 val_spearman-rho: 0.3699
# Saved model weights at "/kaggle/working/model_fold_2.h5"
# 4063/4063 - 123s - loss: 0.3693 - val_loss: 0.3725
# Epoch 15/40
# spearman-rho: 0.4592 val_spearman-rho: 0.3709
# Saved model weights at "/kaggle/working/model_fold_2.h5"
# 4063/4063 - 124s - loss: 0.3679 - val_loss: 0.3722
# Epoch 16/40
# spearman-rho: 0.4635 val_spearman-rho: 0.3711
# 4063/4063 - 123s - loss: 0.3675 - val_loss: 0.3723
# Epoch 17/40
# spearman-rho: 0.4674 val_spearman-rho: 0.3721
# Saved model weights at "/kaggle/working/model_fold_2.h5"
# 4063/4063 - 123s - loss: 0.3665 - val_loss: 0.3717
# Epoch 18/40
# spearman-rho: 0.4710 val_spearman-rho: 0.3726
# Saved model weights at "/kaggle/working/model_fold_2.h5"
# 4063/4063 - 122s - loss: 0.3651 - val_loss: 0.3715
# Epoch 19/40
# spearman-rho: 0.4750 val_spearman-rho: 0.3723
# 4063/4063 - 123s - loss: 0.3651 - val_loss: 0.3717
# Epoch 20/40
# spearman-rho: 0.4783 val_spearman-rho: 0.3723
# Saved model weights at "/kaggle/working/model_fold_2.h5"
# 4063/4063 - 122s - loss: 0.3645 - val_loss: 0.3714
# Epoch 21/40
# spearman-rho: 0.4811 val_spearman-rho: 0.3732
# Saved model weights at "/kaggle/working/model_fold_2.h5"
# 4063/4063 - 123s - loss: 0.3635 - val_loss: 0.3711
# Epoch 22/40
# spearman-rho: 0.4849 val_spearman-rho: 0.3738
# Saved model weights at "/kaggle/working/model_fold_2.h5"
# 4063/4063 - 123s - loss: 0.3628 - val_loss: 0.3711
# Epoch 23/40
# spearman-rho: 0.4878 val_spearman-rho: 0.3738
# Saved model weights at "/kaggle/working/model_fold_2.h5"
# 4063/4063 - 123s - loss: 0.3630 - val_loss: 0.3711
# Epoch 24/40
# spearman-rho: 0.4907 val_spearman-rho: 0.3738
# Saved model weights at "/kaggle/working/model_fold_2.h5"
# 4063/4063 - 123s - loss: 0.3617 - val_loss: 0.3709
# Epoch 25/40
# spearman-rho: 0.4933 val_spearman-rho: 0.3742
# Saved model weights at "/kaggle/working/model_fold_2.h5"
# 4063/4063 - 123s - loss: 0.3610 - val_loss: 0.3709
# Epoch 26/40
# spearman-rho: 0.4964 val_spearman-rho: 0.3743
# Saved model weights at "/kaggle/working/model_fold_2.h5"
# 4063/4063 - 123s - loss: 0.3608 - val_loss: 0.3709
# Epoch 27/40
# spearman-rho: 0.4989 val_spearman-rho: 0.3747
# Saved model weights at "/kaggle/working/model_fold_2.h5"
# 4063/4063 - 123s - loss: 0.3606 - val_loss: 0.3708
# Epoch 28/40
# spearman-rho: 0.5012 val_spearman-rho: 0.3748
# Epoch 00027: early stopping
# 4063/4063 - 122s - loss: 0.3599 - val_loss: 0.3708
# Train on 4044 samples, validate on 2035 samples
# Epoch 1/40
# spearman-rho: 0.2047 val_spearman-rho: 0.1767
# Saved model weights at "/kaggle/working/model_fold_3.h5"
# 4044/4044 - 203s - loss: 0.5055 - val_loss: 0.4170
# Epoch 2/40
# spearman-rho: 0.2958 val_spearman-rho: 0.2609
# Saved model weights at "/kaggle/working/model_fold_3.h5"
# 4044/4044 - 125s - loss: 0.4105 - val_loss: 0.3987
# Epoch 3/40
# spearman-rho: 0.3426 val_spearman-rho: 0.3020
# Saved model weights at "/kaggle/working/model_fold_3.h5"
# 4044/4044 - 124s - loss: 0.3972 - val_loss: 0.3908
# Epoch 4/40
# spearman-rho: 0.3688 val_spearman-rho: 0.3225
# Saved model weights at "/kaggle/working/model_fold_3.h5"
# 4044/4044 - 124s - loss: 0.3902 - val_loss: 0.3860
# Epoch 5/40
# spearman-rho: 0.3861 val_spearman-rho: 0.3340
# Saved model weights at "/kaggle/working/model_fold_3.h5"
# 4044/4044 - 123s - loss: 0.3851 - val_loss: 0.3827
# Epoch 6/40
# spearman-rho: 0.3988 val_spearman-rho: 0.3420
# Saved model weights at "/kaggle/working/model_fold_3.h5"
# 4044/4044 - 124s - loss: 0.3817 - val_loss: 0.3807
# Epoch 7/40
# spearman-rho: 0.4097 val_spearman-rho: 0.3482
# Saved model weights at "/kaggle/working/model_fold_3.h5"
# 4044/4044 - 125s - loss: 0.3793 - val_loss: 0.3791
# Epoch 8/40
# spearman-rho: 0.4189 val_spearman-rho: 0.3518
# Saved model weights at "/kaggle/working/model_fold_3.h5"
# 4044/4044 - 124s - loss: 0.3767 - val_loss: 0.3779
# Epoch 9/40
# spearman-rho: 0.4267 val_spearman-rho: 0.3553
# Saved model weights at "/kaggle/working/model_fold_3.h5"
# 4044/4044 - 125s - loss: 0.3746 - val_loss: 0.3769
# Epoch 10/40
# spearman-rho: 0.4341 val_spearman-rho: 0.3583
# Saved model weights at "/kaggle/working/model_fold_3.h5"
# 4044/4044 - 125s - loss: 0.3734 - val_loss: 0.3762
# Epoch 11/40
# spearman-rho: 0.4400 val_spearman-rho: 0.3596
# Saved model weights at "/kaggle/working/model_fold_3.h5"
# 4044/4044 - 123s - loss: 0.3719 - val_loss: 0.3755
# Epoch 12/40
# spearman-rho: 0.4453 val_spearman-rho: 0.3619
# Saved model weights at "/kaggle/working/model_fold_3.h5"
# 4044/4044 - 124s - loss: 0.3701 - val_loss: 0.3748
# Epoch 13/40
# spearman-rho: 0.4506 val_spearman-rho: 0.3639
# Saved model weights at "/kaggle/working/model_fold_3.h5"
# 4044/4044 - 124s - loss: 0.3699 - val_loss: 0.3746
# Epoch 14/40
# spearman-rho: 0.4559 val_spearman-rho: 0.3654
# Saved model weights at "/kaggle/working/model_fold_3.h5"
# 4044/4044 - 125s - loss: 0.3680 - val_loss: 0.3743
# Epoch 15/40
# spearman-rho: 0.4601 val_spearman-rho: 0.3665
# Saved model weights at "/kaggle/working/model_fold_3.h5"
# 4044/4044 - 125s - loss: 0.3674 - val_loss: 0.3739
# Epoch 16/40
# spearman-rho: 0.4635 val_spearman-rho: 0.3676
# Saved model weights at "/kaggle/working/model_fold_3.h5"
# 4044/4044 - 125s - loss: 0.3662 - val_loss: 0.3736
# Epoch 17/40
# spearman-rho: 0.4674 val_spearman-rho: 0.3687
# Saved model weights at "/kaggle/working/model_fold_3.h5"
# 4044/4044 - 124s - loss: 0.3655 - val_loss: 0.3735
# Epoch 18/40
# spearman-rho: 0.4715 val_spearman-rho: 0.3697
# Saved model weights at "/kaggle/working/model_fold_3.h5"
# 4044/4044 - 124s - loss: 0.3648 - val_loss: 0.3732
# Epoch 19/40
# spearman-rho: 0.4748 val_spearman-rho: 0.3706
# Saved model weights at "/kaggle/working/model_fold_3.h5"
# 4044/4044 - 123s - loss: 0.3638 - val_loss: 0.3730
# Epoch 20/40
# spearman-rho: 0.4782 val_spearman-rho: 0.3715
# Saved model weights at "/kaggle/working/model_fold_3.h5"
# 4044/4044 - 124s - loss: 0.3635 - val_loss: 0.3730
# Epoch 21/40
# spearman-rho: 0.4809 val_spearman-rho: 0.3724
# Saved model weights at "/kaggle/working/model_fold_3.h5"
# 4044/4044 - 124s - loss: 0.3628 - val_loss: 0.3728
# Epoch 22/40
# spearman-rho: 0.4841 val_spearman-rho: 0.3723
# Saved model weights at "/kaggle/working/model_fold_3.h5"
# 4044/4044 - 125s - loss: 0.3620 - val_loss: 0.3725
# Epoch 23/40
# spearman-rho: 0.4871 val_spearman-rho: 0.3726
# Saved model weights at "/kaggle/working/model_fold_3.h5"
# 4044/4044 - 125s - loss: 0.3617 - val_loss: 0.3725
# Epoch 24/40
# spearman-rho: 0.4899 val_spearman-rho: 0.3733
# Saved model weights at "/kaggle/working/model_fold_3.h5"
# 4044/4044 - 125s - loss: 0.3612 - val_loss: 0.3723
# Epoch 25/40
# spearman-rho: 0.4924 val_spearman-rho: 0.3740
# 4044/4044 - 124s - loss: 0.3605 - val_loss: 0.3724
# Epoch 26/40
# spearman-rho: 0.4945 val_spearman-rho: 0.3741
# 4044/4044 - 124s - loss: 0.3595 - val_loss: 0.3723
# Epoch 27/40
# spearman-rho: 0.4970 val_spearman-rho: 0.3740
# Saved model weights at "/kaggle/working/model_fold_3.h5"
# 4044/4044 - 124s - loss: 0.3593 - val_loss: 0.3723
# Epoch 28/40
# spearman-rho: 0.5001 val_spearman-rho: 0.3745
# Epoch 00027: early stopping
# 4044/4044 - 125s - loss: 0.3586 - val_loss: 0.3724

# %% [markdown]
# ## Model loss graph

# %%
for n_fold in range(N_FOLDS):
    print('Fold: %d' % n_fold)
    sns.set(style="whitegrid")
    plot_metrics(history_list[n_fold], metric_list=['loss', 'spearman'])
# Out:
# Fold: 0
# Fold: 1
# Fold: 2

# %% [markdown]
# # Evaluation

# %%
metrics_df = metric_list[0][['Label', 'Train', 'Validation']].copy()
metrics_df.columns = ['Label', 'Train_fold_0', 'Valid_fold_0']

for n_fold in range(1, N_FOLDS):
    metrics_df_idx = metric_list[n_fold][['Train', 'Validation']].copy()
    metrics_df_idx.columns = ['Train_fold_%d' % n_fold, 'Valid_fold_%d' % n_fold]
    metrics_df = pd.concat([metrics_df, metrics_df_idx], axis=1)

metrics_df['Train'] = 0
metrics_df['Validation'] = 0
for n_fold in range(N_FOLDS):
    metrics_df['Train'] += metrics_df['Train_fold_%d' % n_fold] / N_FOLDS
    metrics_df['Validation'] += metrics_df['Valid_fold_%d' % n_fold] / N_FOLDS

metrics_df['Var'] = metrics_df['Train'] - metrics_df['Validation']
display(metrics_df.style.applymap(color_map))
# Out:
# <style  type="text/css" >
#     #T_6a0b200c_3367_11ea_a02a_0d5cc93db60frow0_col0 {
#             color:  black;
#         }    #T_6a0b200c_3367_11ea_a02a_0d5cc93db60frow0_col1 {
#             color:  black;
#         }    #T_6a0b200c_3367_11ea_a02a_0d5cc93db60frow0_col2 {
#             color:  black;
#         }    #T_6a0b200c_3367_11ea_a02a_0d5cc93db60frow0_col3 {
#             color:  black;
#         }    #T_6a0b200c_3367_11ea_a02a_0d5cc93db60frow0_col4 {
#             color:  black;
#         }    #T_6a0b200c_3367_11ea_a02a_0d5cc93db60frow0_col5 {
#             color:  black;
#         }    #T_6a0b200c_3367_11ea_a02a_0d5cc93db60frow0_col6 {
#             color:  black;
#         }    #T_6a0b200c_3367_11ea_a02a_0d5cc93db60frow0_col7 {
#             color:  black;
#         }    #T_6a0b200c_3367_11ea_a02a_0d5cc93db60frow0_col8 {
#             color:  black;
#         }    #T_6a0b200c_3367_11ea_a02a_0d5cc93db60frow0_col9 {
#             color:  orange;
#         }    #T_6a0b200c_3367_11ea_a02a_0d5cc93db60frow1_col0 {
#             color:  black;
#         }    #T_6a0b200c_3367_11ea_a02a_0d5cc93db60frow1_col1 {
#             color:  black;
#         }    #T_6a0b200c_3367_11ea_a02a_0d5cc93db60frow1_col2 {
#             color:  black;
#         }    #T_6a0b200c_3367_11ea_a02a_0d5cc93db60frow1_col3 {
#             color:  black;
#         }    #T_6a0b200c_3367_11ea_a02a_0d5cc93db60frow1_col4 {
#             color:  black;
#         }    #T_6a0b200c_3367_11ea_a02a_0d5cc93db60frow1_col5 {
#             color:  black;
#         }    #T_6a0b200c_3367_11ea_a02a_0d5cc93db60frow1_col6 {
#             color:  black;
#         }    #T_6a0b200c_3367_11ea_a02a_0d5cc93db60frow1_col7 {
#             color:  black;
#         }    #T_6a0b200c_3367_11ea_a02a_0d5cc93db60frow1_col8 {
#             color:  black;
#         }    #T_6a0b200c_3367_11ea_a02a_0d5cc93db60frow1_col9 {
#             color:  orange;
#         }    #T_6a0b200c_3367_11ea_a02a_0d5cc93db60frow2_col0 {
#             color:  black;
#         }    #T_6a0b200c_3367_11ea_a02a_0d5cc93db60frow2_col1 {
#             color:  black;
#         }    #T_6a0b200c_3367_11ea_a02a_0d5cc93db60frow2_col2 {
#             color:  black;
#         }    #T_6a0b200c_3367_11ea_a02a_0d5cc93db60frow2_col3 {
#             color:  black;
#         }    #T_6a0b200c_3367_11ea_a02a_0d5cc93db60frow2_col4 {
#             color:  black;
#         }    #T_6a0b200c_3367_11ea_a02a_0d5cc93db60frow2_col5 {
#             color:  black;
#         }    #T_6a0b200c_3367_11ea_a02a_0d5cc93db60frow2_col6 {
#             color:  black;
#         }    #T_6a0b200c_3367_11ea_a02a_0d5cc93db60frow2_col7 {
#             color:  black;
#         }    #T_6a0b200c_3367_11ea_a02a_0d5cc93db60frow2_col8 {
#             color:  black;
#         }    #T_6a0b200c_3367_11ea_a02a_0d5cc93db60frow2_col9 {
#             color:  orange;
#         }    #T_6a0b200c_3367_11ea_a02a_0d5cc93db60frow3_col0 {
#             color:  black;
#         }    #T_6a0b200c_3367_11ea_a02a_0d5cc93db60frow3_col1 {
#             color:  black;
#         }    #T_6a0b200c_3367_11ea_a02a_0d5cc93db60frow3_col2 {
#             color:  black;
#         }    #T_6a0b200c_3367_11ea_a02a_0d5cc93db60frow3_col3 {
#             color:  black;
#         }    #T_6a0b200c_3367_11ea_a02a_0d5cc93db60frow3_col4 {
#             color:  black;
#         }    #T_6a0b200c_3367_11ea_a02a_0d5cc93db60frow3_col5 {
#             color:  black;
#         }    #T_6a0b200c_3367_11ea_a02a_0d5cc93db60frow3_col6 {
#             color:  black;
#         }    #T_6a0b200c_3367_11ea_a02a_0d5cc93db60frow3_col7 {
#             color:  black;
#         }    #T_6a0b200c_3367_11ea_a02a_0d5cc93db60frow3_col8 {
#             color:  black;
#         }    #T_6a0b200c_3367_11ea_a02a_0d5cc93db60frow3_col9 {
#             color:  orange;
#         }    #T_6a0b200c_3367_11ea_a02a_0d5cc93db60frow4_col0 {
#             color:  black;
#         }    #T_6a0b200c_3367_11ea_a02a_0d5cc93db60frow4_col1 {
#             color:  black;
#         }    #T_6a0b200c_3367_11ea_a02a_0d5cc93db60frow4_col2 {
#             color:  black;
#         }    #T_6a0b200c_3367_11ea_a02a_0d5cc93db60frow4_col3 {
#             color:  black;
#         }    #T_6a0b200c_3367_11ea_a02a_0d5cc93db60frow4_col4 {
#             color:  black;
#         }    #T_6a0b200c_3367_11ea_a02a_0d5cc93db60frow4_col5 {
#             color:  black;
#         }    #T_6a0b200c_3367_11ea_a02a_0d5cc93db60frow4_col6 {
#             color:  black;
#         }    #T_6a0b200c_3367_11ea_a02a_0d5cc93db60frow4_col7 {
#             color:  black;
#         }    #T_6a0b200c_3367_11ea_a02a_0d5cc93db60frow4_col8 {
#             color:  black;
#         }    #T_6a0b200c_3367_11ea_a02a_0d5cc93db60frow4_col9 {
#             color:  purple;
#         }    #T_6a0b200c_3367_11ea_a02a_0d5cc93db60frow5_col0 {
#             color:  black;
#         }    #T_6a0b200c_3367_11ea_a02a_0d5cc93db60frow5_col1 {
#             color:  black;
#         }    #T_6a0b200c_3367_11ea_a02a_0d5cc93db60frow5_col2 {
#             color:  black;
#         }    #T_6a0b200c_3367_11ea_a02a_0d5cc93db60frow5_col3 {
#             color:  black;
#         }    #T_6a0b200c_3367_11ea_a02a_0d5cc93db60frow5_col4 {
#             color:  black;
#         }    #T_6a0b200c_3367_11ea_a02a_0d5cc93db60frow5_col5 {
#             color:  black;
#         }    #T_6a0b200c_3367_11ea_a02a_0d5cc93db60frow5_col6 {
#             color:  black;
#         }    #T_6a0b200c_3367_11ea_a02a_0d5cc93db60frow5_col7 {
#             color:  black;
#         }    #T_6a0b200c_3367_11ea_a02a_0d5cc93db60frow5_col8 {
#             color:  black;
#         }    #T_6a0b200c_3367_11ea_a02a_0d5cc93db60frow5_col9 {
#             color:  purple;
#         }    #T_6a0b200c_3367_11ea_a02a_0d5cc93db60frow6_col0 {
#             color:  black;
#         }    #T_6a0b200c_3367_11ea_a02a_0d5cc93db60frow6_col1 {
#             color:  black;
#         }    #T_6a0b200c_3367_11ea_a02a_0d5cc93db60frow6_col2 {
#             color:  orange;
#         }    #T_6a0b200c_3367_11ea_a02a_0d5cc93db60frow6_col3 {
#             color:  black;
#         }    #T_6a0b200c_3367_11ea_a02a_0d5cc93db60frow6_col4 {
#             color:  orange;
#         }    #T_6a0b200c_3367_11ea_a02a_0d5cc93db60frow6_col5 {
#             color:  black;
#         }    #T_6a0b200c_3367_11ea_a02a_0d5cc93db60frow6_col6 {
#             color:  orange;
#         }    #T_6a0b200c_3367_11ea_a02a_0d5cc93db60frow6_col7 {
#             color:  black;
#         }    #T_6a0b200c_3367_11ea_a02a_0d5cc93db60frow6_col8 {
#             color:  orange;
#         }    #T_6a0b200c_3367_11ea_a02a_0d5cc93db60frow6_col9 {
#             color:  orange;
#         }    #T_6a0b200c_3367_11ea_a02a_0d5cc93db60frow7_col0 {
#             color:  black;
#         }    #T_6a0b200c_3367_11ea_a02a_0d5cc93db60frow7_col1 {
#             color:  black;
#         }    #T_6a0b200c_3367_11ea_a02a_0d5cc93db60frow7_col2 {
#             color:  black;
#         }    #T_6a0b200c_3367_11ea_a02a_0d5cc93db60frow7_col3 {
#             color:  black;
#         }    #T_6a0b200c_3367_11ea_a02a_0d5cc93db60frow7_col4 {
#             color:  black;
#         }    #T_6a0b200c_3367_11ea_a02a_0d5cc93db60frow7_col5 {
#             color:  black;
#         }    #T_6a0b200c_3367_11ea_a02a_0d5cc93db60frow7_col6 {
#             color:  black;
#         }    #T_6a0b200c_3367_11ea_a02a_0d5cc93db60frow7_col7 {
#             color:  black;
#         }    #T_6a0b200c_3367_11ea_a02a_0d5cc93db60frow7_col8 {
#             color:  black;
#         }    #T_6a0b200c_3367_11ea_a02a_0d5cc93db60frow7_col9 {
#             color:  orange;
#         }    #T_6a0b200c_3367_11ea_a02a_0d5cc93db60frow8_col0 {
#             color:  black;
#         }    #T_6a0b200c_3367_11ea_a02a_0d5cc93db60frow8_col1 {
#             color:  black;
#         }    #T_6a0b200c_3367_11ea_a02a_0d5cc93db60frow8_col2 {
#             color:  black;
#         }    #T_6a0b200c_3367_11ea_a02a_0d5cc93db60frow8_col3 {
#             color:  black;
#         }    #T_6a0b200c_3367_11ea_a02a_0d5cc93db60frow8_col4 {
#             color:  black;
#         }    #T_6a0b200c_3367_11ea_a02a_0d5cc93db60frow8_col5 {
#             color:  black;
#         }    #T_6a0b200c_3367_11ea_a02a_0d5cc93db60frow8_col6 {
#             color:  black;
#         }    #T_6a0b200c_3367_11ea_a02a_0d5cc93db60fro

# %% [markdown]
# ## By category

# %%
category_metrics_df = category_metric_list[0][['Label', 'Train', 'Validation']].copy()
category_metrics_df.columns = ['Label', 'Train_fold_0', 'Valid_fold_0']

for n_fold in range(1, N_FOLDS):
    category_metrics_df_idx = category_metric_list[n_fold][['Train', 'Validation']].copy()
    category_metrics_df_idx.columns = ['Train_fold_%d' % n_fold, 'Valid_fold_%d' % n_fold]
    category_metrics_df = pd.concat([category_metrics_df, category_metrics_df_idx], axis=1)
    
category_metrics_df['Train'] = 0
category_metrics_df['Validation'] = 0
for n_fold in range(N_FOLDS):
    category_metrics_df['Train'] += category_metrics_df['Train_fold_%d' % n_fold] / N_FOLDS
    category_metrics_df['Validation'] += category_metrics_df['Valid_fold_%d' % n_fold] / N_FOLDS
    
category_metrics_df['Var'] = category_metrics_df['Train'] - category_metrics_df['Validation']
display(category_metrics_df.style.applymap(color_map))
# Out:
# <style  type="text/css" >
#     #T_6a162cae_3367_11ea_a02a_0d5cc93db60frow0_col0 {
#             color:  black;
#         }    #T_6a162cae_3367_11ea_a02a_0d5cc93db60frow0_col1 {
#             color:  black;
#         }    #T_6a162cae_3367_11ea_a02a_0d5cc93db60frow0_col2 {
#             color:  black;
#         }    #T_6a162cae_3367_11ea_a02a_0d5cc93db60frow0_col3 {
#             color:  black;
#         }    #T_6a162cae_3367_11ea_a02a_0d5cc93db60frow0_col4 {
#             color:  black;
#         }    #T_6a162cae_3367_11ea_a02a_0d5cc93db60frow0_col5 {
#             color:  black;
#         }    #T_6a162cae_3367_11ea_a02a_0d5cc93db60frow0_col6 {
#             color:  black;
#         }    #T_6a162cae_3367_11ea_a02a_0d5cc93db60frow0_col7 {
#             color:  black;
#         }    #T_6a162cae_3367_11ea_a02a_0d5cc93db60frow0_col8 {
#             color:  black;
#         }    #T_6a162cae_3367_11ea_a02a_0d5cc93db60frow0_col9 {
#             color:  orange;
#         }    #T_6a162cae_3367_11ea_a02a_0d5cc93db60frow1_col0 {
#             color:  black;
#         }    #T_6a162cae_3367_11ea_a02a_0d5cc93db60frow1_col1 {
#             color:  black;
#         }    #T_6a162cae_3367_11ea_a02a_0d5cc93db60frow1_col2 {
#             color:  black;
#         }    #T_6a162cae_3367_11ea_a02a_0d5cc93db60frow1_col3 {
#             color:  black;
#         }    #T_6a162cae_3367_11ea_a02a_0d5cc93db60frow1_col4 {
#             color:  black;
#         }    #T_6a162cae_3367_11ea_a02a_0d5cc93db60frow1_col5 {
#             color:  black;
#         }    #T_6a162cae_3367_11ea_a02a_0d5cc93db60frow1_col6 {
#             color:  black;
#         }    #T_6a162cae_3367_11ea_a02a_0d5cc93db60frow1_col7 {
#             color:  black;
#         }    #T_6a162cae_3367_11ea_a02a_0d5cc93db60frow1_col8 {
#             color:  black;
#         }    #T_6a162cae_3367_11ea_a02a_0d5cc93db60frow1_col9 {
#             color:  orange;
#         }    #T_6a162cae_3367_11ea_a02a_0d5cc93db60frow2_col0 {
#             color:  black;
#         }    #T_6a162cae_3367_11ea_a02a_0d5cc93db60frow2_col1 {
#             color:  black;
#         }    #T_6a162cae_3367_11ea_a02a_0d5cc93db60frow2_col2 {
#             color:  black;
#         }    #T_6a162cae_3367_11ea_a02a_0d5cc93db60frow2_col3 {
#             color:  black;
#         }    #T_6a162cae_3367_11ea_a02a_0d5cc93db60frow2_col4 {
#             color:  black;
#         }    #T_6a162cae_3367_11ea_a02a_0d5cc93db60frow2_col5 {
#             color:  black;
#         }    #T_6a162cae_3367_11ea_a02a_0d5cc93db60frow2_col6 {
#             color:  black;
#         }    #T_6a162cae_3367_11ea_a02a_0d5cc93db60frow2_col7 {
#             color:  black;
#         }    #T_6a162cae_3367_11ea_a02a_0d5cc93db60frow2_col8 {
#             color:  black;
#         }    #T_6a162cae_3367_11ea_a02a_0d5cc93db60frow2_col9 {
#             color:  orange;
#         }    #T_6a162cae_3367_11ea_a02a_0d5cc93db60frow3_col0 {
#             color:  black;
#         }    #T_6a162cae_3367_11ea_a02a_0d5cc93db60frow3_col1 {
#             color:  black;
#         }    #T_6a162cae_3367_11ea_a02a_0d5cc93db60frow3_col2 {
#             color:  black;
#         }    #T_6a162cae_3367_11ea_a02a_0d5cc93db60frow3_col3 {
#             color:  black;
#         }    #T_6a162cae_3367_11ea_a02a_0d5cc93db60frow3_col4 {
#             color:  orange;
#         }    #T_6a162cae_3367_11ea_a02a_0d5cc93db60frow3_col5 {
#             color:  black;
#         }    #T_6a162cae_3367_11ea_a02a_0d5cc93db60frow3_col6 {
#             color:  orange;
#         }    #T_6a162cae_3367_11ea_a02a_0d5cc93db60frow3_col7 {
#             color:  black;
#         }    #T_6a162cae_3367_11ea_a02a_0d5cc93db60frow3_col8 {
#             color:  orange;
#         }    #T_6a162cae_3367_11ea_a02a_0d5cc93db60frow3_col9 {
#             color:  orange;
#         }    #T_6a162cae_3367_11ea_a02a_0d5cc93db60frow4_col0 {
#             color:  black;
#         }    #T_6a162cae_3367_11ea_a02a_0d5cc93db60frow4_col1 {
#             color:  black;
#         }    #T_6a162cae_3367_11ea_a02a_0d5cc93db60frow4_col2 {
#             color:  orange;
#         }    #T_6a162cae_3367_11ea_a02a_0d5cc93db60frow4_col3 {
#             color:  black;
#         }    #T_6a162cae_3367_11ea_a02a_0d5cc93db60frow4_col4 {
#             color:  black;
#         }    #T_6a162cae_3367_11ea_a02a_0d5cc93db60frow4_col5 {
#             color:  black;
#         }    #T_6a162cae_3367_11ea_a02a_0d5cc93db60frow4_col6 {
#             color:  black;
#         }    #T_6a162cae_3367_11ea_a02a_0d5cc93db60frow4_col7 {
#             color:  black;
#         }    #T_6a162cae_3367_11ea_a02a_0d5cc93db60frow4_col8 {
#             color:  orange;
#         }    #T_6a162cae_3367_11ea_a02a_0d5cc93db60frow4_col9 {
#             color:  orange;
#         }</style><table id="T_6a162cae_3367_11ea_a02a_0d5cc93db60f" ><thead>    <tr>        <th class="blank level0" ></th>        <th class="col_heading level0 col0" >Label</th>        <th class="col_heading level0 col1" >Train_fold_0</th>        <th class="col_heading level0 col2" >Valid_fold_0</th>        <th class="col_heading level0 col3" >Train_fold_1</th>        <th class="col_heading level0 col4" >Valid_fold_1</th>        <th class="col_heading level0 col5" >Train_fold_2</th>        <th class="col_heading level0 col6" >Valid_fold_2</th>        <th class="col_heading level0 col7" >Train</th>        <th class="col_heading level0 col8" >Validation</th>        <th class="col_heading level0 col9" >Var</th>    </tr></thead><tbody>
#                 <tr>
#                         <th id="T_6a162cae_3367_11ea_a02a_0d5cc93db60flevel0_row0" class="row_heading level0 row0" >0</th>
#                         <td id="T_6a162cae_3367_11ea_a02a_0d5cc93db60frow0_col0" class="data row0 col0" >LIFE_ARTS</td>
#                         <td id="T_6a162cae_3367_11ea_a02a_0d5cc93db60frow0_col1" class="data row0 col1" >0.523</td>
#                         <td id="T_6a162cae_3367_11ea_a02a_0d5cc93db60frow0_col2" class="data row0 col2" >0.387</td>
#                         <td id="T_6a162cae_3367_11ea_a02a_0d5cc93db60frow0_col3" class="data row0 col3" >0.532</td>
#                         <td id="T_6a162cae_3367_11ea_a02a_0d5cc93db60frow0_col4" class="data row0 col4" >0.386</td>
#                         <td id="T_6a162cae_3367_11ea_a02a_0d5cc93db60frow0_col5" class="data row0 col5" >0.517</td>
#                         <td id="T_6a162cae_3367_11ea_a02a_0d5cc93db60frow0_col6" class="data row0 col6" >0.408</td>
#                         <td id="T_6a162cae_3367_11ea_a02a_0d5cc93db60frow0_col7" class="data row0 col7" >0.524</td>
#                         <td id="T_6a162cae_3367_11ea_a02a_0d5cc93db60frow0_col8" class="data row0 col8" >0.393667</td>
#                         <td id="T_6a162cae_3367_11ea_a02a_0d5cc93db60frow0_col9" class="data row0 col9" >0.130333</td>
#             </tr>
#             <tr>
#                         <th id="T_6a162cae_3367_11ea_a02a_0d5cc93db60flevel0_row1" class="row_heading level0 row1" >1</th>
#                         <td id="T_6a162cae_3367_11ea_a02a_0d5cc93db60frow1_col0" class="data row1 col0" >CULTURE</td>
#                         <td id="T_6a162cae_3367_11ea_a02a_0d5cc93db60frow1_col1" class="data row1 col1" >0.521</td>
#                         <td id="T_6a162cae_3367_11ea_a02a_0d5cc93db60frow1_col2" class="data row1 col2" >0.395</td>
#                         <td id="T_6a162cae_3367_11ea_a02a_0d5cc93db60frow1_col3" class="data row1 col3" >0.51</td>
#                         <td id="T_6a162cae_3367_11ea_a02a_0d5cc93db60frow1_col4" class="data row1 col4" >0.4</td>
#                         <td id="T_6a162cae_3367_11ea_a02a_0d5cc93db60frow1_col5" class="data row1 col5" >0.508</td>
#                         <td id="T_6a162cae_3367_11ea_a02a_0d5cc93db60frow1_col6" class="data row1 col6" >0.373</td>
#                         <td id="T_6a162cae_3367_11ea_a02a_0d5cc93db60frow1_col7" class="data row1 col7" >0.513</td>
#                         <td id="T_6a162cae_3367_11ea_a02a_0d5cc93db60frow1_col8" class="data row1 col8" >0.389333</td>
#                         <td id="T_6a162cae_3367_11ea_a02a_0d5cc93db60frow1_col9" class="data row1 col9" >0.123667</td>
#             </tr>
#             <tr>
