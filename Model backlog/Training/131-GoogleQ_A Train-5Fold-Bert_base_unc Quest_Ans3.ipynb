# %%
# !pip install tensorflow-gpu
# Out:
#      |████████████████████████████████| 421.8MB 20kB/s
# Requirement already satisfied: termcolor>=1.1.0 in /usr/local/lib/python3.6/dist-packages (from tensorflow-gpu) (1.1.0)
# Requirement already satisfied: grpcio>=1.8.6 in /usr/local/lib/python3.6/dist-packages (from tensorflow-gpu) (1.15.0)
# Collecting tensorboard<2.2.0,>=2.1.0
#   Downloading https://files.pythonhosted.org/packages/40/23/53ffe290341cd0855d595b0a2e7485932f473798af173bbe3a584b99bb06/tensorboard-2.1.0-py3-none-any.whl (3.8MB)
#      |████████████████████████████████| 3.8MB 60.5MB/s
# Requirement already satisfied: wrapt>=1.11.1 in /usr/local/lib/python3.6/dist-packages (from tensorflow-gpu) (1.11.2)
# Requirement already satisfied: absl-py>=0.7.0 in /usr/local/lib/python3.6/dist-packages (from tensorflow-gpu) (0.9.0)
# Requirement already satisfied: wheel>=0.26; python_version >= "3" in /usr/local/lib/python3.6/dist-packages (from tensorflow-gpu) (0.33.6)
# Requirement already satisfied: scipy==1.4.1; python_version >= "3" in /usr/local/lib/python3.6/dist-packages (from tensorflow-gpu) (1.4.1)
# Requirement already satisfied: numpy<2.0,>=1.16.0 in /usr/local/lib/python3.6/dist-packages (from tensorflow-gpu) (1.17.5)
# Requirement already satisfied: keras-applications>=1.0.8 in /usr/local/lib/python3.6/dist-packages (from tensorflow-gpu) (1.0.8)
# Requirement already satisfied: google-pasta>=0.1.6 in /usr/local/lib/python3.6/dist-packages (from tensorflow-gpu) (0.1.8)
# Requirement already satisfied: six>=1.12.0 in /usr/local/lib/python3.6/dist-packages (from tensorflow-gpu) (1.12.0)
# Requirement already satisfied: keras-preprocessing>=1.1.0 in /usr/local/lib/python3.6/dist-packages (from tensorflow-gpu) (1.1.0)
# Collecting tensorflow-estimator<2.2.0,>=2.1.0rc0
#   Downloading https://files.pythonhosted.org/packages/18/90/b77c328a1304437ab1310b463e533fa7689f4bfc41549593056d812fab8e/tensorflow_estimator-2.1.0-py2.py3-none-any.whl (448kB)
#      |████████████████████████████████| 450kB 43.5MB/s
# Requirement already satisfied: gast==0.2.2 in /usr/local/lib/python3.6/dist-packages (from tensorflow-gpu) (0.2.2)
# Requirement already satisfied: opt-einsum>=2.3.2 in /usr/local/lib/python3.6/dist-packages (from tensorflow-gpu) (3.1.0)
# Requirement already satisfied: protobuf>=3.8.0 in /usr/local/lib/python3.6/dist-packages (from tensorflow-gpu) (3.10.0)
# Requirement already satisfied: astor>=0.6.0 in /usr/local/lib/python3.6/dist-packages (from tensorflow-gpu) (0.8.1)
# Requirement already satisfied: markdown>=2.6.8 in /usr/local/lib/python3.6/dist-packages (from tensorboard<2.2.0,>=2.1.0->tensorflow-gpu) (3.1.1)
# Requirement already satisfied: setuptools>=41.0.0 in /usr/local/lib/python3.6/dist-packages (from tensorboard<2.2.0,>=2.1.0->tensorflow-gpu) (42.0.2)
# Requirement already satisfied: requests<3,>=2.21.0 in /usr/local/lib/python3.6/dist-packages (from tensorboard<2.2.0,>=2.1.0->tensorflow-gpu) (2.21.0)
# Collecting google-auth<2,>=1.6.3
#   Downloading https://files.pythonhosted.org/packages/1c/6d/7aae38a9022f982cf8167775c7fc299f203417b698c27080ce09060bba07/google_auth-1.11.0-py2.py3-none-any.whl (76kB)
#      |████████████████████████████████| 81kB 12.4MB/s
# Requirement already satisfied: google-auth-oauthlib<0.5,>=0.4.1 in /usr/local/lib/python3.6/dist-packages (from tensorboard<2.2.0,>=2.1.0->tensorflow-gpu) (0.4.1)
# Requirement already satisfied: werkzeug>=0.11.15 in /usr/local/lib/python3.6/dist-packages (from tensorboard<2.2.0,>=2.1.0->tensorflow-gpu) (0.16.0)
# Requirement already satisfied: h5py in /usr/local/lib/python3.6/dist-packages (from keras-applications>=1.0.8->tensorflow-gpu) (2.8.0)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.6/dist-packages (from requests<3,>=2.21.0->tensorboard<2.2.0,>=2.1.0->tensorflow-gpu) (2019.11.28)
# Requirement already satisfied: urllib3<1.25,>=1.21.1 in /usr/local/lib/python3.6/dist-packages (from requests<3,>=2.21.0->tensorboard<2.2.0,>=2.1.0->tensorflow-gpu) (1.24.3)
# Requirement already satisfied: chardet<3.1.0,>=3.0.2 in /usr/local/lib/python3.6/dist-packages (from requests<3,>=2.21.0->tensorboard<2.2.0,>=2.1.0->tensorflow-gpu) (3.0.4)
# Requirement already satisfied: idna<2.9,>=2.5 in /usr/local/lib/python3.6/dist-packages (from requests<3,>=2.21.0->tensorboard<2.2.0,>=2.1.0->tensorflow-gpu) (2.8)
# Requirement already satisfied: rsa<4.1,>=3.1.4 in /usr/local/lib/python3.6/dist-packages (from google-auth<2,>=1.6.3->tensorboard<2.2.0,>=2.1.0->tensorflow-gpu) (4.0)
# Requirement already satisfied: cachetools<5.0,>=2.0.0 in /usr/local/lib/python3.6/dist-packages (from google-auth<2,>=1.6.3->tensorboard<2.2.0,>=2.1.0->tensorflow-gpu) (4.0.0)
# Requirement already satisfied: pyasn1-modules>=0.2.1 in /usr/local/lib/python3.6/dist-packages (from google-auth<2,>=1.6.3->tensorboard<2.2.0,>=2.1.0->tensorflow-gpu) (0.2.7)
# Requirement already satisfied: requests-oauthlib>=0.7.0 in /usr/local/lib/python3.6/dist-packages (from google-auth-oauthlib<0.5,>=0.4.1->tensorboard<2.2.0,>=2.1.0->tensorflow-gpu) (1.3.0)
# Requirement already satisfied: pyasn1>=0.1.3 in /usr/local/lib/python3.6/dist-packages (from rsa<4.1,>=3.1.4->google-auth<2,>=1.6.3->tensorboard<2.2.0,>=2.1.0->tensorflow-gpu) (0.4.8)
# Requirement already satisfied: oauthlib>=3.0.0 in /usr/local/lib/python3.6/dist-packages (from requests-oauthlib>=0.7.0->google-auth-oauthlib<0.5,>=0.4.1->tensorboard<2.2.0,>=2.1.0->tensorflow-gpu) (3.1.0)
# ERROR: tensorflow 1.15.0 has requirement tensorboard<1.16.0,>=1.15.0, but you'll have tensorboard 2.1.0 which is incompatible.
# ERROR: tensorflow 1.15.0 has requirement tensorflow-estimator==1.15.1, but you'll have tensorflow-estimator 2.1.0 which is incompatible.
# ERROR: tensorboard 2.1.0 has requirement grpcio>=1.24.3, but you'll have grpcio 1.15.0 which is incompatible.
# ERROR: google-colab 1.0.0 has requirement google-auth~=1.4.0, but you'll have google-auth 1.11.0 which is incompatible.
# Installing collected packages: google-auth, tensorboard, tensorflow-estimator, tensorflow-gpu
#   Found existing installation: google-auth 1.4.2
#     Uninstalling google-auth-1.4.2:
#       Successfully uninstalled google-auth-1.4.2
#   Found existing installation: tensorboard 1.15.0
#     Uninstalling tensorboard-1.15.0:
#       Successfully uninstalled tensorboard-1.15.0
#   Found existing installation: tensorflow-estimator 1.15.1
#     Uninstalling tensorflow-estimator-1.15.1:
#       Successfully uninstalled tensorflow-estimator-1.15.1
# Successfully installed google-auth-1.11.0 tensorboard-2.1.0 tensorflow-estimator-2.1.0 tensorflow-gpu-2.1.0

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Go to this URL in a browser: https://accounts.google.com/o/oauth2/auth?client_id=947318989803-6bn6qk8qdgf4n4g3pfee6491hc0brc4i.apps.googleusercontent.com&redirect_uri=urn%3aietf%3awg%3aoauth%3a2.0%3aoob&response_type=code&scope=email%20https%3a%2f%2fwww.googleapis.com%2fauth%2fdocs.test%20https%3a%2f%2fwww.googleapis.com%2fauth%2fdrive%20https%3a%2f%2fwww.googleapis.com%2fauth%2fdrive.photos.readonly%20https%3a%2f%2fwww.googleapis.com%2fauth%2fpeopleapi.readonly
#
# Enter your authorization code:
# ··········
# Mounted at /content/drive

# %%
# !cp -r '/content/drive/My Drive/Colab Notebooks/Google QUEST Q&A Labeling/Scripts/.' .

# %%
MODEL_BASE_PATH = '/content/drive/My Drive/Colab Notebooks/Google QUEST Q&A Labeling/Model backlog/Files/'
MODEL_NAME = '131-Bert_base_unc Quest_Ans3'

# %% [markdown]
# ## Dependencies

# %%
import glob
import warnings
from tensorflow_hub import KerasLayer
from tensorflow.keras import Model, optimizers
from tensorflow.keras.callbacks import ReduceLROnPlateau
from tensorflow.keras.layers import Input, Dense, Dropout, GlobalAveragePooling1D, SpatialDropout1D, Concatenate
from googleqa_utilityscript import *
from googleqa_map_utilityscript import *
from script_lr_schedulers import WarmUpLearningRateScheduler
import bert_tokenization as tokenization


SEED = 0
seed_everything(SEED)
warnings.filterwarnings("ignore")
# Out:
# Using TensorFlow backend.

# %% [markdown]
# ## Load data

# %%
BERT_PATH = '/content/drive/My Drive/Colab Notebooks/Google QUEST Q&A Labeling/Modules/bert_base_uncased'
VOCAB_PATH = BERT_PATH + '/assets/vocab.txt'

k_fold = pd.read_csv('/content/drive/My Drive/Colab Notebooks/Google QUEST Q&A Labeling/Data/5-fold.csv')
N_FOLDS = 5

print('Samples: %s' % len(k_fold))
display(k_fold.head())
# Out:
# Samples: 6079
#    qa_id  ...      fold_5
# 0      0  ...       train
# 1      1  ...       train
# 2      2  ...       train
# 3      3  ...  validation
# 4      5  ...       train
#
# [5 rows x 46 columns]

# %%
question_target_cols = ['question_asker_intent_understanding','question_body_critical', 'question_conversational', 
                        'question_expect_short_answer', 'question_fact_seeking', 'question_has_commonly_accepted_answer',
                        'question_interestingness_others', 'question_interestingness_self', 'question_multi_intent', 
                        'question_not_really_a_question', 'question_opinion_seeking', 'question_type_choice',
                        'question_type_compare', 'question_type_consequence', 'question_type_definition', 
                        'question_type_entity', 'question_type_instructions', 'question_type_procedure',
                        'question_type_reason_explanation', 'question_type_spelling', 'question_well_written']
answer_target_cols = ['answer_helpful', 'answer_level_of_information', 'answer_plausible', 'answer_relevance',
                      'answer_satisfaction', 'answer_type_instructions', 'answer_type_procedure', 
                      'answer_type_reason_explanation', 'answer_well_written']
target_cols = question_target_cols + answer_target_cols

# %% [markdown]
# # Pre-process data

# %%
text_features = ['question_title', 'question_body', 'answer']
text_features_question = ['question_title', 'question_body']
text_features_answer = ['question_title', 'answer']

# for feature in text_features:
#     # Lower
#     k_fold[feature] = k_fold[feature].apply(lambda x: x.lower())
#     # Map misspellings
#     k_fold[feature] = k_fold[feature].apply(lambda x: map_misspellings(x))
#     # Map contractions
#     k_fold[feature] = k_fold[feature].apply(lambda x: map_contraction(x))
#     # Trim text
#     k_fold[feature] = k_fold[feature].apply(lambda x: x.strip())

# %% [markdown]
# # Model parameters

# %%
EPOCHS = 8
BATCH_SIZE = 4
LEARNING_RATE = 3e-5
N_CLASS = len(target_cols)
N_CLASS_QUESTION = len(question_target_cols)
N_CLASS_ANSWER = len(answer_target_cols)
ES_PATIENCE = 2
MAX_SEQUENCE_LENGTH = 512
MAX_LENGTH_TITLE = 30
MAX_LENGTH_QUESTION = 479
MAX_LENGTH_ANSWER = 479
RLROP_PATIENCE = 1
DECAY_DROP = 0.5
LR_WARMUP_EPOCHS = 2

# %% [markdown]
# # Model

# %%
def model_fn():
    input_word_ids_question = Input((MAX_SEQUENCE_LENGTH,), dtype=tf.int32, name='input_word_ids_question')
    input_masks_question = Input((MAX_SEQUENCE_LENGTH,), dtype=tf.int32, name='input_masks_question')
    segment_ids_question = Input((MAX_SEQUENCE_LENGTH,), dtype=tf.int32, name='segment_ids_question')

    input_word_ids_answer = Input((MAX_SEQUENCE_LENGTH,), dtype=tf.int32, name='input_word_ids_answer')
    input_masks_answer = Input((MAX_SEQUENCE_LENGTH,), dtype=tf.int32, name='input_masks_answer')
    segment_ids_answer = Input((MAX_SEQUENCE_LENGTH,), dtype=tf.int32, name='segment_ids_answer')

    bert_layer = KerasLayer(BERT_PATH, trainable=True)
    pooled_output_question, sequence_output_question = bert_layer([input_word_ids_question, input_masks_question, segment_ids_question])
    pooled_output_answer, sequence_output_answer = bert_layer([input_word_ids_answer, input_masks_answer, segment_ids_answer])

    x_question = GlobalAveragePooling1D()(sequence_output_question)
    x_question = Dropout(0.2)(x_question)
    output_question = Dense(N_CLASS_QUESTION, kernel_initializer='glorot_uniform', activation="sigmoid", name="outputquestion")(x_question)
    
    x_answer = GlobalAveragePooling1D()(sequence_output_answer)
    x_answer = Dropout(0.2)(x_answer)
    output_answer = Dense(N_CLASS_ANSWER, kernel_initializer='glorot_uniform', activation="sigmoid", name="output_answer")(x_answer)
    
    output = Concatenate()([output_question, output_answer])

    model = Model(inputs=[input_word_ids_question, input_masks_question, segment_ids_question, 
                          input_word_ids_answer, input_masks_answer, segment_ids_answer], outputs=output)

    return model

# %% [markdown]
# # Train model

# %%
rlrop = ReduceLROnPlateau(monitor='val_loss', mode='min', patience=RLROP_PATIENCE, factor=DECAY_DROP, min_lr=1e-7, verbose=1)    
tokenizer = tokenization.FullTokenizer(VOCAB_PATH, True)

history_list = []
metric_list = []
category_metric_list = []
target_cols_preds = [col+'_pred' for col in target_cols]

for n_fold in range(N_FOLDS):
    ### Data
    train = k_fold[k_fold['fold_%d' % (n_fold+1)] == 'train']
    validation = k_fold[k_fold['fold_%d' % (n_fold+1)] == 'validation']
    
    ### Create features
    # Train features
    X_train = compute_input_arays_2(train, text_features_question, tokenizer, MAX_SEQUENCE_LENGTH, MAX_LENGTH_TITLE, MAX_LENGTH_QUESTION, ignore_first_sep=False)\
                + compute_input_arays_2(train, text_features_answer, tokenizer, MAX_SEQUENCE_LENGTH, MAX_LENGTH_TITLE, MAX_LENGTH_ANSWER, ignore_first_sep=False)
    Y_train = train[target_cols].values

    # Validation features
    X_valid = compute_input_arays_2(validation, text_features_question, tokenizer, MAX_SEQUENCE_LENGTH, MAX_LENGTH_TITLE, MAX_LENGTH_QUESTION, ignore_first_sep=False)\
                + compute_input_arays_2(validation, text_features_answer, tokenizer, MAX_SEQUENCE_LENGTH, MAX_LENGTH_TITLE, MAX_LENGTH_ANSWER, ignore_first_sep=False)
    Y_valid = validation[target_cols].values

    ## Train model
    model_path = MODEL_BASE_PATH + MODEL_NAME + '_model_fold_%d' % (n_fold+1)
    spearmanCallback = SpearmanRhoCallback(training_data=(X_train, Y_train), 
                                           validation_data=(X_valid, Y_valid), 
                                           model_path=model_path, 
                                           monitor='val_loss', mode='min', 
                                           patience=ES_PATIENCE, checkpoint=True)
    WARMUP_BATCHES = LR_WARMUP_EPOCHS * len(train) // BATCH_SIZE
    warmup_lr = WarmUpLearningRateScheduler(WARMUP_BATCHES, LEARNING_RATE)

    callback_list = [spearmanCallback, rlrop, warmup_lr]
    optimizer = optimizers.Adam(lr=LEARNING_RATE)
    model = model_fn()
    model.compile(optimizer=optimizer, loss='binary_crossentropy')

    history = model.fit(X_train, Y_train, 
                        validation_data=(X_valid, Y_valid), 
                        callbacks=callback_list, 
                        batch_size=BATCH_SIZE, 
                        epochs=EPOCHS, 
                        verbose=2).history
    history_list.append(history)

    # Save last epoch weights
    model.save_weights(MODEL_BASE_PATH + MODEL_NAME + '_model_fold_%d_last_epoch.h5' % (n_fold+1))
    
    ### Evaluation - Label metrics
    model.load_weights(model_path+'.h5')
    preds_train = model.predict(X_train)
    preds_val = model.predict(X_valid)
    metric_list.append(get_metrics(Y_train, preds_train, Y_valid, preds_val, target_cols))
    
    ### Evaluation - Category metrics
    for col in target_cols_preds:
        train[col] = 0
        validation[col] = 0

    train[target_cols_preds] = preds_train
    validation[target_cols_preds] = preds_val 
    category_metric_list.append(get_metrics_category(train, validation, target_cols, target_cols_preds, 'category'))

# %% [markdown]
# ## Model loss graph

# %%
for n_fold in range(N_FOLDS):
    print('Fold: %d' % n_fold)
    sns.set(style="whitegrid")
    plot_metrics(history_list[n_fold], metric_list=['loss', 'spearman'])

# %% [markdown]
# # Evaluation

# %%
metrics_df = metric_list[0][['Label', 'Train', 'Validation']].copy()
metrics_df.columns = ['Label', 'Train_fold_0', 'Valid_fold_0']

for n_fold in range(1, N_FOLDS):
    metrics_df_idx = metric_list[n_fold][['Train', 'Validation']].copy()
    metrics_df_idx.columns = ['Train_fold_%d' % n_fold, 'Valid_fold_%d' % n_fold]
    metrics_df = pd.concat([metrics_df, metrics_df_idx], axis=1)

metrics_df['Train'] = 0
metrics_df['Validation'] = 0
for n_fold in range(N_FOLDS):
    metrics_df['Train'] += metrics_df['Train_fold_%d' % n_fold] / N_FOLDS
    metrics_df['Validation'] += metrics_df['Valid_fold_%d' % n_fold] / N_FOLDS

metrics_df['Var'] = metrics_df['Train'] - metrics_df['Validation']
display(metrics_df.style.applymap(color_map))
# Out:
# <style  type="text/css" >
#     #T_1d6468d2_3edc_11ea_9498_0242ac1c0002row0_col0 {
#             color:  black;
#         }    #T_1d6468d2_3edc_11ea_9498_0242ac1c0002row0_col1 {
#             color:  black;
#         }    #T_1d6468d2_3edc_11ea_9498_0242ac1c0002row0_col2 {
#             color:  black;
#         }    #T_1d6468d2_3edc_11ea_9498_0242ac1c0002row0_col3 {
#             color:  black;
#         }    #T_1d6468d2_3edc_11ea_9498_0242ac1c0002row0_col4 {
#             color:  black;
#         }    #T_1d6468d2_3edc_11ea_9498_0242ac1c0002row0_col5 {
#             color:  black;
#         }    #T_1d6468d2_3edc_11ea_9498_0242ac1c0002row0_col6 {
#             color:  black;
#         }    #T_1d6468d2_3edc_11ea_9498_0242ac1c0002row0_col7 {
#             color:  black;
#         }    #T_1d6468d2_3edc_11ea_9498_0242ac1c0002row0_col8 {
#             color:  black;
#         }    #T_1d6468d2_3edc_11ea_9498_0242ac1c0002row0_col9 {
#             color:  black;
#         }    #T_1d6468d2_3edc_11ea_9498_0242ac1c0002row0_col10 {
#             color:  black;
#         }    #T_1d6468d2_3edc_11ea_9498_0242ac1c0002row0_col11 {
#             color:  black;
#         }    #T_1d6468d2_3edc_11ea_9498_0242ac1c0002row0_col12 {
#             color:  black;
#         }    #T_1d6468d2_3edc_11ea_9498_0242ac1c0002row0_col13 {
#             color:  orange;
#         }    #T_1d6468d2_3edc_11ea_9498_0242ac1c0002row1_col0 {
#             color:  black;
#         }    #T_1d6468d2_3edc_11ea_9498_0242ac1c0002row1_col1 {
#             color:  black;
#         }    #T_1d6468d2_3edc_11ea_9498_0242ac1c0002row1_col2 {
#             color:  black;
#         }    #T_1d6468d2_3edc_11ea_9498_0242ac1c0002row1_col3 {
#             color:  black;
#         }    #T_1d6468d2_3edc_11ea_9498_0242ac1c0002row1_col4 {
#             color:  black;
#         }    #T_1d6468d2_3edc_11ea_9498_0242ac1c0002row1_col5 {
#             color:  black;
#         }    #T_1d6468d2_3edc_11ea_9498_0242ac1c0002row1_col6 {
#             color:  black;
#         }    #T_1d6468d2_3edc_11ea_9498_0242ac1c0002row1_col7 {
#             color:  black;
#         }    #T_1d6468d2_3edc_11ea_9498_0242ac1c0002row1_col8 {
#             color:  black;
#         }    #T_1d6468d2_3edc_11ea_9498_0242ac1c0002row1_col9 {
#             color:  black;
#         }    #T_1d6468d2_3edc_11ea_9498_0242ac1c0002row1_col10 {
#             color:  black;
#         }    #T_1d6468d2_3edc_11ea_9498_0242ac1c0002row1_col11 {
#             color:  black;
#         }    #T_1d6468d2_3edc_11ea_9498_0242ac1c0002row1_col12 {
#             color:  black;
#         }    #T_1d6468d2_3edc_11ea_9498_0242ac1c0002row1_col13 {
#             color:  purple;
#         }    #T_1d6468d2_3edc_11ea_9498_0242ac1c0002row2_col0 {
#             color:  black;
#         }    #T_1d6468d2_3edc_11ea_9498_0242ac1c0002row2_col1 {
#             color:  black;
#         }    #T_1d6468d2_3edc_11ea_9498_0242ac1c0002row2_col2 {
#             color:  black;
#         }    #T_1d6468d2_3edc_11ea_9498_0242ac1c0002row2_col3 {
#             color:  black;
#         }    #T_1d6468d2_3edc_11ea_9498_0242ac1c0002row2_col4 {
#             color:  black;
#         }    #T_1d6468d2_3edc_11ea_9498_0242ac1c0002row2_col5 {
#             color:  black;
#         }    #T_1d6468d2_3edc_11ea_9498_0242ac1c0002row2_col6 {
#             color:  black;
#         }    #T_1d6468d2_3edc_11ea_9498_0242ac1c0002row2_col7 {
#             color:  black;
#         }    #T_1d6468d2_3edc_11ea_9498_0242ac1c0002row2_col8 {
#             color:  black;
#         }    #T_1d6468d2_3edc_11ea_9498_0242ac1c0002row2_col9 {
#             color:  black;
#         }    #T_1d6468d2_3edc_11ea_9498_0242ac1c0002row2_col10 {
#             color:  black;
#         }    #T_1d6468d2_3edc_11ea_9498_0242ac1c0002row2_col11 {
#             color:  black;
#         }    #T_1d6468d2_3edc_11ea_9498_0242ac1c0002row2_col12 {
#             color:  black;
#         }    #T_1d6468d2_3edc_11ea_9498_0242ac1c0002row2_col13 {
#             color:  orange;
#         }    #T_1d6468d2_3edc_11ea_9498_0242ac1c0002row3_col0 {
#             color:  black;
#         }    #T_1d6468d2_3edc_11ea_9498_0242ac1c0002row3_col1 {
#             color:  black;
#         }    #T_1d6468d2_3edc_11ea_9498_0242ac1c0002row3_col2 {
#             color:  black;
#         }    #T_1d6468d2_3edc_11ea_9498_0242ac1c0002row3_col3 {
#             color:  black;
#         }    #T_1d6468d2_3edc_11ea_9498_0242ac1c0002row3_col4 {
#             color:  black;
#         }    #T_1d6468d2_3edc_11ea_9498_0242ac1c0002row3_col5 {
#             color:  black;
#         }    #T_1d6468d2_3edc_11ea_9498_0242ac1c0002row3_col6 {
#             color:  black;
#         }    #T_1d6468d2_3edc_11ea_9498_0242ac1c0002row3_col7 {
#             color:  black;
#         }    #T_1d6468d2_3edc_11ea_9498_0242ac1c0002row3_col8 {
#             color:  black;
#         }    #T_1d6468d2_3edc_11ea_9498_0242ac1c0002row3_col9 {
#             color:  black;
#         }    #T_1d6468d2_3edc_11ea_9498_0242ac1c0002row3_col10 {
#             color:  black;
#         }    #T_1d6468d2_3edc_11ea_9498_0242ac1c0002row3_col11 {
#             color:  black;
#         }    #T_1d6468d2_3edc_11ea_9498_0242ac1c0002row3_col12 {
#             color:  black;
#         }    #T_1d6468d2_3edc_11ea_9498_0242ac1c0002row3_col13 {
#             color:  purple;
#         }    #T_1d6468d2_3edc_11ea_9498_0242ac1c0002row4_col0 {
#             color:  black;
#         }    #T_1d6468d2_3edc_11ea_9498_0242ac1c0002row4_col1 {
#             color:  black;
#         }    #T_1d6468d2_3edc_11ea_9498_0242ac1c0002row4_col2 {
#             color:  black;
#         }    #T_1d6468d2_3edc_11ea_9498_0242ac1c0002row4_col3 {
#             color:  black;
#         }    #T_1d6468d2_3edc_11ea_9498_0242ac1c0002row4_col4 {
#             color:  black;
#         }    #T_1d6468d2_3edc_11ea_9498_0242ac1c0002row4_col5 {
#             color:  black;
#         }    #T_1d6468d2_3edc_11ea_9498_0242ac1c0002row4_col6 {
#             color:  black;
#         }    #T_1d6468d2_3edc_11ea_9498_0242ac1c0002row4_col7 {
#             color:  black;
#         }    #T_1d6468d2_3edc_11ea_9498_0242ac1c0002row4_col8 {
#             color:  black;
#         }    #T_1d6468d2_3edc_11ea_9498_0242ac1c0002row4_col9 {
#             color:  black;
#         }    #T_1d6468d2_3edc_11ea_9498_0242ac1c0002row4_col10 {
#             color:  black;
#         }    #T_1d6468d2_3edc_11ea_9498_0242ac1c0002row4_col11 {
#             color:  black;
#         }    #T_1d6468d2_3edc_11ea_9498_0242ac1c0002row4_col12 {
#             color:  black;
#         }    #T_1d6468d2_3edc_11ea_9498_0242ac1c0002row4_col13 {
#             color:  purple;
#         }    #T_1d6468d2_3edc_11ea_9498_0242ac1c0002row5_col0 {
#             color:  black;
#         }    #T_1d6468d2_3edc_11ea_9498_0242ac1c0002row5_col1 {
#             color:  black;
#         }    #T_1d6468d2_3edc_11ea_9498_0242ac1c0002row5_col2 {
#             color:  black;
#         }    #T_1d6468d2_3edc_11ea_9498_0242ac1c0002row5_col3 {
#             color:  black;
#         }    #T_1d6468d2_3edc_11ea_9498_0242ac1c0002row5_col4 {
#             color:  black;
#         }    #T_1d6468d2_3edc_11ea_9498_0242ac1c0002row5_col5 {
#             color:  black;
#         }    #T_1d6468d2_3edc_11ea_9498_0242ac1c0002row5_col6 {
#             color:  black;
#         }    #T_1d6468d2_3edc_11ea_9498_0242ac1c0002row5_col7 {
#             color:  black;
#         }    #T_1d6468d2_3edc_11ea_9498_0242ac1c0002row5_col8 {
#             color:  black;
#         }    #T_1d6468d2_3edc_11ea_9498_0242ac1c0002row5_col9 {
#             color:  black;
#         }    #T_1d6468d2_3edc_11ea_9498_0242ac1c0002row5_col10 {
#             color:  black;
#         }    #T_1d6468d2_3edc_11ea_9498_0242ac1c0002row5_col11 {
#             color:  black;
#         }    #T_1d6468d2_3edc_11ea_9498_0242ac1c0002row5_col12 {
#             color:  black;
#         }    #T_1d6468d2_3edc_11ea_9498_0242ac1c0002row5_col13 {
#             color:  purple;
#         }    #T_1d6468d2_3edc_11ea_9498_0242ac1c0002row6_col0 {
#             color:  black;
#         }    #T_1d6468d2_3edc_11ea_9498_0242ac1c0002row6_col1 {
#             color:  black;
#         }    #T_1d6468d2_3edc_11ea_9498_0242ac1c0002row6_col2 {
#             color:  black;
#         }    #T_1d6468d2_3edc_11ea_9

# %% [markdown]
# ## By category

# %%
category_metrics_df = category_metric_list[0][['Label', 'Train', 'Validation']].copy()
category_metrics_df.columns = ['Label', 'Train_fold_0', 'Valid_fold_0']

for n_fold in range(1, N_FOLDS):
    category_metrics_df_idx = category_metric_list[n_fold][['Train', 'Validation']].copy()
    category_metrics_df_idx.columns = ['Train_fold_%d' % n_fold, 'Valid_fold_%d' % n_fold]
    category_metrics_df = pd.concat([category_metrics_df, category_metrics_df_idx], axis=1)
    
category_metrics_df['Train'] = 0
category_metrics_df['Validation'] = 0
for n_fold in range(N_FOLDS):
    category_metrics_df['Train'] += category_metrics_df['Train_fold_%d' % n_fold] / N_FOLDS
    category_metrics_df['Validation'] += category_metrics_df['Valid_fold_%d' % n_fold] / N_FOLDS
    
category_metrics_df['Var'] = category_metrics_df['Train'] - category_metrics_df['Validation']
display(category_metrics_df.style.applymap(color_map))
# Out:
# <style  type="text/css" >
#     #T_1dc23d90_3edc_11ea_9498_0242ac1c0002row0_col0 {
#             color:  black;
#         }    #T_1dc23d90_3edc_11ea_9498_0242ac1c0002row0_col1 {
#             color:  black;
#         }    #T_1dc23d90_3edc_11ea_9498_0242ac1c0002row0_col2 {
#             color:  black;
#         }    #T_1dc23d90_3edc_11ea_9498_0242ac1c0002row0_col3 {
#             color:  black;
#         }    #T_1dc23d90_3edc_11ea_9498_0242ac1c0002row0_col4 {
#             color:  black;
#         }    #T_1dc23d90_3edc_11ea_9498_0242ac1c0002row0_col5 {
#             color:  black;
#         }    #T_1dc23d90_3edc_11ea_9498_0242ac1c0002row0_col6 {
#             color:  black;
#         }    #T_1dc23d90_3edc_11ea_9498_0242ac1c0002row0_col7 {
#             color:  black;
#         }    #T_1dc23d90_3edc_11ea_9498_0242ac1c0002row0_col8 {
#             color:  black;
#         }    #T_1dc23d90_3edc_11ea_9498_0242ac1c0002row0_col9 {
#             color:  black;
#         }    #T_1dc23d90_3edc_11ea_9498_0242ac1c0002row0_col10 {
#             color:  black;
#         }    #T_1dc23d90_3edc_11ea_9498_0242ac1c0002row0_col11 {
#             color:  black;
#         }    #T_1dc23d90_3edc_11ea_9498_0242ac1c0002row0_col12 {
#             color:  black;
#         }    #T_1dc23d90_3edc_11ea_9498_0242ac1c0002row0_col13 {
#             color:  orange;
#         }    #T_1dc23d90_3edc_11ea_9498_0242ac1c0002row1_col0 {
#             color:  black;
#         }    #T_1dc23d90_3edc_11ea_9498_0242ac1c0002row1_col1 {
#             color:  black;
#         }    #T_1dc23d90_3edc_11ea_9498_0242ac1c0002row1_col2 {
#             color:  black;
#         }    #T_1dc23d90_3edc_11ea_9498_0242ac1c0002row1_col3 {
#             color:  black;
#         }    #T_1dc23d90_3edc_11ea_9498_0242ac1c0002row1_col4 {
#             color:  black;
#         }    #T_1dc23d90_3edc_11ea_9498_0242ac1c0002row1_col5 {
#             color:  black;
#         }    #T_1dc23d90_3edc_11ea_9498_0242ac1c0002row1_col6 {
#             color:  black;
#         }    #T_1dc23d90_3edc_11ea_9498_0242ac1c0002row1_col7 {
#             color:  black;
#         }    #T_1dc23d90_3edc_11ea_9498_0242ac1c0002row1_col8 {
#             color:  black;
#         }    #T_1dc23d90_3edc_11ea_9498_0242ac1c0002row1_col9 {
#             color:  black;
#         }    #T_1dc23d90_3edc_11ea_9498_0242ac1c0002row1_col10 {
#             color:  black;
#         }    #T_1dc23d90_3edc_11ea_9498_0242ac1c0002row1_col11 {
#             color:  black;
#         }    #T_1dc23d90_3edc_11ea_9498_0242ac1c0002row1_col12 {
#             color:  black;
#         }    #T_1dc23d90_3edc_11ea_9498_0242ac1c0002row1_col13 {
#             color:  orange;
#         }    #T_1dc23d90_3edc_11ea_9498_0242ac1c0002row2_col0 {
#             color:  black;
#         }    #T_1dc23d90_3edc_11ea_9498_0242ac1c0002row2_col1 {
#             color:  black;
#         }    #T_1dc23d90_3edc_11ea_9498_0242ac1c0002row2_col2 {
#             color:  black;
#         }    #T_1dc23d90_3edc_11ea_9498_0242ac1c0002row2_col3 {
#             color:  black;
#         }    #T_1dc23d90_3edc_11ea_9498_0242ac1c0002row2_col4 {
#             color:  black;
#         }    #T_1dc23d90_3edc_11ea_9498_0242ac1c0002row2_col5 {
#             color:  black;
#         }    #T_1dc23d90_3edc_11ea_9498_0242ac1c0002row2_col6 {
#             color:  black;
#         }    #T_1dc23d90_3edc_11ea_9498_0242ac1c0002row2_col7 {
#             color:  black;
#         }    #T_1dc23d90_3edc_11ea_9498_0242ac1c0002row2_col8 {
#             color:  black;
#         }    #T_1dc23d90_3edc_11ea_9498_0242ac1c0002row2_col9 {
#             color:  black;
#         }    #T_1dc23d90_3edc_11ea_9498_0242ac1c0002row2_col10 {
#             color:  black;
#         }    #T_1dc23d90_3edc_11ea_9498_0242ac1c0002row2_col11 {
#             color:  black;
#         }    #T_1dc23d90_3edc_11ea_9498_0242ac1c0002row2_col12 {
#             color:  black;
#         }    #T_1dc23d90_3edc_11ea_9498_0242ac1c0002row2_col13 {
#             color:  orange;
#         }    #T_1dc23d90_3edc_11ea_9498_0242ac1c0002row3_col0 {
#             color:  black;
#         }    #T_1dc23d90_3edc_11ea_9498_0242ac1c0002row3_col1 {
#             color:  black;
#         }    #T_1dc23d90_3edc_11ea_9498_0242ac1c0002row3_col2 {
#             color:  orange;
#         }    #T_1dc23d90_3edc_11ea_9498_0242ac1c0002row3_col3 {
#             color:  black;
#         }    #T_1dc23d90_3edc_11ea_9498_0242ac1c0002row3_col4 {
#             color:  orange;
#         }    #T_1dc23d90_3edc_11ea_9498_0242ac1c0002row3_col5 {
#             color:  black;
#         }    #T_1dc23d90_3edc_11ea_9498_0242ac1c0002row3_col6 {
#             color:  black;
#         }    #T_1dc23d90_3edc_11ea_9498_0242ac1c0002row3_col7 {
#             color:  black;
#         }    #T_1dc23d90_3edc_11ea_9498_0242ac1c0002row3_col8 {
#             color:  orange;
#         }    #T_1dc23d90_3edc_11ea_9498_0242ac1c0002row3_col9 {
#             color:  black;
#         }    #T_1dc23d90_3edc_11ea_9498_0242ac1c0002row3_col10 {
#             color:  orange;
#         }    #T_1dc23d90_3edc_11ea_9498_0242ac1c0002row3_col11 {
#             color:  black;
#         }    #T_1dc23d90_3edc_11ea_9498_0242ac1c0002row3_col12 {
#             color:  black;
#         }    #T_1dc23d90_3edc_11ea_9498_0242ac1c0002row3_col13 {
#             color:  orange;
#         }    #T_1dc23d90_3edc_11ea_9498_0242ac1c0002row4_col0 {
#             color:  black;
#         }    #T_1dc23d90_3edc_11ea_9498_0242ac1c0002row4_col1 {
#             color:  black;
#         }    #T_1dc23d90_3edc_11ea_9498_0242ac1c0002row4_col2 {
#             color:  black;
#         }    #T_1dc23d90_3edc_11ea_9498_0242ac1c0002row4_col3 {
#             color:  black;
#         }    #T_1dc23d90_3edc_11ea_9498_0242ac1c0002row4_col4 {
#             color:  black;
#         }    #T_1dc23d90_3edc_11ea_9498_0242ac1c0002row4_col5 {
#             color:  black;
#         }    #T_1dc23d90_3edc_11ea_9498_0242ac1c0002row4_col6 {
#             color:  orange;
#         }    #T_1dc23d90_3edc_11ea_9498_0242ac1c0002row4_col7 {
#             color:  black;
#         }    #T_1dc23d90_3edc_11ea_9498_0242ac1c0002row4_col8 {
#             color:  black;
#         }    #T_1dc23d90_3edc_11ea_9498_0242ac1c0002row4_col9 {
#             color:  black;
#         }    #T_1dc23d90_3edc_11ea_9498_0242ac1c0002row4_col10 {
#             color:  black;
#         }    #T_1dc23d90_3edc_11ea_9498_0242ac1c0002row4_col11 {
#             color:  black;
#         }    #T_1dc23d90_3edc_11ea_9498_0242ac1c0002row4_col12 {
#             color:  black;
#         }    #T_1dc23d90_3edc_11ea_9498_0242ac1c0002row4_col13 {
#             color:  orange;
#         }</style><table id="T_1dc23d90_3edc_11ea_9498_0242ac1c0002" ><thead>    <tr>        <th class="blank level0" ></th>        <th class="col_heading level0 col0" >Label</th>        <th class="col_heading level0 col1" >Train_fold_0</th>        <th class="col_heading level0 col2" >Valid_fold_0</th>        <th class="col_heading level0 col3" >Train_fold_1</th>        <th class="col_heading level0 col4" >Valid_fold_1</th>        <th class="col_heading level0 col5" >Train_fold_2</th>        <th class="col_heading level0 col6" >Valid_fold_2</th>        <th class="col_heading level0 col7" >Train_fold_3</th>        <th class="col_heading level0 col8" >Valid_fold_3</th>        <th class="col_heading level0 col9" >Train_fold_4</th>        <th class="col_heading level0 col10" >Valid_fold_4</th>        <th class="col_heading level0 col11" >Train</th>        <th class="col_heading level0 col12" >Validation</th>        <th class="col_heading level0 col13" >Var</th>    </tr></thead><tbody>
#                 <tr>
#                         <th id="T_1dc23d90_3edc_11ea_9498_0242ac1c0002level0_row0" class="row_heading level0 row0" >0</th>
#                         <td id="T_1dc23d90_3edc_11ea_9498_0242ac1c0002row0_col0" class="data row0 col0" >LIFE_ARTS</td>
#                         <td id="T_1dc23d90_3edc_11ea_9498_0242ac1c0002row0_col1" class="data row0 col1" >0.491</td>
#                         <td id="T_1dc23d90_3edc_11ea_9498_0242ac1c0002row0_col2" class="data row0 col2" >0.402</td>
#                         <td id="T_1dc23d90_3edc_11ea_9498_0242ac1c0002row0_col3" class="data
