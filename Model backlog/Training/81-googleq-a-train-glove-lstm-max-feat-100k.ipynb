# %% [markdown]
# ## Dependencies

# %%
import gc
import re
import warnings
from joblib import dump
import tensorflow_hub as hub
from tensorflow.keras import Model, optimizers
from tensorflow.keras.callbacks import ReduceLROnPlateau
from tensorflow.keras.preprocessing.text import Tokenizer
from tensorflow.keras.preprocessing.sequence import pad_sequences
from tensorflow.keras.layers import Lambda, Input, Dense, Dropout, Concatenate, BatchNormalization, Activation, Average, Add, Reshape
from tensorflow.keras.layers import GlobalAveragePooling1D, Embedding, LSTM, Conv1D, SpatialDropout1D, Bidirectional, Flatten, Bidirectional
from googleqa_utilityscript import *


SEED = 0
seed_everything(SEED)
warnings.filterwarnings("ignore")

# %% [markdown]
# ## Load data

# %%
module_url = '/kaggle/input/universalsentenceencodermodels/universal-sentence-encoder-models/use'
model_path = '/kaggle/working/model.h5'
tokenizer_path = '/kaggle/working/tokenizer.joblib'
encoder_path = '/kaggle/input/pickled-glove840b300d-for-10sec-loading/glove.840B.300d.pkl'

hold_out = pd.read_csv('/kaggle/input/googleqa-mldataset/hold-out.csv')
test = pd.read_csv('/kaggle/input/google-quest-challenge/test.csv')
train = hold_out[hold_out['set'] == 'train']
validation = hold_out[hold_out['set'] == 'validation']

print('Train samples: %s' % len(train))
print('Validation samples: %s' % len(validation))
display(train.head())
# Out:
# Train samples: 4863
# Validation samples: 1216
#    qa_id                                     question_title  \
# 0   3895  Magento (1.7) Bundled Product with FREE Produc...
# 1   3131                             Find router on network
# 2   1507  Negatively curved metrics minimizing the lengt...
# 3   6784               Isn’t the FAQ label obsolete by now?
# 4   2135  Changing background image one time on responsi...
#
#                                        question_body question_user_name  \
# 0  I'm looking to create a bundle offer where cus...                Joe
# 1  I've just bought a Belkin N+ Wireless Router. ...                Guy
# 2  Good afternoon everyone !\n\nI have the follow...            Selim G
# 3  Don’t get me wrong in the beginning of reading...     Benny Skogberg
# 4  The code I'm using is this one \n\nbackground:...        user2141649
#
#                               question_user_page  \
# 0  https://magento.stackexchange.com/users/16572
# 1               https://superuser.com/users/3248
# 2           https://mathoverflow.net/users/25511
# 3        https://ux.stackexchange.com/users/4679
# 4        https://stackoverflow.com/users/2141649
#
#                                               answer   answer_user_name  \
# 0  Since the third item is fixed, you can use sho...  Fabian Schmengler
# 1  You likely have the router plugged in to the m...             John T
# 2  A very partial answer: by the results of Richa...         Igor Rivin
# 3  Isn’t the FAQ label obsolete by now? \n\nI'd s...        Solracnapod
# 4  &lt;!DOCTYPE html&gt;\n&lt;html&gt;\n&lt;head&...           akkimads
#
#                               answer_user_page  \
# 0  https://magento.stackexchange.com/users/243
# 1             https://superuser.com/users/1931
# 2         https://mathoverflow.net/users/11142
# 3     https://ux.stackexchange.com/users/13153
# 4      https://stackoverflow.com/users/2375373
#
#                                                  url       category  ...  \
# 0  http://magento.stackexchange.com/questions/668...     TECHNOLOGY  ...
# 1               http://superuser.com/questions/87212     TECHNOLOGY  ...
# 2           http://mathoverflow.net/questions/203422        SCIENCE  ...
# 3  http://ux.stackexchange.com/questions/18600/is...     TECHNOLOGY  ...
# 4  http://stackoverflow.com/questions/16359492/ch...  STACKOVERFLOW  ...
#
#   answer_helpful  answer_level_of_information  answer_plausible  \
# 0       0.888889                     0.666667               1.0
# 1       1.000000                     0.666667               1.0
# 2       0.888889                     0.333333               1.0
# 3       0.888889                     0.666667               1.0
# 4       0.888889                     0.500000               1.0
#
#    answer_relevance  answer_satisfaction  answer_type_instructions  \
# 0               1.0             0.933333                  1.000000
# 1               1.0             0.866667                  0.666667
# 2               1.0             0.700000                  0.333333
# 3               1.0             0.933333                  0.000000
# 4               1.0             0.800000                  1.000000
#
#    answer_type_procedure  answer_type_reason_explanation  answer_well_written  \
# 0               0.000000                        0.333333             0.888889
# 1               0.000000                        1.000000             1.000000
# 2               0.333333                        1.000000             0.888889
# 3               0.000000                        0.666667             1.000000
# 4               0.000000                        0.000000             0.777778
#
#      set
# 0  train
# 1  train
# 2  train
# 3  train
# 4  train
#
# [5 rows x 42 columns]

# %%
question_target_cols = ['question_asker_intent_understanding','question_body_critical', 'question_conversational', 
                        'question_expect_short_answer', 'question_fact_seeking', 'question_has_commonly_accepted_answer',
                        'question_interestingness_others', 'question_interestingness_self', 'question_multi_intent', 
                        'question_not_really_a_question', 'question_opinion_seeking', 'question_type_choice',
                        'question_type_compare', 'question_type_consequence', 'question_type_definition', 
                        'question_type_entity', 'question_type_instructions', 'question_type_procedure',
                        'question_type_reason_explanation', 'question_type_spelling', 'question_well_written']
answer_target_cols = ['answer_helpful', 'answer_level_of_information', 'answer_plausible', 'answer_relevance',
                      'answer_satisfaction', 'answer_type_instructions', 'answer_type_procedure', 
                      'answer_type_reason_explanation', 'answer_well_written']
target_cols = question_target_cols + answer_target_cols

# %% [markdown]
# ## Pre-process data

# %%
text_features = ['question_title', 'question_body', 'answer']

for feature in text_features:
    # Lower
    train[feature] = train[feature].apply(lambda x: x.lower())
    validation[feature] = validation[feature].apply(lambda x: x.lower())
    test[feature] = test[feature].apply(lambda x: x.lower())
    # Map contractions
    train[feature] = train[feature].apply(lambda x: map_contraction(x))
    validation[feature] = validation[feature].apply(lambda x: map_contraction(x))
    test[feature] = test[feature].apply(lambda x: map_contraction(x))
    # Trim text
    train[feature] = train[feature].apply(lambda x: x.strip())
    validation[feature] = validation[feature].apply(lambda x: x.strip())
    test[feature] = test[feature].apply(lambda x: x.strip())

for feature in text_features:
    train[feature + '_uncased'] = train[feature]
    validation[feature + '_uncased'] = validation[feature]
    test[feature + '_uncased'] = test[feature]

# %%
display(train.head())
# Out:
#    qa_id                                     question_title  \
# 0   3895  magento (1.7) bundled product with free produc...
# 1   3131                             find router on network
# 2   1507  negatively curved metrics minimizing the lengt...
# 3   6784              is not the faq label obsolete by now?
# 4   2135  changing background image one time on responsi...
#
#                                        question_body question_user_name  \
# 0  I am looking to create a bundle offer where cu...                Joe
# 1  I have just bought a belkin n+ wireless router...                Guy
# 2  good afternoon everyone !\n\ni have the follow...            Selim G
# 3  do not get me wrong in the beginning of readin...     Benny Skogberg
# 4  the code I am using is this one \n\nbackground...        user2141649
#
#                               question_user_page  \
# 0  https://magento.stackexchange.com/users/16572
# 1               https://superuser.com/users/3248
# 2           https://mathoverflow.net/users/25511
# 3        https://ux.stackexchange.com/users/4679
# 4        https://stackoverflow.com/users/2141649
#
#                                               answer   answer_user_name  \
# 0  since the third item is fixed, you can use sho...  Fabian Schmengler
# 1  you likely have the router plugged in to the m...             John T
# 2  a very partial answer: by the results of richa...         Igor Rivin
# 3  is not the faq label obsolete by now? \n\nI ha...        Solracnapod
# 4  &lt;!doctype html&gt;\n&lt;html&gt;\n&lt;head&...           akkimads
#
#                               answer_user_page  \
# 0  https://magento.stackexchange.com/users/243
# 1             https://superuser.com/users/1931
# 2         https://mathoverflow.net/users/11142
# 3     https://ux.stackexchange.com/users/13153
# 4      https://stackoverflow.com/users/2375373
#
#                                                  url       category  ...  \
# 0  http://magento.stackexchange.com/questions/668...     TECHNOLOGY  ...
# 1               http://superuser.com/questions/87212     TECHNOLOGY  ...
# 2           http://mathoverflow.net/questions/203422        SCIENCE  ...
# 3  http://ux.stackexchange.com/questions/18600/is...     TECHNOLOGY  ...
# 4  http://stackoverflow.com/questions/16359492/ch...  STACKOVERFLOW  ...
#
#   answer_relevance  answer_satisfaction  answer_type_instructions  \
# 0              1.0             0.933333                  1.000000
# 1              1.0             0.866667                  0.666667
# 2              1.0             0.700000                  0.333333
# 3              1.0             0.933333                  0.000000
# 4              1.0             0.800000                  1.000000
#
#    answer_type_procedure  answer_type_reason_explanation  answer_well_written  \
# 0               0.000000                        0.333333             0.888889
# 1               0.000000                        1.000000             1.000000
# 2               0.333333                        1.000000             0.888889
# 3               0.000000                        0.666667             1.000000
# 4               0.000000                        0.000000             0.777778
#
#      set                             question_title_uncased  \
# 0  train  magento (1.7) bundled product with free produc...
# 1  train                             find router on network
# 2  train  negatively curved metrics minimizing the lengt...
# 3  train              is not the faq label obsolete by now?
# 4  train  changing background image one time on responsi...
#
#                                question_body_uncased  \
# 0  I am looking to create a bundle offer where cu...
# 1  I have just bought a belkin n+ wireless router...
# 2  good afternoon everyone !\n\ni have the follow...
# 3  do not get me wrong in the beginning of readin...
# 4  the code I am using is this one \n\nbackground...
#
#                                       answer_uncased
# 0  since the third item is fixed, you can use sho...
# 1  you likely have the router plugged in to the m...
# 2  a very partial answer: by the results of richa...
# 3  is not the faq label obsolete by now? \n\nI ha...
# 4  &lt;!doctype html&gt;\n&lt;html&gt;\n&lt;head&...
#
# [5 rows x 45 columns]

# %% [markdown]
# # Model parameters

# %%
EPOCHS = 50
BATCH_SIZE = 32
LEARNING_RATE = 3e-4
EMBEDDDING_SIZE = 512
N_CLASS = len(target_cols)
ES_PATIENCE = 5
RLROP_PATIENCE = 2
DECAY_DROP = 0.3
MAX_FEATURES = 100000
TITLE_MAX_LEN = 30
BODY_MAX_LEN = 200
ANSWER_MAX_LEN = 200

# %%
tokenizer = Tokenizer(num_words=MAX_FEATURES, lower=True)

tokenizer.fit_on_texts(list(train['question_title_uncased']) + list(validation['question_title_uncased']) + list(test['question_title_uncased']) +
                       list(train['question_body_uncased']) + list(validation['question_body_uncased']) + list(test['question_body_uncased']) +
                       list(train['answer_uncased']) + list(validation['answer_uncased']) + list(test['answer_uncased']))

# %% [markdown]
# ## Train/validation sets

# %%
# Train features
# X_train_title = train['question_title']
# X_train_body = train['question_body']
# X_train_answer = train['answer']
X_train_title_seq = train['question_title_uncased']
X_train_body_seq = train['question_body_uncased']
X_train_answer_seq = train['answer_uncased']

# Tokenize the sentences
X_train_title_seq = tokenizer.texts_to_sequences(X_train_title_seq)
X_train_body_seq = tokenizer.texts_to_sequences(X_train_body_seq)
X_train_answer_seq = tokenizer.texts_to_sequences(X_train_answer_seq)

# Pad the sentences
X_train_title_seq = pad_sequences(X_train_title_seq, maxlen=TITLE_MAX_LEN)
X_train_body_seq = pad_sequences(X_train_body_seq, maxlen=BODY_MAX_LEN)
X_train_answer_seq = pad_sequences(X_train_answer_seq, maxlen=ANSWER_MAX_LEN)


X_train = [X_train_title_seq, X_train_body_seq, X_train_answer_seq]
Y_train = train[target_cols].values

# Validation features
# X_valid_title = validation['question_title']
# X_valid_body = validation['question_body']
# X_valid_answer = validation['answer']
X_valid_title_seq = validation['question_title_uncased']
X_valid_body_seq = validation['question_body_uncased']
X_valid_answer_seq = validation['answer_uncased']

# Tokenize the sentences
X_valid_title_seq = tokenizer.texts_to_sequences(X_valid_title_seq)
X_valid_body_seq = tokenizer.texts_to_sequences(X_valid_body_seq)
X_valid_answer_seq = tokenizer.texts_to_sequences(X_valid_answer_seq)

# Pad the sentences
X_valid_title_seq = pad_sequences(X_valid_title_seq, maxlen=TITLE_MAX_LEN)
X_valid_body_seq = pad_sequences(X_valid_body_seq, maxlen=BODY_MAX_LEN)
X_valid_answer_seq = pad_sequences(X_valid_answer_seq, maxlen=ANSWER_MAX_LEN)

X_valid = [X_valid_title_seq, X_valid_body_seq, X_valid_answer_seq]
Y_valid = validation[target_cols].values


print('Train samples: %d' % len(Y_train))
print('Validation samples: %d' % len(Y_valid))
# Out:
# Train samples: 4863
# Validation samples: 1216

# %% [markdown]
# # Model

# %%
use_embed = hub.load(module_url)

def USEEmbedding(x):
    return use_embed(tf.squeeze(tf.cast(x, tf.string)))

def encoder_block(input_layer):
    encoder = Lambda(USEEmbedding, output_shape=(EMBEDDDING_SIZE,))(input_layer)
    
    return encoder

# %% [markdown]
# ## Load embedding

# %%
glove_embedding_matrix, glove_unknown_words = build_matrix(tokenizer.word_index, encoder_path, MAX_FEATURES)
print('n unknown words (GloVe): ', len(glove_unknown_words))
# Out:
# n unknown words (GloVe):  19913

# %%
# Title sequence
input_title_seq = Input(shape=(TITLE_MAX_LEN,), dtype=tf.float32, name='input_title_seq')
title = Embedding(*glove_embedding_matrix.shape, weights=[glove_embedding_matrix], trainable=False)(input_title_seq)
title = LSTM(128, kernel_initializer='lecun_normal', recurrent_dropout=0.5, return_sequences=True)(title)
title_out = GlobalAveragePooling1D()(title)

# Body sequence
input_body_seq = Input(shape=(BODY_MAX_LEN,), dtype=tf.float32, name='input_body_seq')
body = Embedding(*glove_embedding_matrix.shape, weights=[glove_embedding_matrix], trainable=False)(input_body_seq)
body = LSTM(128, kernel_initializer='lecun_normal', recurrent_dropout=0.5, return_sequences=True)(body)
body_out = GlobalAveragePooling1D()(body)

# Answer sequence
input_answer_seq = Input(shape=(ANSWER_MAX_LEN,), dtype=tf.float32, name='input_answer_seq')
answer = Embedding(*glove_embedding_matrix.shape, weights=[glove_embedding_matrix], trainable=False)(input_answer_seq)
answer = LSTM(128, kernel_initializer='lecun_normal', recurrent_dropout=0.5, return_sequences=True)(answer)
answer_out = GlobalAveragePooling1D()(answer)


# Output
x = Concatenate()([title_out, body_out, answer_out])
x = Dropout(0.5)(x)
x = Dense(512, activation='relu', kernel_initializer='lecun_normal')(x)
x = Dropout(0.5)(x)

output = Dense(N_CLASS, activation='sigmoid', kernel_initializer='lecun_normal', name='output')(x)
model = Model(inputs=[input_title_seq, input_body_seq, input_answer_seq], outputs=[output])

model.summary()
# Out:
# Model: "model"
# __________________________________________________________________________________________________
# Layer (type)                    Output Shape         Param #     Connected to
# ==================================================================================================
# input_title_seq (InputLayer)    [(None, 30)]         0
# __________________________________________________________________________________________________
# input_body_seq (InputLayer)     [(None, 200)]        0
# __________________________________________________________________________________________________
# input_answer_seq (InputLayer)   [(None, 200)]        0
# __________________________________________________________________________________________________
# embedding (Embedding)           (None, 30, 300)      17402100    input_title_seq[0][0]
# __________________________________________________________________________________________________
# embedding_1 (Embedding)         (None, 200, 300)     17402100    input_body_seq[0][0]
# __________________________________________________________________________________________________
# embedding_2 (Embedding)         (None, 200, 300)     17402100    input_answer_seq[0][0]
# __________________________________________________________________________________________________
# lstm (LSTM)                     (None, 30, 128)      219648      embedding[0][0]
# __________________________________________________________________________________________________
# lstm_1 (LSTM)                   (None, 200, 128)     219648      embedding_1[0][0]
# __________________________________________________________________________________________________
# lstm_2 (LSTM)                   (None, 200, 128)     219648      embedding_2[0][0]
# __________________________________________________________________________________________________
# global_average_pooling1d (Globa (None, 128)          0           lstm[0][0]
# __________________________________________________________________________________________________
# global_average_pooling1d_1 (Glo (None, 128)          0           lstm_1[0][0]
# __________________________________________________________________________________________________
# global_average_pooling1d_2 (Glo (None, 128)          0           lstm_2[0][0]
# __________________________________________________________________________________________________
# concatenate (Concatenate)       (None, 384)          0           global_average_pooling1d[0][0]
#                                                                  global_average_pooling1d_1[0][0]
#                                                                  global_average_pooling1d_2[0][0]
# __________________________________________________________________________________________________
# dropout (Dropout)               (None, 384)          0           concatenate[0][0]
# __________________________________________________________________________________________________
# dense (Dense)                   (None, 512)          197120      dropout[0][0]
# __________________________________________________________________________________________________
# dropout_1 (Dropout)             (None, 512)          0           dense[0][0]
# __________________________________________________________________________________________________
# output (Dense)                  (None, 30)           15390       dropout_1[0][0]
# ==================================================================================================
# Total params: 53,077,754
# Trainable params: 871,454
# Non-trainable params: 52,206,300
# __________________________________________________________________________________________________

# %% [markdown]
# # Train model

# %%
rlrop = ReduceLROnPlateau(monitor='val_loss', mode='min', patience=RLROP_PATIENCE, factor=DECAY_DROP, min_lr=1e-7, verbose=1)
spearmanCallback = SpearmanRhoCallback(training_data=(X_train, Y_train), validation_data=(X_valid, Y_valid), monitor='val_loss', mode='min', patience=ES_PATIENCE)
callback_list = [rlrop, spearmanCallback]

optimizer = optimizers.Adam(LEARNING_RATE)
model.compile(optimizer=optimizer, loss='binary_crossentropy')

history = model.fit(X_train, Y_train, 
                    validation_data=(X_valid, Y_valid), 
                    callbacks=callback_list, 
                    batch_size=BATCH_SIZE, 
                    epochs=EPOCHS, 
                    verbose=2).history
# Out:
# Train on 4863 samples, validate on 1216 samples
# Epoch 1/50
# spearman-rho: 0.1778 val_spearman-rho: 0.1707
# 4863/4863 - 175s - loss: 0.4744 - val_loss: 0.4202
# Epoch 2/50
# spearman-rho: 0.2555 val_spearman-rho: 0.2524
# 4863/4863 - 163s - loss: 0.4192 - val_loss: 0.4069
# Epoch 3/50
# spearman-rho: 0.2831 val_spearman-rho: 0.2771
# 4863/4863 - 163s - loss: 0.4091 - val_loss: 0.4016
# Epoch 4/50
# spearman-rho: 0.3014 val_spearman-rho: 0.2916
# 4863/4863 - 166s - loss: 0.4039 - val_loss: 0.3976
# Epoch 5/50
# spearman-rho: 0.3129 val_spearman-rho: 0.3008
# 4863/4863 - 161s - loss: 0.4000 - val_loss: 0.3962
# Epoch 6/50
# spearman-rho: 0.3197 val_spearman-rho: 0.3065
# 4863/4863 - 165s - loss: 0.3970 - val_loss: 0.3941
# Epoch 7/50
# spearman-rho: 0.3258 val_spearman-rho: 0.3095
# 4863/4863 - 163s - loss: 0.3949 - val_loss: 0.3929
# Epoch 8/50
# spearman-rho: 0.3331 val_spearman-rho: 0.3133
# 4863/4863 - 164s - loss: 0.3926 - val_loss: 0.3916
# Epoch 9/50
# spearman-rho: 0.3404 val_spearman-rho: 0.3180
# 4863/4863 - 158s - loss: 0.3910 - val_loss: 0.3904
# Epoch 10/50
# spearman-rho: 0.3444 val_spearman-rho: 0.3202
# 4863/4863 - 160s - loss: 0.3901 - val_loss: 0.3897
# Epoch 11/50
# spearman-rho: 0.3501 val_spearman-rho: 0.3241
# 4863/4863 - 157s - loss: 0.3886 - val_loss: 0.3892
# Epoch 12/50
# spearman-rho: 0.3551 val_spearman-rho: 0.3259
# 4863/4863 - 158s - loss: 0.3871 - val_loss: 0.3888
# Epoch 13/50
# spearman-rho: 0.3613 val_spearman-rho: 0.3301
# 4863/4863 - 160s - loss: 0.3859 - val_loss: 0.3873
# Epoch 14/50
# spearman-rho: 0.3660 val_spearman-rho: 0.3308
# 4863/4863 - 163s - loss: 0.3848 - val_loss: 0.3868
# Epoch 15/50
# spearman-rho: 0.3718 val_spearman-rho: 0.3340
# 4863/4863 - 161s - loss: 0.3835 - val_loss: 0.3866
# Epoch 16/50
# spearman-rho: 0.3750 val_spearman-rho: 0.3360
# 4863/4863 - 160s - loss: 0.3825 - val_loss: 0.3859
# Epoch 17/50
# spearman-rho: 0.3795 val_spearman-rho: 0.3382
# 4863/4863 - 157s - loss: 0.3812 - val_loss: 0.3853
# Epoch 18/50
# spearman-rho: 0.3842 val_spearman-rho: 0.3401
# 4863/4863 - 163s - loss: 0.3801 - val_loss: 0.3849
# Epoch 19/50
# spearman-rho: 0.3881 val_spearman-rho: 0.3430
# 4863/4863 - 161s - loss: 0.3792 - val_loss: 0.3850
# Epoch 20/50
# spearman-rho: 0.3911 val_spearman-rho: 0.3431
# 4863/4863 - 162s - loss: 0.3778 - val_loss: 0.3842
# Epoch 21/50
# spearman-rho: 0.3952 val_spearman-rho: 0.3448
# 4863/4863 - 163s - loss: 0.3773 - val_loss: 0.3838
# Epoch 22/50
# spearman-rho: 0.3985 val_spearman-rho: 0.3446
# 4863/4863 - 162s - loss: 0.3762 - val_loss: 0.3838
# Epoch 23/50
# spearman-rho: 0.4036 val_spearman-rho: 0.3456
# 4863/4863 - 162s - loss: 0.3757 - val_loss: 0.3833
# Epoch 24/50
# spearman-rho: 0.4059 val_spearman-rho: 0.3473
# 4863/4863 - 161s - loss: 0.3743 - val_loss: 0.3827
# Epoch 25/50
# spearman-rho: 0.4094 val_spearman-rho: 0.3482
# 4863/4863 - 162s - loss: 0.3732 - val_loss: 0.3827
# Epoch 26/50
#
# Epoch 00026: ReduceLROnPlateau reducing learning rate to 9.000000427477062e-05.
# spearman-rho: 0.4131 val_spearman-rho: 0.3485
# 4863/4863 - 162s - loss: 0.3730 - val_loss: 0.3829
# Epoch 27/50
# spearman-rho: 0.4157 val_spearman-rho: 0.3497
# 4863/4863 - 165s - loss: 0.3709 - val_loss: 0.3821
# Epoch 28/50
# spearman-rho: 0.4172 val_spearman-rho: 0.3503
# 4863/4863 - 159s - loss: 0.3703 - val_loss: 0.3816
# Epoch 29/50
# spearman-rho: 0.4186 val_spearman-rho: 0.3501
# 4863/4863 - 162s - loss: 0.3703 - val_loss: 0.3817
# Epoch 30/50
#
# Epoch 00030: ReduceLROnPlateau reducing learning rate to 2.700000040931627e-05.
# spearman-rho: 0.4199 val_spearman-rho: 0.3511
# Epoch 00029: early stopping
# 4863/4863 - 162s - loss: 0.3696 - val_loss: 0.3818

# %% [markdown]
# ## Model loss graph

# %%
sns.set(style="whitegrid")
plot_metrics(history, metric_list=['loss', 'spearman'])

# %% [markdown]
# # Evaluation

# %%
preds_train = model.predict(X_train)
preds_val = model.predict(X_valid)

display(get_metrics(Y_train, preds_train, Y_valid, preds_val, target_cols).style.applymap(color_map))
# Out:
# <style  type="text/css" >
#     #T_fd6d3ccc_2aac_11ea_895e_c58683e553b1row0_col0 {
#             color:  black;
#         }    #T_fd6d3ccc_2aac_11ea_895e_c58683e553b1row0_col1 {
#             color:  black;
#         }    #T_fd6d3ccc_2aac_11ea_895e_c58683e553b1row0_col2 {
#             color:  black;
#         }    #T_fd6d3ccc_2aac_11ea_895e_c58683e553b1row1_col0 {
#             color:  black;
#         }    #T_fd6d3ccc_2aac_11ea_895e_c58683e553b1row1_col1 {
#             color:  black;
#         }    #T_fd6d3ccc_2aac_11ea_895e_c58683e553b1row1_col2 {
#             color:  black;
#         }    #T_fd6d3ccc_2aac_11ea_895e_c58683e553b1row2_col0 {
#             color:  black;
#         }    #T_fd6d3ccc_2aac_11ea_895e_c58683e553b1row2_col1 {
#             color:  black;
#         }    #T_fd6d3ccc_2aac_11ea_895e_c58683e553b1row2_col2 {
#             color:  black;
#         }    #T_fd6d3ccc_2aac_11ea_895e_c58683e553b1row3_col0 {
#             color:  black;
#         }    #T_fd6d3ccc_2aac_11ea_895e_c58683e553b1row3_col1 {
#             color:  black;
#         }    #T_fd6d3ccc_2aac_11ea_895e_c58683e553b1row3_col2 {
#             color:  black;
#         }    #T_fd6d3ccc_2aac_11ea_895e_c58683e553b1row4_col0 {
#             color:  black;
#         }    #T_fd6d3ccc_2aac_11ea_895e_c58683e553b1row4_col1 {
#             color:  black;
#         }    #T_fd6d3ccc_2aac_11ea_895e_c58683e553b1row4_col2 {
#             color:  orange;
#         }    #T_fd6d3ccc_2aac_11ea_895e_c58683e553b1row5_col0 {
#             color:  black;
#         }    #T_fd6d3ccc_2aac_11ea_895e_c58683e553b1row5_col1 {
#             color:  black;
#         }    #T_fd6d3ccc_2aac_11ea_895e_c58683e553b1row5_col2 {
#             color:  black;
#         }    #T_fd6d3ccc_2aac_11ea_895e_c58683e553b1row6_col0 {
#             color:  black;
#         }    #T_fd6d3ccc_2aac_11ea_895e_c58683e553b1row6_col1 {
#             color:  black;
#         }    #T_fd6d3ccc_2aac_11ea_895e_c58683e553b1row6_col2 {
#             color:  black;
#         }    #T_fd6d3ccc_2aac_11ea_895e_c58683e553b1row7_col0 {
#             color:  black;
#         }    #T_fd6d3ccc_2aac_11ea_895e_c58683e553b1row7_col1 {
#             color:  black;
#         }    #T_fd6d3ccc_2aac_11ea_895e_c58683e553b1row7_col2 {
#             color:  black;
#         }    #T_fd6d3ccc_2aac_11ea_895e_c58683e553b1row8_col0 {
#             color:  black;
#         }    #T_fd6d3ccc_2aac_11ea_895e_c58683e553b1row8_col1 {
#             color:  black;
#         }    #T_fd6d3ccc_2aac_11ea_895e_c58683e553b1row8_col2 {
#             color:  black;
#         }    #T_fd6d3ccc_2aac_11ea_895e_c58683e553b1row9_col0 {
#             color:  black;
#         }    #T_fd6d3ccc_2aac_11ea_895e_c58683e553b1row9_col1 {
#             color:  black;
#         }    #T_fd6d3ccc_2aac_11ea_895e_c58683e553b1row9_col2 {
#             color:  black;
#         }    #T_fd6d3ccc_2aac_11ea_895e_c58683e553b1row10_col0 {
#             color:  black;
#         }    #T_fd6d3ccc_2aac_11ea_895e_c58683e553b1row10_col1 {
#             color:  orange;
#         }    #T_fd6d3ccc_2aac_11ea_895e_c58683e553b1row10_col2 {
#             color:  purple;
#         }    #T_fd6d3ccc_2aac_11ea_895e_c58683e553b1row11_col0 {
#             color:  black;
#         }    #T_fd6d3ccc_2aac_11ea_895e_c58683e553b1row11_col1 {
#             color:  black;
#         }    #T_fd6d3ccc_2aac_11ea_895e_c58683e553b1row11_col2 {
#             color:  black;
#         }    #T_fd6d3ccc_2aac_11ea_895e_c58683e553b1row12_col0 {
#             color:  black;
#         }    #T_fd6d3ccc_2aac_11ea_895e_c58683e553b1row12_col1 {
#             color:  black;
#         }    #T_fd6d3ccc_2aac_11ea_895e_c58683e553b1row12_col2 {
#             color:  black;
#         }    #T_fd6d3ccc_2aac_11ea_895e_c58683e553b1row13_col0 {
#             color:  black;
#         }    #T_fd6d3ccc_2aac_11ea_895e_c58683e553b1row13_col1 {
#             color:  black;
#         }    #T_fd6d3ccc_2aac_11ea_895e_c58683e553b1row13_col2 {
#             color:  orange;
#         }    #T_fd6d3ccc_2aac_11ea_895e_c58683e553b1row14_col0 {
#             color:  black;
#         }    #T_fd6d3ccc_2aac_11ea_895e_c58683e553b1row14_col1 {
#             color:  orange;
#         }    #T_fd6d3ccc_2aac_11ea_895e_c58683e553b1row14_col2 {
#             color:  orange;
#         }    #T_fd6d3ccc_2aac_11ea_895e_c58683e553b1row15_col0 {
#             color:  black;
#         }    #T_fd6d3ccc_2aac_11ea_895e_c58683e553b1row15_col1 {
#             color:  black;
#         }    #T_fd6d3ccc_2aac_11ea_895e_c58683e553b1row15_col2 {
#             color:  orange;
#         }    #T_fd6d3ccc_2aac_11ea_895e_c58683e553b1row16_col0 {
#             color:  black;
#         }    #T_fd6d3ccc_2aac_11ea_895e_c58683e553b1row16_col1 {
#             color:  black;
#         }    #T_fd6d3ccc_2aac_11ea_895e_c58683e553b1row16_col2 {
#             color:  black;
#         }    #T_fd6d3ccc_2aac_11ea_895e_c58683e553b1row17_col0 {
#             color:  black;
#         }    #T_fd6d3ccc_2aac_11ea_895e_c58683e553b1row17_col1 {
#             color:  black;
#         }    #T_fd6d3ccc_2aac_11ea_895e_c58683e553b1row17_col2 {
#             color:  black;
#         }    #T_fd6d3ccc_2aac_11ea_895e_c58683e553b1row18_col0 {
#             color:  black;
#         }    #T_fd6d3ccc_2aac_11ea_895e_c58683e553b1row18_col1 {
#             color:  black;
#         }    #T_fd6d3ccc_2aac_11ea_895e_c58683e553b1row18_col2 {
#             color:  black;
#         }    #T_fd6d3ccc_2aac_11ea_895e_c58683e553b1row19_col0 {
#             color:  black;
#         }    #T_fd6d3ccc_2aac_11ea_895e_c58683e553b1row19_col1 {
#             color:  black;
#         }    #T_fd6d3ccc_2aac_11ea_895e_c58683e553b1row19_col2 {
#             color:  black;
#         }    #T_fd6d3ccc_2aac_11ea_895e_c58683e553b1row20_col0 {
#             color:  black;
#         }    #T_fd6d3ccc_2aac_11ea_895e_c58683e553b1row20_col1 {
#             color:  purple;
#         }    #T_fd6d3ccc_2aac_11ea_895e_c58683e553b1row20_col2 {
#             color:  purple;
#         }    #T_fd6d3ccc_2aac_11ea_895e_c58683e553b1row21_col0 {
#             color:  black;
#         }    #T_fd6d3ccc_2aac_11ea_895e_c58683e553b1row21_col1 {
#             color:  black;
#         }    #T_fd6d3ccc_2aac_11ea_895e_c58683e553b1row21_col2 {
#             color:  black;
#         }    #T_fd6d3ccc_2aac_11ea_895e_c58683e553b1row22_col0 {
#             color:  black;
#         }    #T_fd6d3ccc_2aac_11ea_895e_c58683e553b1row22_col1 {
#             color:  orange;
#         }    #T_fd6d3ccc_2aac_11ea_895e_c58683e553b1row22_col2 {
#             color:  orange;
#         }    #T_fd6d3ccc_2aac_11ea_895e_c58683e553b1row23_col0 {
#             color:  black;
#         }    #T_fd6d3ccc_2aac_11ea_895e_c58683e553b1row23_col1 {
#             color:  black;
#         }    #T_fd6d3ccc_2aac_11ea_895e_c58683e553b1row23_col2 {
#             color:  black;
#         }    #T_fd6d3ccc_2aac_11ea_895e_c58683e553b1row24_col0 {
#             color:  black;
#         }    #T_fd6d3ccc_2aac_11ea_895e_c58683e553b1row24_col1 {
#             color:  orange;
#         }    #T_fd6d3ccc_2aac_11ea_895e_c58683e553b1row24_col2 {
#             color:  purple;
#         }    #T_fd6d3ccc_2aac_11ea_895e_c58683e553b1row25_col0 {
#             color:  black;
#         }    #T_fd6d3ccc_2aac_11ea_895e_c58683e553b1row25_col1 {
#             color:  orange;
#         }    #T_fd6d3ccc_2aac_11ea_895e_c58683e553b1row25_col2 {
#             color:  orange;
#         }    #T_fd6d3ccc_2aac_11ea_895e_c58683e553b1row26_col0 {
#             color:  black;
#         }    #T_fd6d3ccc_2aac_11ea_895e_c58683e553b1row26_col1 {
#             color:  black;
#         }    #T_fd6d3ccc_2aac_11ea_895e_c58683e553b1row26_col2 {
#             color:  orange;
#         }    #T_fd6d3ccc_2aac_11ea_895e_c58683e553b1row27_col0 {
#             color:  black;
#         }    #T_fd6d3ccc_2aac_11ea_895e_c58683e553b1row27_col1 {
#             color:  black;
#         }    #T_fd6d3ccc_2aac_11ea_895e_c58683e553b1row27_col2 {
#             color:  black;
#         }    #T_fd6d3ccc_2aac_11ea_895e_c58683e553b1row28_col0 {
#             color:  black;
#         }    #T_fd6d3ccc_2aac_11ea_895e_c58683e553b1row28_col1 {
#             color:  black;
#         }    #T_fd6d3ccc_2aac_11ea_895e_c58683e553b1row28_col2 {
#             color:

# %% [markdown]
# ## By category

# %%
target_cols_preds = [col+'_pred' for col in target_cols]
for col in target_cols_preds:
    train[col] = 0
    validation[col] = 0
    
train[target_cols_preds] = preds_train
validation[target_cols_preds] = preds_val
    
display(get_metrics_category(train, validation, target_cols, target_cols_preds, 'category').style.applymap(color_map))
# Out:
# <style  type="text/css" >
#     #T_fdc98e3c_2aac_11ea_895e_c58683e553b1row0_col0 {
#             color:  black;
#         }    #T_fdc98e3c_2aac_11ea_895e_c58683e553b1row0_col1 {
#             color:  black;
#         }    #T_fdc98e3c_2aac_11ea_895e_c58683e553b1row0_col2 {
#             color:  black;
#         }    #T_fdc98e3c_2aac_11ea_895e_c58683e553b1row0_col3 {
#             color:  black;
#         }    #T_fdc98e3c_2aac_11ea_895e_c58683e553b1row0_col4 {
#             color:  black;
#         }    #T_fdc98e3c_2aac_11ea_895e_c58683e553b1row0_col5 {
#             color:  orange;
#         }    #T_fdc98e3c_2aac_11ea_895e_c58683e553b1row0_col6 {
#             color:  orange;
#         }    #T_fdc98e3c_2aac_11ea_895e_c58683e553b1row0_col7 {
#             color:  black;
#         }    #T_fdc98e3c_2aac_11ea_895e_c58683e553b1row0_col8 {
#             color:  black;
#         }    #T_fdc98e3c_2aac_11ea_895e_c58683e553b1row0_col9 {
#             color:  black;
#         }    #T_fdc98e3c_2aac_11ea_895e_c58683e553b1row0_col10 {
#             color:  black;
#         }</style><table id="T_fdc98e3c_2aac_11ea_895e_c58683e553b1" ><thead>    <tr>        <th class="blank level0" ></th>        <th class="col_heading level0 col0" >Label</th>        <th class="col_heading level0 col1" >Train (TECHNOLOGY)</th>        <th class="col_heading level0 col2" >Validation (TECHNOLOGY)</th>        <th class="col_heading level0 col3" >Train (SCIENCE)</th>        <th class="col_heading level0 col4" >Validation (SCIENCE)</th>        <th class="col_heading level0 col5" >Train (STACKOVERFLOW)</th>        <th class="col_heading level0 col6" >Validation (STACKOVERFLOW)</th>        <th class="col_heading level0 col7" >Train (LIFE_ARTS)</th>        <th class="col_heading level0 col8" >Validation (LIFE_ARTS)</th>        <th class="col_heading level0 col9" >Train (CULTURE)</th>        <th class="col_heading level0 col10" >Validation (CULTURE)</th>    </tr></thead><tbody>
#                 <tr>
#                         <th id="T_fdc98e3c_2aac_11ea_895e_c58683e553b1level0_row0" class="row_heading level0 row0" >0</th>
#                         <td id="T_fdc98e3c_2aac_11ea_895e_c58683e553b1row0_col0" class="data row0 col0" >Averaged</td>
#                         <td id="T_fdc98e3c_2aac_11ea_895e_c58683e553b1row0_col1" class="data row0 col1" >0.38</td>
#                         <td id="T_fdc98e3c_2aac_11ea_895e_c58683e553b1row0_col2" class="data row0 col2" >0.316</td>
#                         <td id="T_fdc98e3c_2aac_11ea_895e_c58683e553b1row0_col3" class="data row0 col3" >0.44</td>
#                         <td id="T_fdc98e3c_2aac_11ea_895e_c58683e553b1row0_col4" class="data row0 col4" >0.34</td>
#                         <td id="T_fdc98e3c_2aac_11ea_895e_c58683e553b1row0_col5" class="data row0 col5" >0.298</td>
#                         <td id="T_fdc98e3c_2aac_11ea_895e_c58683e553b1row0_col6" class="data row0 col6" >0.196</td>
#                         <td id="T_fdc98e3c_2aac_11ea_895e_c58683e553b1row0_col7" class="data row0 col7" >0.432</td>
#                         <td id="T_fdc98e3c_2aac_11ea_895e_c58683e553b1row0_col8" class="data row0 col8" >0.357</td>
#                         <td id="T_fdc98e3c_2aac_11ea_895e_c58683e553b1row0_col9" class="data row0 col9" >0.411</td>
#                         <td id="T_fdc98e3c_2aac_11ea_895e_c58683e553b1row0_col10" class="data row0 col10" >0.34</td>
#             </tr>
#     </tbody></table>

# %% [markdown]
# #### Save model weights and ecoders

# %%
model.save_weights(model_path)
dump(tokenizer, tokenizer_path)
# Out:
# ['/kaggle/working/tokenizer.joblib']
