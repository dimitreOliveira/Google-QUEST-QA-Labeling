# %% [markdown]
# ## Dependencies

# %%
import gc
import re
import warnings
from joblib import dump
import tensorflow_hub as hub
from tensorflow.keras import Model, optimizers
from tensorflow.keras.callbacks import ReduceLROnPlateau
from tensorflow.keras.preprocessing.text import Tokenizer
from tensorflow.keras.preprocessing.sequence import pad_sequences
from tensorflow.keras.layers import Lambda, Input, Dense, Dropout, Concatenate, BatchNormalization, Activation, Average, Add, Reshape, Attention
from tensorflow.keras.layers import GlobalAveragePooling1D, Embedding, LSTM, Conv1D, SpatialDropout1D, Bidirectional, Flatten, Bidirectional
from googleqa_utilityscript import *


SEED = 0
seed_everything(SEED)
warnings.filterwarnings("ignore")

# %% [markdown]
# ## Load data

# %%
module_url = '/kaggle/input/universalsentenceencodermodels/universal-sentence-encoder-models/use'
model_path = '/kaggle/working/model.h5'
tokenizer_path = '/kaggle/working/tokenizer.joblib'
encoder_path = '/kaggle/input/pickled-glove840b300d-for-10sec-loading/glove.840B.300d.pkl'

hold_out = pd.read_csv('/kaggle/input/googleqa-mldataset/hold-out.csv')
test = pd.read_csv('/kaggle/input/google-quest-challenge/test.csv')
train = hold_out[hold_out['set'] == 'train']
validation = hold_out[hold_out['set'] == 'validation']

print('Train samples: %s' % len(train))
print('Validation samples: %s' % len(validation))
display(train.head())
# Out:
# Train samples: 4863
# Validation samples: 1216
#    qa_id                                     question_title  \
# 0   3895  Magento (1.7) Bundled Product with FREE Produc...
# 1   3131                             Find router on network
# 2   1507  Negatively curved metrics minimizing the lengt...
# 3   6784               Isn’t the FAQ label obsolete by now?
# 4   2135  Changing background image one time on responsi...
#
#                                        question_body question_user_name  \
# 0  I'm looking to create a bundle offer where cus...                Joe
# 1  I've just bought a Belkin N+ Wireless Router. ...                Guy
# 2  Good afternoon everyone !\n\nI have the follow...            Selim G
# 3  Don’t get me wrong in the beginning of reading...     Benny Skogberg
# 4  The code I'm using is this one \n\nbackground:...        user2141649
#
#                               question_user_page  \
# 0  https://magento.stackexchange.com/users/16572
# 1               https://superuser.com/users/3248
# 2           https://mathoverflow.net/users/25511
# 3        https://ux.stackexchange.com/users/4679
# 4        https://stackoverflow.com/users/2141649
#
#                                               answer   answer_user_name  \
# 0  Since the third item is fixed, you can use sho...  Fabian Schmengler
# 1  You likely have the router plugged in to the m...             John T
# 2  A very partial answer: by the results of Richa...         Igor Rivin
# 3  Isn’t the FAQ label obsolete by now? \n\nI'd s...        Solracnapod
# 4  &lt;!DOCTYPE html&gt;\n&lt;html&gt;\n&lt;head&...           akkimads
#
#                               answer_user_page  \
# 0  https://magento.stackexchange.com/users/243
# 1             https://superuser.com/users/1931
# 2         https://mathoverflow.net/users/11142
# 3     https://ux.stackexchange.com/users/13153
# 4      https://stackoverflow.com/users/2375373
#
#                                                  url       category  ...  \
# 0  http://magento.stackexchange.com/questions/668...     TECHNOLOGY  ...
# 1               http://superuser.com/questions/87212     TECHNOLOGY  ...
# 2           http://mathoverflow.net/questions/203422        SCIENCE  ...
# 3  http://ux.stackexchange.com/questions/18600/is...     TECHNOLOGY  ...
# 4  http://stackoverflow.com/questions/16359492/ch...  STACKOVERFLOW  ...
#
#   answer_helpful  answer_level_of_information  answer_plausible  \
# 0       0.888889                     0.666667               1.0
# 1       1.000000                     0.666667               1.0
# 2       0.888889                     0.333333               1.0
# 3       0.888889                     0.666667               1.0
# 4       0.888889                     0.500000               1.0
#
#    answer_relevance  answer_satisfaction  answer_type_instructions  \
# 0               1.0             0.933333                  1.000000
# 1               1.0             0.866667                  0.666667
# 2               1.0             0.700000                  0.333333
# 3               1.0             0.933333                  0.000000
# 4               1.0             0.800000                  1.000000
#
#    answer_type_procedure  answer_type_reason_explanation  answer_well_written  \
# 0               0.000000                        0.333333             0.888889
# 1               0.000000                        1.000000             1.000000
# 2               0.333333                        1.000000             0.888889
# 3               0.000000                        0.666667             1.000000
# 4               0.000000                        0.000000             0.777778
#
#      set
# 0  train
# 1  train
# 2  train
# 3  train
# 4  train
#
# [5 rows x 42 columns]

# %%
question_target_cols = ['question_asker_intent_understanding','question_body_critical', 'question_conversational', 
                        'question_expect_short_answer', 'question_fact_seeking', 'question_has_commonly_accepted_answer',
                        'question_interestingness_others', 'question_interestingness_self', 'question_multi_intent', 
                        'question_not_really_a_question', 'question_opinion_seeking', 'question_type_choice',
                        'question_type_compare', 'question_type_consequence', 'question_type_definition', 
                        'question_type_entity', 'question_type_instructions', 'question_type_procedure',
                        'question_type_reason_explanation', 'question_type_spelling', 'question_well_written']
answer_target_cols = ['answer_helpful', 'answer_level_of_information', 'answer_plausible', 'answer_relevance',
                      'answer_satisfaction', 'answer_type_instructions', 'answer_type_procedure', 
                      'answer_type_reason_explanation', 'answer_well_written']
target_cols = question_target_cols + answer_target_cols

# %% [markdown]
# ## Pre-process data

# %%
text_features = ['question_title', 'question_body', 'answer']

for feature in text_features:
    # Lower
    train[feature] = train[feature].apply(lambda x: x.lower())
    validation[feature] = validation[feature].apply(lambda x: x.lower())
    test[feature] = test[feature].apply(lambda x: x.lower())
    # Map contractions
    train[feature] = train[feature].apply(lambda x: map_contraction(x))
    validation[feature] = validation[feature].apply(lambda x: map_contraction(x))
    test[feature] = test[feature].apply(lambda x: map_contraction(x))
    # Trim text
    train[feature] = train[feature].apply(lambda x: x.strip())
    validation[feature] = validation[feature].apply(lambda x: x.strip())
    test[feature] = test[feature].apply(lambda x: x.strip())

for feature in text_features:
    train[feature + '_uncased'] = train[feature]
    validation[feature + '_uncased'] = validation[feature]
    test[feature + '_uncased'] = test[feature]

# %%
display(train.head())
# Out:
#    qa_id                                     question_title  \
# 0   3895  magento (1.7) bundled product with free produc...
# 1   3131                             find router on network
# 2   1507  negatively curved metrics minimizing the lengt...
# 3   6784              is not the faq label obsolete by now?
# 4   2135  changing background image one time on responsi...
#
#                                        question_body question_user_name  \
# 0  I am looking to create a bundle offer where cu...                Joe
# 1  I have just bought a belkin n+ wireless router...                Guy
# 2  good afternoon everyone !\n\ni have the follow...            Selim G
# 3  do not get me wrong in the beginning of readin...     Benny Skogberg
# 4  the code I am using is this one \n\nbackground...        user2141649
#
#                               question_user_page  \
# 0  https://magento.stackexchange.com/users/16572
# 1               https://superuser.com/users/3248
# 2           https://mathoverflow.net/users/25511
# 3        https://ux.stackexchange.com/users/4679
# 4        https://stackoverflow.com/users/2141649
#
#                                               answer   answer_user_name  \
# 0  since the third item is fixed, you can use sho...  Fabian Schmengler
# 1  you likely have the router plugged in to the m...             John T
# 2  a very partial answer: by the results of richa...         Igor Rivin
# 3  is not the faq label obsolete by now? \n\nI ha...        Solracnapod
# 4  &lt;!doctype html&gt;\n&lt;html&gt;\n&lt;head&...           akkimads
#
#                               answer_user_page  \
# 0  https://magento.stackexchange.com/users/243
# 1             https://superuser.com/users/1931
# 2         https://mathoverflow.net/users/11142
# 3     https://ux.stackexchange.com/users/13153
# 4      https://stackoverflow.com/users/2375373
#
#                                                  url       category  ...  \
# 0  http://magento.stackexchange.com/questions/668...     TECHNOLOGY  ...
# 1               http://superuser.com/questions/87212     TECHNOLOGY  ...
# 2           http://mathoverflow.net/questions/203422        SCIENCE  ...
# 3  http://ux.stackexchange.com/questions/18600/is...     TECHNOLOGY  ...
# 4  http://stackoverflow.com/questions/16359492/ch...  STACKOVERFLOW  ...
#
#   answer_relevance  answer_satisfaction  answer_type_instructions  \
# 0              1.0             0.933333                  1.000000
# 1              1.0             0.866667                  0.666667
# 2              1.0             0.700000                  0.333333
# 3              1.0             0.933333                  0.000000
# 4              1.0             0.800000                  1.000000
#
#    answer_type_procedure  answer_type_reason_explanation  answer_well_written  \
# 0               0.000000                        0.333333             0.888889
# 1               0.000000                        1.000000             1.000000
# 2               0.333333                        1.000000             0.888889
# 3               0.000000                        0.666667             1.000000
# 4               0.000000                        0.000000             0.777778
#
#      set                             question_title_uncased  \
# 0  train  magento (1.7) bundled product with free produc...
# 1  train                             find router on network
# 2  train  negatively curved metrics minimizing the lengt...
# 3  train              is not the faq label obsolete by now?
# 4  train  changing background image one time on responsi...
#
#                                question_body_uncased  \
# 0  I am looking to create a bundle offer where cu...
# 1  I have just bought a belkin n+ wireless router...
# 2  good afternoon everyone !\n\ni have the follow...
# 3  do not get me wrong in the beginning of readin...
# 4  the code I am using is this one \n\nbackground...
#
#                                       answer_uncased
# 0  since the third item is fixed, you can use sho...
# 1  you likely have the router plugged in to the m...
# 2  a very partial answer: by the results of richa...
# 3  is not the faq label obsolete by now? \n\nI ha...
# 4  &lt;!doctype html&gt;\n&lt;html&gt;\n&lt;head&...
#
# [5 rows x 45 columns]

# %% [markdown]
# # Model parameters

# %%
EPOCHS = 50
BATCH_SIZE = 64
LEARNING_RATE = 1e-3
EMBEDDDING_SIZE = 512
N_CLASS = len(target_cols)
ES_PATIENCE = 8
RLROP_PATIENCE = 3
DECAY_DROP = 0.1
MAX_FEATURES = 100000
TITLE_MAX_LEN = 30
BODY_MAX_LEN = 100
ANSWER_MAX_LEN = 100

# %%
tokenizer = Tokenizer(num_words=MAX_FEATURES, lower=True)

tokenizer.fit_on_texts(list(train['question_title_uncased']) + list(validation['question_title_uncased']) + list(test['question_title_uncased']) +
                       list(train['question_body_uncased']) + list(validation['question_body_uncased']) + list(test['question_body_uncased']) +
                       list(train['answer_uncased']) + list(validation['answer_uncased']) + list(test['answer_uncased']))

# %% [markdown]
# ## Train/validation sets

# %%
# Train features
# X_train_title = train['question_title']
# X_train_body = train['question_body']
# X_train_answer = train['answer']
X_train_title_seq = train['question_title_uncased']
X_train_body_seq = train['question_body_uncased']
X_train_answer_seq = train['answer_uncased']

# Tokenize the sentences
X_train_title_seq = tokenizer.texts_to_sequences(X_train_title_seq)
X_train_body_seq = tokenizer.texts_to_sequences(X_train_body_seq)
X_train_answer_seq = tokenizer.texts_to_sequences(X_train_answer_seq)

# Pad the sentences
X_train_title_seq = pad_sequences(X_train_title_seq, maxlen=TITLE_MAX_LEN)
X_train_body_seq = pad_sequences(X_train_body_seq, maxlen=BODY_MAX_LEN)
X_train_answer_seq = pad_sequences(X_train_answer_seq, maxlen=ANSWER_MAX_LEN)


X_train = [X_train_title_seq, X_train_body_seq, X_train_answer_seq]
Y_train = train[target_cols].values

# Validation features
# X_valid_title = validation['question_title']
# X_valid_body = validation['question_body']
# X_valid_answer = validation['answer']
X_valid_title_seq = validation['question_title_uncased']
X_valid_body_seq = validation['question_body_uncased']
X_valid_answer_seq = validation['answer_uncased']

# Tokenize the sentences
X_valid_title_seq = tokenizer.texts_to_sequences(X_valid_title_seq)
X_valid_body_seq = tokenizer.texts_to_sequences(X_valid_body_seq)
X_valid_answer_seq = tokenizer.texts_to_sequences(X_valid_answer_seq)

# Pad the sentences
X_valid_title_seq = pad_sequences(X_valid_title_seq, maxlen=TITLE_MAX_LEN)
X_valid_body_seq = pad_sequences(X_valid_body_seq, maxlen=BODY_MAX_LEN)
X_valid_answer_seq = pad_sequences(X_valid_answer_seq, maxlen=ANSWER_MAX_LEN)

X_valid = [X_valid_title_seq, X_valid_body_seq, X_valid_answer_seq]
Y_valid = validation[target_cols].values


print('Train samples: %d' % len(Y_train))
print('Validation samples: %d' % len(Y_valid))
# Out:
# Train samples: 4863
# Validation samples: 1216

# %% [markdown]
# # Model

# %%
# use_embed = hub.load(module_url)

# def USEEmbedding(x):
#     return use_embed(tf.squeeze(tf.cast(x, tf.string)))

# def encoder_block(input_layer):
#     encoder = Lambda(USEEmbedding, output_shape=(EMBEDDDING_SIZE,))(input_layer)
    
#     return encoder

# %% [markdown]
# ## Load embedding

# %%
glove_embedding_matrix, glove_unknown_words = build_matrix(tokenizer.word_index, encoder_path, MAX_FEATURES)
print('n unknown words (GloVe): ', len(glove_unknown_words))
# Out:
# n unknown words (GloVe):  19913

# %%
# Title sequence
input_title_seq = Input(shape=(TITLE_MAX_LEN,), dtype=tf.float32, name='input_title_seq')
title = Embedding(*glove_embedding_matrix.shape, weights=[glove_embedding_matrix], trainable=False)(input_title_seq)
title = SpatialDropout1D(0.3)(title)
title = Bidirectional(LSTM(128))(title)
title = Dropout(0.5)(title)
title = Dense(512)(title)
title = BatchNormalization()(title)
title_out = Activation('relu')(title)

# Body sequence
input_body_seq = Input(shape=(BODY_MAX_LEN,), dtype=tf.float32, name='input_body_seq')
body = Embedding(*glove_embedding_matrix.shape, weights=[glove_embedding_matrix], trainable=False)(input_body_seq)
body = SpatialDropout1D(0.3)(body)
body = Bidirectional(LSTM(256, return_sequences=True))(body)
body = Bidirectional(LSTM(128))(body)
body = Dropout(0.5)(body)
body = Dense(512)(body)
body = BatchNormalization()(body)
body_out = Activation('relu')(body)

# Answer sequence
input_answer_seq = Input(shape=(ANSWER_MAX_LEN,), dtype=tf.float32, name='input_answer_seq')
answer = Embedding(*glove_embedding_matrix.shape, weights=[glove_embedding_matrix], trainable=False)(input_answer_seq)
answer = SpatialDropout1D(0.3)(answer)
answer = Bidirectional(LSTM(256, return_sequences=True))(answer)
answer = Bidirectional(LSTM(128))(answer)
answer = Dropout(0.5)(answer)
answer = Dense(512)(answer)
answer = BatchNormalization()(answer)
answer_out = Activation('relu')(answer)

# Output
output = Concatenate()([title_out, body_out, answer_out])
output = Dense(512)(output)
output = BatchNormalization()(output)
output = Activation('relu')(output)
output = Dropout(0.5)(output)
output = Dense(N_CLASS, activation='sigmoid')(output)
model = Model(inputs=[input_title_seq, input_body_seq, input_answer_seq], outputs=[output])

model.summary()
# Out:
# Model: "model"
# __________________________________________________________________________________________________
# Layer (type)                    Output Shape         Param #     Connected to
# ==================================================================================================
# input_body_seq (InputLayer)     [(None, 100)]        0
# __________________________________________________________________________________________________
# input_answer_seq (InputLayer)   [(None, 100)]        0
# __________________________________________________________________________________________________
# input_title_seq (InputLayer)    [(None, 30)]         0
# __________________________________________________________________________________________________
# embedding_1 (Embedding)         (None, 100, 300)     17402100    input_body_seq[0][0]
# __________________________________________________________________________________________________
# embedding_2 (Embedding)         (None, 100, 300)     17402100    input_answer_seq[0][0]
# __________________________________________________________________________________________________
# embedding (Embedding)           (None, 30, 300)      17402100    input_title_seq[0][0]
# __________________________________________________________________________________________________
# spatial_dropout1d_1 (SpatialDro (None, 100, 300)     0           embedding_1[0][0]
# __________________________________________________________________________________________________
# spatial_dropout1d_2 (SpatialDro (None, 100, 300)     0           embedding_2[0][0]
# __________________________________________________________________________________________________
# spatial_dropout1d (SpatialDropo (None, 30, 300)      0           embedding[0][0]
# __________________________________________________________________________________________________
# bidirectional_1 (Bidirectional) (None, 100, 512)     1140736     spatial_dropout1d_1[0][0]
# __________________________________________________________________________________________________
# bidirectional_3 (Bidirectional) (None, 100, 512)     1140736     spatial_dropout1d_2[0][0]
# __________________________________________________________________________________________________
# bidirectional (Bidirectional)   (None, 256)          439296      spatial_dropout1d[0][0]
# __________________________________________________________________________________________________
# bidirectional_2 (Bidirectional) (None, 256)          656384      bidirectional_1[0][0]
# __________________________________________________________________________________________________
# bidirectional_4 (Bidirectional) (None, 256)          656384      bidirectional_3[0][0]
# __________________________________________________________________________________________________
# dropout (Dropout)               (None, 256)          0           bidirectional[0][0]
# __________________________________________________________________________________________________
# dropout_1 (Dropout)             (None, 256)          0           bidirectional_2[0][0]
# __________________________________________________________________________________________________
# dropout_2 (Dropout)             (None, 256)          0           bidirectional_4[0][0]
# __________________________________________________________________________________________________
# dense (Dense)                   (None, 512)          131584      dropout[0][0]
# __________________________________________________________________________________________________
# dense_1 (Dense)                 (None, 512)          131584      dropout_1[0][0]
# __________________________________________________________________________________________________
# dense_2 (Dense)                 (None, 512)          131584      dropout_2[0][0]
# __________________________________________________________________________________________________
# batch_normalization (BatchNorma (None, 512)          2048        dense[0][0]
# __________________________________________________________________________________________________
# batch_normalization_1 (BatchNor (None, 512)          2048        dense_1[0][0]
# __________________________________________________________________________________________________
# batch_normalization_2 (BatchNor (None, 512)          2048        dense_2[0][0]
# __________________________________________________________________________________________________
# activation (Activation)         (None, 512)          0           batch_normalization[0][0]
# __________________________________________________________________________________________________
# activation_1 (Activation)       (None, 512)          0           batch_normalization_1[0][0]
# __________________________________________________________________________________________________
# activation_2 (Activation)       (None, 512)          0           batch_normalization_2[0][0]
# __________________________________________________________________________________________________
# concatenate (Concatenate)       (None, 1536)         0           activation[0][0]
#                                                                  activation_1[0][0]
#                                                                  activation_2[0][0]
# __________________________________________________________________________________________________
# dense_3 (Dense)                 (None, 512)          786944      concatenate[0][0]
# __________________________________________________________________________________________________
# batch_normalization_3 (BatchNor (None, 512)          2048        dense_3[0][0]
# __________________________________________________________________________________________________
# activation_3 (Activation)       (None, 512)          0           batch_normalization_3[0][0]
# __________________________________________________________________________________________________
# dropout_3 (Dropout)             (None, 512)          0           activation_3[0][0]
# __________________________________________________________________________________________________
# dense_4 (Dense)                 (None, 30)           15390       dropout_3[0][0]
# ==================================================================================================
# Total params: 57,445,114
# Trainable params: 5,234,718
# Non-trainable params: 52,210,396
# __________________________________________________________________________________________________

# %% [markdown]
# # Train model

# %%
rlrop = ReduceLROnPlateau(monitor='val_loss', mode='min', patience=RLROP_PATIENCE, factor=DECAY_DROP, min_lr=1e-7, verbose=1)
spearmanCallback = SpearmanRhoCallback(training_data=(X_train, Y_train), validation_data=(X_valid, Y_valid), monitor='val_loss', mode='min', patience=ES_PATIENCE)
callback_list = [rlrop, spearmanCallback]

optimizer = optimizers.Adam(LEARNING_RATE)
model.compile(optimizer=optimizer, loss='binary_crossentropy')

history = model.fit(X_train, Y_train, 
                    validation_data=(X_valid, Y_valid), 
                    callbacks=callback_list, 
                    batch_size=BATCH_SIZE, 
                    epochs=EPOCHS, 
                    verbose=2).history
# Out:
# Train on 4863 samples, validate on 1216 samples
# Epoch 1/50
# spearman-rho: 0.2100 val_spearman-rho: 0.2009
# 4863/4863 - 268s - loss: 0.5145 - val_loss: 0.4605
# Epoch 2/50
# spearman-rho: 0.2617 val_spearman-rho: 0.2396
# 4863/4863 - 246s - loss: 0.4425 - val_loss: 0.4116
# Epoch 3/50
# spearman-rho: 0.3074 val_spearman-rho: 0.2798
# 4863/4863 - 244s - loss: 0.4219 - val_loss: 0.4005
# Epoch 4/50
# spearman-rho: 0.3270 val_spearman-rho: 0.2935
# 4863/4863 - 245s - loss: 0.4083 - val_loss: 0.3967
# Epoch 5/50
# spearman-rho: 0.3487 val_spearman-rho: 0.3166
# 4863/4863 - 245s - loss: 0.3996 - val_loss: 0.3940
# Epoch 6/50
# spearman-rho: 0.3638 val_spearman-rho: 0.3190
# 4863/4863 - 244s - loss: 0.3938 - val_loss: 0.3917
# Epoch 7/50
# spearman-rho: 0.3763 val_spearman-rho: 0.3208
# 4863/4863 - 244s - loss: 0.3894 - val_loss: 0.3960
# Epoch 8/50
# spearman-rho: 0.3818 val_spearman-rho: 0.3172
# 4863/4863 - 244s - loss: 0.3850 - val_loss: 0.3940
# Epoch 9/50
# spearman-rho: 0.3981 val_spearman-rho: 0.3236
# 4863/4863 - 244s - loss: 0.3824 - val_loss: 0.3887
# Epoch 10/50
# spearman-rho: 0.4071 val_spearman-rho: 0.3358
# 4863/4863 - 244s - loss: 0.3798 - val_loss: 0.3897
# Epoch 11/50
# spearman-rho: 0.4210 val_spearman-rho: 0.3385
# 4863/4863 - 243s - loss: 0.3763 - val_loss: 0.3899
# Epoch 12/50
#
# Epoch 00012: ReduceLROnPlateau reducing learning rate to 0.00010000000474974513.
# spearman-rho: 0.4322 val_spearman-rho: 0.3424
# 4863/4863 - 244s - loss: 0.3737 - val_loss: 0.3906
# Epoch 13/50
# spearman-rho: 0.4434 val_spearman-rho: 0.3475
# 4863/4863 - 244s - loss: 0.3679 - val_loss: 0.3879
# Epoch 14/50
# spearman-rho: 0.4472 val_spearman-rho: 0.3474
# 4863/4863 - 245s - loss: 0.3649 - val_loss: 0.3875
# Epoch 15/50
# spearman-rho: 0.4503 val_spearman-rho: 0.3458
# 4863/4863 - 244s - loss: 0.3640 - val_loss: 0.3889
# Epoch 16/50
# spearman-rho: 0.4554 val_spearman-rho: 0.3484
# 4863/4863 - 244s - loss: 0.3638 - val_loss: 0.3887
# Epoch 17/50
#
# Epoch 00017: ReduceLROnPlateau reducing learning rate to 1.0000000474974514e-05.
# spearman-rho: 0.4575 val_spearman-rho: 0.3484
# Epoch 00016: early stopping
# 4863/4863 - 245s - loss: 0.3623 - val_loss: 0.3896

# %% [markdown]
# ## Model loss graph

# %%
sns.set(style="whitegrid")
plot_metrics(history, metric_list=['loss', 'spearman'])

# %% [markdown]
# # Evaluation

# %%
preds_train = model.predict(X_train)
preds_val = model.predict(X_valid)

display(get_metrics(Y_train, preds_train, Y_valid, preds_val, target_cols).style.applymap(color_map))
# Out:
# <style  type="text/css" >
#     #T_96617132_2cbf_11ea_8f8d_fbc453a300f7row0_col0 {
#             color:  black;
#         }    #T_96617132_2cbf_11ea_8f8d_fbc453a300f7row0_col1 {
#             color:  black;
#         }    #T_96617132_2cbf_11ea_8f8d_fbc453a300f7row0_col2 {
#             color:  black;
#         }    #T_96617132_2cbf_11ea_8f8d_fbc453a300f7row1_col0 {
#             color:  black;
#         }    #T_96617132_2cbf_11ea_8f8d_fbc453a300f7row1_col1 {
#             color:  black;
#         }    #T_96617132_2cbf_11ea_8f8d_fbc453a300f7row1_col2 {
#             color:  black;
#         }    #T_96617132_2cbf_11ea_8f8d_fbc453a300f7row2_col0 {
#             color:  black;
#         }    #T_96617132_2cbf_11ea_8f8d_fbc453a300f7row2_col1 {
#             color:  black;
#         }    #T_96617132_2cbf_11ea_8f8d_fbc453a300f7row2_col2 {
#             color:  black;
#         }    #T_96617132_2cbf_11ea_8f8d_fbc453a300f7row3_col0 {
#             color:  black;
#         }    #T_96617132_2cbf_11ea_8f8d_fbc453a300f7row3_col1 {
#             color:  black;
#         }    #T_96617132_2cbf_11ea_8f8d_fbc453a300f7row3_col2 {
#             color:  black;
#         }    #T_96617132_2cbf_11ea_8f8d_fbc453a300f7row4_col0 {
#             color:  black;
#         }    #T_96617132_2cbf_11ea_8f8d_fbc453a300f7row4_col1 {
#             color:  black;
#         }    #T_96617132_2cbf_11ea_8f8d_fbc453a300f7row4_col2 {
#             color:  orange;
#         }    #T_96617132_2cbf_11ea_8f8d_fbc453a300f7row5_col0 {
#             color:  black;
#         }    #T_96617132_2cbf_11ea_8f8d_fbc453a300f7row5_col1 {
#             color:  black;
#         }    #T_96617132_2cbf_11ea_8f8d_fbc453a300f7row5_col2 {
#             color:  orange;
#         }    #T_96617132_2cbf_11ea_8f8d_fbc453a300f7row6_col0 {
#             color:  black;
#         }    #T_96617132_2cbf_11ea_8f8d_fbc453a300f7row6_col1 {
#             color:  black;
#         }    #T_96617132_2cbf_11ea_8f8d_fbc453a300f7row6_col2 {
#             color:  black;
#         }    #T_96617132_2cbf_11ea_8f8d_fbc453a300f7row7_col0 {
#             color:  black;
#         }    #T_96617132_2cbf_11ea_8f8d_fbc453a300f7row7_col1 {
#             color:  black;
#         }    #T_96617132_2cbf_11ea_8f8d_fbc453a300f7row7_col2 {
#             color:  black;
#         }    #T_96617132_2cbf_11ea_8f8d_fbc453a300f7row8_col0 {
#             color:  black;
#         }    #T_96617132_2cbf_11ea_8f8d_fbc453a300f7row8_col1 {
#             color:  black;
#         }    #T_96617132_2cbf_11ea_8f8d_fbc453a300f7row8_col2 {
#             color:  black;
#         }    #T_96617132_2cbf_11ea_8f8d_fbc453a300f7row9_col0 {
#             color:  black;
#         }    #T_96617132_2cbf_11ea_8f8d_fbc453a300f7row9_col1 {
#             color:  black;
#         }    #T_96617132_2cbf_11ea_8f8d_fbc453a300f7row9_col2 {
#             color:  black;
#         }    #T_96617132_2cbf_11ea_8f8d_fbc453a300f7row10_col0 {
#             color:  black;
#         }    #T_96617132_2cbf_11ea_8f8d_fbc453a300f7row10_col1 {
#             color:  orange;
#         }    #T_96617132_2cbf_11ea_8f8d_fbc453a300f7row10_col2 {
#             color:  purple;
#         }    #T_96617132_2cbf_11ea_8f8d_fbc453a300f7row11_col0 {
#             color:  black;
#         }    #T_96617132_2cbf_11ea_8f8d_fbc453a300f7row11_col1 {
#             color:  black;
#         }    #T_96617132_2cbf_11ea_8f8d_fbc453a300f7row11_col2 {
#             color:  black;
#         }    #T_96617132_2cbf_11ea_8f8d_fbc453a300f7row12_col0 {
#             color:  black;
#         }    #T_96617132_2cbf_11ea_8f8d_fbc453a300f7row12_col1 {
#             color:  black;
#         }    #T_96617132_2cbf_11ea_8f8d_fbc453a300f7row12_col2 {
#             color:  black;
#         }    #T_96617132_2cbf_11ea_8f8d_fbc453a300f7row13_col0 {
#             color:  black;
#         }    #T_96617132_2cbf_11ea_8f8d_fbc453a300f7row13_col1 {
#             color:  black;
#         }    #T_96617132_2cbf_11ea_8f8d_fbc453a300f7row13_col2 {
#             color:  orange;
#         }    #T_96617132_2cbf_11ea_8f8d_fbc453a300f7row14_col0 {
#             color:  black;
#         }    #T_96617132_2cbf_11ea_8f8d_fbc453a300f7row14_col1 {
#             color:  orange;
#         }    #T_96617132_2cbf_11ea_8f8d_fbc453a300f7row14_col2 {
#             color:  orange;
#         }    #T_96617132_2cbf_11ea_8f8d_fbc453a300f7row15_col0 {
#             color:  black;
#         }    #T_96617132_2cbf_11ea_8f8d_fbc453a300f7row15_col1 {
#             color:  black;
#         }    #T_96617132_2cbf_11ea_8f8d_fbc453a300f7row15_col2 {
#             color:  orange;
#         }    #T_96617132_2cbf_11ea_8f8d_fbc453a300f7row16_col0 {
#             color:  black;
#         }    #T_96617132_2cbf_11ea_8f8d_fbc453a300f7row16_col1 {
#             color:  black;
#         }    #T_96617132_2cbf_11ea_8f8d_fbc453a300f7row16_col2 {
#             color:  black;
#         }    #T_96617132_2cbf_11ea_8f8d_fbc453a300f7row17_col0 {
#             color:  black;
#         }    #T_96617132_2cbf_11ea_8f8d_fbc453a300f7row17_col1 {
#             color:  green;
#         }    #T_96617132_2cbf_11ea_8f8d_fbc453a300f7row17_col2 {
#             color:  black;
#         }    #T_96617132_2cbf_11ea_8f8d_fbc453a300f7row18_col0 {
#             color:  black;
#         }    #T_96617132_2cbf_11ea_8f8d_fbc453a300f7row18_col1 {
#             color:  black;
#         }    #T_96617132_2cbf_11ea_8f8d_fbc453a300f7row18_col2 {
#             color:  orange;
#         }    #T_96617132_2cbf_11ea_8f8d_fbc453a300f7row19_col0 {
#             color:  black;
#         }    #T_96617132_2cbf_11ea_8f8d_fbc453a300f7row19_col1 {
#             color:  black;
#         }    #T_96617132_2cbf_11ea_8f8d_fbc453a300f7row19_col2 {
#             color:  black;
#         }    #T_96617132_2cbf_11ea_8f8d_fbc453a300f7row20_col0 {
#             color:  black;
#         }    #T_96617132_2cbf_11ea_8f8d_fbc453a300f7row20_col1 {
#             color:  purple;
#         }    #T_96617132_2cbf_11ea_8f8d_fbc453a300f7row20_col2 {
#             color:  purple;
#         }    #T_96617132_2cbf_11ea_8f8d_fbc453a300f7row21_col0 {
#             color:  black;
#         }    #T_96617132_2cbf_11ea_8f8d_fbc453a300f7row21_col1 {
#             color:  black;
#         }    #T_96617132_2cbf_11ea_8f8d_fbc453a300f7row21_col2 {
#             color:  black;
#         }    #T_96617132_2cbf_11ea_8f8d_fbc453a300f7row22_col0 {
#             color:  black;
#         }    #T_96617132_2cbf_11ea_8f8d_fbc453a300f7row22_col1 {
#             color:  orange;
#         }    #T_96617132_2cbf_11ea_8f8d_fbc453a300f7row22_col2 {
#             color:  orange;
#         }    #T_96617132_2cbf_11ea_8f8d_fbc453a300f7row23_col0 {
#             color:  black;
#         }    #T_96617132_2cbf_11ea_8f8d_fbc453a300f7row23_col1 {
#             color:  black;
#         }    #T_96617132_2cbf_11ea_8f8d_fbc453a300f7row23_col2 {
#             color:  black;
#         }    #T_96617132_2cbf_11ea_8f8d_fbc453a300f7row24_col0 {
#             color:  black;
#         }    #T_96617132_2cbf_11ea_8f8d_fbc453a300f7row24_col1 {
#             color:  orange;
#         }    #T_96617132_2cbf_11ea_8f8d_fbc453a300f7row24_col2 {
#             color:  orange;
#         }    #T_96617132_2cbf_11ea_8f8d_fbc453a300f7row25_col0 {
#             color:  black;
#         }    #T_96617132_2cbf_11ea_8f8d_fbc453a300f7row25_col1 {
#             color:  orange;
#         }    #T_96617132_2cbf_11ea_8f8d_fbc453a300f7row25_col2 {
#             color:  orange;
#         }    #T_96617132_2cbf_11ea_8f8d_fbc453a300f7row26_col0 {
#             color:  black;
#         }    #T_96617132_2cbf_11ea_8f8d_fbc453a300f7row26_col1 {
#             color:  black;
#         }    #T_96617132_2cbf_11ea_8f8d_fbc453a300f7row26_col2 {
#             color:  orange;
#         }    #T_96617132_2cbf_11ea_8f8d_fbc453a300f7row27_col0 {
#             color:  black;
#         }    #T_96617132_2cbf_11ea_8f8d_fbc453a300f7row27_col1 {
#             color:  green;
#         }    #T_96617132_2cbf_11ea_8f8d_fbc453a300f7row27_col2 {
#             color:  black;
#         }    #T_96617132_2cbf_11ea_8f8d_fbc453a300f7row28_col0 {
#             color:  black;
#         }    #T_96617132_2cbf_11ea_8f8d_fbc453a300f7row28_col1 {
#             color:  black;
#         }    #T_96617132_2cbf_11ea_8f8d_fbc453a300f7row28_col2 {
#             color:

# %% [markdown]
# ## By category

# %%
target_cols_preds = [col+'_pred' for col in target_cols]
for col in target_cols_preds:
    train[col] = 0
    validation[col] = 0
    
train[target_cols_preds] = preds_train
validation[target_cols_preds] = preds_val
    
display(get_metrics_category(train, validation, target_cols, target_cols_preds, 'category').style.applymap(color_map))
# Out:
# <style  type="text/css" >
#     #T_96bba06c_2cbf_11ea_8f8d_fbc453a300f7row0_col0 {
#             color:  black;
#         }    #T_96bba06c_2cbf_11ea_8f8d_fbc453a300f7row0_col1 {
#             color:  black;
#         }    #T_96bba06c_2cbf_11ea_8f8d_fbc453a300f7row0_col2 {
#             color:  black;
#         }    #T_96bba06c_2cbf_11ea_8f8d_fbc453a300f7row0_col3 {
#             color:  black;
#         }    #T_96bba06c_2cbf_11ea_8f8d_fbc453a300f7row0_col4 {
#             color:  black;
#         }    #T_96bba06c_2cbf_11ea_8f8d_fbc453a300f7row0_col5 {
#             color:  black;
#         }    #T_96bba06c_2cbf_11ea_8f8d_fbc453a300f7row0_col6 {
#             color:  orange;
#         }    #T_96bba06c_2cbf_11ea_8f8d_fbc453a300f7row0_col7 {
#             color:  black;
#         }    #T_96bba06c_2cbf_11ea_8f8d_fbc453a300f7row0_col8 {
#             color:  black;
#         }    #T_96bba06c_2cbf_11ea_8f8d_fbc453a300f7row0_col9 {
#             color:  black;
#         }    #T_96bba06c_2cbf_11ea_8f8d_fbc453a300f7row0_col10 {
#             color:  black;
#         }</style><table id="T_96bba06c_2cbf_11ea_8f8d_fbc453a300f7" ><thead>    <tr>        <th class="blank level0" ></th>        <th class="col_heading level0 col0" >Label</th>        <th class="col_heading level0 col1" >Train (TECHNOLOGY)</th>        <th class="col_heading level0 col2" >Validation (TECHNOLOGY)</th>        <th class="col_heading level0 col3" >Train (SCIENCE)</th>        <th class="col_heading level0 col4" >Validation (SCIENCE)</th>        <th class="col_heading level0 col5" >Train (STACKOVERFLOW)</th>        <th class="col_heading level0 col6" >Validation (STACKOVERFLOW)</th>        <th class="col_heading level0 col7" >Train (LIFE_ARTS)</th>        <th class="col_heading level0 col8" >Validation (LIFE_ARTS)</th>        <th class="col_heading level0 col9" >Train (CULTURE)</th>        <th class="col_heading level0 col10" >Validation (CULTURE)</th>    </tr></thead><tbody>
#                 <tr>
#                         <th id="T_96bba06c_2cbf_11ea_8f8d_fbc453a300f7level0_row0" class="row_heading level0 row0" >0</th>
#                         <td id="T_96bba06c_2cbf_11ea_8f8d_fbc453a300f7row0_col0" class="data row0 col0" >Averaged</td>
#                         <td id="T_96bba06c_2cbf_11ea_8f8d_fbc453a300f7row0_col1" class="data row0 col1" >0.424</td>
#                         <td id="T_96bba06c_2cbf_11ea_8f8d_fbc453a300f7row0_col2" class="data row0 col2" >0.317</td>
#                         <td id="T_96bba06c_2cbf_11ea_8f8d_fbc453a300f7row0_col3" class="data row0 col3" >0.478</td>
#                         <td id="T_96bba06c_2cbf_11ea_8f8d_fbc453a300f7row0_col4" class="data row0 col4" >0.327</td>
#                         <td id="T_96bba06c_2cbf_11ea_8f8d_fbc453a300f7row0_col5" class="data row0 col5" >0.353</td>
#                         <td id="T_96bba06c_2cbf_11ea_8f8d_fbc453a300f7row0_col6" class="data row0 col6" >0.193</td>
#                         <td id="T_96bba06c_2cbf_11ea_8f8d_fbc453a300f7row0_col7" class="data row0 col7" >0.466</td>
#                         <td id="T_96bba06c_2cbf_11ea_8f8d_fbc453a300f7row0_col8" class="data row0 col8" >0.357</td>
#                         <td id="T_96bba06c_2cbf_11ea_8f8d_fbc453a300f7row0_col9" class="data row0 col9" >0.46</td>
#                         <td id="T_96bba06c_2cbf_11ea_8f8d_fbc453a300f7row0_col10" class="data row0 col10" >0.34</td>
#             </tr>
#     </tbody></table>

# %% [markdown]
# #### Save model weights and ecoders

# %%
model.save_weights(model_path)
dump(tokenizer, tokenizer_path)
# Out:
# ['/kaggle/working/tokenizer.joblib']
