# %% [markdown]
# ## Dependencies

# %%
import warnings
import pandas as pd
import seaborn as sns
import tensorflow_hub as hub
import matplotlib.pyplot as plt
from tensorflow.keras import Model, optimizers
from tensorflow.keras.layers import Lambda, Input, Dense, Dropout, Concatenate, BatchNormalization, Activation
from tensorflow.keras.callbacks import EarlyStopping, ReduceLROnPlateau
from googleqa_utilityscript import *


SEED = 0
seed_everything(SEED)
warnings.filterwarnings("ignore")

# %% [markdown]
# ## Load data

# %%
hold_out = pd.read_csv('/kaggle/input/googleqa-mldataset/hold-out.csv')
train = hold_out[hold_out['set'] == 'train']
validation = hold_out[hold_out['set'] == 'validation']
test = pd.read_csv('/kaggle/input/google-quest-challenge/test.csv')

print('Train samples: %s' % len(train))
print('Validation samples: %s' % len(validation))
print('Test samples: %s' % len(test))
display(train.head())
# Out:
# Train samples: 4863
# Validation samples: 1216
# Test samples: 476
#    qa_id                                     question_title  \
# 0   3895  Magento (1.7) Bundled Product with FREE Produc...
# 1   3131                             Find router on network
# 2   1507  Negatively curved metrics minimizing the lengt...
# 3   6784               Isn’t the FAQ label obsolete by now?
# 4   2135  Changing background image one time on responsi...
#
#                                        question_body question_user_name  \
# 0  I'm looking to create a bundle offer where cus...                Joe
# 1  I've just bought a Belkin N+ Wireless Router. ...                Guy
# 2  Good afternoon everyone !\n\nI have the follow...            Selim G
# 3  Don’t get me wrong in the beginning of reading...     Benny Skogberg
# 4  The code I'm using is this one \n\nbackground:...        user2141649
#
#                               question_user_page  \
# 0  https://magento.stackexchange.com/users/16572
# 1               https://superuser.com/users/3248
# 2           https://mathoverflow.net/users/25511
# 3        https://ux.stackexchange.com/users/4679
# 4        https://stackoverflow.com/users/2141649
#
#                                               answer   answer_user_name  \
# 0  Since the third item is fixed, you can use sho...  Fabian Schmengler
# 1  You likely have the router plugged in to the m...             John T
# 2  A very partial answer: by the results of Richa...         Igor Rivin
# 3  Isn’t the FAQ label obsolete by now? \n\nI'd s...        Solracnapod
# 4  &lt;!DOCTYPE html&gt;\n&lt;html&gt;\n&lt;head&...           akkimads
#
#                               answer_user_page  \
# 0  https://magento.stackexchange.com/users/243
# 1             https://superuser.com/users/1931
# 2         https://mathoverflow.net/users/11142
# 3     https://ux.stackexchange.com/users/13153
# 4      https://stackoverflow.com/users/2375373
#
#                                                  url       category  ...  \
# 0  http://magento.stackexchange.com/questions/668...     TECHNOLOGY  ...
# 1               http://superuser.com/questions/87212     TECHNOLOGY  ...
# 2           http://mathoverflow.net/questions/203422        SCIENCE  ...
# 3  http://ux.stackexchange.com/questions/18600/is...     TECHNOLOGY  ...
# 4  http://stackoverflow.com/questions/16359492/ch...  STACKOVERFLOW  ...
#
#   answer_helpful  answer_level_of_information  answer_plausible  \
# 0       0.888889                     0.666667               1.0
# 1       1.000000                     0.666667               1.0
# 2       0.888889                     0.333333               1.0
# 3       0.888889                     0.666667               1.0
# 4       0.888889                     0.500000               1.0
#
#    answer_relevance  answer_satisfaction  answer_type_instructions  \
# 0               1.0             0.933333                  1.000000
# 1               1.0             0.866667                  0.666667
# 2               1.0             0.700000                  0.333333
# 3               1.0             0.933333                  0.000000
# 4               1.0             0.800000                  1.000000
#
#    answer_type_procedure  answer_type_reason_explanation  answer_well_written  \
# 0               0.000000                        0.333333             0.888889
# 1               0.000000                        1.000000             1.000000
# 2               0.333333                        1.000000             0.888889
# 3               0.000000                        0.666667             1.000000
# 4               0.000000                        0.000000             0.777778
#
#      set
# 0  train
# 1  train
# 2  train
# 3  train
# 4  train
#
# [5 rows x 42 columns]

# %%
question_target_cols = ['question_asker_intent_understanding','question_body_critical', 'question_conversational', 
                        'question_expect_short_answer', 'question_fact_seeking', 'question_has_commonly_accepted_answer',
                        'question_interestingness_others', 'question_interestingness_self', 'question_multi_intent', 
                        'question_not_really_a_question', 'question_opinion_seeking', 'question_type_choice',
                        'question_type_compare', 'question_type_consequence', 'question_type_definition', 
                        'question_type_entity', 'question_type_instructions', 'question_type_procedure',
                        'question_type_reason_explanation', 'question_type_spelling', 'question_well_written']
answer_target_cols = ['answer_helpful', 'answer_level_of_information', 'answer_plausible', 'answer_relevance',
                      'answer_satisfaction', 'answer_type_instructions', 'answer_type_procedure', 
                      'answer_type_reason_explanation', 'answer_well_written']
target_cols = question_target_cols + answer_target_cols

# %% [markdown]
# ## Train/validation sets

# %%
# Train features
X_train_title = train['question_title']
X_train_body = train['question_body']
X_train_answer = train['answer']

X_train = [X_train_title, X_train_body, X_train_answer]
Y_train = train[target_cols].values

# Validation features
X_valid_title = validation['question_title']
X_valid_body = validation['question_body']
X_valid_answer = validation['answer']

X_valid = [X_valid_title, X_valid_body, X_valid_answer]
Y_valid = validation[target_cols].values

print('Train samples: %d' % len(Y_train))
print('Validation samples: %d' % len(Y_valid))
# Out:
# Train samples: 4863
# Validation samples: 1216

# %% [markdown]
# # Model parameters

# %%
EPOCHS = 30
BATCH_SIZE = 32
LEARNING_RATE = 3e-4
EMBEDDDING_SIZE = 512
N_CLASS = len(target_cols)
ES_PATIENCE = 3
RLROP_PATIENCE = 2
DECAY_DROP = 0.5
module_url = '../input/universalsentenceencodermodels/universal-sentence-encoder-models/use-large'
model_path = '../working/use_baseline.h5'

# %% [markdown]
# # Model

# %%
es = EarlyStopping(monitor='val_loss', mode='min', patience=ES_PATIENCE, restore_best_weights=True, verbose=1)
rlrop = ReduceLROnPlateau(monitor='val_loss', mode='min', patience=RLROP_PATIENCE, factor=DECAY_DROP, min_lr=1e-6, verbose=1)
use_embed = hub.load(module_url)

def USEEmbedding(x):
    return use_embed(tf.squeeze(tf.cast(x, tf.string)))

# %%
input_title = Input(shape=(1,), dtype=tf.string, name='input_title')
embedding_title = Lambda(USEEmbedding, output_shape=(EMBEDDDING_SIZE,))(input_title)

input_body = Input(shape=(1,), dtype=tf.string, name='input_body')
embedding_body = Lambda(USEEmbedding, output_shape=(EMBEDDDING_SIZE,))(input_body)

input_answer = Input(shape=(1,), dtype=tf.string, name='input_answer')
embedding_answer = Lambda(USEEmbedding, output_shape=(EMBEDDDING_SIZE,))(input_answer)

x = Concatenate()([embedding_title, embedding_body, embedding_answer])
x = Dropout(0.5)(x)
x = Dense(512, activation='relu')(x)
x = Dropout(0.5)(x)
output = Dense(N_CLASS, activation='sigmoid', name='output')(x)
model = Model(inputs=[input_title, input_body, input_answer], outputs=[output])

model.summary()
# Out:
# Model: "model"
# __________________________________________________________________________________________________
# Layer (type)                    Output Shape         Param #     Connected to
# ==================================================================================================
# input_title (InputLayer)        [(None, 1)]          0
# __________________________________________________________________________________________________
# input_body (InputLayer)         [(None, 1)]          0
# __________________________________________________________________________________________________
# input_answer (InputLayer)       [(None, 1)]          0
# __________________________________________________________________________________________________
# lambda (Lambda)                 (None, 512)          0           input_title[0][0]
# __________________________________________________________________________________________________
# lambda_1 (Lambda)               (None, 512)          0           input_body[0][0]
# __________________________________________________________________________________________________
# lambda_2 (Lambda)               (None, 512)          0           input_answer[0][0]
# __________________________________________________________________________________________________
# concatenate (Concatenate)       (None, 1536)         0           lambda[0][0]
#                                                                  lambda_1[0][0]
#                                                                  lambda_2[0][0]
# __________________________________________________________________________________________________
# dropout (Dropout)               (None, 1536)         0           concatenate[0][0]
# __________________________________________________________________________________________________
# dense (Dense)                   (None, 512)          786944      dropout[0][0]
# __________________________________________________________________________________________________
# dropout_1 (Dropout)             (None, 512)          0           dense[0][0]
# __________________________________________________________________________________________________
# output (Dense)                  (None, 30)           15390       dropout_1[0][0]
# ==================================================================================================
# Total params: 802,334
# Trainable params: 802,334
# Non-trainable params: 0
# __________________________________________________________________________________________________

# %% [markdown]
# # Train model

# %%
optimizer = optimizers.Adam(LEARNING_RATE)
callback_list = [es, rlrop, SpearmanRhoCallback(training_data=(X_train, Y_train), validation_data=(X_valid, Y_valid))]
model.compile(optimizer=optimizer, loss='binary_crossentropy')

history = model.fit(X_train, Y_train, 
                    validation_data=(X_valid, Y_valid), 
                    callbacks=callback_list, 
                    batch_size=BATCH_SIZE,
                    epochs=EPOCHS, 
                    verbose=2).history
# Out:
# Train on 4863 samples, validate on 1216 samples
# Epoch 1/30
# Train spearman-rho: 0.2291 Validation spearman-rho: 0.2120
# 4863/4863 - 242s - loss: 0.5023 - val_loss: 0.4143
# Epoch 2/30
# Train spearman-rho: 0.3060 Validation spearman-rho: 0.2847
# 4863/4863 - 121s - loss: 0.4059 - val_loss: 0.3965
# Epoch 3/30
# Train spearman-rho: 0.3478 Validation spearman-rho: 0.3217
# 4863/4863 - 121s - loss: 0.3936 - val_loss: 0.3886
# Epoch 4/30
# Train spearman-rho: 0.3718 Validation spearman-rho: 0.3386
# 4863/4863 - 121s - loss: 0.3865 - val_loss: 0.3842
# Epoch 5/30
# Train spearman-rho: 0.3887 Validation spearman-rho: 0.3489
# 4863/4863 - 121s - loss: 0.3823 - val_loss: 0.3813
# Epoch 6/30
# Train spearman-rho: 0.4007 Validation spearman-rho: 0.3549
# 4863/4863 - 123s - loss: 0.3786 - val_loss: 0.3793
# Epoch 7/30
# Train spearman-rho: 0.4111 Validation spearman-rho: 0.3607
# 4863/4863 - 123s - loss: 0.3767 - val_loss: 0.3778
# Epoch 8/30
# Train spearman-rho: 0.4195 Validation spearman-rho: 0.3648
# 4863/4863 - 122s - loss: 0.3745 - val_loss: 0.3765
# Epoch 9/30
# Train spearman-rho: 0.4272 Validation spearman-rho: 0.3680
# 4863/4863 - 123s - loss: 0.3723 - val_loss: 0.3759
# Epoch 10/30
# Train spearman-rho: 0.4335 Validation spearman-rho: 0.3700
# 4863/4863 - 124s - loss: 0.3709 - val_loss: 0.3750
# Epoch 11/30
# Train spearman-rho: 0.4400 Validation spearman-rho: 0.3722
# 4863/4863 - 123s - loss: 0.3702 - val_loss: 0.3747
# Epoch 12/30
# Train spearman-rho: 0.4449 Validation spearman-rho: 0.3739
# 4863/4863 - 123s - loss: 0.3688 - val_loss: 0.3743
# Epoch 13/30
# Train spearman-rho: 0.4498 Validation spearman-rho: 0.3758
# 4863/4863 - 123s - loss: 0.3681 - val_loss: 0.3739
# Epoch 14/30
# Train spearman-rho: 0.4537 Validation spearman-rho: 0.3777
# 4863/4863 - 123s - loss: 0.3665 - val_loss: 0.3737
# Epoch 15/30
# Train spearman-rho: 0.4578 Validation spearman-rho: 0.3785
# 4863/4863 - 122s - loss: 0.3661 - val_loss: 0.3734
# Epoch 16/30
# Train spearman-rho: 0.4615 Validation spearman-rho: 0.3784
# 4863/4863 - 121s - loss: 0.3653 - val_loss: 0.3733
# Epoch 17/30
# Train spearman-rho: 0.4652 Validation spearman-rho: 0.3802
# 4863/4863 - 121s - loss: 0.3645 - val_loss: 0.3730
# Epoch 18/30
# Train spearman-rho: 0.4688 Validation spearman-rho: 0.3812
# 4863/4863 - 121s - loss: 0.3636 - val_loss: 0.3725
# Epoch 19/30
# Train spearman-rho: 0.4721 Validation spearman-rho: 0.3815
# 4863/4863 - 121s - loss: 0.3629 - val_loss: 0.3727
# Epoch 20/30
#
# Epoch 00020: ReduceLROnPlateau reducing learning rate to 0.0001500000071246177.
# Train spearman-rho: 0.4749 Validation spearman-rho: 0.3815
# 4863/4863 - 119s - loss: 0.3624 - val_loss: 0.3725
# Epoch 21/30
# Train spearman-rho: 0.4768 Validation spearman-rho: 0.3822
# 4863/4863 - 119s - loss: 0.3614 - val_loss: 0.3724
# Epoch 22/30
# Train spearman-rho: 0.4787 Validation spearman-rho: 0.3825
# 4863/4863 - 121s - loss: 0.3612 - val_loss: 0.3724
# Epoch 23/30
#
# Epoch 00023: ReduceLROnPlateau reducing learning rate to 7.500000356230885e-05.
# Train spearman-rho: 0.4802 Validation spearman-rho: 0.3830
# 4863/4863 - 121s - loss: 0.3605 - val_loss: 0.3723
# Epoch 24/30
# Train spearman-rho: 0.4811 Validation spearman-rho: 0.3833
# 4863/4863 - 122s - loss: 0.3602 - val_loss: 0.3722
# Epoch 25/30
# Train spearman-rho: 0.4819 Validation spearman-rho: 0.3834
# 4863/4863 - 121s - loss: 0.3601 - val_loss: 0.3722
# Epoch 26/30
#
# Epoch 00026: ReduceLROnPlateau reducing learning rate to 3.7500001781154424e-05.
# Train spearman-rho: 0.4827 Validation spearman-rho: 0.3834
# 4863/4863 - 121s - loss: 0.3594 - val_loss: 0.3721
# Epoch 27/30
# Train spearman-rho: 0.4832 Validation spearman-rho: 0.3835
# 4863/4863 - 121s - loss: 0.3595 - val_loss: 0.3721
# Epoch 28/30
#
# Epoch 00028: ReduceLROnPlateau reducing learning rate to 1.8750000890577212e-05.
# Train spearman-rho: 0.4836 Validation spearman-rho: 0.3836
# 4863/4863 - 120s - loss: 0.3595 - val_loss: 0.3721
# Epoch 29/30
# Train spearman-rho: 0.4838 Validation spearman-rho: 0.3836
# 4863/4863 - 120s - loss: 0.3594 - val_loss: 0.3721
# Epoch 30/30
# Train spearman-rho: 0.4840 Validation spearman-rho: 0.3837
# 4863/4863 - 120s - loss: 0.3591 - val_loss: 0.3721

# %% [markdown]
# #### Save model

# %%
model.save_weights(model_path)

# %% [markdown]
# # Evaluation

# %%
preds_train = model.predict(X_train)
preds_val = model.predict(X_valid)

rho_train = np.mean([spearmanr(Y_train[:, ind], preds_train[:, ind] + np.random.normal(0, 1e-7, preds_train.shape[0])).correlation for ind in range(preds_train.shape[1])])
rho_val = np.mean([spearmanr(Y_valid[:, ind], preds_val[:, ind] + np.random.normal(0, 1e-7, preds_val.shape[0])).correlation for ind in range(preds_val.shape[1])])

print('Train spearman-rho: %.3f' % rho_train)
print('Validation spearman-rho: %.3f' % rho_val)
# Out:
# Train spearman-rho: 0.484
# Validation spearman-rho: 0.384

# %% [markdown]
# # Make predictions on test

# %%
# Test features
X_test_title = test['question_title']
X_test_body = test['question_body']
X_test_answer = test['answer']

X_test = [X_test_title, X_test_body, X_test_answer]
Y_test = model.predict(X_test)

# %%
submission = pd.read_csv('/kaggle/input/google-quest-challenge/sample_submission.csv')
submission[target_cols] = Y_test
submission.to_csv("submission.csv", index=False)
display(submission.head())
# Out:
#    qa_id  question_asker_intent_understanding  question_body_critical  \
# 0     39                             0.888177                0.654442
# 1     46                             0.868677                0.557742
# 2     70                             0.889314                0.617216
# 3    132                             0.828298                0.392723
# 4    200                             0.946821                0.551243
#
#    question_conversational  question_expect_short_answer  \
# 0                 0.230307                      0.745179
# 1                 0.001968                      0.685741
# 2                 0.011346                      0.720350
# 3                 0.015719                      0.625471
# 4                 0.014924                      0.845100
#
#    question_fact_seeking  question_has_commonly_accepted_answer  \
# 0               0.557589                               0.768143
# 1               0.855667                               0.939134
# 2               0.895651                               0.926411
# 3               0.797594                               0.851074
# 4               0.831539                               0.893641
#
#    question_interestingness_others  question_interestingness_self  \
# 0                         0.585011                       0.525256
# 1                         0.556498                       0.454235
# 2                         0.582276                       0.474247
# 3                         0.544889                       0.443005
# 4                         0.628436                       0.613207
#
#    question_multi_intent  ...  question_well_written  answer_helpful  \
# 0               0.206688  ...               0.871539        0.914332
# 1               0.129466  ...               0.734619        0.926880
# 2               0.386285  ...               0.838836        0.926802
# 3               0.429764  ...               0.707652        0.934123
# 4               0.354283  ...               0.831797        0.949669
#
#    answer_level_of_information  answer_plausible  answer_relevance  \
# 0                     0.635211          0.954251          0.967398
# 1                     0.601759          0.961247          0.959278
# 2                     0.623468          0.967598          0.967979
# 3                     0.674723          0.955687          0.970821
# 4                     0.663301          0.977453          0.975294
#
#    answer_satisfaction  answer_type_instructions  answer_type_procedure  \
# 0             0.842930                  0.068725               0.056231
# 1             0.832754                  0.921611               0.182013
# 2             0.843975                  0.171865               0.118089
# 3             0.881134                  0.776165               0.182732
# 4             0.873148                  0.456629               0.222005
#
#    answer_type_reason_explanation  answer_well_written
# 0                        0.904495             0.920958
# 1                        0.116549             0.862853
# 2                        0.831951             0.905744
# 3                        0.736137             0.895872
# 4                        0.479095             0.927727
#
# [5 rows x 31 columns]
