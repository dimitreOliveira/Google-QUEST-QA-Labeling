# %% [markdown]
# ## Dependencies

# %%
import re
import warnings
from joblib import dump
import tensorflow_hub as hub
from sklearn.preprocessing import OneHotEncoder
from tensorflow.keras import Model, optimizers
from tensorflow.keras.layers import Lambda, Input, Dense, Dropout, Concatenate, BatchNormalization, Activation, Average
from tensorflow.keras.callbacks import ReduceLROnPlateau
from googleqa_utilityscript import *


SEED = 0
seed_everything(SEED)
warnings.filterwarnings("ignore")

# %% [markdown]
# ## Load data

# %%
hold_out = pd.read_csv('/kaggle/input/googleqa-mldataset/hold-out.csv')
train = hold_out[hold_out['set'] == 'train']
validation = hold_out[hold_out['set'] == 'validation']

print('Train samples: %s' % len(train))
print('Validation samples: %s' % len(validation))
display(train.head())
# Out:
# Train samples: 4863
# Validation samples: 1216
#    qa_id                                     question_title  \
# 0   3895  Magento (1.7) Bundled Product with FREE Produc...
# 1   3131                             Find router on network
# 2   1507  Negatively curved metrics minimizing the lengt...
# 3   6784               Isn’t the FAQ label obsolete by now?
# 4   2135  Changing background image one time on responsi...
#
#                                        question_body question_user_name  \
# 0  I'm looking to create a bundle offer where cus...                Joe
# 1  I've just bought a Belkin N+ Wireless Router. ...                Guy
# 2  Good afternoon everyone !\n\nI have the follow...            Selim G
# 3  Don’t get me wrong in the beginning of reading...     Benny Skogberg
# 4  The code I'm using is this one \n\nbackground:...        user2141649
#
#                               question_user_page  \
# 0  https://magento.stackexchange.com/users/16572
# 1               https://superuser.com/users/3248
# 2           https://mathoverflow.net/users/25511
# 3        https://ux.stackexchange.com/users/4679
# 4        https://stackoverflow.com/users/2141649
#
#                                               answer   answer_user_name  \
# 0  Since the third item is fixed, you can use sho...  Fabian Schmengler
# 1  You likely have the router plugged in to the m...             John T
# 2  A very partial answer: by the results of Richa...         Igor Rivin
# 3  Isn’t the FAQ label obsolete by now? \n\nI'd s...        Solracnapod
# 4  &lt;!DOCTYPE html&gt;\n&lt;html&gt;\n&lt;head&...           akkimads
#
#                               answer_user_page  \
# 0  https://magento.stackexchange.com/users/243
# 1             https://superuser.com/users/1931
# 2         https://mathoverflow.net/users/11142
# 3     https://ux.stackexchange.com/users/13153
# 4      https://stackoverflow.com/users/2375373
#
#                                                  url       category  ...  \
# 0  http://magento.stackexchange.com/questions/668...     TECHNOLOGY  ...
# 1               http://superuser.com/questions/87212     TECHNOLOGY  ...
# 2           http://mathoverflow.net/questions/203422        SCIENCE  ...
# 3  http://ux.stackexchange.com/questions/18600/is...     TECHNOLOGY  ...
# 4  http://stackoverflow.com/questions/16359492/ch...  STACKOVERFLOW  ...
#
#   answer_helpful  answer_level_of_information  answer_plausible  \
# 0       0.888889                     0.666667               1.0
# 1       1.000000                     0.666667               1.0
# 2       0.888889                     0.333333               1.0
# 3       0.888889                     0.666667               1.0
# 4       0.888889                     0.500000               1.0
#
#    answer_relevance  answer_satisfaction  answer_type_instructions  \
# 0               1.0             0.933333                  1.000000
# 1               1.0             0.866667                  0.666667
# 2               1.0             0.700000                  0.333333
# 3               1.0             0.933333                  0.000000
# 4               1.0             0.800000                  1.000000
#
#    answer_type_procedure  answer_type_reason_explanation  answer_well_written  \
# 0               0.000000                        0.333333             0.888889
# 1               0.000000                        1.000000             1.000000
# 2               0.333333                        1.000000             0.888889
# 3               0.000000                        0.666667             1.000000
# 4               0.000000                        0.000000             0.777778
#
#      set
# 0  train
# 1  train
# 2  train
# 3  train
# 4  train
#
# [5 rows x 42 columns]

# %%
question_target_cols = ['question_asker_intent_understanding','question_body_critical', 'question_conversational', 
                        'question_expect_short_answer', 'question_fact_seeking', 'question_has_commonly_accepted_answer',
                        'question_interestingness_others', 'question_interestingness_self', 'question_multi_intent', 
                        'question_not_really_a_question', 'question_opinion_seeking', 'question_type_choice',
                        'question_type_compare', 'question_type_consequence', 'question_type_definition', 
                        'question_type_entity', 'question_type_instructions', 'question_type_procedure',
                        'question_type_reason_explanation', 'question_type_spelling', 'question_well_written']
answer_target_cols = ['answer_helpful', 'answer_level_of_information', 'answer_plausible', 'answer_relevance',
                      'answer_satisfaction', 'answer_type_instructions', 'answer_type_procedure', 
                      'answer_type_reason_explanation', 'answer_well_written']
target_cols = question_target_cols + answer_target_cols

# %% [markdown]
# ## Pre-process data

# %%
text_features = ['question_title', 'question_body', 'answer']

for feature in text_features:
    # Lower
    train[feature] = train[feature].apply(lambda x: x.lower())
    validation[feature] = validation[feature].apply(lambda x: x.lower())
    # Map misspellings
    train[feature] = train[feature].apply(lambda x: map_misspellings(x))
    validation[feature] = validation[feature].apply(lambda x: map_misspellings(x))
    # Map contractions
    train[feature] = train[feature].apply(lambda x: map_contraction(x))
    validation[feature] = validation[feature].apply(lambda x: map_contraction(x))
    # Trim text
    train[feature] = train[feature].apply(lambda x: x.strip())
    validation[feature] = validation[feature].apply(lambda x: x.strip())

# %% [markdown]
# ## Train/validation sets

# %%
ohe_category = OneHotEncoder(handle_unknown='ignore')
ohe_category.fit(train[['category']])

# Train features
X_train_title = train['question_title']
X_train_body = train['question_body']
X_train_answer = train['answer']
X_train_category = ohe_category.transform(train[['category']]).toarray()

X_train = [X_train_title, X_train_body, X_train_answer, X_train_category]
Y_train = train[target_cols].values

# Validation features
X_valid_title = validation['question_title']
X_valid_body = validation['question_body']
X_valid_answer = validation['answer']
X_valid_category = ohe_category.transform(validation[['category']]).toarray()

X_valid = [X_valid_title, X_valid_body, X_valid_answer, X_valid_category]
Y_valid = validation[target_cols].values

print('Train samples: %d' % len(Y_train))
print('Validation samples: %d' % len(Y_valid))
# Out:
# Train samples: 4863
# Validation samples: 1216

# %% [markdown]
# # Model parameters

# %%
EPOCHS = 30
BATCH_SIZE = 32
LEARNING_RATE = 3e-4
EMBEDDDING_SIZE = 512
N_CLASS = len(target_cols)
ES_PATIENCE = 3
RLROP_PATIENCE = 2
DECAY_DROP = 0.1
module_url = '/kaggle/input/universalsentenceencodermodels/universal-sentence-encoder-models/use'
model_path = '/kaggle/working/use.h5'
category_encoder_path = '/kaggle/working/category_encoder.joblib'

# %% [markdown]
# # Model

# %%
use_embed = hub.load(module_url)

def USEEmbedding(x):
    return use_embed(tf.squeeze(tf.cast(x, tf.string)))

def encoder_block(input_layer):
    encoder = Lambda(USEEmbedding, output_shape=(EMBEDDDING_SIZE,))(input_layer)
    return encoder

# %%
# Title
input_title = Input(shape=(1,), dtype=tf.string, name='input_title')
encoded_title = encoder_block(input_title)

# Body
input_body = Input(shape=(1,), dtype=tf.string, name='input_body')
encoded_body = encoder_block(input_body)

# Answer
input_answer = Input(shape=(1,), dtype=tf.string, name='input_answer')
encoded_answer = encoder_block(input_answer)

# Category
input_category = Input(shape=(5,), dtype=tf.float32, name='input_category')
encoded_category = Dense(6, activation='relu')(input_category)
encoded_category = Dropout(0.5)(encoded_category)
encoded_category = Dense(2, activation='relu')(encoded_category)

# Output
x = Concatenate()([encoded_title, encoded_body, encoded_answer, encoded_category])
x = Dropout(0.5)(x)
x = Dense(512, activation='relu')(x)
x = Dropout(0.5)(x)
output = Dense(N_CLASS, activation='sigmoid', name='output')(x)
model = Model(inputs=[input_title, input_body, input_answer, input_category], outputs=[output])

model.summary()
# Out:
# Model: "model"
# __________________________________________________________________________________________________
# Layer (type)                    Output Shape         Param #     Connected to
# ==================================================================================================
# input_category (InputLayer)     [(None, 5)]          0
# __________________________________________________________________________________________________
# dense (Dense)                   (None, 6)            36          input_category[0][0]
# __________________________________________________________________________________________________
# input_title (InputLayer)        [(None, 1)]          0
# __________________________________________________________________________________________________
# input_body (InputLayer)         [(None, 1)]          0
# __________________________________________________________________________________________________
# input_answer (InputLayer)       [(None, 1)]          0
# __________________________________________________________________________________________________
# dropout (Dropout)               (None, 6)            0           dense[0][0]
# __________________________________________________________________________________________________
# lambda (Lambda)                 (None, 512)          0           input_title[0][0]
# __________________________________________________________________________________________________
# lambda_1 (Lambda)               (None, 512)          0           input_body[0][0]
# __________________________________________________________________________________________________
# lambda_2 (Lambda)               (None, 512)          0           input_answer[0][0]
# __________________________________________________________________________________________________
# dense_1 (Dense)                 (None, 2)            14          dropout[0][0]
# __________________________________________________________________________________________________
# concatenate (Concatenate)       (None, 1538)         0           lambda[0][0]
#                                                                  lambda_1[0][0]
#                                                                  lambda_2[0][0]
#                                                                  dense_1[0][0]
# __________________________________________________________________________________________________
# dropout_1 (Dropout)             (None, 1538)         0           concatenate[0][0]
# __________________________________________________________________________________________________
# dense_2 (Dense)                 (None, 512)          787968      dropout_1[0][0]
# __________________________________________________________________________________________________
# dropout_2 (Dropout)             (None, 512)          0           dense_2[0][0]
# __________________________________________________________________________________________________
# output (Dense)                  (None, 30)           15390       dropout_2[0][0]
# ==================================================================================================
# Total params: 803,408
# Trainable params: 803,408
# Non-trainable params: 0
# __________________________________________________________________________________________________

# %% [markdown]
# # Train model

# %%
rlrop = ReduceLROnPlateau(monitor='val_loss', mode='min', patience=RLROP_PATIENCE, factor=DECAY_DROP, min_lr=1e-7, verbose=1)
spearmanCallback = SpearmanRhoCallback(training_data=(X_train, Y_train), validation_data=(X_valid, Y_valid), monitor='val_loss', mode='min', patience=ES_PATIENCE)
callback_list = [rlrop, spearmanCallback]

optimizer = optimizers.Adam(LEARNING_RATE)
model.compile(optimizer=optimizer, loss='binary_crossentropy')

history = model.fit(X_train, Y_train, 
                    validation_data=(X_valid, Y_valid), 
                    callbacks=callback_list, 
                    batch_size=BATCH_SIZE,
                    epochs=EPOCHS, 
                    verbose=2).history
# Out:
# Train on 4863 samples, validate on 1216 samples
# Epoch 1/30
# spearman-rho: 0.2147 val_spearman-rho: 0.2046
# 4863/4863 - 27s - loss: 0.4887 - val_loss: 0.4140
# Epoch 2/30
# spearman-rho: 0.2881 val_spearman-rho: 0.2697
# 4863/4863 - 19s - loss: 0.4073 - val_loss: 0.3992
# Epoch 3/30
# spearman-rho: 0.3277 val_spearman-rho: 0.3044
# 4863/4863 - 18s - loss: 0.3964 - val_loss: 0.3922
# Epoch 4/30
# spearman-rho: 0.3510 val_spearman-rho: 0.3219
# 4863/4863 - 18s - loss: 0.3903 - val_loss: 0.3880
# Epoch 5/30
# spearman-rho: 0.3696 val_spearman-rho: 0.3342
# 4863/4863 - 18s - loss: 0.3862 - val_loss: 0.3852
# Epoch 6/30
# spearman-rho: 0.3827 val_spearman-rho: 0.3420
# 4863/4863 - 18s - loss: 0.3831 - val_loss: 0.3831
# Epoch 7/30
# spearman-rho: 0.3938 val_spearman-rho: 0.3475
# 4863/4863 - 18s - loss: 0.3805 - val_loss: 0.3816
# Epoch 8/30
# spearman-rho: 0.4032 val_spearman-rho: 0.3504
# 4863/4863 - 18s - loss: 0.3779 - val_loss: 0.3807
# Epoch 9/30
# spearman-rho: 0.4109 val_spearman-rho: 0.3534
# 4863/4863 - 18s - loss: 0.3765 - val_loss: 0.3801
# Epoch 10/30
# spearman-rho: 0.4174 val_spearman-rho: 0.3560
# 4863/4863 - 18s - loss: 0.3748 - val_loss: 0.3793
# Epoch 11/30
# spearman-rho: 0.4243 val_spearman-rho: 0.3589
# 4863/4863 - 18s - loss: 0.3737 - val_loss: 0.3789
# Epoch 12/30
# spearman-rho: 0.4289 val_spearman-rho: 0.3597
# 4863/4863 - 18s - loss: 0.3727 - val_loss: 0.3784
# Epoch 13/30
# spearman-rho: 0.4341 val_spearman-rho: 0.3607
# 4863/4863 - 18s - loss: 0.3715 - val_loss: 0.3781
# Epoch 14/30
# spearman-rho: 0.4385 val_spearman-rho: 0.3619
# 4863/4863 - 18s - loss: 0.3705 - val_loss: 0.3778
# Epoch 15/30
# spearman-rho: 0.4429 val_spearman-rho: 0.3640
# 4863/4863 - 19s - loss: 0.3698 - val_loss: 0.3776
# Epoch 16/30
# spearman-rho: 0.4464 val_spearman-rho: 0.3645
# 4863/4863 - 18s - loss: 0.3690 - val_loss: 0.3773
# Epoch 17/30
# spearman-rho: 0.4501 val_spearman-rho: 0.3658
# 4863/4863 - 18s - loss: 0.3681 - val_loss: 0.3772
# Epoch 18/30
# spearman-rho: 0.4536 val_spearman-rho: 0.3661
# 4863/4863 - 18s - loss: 0.3676 - val_loss: 0.3769
# Epoch 19/30
# spearman-rho: 0.4570 val_spearman-rho: 0.3669
# 4863/4863 - 18s - loss: 0.3669 - val_loss: 0.3768
# Epoch 20/30
# spearman-rho: 0.4604 val_spearman-rho: 0.3679
# 4863/4863 - 18s - loss: 0.3659 - val_loss: 0.3765
# Epoch 21/30
# spearman-rho: 0.4632 val_spearman-rho: 0.3680
# 4863/4863 - 19s - loss: 0.3654 - val_loss: 0.3763
# Epoch 22/30
# spearman-rho: 0.4668 val_spearman-rho: 0.3691
# 4863/4863 - 19s - loss: 0.3645 - val_loss: 0.3763
# Epoch 23/30
# spearman-rho: 0.4693 val_spearman-rho: 0.3699
# 4863/4863 - 18s - loss: 0.3641 - val_loss: 0.3760
# Epoch 24/30
# spearman-rho: 0.4721 val_spearman-rho: 0.3705
# 4863/4863 - 18s - loss: 0.3637 - val_loss: 0.3758
# Epoch 25/30
# spearman-rho: 0.4746 val_spearman-rho: 0.3712
# 4863/4863 - 18s - loss: 0.3631 - val_loss: 0.3758
# Epoch 26/30
#
# Epoch 00026: ReduceLROnPlateau reducing learning rate to 3.000000142492354e-05.
# spearman-rho: 0.4779 val_spearman-rho: 0.3717
# 4863/4863 - 19s - loss: 0.3631 - val_loss: 0.3759
# Epoch 27/30
# spearman-rho: 0.4781 val_spearman-rho: 0.3718
# 4863/4863 - 18s - loss: 0.3615 - val_loss: 0.3757
# Epoch 28/30
# spearman-rho: 0.4783 val_spearman-rho: 0.3719
# 4863/4863 - 18s - loss: 0.3609 - val_loss: 0.3756
# Epoch 29/30
#
# Epoch 00029: ReduceLROnPlateau reducing learning rate to 3.000000106112566e-06.
# spearman-rho: 0.4787 val_spearman-rho: 0.3720
# 4863/4863 - 18s - loss: 0.3615 - val_loss: 0.3756
# Epoch 30/30
# spearman-rho: 0.4787 val_spearman-rho: 0.3720
# 4863/4863 - 18s - loss: 0.3607 - val_loss: 0.3756

# %% [markdown]
# ## Model loss graph

# %%
sns.set(style="whitegrid")
plot_metrics(history, metric_list=['loss', 'spearman'])

# %% [markdown]
# # Evaluation

# %%
preds_train = model.predict(X_train)
preds_val = model.predict(X_valid)

display(get_metrics(Y_train, preds_train, Y_valid, preds_val, target_cols))
# Out:
#                                     Label  Train  Validation
# 0                                Averaged  0.479       0.372
# 1     question_asker_intent_understanding  0.453       0.411
# 2                  question_body_critical  0.703       0.619
# 3                 question_conversational  0.454       0.400
# 4            question_expect_short_answer  0.479       0.257
# 5                   question_fact_seeking  0.503       0.337
# 6   question_has_commonly_accepted_answer  0.539       0.430
# 7         question_interestingness_others  0.452       0.393
# 8           question_interestingness_self  0.584       0.534
# 9                   question_multi_intent  0.566       0.428
# 10         question_not_really_a_question  0.130       0.082
# 11               question_opinion_seeking  0.617       0.450
# 12                   question_type_choice  0.691       0.556
# 13                  question_type_compare  0.386       0.309
# 14              question_type_consequence  0.207       0.158
# 15               question_type_definition  0.377       0.313
# 16                   question_type_entity  0.458       0.427
# 17             question_type_instructions  0.813       0.743
# 18                question_type_procedure  0.496       0.278
# 19       question_type_reason_explanation  0.705       0.637
# 20                 question_type_spelling  0.073       0.070
# 21                  question_well_written  0.583       0.490
# 22                         answer_helpful  0.354       0.207
# 23            answer_level_of_information  0.473       0.368
# 24                       answer_plausible  0.289       0.154
# 25                       answer_relevance  0.267       0.145
# 26                    answer_satisfaction  0.416       0.251
# 27               answer_type_instructions  0.807       0.703
# 28                  answer_type_procedure  0.450       0.254
# 29         answer_type_reason_explanation  0.734       0.630
# 30                    answer_well_written  0.302       0.131

# %% [markdown]
# ## By category

# %%
target_cols_preds = [col+'_pred' for col in target_cols]
for col in target_cols_preds:
    train[col] = 0
    validation[col] = 0
    
train[target_cols_preds] = preds_train
validation[target_cols_preds] = preds_val
    
display(get_metrics_category(train, validation, target_cols, target_cols_preds, 'category'))
# Out:
#       Label Train (TECHNOLOGY) Validation (TECHNOLOGY) Train (SCIENCE)  \
# 0  Averaged              0.445                   0.338            0.49
#
#   Validation (SCIENCE) Train (STACKOVERFLOW) Validation (STACKOVERFLOW)  \
# 0                0.366                 0.375                      0.198
#
#   Train (LIFE_ARTS) Validation (LIFE_ARTS) Train (CULTURE)  \
# 0             0.506                  0.411             0.5
#
#   Validation (CULTURE)
# 0                0.379

# %% [markdown]
# #### Save model weights and ecoders

# %%
model.save_weights(model_path)
dump(ohe_category, category_encoder_path)
# Out:
# ['/kaggle/working/category_encoder.joblib']
