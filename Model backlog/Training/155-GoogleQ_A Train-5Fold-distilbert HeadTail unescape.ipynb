# %%
# !pip --quiet install transformers
# Out:
#      |████████████████████████████████| 481kB 9.5MB/s
#      |████████████████████████████████| 3.1MB 62.2MB/s
#      |████████████████████████████████| 1.0MB 69.1MB/s
#      |████████████████████████████████| 870kB 73.4MB/s
#   Building wheel for sacremoses (setup.py) ... done

# %%
import sys
if 'google.colab' in sys.modules: # Colab-only Tensorflow version selector
  # %tensorflow_version 2.x

import tensorflow as tf
print("Tensorflow version " + tf.__version__)
# Out:
# TensorFlow 2.x selected.
# Tensorflow version 2.1.0

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Go to this URL in a browser: https://accounts.google.com/o/oauth2/auth?client_id=947318989803-6bn6qk8qdgf4n4g3pfee6491hc0brc4i.apps.googleusercontent.com&redirect_uri=urn%3aietf%3awg%3aoauth%3a2.0%3aoob&response_type=code&scope=email%20https%3a%2f%2fwww.googleapis.com%2fauth%2fdocs.test%20https%3a%2f%2fwww.googleapis.com%2fauth%2fdrive%20https%3a%2f%2fwww.googleapis.com%2fauth%2fdrive.photos.readonly%20https%3a%2f%2fwww.googleapis.com%2fauth%2fpeopleapi.readonly
#
# Enter your authorization code:
# ··········
# Mounted at /content/drive

# %%
# !cp -r '/content/drive/My Drive/Colab Notebooks/Google QUEST Q&A Labeling/Scripts/.' .

# %%
MODEL_BASE_PATH = '/content/drive/My Drive/Colab Notebooks/Google QUEST Q&A Labeling/Model backlog/Files/'
MODEL_NAME = '155-DistilBert'

# %% [markdown]
# ## Dependencies

# %%
import glob
import html
import warnings
from tensorflow.keras import Model, optimizers
from tensorflow.keras.layers import Input, Dense, Dropout, GlobalAveragePooling1D, Concatenate
from googleqa_utilityscript import *
from script_lr_schedulers import WarmUpLearningRateScheduler
from transformers import DistilBertConfig, DistilBertTokenizer, TFDistilBertModel


SEED = 0
seed_everything(SEED)
warnings.filterwarnings("ignore")
# Out:
# Using TensorFlow backend.

# %% [markdown]
# ## Load data

# %%
MODULE_BASE_PATH = '/content/drive/My Drive/Colab Notebooks/Google QUEST Q&A Labeling/Modules/distilbert/distilbert-base-uncased'
MODULE_PATH = MODULE_BASE_PATH + '/distilbert-base-uncased-tf_model.h5'
VOCAB_PATH = MODULE_BASE_PATH + '/bert-base-uncased-vocab.txt'
CONF_PATH = MODULE_BASE_PATH + '/distilbert-base-uncased-config.json'

k_fold = pd.read_csv('/content/drive/My Drive/Colab Notebooks/Google QUEST Q&A Labeling/Data/5-fold.csv')
N_FOLDS = 5

print('Samples: %s' % len(k_fold))
display(k_fold.head())
# Out:
# Samples: 6079
#    qa_id  ...      fold_5
# 0      0  ...       train
# 1      1  ...       train
# 2      2  ...       train
# 3      3  ...  validation
# 4      5  ...       train
#
# [5 rows x 46 columns]

# %%
question_target_cols = ['question_asker_intent_understanding','question_body_critical', 'question_conversational', 
                        'question_expect_short_answer', 'question_fact_seeking', 'question_has_commonly_accepted_answer',
                        'question_interestingness_others', 'question_interestingness_self', 'question_multi_intent', 
                        'question_not_really_a_question', 'question_opinion_seeking', 'question_type_choice',
                        'question_type_compare', 'question_type_consequence', 'question_type_definition', 
                        'question_type_entity', 'question_type_instructions', 'question_type_procedure',
                        'question_type_reason_explanation', 'question_type_spelling', 'question_well_written']
answer_target_cols = ['answer_helpful', 'answer_level_of_information', 'answer_plausible', 'answer_relevance',
                      'answer_satisfaction', 'answer_type_instructions', 'answer_type_procedure', 
                      'answer_type_reason_explanation', 'answer_well_written']
target_cols = question_target_cols + answer_target_cols

# %%
### BERT auxiliar function
def _get_masks(tokens, max_seq_length):
    """Mask for padding"""
    if len(tokens)>max_seq_length:
        raise IndexError("Token length more than max seq length!")
    return [1]*len(tokens) + [0] * (max_seq_length - len(tokens))

def _get_segments(tokens, max_seq_length, ignore_first_sep=True):
    """Segments: 0 for the first sequence, 1 for the second"""
    if len(tokens)>max_seq_length:
        raise IndexError("Token length more than max seq length!")
    segments = []
    current_segment_id = 0
    for token in tokens:
        segments.append(current_segment_id)
        if token == "[SEP]":
            if ignore_first_sep:
                ignore_first_sep = False 
            else:
                current_segment_id = 1
    return segments + [0] * (max_seq_length - len(tokens))

def _get_ids(tokens, tokenizer, max_seq_length):
    """Token ids from Tokenizer vocab"""
    token_ids = tokenizer.convert_tokens_to_ids(tokens)
    input_ids = token_ids + [0] * (max_seq_length-len(token_ids))
    return input_ids

def _trim_input_2_tail(ft_input1, ft_input2, tokenizer, max_sequence_length, 
                  max_len_ft1=254, max_len_ft2=255):

    ft1 = tokenizer.tokenize(ft_input1)
    ft2 = tokenizer.tokenize(ft_input2)
    
    ft1_len = len(ft1)
    ft2_len = len(ft2)

    if (ft1_len + ft2_len + 3) > max_sequence_length:
      
        if max_len_ft2 > ft2_len:
            ft2_new_len = ft2_len 
            ft1_new_len = max_len_ft1 + (max_len_ft2 - ft2_len)
        elif max_len_ft1 > ft1_len:
            ft2_new_len = max_len_ft2 + (max_len_ft1 - ft1_len)
            ft1_new_len = ft1_len
        else:
            ft2_new_len = max_len_ft2
            ft1_new_len = max_len_ft1
                        
        if ft1_new_len + ft2_new_len + 3 > max_sequence_length:
            raise ValueError("New sequence length should be %d, but is %d" 
                             % (max_sequence_length, (ft1_new_len + ft2_new_len + 3)))
        
        ft1 = ft1[-ft1_new_len:]
        ft2 = ft2[-ft2_new_len:]
        
    return ft1, ft2

def _convert_to_bert_inputs_2(feature1, feature2, tokenizer, max_sequence_length, ignore_first_sep=True):
    """Converts tokenized input to ids, masks and segments for BERT"""
    
    stoken = ["[CLS]"] + feature1 + ["[SEP]"] + feature2 + ["[SEP]"]

    input_ids = _get_ids(stoken, tokenizer, max_sequence_length)
    input_masks = _get_masks(stoken, max_sequence_length)
    input_segments = _get_segments(stoken, max_sequence_length, ignore_first_sep)

    return [input_ids, input_masks, input_segments]

def compute_input_arays_2_tail(df, columns, tokenizer, max_sequence_length, 
                          max_len_ft1, max_len_ft2, ignore_first_sep=True):
    input_ids, input_masks, input_segments = [], [], []
    for _, instance in df[columns].iterrows():
        ft1, ft2 = instance[columns[0]], instance[columns[1]]

        ft1, ft2 = _trim_input_2_tail(ft1, ft2, tokenizer, max_sequence_length, 
                                      max_len_ft1, max_len_ft2)

        ids, masks, segments = _convert_to_bert_inputs_2(ft1, ft2, tokenizer, max_sequence_length, 
                                                         ignore_first_sep)
        input_ids.append(ids)
        input_masks.append(masks)
        input_segments.append(segments)
        
    return [np.asarray(input_ids, dtype=np.int32), 
            np.asarray(input_masks, dtype=np.int32), 
            np.asarray(input_segments, dtype=np.int32)]

# %% [markdown]
# # Pre-process data

# %%
text_features = ['question_title', 'question_body', 'answer']
text_features_question = ['question_title', 'question_body']
text_features_answer = ['question_title', 'answer']

k_fold['question_title'] = k_fold['question_title'].apply(html.unescape)
k_fold['question_body'] = k_fold['question_body'].apply(html.unescape)
k_fold['answer'] = k_fold['answer'].apply(html.unescape)

# %% [markdown]
# # Model parameters

# %%
EPOCHS = 8
BATCH_SIZE = 10
LEARNING_RATE = 3e-5
N_CLASS = len(target_cols)
N_CLASS_QUESTION = len(question_target_cols)
N_CLASS_ANSWER = len(answer_target_cols)
ES_PATIENCE = 1
LR_WARMUP_EPOCHS = 2
MAX_SEQUENCE_LENGTH = 512
MAX_LENGTH_TITLE = 30
MAX_LENGTH_QUESTION = 479
MAX_LENGTH_ANSWER = 479

# %% [markdown]
# # Model

# %%
module_config = DistilBertConfig.from_pretrained(CONF_PATH)
module_config.output_hidden_states=False

def model_fn():
    input_word_ids_question = Input((MAX_SEQUENCE_LENGTH,), dtype=tf.int32, name='input_word_ids_question')
    input_masks_question = Input((MAX_SEQUENCE_LENGTH,), dtype=tf.int32, name='input_masks_question')
    segment_ids_question = Input((MAX_SEQUENCE_LENGTH,), dtype=tf.int32, name='segment_ids_question')

    input_word_ids_answer = Input((MAX_SEQUENCE_LENGTH,), dtype=tf.int32, name='input_word_ids_answer')
    input_masks_answer = Input((MAX_SEQUENCE_LENGTH,), dtype=tf.int32, name='input_masks_answer')
    segment_ids_answer = Input((MAX_SEQUENCE_LENGTH,), dtype=tf.int32, name='segment_ids_answer')

    module_model = TFDistilBertModel.from_pretrained(MODULE_PATH, config=module_config)
    sequence_output_question = module_model([input_word_ids_question, input_masks_question])
    sequence_output_answer = module_model([input_word_ids_answer, input_masks_answer])

    sequence_output_question = sequence_output_question[0] # The last hidden-state is the first element of the output tuple
    sequence_output_answer = sequence_output_answer[0] # The last hidden-state is the first element of the output tuple
    
    x_question = GlobalAveragePooling1D()(sequence_output_question)
    x_question = Dropout(0.2)(x_question)
    output_question = Dense(N_CLASS_QUESTION, kernel_initializer='glorot_uniform', activation="sigmoid", name="output_question")(x_question)
    
    x_answer = GlobalAveragePooling1D()(sequence_output_answer)
    x_answer = Dropout(0.2)(x_answer)
    output_answer = Dense(N_CLASS_ANSWER, kernel_initializer='glorot_uniform', activation="sigmoid", name="output_answer")(x_answer)
    
    output = Concatenate()([output_question, output_answer])

    model = Model(inputs=[input_word_ids_question, input_masks_question, segment_ids_question, 
                          input_word_ids_answer, input_masks_answer, segment_ids_answer], outputs=output)

    return model

# %% [markdown]
# # Train model

# %%
tokenizer = DistilBertTokenizer.from_pretrained(VOCAB_PATH, do_lower_case=True)

history_list = []
metric_list = []
category_metric_list = []
target_cols_preds = [col+'_pred' for col in target_cols]

for n_fold in range(N_FOLDS):
    ### Data
    train = k_fold[k_fold['fold_%d' % (n_fold+1)] == 'train']
    validation = k_fold[k_fold['fold_%d' % (n_fold+1)] == 'validation']
    
    ### Create features
    # Train features
    X_train_head = compute_input_arays_2(train, text_features_question, tokenizer, MAX_SEQUENCE_LENGTH, 
                                          MAX_LENGTH_TITLE, MAX_LENGTH_QUESTION, ignore_first_sep=False)\
                    + compute_input_arays_2(train, text_features_answer, tokenizer, MAX_SEQUENCE_LENGTH, 
                                             MAX_LENGTH_TITLE, MAX_LENGTH_ANSWER, ignore_first_sep=False)
                    
    X_train_tail = compute_input_arays_2_tail(train, text_features_question, tokenizer, MAX_SEQUENCE_LENGTH, 
                                              MAX_LENGTH_TITLE, MAX_LENGTH_QUESTION, ignore_first_sep=False)\
                    + compute_input_arays_2_tail(train, text_features_answer, tokenizer, MAX_SEQUENCE_LENGTH, 
                                                  MAX_LENGTH_TITLE, MAX_LENGTH_ANSWER, ignore_first_sep=False)
                
    Y_train = train[target_cols].values

    X_train = list(np.hstack((np.asarray(X_train_head), np.asarray(X_train_tail))))
    Y_train = np.vstack((Y_train, Y_train))

    # Validation features
    X_valid = compute_input_arays_2(validation, text_features_question, tokenizer, MAX_SEQUENCE_LENGTH, 
                                    MAX_LENGTH_TITLE, MAX_LENGTH_QUESTION, ignore_first_sep=False)\
              + compute_input_arays_2(validation, text_features_answer, tokenizer, MAX_SEQUENCE_LENGTH, 
                                      MAX_LENGTH_TITLE, MAX_LENGTH_ANSWER, ignore_first_sep=False)
                    
    Y_valid = validation[target_cols].values
    
    # Train model
    model_path = MODEL_BASE_PATH + MODEL_NAME + '_model_fold_%d' % (n_fold+1)
    spearmanCallback = SpearmanRhoCallback(training_data=(X_train, Y_train), 
                                           validation_data=(X_valid, Y_valid), 
                                           model_path=model_path, 
                                           monitor='val_loss', mode='min', 
                                           patience=ES_PATIENCE, checkpoint=True)
    WARMUP_BATCHES = LR_WARMUP_EPOCHS * len(train) // BATCH_SIZE
    warmup_lr = WarmUpLearningRateScheduler(WARMUP_BATCHES, LEARNING_RATE)

    callback_list = [spearmanCallback, warmup_lr]
    optimizer = optimizers.Adam(lr=LEARNING_RATE)
    model = model_fn()
    model.compile(optimizer=optimizer, loss='binary_crossentropy')

    history = model.fit(X_train, Y_train, 
                        validation_data=(X_valid, Y_valid), 
                        callbacks=callback_list, 
                        batch_size=BATCH_SIZE, 
                        epochs=EPOCHS, 
                        verbose=2).history
    history_list.append(history)

    # Save last epoch weights
    model.save_weights(MODEL_BASE_PATH + MODEL_NAME + '_model_fold_%d_last_epoch.h5' % (n_fold+1))
    
    ### Evaluation - Label metrics
    model.load_weights(model_path+'.h5')
    preds_train = model.predict(X_train_head)
    preds_val = model.predict(X_valid)
    metric_list.append(get_metrics(train[target_cols].values, preds_train, Y_valid, preds_val, target_cols))
    
    ### Evaluation - Category metrics
    for col in target_cols_preds:
        train[col] = 0
        validation[col] = 0

    train[target_cols_preds] = preds_train
    validation[target_cols_preds] = preds_val
    category_metric_list.append(get_metrics_category(train, validation, target_cols, target_cols_preds, 'category'))
# Out:
# Calling DistilBertTokenizer.from_pretrained() with the path to a single file or url is deprecated
# Train on 9728 samples, validate on 1215 samples
# Epoch 1/8
# spearman-rho: 0.4210 val_spearman-rho: 0.3804
# Saved model weights at "/content/drive/My Drive/Colab Notebooks/Google QUEST Q&A Labeling/Model backlog/Files/155-DistilBert_model_fold_1.h5"
# 9728/9728 - 920s - loss: 0.4256 - val_loss: 0.3743
# Epoch 2/8
# spearman-rho: 0.5093 val_spearman-rho: 0.3920
# Saved model weights at "/content/drive/My Drive/Colab Notebooks/Google QUEST Q&A Labeling/Model backlog/Files/155-DistilBert_model_fold_1.h5"
# 9728/9728 - 903s - loss: 0.3609 - val_loss: 0.3678
# Epoch 3/8
# spearman-rho: 0.5784 val_spearman-rho: 0.3854
# Epoch 00002: early stopping
# 9728/9728 - 902s - loss: 0.3383 - val_loss: 0.3802
# Train on 9728 samples, validate on 1215 samples
# Epoch 1/8
# spearman-rho: 0.4166 val_spearman-rho: 0.3687
# Saved model weights at "/content/drive/My Drive/Colab Notebooks/Google QUEST Q&A Labeling/Model backlog/Files/155-DistilBert_model_fold_2.h5"
# 9728/9728 - 919s - loss: 0.4266 - val_loss: 0.3736
# Epoch 2/8
# spearman-rho: 0.5038 val_spearman-rho: 0.3874
# Saved model weights at "/content/drive/My Drive/Colab Notebooks/Google QUEST Q&A Labeling/Model backlog/Files/155-DistilBert_model_fold_2.h5"
# 9728/9728 - 902s - loss: 0.3611 - val_loss: 0.3714
# Epoch 3/8
# spearman-rho: 0.5836 val_spearman-rho: 0.3776
# Epoch 00002: early stopping
# 9728/9728 - 900s - loss: 0.3386 - val_loss: 0.3805
# Train on 9718 samples, validate on 1220 samples
# Epoch 1/8
# spearman-rho: 0.4060 val_spearman-rho: 0.3641
# Saved model weights at "/content/drive/My Drive/Colab Notebooks/Google QUEST Q&A Labeling/Model backlog/Files/155-DistilBert_model_fold_3.h5"
# 9718/9718 - 918s - loss: 0.4275 - val_loss: 0.3761
# Epoch 2/8
# spearman-rho: 0.5036 val_spearman-rho: 0.3842
# Saved model weights at "/content/drive/My Drive/Colab Notebooks/Google QUEST Q&A Labeling/Model backlog/Files/155-DistilBert_model_fold_3.h5"
# 9718/9718 - 902s - loss: 0.3630 - val_loss: 0.3687
# Epoch 3/8
# spearman-rho: 0.5791 val_spearman-rho: 0.3795
# Epoch 00002: early stopping
# 9718/9718 - 901s - loss: 0.3406 - val_loss: 0.3769
# Train on 9730 samples, validate on 1214 samples
# Epoch 1/8
# spearman-rho: 0.4113 val_spearman-rho: 0.3770
# Saved model weights at "/content/drive/My Drive/Colab Notebooks/Google QUEST Q&A Labeling/Model backlog/Files/155-DistilBert_model_fold_4.h5"
# 9730/9730 - 902s - loss: 0.4259 - val_loss: 0.3753
# Epoch 2/8
# spearman-rho: 0.5033 val_spearman-rho: 0.3988
# Saved model weights at "/content/drive/My Drive/Colab Notebooks/Google QUEST Q&A Labeling/Model backlog/Files/155-DistilBert_model_fold_4.h5"
# 9730/9730 - 890s - loss: 0.3619 - val_loss: 0.3680
# Epoch 3/8
# spearman-rho: 0.5757 val_spearman-rho: 0.3926
# Epoch 00002: early stopping
# 9730/9730 - 889s - loss: 0.3398 - val_loss: 0.3790
# Train on 9728 samples, validate on 1215 samples
# Epoch 1/8
# spearman-rho: 0.4193 val_spearman-rho: 0.3716
# Saved model weights at "/content/drive/My Drive/Colab Notebooks/Google QUEST Q&A Labeling/Model backlog/Files/155-DistilBert_model_fold_5.h5"
# 9728/9728 - 919s - loss: 0.4223 - val_loss: 0.3772
# Epoch 2/8
# spearman-rho: 0.5090 val_spearman-rho: 0.3851
# Saved model weights at "/content/drive/My Drive/Colab Notebooks/Google QUEST Q&A Labeling/Model backlog/Files/155-DistilBert_model_fold_5.h5"
# 9728/9728 - 903s - loss: 0.3599 - val_loss: 0.3740
# Epoch 3/8
# spearman-rho: 0.5838 val_spearman-rho: 0.3824
# Epoch 00002: early stopping
# 9728/9728 - 901s - loss: 0.3381 - val_loss: 0.3832

# %% [markdown]
# ## Model loss graph

# %%
for n_fold in range(N_FOLDS):
    print('Fold: %d' % n_fold)
    sns.set(style="whitegrid")
    plot_metrics(history_list[n_fold], metric_list=['loss', 'spearman'])
# Out:
# Fold: 0
# Fold: 1
# Fold: 2
# Fold: 3
# Fold: 4

# %% [markdown]
# # Evaluation

# %%
metrics_df = metric_list[0][['Label', 'Train', 'Validation']].copy()
metrics_df.columns = ['Label', 'Train_fold_0', 'Valid_fold_0']

for n_fold in range(1, N_FOLDS):
    metrics_df_idx = metric_list[n_fold][['Train', 'Validation']].copy()
    metrics_df_idx.columns = ['Train_fold_%d' % n_fold, 'Valid_fold_%d' % n_fold]
    metrics_df = pd.concat([metrics_df, metrics_df_idx], axis=1)

metrics_df['Train'] = 0
metrics_df['Validation'] = 0
for n_fold in range(N_FOLDS):
    metrics_df['Train'] += metrics_df['Train_fold_%d' % n_fold] / N_FOLDS
    metrics_df['Validation'] += metrics_df['Valid_fold_%d' % n_fold] / N_FOLDS

metrics_df['Var'] = metrics_df['Train'] - metrics_df['Validation']
display(metrics_df.style.applymap(color_map))
# Out:
# <style  type="text/css" >
#     #T_ce4ec0fe_484e_11ea_afe1_0242ac1c0002row0_col0 {
#             color:  black;
#         }    #T_ce4ec0fe_484e_11ea_afe1_0242ac1c0002row0_col1 {
#             color:  black;
#         }    #T_ce4ec0fe_484e_11ea_afe1_0242ac1c0002row0_col2 {
#             color:  black;
#         }    #T_ce4ec0fe_484e_11ea_afe1_0242ac1c0002row0_col3 {
#             color:  black;
#         }    #T_ce4ec0fe_484e_11ea_afe1_0242ac1c0002row0_col4 {
#             color:  black;
#         }    #T_ce4ec0fe_484e_11ea_afe1_0242ac1c0002row0_col5 {
#             color:  black;
#         }    #T_ce4ec0fe_484e_11ea_afe1_0242ac1c0002row0_col6 {
#             color:  black;
#         }    #T_ce4ec0fe_484e_11ea_afe1_0242ac1c0002row0_col7 {
#             color:  black;
#         }    #T_ce4ec0fe_484e_11ea_afe1_0242ac1c0002row0_col8 {
#             color:  black;
#         }    #T_ce4ec0fe_484e_11ea_afe1_0242ac1c0002row0_col9 {
#             color:  black;
#         }    #T_ce4ec0fe_484e_11ea_afe1_0242ac1c0002row0_col10 {
#             color:  black;
#         }    #T_ce4ec0fe_484e_11ea_afe1_0242ac1c0002row0_col11 {
#             color:  black;
#         }    #T_ce4ec0fe_484e_11ea_afe1_0242ac1c0002row0_col12 {
#             color:  black;
#         }    #T_ce4ec0fe_484e_11ea_afe1_0242ac1c0002row0_col13 {
#             color:  orange;
#         }    #T_ce4ec0fe_484e_11ea_afe1_0242ac1c0002row1_col0 {
#             color:  black;
#         }    #T_ce4ec0fe_484e_11ea_afe1_0242ac1c0002row1_col1 {
#             color:  black;
#         }    #T_ce4ec0fe_484e_11ea_afe1_0242ac1c0002row1_col2 {
#             color:  black;
#         }    #T_ce4ec0fe_484e_11ea_afe1_0242ac1c0002row1_col3 {
#             color:  black;
#         }    #T_ce4ec0fe_484e_11ea_afe1_0242ac1c0002row1_col4 {
#             color:  black;
#         }    #T_ce4ec0fe_484e_11ea_afe1_0242ac1c0002row1_col5 {
#             color:  black;
#         }    #T_ce4ec0fe_484e_11ea_afe1_0242ac1c0002row1_col6 {
#             color:  black;
#         }    #T_ce4ec0fe_484e_11ea_afe1_0242ac1c0002row1_col7 {
#             color:  black;
#         }    #T_ce4ec0fe_484e_11ea_afe1_0242ac1c0002row1_col8 {
#             color:  black;
#         }    #T_ce4ec0fe_484e_11ea_afe1_0242ac1c0002row1_col9 {
#             color:  black;
#         }    #T_ce4ec0fe_484e_11ea_afe1_0242ac1c0002row1_col10 {
#             color:  black;
#         }    #T_ce4ec0fe_484e_11ea_afe1_0242ac1c0002row1_col11 {
#             color:  black;
#         }    #T_ce4ec0fe_484e_11ea_afe1_0242ac1c0002row1_col12 {
#             color:  black;
#         }    #T_ce4ec0fe_484e_11ea_afe1_0242ac1c0002row1_col13 {
#             color:  purple;
#         }    #T_ce4ec0fe_484e_11ea_afe1_0242ac1c0002row2_col0 {
#             color:  black;
#         }    #T_ce4ec0fe_484e_11ea_afe1_0242ac1c0002row2_col1 {
#             color:  black;
#         }    #T_ce4ec0fe_484e_11ea_afe1_0242ac1c0002row2_col2 {
#             color:  black;
#         }    #T_ce4ec0fe_484e_11ea_afe1_0242ac1c0002row2_col3 {
#             color:  black;
#         }    #T_ce4ec0fe_484e_11ea_afe1_0242ac1c0002row2_col4 {
#             color:  black;
#         }    #T_ce4ec0fe_484e_11ea_afe1_0242ac1c0002row2_col5 {
#             color:  black;
#         }    #T_ce4ec0fe_484e_11ea_afe1_0242ac1c0002row2_col6 {
#             color:  black;
#         }    #T_ce4ec0fe_484e_11ea_afe1_0242ac1c0002row2_col7 {
#             color:  black;
#         }    #T_ce4ec0fe_484e_11ea_afe1_0242ac1c0002row2_col8 {
#             color:  black;
#         }    #T_ce4ec0fe_484e_11ea_afe1_0242ac1c0002row2_col9 {
#             color:  black;
#         }    #T_ce4ec0fe_484e_11ea_afe1_0242ac1c0002row2_col10 {
#             color:  black;
#         }    #T_ce4ec0fe_484e_11ea_afe1_0242ac1c0002row2_col11 {
#             color:  black;
#         }    #T_ce4ec0fe_484e_11ea_afe1_0242ac1c0002row2_col12 {
#             color:  black;
#         }    #T_ce4ec0fe_484e_11ea_afe1_0242ac1c0002row2_col13 {
#             color:  orange;
#         }    #T_ce4ec0fe_484e_11ea_afe1_0242ac1c0002row3_col0 {
#             color:  black;
#         }    #T_ce4ec0fe_484e_11ea_afe1_0242ac1c0002row3_col1 {
#             color:  black;
#         }    #T_ce4ec0fe_484e_11ea_afe1_0242ac1c0002row3_col2 {
#             color:  black;
#         }    #T_ce4ec0fe_484e_11ea_afe1_0242ac1c0002row3_col3 {
#             color:  black;
#         }    #T_ce4ec0fe_484e_11ea_afe1_0242ac1c0002row3_col4 {
#             color:  black;
#         }    #T_ce4ec0fe_484e_11ea_afe1_0242ac1c0002row3_col5 {
#             color:  black;
#         }    #T_ce4ec0fe_484e_11ea_afe1_0242ac1c0002row3_col6 {
#             color:  black;
#         }    #T_ce4ec0fe_484e_11ea_afe1_0242ac1c0002row3_col7 {
#             color:  black;
#         }    #T_ce4ec0fe_484e_11ea_afe1_0242ac1c0002row3_col8 {
#             color:  black;
#         }    #T_ce4ec0fe_484e_11ea_afe1_0242ac1c0002row3_col9 {
#             color:  black;
#         }    #T_ce4ec0fe_484e_11ea_afe1_0242ac1c0002row3_col10 {
#             color:  black;
#         }    #T_ce4ec0fe_484e_11ea_afe1_0242ac1c0002row3_col11 {
#             color:  black;
#         }    #T_ce4ec0fe_484e_11ea_afe1_0242ac1c0002row3_col12 {
#             color:  black;
#         }    #T_ce4ec0fe_484e_11ea_afe1_0242ac1c0002row3_col13 {
#             color:  orange;
#         }    #T_ce4ec0fe_484e_11ea_afe1_0242ac1c0002row4_col0 {
#             color:  black;
#         }    #T_ce4ec0fe_484e_11ea_afe1_0242ac1c0002row4_col1 {
#             color:  black;
#         }    #T_ce4ec0fe_484e_11ea_afe1_0242ac1c0002row4_col2 {
#             color:  black;
#         }    #T_ce4ec0fe_484e_11ea_afe1_0242ac1c0002row4_col3 {
#             color:  black;
#         }    #T_ce4ec0fe_484e_11ea_afe1_0242ac1c0002row4_col4 {
#             color:  black;
#         }    #T_ce4ec0fe_484e_11ea_afe1_0242ac1c0002row4_col5 {
#             color:  black;
#         }    #T_ce4ec0fe_484e_11ea_afe1_0242ac1c0002row4_col6 {
#             color:  black;
#         }    #T_ce4ec0fe_484e_11ea_afe1_0242ac1c0002row4_col7 {
#             color:  black;
#         }    #T_ce4ec0fe_484e_11ea_afe1_0242ac1c0002row4_col8 {
#             color:  black;
#         }    #T_ce4ec0fe_484e_11ea_afe1_0242ac1c0002row4_col9 {
#             color:  black;
#         }    #T_ce4ec0fe_484e_11ea_afe1_0242ac1c0002row4_col10 {
#             color:  black;
#         }    #T_ce4ec0fe_484e_11ea_afe1_0242ac1c0002row4_col11 {
#             color:  black;
#         }    #T_ce4ec0fe_484e_11ea_afe1_0242ac1c0002row4_col12 {
#             color:  black;
#         }    #T_ce4ec0fe_484e_11ea_afe1_0242ac1c0002row4_col13 {
#             color:  purple;
#         }    #T_ce4ec0fe_484e_11ea_afe1_0242ac1c0002row5_col0 {
#             color:  black;
#         }    #T_ce4ec0fe_484e_11ea_afe1_0242ac1c0002row5_col1 {
#             color:  black;
#         }    #T_ce4ec0fe_484e_11ea_afe1_0242ac1c0002row5_col2 {
#             color:  black;
#         }    #T_ce4ec0fe_484e_11ea_afe1_0242ac1c0002row5_col3 {
#             color:  black;
#         }    #T_ce4ec0fe_484e_11ea_afe1_0242ac1c0002row5_col4 {
#             color:  black;
#         }    #T_ce4ec0fe_484e_11ea_afe1_0242ac1c0002row5_col5 {
#             color:  black;
#         }    #T_ce4ec0fe_484e_11ea_afe1_0242ac1c0002row5_col6 {
#             color:  black;
#         }    #T_ce4ec0fe_484e_11ea_afe1_0242ac1c0002row5_col7 {
#             color:  black;
#         }    #T_ce4ec0fe_484e_11ea_afe1_0242ac1c0002row5_col8 {
#             color:  black;
#         }    #T_ce4ec0fe_484e_11ea_afe1_0242ac1c0002row5_col9 {
#             color:  black;
#         }    #T_ce4ec0fe_484e_11ea_afe1_0242ac1c0002row5_col10 {
#             color:  black;
#         }    #T_ce4ec0fe_484e_11ea_afe1_0242ac1c0002row5_col11 {
#             color:  black;
#         }    #T_ce4ec0fe_484e_11ea_afe1_0242ac1c0002row5_col12 {
#             color:  black;
#         }    #T_ce4ec0fe_484e_11ea_afe1_0242ac1c0002row5_col13 {
#             color:  purple;
#         }    #T_ce4ec0fe_484e_11ea_afe1_0242ac1c0002row6_col0 {
#             color:  black;
#         }    #T_ce4ec0fe_484e_11ea_afe1_0242ac1c0002row6_col1 {
#             color:  black;
#         }    #T_ce4ec0fe_484e_11ea_afe1_0242ac1c0002row6_col2 {
#             color:  black;
#         }    #T_ce4ec0fe_484e_11ea_a

# %% [markdown]
# ## By category

# %%
category_metrics_df = category_metric_list[0][['Label', 'Train', 'Validation']].copy()
category_metrics_df.columns = ['Label', 'Train_fold_0', 'Valid_fold_0']

for n_fold in range(1, N_FOLDS):
    category_metrics_df_idx = category_metric_list[n_fold][['Train', 'Validation']].copy()
    category_metrics_df_idx.columns = ['Train_fold_%d' % n_fold, 'Valid_fold_%d' % n_fold]
    category_metrics_df = pd.concat([category_metrics_df, category_metrics_df_idx], axis=1)
    
category_metrics_df['Train'] = 0
category_metrics_df['Validation'] = 0
for n_fold in range(N_FOLDS):
    category_metrics_df['Train'] += category_metrics_df['Train_fold_%d' % n_fold] / N_FOLDS
    category_metrics_df['Validation'] += category_metrics_df['Valid_fold_%d' % n_fold] / N_FOLDS
    
category_metrics_df['Var'] = category_metrics_df['Train'] - category_metrics_df['Validation']
display(category_metrics_df.style.applymap(color_map))
# Out:
# <style  type="text/css" >
#     #T_ce5c8572_484e_11ea_afe1_0242ac1c0002row0_col0 {
#             color:  black;
#         }    #T_ce5c8572_484e_11ea_afe1_0242ac1c0002row0_col1 {
#             color:  black;
#         }    #T_ce5c8572_484e_11ea_afe1_0242ac1c0002row0_col2 {
#             color:  black;
#         }    #T_ce5c8572_484e_11ea_afe1_0242ac1c0002row0_col3 {
#             color:  black;
#         }    #T_ce5c8572_484e_11ea_afe1_0242ac1c0002row0_col4 {
#             color:  black;
#         }    #T_ce5c8572_484e_11ea_afe1_0242ac1c0002row0_col5 {
#             color:  black;
#         }    #T_ce5c8572_484e_11ea_afe1_0242ac1c0002row0_col6 {
#             color:  black;
#         }    #T_ce5c8572_484e_11ea_afe1_0242ac1c0002row0_col7 {
#             color:  black;
#         }    #T_ce5c8572_484e_11ea_afe1_0242ac1c0002row0_col8 {
#             color:  black;
#         }    #T_ce5c8572_484e_11ea_afe1_0242ac1c0002row0_col9 {
#             color:  black;
#         }    #T_ce5c8572_484e_11ea_afe1_0242ac1c0002row0_col10 {
#             color:  black;
#         }    #T_ce5c8572_484e_11ea_afe1_0242ac1c0002row0_col11 {
#             color:  black;
#         }    #T_ce5c8572_484e_11ea_afe1_0242ac1c0002row0_col12 {
#             color:  black;
#         }    #T_ce5c8572_484e_11ea_afe1_0242ac1c0002row0_col13 {
#             color:  orange;
#         }    #T_ce5c8572_484e_11ea_afe1_0242ac1c0002row1_col0 {
#             color:  black;
#         }    #T_ce5c8572_484e_11ea_afe1_0242ac1c0002row1_col1 {
#             color:  black;
#         }    #T_ce5c8572_484e_11ea_afe1_0242ac1c0002row1_col2 {
#             color:  black;
#         }    #T_ce5c8572_484e_11ea_afe1_0242ac1c0002row1_col3 {
#             color:  black;
#         }    #T_ce5c8572_484e_11ea_afe1_0242ac1c0002row1_col4 {
#             color:  black;
#         }    #T_ce5c8572_484e_11ea_afe1_0242ac1c0002row1_col5 {
#             color:  black;
#         }    #T_ce5c8572_484e_11ea_afe1_0242ac1c0002row1_col6 {
#             color:  black;
#         }    #T_ce5c8572_484e_11ea_afe1_0242ac1c0002row1_col7 {
#             color:  black;
#         }    #T_ce5c8572_484e_11ea_afe1_0242ac1c0002row1_col8 {
#             color:  black;
#         }    #T_ce5c8572_484e_11ea_afe1_0242ac1c0002row1_col9 {
#             color:  black;
#         }    #T_ce5c8572_484e_11ea_afe1_0242ac1c0002row1_col10 {
#             color:  black;
#         }    #T_ce5c8572_484e_11ea_afe1_0242ac1c0002row1_col11 {
#             color:  black;
#         }    #T_ce5c8572_484e_11ea_afe1_0242ac1c0002row1_col12 {
#             color:  black;
#         }    #T_ce5c8572_484e_11ea_afe1_0242ac1c0002row1_col13 {
#             color:  orange;
#         }    #T_ce5c8572_484e_11ea_afe1_0242ac1c0002row2_col0 {
#             color:  black;
#         }    #T_ce5c8572_484e_11ea_afe1_0242ac1c0002row2_col1 {
#             color:  black;
#         }    #T_ce5c8572_484e_11ea_afe1_0242ac1c0002row2_col2 {
#             color:  black;
#         }    #T_ce5c8572_484e_11ea_afe1_0242ac1c0002row2_col3 {
#             color:  black;
#         }    #T_ce5c8572_484e_11ea_afe1_0242ac1c0002row2_col4 {
#             color:  black;
#         }    #T_ce5c8572_484e_11ea_afe1_0242ac1c0002row2_col5 {
#             color:  black;
#         }    #T_ce5c8572_484e_11ea_afe1_0242ac1c0002row2_col6 {
#             color:  black;
#         }    #T_ce5c8572_484e_11ea_afe1_0242ac1c0002row2_col7 {
#             color:  black;
#         }    #T_ce5c8572_484e_11ea_afe1_0242ac1c0002row2_col8 {
#             color:  black;
#         }    #T_ce5c8572_484e_11ea_afe1_0242ac1c0002row2_col9 {
#             color:  black;
#         }    #T_ce5c8572_484e_11ea_afe1_0242ac1c0002row2_col10 {
#             color:  black;
#         }    #T_ce5c8572_484e_11ea_afe1_0242ac1c0002row2_col11 {
#             color:  black;
#         }    #T_ce5c8572_484e_11ea_afe1_0242ac1c0002row2_col12 {
#             color:  black;
#         }    #T_ce5c8572_484e_11ea_afe1_0242ac1c0002row2_col13 {
#             color:  orange;
#         }    #T_ce5c8572_484e_11ea_afe1_0242ac1c0002row3_col0 {
#             color:  black;
#         }    #T_ce5c8572_484e_11ea_afe1_0242ac1c0002row3_col1 {
#             color:  black;
#         }    #T_ce5c8572_484e_11ea_afe1_0242ac1c0002row3_col2 {
#             color:  orange;
#         }    #T_ce5c8572_484e_11ea_afe1_0242ac1c0002row3_col3 {
#             color:  black;
#         }    #T_ce5c8572_484e_11ea_afe1_0242ac1c0002row3_col4 {
#             color:  orange;
#         }    #T_ce5c8572_484e_11ea_afe1_0242ac1c0002row3_col5 {
#             color:  black;
#         }    #T_ce5c8572_484e_11ea_afe1_0242ac1c0002row3_col6 {
#             color:  black;
#         }    #T_ce5c8572_484e_11ea_afe1_0242ac1c0002row3_col7 {
#             color:  black;
#         }    #T_ce5c8572_484e_11ea_afe1_0242ac1c0002row3_col8 {
#             color:  orange;
#         }    #T_ce5c8572_484e_11ea_afe1_0242ac1c0002row3_col9 {
#             color:  black;
#         }    #T_ce5c8572_484e_11ea_afe1_0242ac1c0002row3_col10 {
#             color:  orange;
#         }    #T_ce5c8572_484e_11ea_afe1_0242ac1c0002row3_col11 {
#             color:  black;
#         }    #T_ce5c8572_484e_11ea_afe1_0242ac1c0002row3_col12 {
#             color:  orange;
#         }    #T_ce5c8572_484e_11ea_afe1_0242ac1c0002row3_col13 {
#             color:  orange;
#         }    #T_ce5c8572_484e_11ea_afe1_0242ac1c0002row4_col0 {
#             color:  black;
#         }    #T_ce5c8572_484e_11ea_afe1_0242ac1c0002row4_col1 {
#             color:  black;
#         }    #T_ce5c8572_484e_11ea_afe1_0242ac1c0002row4_col2 {
#             color:  black;
#         }    #T_ce5c8572_484e_11ea_afe1_0242ac1c0002row4_col3 {
#             color:  black;
#         }    #T_ce5c8572_484e_11ea_afe1_0242ac1c0002row4_col4 {
#             color:  black;
#         }    #T_ce5c8572_484e_11ea_afe1_0242ac1c0002row4_col5 {
#             color:  black;
#         }    #T_ce5c8572_484e_11ea_afe1_0242ac1c0002row4_col6 {
#             color:  orange;
#         }    #T_ce5c8572_484e_11ea_afe1_0242ac1c0002row4_col7 {
#             color:  black;
#         }    #T_ce5c8572_484e_11ea_afe1_0242ac1c0002row4_col8 {
#             color:  black;
#         }    #T_ce5c8572_484e_11ea_afe1_0242ac1c0002row4_col9 {
#             color:  black;
#         }    #T_ce5c8572_484e_11ea_afe1_0242ac1c0002row4_col10 {
#             color:  black;
#         }    #T_ce5c8572_484e_11ea_afe1_0242ac1c0002row4_col11 {
#             color:  black;
#         }    #T_ce5c8572_484e_11ea_afe1_0242ac1c0002row4_col12 {
#             color:  black;
#         }    #T_ce5c8572_484e_11ea_afe1_0242ac1c0002row4_col13 {
#             color:  orange;
#         }</style><table id="T_ce5c8572_484e_11ea_afe1_0242ac1c0002" ><thead>    <tr>        <th class="blank level0" ></th>        <th class="col_heading level0 col0" >Label</th>        <th class="col_heading level0 col1" >Train_fold_0</th>        <th class="col_heading level0 col2" >Valid_fold_0</th>        <th class="col_heading level0 col3" >Train_fold_1</th>        <th class="col_heading level0 col4" >Valid_fold_1</th>        <th class="col_heading level0 col5" >Train_fold_2</th>        <th class="col_heading level0 col6" >Valid_fold_2</th>        <th class="col_heading level0 col7" >Train_fold_3</th>        <th class="col_heading level0 col8" >Valid_fold_3</th>        <th class="col_heading level0 col9" >Train_fold_4</th>        <th class="col_heading level0 col10" >Valid_fold_4</th>        <th class="col_heading level0 col11" >Train</th>        <th class="col_heading level0 col12" >Validation</th>        <th class="col_heading level0 col13" >Var</th>    </tr></thead><tbody>
#                 <tr>
#                         <th id="T_ce5c8572_484e_11ea_afe1_0242ac1c0002level0_row0" class="row_heading level0 row0" >0</th>
#                         <td id="T_ce5c8572_484e_11ea_afe1_0242ac1c0002row0_col0" class="data row0 col0" >LIFE_ARTS</td>
#                         <td id="T_ce5c8572_484e_11ea_afe1_0242ac1c0002row0_col1" class="data row0 col1" >0.537</td>
#                         <td id="T_ce5c8572_484e_11ea_afe1_0242ac1c0002row0_col2" class="data row0 col2" >0.413</td>
#                         <td id="T_ce5c8572_484e_11ea_afe1_0242ac1c0002row0_col3" class="dat
