# %% [markdown]
# ## Dependencies

# %%
import warnings
import pandas as pd
import seaborn as sns
import tensorflow_hub as hub
import matplotlib.pyplot as plt
from tensorflow.keras import Model, optimizers
from tensorflow.keras.layers import Lambda, Input, Dense, Dropout, Concatenate, BatchNormalization, Activation
from tensorflow.keras.callbacks import EarlyStopping, ReduceLROnPlateau
from googleqa_utilityscript import *


SEED = 0
seed_everything(SEED)
warnings.filterwarnings("ignore")

# %% [markdown]
# ## Load data

# %%
hold_out = pd.read_csv('/kaggle/input/googleqa-mldataset/hold-out.csv')
train = hold_out[hold_out['set'] == 'train']
validation = hold_out[hold_out['set'] == 'validation']
test = pd.read_csv('/kaggle/input/google-quest-challenge/test.csv')

print('Train samples: %s' % len(train))
print('Validation samples: %s' % len(validation))
print('Test samples: %s' % len(test))
display(train.head())
# Out:
# Train samples: 4863
# Validation samples: 1216
# Test samples: 476
#    qa_id                                     question_title  \
# 0   3895  Magento (1.7) Bundled Product with FREE Produc...
# 1   3131                             Find router on network
# 2   1507  Negatively curved metrics minimizing the lengt...
# 3   6784               Isn’t the FAQ label obsolete by now?
# 4   2135  Changing background image one time on responsi...
#
#                                        question_body question_user_name  \
# 0  I'm looking to create a bundle offer where cus...                Joe
# 1  I've just bought a Belkin N+ Wireless Router. ...                Guy
# 2  Good afternoon everyone !\n\nI have the follow...            Selim G
# 3  Don’t get me wrong in the beginning of reading...     Benny Skogberg
# 4  The code I'm using is this one \n\nbackground:...        user2141649
#
#                               question_user_page  \
# 0  https://magento.stackexchange.com/users/16572
# 1               https://superuser.com/users/3248
# 2           https://mathoverflow.net/users/25511
# 3        https://ux.stackexchange.com/users/4679
# 4        https://stackoverflow.com/users/2141649
#
#                                               answer   answer_user_name  \
# 0  Since the third item is fixed, you can use sho...  Fabian Schmengler
# 1  You likely have the router plugged in to the m...             John T
# 2  A very partial answer: by the results of Richa...         Igor Rivin
# 3  Isn’t the FAQ label obsolete by now? \n\nI'd s...        Solracnapod
# 4  &lt;!DOCTYPE html&gt;\n&lt;html&gt;\n&lt;head&...           akkimads
#
#                               answer_user_page  \
# 0  https://magento.stackexchange.com/users/243
# 1             https://superuser.com/users/1931
# 2         https://mathoverflow.net/users/11142
# 3     https://ux.stackexchange.com/users/13153
# 4      https://stackoverflow.com/users/2375373
#
#                                                  url       category  ...  \
# 0  http://magento.stackexchange.com/questions/668...     TECHNOLOGY  ...
# 1               http://superuser.com/questions/87212     TECHNOLOGY  ...
# 2           http://mathoverflow.net/questions/203422        SCIENCE  ...
# 3  http://ux.stackexchange.com/questions/18600/is...     TECHNOLOGY  ...
# 4  http://stackoverflow.com/questions/16359492/ch...  STACKOVERFLOW  ...
#
#   answer_helpful  answer_level_of_information  answer_plausible  \
# 0       0.888889                     0.666667               1.0
# 1       1.000000                     0.666667               1.0
# 2       0.888889                     0.333333               1.0
# 3       0.888889                     0.666667               1.0
# 4       0.888889                     0.500000               1.0
#
#    answer_relevance  answer_satisfaction  answer_type_instructions  \
# 0               1.0             0.933333                  1.000000
# 1               1.0             0.866667                  0.666667
# 2               1.0             0.700000                  0.333333
# 3               1.0             0.933333                  0.000000
# 4               1.0             0.800000                  1.000000
#
#    answer_type_procedure  answer_type_reason_explanation  answer_well_written  \
# 0               0.000000                        0.333333             0.888889
# 1               0.000000                        1.000000             1.000000
# 2               0.333333                        1.000000             0.888889
# 3               0.000000                        0.666667             1.000000
# 4               0.000000                        0.000000             0.777778
#
#      set
# 0  train
# 1  train
# 2  train
# 3  train
# 4  train
#
# [5 rows x 42 columns]

# %%
question_target_cols = ['question_asker_intent_understanding','question_body_critical', 'question_conversational', 
                        'question_expect_short_answer', 'question_fact_seeking', 'question_has_commonly_accepted_answer',
                        'question_interestingness_others', 'question_interestingness_self', 'question_multi_intent', 
                        'question_not_really_a_question', 'question_opinion_seeking', 'question_type_choice',
                        'question_type_compare', 'question_type_consequence', 'question_type_definition', 
                        'question_type_entity', 'question_type_instructions', 'question_type_procedure',
                        'question_type_reason_explanation', 'question_type_spelling', 'question_well_written']
answer_target_cols = ['answer_helpful', 'answer_level_of_information', 'answer_plausible', 'answer_relevance',
                      'answer_satisfaction', 'answer_type_instructions', 'answer_type_procedure', 
                      'answer_type_reason_explanation', 'answer_well_written']
target_cols = question_target_cols + answer_target_cols

# %% [markdown]
# ## Train/validation sets

# %%
# Train features
X_train_title = train['question_title']
X_train_body = train['question_body']
X_train_answer = train['answer']

X_train = [X_train_title, X_train_body, X_train_answer]
Y_train = train[target_cols].values

# Validation features
X_valid_title = validation['question_title']
X_valid_body = validation['question_body']
X_valid_answer = validation['answer']

X_valid = [X_valid_title, X_valid_body, X_valid_answer]
Y_valid = validation[target_cols].values

print('Train samples: %d' % len(Y_train))
print('Validation samples: %d' % len(Y_valid))
# Out:
# Train samples: 4863
# Validation samples: 1216

# %% [markdown]
# # Model parameters

# %%
EPOCHS = 50
BATCH_SIZE = 32
LEARNING_RATE = 3e-4
EMBEDDDING_SIZE = 512
N_CLASS = len(target_cols)
ES_PATIENCE = 3
RLROP_PATIENCE = 2
DECAY_DROP = 0.5
module_url = '../input/universalsentenceencodermodels/universal-sentence-encoder-models/use'
model_path = '../working/use_baseline.h5'

# %% [markdown]
# # Model

# %%
es = EarlyStopping(monitor='val_loss', mode='min', patience=ES_PATIENCE, restore_best_weights=True, verbose=1)
rlrop = ReduceLROnPlateau(monitor='val_loss', mode='min', patience=RLROP_PATIENCE, factor=DECAY_DROP, min_lr=1e-6, verbose=1)
use_embed = hub.load(module_url)

def USEEmbedding(x):
    return use_embed(tf.squeeze(tf.cast(x, tf.string)))

# %%
input_title = Input(shape=(1,), dtype=tf.string, name='input_title')
embedding_title = Lambda(USEEmbedding, output_shape=(EMBEDDDING_SIZE,))(input_title)

input_body = Input(shape=(1,), dtype=tf.string, name='input_body')
embedding_body = Lambda(USEEmbedding, output_shape=(EMBEDDDING_SIZE,))(input_body)

input_answer = Input(shape=(1,), dtype=tf.string, name='input_answer')
embedding_answer = Lambda(USEEmbedding, output_shape=(EMBEDDDING_SIZE,))(input_answer)

x = Concatenate()([embedding_title, embedding_body, embedding_answer])
x = Dropout(0.5)(x)
x = Dense(512, activation='relu')(x)
x = Dropout(0.5)(x)
output = Dense(N_CLASS, activation='sigmoid', name='output')(x)
model = Model(inputs=[input_title, input_body, input_answer], outputs=[output])

model.summary()
# Out:
# Model: "model"
# __________________________________________________________________________________________________
# Layer (type)                    Output Shape         Param #     Connected to
# ==================================================================================================
# input_title (InputLayer)        [(None, 1)]          0
# __________________________________________________________________________________________________
# input_body (InputLayer)         [(None, 1)]          0
# __________________________________________________________________________________________________
# input_answer (InputLayer)       [(None, 1)]          0
# __________________________________________________________________________________________________
# lambda (Lambda)                 (None, 512)          0           input_title[0][0]
# __________________________________________________________________________________________________
# lambda_1 (Lambda)               (None, 512)          0           input_body[0][0]
# __________________________________________________________________________________________________
# lambda_2 (Lambda)               (None, 512)          0           input_answer[0][0]
# __________________________________________________________________________________________________
# concatenate (Concatenate)       (None, 1536)         0           lambda[0][0]
#                                                                  lambda_1[0][0]
#                                                                  lambda_2[0][0]
# __________________________________________________________________________________________________
# dropout (Dropout)               (None, 1536)         0           concatenate[0][0]
# __________________________________________________________________________________________________
# dense (Dense)                   (None, 512)          786944      dropout[0][0]
# __________________________________________________________________________________________________
# dropout_1 (Dropout)             (None, 512)          0           dense[0][0]
# __________________________________________________________________________________________________
# output (Dense)                  (None, 30)           15390       dropout_1[0][0]
# ==================================================================================================
# Total params: 802,334
# Trainable params: 802,334
# Non-trainable params: 0
# __________________________________________________________________________________________________

# %% [markdown]
# # Train model

# %%
optimizer = optimizers.Adam(LEARNING_RATE)
callback_list = [es, rlrop, SpearmanRhoCallback(training_data=(X_train, Y_train), validation_data=(X_valid, Y_valid))]
model.compile(optimizer=optimizer, loss='binary_crossentropy')

history = model.fit(X_train, Y_train, 
                    validation_data=(X_valid, Y_valid), 
                    callbacks=callback_list, 
                    batch_size=BATCH_SIZE,
                    epochs=EPOCHS, 
                    verbose=2).history
# Out:
# Train on 4863 samples, validate on 1216 samples
# Epoch 1/50
# Train spearman-rho: 0.2118 Validation spearman-rho: 0.1993
# 4863/4863 - 40s - loss: 0.4908 - val_loss: 0.4142
# Epoch 2/50
# Train spearman-rho: 0.2884 Validation spearman-rho: 0.2706
# 4863/4863 - 30s - loss: 0.4070 - val_loss: 0.3990
# Epoch 3/50
# Train spearman-rho: 0.3289 Validation spearman-rho: 0.3067
# 4863/4863 - 30s - loss: 0.3962 - val_loss: 0.3918
# Epoch 4/50
# Train spearman-rho: 0.3524 Validation spearman-rho: 0.3237
# 4863/4863 - 31s - loss: 0.3898 - val_loss: 0.3876
# Epoch 5/50
# Train spearman-rho: 0.3704 Validation spearman-rho: 0.3345
# 4863/4863 - 30s - loss: 0.3858 - val_loss: 0.3849
# Epoch 6/50
# Train spearman-rho: 0.3841 Validation spearman-rho: 0.3409
# 4863/4863 - 30s - loss: 0.3824 - val_loss: 0.3830
# Epoch 7/50
# Train spearman-rho: 0.3947 Validation spearman-rho: 0.3454
# 4863/4863 - 30s - loss: 0.3804 - val_loss: 0.3815
# Epoch 8/50
# Train spearman-rho: 0.4040 Validation spearman-rho: 0.3482
# 4863/4863 - 30s - loss: 0.3775 - val_loss: 0.3805
# Epoch 9/50
# Train spearman-rho: 0.4126 Validation spearman-rho: 0.3519
# 4863/4863 - 30s - loss: 0.3759 - val_loss: 0.3798
# Epoch 10/50
# Train spearman-rho: 0.4187 Validation spearman-rho: 0.3538
# 4863/4863 - 31s - loss: 0.3743 - val_loss: 0.3790
# Epoch 11/50
# Train spearman-rho: 0.4259 Validation spearman-rho: 0.3561
# 4863/4863 - 31s - loss: 0.3732 - val_loss: 0.3787
# Epoch 12/50
# Train spearman-rho: 0.4307 Validation spearman-rho: 0.3572
# 4863/4863 - 31s - loss: 0.3719 - val_loss: 0.3784
# Epoch 13/50
# Train spearman-rho: 0.4357 Validation spearman-rho: 0.3582
# 4863/4863 - 31s - loss: 0.3708 - val_loss: 0.3778
# Epoch 14/50
# Train spearman-rho: 0.4400 Validation spearman-rho: 0.3595
# 4863/4863 - 32s - loss: 0.3696 - val_loss: 0.3776
# Epoch 15/50
# Train spearman-rho: 0.4446 Validation spearman-rho: 0.3608
# 4863/4863 - 31s - loss: 0.3697 - val_loss: 0.3774
# Epoch 16/50
# Train spearman-rho: 0.4477 Validation spearman-rho: 0.3620
# 4863/4863 - 30s - loss: 0.3682 - val_loss: 0.3769
# Epoch 17/50
# Train spearman-rho: 0.4518 Validation spearman-rho: 0.3635
# 4863/4863 - 30s - loss: 0.3677 - val_loss: 0.3768
# Epoch 18/50
# Train spearman-rho: 0.4551 Validation spearman-rho: 0.3643
# 4863/4863 - 30s - loss: 0.3671 - val_loss: 0.3765
# Epoch 19/50
# Train spearman-rho: 0.4581 Validation spearman-rho: 0.3644
# 4863/4863 - 30s - loss: 0.3662 - val_loss: 0.3767
# Epoch 20/50
# Train spearman-rho: 0.4625 Validation spearman-rho: 0.3657
# 4863/4863 - 30s - loss: 0.3657 - val_loss: 0.3763
# Epoch 21/50
# Train spearman-rho: 0.4651 Validation spearman-rho: 0.3663
# 4863/4863 - 30s - loss: 0.3647 - val_loss: 0.3760
# Epoch 22/50
# Train spearman-rho: 0.4681 Validation spearman-rho: 0.3672
# 4863/4863 - 30s - loss: 0.3643 - val_loss: 0.3760
# Epoch 23/50
# Train spearman-rho: 0.4712 Validation spearman-rho: 0.3677
# 4863/4863 - 30s - loss: 0.3632 - val_loss: 0.3759
# Epoch 24/50
# Train spearman-rho: 0.4739 Validation spearman-rho: 0.3685
# 4863/4863 - 31s - loss: 0.3634 - val_loss: 0.3757
# Epoch 25/50
# Train spearman-rho: 0.4763 Validation spearman-rho: 0.3681
# 4863/4863 - 30s - loss: 0.3630 - val_loss: 0.3755
# Epoch 26/50
# Train spearman-rho: 0.4795 Validation spearman-rho: 0.3685
# 4863/4863 - 30s - loss: 0.3622 - val_loss: 0.3756
# Epoch 27/50
# Train spearman-rho: 0.4824 Validation spearman-rho: 0.3687
# 4863/4863 - 30s - loss: 0.3618 - val_loss: 0.3754
# Epoch 28/50
# Train spearman-rho: 0.4850 Validation spearman-rho: 0.3697
# 4863/4863 - 30s - loss: 0.3608 - val_loss: 0.3751
# Epoch 29/50
# Train spearman-rho: 0.4876 Validation spearman-rho: 0.3696
# 4863/4863 - 30s - loss: 0.3608 - val_loss: 0.3751
# Epoch 30/50
#
# Epoch 00030: ReduceLROnPlateau reducing learning rate to 0.0001500000071246177.
# Train spearman-rho: 0.4897 Validation spearman-rho: 0.3705
# 4863/4863 - 30s - loss: 0.3604 - val_loss: 0.3752
# Epoch 31/50
# Train spearman-rho: 0.4910 Validation spearman-rho: 0.3711
# 4863/4863 - 30s - loss: 0.3591 - val_loss: 0.3749
# Epoch 32/50
# Train spearman-rho: 0.4925 Validation spearman-rho: 0.3713
# 4863/4863 - 30s - loss: 0.3582 - val_loss: 0.3750
# Epoch 33/50
#
# Epoch 00033: ReduceLROnPlateau reducing learning rate to 7.500000356230885e-05.
# Train spearman-rho: 0.4937 Validation spearman-rho: 0.3718
# 4863/4863 - 30s - loss: 0.3583 - val_loss: 0.3749
# Epoch 34/50
# Train spearman-rho: 0.4944 Validation spearman-rho: 0.3716
# 4863/4863 - 31s - loss: 0.3581 - val_loss: 0.3748
# Epoch 35/50
#
# Epoch 00035: ReduceLROnPlateau reducing learning rate to 3.7500001781154424e-05.
# Train spearman-rho: 0.4952 Validation spearman-rho: 0.3719
# 4863/4863 - 30s - loss: 0.3584 - val_loss: 0.3749
# Epoch 36/50
# Train spearman-rho: 0.4955 Validation spearman-rho: 0.3719
# 4863/4863 - 30s - loss: 0.3571 - val_loss: 0.3748
# Epoch 37/50
# Restoring model weights from the end of the best epoch.
#
# Epoch 00037: ReduceLROnPlateau reducing learning rate to 1.8750000890577212e-05.
# Train spearman-rho: 0.4944 Validation spearman-rho: 0.3716
# 4863/4863 - 30s - loss: 0.3582 - val_loss: 0.3748
# Epoch 38/50
# Train spearman-rho: 0.4946 Validation spearman-rho: 0.3717
# 4863/4863 - 30s - loss: 0.3578 - val_loss: 0.3748
# Epoch 39/50
#
# Epoch 00039: ReduceLROnPlateau reducing learning rate to 9.375000445288606e-06.
# Train spearman-rho: 0.4948 Validation spearman-rho: 0.3718
# 4863/4863 - 30s - loss: 0.3577 - val_loss: 0.3748
# Epoch 40/50
# Train spearman-rho: 0.4949 Validation spearman-rho: 0.3717
# 4863/4863 - 30s - loss: 0.3578 - val_loss: 0.3748
# Epoch 41/50
# Restoring model weights from the end of the best epoch.
#
# Epoch 00041: ReduceLROnPlateau reducing learning rate to 4.687500222644303e-06.
# Train spearman-rho: 0.4946 Validation spearman-rho: 0.3717
# 4863/4863 - 30s - loss: 0.3581 - val_loss: 0.3748
# Epoch 42/50
# Train spearman-rho: 0.4946 Validation spearman-rho: 0.3717
# 4863/4863 - 30s - loss: 0.3571 - val_loss: 0.3748
# Epoch 43/50
#
# Epoch 00043: ReduceLROnPlateau reducing learning rate to 2.3437501113221515e-06.
# Train spearman-rho: 0.4947 Validation spearman-rho: 0.3717
# 4863/4863 - 30s - loss: 0.3578 - val_loss: 0.3748
# Epoch 44/50
# Train spearman-rho: 0.4947 Validation spearman-rho: 0.3717
# 4863/4863 - 31s - loss: 0.3577 - val_loss: 0.3748
# Epoch 45/50
# Restoring model weights from the end of the best epoch.
#
# Epoch 00045: ReduceLROnPlateau reducing learning rate to 1.1718750556610757e-06.
# Train spearman-rho: 0.4946 Validation spearman-rho: 0.3717
# 4863/4863 - 30s - loss: 0.3572 - val_loss: 0.3748
# Epoch 46/50
# Restoring model weights from the end of the best epoch.
# Train spearman-rho: 0.4946 Validation spearman-rho: 0.3717
# 4863/4863 - 30s - loss: 0.3576 - val_loss: 0.3748
# Epoch 47/50
# Restoring model weights from the end of the best epoch.
#
# Epoch 00047: ReduceLROnPlateau reducing learning rate to 1e-06.
# Train spearman-rho: 0.4946 Validation spearman-rho: 0.3717
# 4863/4863 - 30s - loss: 0.3579 - val_loss: 0.3748
# Epoch 48/50
# Restoring model weights from the end of the best epoch.
# Train spearman-rho: 0.4946 Validation spearman-rho: 0.3717
# 4863/4863 - 30s - loss: 0.3579 - val_loss: 0.3748
# Epoch 49/50
# Restoring model weights from the end of the best epoch.
# Train spearman-rho: 0.4946 Validation spearman-rho: 0.3717
# 4863/4863 - 30s - loss: 0.3580 - val_loss: 0.3748
# Epoch 50/50
# Restoring model weights from the end of the best epoch.
# Train spearman-rho: 0.4946 Validation spearman-rho: 0.3717
# 4863/4863 - 30s - loss: 0.3581 - val_loss: 0.3748
# Epoch 00050: early stopping

# %% [markdown]
# # Evaluation

# %%
preds_train = model.predict(X_train)
preds_val = model.predict(X_valid)

rho_train = np.mean([spearmanr(Y_train[:, ind], preds_train[:, ind] + np.random.normal(0, 1e-7, preds_train.shape[0])).correlation for ind in range(preds_train.shape[1])])
rho_val = np.mean([spearmanr(Y_valid[:, ind], preds_val[:, ind] + np.random.normal(0, 1e-7, preds_val.shape[0])).correlation for ind in range(preds_val.shape[1])])

print('Train spearman-rho: %.3f' % rho_train)
print('Validation spearman-rho: %.3f' % rho_val)
# Out:
# Train spearman-rho: 0.495
# Validation spearman-rho: 0.372

# %% [markdown]
# #### Save model

# %%
model.save_weights(model_path)
