# %% [markdown]
# ## Dependencies

# %%
import glob
import warnings
from tensorflow_hub import KerasLayer
from tensorflow.keras import Model, optimizers
from tensorflow.keras.callbacks import ReduceLROnPlateau
from tensorflow.keras.layers import Input, Dense, Dropout, GlobalAveragePooling1D, SpatialDropout1D, Concatenate
from googleqa_utilityscript import *
from googleqa_map_utilityscript import *
from script_lr_schedulers import WarmUpLearningRateScheduler
import bert_tokenization as tokenization


SEED = 0
seed_everything(SEED)
warnings.filterwarnings("ignore")
# Out:
# Using TensorFlow backend.

# %% [markdown]
# ## Load data

# %%
BERT_PATH = '/kaggle/input/tf-hub-bert-base/bert_base_uncased'
VOCAB_PATH = BERT_PATH + '/assets/vocab.txt'

k_fold = pd.read_csv('/kaggle/input/googleqa-mldataset/5-fold.csv')
N_FOLDS = 3

print('Samples: %s' % len(k_fold))
display(k_fold.head())
# Out:
# Samples: 6079
#    qa_id                                     question_title  \
# 0      0  What am I losing when using extension tubes in...
# 1      1  What is the distinction between a city and a s...
# 2      2  Maximum protusion length for through-hole comp...
# 3      3              Can an affidavit be used in Beit Din?
# 4      5       How do you make a binary image in Photoshop?
#
#                                        question_body question_user_name  \
# 0  After playing around with macro photography on...               ysap
# 1  I am trying to understand what kinds of places...      russellpierce
# 2  I'm working on a PCB that has through-hole com...          Joe Baker
# 3  An affidavit, from what i understand, is basic...         Scimonster
# 4  I am trying to make a binary image. I want mor...            leigero
#
#                                   question_user_page  \
# 0         https://photo.stackexchange.com/users/1024
# 1           https://rpg.stackexchange.com/users/8774
# 2  https://electronics.stackexchange.com/users/10157
# 3       https://judaism.stackexchange.com/users/5151
# 4  https://graphicdesign.stackexchange.com/users/...
#
#                                               answer answer_user_name  \
# 0  I just got extension tubes, so here's the skin...           rfusca
# 1  It might be helpful to look into the definitio...     Erik Schmidt
# 2  Do you even need grooves?  We make several pro...      Dwayne Reid
# 3  Sending an "affidavit" it is a dispute between...    Y     e     z
# 4  Check out Image Trace in Adobe Illustrator. \n...             q2ra
#
#                                     answer_user_page  \
# 0         https://photo.stackexchange.com/users/1917
# 1           https://rpg.stackexchange.com/users/1871
# 2  https://electronics.stackexchange.com/users/64754
# 3       https://judaism.stackexchange.com/users/4794
# 4  https://graphicdesign.stackexchange.com/users/...
#
#                                                  url   category  ...  \
# 0  http://photo.stackexchange.com/questions/9169/...  LIFE_ARTS  ...
# 1  http://rpg.stackexchange.com/questions/47820/w...    CULTURE  ...
# 2  http://electronics.stackexchange.com/questions...    SCIENCE  ...
# 3  http://judaism.stackexchange.com/questions/551...    CULTURE  ...
# 4  http://graphicdesign.stackexchange.com/questio...  LIFE_ARTS  ...
#
#   answer_satisfaction  answer_type_instructions  answer_type_procedure  \
# 0            0.800000                       1.0               0.000000
# 1            0.666667                       0.0               0.000000
# 2            0.666667                       0.0               0.333333
# 3            0.800000                       0.0               0.000000
# 4            0.800000                       1.0               0.000000
#
#    answer_type_reason_explanation  answer_well_written      fold_1  fold_2  \
# 0                        0.000000             1.000000       train   train
# 1                        0.666667             0.888889  validation   train
# 2                        1.000000             0.888889       train   train
# 3                        1.000000             1.000000       train   train
# 4                        1.000000             1.000000  validation   train
#
#        fold_3      fold_4      fold_5
# 0       train  validation       train
# 1       train       train       train
# 2  validation       train       train
# 3       train       train  validation
# 4       train       train       train
#
# [5 rows x 46 columns]

# %%
question_target_cols = ['question_asker_intent_understanding','question_body_critical', 'question_conversational', 
                        'question_expect_short_answer', 'question_fact_seeking', 'question_has_commonly_accepted_answer',
                        'question_interestingness_others', 'question_interestingness_self', 'question_multi_intent', 
                        'question_not_really_a_question', 'question_opinion_seeking', 'question_type_choice',
                        'question_type_compare', 'question_type_consequence', 'question_type_definition', 
                        'question_type_entity', 'question_type_instructions', 'question_type_procedure',
                        'question_type_reason_explanation', 'question_type_spelling', 'question_well_written']
answer_target_cols = ['answer_helpful', 'answer_level_of_information', 'answer_plausible', 'answer_relevance',
                      'answer_satisfaction', 'answer_type_instructions', 'answer_type_procedure', 
                      'answer_type_reason_explanation', 'answer_well_written']
target_cols = question_target_cols + answer_target_cols

# %% [markdown]
# # Pre-process data

# %%
text_features = ['question_title', 'question_body', 'answer']

for feature in text_features:
    # Lower
    k_fold[feature] = k_fold[feature].apply(lambda x: x.lower())
    # Map misspellings
    k_fold[feature] = k_fold[feature].apply(lambda x: map_misspellings(x))
    # Map contractions
    k_fold[feature] = k_fold[feature].apply(lambda x: map_contraction(x))
    # Trim text
    k_fold[feature] = k_fold[feature].apply(lambda x: x.strip())

# %% [markdown]
# # Model parameters

# %%
EPOCHS = 8
BATCH_SIZE = 8
LEARNING_RATE = 3e-5
N_CLASS = len(target_cols)
ES_PATIENCE = 2
MAX_SEQUENCE_LENGTH = 512
RLROP_PATIENCE = 1
DECAY_DROP = 0.1

# %% [markdown]
# # Model

# %%
def model_fn():
    input_word_ids = Input((MAX_SEQUENCE_LENGTH,), dtype=tf.int32, name='input_word_ids')
    input_masks = Input((MAX_SEQUENCE_LENGTH,), dtype=tf.int32, name='input_masks')
    segment_ids = Input((MAX_SEQUENCE_LENGTH,), dtype=tf.int32, name='segment_ids')

    bert_layer = KerasLayer(BERT_PATH, trainable=True)
    pooled_output, sequence_output = bert_layer([input_word_ids, input_masks, segment_ids])

    x = GlobalAveragePooling1D()(sequence_output)
    x = Dropout(0.2)(x)
    output = Dense(N_CLASS, activation="sigmoid", name="output")(x)

    model = Model(inputs=[input_word_ids, input_masks, segment_ids], outputs=output)
    
    return model

# %% [markdown]
# # Train model

# %%
rlrop = ReduceLROnPlateau(monitor='val_loss', mode='min', patience=RLROP_PATIENCE, 
                          factor=DECAY_DROP, min_lr=1e-7, verbose=1)    
tokenizer = tokenization.FullTokenizer(VOCAB_PATH, True)

history_list = []
metric_list = []
category_metric_list = []
target_cols_preds = [col+'_pred' for col in target_cols]

for n_fold in range(N_FOLDS):
    ### Data
    train = k_fold[k_fold['fold_%d' % (n_fold+1)] == 'train']
    validation = k_fold[k_fold['fold_%d' % (n_fold+1)] == 'validation']
    
    ### Create features
    # Train features
    X_train = compute_input_arays(train, text_features, tokenizer, MAX_SEQUENCE_LENGTH)
    Y_train = train[target_cols].values

    # Validation features
    X_valid = compute_input_arays(validation, text_features, tokenizer, MAX_SEQUENCE_LENGTH)
    Y_valid = validation[target_cols].values

    ### Train model
    model_path = '/kaggle/working/model_fold_%d' % (n_fold+1)
    spearmanCallback = SpearmanRhoCallback(training_data=(X_train, Y_train), 
                                           validation_data=(X_valid, Y_valid), 
                                           model_path=model_path, 
                                           monitor='val_loss', mode='min', 
                                           patience=ES_PATIENCE, checkpoint=True)
    LR_WARMUP_EPOCHS = 2
    WARMUP_BATCHES = LR_WARMUP_EPOCHS * len(train) // BATCH_SIZE
    warmup_lr = WarmUpLearningRateScheduler(WARMUP_BATCHES, LEARNING_RATE)

    callback_list = [spearmanCallback, rlrop, warmup_lr]
    optimizer = optimizers.Adam(lr=LEARNING_RATE)
    model = model_fn()
    model.compile(optimizer=optimizer, loss='binary_crossentropy')

    history = model.fit(X_train, Y_train, 
                        validation_data=(X_valid, Y_valid), 
                        callbacks=callback_list, 
                        batch_size=BATCH_SIZE, 
                        epochs=EPOCHS, 
                        verbose=2).history
    history_list.append(history)
    
    ### Evaluation - Label metrics
    model.load_weights(model_path+'.h5')
    preds_train = model.predict(X_train)
    preds_val = model.predict(X_valid)
    metric_list.append(get_metrics(Y_train, preds_train, Y_valid, preds_val, target_cols))
    
    ### Evaluation - Category metrics
    for col in target_cols_preds:
        train[col] = 0
        validation[col] = 0

    train[target_cols_preds] = preds_train
    validation[target_cols_preds] = preds_val
    category_metric_list.append(get_metrics_category(train, validation, target_cols, target_cols_preds, 'category'))
# Out:
# Train on 4864 samples, validate on 1215 samples
# Epoch 1/8
# spearman-rho: 0.3180 val_spearman-rho: 0.3010
# Saved model weights at "/kaggle/working/model_fold_1.h5"
# 4864/4864 - 505s - loss: 0.4584 - val_loss: 0.3966
# Epoch 2/8
# spearman-rho: 0.4160 val_spearman-rho: 0.3678
# Saved model weights at "/kaggle/working/model_fold_1.h5"
# 4864/4864 - 474s - loss: 0.3864 - val_loss: 0.3750
# Epoch 3/8
# spearman-rho: 0.4704 val_spearman-rho: 0.3818
#
# Epoch 00003: ReduceLROnPlateau reducing learning rate to 2.9999999242136257e-06.
# 4864/4864 - 472s - loss: 0.3670 - val_loss: 0.3759
# Epoch 4/8
# spearman-rho: 0.5106 val_spearman-rho: 0.3949
# Saved model weights at "/kaggle/working/model_fold_1.h5"
# 4864/4864 - 473s - loss: 0.3425 - val_loss: 0.3665
# Epoch 5/8
# spearman-rho: 0.5306 val_spearman-rho: 0.3940
# Epoch 00004: early stopping
#
# Epoch 00005: ReduceLROnPlateau reducing learning rate to 2.9999998787388907e-07.
# 4864/4864 - 472s - loss: 0.3354 - val_loss: 0.3677
# Train on 4864 samples, validate on 1215 samples
# Epoch 1/8
# spearman-rho: 0.3478 val_spearman-rho: 0.3186
# Saved model weights at "/kaggle/working/model_fold_2.h5"
# 4864/4864 - 503s - loss: 0.4478 - val_loss: 0.3863
# Epoch 2/8
# spearman-rho: 0.4312 val_spearman-rho: 0.3763
# Saved model weights at "/kaggle/working/model_fold_2.h5"
# 4864/4864 - 473s - loss: 0.3813 - val_loss: 0.3688
# Epoch 3/8
# spearman-rho: 0.5021 val_spearman-rho: 0.3873
#
# Epoch 00003: ReduceLROnPlateau reducing learning rate to 2.9999999242136257e-06.
# 4864/4864 - 472s - loss: 0.3630 - val_loss: 0.3702
# Epoch 4/8
# spearman-rho: 0.5348 val_spearman-rho: 0.3937
# Saved model weights at "/kaggle/working/model_fold_2.h5"
# 4864/4864 - 473s - loss: 0.3367 - val_loss: 0.3674
# Epoch 5/8
# spearman-rho: 0.5574 val_spearman-rho: 0.3922
# Epoch 00004: early stopping
#
# Epoch 00005: ReduceLROnPlateau reducing learning rate to 2.9999998787388907e-07.
# 4864/4864 - 472s - loss: 0.3288 - val_loss: 0.3691
# Train on 4859 samples, validate on 1220 samples
# Epoch 1/8
# spearman-rho: 0.3348 val_spearman-rho: 0.3082
# Saved model weights at "/kaggle/working/model_fold_3.h5"
# 4859/4859 - 504s - loss: 0.4544 - val_loss: 0.3904
# Epoch 2/8
# spearman-rho: 0.4223 val_spearman-rho: 0.3598
# Saved model weights at "/kaggle/working/model_fold_3.h5"
# 4859/4859 - 477s - loss: 0.3833 - val_loss: 0.3727
# Epoch 3/8
# spearman-rho: 0.4969 val_spearman-rho: 0.3863
# Saved model weights at "/kaggle/working/model_fold_3.h5"
# 4859/4859 - 476s - loss: 0.3649 - val_loss: 0.3682
# Epoch 4/8
# spearman-rho: 0.5621 val_spearman-rho: 0.3832
#
# Epoch 00004: ReduceLROnPlateau reducing learning rate to 2.9999999242136257e-06.
# 4859/4859 - 475s - loss: 0.3466 - val_loss: 0.3710
# Epoch 5/8
# spearman-rho: 0.6000 val_spearman-rho: 0.3866
# Epoch 00004: early stopping
#
# Epoch 00005: ReduceLROnPlateau reducing learning rate to 2.9999998787388907e-07.
# 4859/4859 - 475s - loss: 0.3172 - val_loss: 0.3717

# %% [markdown]
# ## Model loss graph

# %%
for n_fold in range(N_FOLDS):
    print('Fold: %d' % n_fold)
    sns.set(style="whitegrid")
    plot_metrics(history_list[n_fold], metric_list=['loss', 'spearman'])
# Out:
# Fold: 0
# Fold: 1
# Fold: 2

# %% [markdown]
# # Evaluation

# %%
metrics_df = metric_list[0][['Label', 'Train', 'Validation']].copy()
metrics_df.columns = ['Label', 'Train_fold_0', 'Valid_fold_0']

for n_fold in range(1, N_FOLDS):
    metrics_df_idx = metric_list[n_fold][['Train', 'Validation']].copy()
    metrics_df_idx.columns = ['Train_fold_%d' % n_fold, 'Valid_fold_%d' % n_fold]
    metrics_df = pd.concat([metrics_df, metrics_df_idx], axis=1)

metrics_df['Train'] = 0
metrics_df['Validation'] = 0
for n_fold in range(N_FOLDS):
    metrics_df['Train'] += metrics_df['Train_fold_%d' % n_fold] / N_FOLDS
    metrics_df['Validation'] += metrics_df['Valid_fold_%d' % n_fold] / N_FOLDS

metrics_df['Var'] = metrics_df['Train'] - metrics_df['Validation']
display(metrics_df.style.applymap(color_map))
# Out:
# <style  type="text/css" >
#     #T_d841f5b0_35b9_11ea_a180_f9f34b83b661row0_col0 {
#             color:  black;
#         }    #T_d841f5b0_35b9_11ea_a180_f9f34b83b661row0_col1 {
#             color:  black;
#         }    #T_d841f5b0_35b9_11ea_a180_f9f34b83b661row0_col2 {
#             color:  black;
#         }    #T_d841f5b0_35b9_11ea_a180_f9f34b83b661row0_col3 {
#             color:  black;
#         }    #T_d841f5b0_35b9_11ea_a180_f9f34b83b661row0_col4 {
#             color:  black;
#         }    #T_d841f5b0_35b9_11ea_a180_f9f34b83b661row0_col5 {
#             color:  black;
#         }    #T_d841f5b0_35b9_11ea_a180_f9f34b83b661row0_col6 {
#             color:  black;
#         }    #T_d841f5b0_35b9_11ea_a180_f9f34b83b661row0_col7 {
#             color:  black;
#         }    #T_d841f5b0_35b9_11ea_a180_f9f34b83b661row0_col8 {
#             color:  black;
#         }    #T_d841f5b0_35b9_11ea_a180_f9f34b83b661row0_col9 {
#             color:  orange;
#         }    #T_d841f5b0_35b9_11ea_a180_f9f34b83b661row1_col0 {
#             color:  black;
#         }    #T_d841f5b0_35b9_11ea_a180_f9f34b83b661row1_col1 {
#             color:  black;
#         }    #T_d841f5b0_35b9_11ea_a180_f9f34b83b661row1_col2 {
#             color:  black;
#         }    #T_d841f5b0_35b9_11ea_a180_f9f34b83b661row1_col3 {
#             color:  black;
#         }    #T_d841f5b0_35b9_11ea_a180_f9f34b83b661row1_col4 {
#             color:  black;
#         }    #T_d841f5b0_35b9_11ea_a180_f9f34b83b661row1_col5 {
#             color:  black;
#         }    #T_d841f5b0_35b9_11ea_a180_f9f34b83b661row1_col6 {
#             color:  black;
#         }    #T_d841f5b0_35b9_11ea_a180_f9f34b83b661row1_col7 {
#             color:  black;
#         }    #T_d841f5b0_35b9_11ea_a180_f9f34b83b661row1_col8 {
#             color:  black;
#         }    #T_d841f5b0_35b9_11ea_a180_f9f34b83b661row1_col9 {
#             color:  orange;
#         }    #T_d841f5b0_35b9_11ea_a180_f9f34b83b661row2_col0 {
#             color:  black;
#         }    #T_d841f5b0_35b9_11ea_a180_f9f34b83b661row2_col1 {
#             color:  black;
#         }    #T_d841f5b0_35b9_11ea_a180_f9f34b83b661row2_col2 {
#             color:  black;
#         }    #T_d841f5b0_35b9_11ea_a180_f9f34b83b661row2_col3 {
#             color:  black;
#         }    #T_d841f5b0_35b9_11ea_a180_f9f34b83b661row2_col4 {
#             color:  black;
#         }    #T_d841f5b0_35b9_11ea_a180_f9f34b83b661row2_col5 {
#             color:  black;
#         }    #T_d841f5b0_35b9_11ea_a180_f9f34b83b661row2_col6 {
#             color:  black;
#         }    #T_d841f5b0_35b9_11ea_a180_f9f34b83b661row2_col7 {
#             color:  black;
#         }    #T_d841f5b0_35b9_11ea_a180_f9f34b83b661row2_col8 {
#             color:  black;
#         }    #T_d841f5b0_35b9_11ea_a180_f9f34b83b661row2_col9 {
#             color:  orange;
#         }    #T_d841f5b0_35b9_11ea_a180_f9f34b83b661row3_col0 {
#             color:  black;
#         }    #T_d841f5b0_35b9_11ea_a180_f9f34b83b661row3_col1 {
#             color:  black;
#         }    #T_d841f5b0_35b9_11ea_a180_f9f34b83b661row3_col2 {
#             color:  black;
#         }    #T_d841f5b0_35b9_11ea_a180_f9f34b83b661row3_col3 {
#             color:  black;
#         }    #T_d841f5b0_35b9_11ea_a180_f9f34b83b661row3_col4 {
#             color:  black;
#         }    #T_d841f5b0_35b9_11ea_a180_f9f34b83b661row3_col5 {
#             color:  black;
#         }    #T_d841f5b0_35b9_11ea_a180_f9f34b83b661row3_col6 {
#             color:  orange;
#         }    #T_d841f5b0_35b9_11ea_a180_f9f34b83b661row3_col7 {
#             color:  black;
#         }    #T_d841f5b0_35b9_11ea_a180_f9f34b83b661row3_col8 {
#             color:  black;
#         }    #T_d841f5b0_35b9_11ea_a180_f9f34b83b661row3_col9 {
#             color:  orange;
#         }    #T_d841f5b0_35b9_11ea_a180_f9f34b83b661row4_col0 {
#             color:  black;
#         }    #T_d841f5b0_35b9_11ea_a180_f9f34b83b661row4_col1 {
#             color:  black;
#         }    #T_d841f5b0_35b9_11ea_a180_f9f34b83b661row4_col2 {
#             color:  black;
#         }    #T_d841f5b0_35b9_11ea_a180_f9f34b83b661row4_col3 {
#             color:  black;
#         }    #T_d841f5b0_35b9_11ea_a180_f9f34b83b661row4_col4 {
#             color:  black;
#         }    #T_d841f5b0_35b9_11ea_a180_f9f34b83b661row4_col5 {
#             color:  black;
#         }    #T_d841f5b0_35b9_11ea_a180_f9f34b83b661row4_col6 {
#             color:  black;
#         }    #T_d841f5b0_35b9_11ea_a180_f9f34b83b661row4_col7 {
#             color:  black;
#         }    #T_d841f5b0_35b9_11ea_a180_f9f34b83b661row4_col8 {
#             color:  black;
#         }    #T_d841f5b0_35b9_11ea_a180_f9f34b83b661row4_col9 {
#             color:  purple;
#         }    #T_d841f5b0_35b9_11ea_a180_f9f34b83b661row5_col0 {
#             color:  black;
#         }    #T_d841f5b0_35b9_11ea_a180_f9f34b83b661row5_col1 {
#             color:  black;
#         }    #T_d841f5b0_35b9_11ea_a180_f9f34b83b661row5_col2 {
#             color:  black;
#         }    #T_d841f5b0_35b9_11ea_a180_f9f34b83b661row5_col3 {
#             color:  black;
#         }    #T_d841f5b0_35b9_11ea_a180_f9f34b83b661row5_col4 {
#             color:  black;
#         }    #T_d841f5b0_35b9_11ea_a180_f9f34b83b661row5_col5 {
#             color:  black;
#         }    #T_d841f5b0_35b9_11ea_a180_f9f34b83b661row5_col6 {
#             color:  black;
#         }    #T_d841f5b0_35b9_11ea_a180_f9f34b83b661row5_col7 {
#             color:  black;
#         }    #T_d841f5b0_35b9_11ea_a180_f9f34b83b661row5_col8 {
#             color:  black;
#         }    #T_d841f5b0_35b9_11ea_a180_f9f34b83b661row5_col9 {
#             color:  purple;
#         }    #T_d841f5b0_35b9_11ea_a180_f9f34b83b661row6_col0 {
#             color:  black;
#         }    #T_d841f5b0_35b9_11ea_a180_f9f34b83b661row6_col1 {
#             color:  black;
#         }    #T_d841f5b0_35b9_11ea_a180_f9f34b83b661row6_col2 {
#             color:  black;
#         }    #T_d841f5b0_35b9_11ea_a180_f9f34b83b661row6_col3 {
#             color:  black;
#         }    #T_d841f5b0_35b9_11ea_a180_f9f34b83b661row6_col4 {
#             color:  orange;
#         }    #T_d841f5b0_35b9_11ea_a180_f9f34b83b661row6_col5 {
#             color:  black;
#         }    #T_d841f5b0_35b9_11ea_a180_f9f34b83b661row6_col6 {
#             color:  orange;
#         }    #T_d841f5b0_35b9_11ea_a180_f9f34b83b661row6_col7 {
#             color:  black;
#         }    #T_d841f5b0_35b9_11ea_a180_f9f34b83b661row6_col8 {
#             color:  orange;
#         }    #T_d841f5b0_35b9_11ea_a180_f9f34b83b661row6_col9 {
#             color:  orange;
#         }    #T_d841f5b0_35b9_11ea_a180_f9f34b83b661row7_col0 {
#             color:  black;
#         }    #T_d841f5b0_35b9_11ea_a180_f9f34b83b661row7_col1 {
#             color:  black;
#         }    #T_d841f5b0_35b9_11ea_a180_f9f34b83b661row7_col2 {
#             color:  black;
#         }    #T_d841f5b0_35b9_11ea_a180_f9f34b83b661row7_col3 {
#             color:  black;
#         }    #T_d841f5b0_35b9_11ea_a180_f9f34b83b661row7_col4 {
#             color:  black;
#         }    #T_d841f5b0_35b9_11ea_a180_f9f34b83b661row7_col5 {
#             color:  black;
#         }    #T_d841f5b0_35b9_11ea_a180_f9f34b83b661row7_col6 {
#             color:  black;
#         }    #T_d841f5b0_35b9_11ea_a180_f9f34b83b661row7_col7 {
#             color:  black;
#         }    #T_d841f5b0_35b9_11ea_a180_f9f34b83b661row7_col8 {
#             color:  black;
#         }    #T_d841f5b0_35b9_11ea_a180_f9f34b83b661row7_col9 {
#             color:  orange;
#         }    #T_d841f5b0_35b9_11ea_a180_f9f34b83b661row8_col0 {
#             color:  black;
#         }    #T_d841f5b0_35b9_11ea_a180_f9f34b83b661row8_col1 {
#             color:  black;
#         }    #T_d841f5b0_35b9_11ea_a180_f9f34b83b661row8_col2 {
#             color:  black;
#         }    #T_d841f5b0_35b9_11ea_a180_f9f34b83b661row8_col3 {
#             color:  black;
#         }    #T_d841f5b0_35b9_11ea_a180_f9f34b83b661row8_col4 {
#             color:  black;
#         }    #T_d841f5b0_35b9_11ea_a180_f9f34b83b661row8_col5 {
#             color:  black;
#         }    #T_d841f5b0_35b9_11ea_a180_f9f34b83b661row8_col6 {
#             color:  black;
#         }    #T_d841f5b0_35b9_11ea_a180_f9f34b83b661ro

# %% [markdown]
# ## By category

# %%
category_metrics_df = category_metric_list[0][['Label', 'Train', 'Validation']].copy()
category_metrics_df.columns = ['Label', 'Train_fold_0', 'Valid_fold_0']

for n_fold in range(1, N_FOLDS):
    category_metrics_df_idx = category_metric_list[n_fold][['Train', 'Validation']].copy()
    category_metrics_df_idx.columns = ['Train_fold_%d' % n_fold, 'Valid_fold_%d' % n_fold]
    category_metrics_df = pd.concat([category_metrics_df, category_metrics_df_idx], axis=1)
    
category_metrics_df['Train'] = 0
category_metrics_df['Validation'] = 0
for n_fold in range(N_FOLDS):
    category_metrics_df['Train'] += category_metrics_df['Train_fold_%d' % n_fold] / N_FOLDS
    category_metrics_df['Validation'] += category_metrics_df['Valid_fold_%d' % n_fold] / N_FOLDS
    
category_metrics_df['Var'] = category_metrics_df['Train'] - category_metrics_df['Validation']
display(category_metrics_df.style.applymap(color_map))
# Out:
# <style  type="text/css" >
#     #T_d84c4092_35b9_11ea_a180_f9f34b83b661row0_col0 {
#             color:  black;
#         }    #T_d84c4092_35b9_11ea_a180_f9f34b83b661row0_col1 {
#             color:  black;
#         }    #T_d84c4092_35b9_11ea_a180_f9f34b83b661row0_col2 {
#             color:  black;
#         }    #T_d84c4092_35b9_11ea_a180_f9f34b83b661row0_col3 {
#             color:  black;
#         }    #T_d84c4092_35b9_11ea_a180_f9f34b83b661row0_col4 {
#             color:  black;
#         }    #T_d84c4092_35b9_11ea_a180_f9f34b83b661row0_col5 {
#             color:  black;
#         }    #T_d84c4092_35b9_11ea_a180_f9f34b83b661row0_col6 {
#             color:  black;
#         }    #T_d84c4092_35b9_11ea_a180_f9f34b83b661row0_col7 {
#             color:  black;
#         }    #T_d84c4092_35b9_11ea_a180_f9f34b83b661row0_col8 {
#             color:  black;
#         }    #T_d84c4092_35b9_11ea_a180_f9f34b83b661row0_col9 {
#             color:  orange;
#         }    #T_d84c4092_35b9_11ea_a180_f9f34b83b661row1_col0 {
#             color:  black;
#         }    #T_d84c4092_35b9_11ea_a180_f9f34b83b661row1_col1 {
#             color:  black;
#         }    #T_d84c4092_35b9_11ea_a180_f9f34b83b661row1_col2 {
#             color:  black;
#         }    #T_d84c4092_35b9_11ea_a180_f9f34b83b661row1_col3 {
#             color:  black;
#         }    #T_d84c4092_35b9_11ea_a180_f9f34b83b661row1_col4 {
#             color:  black;
#         }    #T_d84c4092_35b9_11ea_a180_f9f34b83b661row1_col5 {
#             color:  black;
#         }    #T_d84c4092_35b9_11ea_a180_f9f34b83b661row1_col6 {
#             color:  black;
#         }    #T_d84c4092_35b9_11ea_a180_f9f34b83b661row1_col7 {
#             color:  black;
#         }    #T_d84c4092_35b9_11ea_a180_f9f34b83b661row1_col8 {
#             color:  black;
#         }    #T_d84c4092_35b9_11ea_a180_f9f34b83b661row1_col9 {
#             color:  orange;
#         }    #T_d84c4092_35b9_11ea_a180_f9f34b83b661row2_col0 {
#             color:  black;
#         }    #T_d84c4092_35b9_11ea_a180_f9f34b83b661row2_col1 {
#             color:  black;
#         }    #T_d84c4092_35b9_11ea_a180_f9f34b83b661row2_col2 {
#             color:  black;
#         }    #T_d84c4092_35b9_11ea_a180_f9f34b83b661row2_col3 {
#             color:  black;
#         }    #T_d84c4092_35b9_11ea_a180_f9f34b83b661row2_col4 {
#             color:  black;
#         }    #T_d84c4092_35b9_11ea_a180_f9f34b83b661row2_col5 {
#             color:  black;
#         }    #T_d84c4092_35b9_11ea_a180_f9f34b83b661row2_col6 {
#             color:  black;
#         }    #T_d84c4092_35b9_11ea_a180_f9f34b83b661row2_col7 {
#             color:  black;
#         }    #T_d84c4092_35b9_11ea_a180_f9f34b83b661row2_col8 {
#             color:  black;
#         }    #T_d84c4092_35b9_11ea_a180_f9f34b83b661row2_col9 {
#             color:  orange;
#         }    #T_d84c4092_35b9_11ea_a180_f9f34b83b661row3_col0 {
#             color:  black;
#         }    #T_d84c4092_35b9_11ea_a180_f9f34b83b661row3_col1 {
#             color:  black;
#         }    #T_d84c4092_35b9_11ea_a180_f9f34b83b661row3_col2 {
#             color:  orange;
#         }    #T_d84c4092_35b9_11ea_a180_f9f34b83b661row3_col3 {
#             color:  black;
#         }    #T_d84c4092_35b9_11ea_a180_f9f34b83b661row3_col4 {
#             color:  orange;
#         }    #T_d84c4092_35b9_11ea_a180_f9f34b83b661row3_col5 {
#             color:  black;
#         }    #T_d84c4092_35b9_11ea_a180_f9f34b83b661row3_col6 {
#             color:  black;
#         }    #T_d84c4092_35b9_11ea_a180_f9f34b83b661row3_col7 {
#             color:  black;
#         }    #T_d84c4092_35b9_11ea_a180_f9f34b83b661row3_col8 {
#             color:  black;
#         }    #T_d84c4092_35b9_11ea_a180_f9f34b83b661row3_col9 {
#             color:  orange;
#         }    #T_d84c4092_35b9_11ea_a180_f9f34b83b661row4_col0 {
#             color:  black;
#         }    #T_d84c4092_35b9_11ea_a180_f9f34b83b661row4_col1 {
#             color:  black;
#         }    #T_d84c4092_35b9_11ea_a180_f9f34b83b661row4_col2 {
#             color:  black;
#         }    #T_d84c4092_35b9_11ea_a180_f9f34b83b661row4_col3 {
#             color:  black;
#         }    #T_d84c4092_35b9_11ea_a180_f9f34b83b661row4_col4 {
#             color:  black;
#         }    #T_d84c4092_35b9_11ea_a180_f9f34b83b661row4_col5 {
#             color:  black;
#         }    #T_d84c4092_35b9_11ea_a180_f9f34b83b661row4_col6 {
#             color:  orange;
#         }    #T_d84c4092_35b9_11ea_a180_f9f34b83b661row4_col7 {
#             color:  black;
#         }    #T_d84c4092_35b9_11ea_a180_f9f34b83b661row4_col8 {
#             color:  black;
#         }    #T_d84c4092_35b9_11ea_a180_f9f34b83b661row4_col9 {
#             color:  orange;
#         }</style><table id="T_d84c4092_35b9_11ea_a180_f9f34b83b661" ><thead>    <tr>        <th class="blank level0" ></th>        <th class="col_heading level0 col0" >Label</th>        <th class="col_heading level0 col1" >Train_fold_0</th>        <th class="col_heading level0 col2" >Valid_fold_0</th>        <th class="col_heading level0 col3" >Train_fold_1</th>        <th class="col_heading level0 col4" >Valid_fold_1</th>        <th class="col_heading level0 col5" >Train_fold_2</th>        <th class="col_heading level0 col6" >Valid_fold_2</th>        <th class="col_heading level0 col7" >Train</th>        <th class="col_heading level0 col8" >Validation</th>        <th class="col_heading level0 col9" >Var</th>    </tr></thead><tbody>
#                 <tr>
#                         <th id="T_d84c4092_35b9_11ea_a180_f9f34b83b661level0_row0" class="row_heading level0 row0" >0</th>
#                         <td id="T_d84c4092_35b9_11ea_a180_f9f34b83b661row0_col0" class="data row0 col0" >LIFE_ARTS</td>
#                         <td id="T_d84c4092_35b9_11ea_a180_f9f34b83b661row0_col1" class="data row0 col1" >0.548</td>
#                         <td id="T_d84c4092_35b9_11ea_a180_f9f34b83b661row0_col2" class="data row0 col2" >0.423</td>
#                         <td id="T_d84c4092_35b9_11ea_a180_f9f34b83b661row0_col3" class="data row0 col3" >0.572</td>
#                         <td id="T_d84c4092_35b9_11ea_a180_f9f34b83b661row0_col4" class="data row0 col4" >0.418</td>
#                         <td id="T_d84c4092_35b9_11ea_a180_f9f34b83b661row0_col5" class="data row0 col5" >0.532</td>
#                         <td id="T_d84c4092_35b9_11ea_a180_f9f34b83b661row0_col6" class="data row0 col6" >0.415</td>
#                         <td id="T_d84c4092_35b9_11ea_a180_f9f34b83b661row0_col7" class="data row0 col7" >0.550667</td>
#                         <td id="T_d84c4092_35b9_11ea_a180_f9f34b83b661row0_col8" class="data row0 col8" >0.418667</td>
#                         <td id="T_d84c4092_35b9_11ea_a180_f9f34b83b661row0_col9" class="data row0 col9" >0.132</td>
#             </tr>
#             <tr>
#                         <th id="T_d84c4092_35b9_11ea_a180_f9f34b83b661level0_row1" class="row_heading level0 row1" >1</th>
#                         <td id="T_d84c4092_35b9_11ea_a180_f9f34b83b661row1_col0" class="data row1 col0" >SCIENCE</td>
#                         <td id="T_d84c4092_35b9_11ea_a180_f9f34b83b661row1_col1" class="data row1 col1" >0.528</td>
#                         <td id="T_d84c4092_35b9_11ea_a180_f9f34b83b661row1_col2" class="data row1 col2" >0.418</td>
#                         <td id="T_d84c4092_35b9_11ea_a180_f9f34b83b661row1_col3" class="data row1 col3" >0.577</td>
#                         <td id="T_d84c4092_35b9_11ea_a180_f9f34b83b661row1_col4" class="data row1 col4" >0.36</td>
#                         <td id="T_d84c4092_35b9_11ea_a180_f9f34b83b661row1_col5" class="data row1 col5" >0.531</td>
#                         <td id="T_d84c4092_35b9_11ea_a180_f9f34b83b661row1_col6" class="data row1 col6" >0.4</td>
#                         <td id="T_d84c4092_35b9_11ea_a180_f9f34b83b661row1_col7" class="data row1 col7" >0.545333</td>
#                         <td id="T_d84c4092_35b9_11ea_a180_f9f34b83b661row1_col8" class="data row1 col8" >0.392667</td>
#                         <td id="T_d84c4092_35b9_11ea_a180_f9f34b83b661row1_col9" class="data row1 col9" >0.152667</td>
#             </tr>
#             <tr>
