# %%
import sys
if 'google.colab' in sys.modules: # Colab-only Tensorflow version selector
  # %tensorflow_version 2.x

import tensorflow as tf
print("Tensorflow version " + tf.__version__)
# Out:
# TensorFlow 2.x selected.
# Tensorflow version 2.1.0

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Go to this URL in a browser: https://accounts.google.com/o/oauth2/auth?client_id=947318989803-6bn6qk8qdgf4n4g3pfee6491hc0brc4i.apps.googleusercontent.com&redirect_uri=urn%3aietf%3awg%3aoauth%3a2.0%3aoob&response_type=code&scope=email%20https%3a%2f%2fwww.googleapis.com%2fauth%2fdocs.test%20https%3a%2f%2fwww.googleapis.com%2fauth%2fdrive%20https%3a%2f%2fwww.googleapis.com%2fauth%2fdrive.photos.readonly%20https%3a%2f%2fwww.googleapis.com%2fauth%2fpeopleapi.readonly
#
# Enter your authorization code:
# ··········
# Mounted at /content/drive

# %%
# !cp -r '/content/drive/My Drive/Colab Notebooks/Google QUEST Q&A Labeling/Scripts/.' .

# %%
MODEL_BASE_PATH = '/content/drive/My Drive/Colab Notebooks/Google QUEST Q&A Labeling/Model backlog/Files/'
MODEL_NAME = '139-BERT_base_uncased'

# %% [markdown]
# ## Dependencies

# %%
import glob
import warnings
from tensorflow_hub import KerasLayer
from tensorflow.keras import Model, optimizers
from tensorflow.keras.callbacks import ReduceLROnPlateau
from tensorflow.keras.layers import Input, Dense, Dropout, GlobalAveragePooling1D, SpatialDropout1D, Concatenate
from googleqa_utilityscript import *
from googleqa_map_utilityscript import *
from script_lr_schedulers import WarmUpLearningRateScheduler
import bert_tokenization as tokenization


SEED = 0
seed_everything(SEED)
warnings.filterwarnings("ignore")
# Out:
# Using TensorFlow backend.

# %% [markdown]
# ## Load data

# %%
BERT_PATH = '/content/drive/My Drive/Colab Notebooks/Google QUEST Q&A Labeling/Modules/bert_base_uncased'
VOCAB_PATH = BERT_PATH + '/assets/vocab.txt'

k_fold = pd.read_csv('/content/drive/My Drive/Colab Notebooks/Google QUEST Q&A Labeling/Data/5-fold.csv')
N_FOLDS = 5

print('Samples: %s' % len(k_fold))
display(k_fold.head())
# Out:
# Samples: 6079
#    qa_id  ...      fold_5
# 0      0  ...       train
# 1      1  ...       train
# 2      2  ...       train
# 3      3  ...  validation
# 4      5  ...       train
#
# [5 rows x 46 columns]

# %%
question_target_cols = ['question_asker_intent_understanding','question_body_critical', 'question_conversational', 
                        'question_expect_short_answer', 'question_fact_seeking', 'question_has_commonly_accepted_answer',
                        'question_interestingness_others', 'question_interestingness_self', 'question_multi_intent', 
                        'question_not_really_a_question', 'question_opinion_seeking', 'question_type_choice',
                        'question_type_compare', 'question_type_consequence', 'question_type_definition', 
                        'question_type_entity', 'question_type_instructions', 'question_type_procedure',
                        'question_type_reason_explanation', 'question_type_spelling', 'question_well_written']
answer_target_cols = ['answer_helpful', 'answer_level_of_information', 'answer_plausible', 'answer_relevance',
                      'answer_satisfaction', 'answer_type_instructions', 'answer_type_procedure', 
                      'answer_type_reason_explanation', 'answer_well_written']
target_cols = question_target_cols + answer_target_cols

# %%
### BERT auxiliar function
def _get_masks(tokens, max_seq_length):
    """Mask for padding"""
    if len(tokens)>max_seq_length:
        raise IndexError("Token length more than max seq length!")
    return [1]*len(tokens) + [0] * (max_seq_length - len(tokens))

def _get_segments(tokens, max_seq_length, ignore_first_sep=True):
    """Segments: 0 for the first sequence, 1 for the second"""
    if len(tokens)>max_seq_length:
        raise IndexError("Token length more than max seq length!")
    segments = []
    current_segment_id = 0
    for token in tokens:
        segments.append(current_segment_id)
        if token == "[SEP]":
            if ignore_first_sep:
                ignore_first_sep = False 
            else:
                current_segment_id = 1
    return segments + [0] * (max_seq_length - len(tokens))

def _get_ids(tokens, tokenizer, max_seq_length):
    """Token ids from Tokenizer vocab"""
    token_ids = tokenizer.convert_tokens_to_ids(tokens)
    input_ids = token_ids + [0] * (max_seq_length-len(token_ids))
    return input_ids

def _trim_input(title, question, answer, tokenizer, max_sequence_length, 
                t_max_len=30, q_max_len=239, a_max_len=239):
    
    t = tokenizer.tokenize(title)
    q = tokenizer.tokenize(question)
    a = tokenizer.tokenize(answer)
    
    t_len = len(t)
    q_len = len(q)
    a_len = len(a)

    if (t_len+q_len+a_len+4) > max_sequence_length:
        
        if t_max_len > t_len:
            t_new_len = t_len
            a_max_len = a_max_len + floor((t_max_len - t_len)/2)
            q_max_len = q_max_len + ceil((t_max_len - t_len)/2)
        else:
            t_new_len = t_max_len
      
        if a_max_len > a_len:
            a_new_len = a_len 
            q_new_len = q_max_len + (a_max_len - a_len)
        elif q_max_len > q_len:
            a_new_len = a_max_len + (q_max_len - q_len)
            q_new_len = q_len
        else:
            a_new_len = a_max_len
            q_new_len = q_max_len
            
            
        if t_new_len+a_new_len+q_new_len+4 != max_sequence_length:
            raise ValueError("New sequence length should be %d, but is %d" 
                             % (max_sequence_length, (t_new_len+a_new_len+q_new_len+4)))
            

        t = t[:int(t_new_len*0.3)] + t[-int(t_new_len*0.7):]
        q = q[:int(q_new_len*0.3)] + q[-int(q_new_len*0.7):]
        a = a[:int(a_new_len*0.3)] + a[-int(a_new_len*0.7):]

    return t, q, a

def _convert_to_bert_inputs(title, question, answer, tokenizer, max_sequence_length, ignore_first_sep=True):
    """Converts tokenized input to ids, masks and segments for BERT"""
    
    stoken = ["[CLS]"] + title + ["[SEP]"] + question + ["[SEP]"] + answer + ["[SEP]"]

    input_ids = _get_ids(stoken, tokenizer, max_sequence_length)
    input_masks = _get_masks(stoken, max_sequence_length)
    input_segments = _get_segments(stoken, max_sequence_length, ignore_first_sep)

    return [input_ids, input_masks, input_segments]

def compute_input_arays(df, columns, tokenizer, max_sequence_length, ignore_first_sep=True):
    input_ids, input_masks, input_segments = [], [], []
    for _, instance in df[columns].iterrows():
        t, q, a = instance.question_title, instance.question_body, instance.answer

        t, q, a = _trim_input(t, q, a, tokenizer, max_sequence_length)

        ids, masks, segments = _convert_to_bert_inputs(t, q, a, tokenizer, max_sequence_length, ignore_first_sep)
        input_ids.append(ids)
        input_masks.append(masks)
        input_segments.append(segments)
        
    return [np.asarray(input_ids, dtype=np.int32), 
            np.asarray(input_masks, dtype=np.int32), 
            np.asarray(input_segments, dtype=np.int32)]

# %% [markdown]
# # Pre-process data

# %%
text_features = ['question_title', 'question_body', 'answer']

# for feature in text_features:
#     # Lower
#     k_fold[feature] = k_fold[feature].apply(lambda x: x.lower())
#     # Map misspellings
#     k_fold[feature] = k_fold[feature].apply(lambda x: map_misspellings(x))
#     # Map contractions
#     k_fold[feature] = k_fold[feature].apply(lambda x: map_contraction(x))
#     # Trim text
#     k_fold[feature] = k_fold[feature].apply(lambda x: x.strip())

# %% [markdown]
# # Model parameters

# %%
EPOCHS = 8
BATCH_SIZE = 8
LEARNING_RATE = 3e-5
N_CLASS = len(target_cols)
ES_PATIENCE = 1
MAX_SEQUENCE_LENGTH = 512
LR_WARMUP_EPOCHS = 2

# %% [markdown]
# # Model

# %%
def model_fn():
    input_word_ids = Input((MAX_SEQUENCE_LENGTH,), dtype=tf.int32, name='input_word_ids')
    input_masks = Input((MAX_SEQUENCE_LENGTH,), dtype=tf.int32, name='input_masks')
    segment_ids = Input((MAX_SEQUENCE_LENGTH,), dtype=tf.int32, name='segment_ids')

    bert_layer = KerasLayer(BERT_PATH, trainable=True)
    pooled_output, sequence_output = bert_layer([input_word_ids, input_masks, segment_ids])

    x = GlobalAveragePooling1D()(sequence_output)
    x = Dropout(0.2)(x)
    output = Dense(N_CLASS, activation="sigmoid", name="output")(x)

    model = Model(inputs=[input_word_ids, input_masks, segment_ids], outputs=output)
    
    return model

# %% [markdown]
# # Train model

# %%
tokenizer = tokenization.FullTokenizer(VOCAB_PATH, True)

history_list = []
metric_list = []
category_metric_list = []
target_cols_preds = [col+'_pred' for col in target_cols]

for n_fold in range(N_FOLDS):
    ### Data
    train = k_fold[k_fold['fold_%d' % (n_fold+1)] == 'train']
    validation = k_fold[k_fold['fold_%d' % (n_fold+1)] == 'validation']
    
    ### Create features
    # Train features
    X_train = compute_input_arays(train, text_features, tokenizer, MAX_SEQUENCE_LENGTH)
    Y_train = train[target_cols].values

    # Validation features
    X_valid = compute_input_arays(validation, text_features, tokenizer, MAX_SEQUENCE_LENGTH)
    Y_valid = validation[target_cols].values

    # Train model
    model_path = MODEL_BASE_PATH + MODEL_NAME + '_model_fold_%d' % (n_fold+1)
    spearmanCallback = SpearmanRhoCallback(training_data=(X_train, Y_train), 
                                           validation_data=(X_valid, Y_valid), 
                                           model_path=model_path, 
                                           monitor='val_loss', mode='min', 
                                           patience=ES_PATIENCE, checkpoint=True)
    WARMUP_BATCHES = LR_WARMUP_EPOCHS * len(train) // BATCH_SIZE
    warmup_lr = WarmUpLearningRateScheduler(WARMUP_BATCHES, LEARNING_RATE)

    callback_list = [spearmanCallback, warmup_lr]
    optimizer = optimizers.Adam(lr=LEARNING_RATE)
    model = model_fn()
    model.compile(optimizer=optimizer, loss='binary_crossentropy')

    history = model.fit(X_train, Y_train, 
                        validation_data=(X_valid, Y_valid), 
                        callbacks=callback_list, 
                        batch_size=BATCH_SIZE, 
                        epochs=EPOCHS, 
                        verbose=2).history
    history_list.append(history)

    # Save last epoch weights
    model.save_weights(MODEL_BASE_PATH + MODEL_NAME + '_model_fold_%d_last_epoch.h5' % (n_fold+1))
    
    ### Evaluation - Label metrics
    model.load_weights(model_path+'.h5')
    preds_train = model.predict(X_train)
    preds_val = model.predict(X_valid)
    metric_list.append(get_metrics(Y_train, preds_train, Y_valid, preds_val, target_cols))
    
    ### Evaluation - Category metrics
    for col in target_cols_preds:
        train[col] = 0
        validation[col] = 0

    train[target_cols_preds] = preds_train
    validation[target_cols_preds] = preds_val
    category_metric_list.append(get_metrics_category(train, validation, target_cols, target_cols_preds, 'category'))

# %% [markdown]
# ## Model loss graph

# %%
for n_fold in range(N_FOLDS):
    print('Fold: %d' % n_fold)
    sns.set(style="whitegrid")
    plot_metrics(history_list[n_fold], metric_list=['loss', 'spearman'])
# Out:
# Fold: 0
# Fold: 1
# Fold: 2
# Fold: 3
# Fold: 4
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# <ipython-input-15-efe72449ff86> in <module>()
#       2     print('Fold: %d' % n_fold)
#       3     sns.set(style="whitegrid")
# ----> 4     plot_metrics(history_list[n_fold], metric_list=['loss', 'spearman'])
#
# IndexError: list index out of range

# %% [markdown]
# # Evaluation

# %%
metrics_df = metric_list[0][['Label', 'Train', 'Validation']].copy()
metrics_df.columns = ['Label', 'Train_fold_0', 'Valid_fold_0']

for n_fold in range(1, N_FOLDS):
    metrics_df_idx = metric_list[n_fold][['Train', 'Validation']].copy()
    metrics_df_idx.columns = ['Train_fold_%d' % n_fold, 'Valid_fold_%d' % n_fold]
    metrics_df = pd.concat([metrics_df, metrics_df_idx], axis=1)

metrics_df['Train'] = 0
metrics_df['Validation'] = 0
for n_fold in range(N_FOLDS):
    metrics_df['Train'] += metrics_df['Train_fold_%d' % n_fold] / N_FOLDS
    metrics_df['Validation'] += metrics_df['Valid_fold_%d' % n_fold] / N_FOLDS

metrics_df['Var'] = metrics_df['Train'] - metrics_df['Validation']
display(metrics_df.style.applymap(color_map))
# Out:
# <style  type="text/css" >
#     #T_9cbb6cf8_451b_11ea_82e2_0242ac1c0002row0_col0 {
#             color:  black;
#         }    #T_9cbb6cf8_451b_11ea_82e2_0242ac1c0002row0_col1 {
#             color:  black;
#         }    #T_9cbb6cf8_451b_11ea_82e2_0242ac1c0002row0_col2 {
#             color:  black;
#         }    #T_9cbb6cf8_451b_11ea_82e2_0242ac1c0002row0_col3 {
#             color:  black;
#         }    #T_9cbb6cf8_451b_11ea_82e2_0242ac1c0002row0_col4 {
#             color:  black;
#         }    #T_9cbb6cf8_451b_11ea_82e2_0242ac1c0002row0_col5 {
#             color:  black;
#         }    #T_9cbb6cf8_451b_11ea_82e2_0242ac1c0002row0_col6 {
#             color:  black;
#         }    #T_9cbb6cf8_451b_11ea_82e2_0242ac1c0002row0_col7 {
#             color:  black;
#         }    #T_9cbb6cf8_451b_11ea_82e2_0242ac1c0002row0_col8 {
#             color:  black;
#         }    #T_9cbb6cf8_451b_11ea_82e2_0242ac1c0002row0_col9 {
#             color:  black;
#         }    #T_9cbb6cf8_451b_11ea_82e2_0242ac1c0002row0_col10 {
#             color:  black;
#         }    #T_9cbb6cf8_451b_11ea_82e2_0242ac1c0002row0_col11 {
#             color:  black;
#         }    #T_9cbb6cf8_451b_11ea_82e2_0242ac1c0002row0_col12 {
#             color:  black;
#         }    #T_9cbb6cf8_451b_11ea_82e2_0242ac1c0002row0_col13 {
#             color:  purple;
#         }    #T_9cbb6cf8_451b_11ea_82e2_0242ac1c0002row1_col0 {
#             color:  black;
#         }    #T_9cbb6cf8_451b_11ea_82e2_0242ac1c0002row1_col1 {
#             color:  black;
#         }    #T_9cbb6cf8_451b_11ea_82e2_0242ac1c0002row1_col2 {
#             color:  black;
#         }    #T_9cbb6cf8_451b_11ea_82e2_0242ac1c0002row1_col3 {
#             color:  black;
#         }    #T_9cbb6cf8_451b_11ea_82e2_0242ac1c0002row1_col4 {
#             color:  black;
#         }    #T_9cbb6cf8_451b_11ea_82e2_0242ac1c0002row1_col5 {
#             color:  black;
#         }    #T_9cbb6cf8_451b_11ea_82e2_0242ac1c0002row1_col6 {
#             color:  black;
#         }    #T_9cbb6cf8_451b_11ea_82e2_0242ac1c0002row1_col7 {
#             color:  black;
#         }    #T_9cbb6cf8_451b_11ea_82e2_0242ac1c0002row1_col8 {
#             color:  black;
#         }    #T_9cbb6cf8_451b_11ea_82e2_0242ac1c0002row1_col9 {
#             color:  black;
#         }    #T_9cbb6cf8_451b_11ea_82e2_0242ac1c0002row1_col10 {
#             color:  black;
#         }    #T_9cbb6cf8_451b_11ea_82e2_0242ac1c0002row1_col11 {
#             color:  black;
#         }    #T_9cbb6cf8_451b_11ea_82e2_0242ac1c0002row1_col12 {
#             color:  black;
#         }    #T_9cbb6cf8_451b_11ea_82e2_0242ac1c0002row1_col13 {
#             color:  purple;
#         }    #T_9cbb6cf8_451b_11ea_82e2_0242ac1c0002row2_col0 {
#             color:  black;
#         }    #T_9cbb6cf8_451b_11ea_82e2_0242ac1c0002row2_col1 {
#             color:  black;
#         }    #T_9cbb6cf8_451b_11ea_82e2_0242ac1c0002row2_col2 {
#             color:  black;
#         }    #T_9cbb6cf8_451b_11ea_82e2_0242ac1c0002row2_col3 {
#             color:  black;
#         }    #T_9cbb6cf8_451b_11ea_82e2_0242ac1c0002row2_col4 {
#             color:  black;
#         }    #T_9cbb6cf8_451b_11ea_82e2_0242ac1c0002row2_col5 {
#             color:  black;
#         }    #T_9cbb6cf8_451b_11ea_82e2_0242ac1c0002row2_col6 {
#             color:  black;
#         }    #T_9cbb6cf8_451b_11ea_82e2_0242ac1c0002row2_col7 {
#             color:  black;
#         }    #T_9cbb6cf8_451b_11ea_82e2_0242ac1c0002row2_col8 {
#             color:  black;
#         }    #T_9cbb6cf8_451b_11ea_82e2_0242ac1c0002row2_col9 {
#             color:  black;
#         }    #T_9cbb6cf8_451b_11ea_82e2_0242ac1c0002row2_col10 {
#             color:  black;
#         }    #T_9cbb6cf8_451b_11ea_82e2_0242ac1c0002row2_col11 {
#             color:  black;
#         }    #T_9cbb6cf8_451b_11ea_82e2_0242ac1c0002row2_col12 {
#             color:  black;
#         }    #T_9cbb6cf8_451b_11ea_82e2_0242ac1c0002row2_col13 {
#             color:  orange;
#         }    #T_9cbb6cf8_451b_11ea_82e2_0242ac1c0002row3_col0 {
#             color:  black;
#         }    #T_9cbb6cf8_451b_11ea_82e2_0242ac1c0002row3_col1 {
#             color:  black;
#         }    #T_9cbb6cf8_451b_11ea_82e2_0242ac1c0002row3_col2 {
#             color:  black;
#         }    #T_9cbb6cf8_451b_11ea_82e2_0242ac1c0002row3_col3 {
#             color:  black;
#         }    #T_9cbb6cf8_451b_11ea_82e2_0242ac1c0002row3_col4 {
#             color:  black;
#         }    #T_9cbb6cf8_451b_11ea_82e2_0242ac1c0002row3_col5 {
#             color:  black;
#         }    #T_9cbb6cf8_451b_11ea_82e2_0242ac1c0002row3_col6 {
#             color:  orange;
#         }    #T_9cbb6cf8_451b_11ea_82e2_0242ac1c0002row3_col7 {
#             color:  black;
#         }    #T_9cbb6cf8_451b_11ea_82e2_0242ac1c0002row3_col8 {
#             color:  black;
#         }    #T_9cbb6cf8_451b_11ea_82e2_0242ac1c0002row3_col9 {
#             color:  black;
#         }    #T_9cbb6cf8_451b_11ea_82e2_0242ac1c0002row3_col10 {
#             color:  black;
#         }    #T_9cbb6cf8_451b_11ea_82e2_0242ac1c0002row3_col11 {
#             color:  black;
#         }    #T_9cbb6cf8_451b_11ea_82e2_0242ac1c0002row3_col12 {
#             color:  black;
#         }    #T_9cbb6cf8_451b_11ea_82e2_0242ac1c0002row3_col13 {
#             color:  orange;
#         }    #T_9cbb6cf8_451b_11ea_82e2_0242ac1c0002row4_col0 {
#             color:  black;
#         }    #T_9cbb6cf8_451b_11ea_82e2_0242ac1c0002row4_col1 {
#             color:  black;
#         }    #T_9cbb6cf8_451b_11ea_82e2_0242ac1c0002row4_col2 {
#             color:  black;
#         }    #T_9cbb6cf8_451b_11ea_82e2_0242ac1c0002row4_col3 {
#             color:  black;
#         }    #T_9cbb6cf8_451b_11ea_82e2_0242ac1c0002row4_col4 {
#             color:  black;
#         }    #T_9cbb6cf8_451b_11ea_82e2_0242ac1c0002row4_col5 {
#             color:  black;
#         }    #T_9cbb6cf8_451b_11ea_82e2_0242ac1c0002row4_col6 {
#             color:  black;
#         }    #T_9cbb6cf8_451b_11ea_82e2_0242ac1c0002row4_col7 {
#             color:  black;
#         }    #T_9cbb6cf8_451b_11ea_82e2_0242ac1c0002row4_col8 {
#             color:  black;
#         }    #T_9cbb6cf8_451b_11ea_82e2_0242ac1c0002row4_col9 {
#             color:  black;
#         }    #T_9cbb6cf8_451b_11ea_82e2_0242ac1c0002row4_col10 {
#             color:  black;
#         }    #T_9cbb6cf8_451b_11ea_82e2_0242ac1c0002row4_col11 {
#             color:  black;
#         }    #T_9cbb6cf8_451b_11ea_82e2_0242ac1c0002row4_col12 {
#             color:  black;
#         }    #T_9cbb6cf8_451b_11ea_82e2_0242ac1c0002row4_col13 {
#             color:  purple;
#         }    #T_9cbb6cf8_451b_11ea_82e2_0242ac1c0002row5_col0 {
#             color:  black;
#         }    #T_9cbb6cf8_451b_11ea_82e2_0242ac1c0002row5_col1 {
#             color:  black;
#         }    #T_9cbb6cf8_451b_11ea_82e2_0242ac1c0002row5_col2 {
#             color:  black;
#         }    #T_9cbb6cf8_451b_11ea_82e2_0242ac1c0002row5_col3 {
#             color:  black;
#         }    #T_9cbb6cf8_451b_11ea_82e2_0242ac1c0002row5_col4 {
#             color:  black;
#         }    #T_9cbb6cf8_451b_11ea_82e2_0242ac1c0002row5_col5 {
#             color:  black;
#         }    #T_9cbb6cf8_451b_11ea_82e2_0242ac1c0002row5_col6 {
#             color:  black;
#         }    #T_9cbb6cf8_451b_11ea_82e2_0242ac1c0002row5_col7 {
#             color:  black;
#         }    #T_9cbb6cf8_451b_11ea_82e2_0242ac1c0002row5_col8 {
#             color:  black;
#         }    #T_9cbb6cf8_451b_11ea_82e2_0242ac1c0002row5_col9 {
#             color:  black;
#         }    #T_9cbb6cf8_451b_11ea_82e2_0242ac1c0002row5_col10 {
#             color:  black;
#         }    #T_9cbb6cf8_451b_11ea_82e2_0242ac1c0002row5_col11 {
#             color:  black;
#         }    #T_9cbb6cf8_451b_11ea_82e2_0242ac1c0002row5_col12 {
#             color:  black;
#         }    #T_9cbb6cf8_451b_11ea_82e2_0242ac1c0002row5_col13 {
#             color:  purple;
#         }    #T_9cbb6cf8_451b_11ea_82e2_0242ac1c0002row6_col0 {
#             color:  black;
#         }    #T_9cbb6cf8_451b_11ea_82e2_0242ac1c0002row6_col1 {
#             color:  black;
#         }    #T_9cbb6cf8_451b_11ea_82e2_0242ac1c0002row6_col2 {
#             color:  black;
#         }    #T_9cbb6cf8_451b_11ea_

# %% [markdown]
# ## By category

# %%
category_metrics_df = category_metric_list[0][['Label', 'Train', 'Validation']].copy()
category_metrics_df.columns = ['Label', 'Train_fold_0', 'Valid_fold_0']

for n_fold in range(1, N_FOLDS):
    category_metrics_df_idx = category_metric_list[n_fold][['Train', 'Validation']].copy()
    category_metrics_df_idx.columns = ['Train_fold_%d' % n_fold, 'Valid_fold_%d' % n_fold]
    category_metrics_df = pd.concat([category_metrics_df, category_metrics_df_idx], axis=1)
    
category_metrics_df['Train'] = 0
category_metrics_df['Validation'] = 0
for n_fold in range(N_FOLDS):
    category_metrics_df['Train'] += category_metrics_df['Train_fold_%d' % n_fold] / N_FOLDS
    category_metrics_df['Validation'] += category_metrics_df['Valid_fold_%d' % n_fold] / N_FOLDS
    
category_metrics_df['Var'] = category_metrics_df['Train'] - category_metrics_df['Validation']
display(category_metrics_df.style.applymap(color_map))
# Out:
# <style  type="text/css" >
#     #T_9d25c2ec_451b_11ea_82e2_0242ac1c0002row0_col0 {
#             color:  black;
#         }    #T_9d25c2ec_451b_11ea_82e2_0242ac1c0002row0_col1 {
#             color:  black;
#         }    #T_9d25c2ec_451b_11ea_82e2_0242ac1c0002row0_col2 {
#             color:  black;
#         }    #T_9d25c2ec_451b_11ea_82e2_0242ac1c0002row0_col3 {
#             color:  black;
#         }    #T_9d25c2ec_451b_11ea_82e2_0242ac1c0002row0_col4 {
#             color:  black;
#         }    #T_9d25c2ec_451b_11ea_82e2_0242ac1c0002row0_col5 {
#             color:  black;
#         }    #T_9d25c2ec_451b_11ea_82e2_0242ac1c0002row0_col6 {
#             color:  black;
#         }    #T_9d25c2ec_451b_11ea_82e2_0242ac1c0002row0_col7 {
#             color:  black;
#         }    #T_9d25c2ec_451b_11ea_82e2_0242ac1c0002row0_col8 {
#             color:  black;
#         }    #T_9d25c2ec_451b_11ea_82e2_0242ac1c0002row0_col9 {
#             color:  black;
#         }    #T_9d25c2ec_451b_11ea_82e2_0242ac1c0002row0_col10 {
#             color:  black;
#         }    #T_9d25c2ec_451b_11ea_82e2_0242ac1c0002row0_col11 {
#             color:  black;
#         }    #T_9d25c2ec_451b_11ea_82e2_0242ac1c0002row0_col12 {
#             color:  black;
#         }    #T_9d25c2ec_451b_11ea_82e2_0242ac1c0002row0_col13 {
#             color:  orange;
#         }    #T_9d25c2ec_451b_11ea_82e2_0242ac1c0002row1_col0 {
#             color:  black;
#         }    #T_9d25c2ec_451b_11ea_82e2_0242ac1c0002row1_col1 {
#             color:  black;
#         }    #T_9d25c2ec_451b_11ea_82e2_0242ac1c0002row1_col2 {
#             color:  black;
#         }    #T_9d25c2ec_451b_11ea_82e2_0242ac1c0002row1_col3 {
#             color:  black;
#         }    #T_9d25c2ec_451b_11ea_82e2_0242ac1c0002row1_col4 {
#             color:  black;
#         }    #T_9d25c2ec_451b_11ea_82e2_0242ac1c0002row1_col5 {
#             color:  black;
#         }    #T_9d25c2ec_451b_11ea_82e2_0242ac1c0002row1_col6 {
#             color:  black;
#         }    #T_9d25c2ec_451b_11ea_82e2_0242ac1c0002row1_col7 {
#             color:  black;
#         }    #T_9d25c2ec_451b_11ea_82e2_0242ac1c0002row1_col8 {
#             color:  black;
#         }    #T_9d25c2ec_451b_11ea_82e2_0242ac1c0002row1_col9 {
#             color:  black;
#         }    #T_9d25c2ec_451b_11ea_82e2_0242ac1c0002row1_col10 {
#             color:  black;
#         }    #T_9d25c2ec_451b_11ea_82e2_0242ac1c0002row1_col11 {
#             color:  black;
#         }    #T_9d25c2ec_451b_11ea_82e2_0242ac1c0002row1_col12 {
#             color:  black;
#         }    #T_9d25c2ec_451b_11ea_82e2_0242ac1c0002row1_col13 {
#             color:  orange;
#         }    #T_9d25c2ec_451b_11ea_82e2_0242ac1c0002row2_col0 {
#             color:  black;
#         }    #T_9d25c2ec_451b_11ea_82e2_0242ac1c0002row2_col1 {
#             color:  black;
#         }    #T_9d25c2ec_451b_11ea_82e2_0242ac1c0002row2_col2 {
#             color:  black;
#         }    #T_9d25c2ec_451b_11ea_82e2_0242ac1c0002row2_col3 {
#             color:  black;
#         }    #T_9d25c2ec_451b_11ea_82e2_0242ac1c0002row2_col4 {
#             color:  black;
#         }    #T_9d25c2ec_451b_11ea_82e2_0242ac1c0002row2_col5 {
#             color:  black;
#         }    #T_9d25c2ec_451b_11ea_82e2_0242ac1c0002row2_col6 {
#             color:  black;
#         }    #T_9d25c2ec_451b_11ea_82e2_0242ac1c0002row2_col7 {
#             color:  black;
#         }    #T_9d25c2ec_451b_11ea_82e2_0242ac1c0002row2_col8 {
#             color:  black;
#         }    #T_9d25c2ec_451b_11ea_82e2_0242ac1c0002row2_col9 {
#             color:  black;
#         }    #T_9d25c2ec_451b_11ea_82e2_0242ac1c0002row2_col10 {
#             color:  black;
#         }    #T_9d25c2ec_451b_11ea_82e2_0242ac1c0002row2_col11 {
#             color:  black;
#         }    #T_9d25c2ec_451b_11ea_82e2_0242ac1c0002row2_col12 {
#             color:  black;
#         }    #T_9d25c2ec_451b_11ea_82e2_0242ac1c0002row2_col13 {
#             color:  purple;
#         }    #T_9d25c2ec_451b_11ea_82e2_0242ac1c0002row3_col0 {
#             color:  black;
#         }    #T_9d25c2ec_451b_11ea_82e2_0242ac1c0002row3_col1 {
#             color:  black;
#         }    #T_9d25c2ec_451b_11ea_82e2_0242ac1c0002row3_col2 {
#             color:  orange;
#         }    #T_9d25c2ec_451b_11ea_82e2_0242ac1c0002row3_col3 {
#             color:  black;
#         }    #T_9d25c2ec_451b_11ea_82e2_0242ac1c0002row3_col4 {
#             color:  orange;
#         }    #T_9d25c2ec_451b_11ea_82e2_0242ac1c0002row3_col5 {
#             color:  black;
#         }    #T_9d25c2ec_451b_11ea_82e2_0242ac1c0002row3_col6 {
#             color:  black;
#         }    #T_9d25c2ec_451b_11ea_82e2_0242ac1c0002row3_col7 {
#             color:  black;
#         }    #T_9d25c2ec_451b_11ea_82e2_0242ac1c0002row3_col8 {
#             color:  orange;
#         }    #T_9d25c2ec_451b_11ea_82e2_0242ac1c0002row3_col9 {
#             color:  black;
#         }    #T_9d25c2ec_451b_11ea_82e2_0242ac1c0002row3_col10 {
#             color:  orange;
#         }    #T_9d25c2ec_451b_11ea_82e2_0242ac1c0002row3_col11 {
#             color:  black;
#         }    #T_9d25c2ec_451b_11ea_82e2_0242ac1c0002row3_col12 {
#             color:  orange;
#         }    #T_9d25c2ec_451b_11ea_82e2_0242ac1c0002row3_col13 {
#             color:  orange;
#         }    #T_9d25c2ec_451b_11ea_82e2_0242ac1c0002row4_col0 {
#             color:  black;
#         }    #T_9d25c2ec_451b_11ea_82e2_0242ac1c0002row4_col1 {
#             color:  black;
#         }    #T_9d25c2ec_451b_11ea_82e2_0242ac1c0002row4_col2 {
#             color:  black;
#         }    #T_9d25c2ec_451b_11ea_82e2_0242ac1c0002row4_col3 {
#             color:  black;
#         }    #T_9d25c2ec_451b_11ea_82e2_0242ac1c0002row4_col4 {
#             color:  black;
#         }    #T_9d25c2ec_451b_11ea_82e2_0242ac1c0002row4_col5 {
#             color:  black;
#         }    #T_9d25c2ec_451b_11ea_82e2_0242ac1c0002row4_col6 {
#             color:  orange;
#         }    #T_9d25c2ec_451b_11ea_82e2_0242ac1c0002row4_col7 {
#             color:  black;
#         }    #T_9d25c2ec_451b_11ea_82e2_0242ac1c0002row4_col8 {
#             color:  black;
#         }    #T_9d25c2ec_451b_11ea_82e2_0242ac1c0002row4_col9 {
#             color:  black;
#         }    #T_9d25c2ec_451b_11ea_82e2_0242ac1c0002row4_col10 {
#             color:  black;
#         }    #T_9d25c2ec_451b_11ea_82e2_0242ac1c0002row4_col11 {
#             color:  black;
#         }    #T_9d25c2ec_451b_11ea_82e2_0242ac1c0002row4_col12 {
#             color:  black;
#         }    #T_9d25c2ec_451b_11ea_82e2_0242ac1c0002row4_col13 {
#             color:  orange;
#         }</style><table id="T_9d25c2ec_451b_11ea_82e2_0242ac1c0002" ><thead>    <tr>        <th class="blank level0" ></th>        <th class="col_heading level0 col0" >Label</th>        <th class="col_heading level0 col1" >Train_fold_0</th>        <th class="col_heading level0 col2" >Valid_fold_0</th>        <th class="col_heading level0 col3" >Train_fold_1</th>        <th class="col_heading level0 col4" >Valid_fold_1</th>        <th class="col_heading level0 col5" >Train_fold_2</th>        <th class="col_heading level0 col6" >Valid_fold_2</th>        <th class="col_heading level0 col7" >Train_fold_3</th>        <th class="col_heading level0 col8" >Valid_fold_3</th>        <th class="col_heading level0 col9" >Train_fold_4</th>        <th class="col_heading level0 col10" >Valid_fold_4</th>        <th class="col_heading level0 col11" >Train</th>        <th class="col_heading level0 col12" >Validation</th>        <th class="col_heading level0 col13" >Var</th>    </tr></thead><tbody>
#                 <tr>
#                         <th id="T_9d25c2ec_451b_11ea_82e2_0242ac1c0002level0_row0" class="row_heading level0 row0" >0</th>
#                         <td id="T_9d25c2ec_451b_11ea_82e2_0242ac1c0002row0_col0" class="data row0 col0" >LIFE_ARTS</td>
#                         <td id="T_9d25c2ec_451b_11ea_82e2_0242ac1c0002row0_col1" class="data row0 col1" >0.514</td>
#                         <td id="T_9d25c2ec_451b_11ea_82e2_0242ac1c0002row0_col2" class="data row0 col2" >0.404</td>
#                         <td id="T_9d25c2ec_451b_11ea_82e2_0242ac1c0002row0_col3" class="dat
