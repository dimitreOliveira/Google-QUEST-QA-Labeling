# %%
# !pip --quiet install transformers
# Out:
#      |████████████████████████████████| 481kB 2.8MB/s
#      |████████████████████████████████| 3.1MB 13.4MB/s
#      |████████████████████████████████| 1.0MB 32.3MB/s
#      |████████████████████████████████| 870kB 37.9MB/s
#   Building wheel for sacremoses (setup.py) ... done

# %%
import sys
if 'google.colab' in sys.modules: # Colab-only Tensorflow version selector
  # %tensorflow_version 2.x

import tensorflow as tf
print("Tensorflow version " + tf.__version__)
# Out:
# TensorFlow 2.x selected.
# Tensorflow version 2.1.0

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Go to this URL in a browser: https://accounts.google.com/o/oauth2/auth?client_id=947318989803-6bn6qk8qdgf4n4g3pfee6491hc0brc4i.apps.googleusercontent.com&redirect_uri=urn%3aietf%3awg%3aoauth%3a2.0%3aoob&response_type=code&scope=email%20https%3a%2f%2fwww.googleapis.com%2fauth%2fdocs.test%20https%3a%2f%2fwww.googleapis.com%2fauth%2fdrive%20https%3a%2f%2fwww.googleapis.com%2fauth%2fdrive.photos.readonly%20https%3a%2f%2fwww.googleapis.com%2fauth%2fpeopleapi.readonly
#
# Enter your authorization code:
# ··········
# Mounted at /content/drive

# %%
# !cp -r '/content/drive/My Drive/Colab Notebooks/Google QUEST Q&A Labeling/Scripts/.' .

# %%
MODEL_BASE_PATH = '/content/drive/My Drive/Colab Notebooks/Google QUEST Q&A Labeling/Model backlog/Files/'
MODEL_NAME = '140-DistilBert'

# %% [markdown]
# ## Dependencies

# %%
import glob
import warnings
from tensorflow.keras import Model, optimizers
from tensorflow.keras.layers import Input, Dense, Dropout, GlobalAveragePooling1D, Concatenate
from googleqa_utilityscript import *
from script_lr_schedulers import WarmUpLearningRateScheduler
from transformers import DistilBertConfig, DistilBertTokenizer, TFDistilBertModel


SEED = 0
seed_everything(SEED)
warnings.filterwarnings("ignore")
# Out:
# Using TensorFlow backend.

# %% [markdown]
# ## Load data

# %%
MODULE_BASE_PATH = '/content/drive/My Drive/Colab Notebooks/Google QUEST Q&A Labeling/Modules/distilbert/distilbert-base-uncased'
MODULE_PATH = MODULE_BASE_PATH + '/distilbert-base-uncased-tf_model.h5'
VOCAB_PATH = MODULE_BASE_PATH + '/bert-base-uncased-vocab.txt'
CONF_PATH = MODULE_BASE_PATH + '/distilbert-base-uncased-config.json'

k_fold = pd.read_csv('/content/drive/My Drive/Colab Notebooks/Google QUEST Q&A Labeling/Data/5-fold.csv')
N_FOLDS = 5

print('Samples: %s' % len(k_fold))
display(k_fold.head())
# Out:
# Samples: 6079
#    qa_id  ...      fold_5
# 0      0  ...       train
# 1      1  ...       train
# 2      2  ...       train
# 3      3  ...  validation
# 4      5  ...       train
#
# [5 rows x 46 columns]

# %%
question_target_cols = ['question_asker_intent_understanding','question_body_critical', 'question_conversational', 
                        'question_expect_short_answer', 'question_fact_seeking', 'question_has_commonly_accepted_answer',
                        'question_interestingness_others', 'question_interestingness_self', 'question_multi_intent', 
                        'question_not_really_a_question', 'question_opinion_seeking', 'question_type_choice',
                        'question_type_compare', 'question_type_consequence', 'question_type_definition', 
                        'question_type_entity', 'question_type_instructions', 'question_type_procedure',
                        'question_type_reason_explanation', 'question_type_spelling', 'question_well_written']
answer_target_cols = ['answer_helpful', 'answer_level_of_information', 'answer_plausible', 'answer_relevance',
                      'answer_satisfaction', 'answer_type_instructions', 'answer_type_procedure', 
                      'answer_type_reason_explanation', 'answer_well_written']
target_cols = question_target_cols + answer_target_cols

# %% [markdown]
# # Pre-process data

# %%
text_features = ['question_title', 'question_body', 'answer']
text_features_question = ['question_title', 'question_body']
text_features_answer = ['question_title', 'answer']

# %% [markdown]
# # Model parameters

# %%
EPOCHS = 8
BATCH_SIZE = 10
LEARNING_RATE = 3e-5
N_CLASS = len(target_cols)
N_CLASS_QUESTION = len(question_target_cols)
N_CLASS_ANSWER = len(answer_target_cols)
ES_PATIENCE = 1
LR_WARMUP_EPOCHS = 2
MAX_SEQUENCE_LENGTH = 512
MAX_LENGTH_TITLE = 30
MAX_LENGTH_QUESTION = 479
MAX_LENGTH_ANSWER = 479

# %% [markdown]
# # Model

# %%
module_config = DistilBertConfig.from_pretrained(CONF_PATH)
module_config.output_hidden_states=False

def model_fn():
    input_word_ids_question = Input((MAX_SEQUENCE_LENGTH,), dtype=tf.int32, name='input_word_ids_question')
    input_masks_question = Input((MAX_SEQUENCE_LENGTH,), dtype=tf.int32, name='input_masks_question')
    segment_ids_question = Input((MAX_SEQUENCE_LENGTH,), dtype=tf.int32, name='segment_ids_question')

    input_word_ids_answer = Input((MAX_SEQUENCE_LENGTH,), dtype=tf.int32, name='input_word_ids_answer')
    input_masks_answer = Input((MAX_SEQUENCE_LENGTH,), dtype=tf.int32, name='input_masks_answer')
    segment_ids_answer = Input((MAX_SEQUENCE_LENGTH,), dtype=tf.int32, name='segment_ids_answer')

    module_model = TFDistilBertModel.from_pretrained(MODULE_PATH, config=module_config)
    sequence_output_question = module_model([input_word_ids_question, input_masks_question])
    sequence_output_answer = module_model([input_word_ids_answer, input_masks_answer])

    sequence_output_question = sequence_output_question[0] # The last hidden-state is the first element of the output tuple
    sequence_output_answer = sequence_output_answer[0] # The last hidden-state is the first element of the output tuple
    
    x_question = GlobalAveragePooling1D()(sequence_output_question)
    x_question = Dropout(0.2)(x_question)
    output_question = Dense(N_CLASS_QUESTION, kernel_initializer='glorot_uniform', activation="sigmoid", name="output_question")(x_question)
    
    x_answer = GlobalAveragePooling1D()(sequence_output_answer)
    x_answer = Dropout(0.2)(x_answer)
    output_answer = Dense(N_CLASS_ANSWER, kernel_initializer='glorot_uniform', activation="sigmoid", name="output_answer")(x_answer)
    
    output = Concatenate()([output_question, output_answer])

    model = Model(inputs=[input_word_ids_question, input_masks_question, segment_ids_question, 
                          input_word_ids_answer, input_masks_answer, segment_ids_answer], outputs=output)

    return model

# %% [markdown]
# # Train model

# %%
tokenizer = DistilBertTokenizer.from_pretrained(VOCAB_PATH, do_lower_case=True)

history_list = []
metric_list = []
category_metric_list = []
target_cols_preds = [col+'_pred' for col in target_cols]

for n_fold in range(N_FOLDS):
    ### Data
    train = k_fold[k_fold['fold_%d' % (n_fold+1)] == 'train']
    validation = k_fold[k_fold['fold_%d' % (n_fold+1)] == 'validation']
    
    ### Create features
    # Train features
    X_train = compute_input_arays_2(train, text_features_question, tokenizer, MAX_SEQUENCE_LENGTH, 
                                    MAX_LENGTH_TITLE, MAX_LENGTH_QUESTION, ignore_first_sep=False)\
                + compute_input_arays_2(train, text_features_answer, tokenizer, MAX_SEQUENCE_LENGTH, 
                                        MAX_LENGTH_TITLE, MAX_LENGTH_ANSWER, ignore_first_sep=False)
    Y_train = train[target_cols].values

    # Validation features
    X_valid = compute_input_arays_2(validation, text_features_question, tokenizer, MAX_SEQUENCE_LENGTH, 
                                    MAX_LENGTH_TITLE, MAX_LENGTH_QUESTION, ignore_first_sep=False)\
                + compute_input_arays_2(validation, text_features_answer, tokenizer, MAX_SEQUENCE_LENGTH, 
                                        MAX_LENGTH_TITLE, MAX_LENGTH_ANSWER, ignore_first_sep=False)
    Y_valid = validation[target_cols].values

    # Train model
    model_path = MODEL_BASE_PATH + MODEL_NAME + '_model_fold_%d' % (n_fold+1)
    spearmanCallback = SpearmanRhoCallback(training_data=(X_train, Y_train), 
                                           validation_data=(X_valid, Y_valid), 
                                           model_path=model_path, 
                                           monitor='val_loss', mode='min', 
                                           patience=ES_PATIENCE, checkpoint=True)
    WARMUP_BATCHES = LR_WARMUP_EPOCHS * len(train) // BATCH_SIZE
    warmup_lr = WarmUpLearningRateScheduler(WARMUP_BATCHES, LEARNING_RATE)

    callback_list = [spearmanCallback, warmup_lr]
    optimizer = optimizers.Adam(lr=LEARNING_RATE)
    model = model_fn()
    model.compile(optimizer=optimizer, loss='binary_crossentropy')

    history = model.fit(X_train, Y_train, 
                        validation_data=(X_valid, Y_valid), 
                        callbacks=callback_list, 
                        batch_size=BATCH_SIZE, 
                        epochs=EPOCHS, 
                        verbose=2).history
    history_list.append(history)

    # Save last epoch weights
    model.save_weights(MODEL_BASE_PATH + MODEL_NAME + '_model_fold_%d_last_epoch.h5' % (n_fold+1))
    
    ### Evaluation - Label metrics
    model.load_weights(model_path+'.h5')
    preds_train = model.predict(X_train)
    preds_val = model.predict(X_valid)
    metric_list.append(get_metrics(Y_train, preds_train, Y_valid, preds_val, target_cols))
    
    ### Evaluation - Category metrics
    for col in target_cols_preds:
        train[col] = 0
        validation[col] = 0

    train[target_cols_preds] = preds_train
    validation[target_cols_preds] = preds_val
    category_metric_list.append(get_metrics_category(train, validation, target_cols, target_cols_preds, 'category'))
# Out:
# Calling DistilBertTokenizer.from_pretrained() with the path to a single file or url is deprecated

# %% [markdown]
# ## Model loss graph

# %%
for n_fold in range(N_FOLDS):
    print('Fold: %d' % n_fold)
    sns.set(style="whitegrid")
    plot_metrics(history_list[n_fold], metric_list=['loss', 'spearman'])

# %% [markdown]
# # Evaluation

# %%
metrics_df = metric_list[0][['Label', 'Train', 'Validation']].copy()
metrics_df.columns = ['Label', 'Train_fold_0', 'Valid_fold_0']

for n_fold in range(1, N_FOLDS):
    metrics_df_idx = metric_list[n_fold][['Train', 'Validation']].copy()
    metrics_df_idx.columns = ['Train_fold_%d' % n_fold, 'Valid_fold_%d' % n_fold]
    metrics_df = pd.concat([metrics_df, metrics_df_idx], axis=1)

metrics_df['Train'] = 0
metrics_df['Validation'] = 0
for n_fold in range(N_FOLDS):
    metrics_df['Train'] += metrics_df['Train_fold_%d' % n_fold] / N_FOLDS
    metrics_df['Validation'] += metrics_df['Valid_fold_%d' % n_fold] / N_FOLDS

metrics_df['Var'] = metrics_df['Train'] - metrics_df['Validation']
display(metrics_df.style.applymap(color_map))
# Out:
# <style  type="text/css" >
#     #T_beab56ca_46a1_11ea_a2dc_0242ac1c0002row0_col0 {
#             color:  black;
#         }    #T_beab56ca_46a1_11ea_a2dc_0242ac1c0002row0_col1 {
#             color:  black;
#         }    #T_beab56ca_46a1_11ea_a2dc_0242ac1c0002row0_col2 {
#             color:  black;
#         }    #T_beab56ca_46a1_11ea_a2dc_0242ac1c0002row0_col3 {
#             color:  black;
#         }    #T_beab56ca_46a1_11ea_a2dc_0242ac1c0002row0_col4 {
#             color:  black;
#         }    #T_beab56ca_46a1_11ea_a2dc_0242ac1c0002row0_col5 {
#             color:  black;
#         }    #T_beab56ca_46a1_11ea_a2dc_0242ac1c0002row0_col6 {
#             color:  black;
#         }    #T_beab56ca_46a1_11ea_a2dc_0242ac1c0002row0_col7 {
#             color:  black;
#         }    #T_beab56ca_46a1_11ea_a2dc_0242ac1c0002row0_col8 {
#             color:  black;
#         }    #T_beab56ca_46a1_11ea_a2dc_0242ac1c0002row0_col9 {
#             color:  black;
#         }    #T_beab56ca_46a1_11ea_a2dc_0242ac1c0002row0_col10 {
#             color:  black;
#         }    #T_beab56ca_46a1_11ea_a2dc_0242ac1c0002row0_col11 {
#             color:  black;
#         }    #T_beab56ca_46a1_11ea_a2dc_0242ac1c0002row0_col12 {
#             color:  black;
#         }    #T_beab56ca_46a1_11ea_a2dc_0242ac1c0002row0_col13 {
#             color:  purple;
#         }    #T_beab56ca_46a1_11ea_a2dc_0242ac1c0002row1_col0 {
#             color:  black;
#         }    #T_beab56ca_46a1_11ea_a2dc_0242ac1c0002row1_col1 {
#             color:  black;
#         }    #T_beab56ca_46a1_11ea_a2dc_0242ac1c0002row1_col2 {
#             color:  black;
#         }    #T_beab56ca_46a1_11ea_a2dc_0242ac1c0002row1_col3 {
#             color:  black;
#         }    #T_beab56ca_46a1_11ea_a2dc_0242ac1c0002row1_col4 {
#             color:  black;
#         }    #T_beab56ca_46a1_11ea_a2dc_0242ac1c0002row1_col5 {
#             color:  black;
#         }    #T_beab56ca_46a1_11ea_a2dc_0242ac1c0002row1_col6 {
#             color:  black;
#         }    #T_beab56ca_46a1_11ea_a2dc_0242ac1c0002row1_col7 {
#             color:  black;
#         }    #T_beab56ca_46a1_11ea_a2dc_0242ac1c0002row1_col8 {
#             color:  black;
#         }    #T_beab56ca_46a1_11ea_a2dc_0242ac1c0002row1_col9 {
#             color:  black;
#         }    #T_beab56ca_46a1_11ea_a2dc_0242ac1c0002row1_col10 {
#             color:  black;
#         }    #T_beab56ca_46a1_11ea_a2dc_0242ac1c0002row1_col11 {
#             color:  black;
#         }    #T_beab56ca_46a1_11ea_a2dc_0242ac1c0002row1_col12 {
#             color:  black;
#         }    #T_beab56ca_46a1_11ea_a2dc_0242ac1c0002row1_col13 {
#             color:  purple;
#         }    #T_beab56ca_46a1_11ea_a2dc_0242ac1c0002row2_col0 {
#             color:  black;
#         }    #T_beab56ca_46a1_11ea_a2dc_0242ac1c0002row2_col1 {
#             color:  black;
#         }    #T_beab56ca_46a1_11ea_a2dc_0242ac1c0002row2_col2 {
#             color:  black;
#         }    #T_beab56ca_46a1_11ea_a2dc_0242ac1c0002row2_col3 {
#             color:  black;
#         }    #T_beab56ca_46a1_11ea_a2dc_0242ac1c0002row2_col4 {
#             color:  black;
#         }    #T_beab56ca_46a1_11ea_a2dc_0242ac1c0002row2_col5 {
#             color:  black;
#         }    #T_beab56ca_46a1_11ea_a2dc_0242ac1c0002row2_col6 {
#             color:  black;
#         }    #T_beab56ca_46a1_11ea_a2dc_0242ac1c0002row2_col7 {
#             color:  black;
#         }    #T_beab56ca_46a1_11ea_a2dc_0242ac1c0002row2_col8 {
#             color:  black;
#         }    #T_beab56ca_46a1_11ea_a2dc_0242ac1c0002row2_col9 {
#             color:  black;
#         }    #T_beab56ca_46a1_11ea_a2dc_0242ac1c0002row2_col10 {
#             color:  black;
#         }    #T_beab56ca_46a1_11ea_a2dc_0242ac1c0002row2_col11 {
#             color:  black;
#         }    #T_beab56ca_46a1_11ea_a2dc_0242ac1c0002row2_col12 {
#             color:  black;
#         }    #T_beab56ca_46a1_11ea_a2dc_0242ac1c0002row2_col13 {
#             color:  orange;
#         }    #T_beab56ca_46a1_11ea_a2dc_0242ac1c0002row3_col0 {
#             color:  black;
#         }    #T_beab56ca_46a1_11ea_a2dc_0242ac1c0002row3_col1 {
#             color:  black;
#         }    #T_beab56ca_46a1_11ea_a2dc_0242ac1c0002row3_col2 {
#             color:  black;
#         }    #T_beab56ca_46a1_11ea_a2dc_0242ac1c0002row3_col3 {
#             color:  black;
#         }    #T_beab56ca_46a1_11ea_a2dc_0242ac1c0002row3_col4 {
#             color:  black;
#         }    #T_beab56ca_46a1_11ea_a2dc_0242ac1c0002row3_col5 {
#             color:  black;
#         }    #T_beab56ca_46a1_11ea_a2dc_0242ac1c0002row3_col6 {
#             color:  black;
#         }    #T_beab56ca_46a1_11ea_a2dc_0242ac1c0002row3_col7 {
#             color:  black;
#         }    #T_beab56ca_46a1_11ea_a2dc_0242ac1c0002row3_col8 {
#             color:  black;
#         }    #T_beab56ca_46a1_11ea_a2dc_0242ac1c0002row3_col9 {
#             color:  black;
#         }    #T_beab56ca_46a1_11ea_a2dc_0242ac1c0002row3_col10 {
#             color:  black;
#         }    #T_beab56ca_46a1_11ea_a2dc_0242ac1c0002row3_col11 {
#             color:  black;
#         }    #T_beab56ca_46a1_11ea_a2dc_0242ac1c0002row3_col12 {
#             color:  black;
#         }    #T_beab56ca_46a1_11ea_a2dc_0242ac1c0002row3_col13 {
#             color:  orange;
#         }    #T_beab56ca_46a1_11ea_a2dc_0242ac1c0002row4_col0 {
#             color:  black;
#         }    #T_beab56ca_46a1_11ea_a2dc_0242ac1c0002row4_col1 {
#             color:  black;
#         }    #T_beab56ca_46a1_11ea_a2dc_0242ac1c0002row4_col2 {
#             color:  black;
#         }    #T_beab56ca_46a1_11ea_a2dc_0242ac1c0002row4_col3 {
#             color:  black;
#         }    #T_beab56ca_46a1_11ea_a2dc_0242ac1c0002row4_col4 {
#             color:  black;
#         }    #T_beab56ca_46a1_11ea_a2dc_0242ac1c0002row4_col5 {
#             color:  black;
#         }    #T_beab56ca_46a1_11ea_a2dc_0242ac1c0002row4_col6 {
#             color:  black;
#         }    #T_beab56ca_46a1_11ea_a2dc_0242ac1c0002row4_col7 {
#             color:  black;
#         }    #T_beab56ca_46a1_11ea_a2dc_0242ac1c0002row4_col8 {
#             color:  black;
#         }    #T_beab56ca_46a1_11ea_a2dc_0242ac1c0002row4_col9 {
#             color:  black;
#         }    #T_beab56ca_46a1_11ea_a2dc_0242ac1c0002row4_col10 {
#             color:  black;
#         }    #T_beab56ca_46a1_11ea_a2dc_0242ac1c0002row4_col11 {
#             color:  black;
#         }    #T_beab56ca_46a1_11ea_a2dc_0242ac1c0002row4_col12 {
#             color:  black;
#         }    #T_beab56ca_46a1_11ea_a2dc_0242ac1c0002row4_col13 {
#             color:  purple;
#         }    #T_beab56ca_46a1_11ea_a2dc_0242ac1c0002row5_col0 {
#             color:  black;
#         }    #T_beab56ca_46a1_11ea_a2dc_0242ac1c0002row5_col1 {
#             color:  black;
#         }    #T_beab56ca_46a1_11ea_a2dc_0242ac1c0002row5_col2 {
#             color:  black;
#         }    #T_beab56ca_46a1_11ea_a2dc_0242ac1c0002row5_col3 {
#             color:  black;
#         }    #T_beab56ca_46a1_11ea_a2dc_0242ac1c0002row5_col4 {
#             color:  black;
#         }    #T_beab56ca_46a1_11ea_a2dc_0242ac1c0002row5_col5 {
#             color:  black;
#         }    #T_beab56ca_46a1_11ea_a2dc_0242ac1c0002row5_col6 {
#             color:  black;
#         }    #T_beab56ca_46a1_11ea_a2dc_0242ac1c0002row5_col7 {
#             color:  black;
#         }    #T_beab56ca_46a1_11ea_a2dc_0242ac1c0002row5_col8 {
#             color:  black;
#         }    #T_beab56ca_46a1_11ea_a2dc_0242ac1c0002row5_col9 {
#             color:  black;
#         }    #T_beab56ca_46a1_11ea_a2dc_0242ac1c0002row5_col10 {
#             color:  black;
#         }    #T_beab56ca_46a1_11ea_a2dc_0242ac1c0002row5_col11 {
#             color:  black;
#         }    #T_beab56ca_46a1_11ea_a2dc_0242ac1c0002row5_col12 {
#             color:  black;
#         }    #T_beab56ca_46a1_11ea_a2dc_0242ac1c0002row5_col13 {
#             color:  purple;
#         }    #T_beab56ca_46a1_11ea_a2dc_0242ac1c0002row6_col0 {
#             color:  black;
#         }    #T_beab56ca_46a1_11ea_a2dc_0242ac1c0002row6_col1 {
#             color:  black;
#         }    #T_beab56ca_46a1_11ea_a2dc_0242ac1c0002row6_col2 {
#             color:  black;
#         }    #T_beab56ca_46a1_11ea_a

# %% [markdown]
# ## By category

# %%
category_metrics_df = category_metric_list[0][['Label', 'Train', 'Validation']].copy()
category_metrics_df.columns = ['Label', 'Train_fold_0', 'Valid_fold_0']

for n_fold in range(1, N_FOLDS):
    category_metrics_df_idx = category_metric_list[n_fold][['Train', 'Validation']].copy()
    category_metrics_df_idx.columns = ['Train_fold_%d' % n_fold, 'Valid_fold_%d' % n_fold]
    category_metrics_df = pd.concat([category_metrics_df, category_metrics_df_idx], axis=1)
    
category_metrics_df['Train'] = 0
category_metrics_df['Validation'] = 0
for n_fold in range(N_FOLDS):
    category_metrics_df['Train'] += category_metrics_df['Train_fold_%d' % n_fold] / N_FOLDS
    category_metrics_df['Validation'] += category_metrics_df['Valid_fold_%d' % n_fold] / N_FOLDS
    
category_metrics_df['Var'] = category_metrics_df['Train'] - category_metrics_df['Validation']
display(category_metrics_df.style.applymap(color_map))
# Out:
# <style  type="text/css" >
#     #T_beb68004_46a1_11ea_a2dc_0242ac1c0002row0_col0 {
#             color:  black;
#         }    #T_beb68004_46a1_11ea_a2dc_0242ac1c0002row0_col1 {
#             color:  black;
#         }    #T_beb68004_46a1_11ea_a2dc_0242ac1c0002row0_col2 {
#             color:  black;
#         }    #T_beb68004_46a1_11ea_a2dc_0242ac1c0002row0_col3 {
#             color:  black;
#         }    #T_beb68004_46a1_11ea_a2dc_0242ac1c0002row0_col4 {
#             color:  black;
#         }    #T_beb68004_46a1_11ea_a2dc_0242ac1c0002row0_col5 {
#             color:  black;
#         }    #T_beb68004_46a1_11ea_a2dc_0242ac1c0002row0_col6 {
#             color:  black;
#         }    #T_beb68004_46a1_11ea_a2dc_0242ac1c0002row0_col7 {
#             color:  black;
#         }    #T_beb68004_46a1_11ea_a2dc_0242ac1c0002row0_col8 {
#             color:  black;
#         }    #T_beb68004_46a1_11ea_a2dc_0242ac1c0002row0_col9 {
#             color:  black;
#         }    #T_beb68004_46a1_11ea_a2dc_0242ac1c0002row0_col10 {
#             color:  black;
#         }    #T_beb68004_46a1_11ea_a2dc_0242ac1c0002row0_col11 {
#             color:  black;
#         }    #T_beb68004_46a1_11ea_a2dc_0242ac1c0002row0_col12 {
#             color:  black;
#         }    #T_beb68004_46a1_11ea_a2dc_0242ac1c0002row0_col13 {
#             color:  orange;
#         }    #T_beb68004_46a1_11ea_a2dc_0242ac1c0002row1_col0 {
#             color:  black;
#         }    #T_beb68004_46a1_11ea_a2dc_0242ac1c0002row1_col1 {
#             color:  black;
#         }    #T_beb68004_46a1_11ea_a2dc_0242ac1c0002row1_col2 {
#             color:  black;
#         }    #T_beb68004_46a1_11ea_a2dc_0242ac1c0002row1_col3 {
#             color:  black;
#         }    #T_beb68004_46a1_11ea_a2dc_0242ac1c0002row1_col4 {
#             color:  black;
#         }    #T_beb68004_46a1_11ea_a2dc_0242ac1c0002row1_col5 {
#             color:  black;
#         }    #T_beb68004_46a1_11ea_a2dc_0242ac1c0002row1_col6 {
#             color:  black;
#         }    #T_beb68004_46a1_11ea_a2dc_0242ac1c0002row1_col7 {
#             color:  black;
#         }    #T_beb68004_46a1_11ea_a2dc_0242ac1c0002row1_col8 {
#             color:  black;
#         }    #T_beb68004_46a1_11ea_a2dc_0242ac1c0002row1_col9 {
#             color:  black;
#         }    #T_beb68004_46a1_11ea_a2dc_0242ac1c0002row1_col10 {
#             color:  black;
#         }    #T_beb68004_46a1_11ea_a2dc_0242ac1c0002row1_col11 {
#             color:  black;
#         }    #T_beb68004_46a1_11ea_a2dc_0242ac1c0002row1_col12 {
#             color:  black;
#         }    #T_beb68004_46a1_11ea_a2dc_0242ac1c0002row1_col13 {
#             color:  orange;
#         }    #T_beb68004_46a1_11ea_a2dc_0242ac1c0002row2_col0 {
#             color:  black;
#         }    #T_beb68004_46a1_11ea_a2dc_0242ac1c0002row2_col1 {
#             color:  black;
#         }    #T_beb68004_46a1_11ea_a2dc_0242ac1c0002row2_col2 {
#             color:  black;
#         }    #T_beb68004_46a1_11ea_a2dc_0242ac1c0002row2_col3 {
#             color:  black;
#         }    #T_beb68004_46a1_11ea_a2dc_0242ac1c0002row2_col4 {
#             color:  black;
#         }    #T_beb68004_46a1_11ea_a2dc_0242ac1c0002row2_col5 {
#             color:  black;
#         }    #T_beb68004_46a1_11ea_a2dc_0242ac1c0002row2_col6 {
#             color:  black;
#         }    #T_beb68004_46a1_11ea_a2dc_0242ac1c0002row2_col7 {
#             color:  black;
#         }    #T_beb68004_46a1_11ea_a2dc_0242ac1c0002row2_col8 {
#             color:  black;
#         }    #T_beb68004_46a1_11ea_a2dc_0242ac1c0002row2_col9 {
#             color:  black;
#         }    #T_beb68004_46a1_11ea_a2dc_0242ac1c0002row2_col10 {
#             color:  black;
#         }    #T_beb68004_46a1_11ea_a2dc_0242ac1c0002row2_col11 {
#             color:  black;
#         }    #T_beb68004_46a1_11ea_a2dc_0242ac1c0002row2_col12 {
#             color:  black;
#         }    #T_beb68004_46a1_11ea_a2dc_0242ac1c0002row2_col13 {
#             color:  purple;
#         }    #T_beb68004_46a1_11ea_a2dc_0242ac1c0002row3_col0 {
#             color:  black;
#         }    #T_beb68004_46a1_11ea_a2dc_0242ac1c0002row3_col1 {
#             color:  black;
#         }    #T_beb68004_46a1_11ea_a2dc_0242ac1c0002row3_col2 {
#             color:  orange;
#         }    #T_beb68004_46a1_11ea_a2dc_0242ac1c0002row3_col3 {
#             color:  black;
#         }    #T_beb68004_46a1_11ea_a2dc_0242ac1c0002row3_col4 {
#             color:  orange;
#         }    #T_beb68004_46a1_11ea_a2dc_0242ac1c0002row3_col5 {
#             color:  black;
#         }    #T_beb68004_46a1_11ea_a2dc_0242ac1c0002row3_col6 {
#             color:  black;
#         }    #T_beb68004_46a1_11ea_a2dc_0242ac1c0002row3_col7 {
#             color:  black;
#         }    #T_beb68004_46a1_11ea_a2dc_0242ac1c0002row3_col8 {
#             color:  orange;
#         }    #T_beb68004_46a1_11ea_a2dc_0242ac1c0002row3_col9 {
#             color:  black;
#         }    #T_beb68004_46a1_11ea_a2dc_0242ac1c0002row3_col10 {
#             color:  orange;
#         }    #T_beb68004_46a1_11ea_a2dc_0242ac1c0002row3_col11 {
#             color:  black;
#         }    #T_beb68004_46a1_11ea_a2dc_0242ac1c0002row3_col12 {
#             color:  orange;
#         }    #T_beb68004_46a1_11ea_a2dc_0242ac1c0002row3_col13 {
#             color:  orange;
#         }    #T_beb68004_46a1_11ea_a2dc_0242ac1c0002row4_col0 {
#             color:  black;
#         }    #T_beb68004_46a1_11ea_a2dc_0242ac1c0002row4_col1 {
#             color:  black;
#         }    #T_beb68004_46a1_11ea_a2dc_0242ac1c0002row4_col2 {
#             color:  black;
#         }    #T_beb68004_46a1_11ea_a2dc_0242ac1c0002row4_col3 {
#             color:  black;
#         }    #T_beb68004_46a1_11ea_a2dc_0242ac1c0002row4_col4 {
#             color:  black;
#         }    #T_beb68004_46a1_11ea_a2dc_0242ac1c0002row4_col5 {
#             color:  black;
#         }    #T_beb68004_46a1_11ea_a2dc_0242ac1c0002row4_col6 {
#             color:  orange;
#         }    #T_beb68004_46a1_11ea_a2dc_0242ac1c0002row4_col7 {
#             color:  black;
#         }    #T_beb68004_46a1_11ea_a2dc_0242ac1c0002row4_col8 {
#             color:  black;
#         }    #T_beb68004_46a1_11ea_a2dc_0242ac1c0002row4_col9 {
#             color:  black;
#         }    #T_beb68004_46a1_11ea_a2dc_0242ac1c0002row4_col10 {
#             color:  black;
#         }    #T_beb68004_46a1_11ea_a2dc_0242ac1c0002row4_col11 {
#             color:  black;
#         }    #T_beb68004_46a1_11ea_a2dc_0242ac1c0002row4_col12 {
#             color:  black;
#         }    #T_beb68004_46a1_11ea_a2dc_0242ac1c0002row4_col13 {
#             color:  orange;
#         }</style><table id="T_beb68004_46a1_11ea_a2dc_0242ac1c0002" ><thead>    <tr>        <th class="blank level0" ></th>        <th class="col_heading level0 col0" >Label</th>        <th class="col_heading level0 col1" >Train_fold_0</th>        <th class="col_heading level0 col2" >Valid_fold_0</th>        <th class="col_heading level0 col3" >Train_fold_1</th>        <th class="col_heading level0 col4" >Valid_fold_1</th>        <th class="col_heading level0 col5" >Train_fold_2</th>        <th class="col_heading level0 col6" >Valid_fold_2</th>        <th class="col_heading level0 col7" >Train_fold_3</th>        <th class="col_heading level0 col8" >Valid_fold_3</th>        <th class="col_heading level0 col9" >Train_fold_4</th>        <th class="col_heading level0 col10" >Valid_fold_4</th>        <th class="col_heading level0 col11" >Train</th>        <th class="col_heading level0 col12" >Validation</th>        <th class="col_heading level0 col13" >Var</th>    </tr></thead><tbody>
#                 <tr>
#                         <th id="T_beb68004_46a1_11ea_a2dc_0242ac1c0002level0_row0" class="row_heading level0 row0" >0</th>
#                         <td id="T_beb68004_46a1_11ea_a2dc_0242ac1c0002row0_col0" class="data row0 col0" >LIFE_ARTS</td>
#                         <td id="T_beb68004_46a1_11ea_a2dc_0242ac1c0002row0_col1" class="data row0 col1" >0.5</td>
#                         <td id="T_beb68004_46a1_11ea_a2dc_0242ac1c0002row0_col2" class="data row0 col2" >0.411</td>
#                         <td id="T_beb68004_46a1_11ea_a2dc_0242ac1c0002row0_col3" class="data
