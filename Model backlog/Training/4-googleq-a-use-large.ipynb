# %% [markdown]
# ## Dependencies

# %%
import warnings
import pandas as pd
import seaborn as sns
import tensorflow_hub as hub
import matplotlib.pyplot as plt
from tensorflow.keras import Model, optimizers
from tensorflow.keras.layers import Lambda, Input, Dense, Dropout, Concatenate, BatchNormalization, Activation
from tensorflow.keras.callbacks import EarlyStopping, ReduceLROnPlateau
from googleqa_utilityscript import *


SEED = 0
seed_everything(SEED)
warnings.filterwarnings("ignore")

# %% [markdown]
# ## Load data

# %%
hold_out = pd.read_csv('/kaggle/input/googleqa-dataset/hold-out.csv')
train = hold_out[hold_out['set'] == 'train']
validation = hold_out[hold_out['set'] == 'validation']
test = pd.read_csv('/kaggle/input/google-quest-challenge/test.csv')

print('Train samples: %s' % len(train))
print('Validation samples: %s' % len(validation))
print('Test samples: %s' % len(test))
display(train.head())
# Out:
# Train samples: 4863
# Validation samples: 1216
# Test samples: 476
#    qa_id                                     question_title  \
# 0   6148    Important non-technical course for programmers?
# 1   3971                     Water : Aquatic :: Sand : xxx?
# 2   4367  Learning the musical concepts in the book "Göd...
# 3   6605      HowTo: Add Class to Sidebar Widget List-Items
# 4   6522                       MVC4 jQuery UI does not work
#
#                                        question_body question_user_name  \
# 0  What kind of non-technical training course do ...         Louis Rhys
# 1  Just as aquatic is to water and aerial is to a...       coleopterist
# 2  I am reading the book "Gödel, Escher, Bach", i...      Otavio Macedo
# 3  The newest version of Bootstrap (v3.0) adds a ...            sleeper
# 4  I cannot get jQuery UI working in my ASP.NET M...               Petr
#
#                                  question_user_page  \
# 0  https://programmers.stackexchange.com/users/8486
# 1     https://english.stackexchange.com/users/23608
# 2       https://music.stackexchange.com/users/12666
# 3   https://wordpress.stackexchange.com/users/12116
# 4            https://stackoverflow.com/users/958557
#
#                                               answer answer_user_name  \
# 0  Business\n\nThe biggest problem I've seen with...       Ryan Hayes
# 1  Well, fancy words for ‘sandy’ are arenarious a...          tchrist
# 2  I agree with luser droog's answer.\n\nMy under...      luser droog
# 3  Update: I fixed the debug warning and everythi...          sleeper
# 4  In the layout.cshtml view, move \n\n@Scripts.R...     Yuri Morales
#
#                                    answer_user_page  \
# 0  https://programmers.stackexchange.com/users/1521
# 1      https://english.stackexchange.com/users/2085
# 2        https://music.stackexchange.com/users/1344
# 3   https://wordpress.stackexchange.com/users/12116
# 4           https://stackoverflow.com/users/1459163
#
#                                                  url       category  ...  \
# 0  http://programmers.stackexchange.com/questions...     TECHNOLOGY  ...
# 1  http://english.stackexchange.com/questions/938...        CULTURE  ...
# 2  http://music.stackexchange.com/questions/22216...      LIFE_ARTS  ...
# 3  http://wordpress.stackexchange.com/questions/1...     TECHNOLOGY  ...
# 4  http://stackoverflow.com/questions/13112519/mv...  STACKOVERFLOW  ...
#
#   answer_helpful  answer_level_of_information  answer_plausible  \
# 0       1.000000                     0.666667               1.0
# 1       1.000000                     1.000000               1.0
# 2       1.000000                     0.666667               1.0
# 3       0.777778                     0.555556               1.0
# 4       1.000000                     0.666667               1.0
#
#    answer_relevance  answer_satisfaction  answer_type_instructions  \
# 0               1.0             0.933333                  0.000000
# 1               1.0             1.000000                  0.000000
# 2               1.0             0.900000                  0.333333
# 3               1.0             0.733333                  0.500000
# 4               1.0             1.000000                  0.000000
#
#    answer_type_procedure  answer_type_reason_explanation  answer_well_written  \
# 0               0.000000                             1.0             0.888889
# 1               0.000000                             1.0             0.888889
# 2               0.333333                             1.0             0.777778
# 3               0.000000                             0.5             0.888889
# 4               1.000000                             0.0             1.000000
#
#      set
# 0  train
# 1  train
# 2  train
# 3  train
# 4  train
#
# [5 rows x 42 columns]

# %%
question_target_cols = ['question_asker_intent_understanding','question_body_critical', 'question_conversational', 
                        'question_expect_short_answer', 'question_fact_seeking', 'question_has_commonly_accepted_answer',
                        'question_interestingness_others', 'question_interestingness_self', 'question_multi_intent', 
                        'question_not_really_a_question', 'question_opinion_seeking', 'question_type_choice',
                        'question_type_compare', 'question_type_consequence', 'question_type_definition', 
                        'question_type_entity', 'question_type_instructions', 'question_type_procedure',
                        'question_type_reason_explanation', 'question_type_spelling', 'question_well_written']
answer_target_cols = ['answer_helpful', 'answer_level_of_information', 'answer_plausible', 'answer_relevance',
                      'answer_satisfaction', 'answer_type_instructions', 'answer_type_procedure', 
                      'answer_type_reason_explanation', 'answer_well_written']
target_cols = question_target_cols + answer_target_cols

# %% [markdown]
# ## Train/validation sets

# %%
# Train features
X_train_title = train['question_title']
X_train_body = train['question_body']
X_train_answer = train['answer']

X_train = [X_train_title, X_train_body, X_train_answer]
Y_train = train[target_cols].values

# Validation features
X_valid_title = validation['question_title']
X_valid_body = validation['question_body']
X_valid_answer = validation['answer']

X_valid = [X_valid_title, X_valid_body, X_valid_answer]
Y_valid = validation[target_cols].values

print('Train samples: %d' % len(Y_train))
print('Validation samples: %d' % len(Y_valid))
# Out:
# Train samples: 4863
# Validation samples: 1216

# %% [markdown]
# # Model parameters

# %%
EPOCHS = 30
BATCH_SIZE = 64
LEARNING_RATE = 3e-4
EMBEDDDING_SIZE = 512
N_CLASS = len(target_cols)
ES_PATIENCE = 3
RLROP_PATIENCE = 2
DECAY_DROP = 0.5
module_url = '../input/universalsentenceencodermodels/universal-sentence-encoder-models/use-large'
model_path = '../working/use_baseline.h5'

# %% [markdown]
# # Model

# %%
es = EarlyStopping(monitor='val_loss', mode='min', patience=ES_PATIENCE, restore_best_weights=True, verbose=1)
rlrop = ReduceLROnPlateau(monitor='val_loss', mode='min', patience=RLROP_PATIENCE, factor=DECAY_DROP, min_lr=1e-6, verbose=1)
use_embed = hub.load(module_url)

def USEEmbedding(x):
    return use_embed(tf.squeeze(tf.cast(x, tf.string)))

# %%
input_title = Input(shape=(1,), dtype=tf.string, name='input_title')
embedding_title = Lambda(USEEmbedding, output_shape=(EMBEDDDING_SIZE,))(input_title)

input_body = Input(shape=(1,), dtype=tf.string, name='input_body')
embedding_body = Lambda(USEEmbedding, output_shape=(EMBEDDDING_SIZE,))(input_body)

input_answer = Input(shape=(1,), dtype=tf.string, name='input_answer')
embedding_answer = Lambda(USEEmbedding, output_shape=(EMBEDDDING_SIZE,))(input_answer)

x = Concatenate()([embedding_title, embedding_body, embedding_answer])
x = Dropout(0.5)(x)
x = Dense(512, activation='relu')(x)
x = Dropout(0.5)(x)
output = Dense(N_CLASS, activation='sigmoid', name='output')(x)
model = Model(inputs=[input_title, input_body, input_answer], outputs=[output])

model.summary()
# Out:
# Model: "model"
# __________________________________________________________________________________________________
# Layer (type)                    Output Shape         Param #     Connected to
# ==================================================================================================
# input_title (InputLayer)        [(None, 1)]          0
# __________________________________________________________________________________________________
# input_body (InputLayer)         [(None, 1)]          0
# __________________________________________________________________________________________________
# input_answer (InputLayer)       [(None, 1)]          0
# __________________________________________________________________________________________________
# lambda (Lambda)                 (None, 512)          0           input_title[0][0]
# __________________________________________________________________________________________________
# lambda_1 (Lambda)               (None, 512)          0           input_body[0][0]
# __________________________________________________________________________________________________
# lambda_2 (Lambda)               (None, 512)          0           input_answer[0][0]
# __________________________________________________________________________________________________
# concatenate (Concatenate)       (None, 1536)         0           lambda[0][0]
#                                                                  lambda_1[0][0]
#                                                                  lambda_2[0][0]
# __________________________________________________________________________________________________
# dropout (Dropout)               (None, 1536)         0           concatenate[0][0]
# __________________________________________________________________________________________________
# dense (Dense)                   (None, 512)          786944      dropout[0][0]
# __________________________________________________________________________________________________
# dropout_1 (Dropout)             (None, 512)          0           dense[0][0]
# __________________________________________________________________________________________________
# output (Dense)                  (None, 30)           15390       dropout_1[0][0]
# ==================================================================================================
# Total params: 802,334
# Trainable params: 802,334
# Non-trainable params: 0
# __________________________________________________________________________________________________

# %% [markdown]
# # Train model

# %%
optimizer = optimizers.Adam(LEARNING_RATE)
callback_list = [es, rlrop, SpearmanRhoCallback(training_data=(X_train, Y_train), validation_data=(X_valid, Y_valid))]
model.compile(optimizer=optimizer, loss='binary_crossentropy')

history = model.fit(X_train, Y_train, 
                    validation_data=(X_valid, Y_valid), 
                    callbacks=callback_list, 
                    epochs=EPOCHS, 
                    verbose=2).history
# Out:
# Train on 4863 samples, validate on 1216 samples
# Epoch 1/30
# Train spearman-rho: 0.2249 Validation spearman-rho: 0.2163
# 4863/4863 - 289s - loss: 0.5033 - val_loss: 0.4114
# Epoch 2/30
# Train spearman-rho: 0.3069 Validation spearman-rho: 0.2917
# 4863/4863 - 129s - loss: 0.4068 - val_loss: 0.3926
# Epoch 3/30
# Train spearman-rho: 0.3487 Validation spearman-rho: 0.3272
# 4863/4863 - 128s - loss: 0.3947 - val_loss: 0.3843
# Epoch 4/30
# Train spearman-rho: 0.3718 Validation spearman-rho: 0.3435
# 4863/4863 - 127s - loss: 0.3882 - val_loss: 0.3797
# Epoch 5/30
# Train spearman-rho: 0.3886 Validation spearman-rho: 0.3537
# 4863/4863 - 127s - loss: 0.3834 - val_loss: 0.3768
# Epoch 6/30
# Train spearman-rho: 0.4003 Validation spearman-rho: 0.3603
# 4863/4863 - 127s - loss: 0.3804 - val_loss: 0.3749
# Epoch 7/30
# Train spearman-rho: 0.4113 Validation spearman-rho: 0.3651
# 4863/4863 - 125s - loss: 0.3781 - val_loss: 0.3737
# Epoch 8/30
# Train spearman-rho: 0.4201 Validation spearman-rho: 0.3692
# 4863/4863 - 126s - loss: 0.3758 - val_loss: 0.3726
# Epoch 9/30
# Train spearman-rho: 0.4278 Validation spearman-rho: 0.3722
# 4863/4863 - 127s - loss: 0.3741 - val_loss: 0.3719
# Epoch 10/30
# Train spearman-rho: 0.4343 Validation spearman-rho: 0.3750
# 4863/4863 - 127s - loss: 0.3724 - val_loss: 0.3712
# Epoch 11/30
# Train spearman-rho: 0.4401 Validation spearman-rho: 0.3773
# 4863/4863 - 127s - loss: 0.3710 - val_loss: 0.3706
# Epoch 12/30
# Train spearman-rho: 0.4456 Validation spearman-rho: 0.3795
# 4863/4863 - 126s - loss: 0.3693 - val_loss: 0.3702
# Epoch 13/30
# Train spearman-rho: 0.4502 Validation spearman-rho: 0.3815
# 4863/4863 - 125s - loss: 0.3686 - val_loss: 0.3697
# Epoch 14/30
# Train spearman-rho: 0.4551 Validation spearman-rho: 0.3829
# 4863/4863 - 123s - loss: 0.3679 - val_loss: 0.3697
# Epoch 15/30
# Train spearman-rho: 0.4594 Validation spearman-rho: 0.3837
# 4863/4863 - 124s - loss: 0.3664 - val_loss: 0.3695
# Epoch 16/30
# Train spearman-rho: 0.4634 Validation spearman-rho: 0.3854
# 4863/4863 - 124s - loss: 0.3660 - val_loss: 0.3694
# Epoch 17/30
# Train spearman-rho: 0.4669 Validation spearman-rho: 0.3864
# 4863/4863 - 123s - loss: 0.3654 - val_loss: 0.3690
# Epoch 18/30
# Train spearman-rho: 0.4704 Validation spearman-rho: 0.3871
# 4863/4863 - 124s - loss: 0.3643 - val_loss: 0.3688
# Epoch 19/30
# Train spearman-rho: 0.4738 Validation spearman-rho: 0.3879
# 4863/4863 - 123s - loss: 0.3637 - val_loss: 0.3689
# Epoch 20/30
# Train spearman-rho: 0.4771 Validation spearman-rho: 0.3886
# 4863/4863 - 124s - loss: 0.3627 - val_loss: 0.3687
# Epoch 21/30
# Train spearman-rho: 0.4802 Validation spearman-rho: 0.3892
# 4863/4863 - 124s - loss: 0.3625 - val_loss: 0.3683
# Epoch 22/30
# Train spearman-rho: 0.4830 Validation spearman-rho: 0.3896
# 4863/4863 - 124s - loss: 0.3620 - val_loss: 0.3685
# Epoch 23/30
# Train spearman-rho: 0.4852 Validation spearman-rho: 0.3906
# 4863/4863 - 125s - loss: 0.3611 - val_loss: 0.3682
# Epoch 24/30
# Train spearman-rho: 0.4880 Validation spearman-rho: 0.3919
# 4863/4863 - 125s - loss: 0.3603 - val_loss: 0.3681
# Epoch 25/30
# Train spearman-rho: 0.4911 Validation spearman-rho: 0.3915
# 4863/4863 - 125s - loss: 0.3601 - val_loss: 0.3680
# Epoch 26/30
# Train spearman-rho: 0.4939 Validation spearman-rho: 0.3916
# 4863/4863 - 127s - loss: 0.3599 - val_loss: 0.3681
# Epoch 27/30
#
# Epoch 00027: ReduceLROnPlateau reducing learning rate to 0.0001500000071246177.
# Train spearman-rho: 0.4965 Validation spearman-rho: 0.3927
# 4863/4863 - 128s - loss: 0.3590 - val_loss: 0.3681
# Epoch 28/30
# Train spearman-rho: 0.4979 Validation spearman-rho: 0.3929
# 4863/4863 - 128s - loss: 0.3581 - val_loss: 0.3678
# Epoch 29/30
# Train spearman-rho: 0.4995 Validation spearman-rho: 0.3925
# 4863/4863 - 126s - loss: 0.3581 - val_loss: 0.3679
# Epoch 30/30
#
# Epoch 00030: ReduceLROnPlateau reducing learning rate to 7.500000356230885e-05.
# Train spearman-rho: 0.5009 Validation spearman-rho: 0.3927
# 4863/4863 - 124s - loss: 0.3580 - val_loss: 0.3679

# %% [markdown]
# #### Save model

# %%
model.save_weights(model_path)

# %% [markdown]
# # Evaluation

# %%
preds_train = model.predict(X_train)
preds_val = model.predict(X_valid)

rho_train = np.mean([spearmanr(Y_train[:, ind], preds_train[:, ind] + np.random.normal(0, 1e-7, preds_train.shape[0])).correlation for ind in range(preds_train.shape[1])])
rho_val = np.mean([spearmanr(Y_valid[:, ind], preds_val[:, ind] + np.random.normal(0, 1e-7, preds_val.shape[0])).correlation for ind in range(preds_val.shape[1])])

print('Train spearman-rho: %.3f' % rho_train)
print('Validation spearman-rho: %.3f' % rho_val)
# Out:
# Train spearman-rho: 0.501
# Validation spearman-rho: 0.393

# %% [markdown]
# # Make predictions on test

# %%
# Test features
X_test_title = test['question_title']
X_test_body = test['question_body']
X_test_answer = test['answer']

X_test = [X_test_title, X_test_body, X_test_answer]
Y_test = model.predict(X_test)

# %%
submission = pd.read_csv('/kaggle/input/google-quest-challenge/sample_submission.csv')
submission[target_cols] = Y_test
submission.to_csv("submission.csv", index=False)
display(submission.head())
# Out:
#    qa_id  question_asker_intent_understanding  question_body_critical  \
# 0     39                             0.898401                0.701306
# 1     46                             0.868948                0.560108
# 2     70                             0.888613                0.617331
# 3    132                             0.813217                0.391429
# 4    200                             0.934949                0.517310
#
#    question_conversational  question_expect_short_answer  \
# 0                 0.195216                      0.775750
# 1                 0.001610                      0.604412
# 2                 0.011006                      0.746879
# 3                 0.011527                      0.688667
# 4                 0.010834                      0.848519
#
#    question_fact_seeking  question_has_commonly_accepted_answer  \
# 0               0.657974                               0.790829
# 1               0.845550                               0.923662
# 2               0.869945                               0.943018
# 3               0.805134                               0.863633
# 4               0.827655                               0.937916
#
#    question_interestingness_others  question_interestingness_self  \
# 0                         0.592663                       0.528118
# 1                         0.575871                       0.468556
# 2                         0.586665                       0.461787
# 3                         0.541603                       0.439496
# 4                         0.601781                       0.572593
#
#    question_multi_intent  ...  question_well_written  answer_helpful  \
# 0               0.189943  ...               0.890848        0.907991
# 1               0.112189  ...               0.744621        0.930638
# 2               0.341399  ...               0.836117        0.922925
# 3               0.411479  ...               0.684726        0.936774
# 4               0.319013  ...               0.768523        0.948583
#
#    answer_level_of_information  answer_plausible  answer_relevance  \
# 0                     0.628950          0.955336          0.965077
# 1                     0.624883          0.960260          0.970378
# 2                     0.615265          0.964007          0.964906
# 3                     0.676810          0.960521          0.974875
# 4                     0.665946          0.976426          0.977590
#
#    answer_satisfaction  answer_type_instructions  answer_type_procedure  \
# 0             0.849752                  0.051199               0.074912
# 1             0.859254                  0.945876               0.148701
# 2             0.830993                  0.148751               0.101253
# 3             0.875578                  0.766690               0.225465
# 4             0.866930                  0.436373               0.232336
#
#    answer_type_reason_explanation  answer_well_written
# 0                        0.860011             0.918877
# 1                        0.085640             0.884112
# 2                        0.835232             0.901700
# 3                        0.652762             0.875146
# 4                        0.615588             0.908965
#
# [5 rows x 31 columns]
