# %% [markdown]
# ## Dependencies

# %%
import re
import warnings
import tensorflow_hub as hub
from nltk.corpus import stopwords
from tensorflow.keras import Model, optimizers
from tensorflow.keras.layers import Lambda, Input, Dense, Dropout, Concatenate, BatchNormalization, Activation
from tensorflow.keras.callbacks import EarlyStopping, ReduceLROnPlateau
from googleqa_utilityscript import *


SEED = 0
seed_everything(SEED)
warnings.filterwarnings("ignore")

# %% [markdown]
# ## Load data

# %%
hold_out = pd.read_csv('/kaggle/input/googleqa-mldataset/hold-out.csv')
train = hold_out[hold_out['set'] == 'train']
validation = hold_out[hold_out['set'] == 'validation']

print('Train samples: %s' % len(train))
print('Validation samples: %s' % len(validation))
display(train.head())
# Out:
# Train samples: 4863
# Validation samples: 1216
#    qa_id                                     question_title  \
# 0   3895  Magento (1.7) Bundled Product with FREE Produc...
# 1   3131                             Find router on network
# 2   1507  Negatively curved metrics minimizing the lengt...
# 3   6784               Isn’t the FAQ label obsolete by now?
# 4   2135  Changing background image one time on responsi...
#
#                                        question_body question_user_name  \
# 0  I'm looking to create a bundle offer where cus...                Joe
# 1  I've just bought a Belkin N+ Wireless Router. ...                Guy
# 2  Good afternoon everyone !\n\nI have the follow...            Selim G
# 3  Don’t get me wrong in the beginning of reading...     Benny Skogberg
# 4  The code I'm using is this one \n\nbackground:...        user2141649
#
#                               question_user_page  \
# 0  https://magento.stackexchange.com/users/16572
# 1               https://superuser.com/users/3248
# 2           https://mathoverflow.net/users/25511
# 3        https://ux.stackexchange.com/users/4679
# 4        https://stackoverflow.com/users/2141649
#
#                                               answer   answer_user_name  \
# 0  Since the third item is fixed, you can use sho...  Fabian Schmengler
# 1  You likely have the router plugged in to the m...             John T
# 2  A very partial answer: by the results of Richa...         Igor Rivin
# 3  Isn’t the FAQ label obsolete by now? \n\nI'd s...        Solracnapod
# 4  &lt;!DOCTYPE html&gt;\n&lt;html&gt;\n&lt;head&...           akkimads
#
#                               answer_user_page  \
# 0  https://magento.stackexchange.com/users/243
# 1             https://superuser.com/users/1931
# 2         https://mathoverflow.net/users/11142
# 3     https://ux.stackexchange.com/users/13153
# 4      https://stackoverflow.com/users/2375373
#
#                                                  url       category  ...  \
# 0  http://magento.stackexchange.com/questions/668...     TECHNOLOGY  ...
# 1               http://superuser.com/questions/87212     TECHNOLOGY  ...
# 2           http://mathoverflow.net/questions/203422        SCIENCE  ...
# 3  http://ux.stackexchange.com/questions/18600/is...     TECHNOLOGY  ...
# 4  http://stackoverflow.com/questions/16359492/ch...  STACKOVERFLOW  ...
#
#   answer_helpful  answer_level_of_information  answer_plausible  \
# 0       0.888889                     0.666667               1.0
# 1       1.000000                     0.666667               1.0
# 2       0.888889                     0.333333               1.0
# 3       0.888889                     0.666667               1.0
# 4       0.888889                     0.500000               1.0
#
#    answer_relevance  answer_satisfaction  answer_type_instructions  \
# 0               1.0             0.933333                  1.000000
# 1               1.0             0.866667                  0.666667
# 2               1.0             0.700000                  0.333333
# 3               1.0             0.933333                  0.000000
# 4               1.0             0.800000                  1.000000
#
#    answer_type_procedure  answer_type_reason_explanation  answer_well_written  \
# 0               0.000000                        0.333333             0.888889
# 1               0.000000                        1.000000             1.000000
# 2               0.333333                        1.000000             0.888889
# 3               0.000000                        0.666667             1.000000
# 4               0.000000                        0.000000             0.777778
#
#      set
# 0  train
# 1  train
# 2  train
# 3  train
# 4  train
#
# [5 rows x 42 columns]

# %%
question_target_cols = ['question_asker_intent_understanding','question_body_critical', 'question_conversational', 
                        'question_expect_short_answer', 'question_fact_seeking', 'question_has_commonly_accepted_answer',
                        'question_interestingness_others', 'question_interestingness_self', 'question_multi_intent', 
                        'question_not_really_a_question', 'question_opinion_seeking', 'question_type_choice',
                        'question_type_compare', 'question_type_consequence', 'question_type_definition', 
                        'question_type_entity', 'question_type_instructions', 'question_type_procedure',
                        'question_type_reason_explanation', 'question_type_spelling', 'question_well_written']
answer_target_cols = ['answer_helpful', 'answer_level_of_information', 'answer_plausible', 'answer_relevance',
                      'answer_satisfaction', 'answer_type_instructions', 'answer_type_procedure', 
                      'answer_type_reason_explanation', 'answer_well_written']
target_cols = question_target_cols + answer_target_cols

# %% [markdown]
# ## Pre-process data

# %%
def textClean(text):
    text = text.lower().split()
    stops = set(stopwords.words("english"))
    text = [w for w in text if not w in stops]    
    text = " ".join(text)
    return(text)

# %%
text_features = ['question_title', 'question_body', 'answer']

for feature in text_features:
    # Remove stopwords
    train[feature] = train[feature].apply(lambda x: textClean(x))
    validation[feature] = validation[feature].apply(lambda x: textClean(x))
    # Trim text
    train[feature] = train[feature].apply(lambda x: x.strip())
    validation[feature] = validation[feature].apply(lambda x: x.strip())

# %% [markdown]
# ## Train/validation sets

# %%
# Train features
X_train_title = train['question_title']
X_train_body = train['question_body']
X_train_answer = train['answer']

X_train = [X_train_title, X_train_body, X_train_answer]
Y_train = train[target_cols].values

# Validation features
X_valid_title = validation['question_title']
X_valid_body = validation['question_body']
X_valid_answer = validation['answer']

X_valid = [X_valid_title, X_valid_body, X_valid_answer]
Y_valid = validation[target_cols].values

print('Train samples: %d' % len(Y_train))
print('Validation samples: %d' % len(Y_valid))
# Out:
# Train samples: 4863
# Validation samples: 1216

# %% [markdown]
# # Model parameters

# %%
EPOCHS = 40
BATCH_SIZE = 32
LEARNING_RATE = 3e-4
EMBEDDDING_SIZE = 512
N_CLASS = len(target_cols)
ES_PATIENCE = 3
RLROP_PATIENCE = 2
DECAY_DROP = 0.3
module_url = '/kaggle/input/universalsentenceencodermodels/universal-sentence-encoder-models/use'
model_path = '/kaggle/working/use.h5'

# %% [markdown]
# # Model

# %%
es = EarlyStopping(monitor='val_loss', mode='min', patience=ES_PATIENCE, restore_best_weights=True, verbose=1)
rlrop = ReduceLROnPlateau(monitor='val_loss', mode='min', patience=RLROP_PATIENCE, factor=DECAY_DROP, min_lr=1e-6, verbose=1)
use_embed = hub.load(module_url)

def USEEmbedding(x):
    return use_embed(tf.squeeze(tf.cast(x, tf.string)))

# %%
input_title = Input(shape=(1,), dtype=tf.string, name='input_title')
embedding_title = Lambda(USEEmbedding, output_shape=(EMBEDDDING_SIZE,))(input_title)

input_body = Input(shape=(1,), dtype=tf.string, name='input_body')
embedding_body = Lambda(USEEmbedding, output_shape=(EMBEDDDING_SIZE,))(input_body)

input_answer = Input(shape=(1,), dtype=tf.string, name='input_answer')
embedding_answer = Lambda(USEEmbedding, output_shape=(EMBEDDDING_SIZE,))(input_answer)

x = Concatenate()([embedding_title, embedding_body, embedding_answer])
x = Dropout(0.5)(x)
x = Dense(512, activation='relu')(x)
x = Dropout(0.5)(x)
output = Dense(N_CLASS, activation='sigmoid', name='output')(x)
model = Model(inputs=[input_title, input_body, input_answer], outputs=[output])

model.summary()
# Out:
# Model: "model"
# __________________________________________________________________________________________________
# Layer (type)                    Output Shape         Param #     Connected to
# ==================================================================================================
# input_title (InputLayer)        [(None, 1)]          0
# __________________________________________________________________________________________________
# input_body (InputLayer)         [(None, 1)]          0
# __________________________________________________________________________________________________
# input_answer (InputLayer)       [(None, 1)]          0
# __________________________________________________________________________________________________
# lambda (Lambda)                 (None, 512)          0           input_title[0][0]
# __________________________________________________________________________________________________
# lambda_1 (Lambda)               (None, 512)          0           input_body[0][0]
# __________________________________________________________________________________________________
# lambda_2 (Lambda)               (None, 512)          0           input_answer[0][0]
# __________________________________________________________________________________________________
# concatenate (Concatenate)       (None, 1536)         0           lambda[0][0]
#                                                                  lambda_1[0][0]
#                                                                  lambda_2[0][0]
# __________________________________________________________________________________________________
# dropout (Dropout)               (None, 1536)         0           concatenate[0][0]
# __________________________________________________________________________________________________
# dense (Dense)                   (None, 512)          786944      dropout[0][0]
# __________________________________________________________________________________________________
# dropout_1 (Dropout)             (None, 512)          0           dense[0][0]
# __________________________________________________________________________________________________
# output (Dense)                  (None, 30)           15390       dropout_1[0][0]
# ==================================================================================================
# Total params: 802,334
# Trainable params: 802,334
# Non-trainable params: 0
# __________________________________________________________________________________________________

# %% [markdown]
# # Train model

# %%
optimizer = optimizers.Adam(LEARNING_RATE)
spearmanCallback = SpearmanRhoCallback(training_data=(X_train, Y_train), validation_data=(X_valid, Y_valid))
callback_list = [es, rlrop, spearmanCallback]
model.compile(optimizer=optimizer, loss='binary_crossentropy')

history = model.fit(X_train, Y_train, 
                    validation_data=(X_valid, Y_valid), 
                    callbacks=callback_list, 
                    batch_size=BATCH_SIZE,
                    epochs=EPOCHS, 
                    verbose=2).history
# Out:
# Train on 4863 samples, validate on 1216 samples
# Epoch 1/40
# Train spearman-rho: 0.1749 Validation spearman-rho: 0.1560
# 4863/4863 - 27s - loss: 0.4961 - val_loss: 0.4199
# Epoch 2/40
# Train spearman-rho: 0.2522 Validation spearman-rho: 0.2252
# 4863/4863 - 18s - loss: 0.4127 - val_loss: 0.4064
# Epoch 3/40
# Train spearman-rho: 0.2954 Validation spearman-rho: 0.2647
# 4863/4863 - 18s - loss: 0.4031 - val_loss: 0.4005
# Epoch 4/40
# Train spearman-rho: 0.3216 Validation spearman-rho: 0.2852
# 4863/4863 - 18s - loss: 0.3971 - val_loss: 0.3967
# Epoch 5/40
# Train spearman-rho: 0.3412 Validation spearman-rho: 0.2981
# 4863/4863 - 18s - loss: 0.3934 - val_loss: 0.3943
# Epoch 6/40
# Train spearman-rho: 0.3566 Validation spearman-rho: 0.3062
# 4863/4863 - 18s - loss: 0.3905 - val_loss: 0.3926
# Epoch 7/40
# Train spearman-rho: 0.3681 Validation spearman-rho: 0.3115
# 4863/4863 - 18s - loss: 0.3881 - val_loss: 0.3911
# Epoch 8/40
# Train spearman-rho: 0.3781 Validation spearman-rho: 0.3153
# 4863/4863 - 18s - loss: 0.3851 - val_loss: 0.3901
# Epoch 9/40
# Train spearman-rho: 0.3871 Validation spearman-rho: 0.3189
# 4863/4863 - 18s - loss: 0.3838 - val_loss: 0.3894
# Epoch 10/40
# Train spearman-rho: 0.3940 Validation spearman-rho: 0.3212
# 4863/4863 - 18s - loss: 0.3821 - val_loss: 0.3887
# Epoch 11/40
# Train spearman-rho: 0.4020 Validation spearman-rho: 0.3237
# 4863/4863 - 18s - loss: 0.3810 - val_loss: 0.3883
# Epoch 12/40
# Train spearman-rho: 0.4077 Validation spearman-rho: 0.3249
# 4863/4863 - 18s - loss: 0.3796 - val_loss: 0.3878
# Epoch 13/40
# Train spearman-rho: 0.4136 Validation spearman-rho: 0.3259
# 4863/4863 - 18s - loss: 0.3789 - val_loss: 0.3874
# Epoch 14/40
# Train spearman-rho: 0.4183 Validation spearman-rho: 0.3275
# 4863/4863 - 18s - loss: 0.3774 - val_loss: 0.3872
# Epoch 15/40
# Train spearman-rho: 0.4236 Validation spearman-rho: 0.3291
# 4863/4863 - 18s - loss: 0.3768 - val_loss: 0.3871
# Epoch 16/40
# Train spearman-rho: 0.4276 Validation spearman-rho: 0.3295
# 4863/4863 - 19s - loss: 0.3760 - val_loss: 0.3867
# Epoch 17/40
# Train spearman-rho: 0.4320 Validation spearman-rho: 0.3316
# 4863/4863 - 18s - loss: 0.3754 - val_loss: 0.3866
# Epoch 18/40
# Train spearman-rho: 0.4355 Validation spearman-rho: 0.3326
# 4863/4863 - 18s - loss: 0.3746 - val_loss: 0.3863
# Epoch 19/40
# Train spearman-rho: 0.4393 Validation spearman-rho: 0.3334
# 4863/4863 - 18s - loss: 0.3736 - val_loss: 0.3864
# Epoch 20/40
# Train spearman-rho: 0.4442 Validation spearman-rho: 0.3338
# 4863/4863 - 18s - loss: 0.3737 - val_loss: 0.3860
# Epoch 21/40
# Train spearman-rho: 0.4473 Validation spearman-rho: 0.3341
# 4863/4863 - 18s - loss: 0.3720 - val_loss: 0.3858
# Epoch 22/40
# Train spearman-rho: 0.4511 Validation spearman-rho: 0.3351
# 4863/4863 - 18s - loss: 0.3720 - val_loss: 0.3856
# Epoch 23/40
# Train spearman-rho: 0.4544 Validation spearman-rho: 0.3362
# 4863/4863 - 18s - loss: 0.3707 - val_loss: 0.3856
# Epoch 24/40
# Train spearman-rho: 0.4575 Validation spearman-rho: 0.3368
# 4863/4863 - 18s - loss: 0.3709 - val_loss: 0.3853
# Epoch 25/40
# Train spearman-rho: 0.4605 Validation spearman-rho: 0.3366
# 4863/4863 - 18s - loss: 0.3702 - val_loss: 0.3852
# Epoch 26/40
# Train spearman-rho: 0.4646 Validation spearman-rho: 0.3377
# 4863/4863 - 18s - loss: 0.3695 - val_loss: 0.3851
# Epoch 27/40
# Train spearman-rho: 0.4679 Validation spearman-rho: 0.3382
# 4863/4863 - 18s - loss: 0.3687 - val_loss: 0.3849
# Epoch 28/40
# Train spearman-rho: 0.4707 Validation spearman-rho: 0.3393
# 4863/4863 - 18s - loss: 0.3686 - val_loss: 0.3848
# Epoch 29/40
# Train spearman-rho: 0.4731 Validation spearman-rho: 0.3391
# 4863/4863 - 18s - loss: 0.3674 - val_loss: 0.3847
# Epoch 30/40
#
# Epoch 00030: ReduceLROnPlateau reducing learning rate to 9.000000427477062e-05.
# Train spearman-rho: 0.4755 Validation spearman-rho: 0.3398
# 4863/4863 - 18s - loss: 0.3672 - val_loss: 0.3849
# Epoch 31/40
# Train spearman-rho: 0.4768 Validation spearman-rho: 0.3401
# 4863/4863 - 18s - loss: 0.3660 - val_loss: 0.3846
# Epoch 32/40
# Train spearman-rho: 0.4778 Validation spearman-rho: 0.3405
# 4863/4863 - 19s - loss: 0.3653 - val_loss: 0.3846
# Epoch 33/40
# Train spearman-rho: 0.4788 Validation spearman-rho: 0.3408
# 4863/4863 - 19s - loss: 0.3655 - val_loss: 0.3845
# Epoch 34/40
# Train spearman-rho: 0.4799 Validation spearman-rho: 0.3407
# 4863/4863 - 18s - loss: 0.3649 - val_loss: 0.3844
# Epoch 35/40
#
# Epoch 00035: ReduceLROnPlateau reducing learning rate to 2.700000040931627e-05.
# Train spearman-rho: 0.4811 Validation spearman-rho: 0.3412
# 4863/4863 - 18s - loss: 0.3657 - val_loss: 0.3844
# Epoch 36/40
# Train spearman-rho: 0.4813 Validation spearman-rho: 0.3413
# 4863/4863 - 18s - loss: 0.3644 - val_loss: 0.3844
# Epoch 37/40
#
# Epoch 00037: ReduceLROnPlateau reducing learning rate to 8.100000013655517e-06.
# Train spearman-rho: 0.4816 Validation spearman-rho: 0.3414
# 4863/4863 - 18s - loss: 0.3654 - val_loss: 0.3844
# Epoch 38/40
# Train spearman-rho: 0.4816 Validation spearman-rho: 0.3415
# 4863/4863 - 18s - loss: 0.3645 - val_loss: 0.3844
# Epoch 39/40
# Train spearman-rho: 0.4817 Validation spearman-rho: 0.3415
# 4863/4863 - 18s - loss: 0.3651 - val_loss: 0.3843
# Epoch 40/40
# Train spearman-rho: 0.4818 Validation spearman-rho: 0.3415
# 4863/4863 - 18s - loss: 0.3648 - val_loss: 0.3843

# %% [markdown]
# ## Model loss graph

# %%
sns.set(style="whitegrid")
for key in spearmanCallback.history.keys():
    history[key] = spearmanCallback.history[key]

plot_metrics(history, metric_list=['loss', 'spearman'])

# %% [markdown]
# # Evaluation

# %%
preds_train = model.predict(X_train)
preds_val = model.predict(X_valid)

display(get_metrics(Y_train, preds_train, Y_valid, preds_val, target_cols))
# Out:
#                                     Label  Train  Validation
# 0                                Averaged  0.482       0.342
# 1     question_asker_intent_understanding  0.470       0.378
# 2                  question_body_critical  0.649       0.510
# 3                 question_conversational  0.458       0.398
# 4            question_expect_short_answer  0.508       0.215
# 5                   question_fact_seeking  0.546       0.324
# 6   question_has_commonly_accepted_answer  0.551       0.403
# 7         question_interestingness_others  0.458       0.392
# 8           question_interestingness_self  0.598       0.526
# 9                   question_multi_intent  0.565       0.400
# 10         question_not_really_a_question  0.141       0.046
# 11               question_opinion_seeking  0.647       0.438
# 12                   question_type_choice  0.630       0.414
# 13                  question_type_compare  0.383       0.297
# 14              question_type_consequence  0.209       0.147
# 15               question_type_definition  0.379       0.307
# 16                   question_type_entity  0.450       0.415
# 17             question_type_instructions  0.802       0.677
# 18                question_type_procedure  0.501       0.250
# 19       question_type_reason_explanation  0.684       0.561
# 20                 question_type_spelling  0.074       0.070
# 21                  question_well_written  0.543       0.422
# 22                         answer_helpful  0.378       0.196
# 23            answer_level_of_information  0.484       0.366
# 24                       answer_plausible  0.305       0.127
# 25                       answer_relevance  0.285       0.138
# 26                    answer_satisfaction  0.444       0.221
# 27               answer_type_instructions  0.809       0.671
# 28                  answer_type_procedure  0.466       0.223
# 29         answer_type_reason_explanation  0.724       0.598
# 30                    answer_well_written  0.313       0.115

# %% [markdown]
# ## By category

# %%
target_cols_preds = [col+'_pred' for col in target_cols]
for col in target_cols_preds:
    train[col] = 0
    validation[col] = 0
    
train[target_cols_preds] = preds_train
validation[target_cols_preds] = preds_val
    
display(get_metrics_category(train, validation, target_cols, target_cols_preds, 'category'))
# Out:
#       Label Train (TECHNOLOGY) Validation (TECHNOLOGY) Train (SCIENCE)  \
# 0  Averaged               0.45                   0.294           0.491
#
#   Validation (SCIENCE) Train (STACKOVERFLOW) Validation (STACKOVERFLOW)  \
# 0                0.346                 0.382                      0.176
#
#   Train (LIFE_ARTS) Validation (LIFE_ARTS) Train (CULTURE)  \
# 0             0.503                  0.363           0.504
#
#   Validation (CULTURE)
# 0                0.349

# %% [markdown]
# #### Save model weights

# %%
model.save_weights(model_path)
