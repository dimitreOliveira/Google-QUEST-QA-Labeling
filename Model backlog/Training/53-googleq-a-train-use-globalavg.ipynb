# %% [markdown]
# ## Dependencies

# %%
import re
import warnings
from joblib import dump
import tensorflow_hub as hub
from tensorflow.keras import Model, optimizers
from tensorflow.keras.layers import Lambda, Input, Dense, Dropout, Concatenate, BatchNormalization, Activation, Average, Add, Reshape, GlobalAveragePooling1D, Multiply
from tensorflow.keras.callbacks import ReduceLROnPlateau
from googleqa_utilityscript import *


SEED = 0
seed_everything(SEED)
warnings.filterwarnings("ignore")

# %% [markdown]
# ## Load data

# %%
module_url = '/kaggle/input/universalsentenceencodermodels/universal-sentence-encoder-models/use'
model_path = '/kaggle/working/use.h5'

hold_out = pd.read_csv('/kaggle/input/googleqa-mldataset/hold-out.csv')
train = hold_out[hold_out['set'] == 'train']
validation = hold_out[hold_out['set'] == 'validation']

print('Train samples: %s' % len(train))
print('Validation samples: %s' % len(validation))
display(train.head())
# Out:
# Train samples: 4863
# Validation samples: 1216
#    qa_id                                     question_title  \
# 0   3895  Magento (1.7) Bundled Product with FREE Produc...
# 1   3131                             Find router on network
# 2   1507  Negatively curved metrics minimizing the lengt...
# 3   6784               Isn’t the FAQ label obsolete by now?
# 4   2135  Changing background image one time on responsi...
#
#                                        question_body question_user_name  \
# 0  I'm looking to create a bundle offer where cus...                Joe
# 1  I've just bought a Belkin N+ Wireless Router. ...                Guy
# 2  Good afternoon everyone !\n\nI have the follow...            Selim G
# 3  Don’t get me wrong in the beginning of reading...     Benny Skogberg
# 4  The code I'm using is this one \n\nbackground:...        user2141649
#
#                               question_user_page  \
# 0  https://magento.stackexchange.com/users/16572
# 1               https://superuser.com/users/3248
# 2           https://mathoverflow.net/users/25511
# 3        https://ux.stackexchange.com/users/4679
# 4        https://stackoverflow.com/users/2141649
#
#                                               answer   answer_user_name  \
# 0  Since the third item is fixed, you can use sho...  Fabian Schmengler
# 1  You likely have the router plugged in to the m...             John T
# 2  A very partial answer: by the results of Richa...         Igor Rivin
# 3  Isn’t the FAQ label obsolete by now? \n\nI'd s...        Solracnapod
# 4  &lt;!DOCTYPE html&gt;\n&lt;html&gt;\n&lt;head&...           akkimads
#
#                               answer_user_page  \
# 0  https://magento.stackexchange.com/users/243
# 1             https://superuser.com/users/1931
# 2         https://mathoverflow.net/users/11142
# 3     https://ux.stackexchange.com/users/13153
# 4      https://stackoverflow.com/users/2375373
#
#                                                  url       category  ...  \
# 0  http://magento.stackexchange.com/questions/668...     TECHNOLOGY  ...
# 1               http://superuser.com/questions/87212     TECHNOLOGY  ...
# 2           http://mathoverflow.net/questions/203422        SCIENCE  ...
# 3  http://ux.stackexchange.com/questions/18600/is...     TECHNOLOGY  ...
# 4  http://stackoverflow.com/questions/16359492/ch...  STACKOVERFLOW  ...
#
#   answer_helpful  answer_level_of_information  answer_plausible  \
# 0       0.888889                     0.666667               1.0
# 1       1.000000                     0.666667               1.0
# 2       0.888889                     0.333333               1.0
# 3       0.888889                     0.666667               1.0
# 4       0.888889                     0.500000               1.0
#
#    answer_relevance  answer_satisfaction  answer_type_instructions  \
# 0               1.0             0.933333                  1.000000
# 1               1.0             0.866667                  0.666667
# 2               1.0             0.700000                  0.333333
# 3               1.0             0.933333                  0.000000
# 4               1.0             0.800000                  1.000000
#
#    answer_type_procedure  answer_type_reason_explanation  answer_well_written  \
# 0               0.000000                        0.333333             0.888889
# 1               0.000000                        1.000000             1.000000
# 2               0.333333                        1.000000             0.888889
# 3               0.000000                        0.666667             1.000000
# 4               0.000000                        0.000000             0.777778
#
#      set
# 0  train
# 1  train
# 2  train
# 3  train
# 4  train
#
# [5 rows x 42 columns]

# %%
question_target_cols = ['question_asker_intent_understanding','question_body_critical', 'question_conversational', 
                        'question_expect_short_answer', 'question_fact_seeking', 'question_has_commonly_accepted_answer',
                        'question_interestingness_others', 'question_interestingness_self', 'question_multi_intent', 
                        'question_not_really_a_question', 'question_opinion_seeking', 'question_type_choice',
                        'question_type_compare', 'question_type_consequence', 'question_type_definition', 
                        'question_type_entity', 'question_type_instructions', 'question_type_procedure',
                        'question_type_reason_explanation', 'question_type_spelling', 'question_well_written']
answer_target_cols = ['answer_helpful', 'answer_level_of_information', 'answer_plausible', 'answer_relevance',
                      'answer_satisfaction', 'answer_type_instructions', 'answer_type_procedure', 
                      'answer_type_reason_explanation', 'answer_well_written']
target_cols = question_target_cols + answer_target_cols

# %% [markdown]
# ## Pre-process data

# %%
text_features = ['question_title', 'question_body', 'answer']

for feature in text_features:
    # Lower
    train[feature] = train[feature].apply(lambda x: x.lower())
    validation[feature] = validation[feature].apply(lambda x: x.lower())
    # Map misspellings
#     train[feature] = train[feature].apply(lambda x: map_misspellings(x))
#     validation[feature] = validation[feature].apply(lambda x: map_misspellings(x))
    # Map contractions
    train[feature] = train[feature].apply(lambda x: map_contraction(x))
    validation[feature] = validation[feature].apply(lambda x: map_contraction(x))
    # Trim text
    train[feature] = train[feature].apply(lambda x: x.strip())
    validation[feature] = validation[feature].apply(lambda x: x.strip())

# %% [markdown]
# ## Train/validation sets

# %%
# Train features
X_train_title = train['question_title']
X_train_body = train['question_body']
X_train_answer = train['answer']


X_train = [X_train_title, X_train_body, X_train_answer]
Y_train = train[target_cols].values

# Validation features
X_valid_title = validation['question_title']
X_valid_body = validation['question_body']
X_valid_answer = validation['answer']

X_valid = [X_valid_title, X_valid_body, X_valid_answer]
Y_valid = validation[target_cols].values

print('Train samples: %d' % len(Y_train))
print('Validation samples: %d' % len(Y_valid))
# Out:
# Train samples: 4863
# Validation samples: 1216

# %% [markdown]
# # Model parameters

# %%
EPOCHS = 50
BATCH_SIZE = 32
LEARNING_RATE = 3e-4
EMBEDDDING_SIZE = 512
N_CLASS = len(target_cols)
ES_PATIENCE = 5
RLROP_PATIENCE = 2
DECAY_DROP = 0.3

# %% [markdown]
# # Model

# %%
use_embed = hub.load(module_url)

def USEEmbedding(x):
    return use_embed(tf.squeeze(tf.cast(x, tf.string)))

def encoder_block(input_layer):
    encoder = Lambda(USEEmbedding, output_shape=(EMBEDDDING_SIZE,))(input_layer)
    
    return encoder

# %%
# Title
input_title = Input(shape=(1,), dtype=tf.string, name='input_title')
encoded_title = encoder_block(input_title)

# Body
input_body = Input(shape=(1,), dtype=tf.string, name='input_body')
encoded_body = encoder_block(input_body)

# Answer
input_answer = Input(shape=(1,), dtype=tf.string, name='input_answer')
encoded_answer = encoder_block(input_answer)

# Output
title = Reshape((EMBEDDDING_SIZE, 1))(encoded_title)
title = GlobalAveragePooling1D()(title)
title = Concatenate()([title, encoded_title])
title_out = Dense(128, activation='relu', kernel_initializer='lecun_normal')(title)

body = Reshape((EMBEDDDING_SIZE, 1))(encoded_body)
body = GlobalAveragePooling1D()(body)
body = Concatenate()([body, encoded_body])
body_out = Dense(128, activation='relu', kernel_initializer='lecun_normal')(body)

answer = Reshape((EMBEDDDING_SIZE, 1))(encoded_answer)
answer = GlobalAveragePooling1D()(answer)
answer = Concatenate()([answer, encoded_answer])
answer_out = Dense(128, activation='relu', kernel_initializer='lecun_normal')(answer)

x = Concatenate()([title_out, body_out, answer_out])
x = Dropout(0.5)(x)
x = Dense(512, activation='relu', kernel_initializer='lecun_normal')(x)
x = Dropout(0.5)(x)

output = Dense(N_CLASS, activation='sigmoid', kernel_initializer='lecun_normal', name='output')(x)
model = Model(inputs=[input_title, input_body, input_answer], outputs=[output])

model.summary()
# Out:
# Model: "model"
# __________________________________________________________________________________________________
# Layer (type)                    Output Shape         Param #     Connected to
# ==================================================================================================
# input_title (InputLayer)        [(None, 1)]          0
# __________________________________________________________________________________________________
# input_body (InputLayer)         [(None, 1)]          0
# __________________________________________________________________________________________________
# input_answer (InputLayer)       [(None, 1)]          0
# __________________________________________________________________________________________________
# lambda (Lambda)                 (None, 512)          0           input_title[0][0]
# __________________________________________________________________________________________________
# lambda_1 (Lambda)               (None, 512)          0           input_body[0][0]
# __________________________________________________________________________________________________
# lambda_2 (Lambda)               (None, 512)          0           input_answer[0][0]
# __________________________________________________________________________________________________
# reshape (Reshape)               (None, 512, 1)       0           lambda[0][0]
# __________________________________________________________________________________________________
# reshape_1 (Reshape)             (None, 512, 1)       0           lambda_1[0][0]
# __________________________________________________________________________________________________
# reshape_2 (Reshape)             (None, 512, 1)       0           lambda_2[0][0]
# __________________________________________________________________________________________________
# global_average_pooling1d (Globa (None, 1)            0           reshape[0][0]
# __________________________________________________________________________________________________
# global_average_pooling1d_1 (Glo (None, 1)            0           reshape_1[0][0]
# __________________________________________________________________________________________________
# global_average_pooling1d_2 (Glo (None, 1)            0           reshape_2[0][0]
# __________________________________________________________________________________________________
# concatenate (Concatenate)       (None, 513)          0           global_average_pooling1d[0][0]
#                                                                  lambda[0][0]
# __________________________________________________________________________________________________
# concatenate_1 (Concatenate)     (None, 513)          0           global_average_pooling1d_1[0][0]
#                                                                  lambda_1[0][0]
# __________________________________________________________________________________________________
# concatenate_2 (Concatenate)     (None, 513)          0           global_average_pooling1d_2[0][0]
#                                                                  lambda_2[0][0]
# __________________________________________________________________________________________________
# dense (Dense)                   (None, 128)          65792       concatenate[0][0]
# __________________________________________________________________________________________________
# dense_1 (Dense)                 (None, 128)          65792       concatenate_1[0][0]
# __________________________________________________________________________________________________
# dense_2 (Dense)                 (None, 128)          65792       concatenate_2[0][0]
# __________________________________________________________________________________________________
# concatenate_3 (Concatenate)     (None, 384)          0           dense[0][0]
#                                                                  dense_1[0][0]
#                                                                  dense_2[0][0]
# __________________________________________________________________________________________________
# dropout (Dropout)               (None, 384)          0           concatenate_3[0][0]
# __________________________________________________________________________________________________
# dense_3 (Dense)                 (None, 512)          197120      dropout[0][0]
# __________________________________________________________________________________________________
# dropout_1 (Dropout)             (None, 512)          0           dense_3[0][0]
# __________________________________________________________________________________________________
# output (Dense)                  (None, 30)           15390       dropout_1[0][0]
# ==================================================================================================
# Total params: 409,886
# Trainable params: 409,886
# Non-trainable params: 0
# __________________________________________________________________________________________________

# %% [markdown]
# # Train model

# %%
rlrop = ReduceLROnPlateau(monitor='val_loss', mode='min', patience=RLROP_PATIENCE, factor=DECAY_DROP, min_lr=1e-7, verbose=1)
spearmanCallback = SpearmanRhoCallback(training_data=(X_train, Y_train), validation_data=(X_valid, Y_valid), monitor='val_loss', mode='min', patience=ES_PATIENCE)
callback_list = [rlrop, spearmanCallback]

optimizer = optimizers.Adam(LEARNING_RATE)
model.compile(optimizer=optimizer, loss='binary_crossentropy')

history = model.fit(X_train, Y_train, 
                    validation_data=(X_valid, Y_valid), 
                    callbacks=callback_list, 
                    batch_size=BATCH_SIZE, 
                    epochs=EPOCHS, 
                    verbose=2).history
# Out:
# Train on 4863 samples, validate on 1216 samples
# Epoch 1/50
# spearman-rho: 0.1934 val_spearman-rho: 0.1808
# 4863/4863 - 28s - loss: 0.4841 - val_loss: 0.4184
# Epoch 2/50
# spearman-rho: 0.2739 val_spearman-rho: 0.2562
# 4863/4863 - 19s - loss: 0.4093 - val_loss: 0.4010
# Epoch 3/50
# spearman-rho: 0.3103 val_spearman-rho: 0.2888
# 4863/4863 - 19s - loss: 0.3975 - val_loss: 0.3945
# Epoch 4/50
# spearman-rho: 0.3360 val_spearman-rho: 0.3082
# 4863/4863 - 19s - loss: 0.3916 - val_loss: 0.3896
# Epoch 5/50
# spearman-rho: 0.3555 val_spearman-rho: 0.3217
# 4863/4863 - 19s - loss: 0.3861 - val_loss: 0.3867
# Epoch 6/50
# spearman-rho: 0.3693 val_spearman-rho: 0.3295
# 4863/4863 - 19s - loss: 0.3825 - val_loss: 0.3833
# Epoch 7/50
# spearman-rho: 0.3805 val_spearman-rho: 0.3340
# 4863/4863 - 19s - loss: 0.3794 - val_loss: 0.3814
# Epoch 8/50
# spearman-rho: 0.3898 val_spearman-rho: 0.3379
# 4863/4863 - 19s - loss: 0.3767 - val_loss: 0.3805
# Epoch 9/50
# spearman-rho: 0.3980 val_spearman-rho: 0.3427
# 4863/4863 - 19s - loss: 0.3745 - val_loss: 0.3794
# Epoch 10/50
# spearman-rho: 0.4058 val_spearman-rho: 0.3468
# 4863/4863 - 19s - loss: 0.3728 - val_loss: 0.3785
# Epoch 11/50
# spearman-rho: 0.4130 val_spearman-rho: 0.3492
# 4863/4863 - 19s - loss: 0.3710 - val_loss: 0.3782
# Epoch 12/50
# spearman-rho: 0.4189 val_spearman-rho: 0.3511
# 4863/4863 - 19s - loss: 0.3696 - val_loss: 0.3776
# Epoch 13/50
# spearman-rho: 0.4254 val_spearman-rho: 0.3538
# 4863/4863 - 19s - loss: 0.3683 - val_loss: 0.3771
# Epoch 14/50
# spearman-rho: 0.4296 val_spearman-rho: 0.3548
# 4863/4863 - 19s - loss: 0.3666 - val_loss: 0.3770
# Epoch 15/50
# spearman-rho: 0.4356 val_spearman-rho: 0.3566
# 4863/4863 - 19s - loss: 0.3655 - val_loss: 0.3767
# Epoch 16/50
# spearman-rho: 0.4402 val_spearman-rho: 0.3565
# 4863/4863 - 19s - loss: 0.3641 - val_loss: 0.3765
# Epoch 17/50
# spearman-rho: 0.4446 val_spearman-rho: 0.3571
# 4863/4863 - 18s - loss: 0.3629 - val_loss: 0.3763
# Epoch 18/50
# spearman-rho: 0.4496 val_spearman-rho: 0.3587
# 4863/4863 - 19s - loss: 0.3620 - val_loss: 0.3760
# Epoch 19/50
# spearman-rho: 0.4536 val_spearman-rho: 0.3590
# 4863/4863 - 19s - loss: 0.3606 - val_loss: 0.3764
# Epoch 20/50
# spearman-rho: 0.4589 val_spearman-rho: 0.3605
# 4863/4863 - 19s - loss: 0.3595 - val_loss: 0.3757
# Epoch 21/50
# spearman-rho: 0.4629 val_spearman-rho: 0.3611
# 4863/4863 - 18s - loss: 0.3582 - val_loss: 0.3755
# Epoch 22/50
# spearman-rho: 0.4673 val_spearman-rho: 0.3617
# 4863/4863 - 19s - loss: 0.3572 - val_loss: 0.3755
# Epoch 23/50
#
# Epoch 00023: ReduceLROnPlateau reducing learning rate to 9.000000427477062e-05.
# spearman-rho: 0.4710 val_spearman-rho: 0.3626
# 4863/4863 - 21s - loss: 0.3561 - val_loss: 0.3756
# Epoch 24/50
# spearman-rho: 0.4729 val_spearman-rho: 0.3630
# 4863/4863 - 19s - loss: 0.3548 - val_loss: 0.3753
# Epoch 25/50
# spearman-rho: 0.4744 val_spearman-rho: 0.3630
# 4863/4863 - 19s - loss: 0.3545 - val_loss: 0.3753
# Epoch 26/50
#
# Epoch 00026: ReduceLROnPlateau reducing learning rate to 2.700000040931627e-05.
# spearman-rho: 0.4759 val_spearman-rho: 0.3632
# 4863/4863 - 19s - loss: 0.3536 - val_loss: 0.3753
# Epoch 27/50
# spearman-rho: 0.4763 val_spearman-rho: 0.3634
# Epoch 00026: early stopping
# 4863/4863 - 18s - loss: 0.3534 - val_loss: 0.3753

# %% [markdown]
# ## Model loss graph

# %%
sns.set(style="whitegrid")
plot_metrics(history, metric_list=['loss', 'spearman'])

# %% [markdown]
# # Evaluation

# %%
preds_train = model.predict(X_train)
preds_val = model.predict(X_valid)

display(get_metrics(Y_train, preds_train, Y_valid, preds_val, target_cols))
# 0.482	0.367
# Out:
#                                     Label  Train  Validation
# 0                                Averaged  0.476       0.363
# 1     question_asker_intent_understanding  0.433       0.387
# 2                  question_body_critical  0.684       0.613
# 3                 question_conversational  0.459       0.395
# 4            question_expect_short_answer  0.482       0.261
# 5                   question_fact_seeking  0.536       0.343
# 6   question_has_commonly_accepted_answer  0.584       0.432
# 7         question_interestingness_others  0.384       0.370
# 8           question_interestingness_self  0.525       0.494
# 9                   question_multi_intent  0.588       0.431
# 10         question_not_really_a_question  0.108       0.056
# 11               question_opinion_seeking  0.664       0.441
# 12                   question_type_choice  0.752       0.596
# 13                  question_type_compare  0.383       0.308
# 14              question_type_consequence  0.189       0.152
# 15               question_type_definition  0.376       0.312
# 16                   question_type_entity  0.464       0.419
# 17             question_type_instructions  0.838       0.752
# 18                question_type_procedure  0.471       0.269
# 19       question_type_reason_explanation  0.745       0.643
# 20                 question_type_spelling  0.067       0.066
# 21                  question_well_written  0.553       0.490
# 22                         answer_helpful  0.341       0.169
# 23            answer_level_of_information  0.426       0.328
# 24                       answer_plausible  0.291       0.160
# 25                       answer_relevance  0.286       0.122
# 26                    answer_satisfaction  0.394       0.213
# 27               answer_type_instructions  0.833       0.706
# 28                  answer_type_procedure  0.417       0.231
# 29         answer_type_reason_explanation  0.768       0.646
# 30                    answer_well_written  0.247       0.096

# %% [markdown]
# ## By category

# %%
target_cols_preds = [col+'_pred' for col in target_cols]
for col in target_cols_preds:
    train[col] = 0
    validation[col] = 0
    
train[target_cols_preds] = preds_train
validation[target_cols_preds] = preds_val
    
display(get_metrics_category(train, validation, target_cols, target_cols_preds, 'category'))
# Out:
#       Label Train (TECHNOLOGY) Validation (TECHNOLOGY) Train (SCIENCE)  \
# 0  Averaged              0.443                   0.328           0.485
#
#   Validation (SCIENCE) Train (STACKOVERFLOW) Validation (STACKOVERFLOW)  \
# 0                0.353                 0.376                      0.189
#
#   Train (LIFE_ARTS) Validation (LIFE_ARTS) Train (CULTURE)  \
# 0             0.492                  0.395           0.489
#
#   Validation (CULTURE)
# 0                0.368

# %% [markdown]
# #### Save model weights and ecoders

# %%
model.save_weights(model_path)
