# %% [markdown]
# ## Dependencies

# %%
import re
import warnings
import tensorflow_hub as hub
from tensorflow.keras import Model, optimizers
from tensorflow.keras.layers import Lambda, Input, Dense, Dropout, Concatenate, BatchNormalization, Activation
from tensorflow.keras.callbacks import EarlyStopping, ReduceLROnPlateau
from googleqa_utilityscript import *


SEED = 0
seed_everything(SEED)
warnings.filterwarnings("ignore")

# %% [markdown]
# ## Load data

# %%
hold_out = pd.read_csv('/kaggle/input/googleqa-mldataset/hold-out.csv')
train = hold_out[hold_out['set'] == 'train']
validation = hold_out[hold_out['set'] == 'validation']

print('Train samples: %s' % len(train))
print('Validation samples: %s' % len(validation))
display(train.head())
# Out:
# Train samples: 4863
# Validation samples: 1216
#    qa_id                                     question_title  \
# 0   3895  Magento (1.7) Bundled Product with FREE Produc...
# 1   3131                             Find router on network
# 2   1507  Negatively curved metrics minimizing the lengt...
# 3   6784               Isn’t the FAQ label obsolete by now?
# 4   2135  Changing background image one time on responsi...
#
#                                        question_body question_user_name  \
# 0  I'm looking to create a bundle offer where cus...                Joe
# 1  I've just bought a Belkin N+ Wireless Router. ...                Guy
# 2  Good afternoon everyone !\n\nI have the follow...            Selim G
# 3  Don’t get me wrong in the beginning of reading...     Benny Skogberg
# 4  The code I'm using is this one \n\nbackground:...        user2141649
#
#                               question_user_page  \
# 0  https://magento.stackexchange.com/users/16572
# 1               https://superuser.com/users/3248
# 2           https://mathoverflow.net/users/25511
# 3        https://ux.stackexchange.com/users/4679
# 4        https://stackoverflow.com/users/2141649
#
#                                               answer   answer_user_name  \
# 0  Since the third item is fixed, you can use sho...  Fabian Schmengler
# 1  You likely have the router plugged in to the m...             John T
# 2  A very partial answer: by the results of Richa...         Igor Rivin
# 3  Isn’t the FAQ label obsolete by now? \n\nI'd s...        Solracnapod
# 4  &lt;!DOCTYPE html&gt;\n&lt;html&gt;\n&lt;head&...           akkimads
#
#                               answer_user_page  \
# 0  https://magento.stackexchange.com/users/243
# 1             https://superuser.com/users/1931
# 2         https://mathoverflow.net/users/11142
# 3     https://ux.stackexchange.com/users/13153
# 4      https://stackoverflow.com/users/2375373
#
#                                                  url       category  ...  \
# 0  http://magento.stackexchange.com/questions/668...     TECHNOLOGY  ...
# 1               http://superuser.com/questions/87212     TECHNOLOGY  ...
# 2           http://mathoverflow.net/questions/203422        SCIENCE  ...
# 3  http://ux.stackexchange.com/questions/18600/is...     TECHNOLOGY  ...
# 4  http://stackoverflow.com/questions/16359492/ch...  STACKOVERFLOW  ...
#
#   answer_helpful  answer_level_of_information  answer_plausible  \
# 0       0.888889                     0.666667               1.0
# 1       1.000000                     0.666667               1.0
# 2       0.888889                     0.333333               1.0
# 3       0.888889                     0.666667               1.0
# 4       0.888889                     0.500000               1.0
#
#    answer_relevance  answer_satisfaction  answer_type_instructions  \
# 0               1.0             0.933333                  1.000000
# 1               1.0             0.866667                  0.666667
# 2               1.0             0.700000                  0.333333
# 3               1.0             0.933333                  0.000000
# 4               1.0             0.800000                  1.000000
#
#    answer_type_procedure  answer_type_reason_explanation  answer_well_written  \
# 0               0.000000                        0.333333             0.888889
# 1               0.000000                        1.000000             1.000000
# 2               0.333333                        1.000000             0.888889
# 3               0.000000                        0.666667             1.000000
# 4               0.000000                        0.000000             0.777778
#
#      set
# 0  train
# 1  train
# 2  train
# 3  train
# 4  train
#
# [5 rows x 42 columns]

# %%
question_target_cols = ['question_asker_intent_understanding','question_body_critical', 'question_conversational', 
                        'question_expect_short_answer', 'question_fact_seeking', 'question_has_commonly_accepted_answer',
                        'question_interestingness_others', 'question_interestingness_self', 'question_multi_intent', 
                        'question_not_really_a_question', 'question_opinion_seeking', 'question_type_choice',
                        'question_type_compare', 'question_type_consequence', 'question_type_definition', 
                        'question_type_entity', 'question_type_instructions', 'question_type_procedure',
                        'question_type_reason_explanation', 'question_type_spelling', 'question_well_written']
answer_target_cols = ['answer_helpful', 'answer_level_of_information', 'answer_plausible', 'answer_relevance',
                      'answer_satisfaction', 'answer_type_instructions', 'answer_type_procedure', 
                      'answer_type_reason_explanation', 'answer_well_written']
target_cols = question_target_cols + answer_target_cols

# %% [markdown]
# ## Pre-process data

# %%
text_features = ['question_title', 'question_body', 'answer']

for feature in text_features:
    # Clean special symbols
    train[feature] = train[feature].apply(lambda x: re.sub(r"[^A-Za-z0-9^,!.\/'+-=]", " ", x))
    validation[feature] = validation[feature].apply(lambda x: re.sub(r"[^A-Za-z0-9^,!.\/'+-=]", " ", x))
    # Trim text
    train[feature] = train[feature].apply(lambda x: x.strip())
    validation[feature] = validation[feature].apply(lambda x: x.strip())

# %% [markdown]
# ## Train/validation sets

# %%
# Train features
X_train_title = train['question_title']
X_train_body = train['question_body']
X_train_answer = train['answer']

X_train = [X_train_title, X_train_body, X_train_answer]
Y_train = train[target_cols].values

# Validation features
X_valid_title = validation['question_title']
X_valid_body = validation['question_body']
X_valid_answer = validation['answer']

X_valid = [X_valid_title, X_valid_body, X_valid_answer]
Y_valid = validation[target_cols].values

print('Train samples: %d' % len(Y_train))
print('Validation samples: %d' % len(Y_valid))
# Out:
# Train samples: 4863
# Validation samples: 1216

# %% [markdown]
# # Model parameters

# %%
EPOCHS = 40
BATCH_SIZE = 32
LEARNING_RATE = 3e-4
EMBEDDDING_SIZE = 512
N_CLASS = len(target_cols)
ES_PATIENCE = 3
RLROP_PATIENCE = 2
DECAY_DROP = 0.3
module_url = '/kaggle/input/universalsentenceencodermodels/universal-sentence-encoder-models/use'
model_path = '/kaggle/working/use.h5'

# %% [markdown]
# # Model

# %%
es = EarlyStopping(monitor='val_loss', mode='min', patience=ES_PATIENCE, restore_best_weights=True, verbose=1)
rlrop = ReduceLROnPlateau(monitor='val_loss', mode='min', patience=RLROP_PATIENCE, factor=DECAY_DROP, min_lr=1e-6, verbose=1)
use_embed = hub.load(module_url)

def USEEmbedding(x):
    return use_embed(tf.squeeze(tf.cast(x, tf.string)))

# %%
input_title = Input(shape=(1,), dtype=tf.string, name='input_title')
embedding_title = Lambda(USEEmbedding, output_shape=(EMBEDDDING_SIZE,))(input_title)

input_body = Input(shape=(1,), dtype=tf.string, name='input_body')
embedding_body = Lambda(USEEmbedding, output_shape=(EMBEDDDING_SIZE,))(input_body)

input_answer = Input(shape=(1,), dtype=tf.string, name='input_answer')
embedding_answer = Lambda(USEEmbedding, output_shape=(EMBEDDDING_SIZE,))(input_answer)

x = Concatenate()([embedding_title, embedding_body, embedding_answer])
x = Dropout(0.5)(x)
x = Dense(512, activation='relu')(x)
x = Dropout(0.5)(x)
output = Dense(N_CLASS, activation='sigmoid', name='output')(x)
model = Model(inputs=[input_title, input_body, input_answer], outputs=[output])

model.summary()
# Out:
# Model: "model"
# __________________________________________________________________________________________________
# Layer (type)                    Output Shape         Param #     Connected to
# ==================================================================================================
# input_title (InputLayer)        [(None, 1)]          0
# __________________________________________________________________________________________________
# input_body (InputLayer)         [(None, 1)]          0
# __________________________________________________________________________________________________
# input_answer (InputLayer)       [(None, 1)]          0
# __________________________________________________________________________________________________
# lambda (Lambda)                 (None, 512)          0           input_title[0][0]
# __________________________________________________________________________________________________
# lambda_1 (Lambda)               (None, 512)          0           input_body[0][0]
# __________________________________________________________________________________________________
# lambda_2 (Lambda)               (None, 512)          0           input_answer[0][0]
# __________________________________________________________________________________________________
# concatenate (Concatenate)       (None, 1536)         0           lambda[0][0]
#                                                                  lambda_1[0][0]
#                                                                  lambda_2[0][0]
# __________________________________________________________________________________________________
# dropout (Dropout)               (None, 1536)         0           concatenate[0][0]
# __________________________________________________________________________________________________
# dense (Dense)                   (None, 512)          786944      dropout[0][0]
# __________________________________________________________________________________________________
# dropout_1 (Dropout)             (None, 512)          0           dense[0][0]
# __________________________________________________________________________________________________
# output (Dense)                  (None, 30)           15390       dropout_1[0][0]
# ==================================================================================================
# Total params: 802,334
# Trainable params: 802,334
# Non-trainable params: 0
# __________________________________________________________________________________________________

# %% [markdown]
# # Train model

# %%
optimizer = optimizers.Adam(LEARNING_RATE)
spearmanCallback = SpearmanRhoCallback(training_data=(X_train, Y_train), validation_data=(X_valid, Y_valid))
callback_list = [es, rlrop, spearmanCallback]
model.compile(optimizer=optimizer, loss='binary_crossentropy')

history = model.fit(X_train, Y_train, 
                    validation_data=(X_valid, Y_valid), 
                    callbacks=callback_list, 
                    batch_size=BATCH_SIZE,
                    epochs=EPOCHS, 
                    verbose=2).history
# Out:
# Train on 4863 samples, validate on 1216 samples
# Epoch 1/40
# Train spearman-rho: 0.2151 Validation spearman-rho: 0.2037
# 4863/4863 - 43s - loss: 0.4922 - val_loss: 0.4138
# Epoch 2/40
# Train spearman-rho: 0.2902 Validation spearman-rho: 0.2731
# 4863/4863 - 32s - loss: 0.4065 - val_loss: 0.3988
# Epoch 3/40
# Train spearman-rho: 0.3299 Validation spearman-rho: 0.3083
# 4863/4863 - 33s - loss: 0.3958 - val_loss: 0.3917
# Epoch 4/40
# Train spearman-rho: 0.3539 Validation spearman-rho: 0.3255
# 4863/4863 - 32s - loss: 0.3895 - val_loss: 0.3874
# Epoch 5/40
# Train spearman-rho: 0.3723 Validation spearman-rho: 0.3363
# 4863/4863 - 32s - loss: 0.3854 - val_loss: 0.3847
# Epoch 6/40
# Train spearman-rho: 0.3860 Validation spearman-rho: 0.3425
# 4863/4863 - 32s - loss: 0.3821 - val_loss: 0.3828
# Epoch 7/40
# Train spearman-rho: 0.3966 Validation spearman-rho: 0.3472
# 4863/4863 - 32s - loss: 0.3801 - val_loss: 0.3812
# Epoch 8/40
# Train spearman-rho: 0.4061 Validation spearman-rho: 0.3503
# 4863/4863 - 32s - loss: 0.3771 - val_loss: 0.3802
# Epoch 9/40
# Train spearman-rho: 0.4145 Validation spearman-rho: 0.3537
# 4863/4863 - 34s - loss: 0.3753 - val_loss: 0.3795
# Epoch 10/40
# Train spearman-rho: 0.4208 Validation spearman-rho: 0.3557
# 4863/4863 - 33s - loss: 0.3739 - val_loss: 0.3787
# Epoch 11/40
# Train spearman-rho: 0.4280 Validation spearman-rho: 0.3578
# 4863/4863 - 33s - loss: 0.3727 - val_loss: 0.3784
# Epoch 12/40
# Train spearman-rho: 0.4326 Validation spearman-rho: 0.3585
# 4863/4863 - 33s - loss: 0.3716 - val_loss: 0.3781
# Epoch 13/40
# Train spearman-rho: 0.4378 Validation spearman-rho: 0.3592
# 4863/4863 - 34s - loss: 0.3702 - val_loss: 0.3775
# Epoch 14/40
# Train spearman-rho: 0.4421 Validation spearman-rho: 0.3612
# 4863/4863 - 32s - loss: 0.3693 - val_loss: 0.3772
# Epoch 15/40
# Train spearman-rho: 0.4468 Validation spearman-rho: 0.3625
# 4863/4863 - 32s - loss: 0.3691 - val_loss: 0.3770
# Epoch 16/40
# Train spearman-rho: 0.4499 Validation spearman-rho: 0.3636
# 4863/4863 - 32s - loss: 0.3678 - val_loss: 0.3765
# Epoch 17/40
# Train spearman-rho: 0.4536 Validation spearman-rho: 0.3647
# 4863/4863 - 32s - loss: 0.3674 - val_loss: 0.3764
# Epoch 18/40
# Train spearman-rho: 0.4573 Validation spearman-rho: 0.3659
# 4863/4863 - 33s - loss: 0.3667 - val_loss: 0.3762
# Epoch 19/40
# Train spearman-rho: 0.4601 Validation spearman-rho: 0.3660
# 4863/4863 - 32s - loss: 0.3658 - val_loss: 0.3763
# Epoch 20/40
# Train spearman-rho: 0.4644 Validation spearman-rho: 0.3675
# 4863/4863 - 32s - loss: 0.3652 - val_loss: 0.3759
# Epoch 21/40
# Train spearman-rho: 0.4673 Validation spearman-rho: 0.3675
# 4863/4863 - 32s - loss: 0.3642 - val_loss: 0.3757
# Epoch 22/40
# Train spearman-rho: 0.4705 Validation spearman-rho: 0.3687
# 4863/4863 - 32s - loss: 0.3637 - val_loss: 0.3756
# Epoch 23/40
# Train spearman-rho: 0.4737 Validation spearman-rho: 0.3694
# 4863/4863 - 31s - loss: 0.3630 - val_loss: 0.3755
# Epoch 24/40
# Train spearman-rho: 0.4762 Validation spearman-rho: 0.3703
# 4863/4863 - 31s - loss: 0.3627 - val_loss: 0.3753
# Epoch 25/40
# Train spearman-rho: 0.4786 Validation spearman-rho: 0.3703
# 4863/4863 - 31s - loss: 0.3626 - val_loss: 0.3752
# Epoch 26/40
# Train spearman-rho: 0.4814 Validation spearman-rho: 0.3707
# 4863/4863 - 30s - loss: 0.3619 - val_loss: 0.3751
# Epoch 27/40
# Train spearman-rho: 0.4843 Validation spearman-rho: 0.3711
# 4863/4863 - 31s - loss: 0.3614 - val_loss: 0.3749
# Epoch 28/40
# Train spearman-rho: 0.4870 Validation spearman-rho: 0.3720
# 4863/4863 - 31s - loss: 0.3607 - val_loss: 0.3747
# Epoch 29/40
# Train spearman-rho: 0.4894 Validation spearman-rho: 0.3721
# 4863/4863 - 31s - loss: 0.3602 - val_loss: 0.3748
# Epoch 30/40
#
# Epoch 00030: ReduceLROnPlateau reducing learning rate to 9.000000427477062e-05.
# Train spearman-rho: 0.4916 Validation spearman-rho: 0.3730
# 4863/4863 - 30s - loss: 0.3599 - val_loss: 0.3748
# Epoch 31/40
# Train spearman-rho: 0.4926 Validation spearman-rho: 0.3734
# 4863/4863 - 31s - loss: 0.3583 - val_loss: 0.3745
# Epoch 32/40
# Train spearman-rho: 0.4935 Validation spearman-rho: 0.3735
# 4863/4863 - 31s - loss: 0.3578 - val_loss: 0.3745
# Epoch 33/40
#
# Epoch 00033: ReduceLROnPlateau reducing learning rate to 2.700000040931627e-05.
# Train spearman-rho: 0.4942 Validation spearman-rho: 0.3737
# 4863/4863 - 32s - loss: 0.3579 - val_loss: 0.3745
# Epoch 34/40
# Train spearman-rho: 0.4946 Validation spearman-rho: 0.3736
# 4863/4863 - 32s - loss: 0.3577 - val_loss: 0.3745
# Epoch 35/40
#
# Epoch 00035: ReduceLROnPlateau reducing learning rate to 8.100000013655517e-06.
# Train spearman-rho: 0.4949 Validation spearman-rho: 0.3737
# 4863/4863 - 31s - loss: 0.3584 - val_loss: 0.3745
# Epoch 36/40
# Train spearman-rho: 0.4950 Validation spearman-rho: 0.3737
# 4863/4863 - 32s - loss: 0.3572 - val_loss: 0.3745
# Epoch 37/40
# Restoring model weights from the end of the best epoch.
#
# Epoch 00037: ReduceLROnPlateau reducing learning rate to 2.429999949526973e-06.
# Train spearman-rho: 0.4946 Validation spearman-rho: 0.3736
# 4863/4863 - 32s - loss: 0.3584 - val_loss: 0.3745
# Epoch 38/40
# Train spearman-rho: 0.4946 Validation spearman-rho: 0.3736
# 4863/4863 - 32s - loss: 0.3579 - val_loss: 0.3745
# Epoch 39/40
#
# Epoch 00039: ReduceLROnPlateau reducing learning rate to 1e-06.
# Train spearman-rho: 0.4947 Validation spearman-rho: 0.3736
# 4863/4863 - 31s - loss: 0.3577 - val_loss: 0.3745
# Epoch 40/40
# Train spearman-rho: 0.4947 Validation spearman-rho: 0.3736
# 4863/4863 - 31s - loss: 0.3578 - val_loss: 0.3745
# Epoch 00037: early stopping

# %% [markdown]
# ## Model loss graph

# %%
sns.set(style="whitegrid")
for key in spearmanCallback.history.keys():
    history[key] = spearmanCallback.history[key]

plot_metrics(history, metric_list=['loss', 'spearman'])

# %% [markdown]
# # Evaluation

# %%
preds_train = model.predict(X_train)
preds_val = model.predict(X_valid)

display(get_metrics(Y_train, preds_train, Y_valid, preds_val, target_cols))
# Out:
#                                     Label  Train  Validation
# 0                                Averaged  0.495       0.374
# 1     question_asker_intent_understanding  0.477       0.403
# 2                  question_body_critical  0.716       0.623
# 3                 question_conversational  0.462       0.409
# 4            question_expect_short_answer  0.517       0.265
# 5                   question_fact_seeking  0.537       0.342
# 6   question_has_commonly_accepted_answer  0.556       0.421
# 7         question_interestingness_others  0.453       0.392
# 8           question_interestingness_self  0.596       0.535
# 9                   question_multi_intent  0.597       0.439
# 10         question_not_really_a_question  0.143       0.056
# 11               question_opinion_seeking  0.637       0.461
# 12                   question_type_choice  0.727       0.590
# 13                  question_type_compare  0.396       0.305
# 14              question_type_consequence  0.214       0.173
# 15               question_type_definition  0.381       0.309
# 16                   question_type_entity  0.472       0.444
# 17             question_type_instructions  0.821       0.742
# 18                question_type_procedure  0.515       0.284
# 19       question_type_reason_explanation  0.718       0.641
# 20                 question_type_spelling  0.074       0.070
# 21                  question_well_written  0.602       0.491
# 22                         answer_helpful  0.373       0.192
# 23            answer_level_of_information  0.479       0.356
# 24                       answer_plausible  0.300       0.137
# 25                       answer_relevance  0.282       0.142
# 26                    answer_satisfaction  0.443       0.257
# 27               answer_type_instructions  0.820       0.708
# 28                  answer_type_procedure  0.471       0.260
# 29         answer_type_reason_explanation  0.742       0.630
# 30                    answer_well_written  0.319       0.130

# %% [markdown]
# ## By category

# %%
target_cols_preds = [col+'_pred' for col in target_cols]
for col in target_cols_preds:
    train[col] = 0
    validation[col] = 0
    
train[target_cols_preds] = preds_train
validation[target_cols_preds] = preds_val
    
display(get_metrics_category(train, validation, target_cols, target_cols_preds, 'category'))
# Out:
#       Label Train (TECHNOLOGY) Validation (TECHNOLOGY) Train (SCIENCE)  \
# 0  Averaged              0.464                   0.335           0.505
#
#   Validation (SCIENCE) Train (STACKOVERFLOW) Validation (STACKOVERFLOW)  \
# 0                0.374                 0.398                      0.195
#
#   Train (LIFE_ARTS) Validation (LIFE_ARTS) Train (CULTURE)  \
# 0             0.519                  0.416           0.518
#
#   Validation (CULTURE)
# 0                0.383

# %% [markdown]
# #### Save model weights

# %%
model.save_weights(model_path)
