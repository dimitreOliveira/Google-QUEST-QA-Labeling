# %% [markdown]
# ## Dependencies

# %%
import gc
import re
import warnings
from joblib import dump
import tensorflow_hub as hub
from tensorflow.keras import Model, optimizers
from tensorflow.keras.callbacks import ReduceLROnPlateau
from tensorflow.keras.preprocessing.text import Tokenizer
from tensorflow.keras.preprocessing.sequence import pad_sequences
from tensorflow.keras.layers import Lambda, Input, Dense, Dropout, Concatenate, BatchNormalization, Activation, Average, Add, Reshape
from tensorflow.keras.layers import GlobalAveragePooling1D, Embedding, LSTM, Conv1D, SpatialDropout1D, Bidirectional, Flatten
from googleqa_utilityscript import *


SEED = 0
seed_everything(SEED)
warnings.filterwarnings("ignore")

# %% [markdown]
# ## Load data

# %%
module_url = '/kaggle/input/universalsentenceencodermodels/universal-sentence-encoder-models/use'
model_path = '/kaggle/working/model.h5'
tokenizer_path = '/kaggle/working/tokenizer.joblib'
encoder_path = '/kaggle/input/pickled-glove840b300d-for-10sec-loading/glove.840B.300d.pkl'

hold_out = pd.read_csv('/kaggle/input/googleqa-mldataset/hold-out.csv')
test = pd.read_csv('/kaggle/input/google-quest-challenge/test.csv')
train = hold_out[hold_out['set'] == 'train']
validation = hold_out[hold_out['set'] == 'validation']

print('Train samples: %s' % len(train))
print('Validation samples: %s' % len(validation))
display(train.head())
# Out:
# Train samples: 4863
# Validation samples: 1216
#    qa_id                                     question_title  \
# 0   3895  Magento (1.7) Bundled Product with FREE Produc...
# 1   3131                             Find router on network
# 2   1507  Negatively curved metrics minimizing the lengt...
# 3   6784               Isn’t the FAQ label obsolete by now?
# 4   2135  Changing background image one time on responsi...
#
#                                        question_body question_user_name  \
# 0  I'm looking to create a bundle offer where cus...                Joe
# 1  I've just bought a Belkin N+ Wireless Router. ...                Guy
# 2  Good afternoon everyone !\n\nI have the follow...            Selim G
# 3  Don’t get me wrong in the beginning of reading...     Benny Skogberg
# 4  The code I'm using is this one \n\nbackground:...        user2141649
#
#                               question_user_page  \
# 0  https://magento.stackexchange.com/users/16572
# 1               https://superuser.com/users/3248
# 2           https://mathoverflow.net/users/25511
# 3        https://ux.stackexchange.com/users/4679
# 4        https://stackoverflow.com/users/2141649
#
#                                               answer   answer_user_name  \
# 0  Since the third item is fixed, you can use sho...  Fabian Schmengler
# 1  You likely have the router plugged in to the m...             John T
# 2  A very partial answer: by the results of Richa...         Igor Rivin
# 3  Isn’t the FAQ label obsolete by now? \n\nI'd s...        Solracnapod
# 4  &lt;!DOCTYPE html&gt;\n&lt;html&gt;\n&lt;head&...           akkimads
#
#                               answer_user_page  \
# 0  https://magento.stackexchange.com/users/243
# 1             https://superuser.com/users/1931
# 2         https://mathoverflow.net/users/11142
# 3     https://ux.stackexchange.com/users/13153
# 4      https://stackoverflow.com/users/2375373
#
#                                                  url       category  ...  \
# 0  http://magento.stackexchange.com/questions/668...     TECHNOLOGY  ...
# 1               http://superuser.com/questions/87212     TECHNOLOGY  ...
# 2           http://mathoverflow.net/questions/203422        SCIENCE  ...
# 3  http://ux.stackexchange.com/questions/18600/is...     TECHNOLOGY  ...
# 4  http://stackoverflow.com/questions/16359492/ch...  STACKOVERFLOW  ...
#
#   answer_helpful  answer_level_of_information  answer_plausible  \
# 0       0.888889                     0.666667               1.0
# 1       1.000000                     0.666667               1.0
# 2       0.888889                     0.333333               1.0
# 3       0.888889                     0.666667               1.0
# 4       0.888889                     0.500000               1.0
#
#    answer_relevance  answer_satisfaction  answer_type_instructions  \
# 0               1.0             0.933333                  1.000000
# 1               1.0             0.866667                  0.666667
# 2               1.0             0.700000                  0.333333
# 3               1.0             0.933333                  0.000000
# 4               1.0             0.800000                  1.000000
#
#    answer_type_procedure  answer_type_reason_explanation  answer_well_written  \
# 0               0.000000                        0.333333             0.888889
# 1               0.000000                        1.000000             1.000000
# 2               0.333333                        1.000000             0.888889
# 3               0.000000                        0.666667             1.000000
# 4               0.000000                        0.000000             0.777778
#
#      set
# 0  train
# 1  train
# 2  train
# 3  train
# 4  train
#
# [5 rows x 42 columns]

# %%
question_target_cols = ['question_asker_intent_understanding','question_body_critical', 'question_conversational', 
                        'question_expect_short_answer', 'question_fact_seeking', 'question_has_commonly_accepted_answer',
                        'question_interestingness_others', 'question_interestingness_self', 'question_multi_intent', 
                        'question_not_really_a_question', 'question_opinion_seeking', 'question_type_choice',
                        'question_type_compare', 'question_type_consequence', 'question_type_definition', 
                        'question_type_entity', 'question_type_instructions', 'question_type_procedure',
                        'question_type_reason_explanation', 'question_type_spelling', 'question_well_written']
answer_target_cols = ['answer_helpful', 'answer_level_of_information', 'answer_plausible', 'answer_relevance',
                      'answer_satisfaction', 'answer_type_instructions', 'answer_type_procedure', 
                      'answer_type_reason_explanation', 'answer_well_written']
target_cols = question_target_cols + answer_target_cols

# %% [markdown]
# ## Pre-process data

# %%
text_features = ['question_title', 'question_body', 'answer']
text_features_uncased = ['question_title_uncased', 'question_body_uncased', 'answer_uncased']


for feature in text_features:
    # Map contractions
    train[feature] = train[feature].apply(lambda x: map_contraction(x))
    validation[feature] = validation[feature].apply(lambda x: map_contraction(x))
    test[feature] = test[feature].apply(lambda x: map_contraction(x))
    # Trim text
    train[feature] = train[feature].apply(lambda x: x.strip())
    validation[feature] = validation[feature].apply(lambda x: x.strip())
    test[feature] = test[feature].apply(lambda x: x.strip())

for feature in text_features:
    train[feature + '_uncased'] = train[feature]
    validation[feature + '_uncased'] = validation[feature]
    test[feature + '_uncased'] = test[feature]

for feature in text_features:
    # Lower
    train[feature] = train[feature].apply(lambda x: x.lower())
    validation[feature] = validation[feature].apply(lambda x: x.lower())
    test[feature] = test[feature].apply(lambda x: x.lower())

# %% [markdown]
# # Model parameters

# %%
EPOCHS = 50
BATCH_SIZE = 32
LEARNING_RATE = 3e-4
EMBEDDDING_SIZE = 512
N_CLASS = len(target_cols)
ES_PATIENCE = 5
RLROP_PATIENCE = 2
DECAY_DROP = 0.3
MAX_FEATURES = 10000
TITLE_MAX_LEN = 30
BODY_MAX_LEN = 150
ANSWER_MAX_LEN = 150
EMBED_OUT = 250

# %%
tokenizer = Tokenizer(num_words=MAX_FEATURES)

tokenizer.fit_on_texts(list(train['question_title_uncased']) + list(validation['question_title_uncased']) + list(test['question_title_uncased']) +
                       list(train['question_body_uncased']) + list(validation['question_body_uncased']) + list(test['question_body_uncased']) +
                       list(train['answer_uncased']) + list(validation['answer_uncased']) + list(test['answer_uncased']))

# %% [markdown]
# ## Train/validation sets

# %%
# Train features
X_train_title = train['question_title']
X_train_body = train['question_body']
X_train_answer = train['answer']
X_train_title_seq = train['question_title_uncased']
X_train_body_seq = train['question_body_uncased']
X_train_answer_seq = train['answer_uncased']

# Tokenize the sentences
X_train_title_seq = tokenizer.texts_to_sequences(X_train_title_seq)
X_train_body_seq = tokenizer.texts_to_sequences(X_train_body_seq)
X_train_answer_seq = tokenizer.texts_to_sequences(X_train_answer_seq)

# Pad the sentences
X_train_title_seq = pad_sequences(X_train_title_seq, maxlen=TITLE_MAX_LEN)
X_train_body_seq = pad_sequences(X_train_body_seq, maxlen=BODY_MAX_LEN)
X_train_answer_seq = pad_sequences(X_train_answer_seq, maxlen=ANSWER_MAX_LEN)


X_train = [X_train_title, X_train_body, X_train_answer, X_train_title_seq, X_train_body_seq, X_train_answer_seq]
Y_train = train[target_cols].values

# Validation features
X_valid_title = validation['question_title']
X_valid_body = validation['question_body']
X_valid_answer = validation['answer']
X_valid_title_seq = validation['question_title_uncased']
X_valid_body_seq = validation['question_body_uncased']
X_valid_answer_seq = validation['answer_uncased']

# Tokenize the sentences
X_valid_title_seq = tokenizer.texts_to_sequences(X_valid_title_seq)
X_valid_body_seq = tokenizer.texts_to_sequences(X_valid_body_seq)
X_valid_answer_seq = tokenizer.texts_to_sequences(X_valid_answer_seq)

# Pad the sentences
X_valid_title_seq = pad_sequences(X_valid_title_seq, maxlen=TITLE_MAX_LEN)
X_valid_body_seq = pad_sequences(X_valid_body_seq, maxlen=BODY_MAX_LEN)
X_valid_answer_seq = pad_sequences(X_valid_answer_seq, maxlen=ANSWER_MAX_LEN)

X_valid = [X_valid_title, X_valid_body, X_valid_answer, X_valid_title_seq, X_valid_body_seq, X_valid_answer_seq]
Y_valid = validation[target_cols].values


print('Train samples: %d' % len(Y_train))
print('Validation samples: %d' % len(Y_valid))
# Out:
# Train samples: 4863
# Validation samples: 1216

# %% [markdown]
# # Model

# %%
use_embed = hub.load(module_url)

def USEEmbedding(x):
    return use_embed(tf.squeeze(tf.cast(x, tf.string)))

def encoder_block(input_layer):
    encoder = Lambda(USEEmbedding, output_shape=(EMBEDDDING_SIZE,))(input_layer)
    
    return encoder

# %% [markdown]
# ## Load embedding

# %%
glove_embedding_matrix, glove_unknown_words = build_matrix(tokenizer.word_index, encoder_path, MAX_FEATURES)
print('n unknown words (GloVe): ', len(glove_unknown_words))
# Out:
# n unknown words (GloVe):  685

# %%
# Title
input_title = Input(shape=(1,), dtype=tf.string, name='input_title')
encoded_title = encoder_block(input_title)

# Body
input_body = Input(shape=(1,), dtype=tf.string, name='input_body')
encoded_body = encoder_block(input_body)

# Answer
input_answer = Input(shape=(1,), dtype=tf.string, name='input_answer')
encoded_answer = encoder_block(input_answer)

# Title sequence
input_title_seq = Input(shape=(TITLE_MAX_LEN,), dtype=tf.float32, name='input_title_seq')
title = Embedding(*glove_embedding_matrix.shape, weights=[glove_embedding_matrix], trainable=False)(input_title_seq)
title_out = GlobalAveragePooling1D()(title)

# Body sequence
input_body_seq = Input(shape=(BODY_MAX_LEN,), dtype=tf.float32, name='input_body_seq')
body = Embedding(*glove_embedding_matrix.shape, weights=[glove_embedding_matrix], trainable=False)(input_body_seq)
body_out = GlobalAveragePooling1D()(body)

# Answer sequence
input_answer_seq = Input(shape=(ANSWER_MAX_LEN,), dtype=tf.float32, name='input_answer_seq')
answer = Embedding(*glove_embedding_matrix.shape, weights=[glove_embedding_matrix], trainable=False)(input_answer_seq)
answer_out = GlobalAveragePooling1D()(answer)


# Output
x = Concatenate()([encoded_title, encoded_body, encoded_answer, title_out, body_out, answer_out])
x = Dropout(0.5)(x)
x = Dense(512, activation='relu', kernel_initializer='lecun_normal')(x)
x = Dropout(0.5)(x)
output = Dense(N_CLASS, activation='sigmoid', kernel_initializer='lecun_normal', name='output')(x)
model = Model(inputs=[input_title, input_body, input_answer, input_title_seq, input_body_seq, input_answer_seq], outputs=[output])

model.summary()
# Out:
# Model: "model"
# __________________________________________________________________________________________________
# Layer (type)                    Output Shape         Param #     Connected to
# ==================================================================================================
# input_title_seq (InputLayer)    [(None, 30)]         0
# __________________________________________________________________________________________________
# input_body_seq (InputLayer)     [(None, 150)]        0
# __________________________________________________________________________________________________
# input_answer_seq (InputLayer)   [(None, 150)]        0
# __________________________________________________________________________________________________
# input_title (InputLayer)        [(None, 1)]          0
# __________________________________________________________________________________________________
# input_body (InputLayer)         [(None, 1)]          0
# __________________________________________________________________________________________________
# input_answer (InputLayer)       [(None, 1)]          0
# __________________________________________________________________________________________________
# embedding (Embedding)           (None, 30, 300)      17424600    input_title_seq[0][0]
# __________________________________________________________________________________________________
# embedding_1 (Embedding)         (None, 150, 300)     17424600    input_body_seq[0][0]
# __________________________________________________________________________________________________
# embedding_2 (Embedding)         (None, 150, 300)     17424600    input_answer_seq[0][0]
# __________________________________________________________________________________________________
# lambda (Lambda)                 (None, 512)          0           input_title[0][0]
# __________________________________________________________________________________________________
# lambda_1 (Lambda)               (None, 512)          0           input_body[0][0]
# __________________________________________________________________________________________________
# lambda_2 (Lambda)               (None, 512)          0           input_answer[0][0]
# __________________________________________________________________________________________________
# global_average_pooling1d (Globa (None, 300)          0           embedding[0][0]
# __________________________________________________________________________________________________
# global_average_pooling1d_1 (Glo (None, 300)          0           embedding_1[0][0]
# __________________________________________________________________________________________________
# global_average_pooling1d_2 (Glo (None, 300)          0           embedding_2[0][0]
# __________________________________________________________________________________________________
# concatenate (Concatenate)       (None, 2436)         0           lambda[0][0]
#                                                                  lambda_1[0][0]
#                                                                  lambda_2[0][0]
#                                                                  global_average_pooling1d[0][0]
#                                                                  global_average_pooling1d_1[0][0]
#                                                                  global_average_pooling1d_2[0][0]
# __________________________________________________________________________________________________
# dropout (Dropout)               (None, 2436)         0           concatenate[0][0]
# __________________________________________________________________________________________________
# dense (Dense)                   (None, 512)          1247744     dropout[0][0]
# __________________________________________________________________________________________________
# dropout_1 (Dropout)             (None, 512)          0           dense[0][0]
# __________________________________________________________________________________________________
# output (Dense)                  (None, 30)           15390       dropout_1[0][0]
# ==================================================================================================
# Total params: 53,536,934
# Trainable params: 1,263,134
# Non-trainable params: 52,273,800
# __________________________________________________________________________________________________

# %% [markdown]
# # Train model

# %%
rlrop = ReduceLROnPlateau(monitor='val_loss', mode='min', patience=RLROP_PATIENCE, factor=DECAY_DROP, min_lr=1e-7, verbose=1)
spearmanCallback = SpearmanRhoCallback(training_data=(X_train, Y_train), validation_data=(X_valid, Y_valid), monitor='val_loss', mode='min', patience=ES_PATIENCE)
callback_list = [rlrop, spearmanCallback]

optimizer = optimizers.Adam(LEARNING_RATE)
model.compile(optimizer=optimizer, loss='binary_crossentropy')

history = model.fit(X_train, Y_train, 
                    validation_data=(X_valid, Y_valid), 
                    callbacks=callback_list, 
                    batch_size=BATCH_SIZE, 
                    epochs=EPOCHS, 
                    verbose=2).history
# Out:
# Train on 4863 samples, validate on 1216 samples
# Epoch 1/50
# spearman-rho: 0.2160 val_spearman-rho: 0.1981
# 4863/4863 - 30s - loss: 0.4625 - val_loss: 0.4130
# Epoch 2/50
# spearman-rho: 0.2915 val_spearman-rho: 0.2740
# 4863/4863 - 21s - loss: 0.4070 - val_loss: 0.3993
# Epoch 3/50
# spearman-rho: 0.3365 val_spearman-rho: 0.3159
# 4863/4863 - 20s - loss: 0.3952 - val_loss: 0.3913
# Epoch 4/50
# spearman-rho: 0.3596 val_spearman-rho: 0.3331
# 4863/4863 - 20s - loss: 0.3886 - val_loss: 0.3870
# Epoch 5/50
# spearman-rho: 0.3772 val_spearman-rho: 0.3441
# 4863/4863 - 20s - loss: 0.3840 - val_loss: 0.3851
# Epoch 6/50
# spearman-rho: 0.3900 val_spearman-rho: 0.3517
# 4863/4863 - 21s - loss: 0.3809 - val_loss: 0.3822
# Epoch 7/50
# spearman-rho: 0.4007 val_spearman-rho: 0.3566
# 4863/4863 - 21s - loss: 0.3784 - val_loss: 0.3806
# Epoch 8/50
# spearman-rho: 0.4098 val_spearman-rho: 0.3602
# 4863/4863 - 21s - loss: 0.3763 - val_loss: 0.3796
# Epoch 9/50
# spearman-rho: 0.4177 val_spearman-rho: 0.3635
# 4863/4863 - 21s - loss: 0.3743 - val_loss: 0.3787
# Epoch 10/50
# spearman-rho: 0.4238 val_spearman-rho: 0.3656
# 4863/4863 - 21s - loss: 0.3727 - val_loss: 0.3778
# Epoch 11/50
# spearman-rho: 0.4304 val_spearman-rho: 0.3672
# 4863/4863 - 20s - loss: 0.3717 - val_loss: 0.3775
# Epoch 12/50
# spearman-rho: 0.4349 val_spearman-rho: 0.3685
# 4863/4863 - 21s - loss: 0.3702 - val_loss: 0.3771
# Epoch 13/50
# spearman-rho: 0.4406 val_spearman-rho: 0.3696
# 4863/4863 - 20s - loss: 0.3691 - val_loss: 0.3764
# Epoch 14/50
# spearman-rho: 0.4445 val_spearman-rho: 0.3704
# 4863/4863 - 21s - loss: 0.3680 - val_loss: 0.3762
# Epoch 15/50
# spearman-rho: 0.4502 val_spearman-rho: 0.3720
# 4863/4863 - 21s - loss: 0.3671 - val_loss: 0.3758
# Epoch 16/50
# spearman-rho: 0.4538 val_spearman-rho: 0.3731
# 4863/4863 - 20s - loss: 0.3661 - val_loss: 0.3753
# Epoch 17/50
# spearman-rho: 0.4572 val_spearman-rho: 0.3745
# 4863/4863 - 20s - loss: 0.3652 - val_loss: 0.3751
# Epoch 18/50
# spearman-rho: 0.4624 val_spearman-rho: 0.3756
# 4863/4863 - 20s - loss: 0.3639 - val_loss: 0.3748
# Epoch 19/50
# spearman-rho: 0.4663 val_spearman-rho: 0.3757
# 4863/4863 - 20s - loss: 0.3630 - val_loss: 0.3755
# Epoch 20/50
#
# Epoch 00020: ReduceLROnPlateau reducing learning rate to 9.000000427477062e-05.
# spearman-rho: 0.4711 val_spearman-rho: 0.3766
# 4863/4863 - 21s - loss: 0.3625 - val_loss: 0.3747
# Epoch 21/50
# spearman-rho: 0.4725 val_spearman-rho: 0.3771
# 4863/4863 - 20s - loss: 0.3612 - val_loss: 0.3743
# Epoch 22/50
# spearman-rho: 0.4737 val_spearman-rho: 0.3772
# 4863/4863 - 21s - loss: 0.3606 - val_loss: 0.3743
# Epoch 23/50
#
# Epoch 00023: ReduceLROnPlateau reducing learning rate to 2.700000040931627e-05.
# spearman-rho: 0.4754 val_spearman-rho: 0.3774
# 4863/4863 - 20s - loss: 0.3602 - val_loss: 0.3743
# Epoch 24/50
# spearman-rho: 0.4757 val_spearman-rho: 0.3775
# 4863/4863 - 20s - loss: 0.3600 - val_loss: 0.3741
# Epoch 25/50
# spearman-rho: 0.4761 val_spearman-rho: 0.3777
# 4863/4863 - 20s - loss: 0.3598 - val_loss: 0.3741
# Epoch 26/50
#
# Epoch 00026: ReduceLROnPlateau reducing learning rate to 8.100000013655517e-06.
# spearman-rho: 0.4765 val_spearman-rho: 0.3777
# 4863/4863 - 20s - loss: 0.3596 - val_loss: 0.3741
# Epoch 27/50
# spearman-rho: 0.4767 val_spearman-rho: 0.3777
# 4863/4863 - 21s - loss: 0.3595 - val_loss: 0.3741
# Epoch 28/50
#
# Epoch 00028: ReduceLROnPlateau reducing learning rate to 2.429999949526973e-06.
# spearman-rho: 0.4768 val_spearman-rho: 0.3778
# 4863/4863 - 20s - loss: 0.3599 - val_loss: 0.3741
# Epoch 29/50
# spearman-rho: 0.4768 val_spearman-rho: 0.3778
# 4863/4863 - 21s - loss: 0.3591 - val_loss: 0.3741
# Epoch 30/50
#
# Epoch 00030: ReduceLROnPlateau reducing learning rate to 7.289999985005124e-07.
# spearman-rho: 0.4769 val_spearman-rho: 0.3778
# 4863/4863 - 21s - loss: 0.3596 - val_loss: 0.3741
# Epoch 31/50
# spearman-rho: 0.4769 val_spearman-rho: 0.3778
# 4863/4863 - 21s - loss: 0.3596 - val_loss: 0.3741
# Epoch 32/50
#
# Epoch 00032: ReduceLROnPlateau reducing learning rate to 2.1870000637136398e-07.
# spearman-rho: 0.4769 val_spearman-rho: 0.3778
# 4863/4863 - 21s - loss: 0.3594 - val_loss: 0.3741
# Epoch 33/50
# spearman-rho: 0.4769 val_spearman-rho: 0.3778
# Epoch 00032: early stopping
# 4863/4863 - 20s - loss: 0.3592 - val_loss: 0.3741

# %% [markdown]
# ## Model loss graph

# %%
sns.set(style="whitegrid")
plot_metrics(history, metric_list=['loss', 'spearman'])

# %% [markdown]
# # Evaluation

# %%
preds_train = model.predict(X_train)
preds_val = model.predict(X_valid)

display(get_metrics(Y_train, preds_train, Y_valid, preds_val, target_cols).style.applymap(color_map))
# Out:
# <style  type="text/css" >
#     #T_8066401a_2814_11ea_bdf8_fb28c705d4b3row0_col0 {
#             color:  black;
#         }    #T_8066401a_2814_11ea_bdf8_fb28c705d4b3row0_col1 {
#             color:  black;
#         }    #T_8066401a_2814_11ea_bdf8_fb28c705d4b3row0_col2 {
#             color:  black;
#         }    #T_8066401a_2814_11ea_bdf8_fb28c705d4b3row1_col0 {
#             color:  black;
#         }    #T_8066401a_2814_11ea_bdf8_fb28c705d4b3row1_col1 {
#             color:  black;
#         }    #T_8066401a_2814_11ea_bdf8_fb28c705d4b3row1_col2 {
#             color:  black;
#         }    #T_8066401a_2814_11ea_bdf8_fb28c705d4b3row2_col0 {
#             color:  black;
#         }    #T_8066401a_2814_11ea_bdf8_fb28c705d4b3row2_col1 {
#             color:  black;
#         }    #T_8066401a_2814_11ea_bdf8_fb28c705d4b3row2_col2 {
#             color:  black;
#         }    #T_8066401a_2814_11ea_bdf8_fb28c705d4b3row3_col0 {
#             color:  black;
#         }    #T_8066401a_2814_11ea_bdf8_fb28c705d4b3row3_col1 {
#             color:  black;
#         }    #T_8066401a_2814_11ea_bdf8_fb28c705d4b3row3_col2 {
#             color:  black;
#         }    #T_8066401a_2814_11ea_bdf8_fb28c705d4b3row4_col0 {
#             color:  black;
#         }    #T_8066401a_2814_11ea_bdf8_fb28c705d4b3row4_col1 {
#             color:  black;
#         }    #T_8066401a_2814_11ea_bdf8_fb28c705d4b3row4_col2 {
#             color:  orange;
#         }    #T_8066401a_2814_11ea_bdf8_fb28c705d4b3row5_col0 {
#             color:  black;
#         }    #T_8066401a_2814_11ea_bdf8_fb28c705d4b3row5_col1 {
#             color:  black;
#         }    #T_8066401a_2814_11ea_bdf8_fb28c705d4b3row5_col2 {
#             color:  black;
#         }    #T_8066401a_2814_11ea_bdf8_fb28c705d4b3row6_col0 {
#             color:  black;
#         }    #T_8066401a_2814_11ea_bdf8_fb28c705d4b3row6_col1 {
#             color:  black;
#         }    #T_8066401a_2814_11ea_bdf8_fb28c705d4b3row6_col2 {
#             color:  black;
#         }    #T_8066401a_2814_11ea_bdf8_fb28c705d4b3row7_col0 {
#             color:  black;
#         }    #T_8066401a_2814_11ea_bdf8_fb28c705d4b3row7_col1 {
#             color:  black;
#         }    #T_8066401a_2814_11ea_bdf8_fb28c705d4b3row7_col2 {
#             color:  black;
#         }    #T_8066401a_2814_11ea_bdf8_fb28c705d4b3row8_col0 {
#             color:  black;
#         }    #T_8066401a_2814_11ea_bdf8_fb28c705d4b3row8_col1 {
#             color:  black;
#         }    #T_8066401a_2814_11ea_bdf8_fb28c705d4b3row8_col2 {
#             color:  black;
#         }    #T_8066401a_2814_11ea_bdf8_fb28c705d4b3row9_col0 {
#             color:  black;
#         }    #T_8066401a_2814_11ea_bdf8_fb28c705d4b3row9_col1 {
#             color:  black;
#         }    #T_8066401a_2814_11ea_bdf8_fb28c705d4b3row9_col2 {
#             color:  black;
#         }    #T_8066401a_2814_11ea_bdf8_fb28c705d4b3row10_col0 {
#             color:  black;
#         }    #T_8066401a_2814_11ea_bdf8_fb28c705d4b3row10_col1 {
#             color:  orange;
#         }    #T_8066401a_2814_11ea_bdf8_fb28c705d4b3row10_col2 {
#             color:  purple;
#         }    #T_8066401a_2814_11ea_bdf8_fb28c705d4b3row11_col0 {
#             color:  black;
#         }    #T_8066401a_2814_11ea_bdf8_fb28c705d4b3row11_col1 {
#             color:  black;
#         }    #T_8066401a_2814_11ea_bdf8_fb28c705d4b3row11_col2 {
#             color:  black;
#         }    #T_8066401a_2814_11ea_bdf8_fb28c705d4b3row12_col0 {
#             color:  black;
#         }    #T_8066401a_2814_11ea_bdf8_fb28c705d4b3row12_col1 {
#             color:  black;
#         }    #T_8066401a_2814_11ea_bdf8_fb28c705d4b3row12_col2 {
#             color:  black;
#         }    #T_8066401a_2814_11ea_bdf8_fb28c705d4b3row13_col0 {
#             color:  black;
#         }    #T_8066401a_2814_11ea_bdf8_fb28c705d4b3row13_col1 {
#             color:  black;
#         }    #T_8066401a_2814_11ea_bdf8_fb28c705d4b3row13_col2 {
#             color:  black;
#         }    #T_8066401a_2814_11ea_bdf8_fb28c705d4b3row14_col0 {
#             color:  black;
#         }    #T_8066401a_2814_11ea_bdf8_fb28c705d4b3row14_col1 {
#             color:  orange;
#         }    #T_8066401a_2814_11ea_bdf8_fb28c705d4b3row14_col2 {
#             color:  orange;
#         }    #T_8066401a_2814_11ea_bdf8_fb28c705d4b3row15_col0 {
#             color:  black;
#         }    #T_8066401a_2814_11ea_bdf8_fb28c705d4b3row15_col1 {
#             color:  black;
#         }    #T_8066401a_2814_11ea_bdf8_fb28c705d4b3row15_col2 {
#             color:  black;
#         }    #T_8066401a_2814_11ea_bdf8_fb28c705d4b3row16_col0 {
#             color:  black;
#         }    #T_8066401a_2814_11ea_bdf8_fb28c705d4b3row16_col1 {
#             color:  black;
#         }    #T_8066401a_2814_11ea_bdf8_fb28c705d4b3row16_col2 {
#             color:  black;
#         }    #T_8066401a_2814_11ea_bdf8_fb28c705d4b3row17_col0 {
#             color:  black;
#         }    #T_8066401a_2814_11ea_bdf8_fb28c705d4b3row17_col1 {
#             color:  green;
#         }    #T_8066401a_2814_11ea_bdf8_fb28c705d4b3row17_col2 {
#             color:  black;
#         }    #T_8066401a_2814_11ea_bdf8_fb28c705d4b3row18_col0 {
#             color:  black;
#         }    #T_8066401a_2814_11ea_bdf8_fb28c705d4b3row18_col1 {
#             color:  black;
#         }    #T_8066401a_2814_11ea_bdf8_fb28c705d4b3row18_col2 {
#             color:  orange;
#         }    #T_8066401a_2814_11ea_bdf8_fb28c705d4b3row19_col0 {
#             color:  black;
#         }    #T_8066401a_2814_11ea_bdf8_fb28c705d4b3row19_col1 {
#             color:  black;
#         }    #T_8066401a_2814_11ea_bdf8_fb28c705d4b3row19_col2 {
#             color:  black;
#         }    #T_8066401a_2814_11ea_bdf8_fb28c705d4b3row20_col0 {
#             color:  black;
#         }    #T_8066401a_2814_11ea_bdf8_fb28c705d4b3row20_col1 {
#             color:  purple;
#         }    #T_8066401a_2814_11ea_bdf8_fb28c705d4b3row20_col2 {
#             color:  purple;
#         }    #T_8066401a_2814_11ea_bdf8_fb28c705d4b3row21_col0 {
#             color:  black;
#         }    #T_8066401a_2814_11ea_bdf8_fb28c705d4b3row21_col1 {
#             color:  black;
#         }    #T_8066401a_2814_11ea_bdf8_fb28c705d4b3row21_col2 {
#             color:  black;
#         }    #T_8066401a_2814_11ea_bdf8_fb28c705d4b3row22_col0 {
#             color:  black;
#         }    #T_8066401a_2814_11ea_bdf8_fb28c705d4b3row22_col1 {
#             color:  black;
#         }    #T_8066401a_2814_11ea_bdf8_fb28c705d4b3row22_col2 {
#             color:  orange;
#         }    #T_8066401a_2814_11ea_bdf8_fb28c705d4b3row23_col0 {
#             color:  black;
#         }    #T_8066401a_2814_11ea_bdf8_fb28c705d4b3row23_col1 {
#             color:  black;
#         }    #T_8066401a_2814_11ea_bdf8_fb28c705d4b3row23_col2 {
#             color:  black;
#         }    #T_8066401a_2814_11ea_bdf8_fb28c705d4b3row24_col0 {
#             color:  black;
#         }    #T_8066401a_2814_11ea_bdf8_fb28c705d4b3row24_col1 {
#             color:  orange;
#         }    #T_8066401a_2814_11ea_bdf8_fb28c705d4b3row24_col2 {
#             color:  orange;
#         }    #T_8066401a_2814_11ea_bdf8_fb28c705d4b3row25_col0 {
#             color:  black;
#         }    #T_8066401a_2814_11ea_bdf8_fb28c705d4b3row25_col1 {
#             color:  orange;
#         }    #T_8066401a_2814_11ea_bdf8_fb28c705d4b3row25_col2 {
#             color:  orange;
#         }    #T_8066401a_2814_11ea_bdf8_fb28c705d4b3row26_col0 {
#             color:  black;
#         }    #T_8066401a_2814_11ea_bdf8_fb28c705d4b3row26_col1 {
#             color:  black;
#         }    #T_8066401a_2814_11ea_bdf8_fb28c705d4b3row26_col2 {
#             color:  orange;
#         }    #T_8066401a_2814_11ea_bdf8_fb28c705d4b3row27_col0 {
#             color:  black;
#         }    #T_8066401a_2814_11ea_bdf8_fb28c705d4b3row27_col1 {
#             color:  green;
#         }    #T_8066401a_2814_11ea_bdf8_fb28c705d4b3row27_col2 {
#             color:  black;
#         }    #T_8066401a_2814_11ea_bdf8_fb28c705d4b3row28_col0 {
#             color:  black;
#         }    #T_8066401a_2814_11ea_bdf8_fb28c705d4b3row28_col1 {
#             color:  black;
#         }    #T_8066401a_2814_11ea_bdf8_fb28c705d4b3row28_col2 {
#             color:  or

# %% [markdown]
# ## By category

# %%
target_cols_preds = [col+'_pred' for col in target_cols]
for col in target_cols_preds:
    train[col] = 0
    validation[col] = 0
    
train[target_cols_preds] = preds_train
validation[target_cols_preds] = preds_val
    
display(get_metrics_category(train, validation, target_cols, target_cols_preds, 'category').style.applymap(color_map))
# Out:
# <style  type="text/css" >
#     #T_80c48076_2814_11ea_bdf8_fb28c705d4b3row0_col0 {
#             color:  black;
#         }    #T_80c48076_2814_11ea_bdf8_fb28c705d4b3row0_col1 {
#             color:  black;
#         }    #T_80c48076_2814_11ea_bdf8_fb28c705d4b3row0_col2 {
#             color:  black;
#         }    #T_80c48076_2814_11ea_bdf8_fb28c705d4b3row0_col3 {
#             color:  black;
#         }    #T_80c48076_2814_11ea_bdf8_fb28c705d4b3row0_col4 {
#             color:  black;
#         }    #T_80c48076_2814_11ea_bdf8_fb28c705d4b3row0_col5 {
#             color:  black;
#         }    #T_80c48076_2814_11ea_bdf8_fb28c705d4b3row0_col6 {
#             color:  orange;
#         }    #T_80c48076_2814_11ea_bdf8_fb28c705d4b3row0_col7 {
#             color:  black;
#         }    #T_80c48076_2814_11ea_bdf8_fb28c705d4b3row0_col8 {
#             color:  black;
#         }    #T_80c48076_2814_11ea_bdf8_fb28c705d4b3row0_col9 {
#             color:  black;
#         }    #T_80c48076_2814_11ea_bdf8_fb28c705d4b3row0_col10 {
#             color:  black;
#         }</style><table id="T_80c48076_2814_11ea_bdf8_fb28c705d4b3" ><thead>    <tr>        <th class="blank level0" ></th>        <th class="col_heading level0 col0" >Label</th>        <th class="col_heading level0 col1" >Train (TECHNOLOGY)</th>        <th class="col_heading level0 col2" >Validation (TECHNOLOGY)</th>        <th class="col_heading level0 col3" >Train (SCIENCE)</th>        <th class="col_heading level0 col4" >Validation (SCIENCE)</th>        <th class="col_heading level0 col5" >Train (STACKOVERFLOW)</th>        <th class="col_heading level0 col6" >Validation (STACKOVERFLOW)</th>        <th class="col_heading level0 col7" >Train (LIFE_ARTS)</th>        <th class="col_heading level0 col8" >Validation (LIFE_ARTS)</th>        <th class="col_heading level0 col9" >Train (CULTURE)</th>        <th class="col_heading level0 col10" >Validation (CULTURE)</th>    </tr></thead><tbody>
#                 <tr>
#                         <th id="T_80c48076_2814_11ea_bdf8_fb28c705d4b3level0_row0" class="row_heading level0 row0" >0</th>
#                         <td id="T_80c48076_2814_11ea_bdf8_fb28c705d4b3row0_col0" class="data row0 col0" >Averaged</td>
#                         <td id="T_80c48076_2814_11ea_bdf8_fb28c705d4b3row0_col1" class="data row0 col1" >0.444</td>
#                         <td id="T_80c48076_2814_11ea_bdf8_fb28c705d4b3row0_col2" class="data row0 col2" >0.34</td>
#                         <td id="T_80c48076_2814_11ea_bdf8_fb28c705d4b3row0_col3" class="data row0 col3" >0.488</td>
#                         <td id="T_80c48076_2814_11ea_bdf8_fb28c705d4b3row0_col4" class="data row0 col4" >0.368</td>
#                         <td id="T_80c48076_2814_11ea_bdf8_fb28c705d4b3row0_col5" class="data row0 col5" >0.381</td>
#                         <td id="T_80c48076_2814_11ea_bdf8_fb28c705d4b3row0_col6" class="data row0 col6" >0.212</td>
#                         <td id="T_80c48076_2814_11ea_bdf8_fb28c705d4b3row0_col7" class="data row0 col7" >0.496</td>
#                         <td id="T_80c48076_2814_11ea_bdf8_fb28c705d4b3row0_col8" class="data row0 col8" >0.407</td>
#                         <td id="T_80c48076_2814_11ea_bdf8_fb28c705d4b3row0_col9" class="data row0 col9" >0.491</td>
#                         <td id="T_80c48076_2814_11ea_bdf8_fb28c705d4b3row0_col10" class="data row0 col10" >0.389</td>
#             </tr>
#     </tbody></table>

# %% [markdown]
# #### Save model weights and ecoders

# %%
model.save_weights(model_path)
dump(tokenizer, tokenizer_path)
# Out:
# ['/kaggle/working/tokenizer.joblib']
