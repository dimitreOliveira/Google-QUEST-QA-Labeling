# %% [markdown]
# ## Dependencies

# %%
import warnings
from tensorflow_hub import KerasLayer
from tensorflow.keras import Model, optimizers
from tensorflow.keras.layers import Input, Dense, Dropout, GlobalAveragePooling1D, SpatialDropout1D, Concatenate
from googleqa_utilityscript import *
from googleqa_map_utilityscript import *
import bert_tokenization as tokenization
from script_lr_schedulers import RectifiedAdam

SEED = 0
seed_everything(SEED)
warnings.filterwarnings("ignore")
# Out:
# Using TensorFlow backend.

# %% [markdown]
# ## Load data

# %%
model_path = '/kaggle/working/model.h5'
BERT_PATH = '/kaggle/input/tf-hub-bert-base/bert_base_uncased'
VOCAB_PATH = BERT_PATH + '/assets/vocab.txt'

hold_out = pd.read_csv('/kaggle/input/googleqa-mldataset/hold-out.csv')
train = hold_out[hold_out['set'] == 'train']
validation = hold_out[hold_out['set'] == 'validation']

print('Train samples: %s' % len(train))
print('Validation samples: %s' % len(validation))
display(train.head())
# Out:
# Train samples: 4863
# Validation samples: 1216
#    qa_id                                     question_title  \
# 0   3895  Magento (1.7) Bundled Product with FREE Produc...
# 1   3131                             Find router on network
# 2   1507  Negatively curved metrics minimizing the lengt...
# 3   6784               Isn’t the FAQ label obsolete by now?
# 4   2135  Changing background image one time on responsi...
#
#                                        question_body question_user_name  \
# 0  I'm looking to create a bundle offer where cus...                Joe
# 1  I've just bought a Belkin N+ Wireless Router. ...                Guy
# 2  Good afternoon everyone !\n\nI have the follow...            Selim G
# 3  Don’t get me wrong in the beginning of reading...     Benny Skogberg
# 4  The code I'm using is this one \n\nbackground:...        user2141649
#
#                               question_user_page  \
# 0  https://magento.stackexchange.com/users/16572
# 1               https://superuser.com/users/3248
# 2           https://mathoverflow.net/users/25511
# 3        https://ux.stackexchange.com/users/4679
# 4        https://stackoverflow.com/users/2141649
#
#                                               answer   answer_user_name  \
# 0  Since the third item is fixed, you can use sho...  Fabian Schmengler
# 1  You likely have the router plugged in to the m...             John T
# 2  A very partial answer: by the results of Richa...         Igor Rivin
# 3  Isn’t the FAQ label obsolete by now? \n\nI'd s...        Solracnapod
# 4  &lt;!DOCTYPE html&gt;\n&lt;html&gt;\n&lt;head&...           akkimads
#
#                               answer_user_page  \
# 0  https://magento.stackexchange.com/users/243
# 1             https://superuser.com/users/1931
# 2         https://mathoverflow.net/users/11142
# 3     https://ux.stackexchange.com/users/13153
# 4      https://stackoverflow.com/users/2375373
#
#                                                  url       category  ...  \
# 0  http://magento.stackexchange.com/questions/668...     TECHNOLOGY  ...
# 1               http://superuser.com/questions/87212     TECHNOLOGY  ...
# 2           http://mathoverflow.net/questions/203422        SCIENCE  ...
# 3  http://ux.stackexchange.com/questions/18600/is...     TECHNOLOGY  ...
# 4  http://stackoverflow.com/questions/16359492/ch...  STACKOVERFLOW  ...
#
#   answer_helpful  answer_level_of_information  answer_plausible  \
# 0       0.888889                     0.666667               1.0
# 1       1.000000                     0.666667               1.0
# 2       0.888889                     0.333333               1.0
# 3       0.888889                     0.666667               1.0
# 4       0.888889                     0.500000               1.0
#
#    answer_relevance  answer_satisfaction  answer_type_instructions  \
# 0               1.0             0.933333                  1.000000
# 1               1.0             0.866667                  0.666667
# 2               1.0             0.700000                  0.333333
# 3               1.0             0.933333                  0.000000
# 4               1.0             0.800000                  1.000000
#
#    answer_type_procedure  answer_type_reason_explanation  answer_well_written  \
# 0               0.000000                        0.333333             0.888889
# 1               0.000000                        1.000000             1.000000
# 2               0.333333                        1.000000             0.888889
# 3               0.000000                        0.666667             1.000000
# 4               0.000000                        0.000000             0.777778
#
#      set
# 0  train
# 1  train
# 2  train
# 3  train
# 4  train
#
# [5 rows x 42 columns]

# %%
question_target_cols = ['question_asker_intent_understanding','question_body_critical', 'question_conversational', 
                        'question_expect_short_answer', 'question_fact_seeking', 'question_has_commonly_accepted_answer',
                        'question_interestingness_others', 'question_interestingness_self', 'question_multi_intent', 
                        'question_not_really_a_question', 'question_opinion_seeking', 'question_type_choice',
                        'question_type_compare', 'question_type_consequence', 'question_type_definition', 
                        'question_type_entity', 'question_type_instructions', 'question_type_procedure',
                        'question_type_reason_explanation', 'question_type_spelling', 'question_well_written']
answer_target_cols = ['answer_helpful', 'answer_level_of_information', 'answer_plausible', 'answer_relevance',
                      'answer_satisfaction', 'answer_type_instructions', 'answer_type_procedure', 
                      'answer_type_reason_explanation', 'answer_well_written']
target_cols = question_target_cols + answer_target_cols

# %% [markdown]
# # Pre-process data

# %%
text_features = ['question_title', 'question_body', 'answer']

for feature in text_features:
    # Lower
    train[feature] = train[feature].apply(lambda x: x.lower())
    validation[feature] = validation[feature].apply(lambda x: x.lower())
    # Map misspellings
    train[feature] = train[feature].apply(lambda x: map_misspellings(x))
    validation[feature] = validation[feature].apply(lambda x: map_misspellings(x))
    # Map contractions
    train[feature] = train[feature].apply(lambda x: map_contraction(x))
    validation[feature] = validation[feature].apply(lambda x: map_contraction(x))
    # Trim text
    train[feature] = train[feature].apply(lambda x: x.strip())
    validation[feature] = validation[feature].apply(lambda x: x.strip())

# %% [markdown]
# # Model parameters

# %%
EPOCHS = 10
BATCH_SIZE = 16
LEARNING_RATE = 3e-5
N_CLASS = len(target_cols)
ES_PATIENCE = 3
MAX_SEQUENCE_LENGTH = 512
TOTAL_STEPS = (len(train) // BATCH_SIZE) * EPOCHS

# %% [markdown]
# ## Train/validation sets

# %%
tokenizer = tokenization.FullTokenizer(VOCAB_PATH, do_lower_case=True)

# Train features
X_train = compute_input_arays(train, text_features, tokenizer, MAX_SEQUENCE_LENGTH)
Y_train = train[target_cols].values

# Validation features
X_valid = compute_input_arays(validation, text_features, tokenizer, MAX_SEQUENCE_LENGTH)
Y_valid = validation[target_cols].values


print('Train samples: %d' % len(Y_train))
print('Validation samples: %d' % len(Y_valid))
# Out:
# Train samples: 4863
# Validation samples: 1216

# %% [markdown]
# # Model

# %%
input_word_ids = Input((MAX_SEQUENCE_LENGTH,), dtype=tf.int32, name='input_word_ids')
input_masks = Input((MAX_SEQUENCE_LENGTH,), dtype=tf.int32, name='input_masks')
segment_ids = Input((MAX_SEQUENCE_LENGTH,), dtype=tf.int32, name='segment_ids')

bert_layer = KerasLayer(BERT_PATH, trainable=True)
pooled_output, sequence_output = bert_layer([input_word_ids, input_masks, segment_ids])

x = GlobalAveragePooling1D()(sequence_output)
x = Dropout(0.2)(x)
output = Dense(N_CLASS, kernel_initializer='glorot_uniform', activation="sigmoid", name="output")(x)

model = Model(inputs=[input_word_ids, input_masks, segment_ids], outputs=output)

model.summary()
# Out:
# Model: "model"
# __________________________________________________________________________________________________
# Layer (type)                    Output Shape         Param #     Connected to
# ==================================================================================================
# input_word_ids (InputLayer)     [(None, 512)]        0
# __________________________________________________________________________________________________
# input_masks (InputLayer)        [(None, 512)]        0
# __________________________________________________________________________________________________
# segment_ids (InputLayer)        [(None, 512)]        0
# __________________________________________________________________________________________________
# keras_layer (KerasLayer)        [(None, 768), (None, 109482241   input_word_ids[0][0]
#                                                                  input_masks[0][0]
#                                                                  segment_ids[0][0]
# __________________________________________________________________________________________________
# global_average_pooling1d (Globa (None, 768)          0           keras_layer[0][1]
# __________________________________________________________________________________________________
# dropout (Dropout)               (None, 768)          0           global_average_pooling1d[0][0]
# __________________________________________________________________________________________________
# output (Dense)                  (None, 30)           23070       dropout[0][0]
# ==================================================================================================
# Total params: 109,505,311
# Trainable params: 109,505,310
# Non-trainable params: 1
# __________________________________________________________________________________________________

# %% [markdown]
# # Train model

# %%
spearmanCallback = SpearmanRhoCallback(training_data=(X_train, Y_train), 
                                       validation_data=(X_valid, Y_valid), 
                                       model_path=model_path, 
                                       monitor='val_loss', mode='min', 
                                       patience=ES_PATIENCE, checkpoint=True)

callback_list = [spearmanCallback]

optimizer = RectifiedAdam(lr=LEARNING_RATE,
                          total_steps=TOTAL_STEPS,
                          warmup_proportion=0.25,
                          min_lr=1e-7)
model.compile(optimizer=optimizer, loss='binary_crossentropy')

history = model.fit(X_train, Y_train, 
                    validation_data=(X_valid, Y_valid), 
                    callbacks=callback_list, 
                    batch_size=BATCH_SIZE, 
                    epochs=EPOCHS, 
                    verbose=2).history
# Out:
# Train on 4863 samples, validate on 1216 samples
# Epoch 1/10
# spearman-rho: 0.2166 val_spearman-rho: 0.2062
# Saved model weights at "/kaggle/working/model.h5"
# 4863/4863 - 555s - loss: 0.5589 - val_loss: 0.4116
# Epoch 2/10
# spearman-rho: 0.3106 val_spearman-rho: 0.2927
# Saved model weights at "/kaggle/working/model.h5"
# 4863/4863 - 470s - loss: 0.4091 - val_loss: 0.3973
# Epoch 3/10
# spearman-rho: 0.3986 val_spearman-rho: 0.3554
# Saved model weights at "/kaggle/working/model.h5"
# 4863/4863 - 470s - loss: 0.3866 - val_loss: 0.3783
# Epoch 4/10
# spearman-rho: 0.4525 val_spearman-rho: 0.3752
# Saved model weights at "/kaggle/working/model.h5"
# 4863/4863 - 470s - loss: 0.3700 - val_loss: 0.3732
# Epoch 5/10
# spearman-rho: 0.5000 val_spearman-rho: 0.3802
# 4863/4863 - 469s - loss: 0.3555 - val_loss: 0.3748
# Epoch 6/10
# spearman-rho: 0.5451 val_spearman-rho: 0.3773
# 4863/4863 - 469s - loss: 0.3413 - val_loss: 0.3774
# Epoch 7/10
# spearman-rho: 0.5873 val_spearman-rho: 0.3778
# Epoch 00006: early stopping
# 4863/4863 - 469s - loss: 0.3267 - val_loss: 0.3813

# %% [markdown]
# ## Model loss graph

# %%
sns.set(style="whitegrid")
plot_metrics(history, metric_list=['loss', 'spearman'])

# %% [markdown]
# # Evaluation

# %%
model.load_weights(model_path)
preds_train = model.predict(X_train)
preds_val = model.predict(X_valid)

display(get_metrics(Y_train, preds_train, Y_valid, preds_val, target_cols).style.applymap(color_map))
# Out:
# <style  type="text/css" >
#     #T_904be33c_34e8_11ea_a4d0_77239e3136fcrow0_col0 {
#             color:  black;
#         }    #T_904be33c_34e8_11ea_a4d0_77239e3136fcrow0_col1 {
#             color:  black;
#         }    #T_904be33c_34e8_11ea_a4d0_77239e3136fcrow0_col2 {
#             color:  black;
#         }    #T_904be33c_34e8_11ea_a4d0_77239e3136fcrow0_col3 {
#             color:  purple;
#         }    #T_904be33c_34e8_11ea_a4d0_77239e3136fcrow1_col0 {
#             color:  black;
#         }    #T_904be33c_34e8_11ea_a4d0_77239e3136fcrow1_col1 {
#             color:  black;
#         }    #T_904be33c_34e8_11ea_a4d0_77239e3136fcrow1_col2 {
#             color:  black;
#         }    #T_904be33c_34e8_11ea_a4d0_77239e3136fcrow1_col3 {
#             color:  purple;
#         }    #T_904be33c_34e8_11ea_a4d0_77239e3136fcrow2_col0 {
#             color:  black;
#         }    #T_904be33c_34e8_11ea_a4d0_77239e3136fcrow2_col1 {
#             color:  black;
#         }    #T_904be33c_34e8_11ea_a4d0_77239e3136fcrow2_col2 {
#             color:  black;
#         }    #T_904be33c_34e8_11ea_a4d0_77239e3136fcrow2_col3 {
#             color:  purple;
#         }    #T_904be33c_34e8_11ea_a4d0_77239e3136fcrow3_col0 {
#             color:  black;
#         }    #T_904be33c_34e8_11ea_a4d0_77239e3136fcrow3_col1 {
#             color:  black;
#         }    #T_904be33c_34e8_11ea_a4d0_77239e3136fcrow3_col2 {
#             color:  black;
#         }    #T_904be33c_34e8_11ea_a4d0_77239e3136fcrow3_col3 {
#             color:  purple;
#         }    #T_904be33c_34e8_11ea_a4d0_77239e3136fcrow4_col0 {
#             color:  black;
#         }    #T_904be33c_34e8_11ea_a4d0_77239e3136fcrow4_col1 {
#             color:  black;
#         }    #T_904be33c_34e8_11ea_a4d0_77239e3136fcrow4_col2 {
#             color:  black;
#         }    #T_904be33c_34e8_11ea_a4d0_77239e3136fcrow4_col3 {
#             color:  purple;
#         }    #T_904be33c_34e8_11ea_a4d0_77239e3136fcrow5_col0 {
#             color:  black;
#         }    #T_904be33c_34e8_11ea_a4d0_77239e3136fcrow5_col1 {
#             color:  black;
#         }    #T_904be33c_34e8_11ea_a4d0_77239e3136fcrow5_col2 {
#             color:  black;
#         }    #T_904be33c_34e8_11ea_a4d0_77239e3136fcrow5_col3 {
#             color:  purple;
#         }    #T_904be33c_34e8_11ea_a4d0_77239e3136fcrow6_col0 {
#             color:  black;
#         }    #T_904be33c_34e8_11ea_a4d0_77239e3136fcrow6_col1 {
#             color:  black;
#         }    #T_904be33c_34e8_11ea_a4d0_77239e3136fcrow6_col2 {
#             color:  orange;
#         }    #T_904be33c_34e8_11ea_a4d0_77239e3136fcrow6_col3 {
#             color:  orange;
#         }    #T_904be33c_34e8_11ea_a4d0_77239e3136fcrow7_col0 {
#             color:  black;
#         }    #T_904be33c_34e8_11ea_a4d0_77239e3136fcrow7_col1 {
#             color:  black;
#         }    #T_904be33c_34e8_11ea_a4d0_77239e3136fcrow7_col2 {
#             color:  black;
#         }    #T_904be33c_34e8_11ea_a4d0_77239e3136fcrow7_col3 {
#             color:  orange;
#         }    #T_904be33c_34e8_11ea_a4d0_77239e3136fcrow8_col0 {
#             color:  black;
#         }    #T_904be33c_34e8_11ea_a4d0_77239e3136fcrow8_col1 {
#             color:  black;
#         }    #T_904be33c_34e8_11ea_a4d0_77239e3136fcrow8_col2 {
#             color:  black;
#         }    #T_904be33c_34e8_11ea_a4d0_77239e3136fcrow8_col3 {
#             color:  purple;
#         }    #T_904be33c_34e8_11ea_a4d0_77239e3136fcrow9_col0 {
#             color:  black;
#         }    #T_904be33c_34e8_11ea_a4d0_77239e3136fcrow9_col1 {
#             color:  black;
#         }    #T_904be33c_34e8_11ea_a4d0_77239e3136fcrow9_col2 {
#             color:  black;
#         }    #T_904be33c_34e8_11ea_a4d0_77239e3136fcrow9_col3 {
#             color:  purple;
#         }    #T_904be33c_34e8_11ea_a4d0_77239e3136fcrow10_col0 {
#             color:  black;
#         }    #T_904be33c_34e8_11ea_a4d0_77239e3136fcrow10_col1 {
#             color:  black;
#         }    #T_904be33c_34e8_11ea_a4d0_77239e3136fcrow10_col2 {
#             color:  black;
#         }    #T_904be33c_34e8_11ea_a4d0_77239e3136fcrow10_col3 {
#             color:  purple;
#         }    #T_904be33c_34e8_11ea_a4d0_77239e3136fcrow11_col0 {
#             color:  black;
#         }    #T_904be33c_34e8_11ea_a4d0_77239e3136fcrow11_col1 {
#             color:  black;
#         }    #T_904be33c_34e8_11ea_a4d0_77239e3136fcrow11_col2 {
#             color:  black;
#         }    #T_904be33c_34e8_11ea_a4d0_77239e3136fcrow11_col3 {
#             color:  purple;
#         }    #T_904be33c_34e8_11ea_a4d0_77239e3136fcrow12_col0 {
#             color:  black;
#         }    #T_904be33c_34e8_11ea_a4d0_77239e3136fcrow12_col1 {
#             color:  orange;
#         }    #T_904be33c_34e8_11ea_a4d0_77239e3136fcrow12_col2 {
#             color:  purple;
#         }    #T_904be33c_34e8_11ea_a4d0_77239e3136fcrow12_col3 {
#             color:  purple;
#         }    #T_904be33c_34e8_11ea_a4d0_77239e3136fcrow13_col0 {
#             color:  black;
#         }    #T_904be33c_34e8_11ea_a4d0_77239e3136fcrow13_col1 {
#             color:  black;
#         }    #T_904be33c_34e8_11ea_a4d0_77239e3136fcrow13_col2 {
#             color:  black;
#         }    #T_904be33c_34e8_11ea_a4d0_77239e3136fcrow13_col3 {
#             color:  orange;
#         }    #T_904be33c_34e8_11ea_a4d0_77239e3136fcrow14_col0 {
#             color:  black;
#         }    #T_904be33c_34e8_11ea_a4d0_77239e3136fcrow14_col1 {
#             color:  black;
#         }    #T_904be33c_34e8_11ea_a4d0_77239e3136fcrow14_col2 {
#             color:  black;
#         }    #T_904be33c_34e8_11ea_a4d0_77239e3136fcrow14_col3 {
#             color:  orange;
#         }    #T_904be33c_34e8_11ea_a4d0_77239e3136fcrow15_col0 {
#             color:  black;
#         }    #T_904be33c_34e8_11ea_a4d0_77239e3136fcrow15_col1 {
#             color:  black;
#         }    #T_904be33c_34e8_11ea_a4d0_77239e3136fcrow15_col2 {
#             color:  orange;
#         }    #T_904be33c_34e8_11ea_a4d0_77239e3136fcrow15_col3 {
#             color:  purple;
#         }    #T_904be33c_34e8_11ea_a4d0_77239e3136fcrow16_col0 {
#             color:  black;
#         }    #T_904be33c_34e8_11ea_a4d0_77239e3136fcrow16_col1 {
#             color:  orange;
#         }    #T_904be33c_34e8_11ea_a4d0_77239e3136fcrow16_col2 {
#             color:  orange;
#         }    #T_904be33c_34e8_11ea_a4d0_77239e3136fcrow16_col3 {
#             color:  purple;
#         }    #T_904be33c_34e8_11ea_a4d0_77239e3136fcrow17_col0 {
#             color:  black;
#         }    #T_904be33c_34e8_11ea_a4d0_77239e3136fcrow17_col1 {
#             color:  black;
#         }    #T_904be33c_34e8_11ea_a4d0_77239e3136fcrow17_col2 {
#             color:  black;
#         }    #T_904be33c_34e8_11ea_a4d0_77239e3136fcrow17_col3 {
#             color:  purple;
#         }    #T_904be33c_34e8_11ea_a4d0_77239e3136fcrow18_col0 {
#             color:  black;
#         }    #T_904be33c_34e8_11ea_a4d0_77239e3136fcrow18_col1 {
#             color:  black;
#         }    #T_904be33c_34e8_11ea_a4d0_77239e3136fcrow18_col2 {
#             color:  black;
#         }    #T_904be33c_34e8_11ea_a4d0_77239e3136fcrow18_col3 {
#             color:  purple;
#         }    #T_904be33c_34e8_11ea_a4d0_77239e3136fcrow19_col0 {
#             color:  black;
#         }    #T_904be33c_34e8_11ea_a4d0_77239e3136fcrow19_col1 {
#             color:  green;
#         }    #T_904be33c_34e8_11ea_a4d0_77239e3136fcrow19_col2 {
#             color:  black;
#         }    #T_904be33c_34e8_11ea_a4d0_77239e3136fcrow19_col3 {
#             color:  purple;
#         }    #T_904be33c_34e8_11ea_a4d0_77239e3136fcrow20_col0 {
#             color:  black;
#         }    #T_904be33c_34e8_11ea_a4d0_77239e3136fcrow20_col1 {
#             color:  black;
#         }    #T_904be33c_34e8_11ea_a4d0_77239e3136fcrow20_col2 {
#             color:  black;
#         }    #T_904be33c_34e8_11ea_a4d0_77239e3136fcrow20_col3 {
#             color:  orange;
#         }    #T_904be33c_34e8_11ea_a4d0_77239e3136fcrow21_col0 {
#             color:  black;
#         }    #T_904be33c_34e8_11ea_a4d0_77239e3136fcrow21_col1 {
#             color:  black;
#         }    #T_904be33c_34e8_11ea_a4d0_77239e3136fcrow21_col2 {
#             color:

# %% [markdown]
# ## By category

# %%
target_cols_preds = [col+'_pred' for col in target_cols]
for col in target_cols_preds:
    train[col] = 0
    validation[col] = 0
    
train[target_cols_preds] = preds_train
validation[target_cols_preds] = preds_val
    
display(get_metrics_category(train, validation, target_cols, target_cols_preds, 'category').style.applymap(color_map))
# Out:
# <style  type="text/css" >
#     #T_908f30ec_34e8_11ea_a4d0_77239e3136fcrow0_col0 {
#             color:  black;
#         }    #T_908f30ec_34e8_11ea_a4d0_77239e3136fcrow0_col1 {
#             color:  black;
#         }    #T_908f30ec_34e8_11ea_a4d0_77239e3136fcrow0_col2 {
#             color:  black;
#         }    #T_908f30ec_34e8_11ea_a4d0_77239e3136fcrow0_col3 {
#             color:  purple;
#         }    #T_908f30ec_34e8_11ea_a4d0_77239e3136fcrow1_col0 {
#             color:  black;
#         }    #T_908f30ec_34e8_11ea_a4d0_77239e3136fcrow1_col1 {
#             color:  black;
#         }    #T_908f30ec_34e8_11ea_a4d0_77239e3136fcrow1_col2 {
#             color:  black;
#         }    #T_908f30ec_34e8_11ea_a4d0_77239e3136fcrow1_col3 {
#             color:  purple;
#         }    #T_908f30ec_34e8_11ea_a4d0_77239e3136fcrow2_col0 {
#             color:  black;
#         }    #T_908f30ec_34e8_11ea_a4d0_77239e3136fcrow2_col1 {
#             color:  black;
#         }    #T_908f30ec_34e8_11ea_a4d0_77239e3136fcrow2_col2 {
#             color:  orange;
#         }    #T_908f30ec_34e8_11ea_a4d0_77239e3136fcrow2_col3 {
#             color:  orange;
#         }    #T_908f30ec_34e8_11ea_a4d0_77239e3136fcrow3_col0 {
#             color:  black;
#         }    #T_908f30ec_34e8_11ea_a4d0_77239e3136fcrow3_col1 {
#             color:  black;
#         }    #T_908f30ec_34e8_11ea_a4d0_77239e3136fcrow3_col2 {
#             color:  black;
#         }    #T_908f30ec_34e8_11ea_a4d0_77239e3136fcrow3_col3 {
#             color:  purple;
#         }    #T_908f30ec_34e8_11ea_a4d0_77239e3136fcrow4_col0 {
#             color:  black;
#         }    #T_908f30ec_34e8_11ea_a4d0_77239e3136fcrow4_col1 {
#             color:  black;
#         }    #T_908f30ec_34e8_11ea_a4d0_77239e3136fcrow4_col2 {
#             color:  black;
#         }    #T_908f30ec_34e8_11ea_a4d0_77239e3136fcrow4_col3 {
#             color:  purple;
#         }</style><table id="T_908f30ec_34e8_11ea_a4d0_77239e3136fc" ><thead>    <tr>        <th class="blank level0" ></th>        <th class="col_heading level0 col0" >Label</th>        <th class="col_heading level0 col1" >Train</th>        <th class="col_heading level0 col2" >Validation</th>        <th class="col_heading level0 col3" >Var</th>    </tr></thead><tbody>
#                 <tr>
#                         <th id="T_908f30ec_34e8_11ea_a4d0_77239e3136fclevel0_row0" class="row_heading level0 row0" >0</th>
#                         <td id="T_908f30ec_34e8_11ea_a4d0_77239e3136fcrow0_col0" class="data row0 col0" >TECHNOLOGY</td>
#                         <td id="T_908f30ec_34e8_11ea_a4d0_77239e3136fcrow0_col1" class="data row0 col1" >0.415</td>
#                         <td id="T_908f30ec_34e8_11ea_a4d0_77239e3136fcrow0_col2" class="data row0 col2" >0.33</td>
#                         <td id="T_908f30ec_34e8_11ea_a4d0_77239e3136fcrow0_col3" class="data row0 col3" >0.085</td>
#             </tr>
#             <tr>
#                         <th id="T_908f30ec_34e8_11ea_a4d0_77239e3136fclevel0_row1" class="row_heading level0 row1" >1</th>
#                         <td id="T_908f30ec_34e8_11ea_a4d0_77239e3136fcrow1_col0" class="data row1 col0" >SCIENCE</td>
#                         <td id="T_908f30ec_34e8_11ea_a4d0_77239e3136fcrow1_col1" class="data row1 col1" >0.469</td>
#                         <td id="T_908f30ec_34e8_11ea_a4d0_77239e3136fcrow1_col2" class="data row1 col2" >0.37</td>
#                         <td id="T_908f30ec_34e8_11ea_a4d0_77239e3136fcrow1_col3" class="data row1 col3" >0.099</td>
#             </tr>
#             <tr>
#                         <th id="T_908f30ec_34e8_11ea_a4d0_77239e3136fclevel0_row2" class="row_heading level0 row2" >2</th>
#                         <td id="T_908f30ec_34e8_11ea_a4d0_77239e3136fcrow2_col0" class="data row2 col0" >STACKOVERFLOW</td>
#                         <td id="T_908f30ec_34e8_11ea_a4d0_77239e3136fcrow2_col1" class="data row2 col1" >0.337</td>
#                         <td id="T_908f30ec_34e8_11ea_a4d0_77239e3136fcrow2_col2" class="data row2 col2" >0.232</td>
#                         <td id="T_908f30ec_34e8_11ea_a4d0_77239e3136fcrow2_col3" class="data row2 col3" >0.105</td>
#             </tr>
#             <tr>
#                         <th id="T_908f30ec_34e8_11ea_a4d0_77239e3136fclevel0_row3" class="row_heading level0 row3" >3</th>
#                         <td id="T_908f30ec_34e8_11ea_a4d0_77239e3136fcrow3_col0" class="data row3 col0" >LIFE_ARTS</td>
#                         <td id="T_908f30ec_34e8_11ea_a4d0_77239e3136fcrow3_col1" class="data row3 col1" >0.479</td>
#                         <td id="T_908f30ec_34e8_11ea_a4d0_77239e3136fcrow3_col2" class="data row3 col2" >0.413</td>
#                         <td id="T_908f30ec_34e8_11ea_a4d0_77239e3136fcrow3_col3" class="data row3 col3" >0.066</td>
#             </tr>
#             <tr>
#                         <th id="T_908f30ec_34e8_11ea_a4d0_77239e3136fclevel0_row4" class="row_heading level0 row4" >4</th>
#                         <td id="T_908f30ec_34e8_11ea_a4d0_77239e3136fcrow4_col0" class="data row4 col0" >CULTURE</td>
#                         <td id="T_908f30ec_34e8_11ea_a4d0_77239e3136fcrow4_col1" class="data row4 col1" >0.475</td>
#                         <td id="T_908f30ec_34e8_11ea_a4d0_77239e3136fcrow4_col2" class="data row4 col2" >0.38</td>
#                         <td id="T_908f30ec_34e8_11ea_a4d0_77239e3136fcrow4_col3" class="data row4 col3" >0.095</td>
#             </tr>
#     </tbody></table>
