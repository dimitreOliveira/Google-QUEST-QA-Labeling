# %% [markdown]
# ## Dependencies

# %%
import warnings
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
from sklearn.model_selection import train_test_split, StratifiedKFold

SEED = 0
sns.set(style="whitegrid")
warnings.filterwarnings("ignore")

# %% [markdown]
# ## Load data

# %%
train_df = pd.read_csv('/kaggle/input/google-quest-challenge/train.csv')

category_cols = train_df['category'].unique()
question_target_cols = ['question_asker_intent_understanding','question_body_critical', 'question_conversational', 
                        'question_expect_short_answer', 'question_fact_seeking', 'question_has_commonly_accepted_answer',
                        'question_interestingness_others', 'question_interestingness_self', 'question_multi_intent', 
                        'question_not_really_a_question', 'question_opinion_seeking', 'question_type_choice',
                        'question_type_compare', 'question_type_consequence', 'question_type_definition', 
                        'question_type_entity', 'question_type_instructions', 'question_type_procedure',
                        'question_type_reason_explanation', 'question_type_spelling', 'question_well_written']
answer_target_cols = ['answer_helpful', 'answer_level_of_information', 'answer_plausible', 'answer_relevance',
                      'answer_satisfaction', 'answer_type_instructions', 'answer_type_procedure', 
                      'answer_type_reason_explanation', 'answer_well_written']
target_cols = question_target_cols + answer_target_cols

print('Train samples: %s' % len(train_df))
display(train_df.head())
# Out:
# Train samples: 6079
#    qa_id                                     question_title  \
# 0      0  What am I losing when using extension tubes in...
# 1      1  What is the distinction between a city and a s...
# 2      2  Maximum protusion length for through-hole comp...
# 3      3              Can an affidavit be used in Beit Din?
# 4      5       How do you make a binary image in Photoshop?
#
#                                        question_body question_user_name  \
# 0  After playing around with macro photography on...               ysap
# 1  I am trying to understand what kinds of places...      russellpierce
# 2  I'm working on a PCB that has through-hole com...          Joe Baker
# 3  An affidavit, from what i understand, is basic...         Scimonster
# 4  I am trying to make a binary image. I want mor...            leigero
#
#                                   question_user_page  \
# 0         https://photo.stackexchange.com/users/1024
# 1           https://rpg.stackexchange.com/users/8774
# 2  https://electronics.stackexchange.com/users/10157
# 3       https://judaism.stackexchange.com/users/5151
# 4  https://graphicdesign.stackexchange.com/users/...
#
#                                               answer answer_user_name  \
# 0  I just got extension tubes, so here's the skin...           rfusca
# 1  It might be helpful to look into the definitio...     Erik Schmidt
# 2  Do you even need grooves?  We make several pro...      Dwayne Reid
# 3  Sending an "affidavit" it is a dispute between...    Y     e     z
# 4  Check out Image Trace in Adobe Illustrator. \n...             q2ra
#
#                                     answer_user_page  \
# 0         https://photo.stackexchange.com/users/1917
# 1           https://rpg.stackexchange.com/users/1871
# 2  https://electronics.stackexchange.com/users/64754
# 3       https://judaism.stackexchange.com/users/4794
# 4  https://graphicdesign.stackexchange.com/users/...
#
#                                                  url   category  ...  \
# 0  http://photo.stackexchange.com/questions/9169/...  LIFE_ARTS  ...
# 1  http://rpg.stackexchange.com/questions/47820/w...    CULTURE  ...
# 2  http://electronics.stackexchange.com/questions...    SCIENCE  ...
# 3  http://judaism.stackexchange.com/questions/551...    CULTURE  ...
# 4  http://graphicdesign.stackexchange.com/questio...  LIFE_ARTS  ...
#
#   question_well_written  answer_helpful  answer_level_of_information  \
# 0              1.000000        1.000000                     0.666667
# 1              0.888889        0.888889                     0.555556
# 2              0.777778        0.777778                     0.555556
# 3              0.888889        0.833333                     0.333333
# 4              1.000000        1.000000                     0.666667
#
#    answer_plausible  answer_relevance  answer_satisfaction  \
# 0          1.000000          1.000000             0.800000
# 1          0.888889          0.888889             0.666667
# 2          1.000000          1.000000             0.666667
# 3          0.833333          1.000000             0.800000
# 4          1.000000          1.000000             0.800000
#
#    answer_type_instructions  answer_type_procedure  \
# 0                       1.0               0.000000
# 1                       0.0               0.000000
# 2                       0.0               0.333333
# 3                       0.0               0.000000
# 4                       1.0               0.000000
#
#    answer_type_reason_explanation  answer_well_written
# 0                        0.000000             1.000000
# 1                        0.666667             0.888889
# 2                        1.000000             0.888889
# 3                        1.000000             1.000000
# 4                        1.000000             1.000000
#
# [5 rows x 41 columns]

# %% [markdown]
# # Hold-out train validation split (20%)

# %%
train, validation = train_test_split(train_df, test_size=0.2, random_state=SEED)
print('Train samples: %s' % len(train))
print('Validation samples: %s' % len(validation))
# Out:
# Train samples: 4863
# Validation samples: 1216

# %% [markdown]
# ## Category distribution

# %%
fig, (ax1, ax2) = plt.subplots(1, 2, figsize=(24, 8.7))
sns.countplot(x="category", data=train, palette="GnBu_d", order=category_cols, ax=ax1).set_title('Train')
sns.countplot(x="category", data=validation, palette="GnBu_d", order=category_cols, ax=ax2).set_title('Validation')
sns.despine()
plt.show()

# %% [markdown]
# ## Label distribution

# %%
train_lbls = []
validation_lbls = []
for col in target_cols:
    train_lbls.append([col, len(train[train[col] > 0])])
    validation_lbls.append([col, len(validation[validation[col] > 0])])
    
train_lbls = pd.DataFrame(train_lbls, columns=['Label', 'Count'])
validation_lbls = pd.DataFrame(validation_lbls, columns=['Label', 'Count'])
sumary_lbl = train_lbls.merge(validation_lbls, on='Label')
sumary_lbl.columns = ['Label', 'Train count', 'Validation count']

fig, (ax1, ax2) = plt.subplots(1, 2, figsize=(24, 20))
sns.barplot(y='Label', x='Count', data=train_lbls, palette="GnBu_d", ax=ax1).set_title('Train')
sns.barplot(y='Label', x='Count', data=validation_lbls, palette="GnBu_d", ax=ax2).set_title('Validation')
plt.show()

display(sumary_lbl)
# Out:
#                                     Label  Train count  Validation count
# 0     question_asker_intent_understanding         4863              1216
# 1                  question_body_critical         4863              1216
# 2                 question_conversational          538               132
# 3            question_expect_short_answer         4205              1068
# 4                   question_fact_seeking         4616              1148
# 5   question_has_commonly_accepted_answer         4329              1093
# 6         question_interestingness_others         4863              1216
# 7           question_interestingness_self         4863              1216
# 8                   question_multi_intent         1949               513
# 9          question_not_really_a_question           51                15
# 10               question_opinion_seeking         3310               805
# 11                   question_type_choice         2161               555
# 12                  question_type_compare          349                78
# 13              question_type_consequence          105                26
# 14               question_type_definition          263                81
# 15                   question_type_entity          589               142
# 16             question_type_instructions         3110               798
# 17                question_type_procedure         1693               428
# 18       question_type_reason_explanation         2899               724
# 19                 question_type_spelling           10                 1
# 20                  question_well_written         4863              1216
# 21                         answer_helpful         4863              1216
# 22            answer_level_of_information         4863              1216
# 23                       answer_plausible         4863              1216
# 24                       answer_relevance         4863              1216
# 25                    answer_satisfaction         4863              1216
# 26               answer_type_instructions         3059               776
# 27                  answer_type_procedure         1427               371
# 28         answer_type_reason_explanation         3357               830
# 29                    answer_well_written         4863              1216

# %% [markdown]
# ## Duplicated question

# %%
train_unique_qt = set(train['question_title'].unique())
validation_unique_qt = set(validation['question_title'].unique())

print('Duplicated questions %s' % len(train_unique_qt & validation_unique_qt))
# Out:
# Duplicated questions 675

# %% [markdown]
# ## Output hold-out set

# %%
train['set'] = 'train'
validation['set'] = 'validation'
train_complete = train.append(validation)
train_complete.to_csv('hold-out.csv', index=False)
display(train_complete.head())
# Out:
#       qa_id                                     question_title  \
# 3862   6148    Important non-technical course for programmers?
# 2490   3971                     Water : Aquatic :: Sand : xxx?
# 2738   4367  Learning the musical concepts in the book "Göd...
# 4140   6605      HowTo: Add Class to Sidebar Widget List-Items
# 4086   6522                       MVC4 jQuery UI does not work
#
#                                           question_body question_user_name  \
# 3862  What kind of non-technical training course do ...         Louis Rhys
# 2490  Just as aquatic is to water and aerial is to a...       coleopterist
# 2738  I am reading the book "Gödel, Escher, Bach", i...      Otavio Macedo
# 4140  The newest version of Bootstrap (v3.0) adds a ...            sleeper
# 4086  I cannot get jQuery UI working in my ASP.NET M...               Petr
#
#                                     question_user_page  \
# 3862  https://programmers.stackexchange.com/users/8486
# 2490     https://english.stackexchange.com/users/23608
# 2738       https://music.stackexchange.com/users/12666
# 4140   https://wordpress.stackexchange.com/users/12116
# 4086            https://stackoverflow.com/users/958557
#
#                                                  answer answer_user_name  \
# 3862  Business\n\nThe biggest problem I've seen with...       Ryan Hayes
# 2490  Well, fancy words for ‘sandy’ are arenarious a...          tchrist
# 2738  I agree with luser droog's answer.\n\nMy under...      luser droog
# 4140  Update: I fixed the debug warning and everythi...          sleeper
# 4086  In the layout.cshtml view, move \n\n@Scripts.R...     Yuri Morales
#
#                                       answer_user_page  \
# 3862  https://programmers.stackexchange.com/users/1521
# 2490      https://english.stackexchange.com/users/2085
# 2738        https://music.stackexchange.com/users/1344
# 4140   https://wordpress.stackexchange.com/users/12116
# 4086           https://stackoverflow.com/users/1459163
#
#                                                     url       category  ...  \
# 3862  http://programmers.stackexchange.com/questions...     TECHNOLOGY  ...
# 2490  http://english.stackexchange.com/questions/938...        CULTURE  ...
# 2738  http://music.stackexchange.com/questions/22216...      LIFE_ARTS  ...
# 4140  http://wordpress.stackexchange.com/questions/1...     TECHNOLOGY  ...
# 4086  http://stackoverflow.com/questions/13112519/mv...  STACKOVERFLOW  ...
#
#      answer_helpful  answer_level_of_information  answer_plausible  \
# 3862       1.000000                     0.666667               1.0
# 2490       1.000000                     1.000000               1.0
# 2738       1.000000                     0.666667               1.0
# 4140       0.777778                     0.555556               1.0
# 4086       1.000000                     0.666667               1.0
#
#       answer_relevance  answer_satisfaction  answer_type_instructions  \
# 3862               1.0             0.933333                  0.000000
# 2490               1.0             1.000000                  0.000000
# 2738               1.0             0.900000                  0.333333
# 4140               1.0             0.733333                  0.500000
# 4086               1.0             1.000000                  0.000000
#
#       answer_type_procedure  answer_type_reason_explanation  \
# 3862               0.000000                             1.0
# 2490               0.000000                             1.0
# 2738               0.333333                             1.0
# 4140               0.000000                             0.5
# 4086               1.000000                             0.0
#
#       answer_well_written    set
# 3862             0.888889  train
# 2490             0.888889  train
# 2738             0.777778  train
# 4140             0.888889  train
# 4086             1.000000  train
#
# [5 rows x 42 columns]

# %% [markdown]
# # 3-Fold split

# %%
folds = StratifiedKFold(n_splits=3, shuffle=True, random_state=SEED)

for fold_n, (train_idx, val_idx) in enumerate(folds.split(train_df, train_df['category'])):
    print('Fold: %s, Train size: %s, Validation size %s' % (fold_n+1, len(train_idx), len(val_idx)))
    train_df[('fold_%s' % str(fold_n+1))] = 0
    train_df[('fold_%s' % str(fold_n+1))].loc[train_idx] = 'train'
    train_df[('fold_%s' % str(fold_n+1))].loc[val_idx] = 'validation'
# Out:
# Fold: 1, Train size: 4051, Validation size 2028
# Fold: 2, Train size: 4052, Validation size 2027
# Fold: 3, Train size: 4055, Validation size 2024

# %% [markdown]
# ## Category distribution

# %%
for fold_n in range(folds.n_splits):
    fold_n += 1
    fig, (ax1, ax2) = plt.subplots(1, 2, figsize=(24, 8.7))
    fig.suptitle('Fold %s' % fold_n, fontsize=22)    
    sns.countplot(x="category", data=train_df[train_df[('fold_%s' % fold_n)] == 'train'], palette="GnBu_d", order=category_cols, ax=ax1).set_title('Train')
    sns.countplot(x="category", data=train_df[train_df[('fold_%s' % fold_n)] == 'validation'], palette="GnBu_d", order=category_cols, ax=ax2).set_title('Validation')
    sns.despine()
    plt.show()

# %% [markdown]
# ## Label distribution

# %%
sumary_lbl = pd.DataFrame(target_cols, columns=['Label'])
for fold_n in range(folds.n_splits):
    fold_n += 1
    for col in target_cols:
        sumary_lbl.loc[sumary_lbl['Label'] == col, 'Fold %s count (train)' % fold_n] = len(train_df[(train_df[('fold_%s' % fold_n)] == 'train') & (train_df[col] > 0)])
        sumary_lbl.loc[sumary_lbl['Label'] == col, 'Fold %s count (valid)' % fold_n] = len(train_df[(train_df[('fold_%s' % fold_n)] == 'validation') & (train_df[col] > 0)])
            

for fold_n in range(folds.n_splits):
    fold_n += 1
    fold_col = 'Fold %s count' % fold_n
    fig, (ax1, ax2) = plt.subplots(1, 2, figsize=(24, 20))
    fig.suptitle(fold_col, fontsize=22)
    sns.barplot(y='Label', x=fold_col + ' (train)', data=sumary_lbl, palette="GnBu_d", ax=ax1).set_title('Train')
    sns.barplot(y='Label', x=fold_col + ' (valid)', data=sumary_lbl, palette="GnBu_d", ax=ax2).set_title('Validation')
    plt.show()

display(sumary_lbl)
# Out:
#                                     Label  Fold 1 count (train)  \
# 0     question_asker_intent_understanding                4051.0
# 1                  question_body_critical                4051.0
# 2                 question_conversational                 442.0
# 3            question_expect_short_answer                3524.0
# 4                   question_fact_seeking                3837.0
# 5   question_has_commonly_accepted_answer                3614.0
# 6         question_interestingness_others                4051.0
# 7           question_interestingness_self                4051.0
# 8                   question_multi_intent                1648.0
# 9          question_not_really_a_question                  46.0
# 10               question_opinion_seeking                2729.0
# 11                   question_type_choice                1817.0
# 12                  question_type_compare                 278.0
# 13              question_type_consequence                  83.0
# 14               question_type_definition                 219.0
# 15                   question_type_entity                 508.0
# 16             question_type_instructions                2609.0
# 17                question_type_procedure                1400.0
# 18       question_type_reason_explanation                2401.0
# 19                 question_type_spelling                   8.0
# 20                  question_well_written                4051.0
# 21                         answer_helpful                4051.0
# 22            answer_level_of_information                4051.0
# 23                       answer_plausible                4051.0
# 24                       answer_relevance                4051.0
# 25                    answer_satisfaction                4051.0
# 26               answer_type_instructions                2561.0
# 27                  answer_type_procedure                1183.0
# 28         answer_type_reason_explanation                2789.0
# 29                    answer_well_written                4051.0
#
#     Fold 1 count (valid)  Fold 2 count (train)  Fold 2 count (valid)  \
# 0                 2028.0                4052.0                2027.0
# 1                 2028.0                4052.0                2027.0
# 2                  228.0                 448.0                 222.0
# 3                 1749.0                3512.0                1761.0
# 4                 1927.0                3852.0                1912.0
# 5                 1808.0                3623.0                1799.0
# 6                 2028.0                4052.0                2027.0
# 7                 2028.0                4052.0                2027.0
# 8                  814.0                1647.0                 815.0
# 9                   20.0                  47.0                  19.0
# 10                1386.0                2767.0                1348.0
# 11                 899.0                1799.0                 917.0
# 12                 149.0                 283.0                 144.0
# 13                  48.0                  84.0                  47.0
# 14                 125.0                 241.0                 103.0
# 15                 223.0                 456.0                 275.0
# 16                1299.0                2645.0                1263.0
# 17                 721.0                1419.0                 702.0
# 18                1222.0                2418.0                1205.0
# 19                   3.0                   9.0                   2.0
# 20                2028.0                4052.0                2027.0
# 21                2028.0                4052.0                2027.0
# 22                2028.0                4052.0                2027.0
# 23                2028.0                4052.0                2027.0
# 24                2028.0                4052.0                2027.0
# 25                2028.0                4052.0                2027.0
# 26                1274.0                2573.0                1262.0
# 27                 615.0                1216.0                 582.0
# 28                1398.0                2778.0                1409.0
# 29                2028.0                4052.0                2027.0
#
#     Fold 3 count (train)  Fold 3 count (valid)
# 0                 4055.0                2024.0
# 1                 4055.0                2024.0
# 2                  450.0                 220.0
# 3                 3510.0                1763.0
# 4                 3839.0                1925.0
# 5                 3607.0                1815.0
# 6                 4055.0                2024.0
# 7                 4055.0                2024.0
# 8                 1629.0                 833.0
# 9                   39.0                  27.0
# 10                2734.0                1381.0
# 11                1816.0                 900.0
# 12                 293.0                 134.0
# 13                  95.0                  36.0
# 14                 228.0                 116.0
# 15                 498.0                 233.0
# 16                2562.0                1346.0
# 17                1423.0                 698.0
# 18                2427.0                1196.0
# 19                   5.0                   6.0
# 20                4055.0                2024.0
# 21                4055.0                2024.0
# 22                4055.0                2024.0
# 23                4055.0                2024.0
# 24                4055.0                2024.0
# 25                4055.0                2024.0
# 26                2536.0                1299.0
# 27                1197.0                 601.0
# 28                2807.0                1380.0
# 29                4055.0                2024.0

# %% [markdown]
# ## Duplicated question & answer

# %%
for fold_n in range(folds.n_splits):
    fold_n += 1
    train_unique_qt = set(train_df[train_df[('fold_%s' % fold_n)] == 'train']['question_title'].unique())
    validation_unique_qt = set(train_df[train_df[('fold_%s' % fold_n)] == 'validation']['question_title'].unique())

    print('Fold %d' % fold_n)
    print('Duplicated questions %s' % len(train_unique_qt & validation_unique_qt))
# Out:
# Fold 1
# Duplicated questions 931
# Fold 2
# Duplicated questions 937
# Fold 3
# Duplicated questions 921

# %% [markdown]
# ## Output 3-fold set

# %%
train_df.to_csv('3-fold.csv', index=False)
display(train_df.head())
# Out:
#    qa_id                                     question_title  \
# 0      0  What am I losing when using extension tubes in...
# 1      1  What is the distinction between a city and a s...
# 2      2  Maximum protusion length for through-hole comp...
# 3      3              Can an affidavit be used in Beit Din?
# 4      5       How do you make a binary image in Photoshop?
#
#                                        question_body question_user_name  \
# 0  After playing around with macro photography on...               ysap
# 1  I am trying to understand what kinds of places...      russellpierce
# 2  I'm working on a PCB that has through-hole com...          Joe Baker
# 3  An affidavit, from what i understand, is basic...         Scimonster
# 4  I am trying to make a binary image. I want mor...            leigero
#
#                                   question_user_page  \
# 0         https://photo.stackexchange.com/users/1024
# 1           https://rpg.stackexchange.com/users/8774
# 2  https://electronics.stackexchange.com/users/10157
# 3       https://judaism.stackexchange.com/users/5151
# 4  https://graphicdesign.stackexchange.com/users/...
#
#                                               answer answer_user_name  \
# 0  I just got extension tubes, so here's the skin...           rfusca
# 1  It might be helpful to look into the definitio...     Erik Schmidt
# 2  Do you even need grooves?  We make several pro...      Dwayne Reid
# 3  Sending an "affidavit" it is a dispute between...    Y     e     z
# 4  Check out Image Trace in Adobe Illustrator. \n...             q2ra
#
#                                     answer_user_page  \
# 0         https://photo.stackexchange.com/users/1917
# 1           https://rpg.stackexchange.com/users/1871
# 2  https://electronics.stackexchange.com/users/64754
# 3       https://judaism.stackexchange.com/users/4794
# 4  https://graphicdesign.stackexchange.com/users/...
#
#                                                  url   category  ...  \
# 0  http://photo.stackexchange.com/questions/9169/...  LIFE_ARTS  ...
# 1  http://rpg.stackexchange.com/questions/47820/w...    CULTURE  ...
# 2  http://electronics.stackexchange.com/questions...    SCIENCE  ...
# 3  http://judaism.stackexchange.com/questions/551...    CULTURE  ...
# 4  http://graphicdesign.stackexchange.com/questio...  LIFE_ARTS  ...
#
#   answer_plausible  answer_relevance  answer_satisfaction  \
# 0         1.000000          1.000000             0.800000
# 1         0.888889          0.888889             0.666667
# 2         1.000000          1.000000             0.666667
# 3         0.833333          1.000000             0.800000
# 4         1.000000          1.000000             0.800000
#
#    answer_type_instructions  answer_type_procedure  \
# 0                       1.0               0.000000
# 1                       0.0               0.000000
# 2                       0.0               0.333333
# 3                       0.0               0.000000
# 4                       1.0               0.000000
#
#    answer_type_reason_explanation  answer_well_written      fold_1  \
# 0                        0.000000             1.000000       train
# 1                        0.666667             0.888889       train
# 2                        1.000000             0.888889       train
# 3                        1.000000             1.000000  validation
# 4                        1.000000             1.000000       train
#
#        fold_2      fold_3
# 0       train  validation
# 1  validation       train
# 2  validation       train
# 3       train       train
# 4  validation       train
#
# [5 rows x 44 columns]

# %% [markdown]
# # 5-Fold split

# %%
folds = StratifiedKFold(n_splits=5, shuffle=True, random_state=SEED)

for fold_n, (train_idx, val_idx) in enumerate(folds.split(train_df, train_df['category'])):
    print('Fold: %s, Train size: %s, Validation size %s' % (fold_n+1, len(train_idx), len(val_idx)))
    train_df[('fold_%s' % str(fold_n+1))] = 0
    train_df[('fold_%s' % str(fold_n+1))].loc[train_idx] = 'train'
    train_df[('fold_%s' % str(fold_n+1))].loc[val_idx] = 'validation'
# Out:
# Fold: 1, Train size: 4861, Validation size 1218
# Fold: 2, Train size: 4862, Validation size 1217
# Fold: 3, Train size: 4862, Validation size 1217
# Fold: 4, Train size: 4865, Validation size 1214
# Fold: 5, Train size: 4866, Validation size 1213

# %% [markdown]
# ## Category distribution

# %%
for fold_n in range(folds.n_splits):
    fold_n += 1
    fig, (ax1, ax2) = plt.subplots(1, 2, figsize=(24, 8.7))
    fig.suptitle('Fold %s' % fold_n, fontsize=22)    
    sns.countplot(x="category", data=train_df[train_df[('fold_%s' % fold_n)] == 'train'], palette="GnBu_d", order=category_cols, ax=ax1).set_title('Train')
    sns.countplot(x="category", data=train_df[train_df[('fold_%s' % fold_n)] == 'validation'], palette="GnBu_d", order=category_cols, ax=ax2).set_title('Validation')
    sns.despine()
    plt.show()

# %% [markdown]
# ## Label distribution

# %%
sumary_lbl = pd.DataFrame(target_cols, columns=['Label'])
for fold_n in range(folds.n_splits):
    fold_n += 1
    for col in target_cols:
        sumary_lbl.loc[sumary_lbl['Label'] == col, 'Fold %s count (train)' % fold_n] = len(train_df[(train_df[('fold_%s' % fold_n)] == 'train') & (train_df[col] > 0)])
        sumary_lbl.loc[sumary_lbl['Label'] == col, 'Fold %s count (valid)' % fold_n] = len(train_df[(train_df[('fold_%s' % fold_n)] == 'validation') & (train_df[col] > 0)])
            

for fold_n in range(folds.n_splits):
    fold_n += 1
    fold_col = 'Fold %s count' % fold_n
    fig, (ax1, ax2) = plt.subplots(1, 2, figsize=(24, 20))
    fig.suptitle(fold_col, fontsize=22)
    sns.barplot(y='Label', x=fold_col + ' (train)', data=sumary_lbl, palette="GnBu_d", ax=ax1).set_title('Train')
    sns.barplot(y='Label', x=fold_col + ' (valid)', data=sumary_lbl, palette="GnBu_d", ax=ax2).set_title('Validation')
    plt.show()

display(sumary_lbl)
# Out:
#                                     Label  Fold 1 count (train)  \
# 0     question_asker_intent_understanding                4861.0
# 1                  question_body_critical                4861.0
# 2                 question_conversational                 538.0
# 3            question_expect_short_answer                4235.0
# 4                   question_fact_seeking                4602.0
# 5   question_has_commonly_accepted_answer                4326.0
# 6         question_interestingness_others                4861.0
# 7           question_interestingness_self                4861.0
# 8                   question_multi_intent                1980.0
# 9          question_not_really_a_question                  51.0
# 10               question_opinion_seeking                3301.0
# 11                   question_type_choice                2191.0
# 12                  question_type_compare                 336.0
# 13              question_type_consequence                  99.0
# 14               question_type_definition                 262.0
# 15                   question_type_entity                 599.0
# 16             question_type_instructions                3123.0
# 17                question_type_procedure                1702.0
# 18       question_type_reason_explanation                2891.0
# 19                 question_type_spelling                   8.0
# 20                  question_well_written                4861.0
# 21                         answer_helpful                4861.0
# 22            answer_level_of_information                4861.0
# 23                       answer_plausible                4861.0
# 24                       answer_relevance                4861.0
# 25                    answer_satisfaction                4861.0
# 26               answer_type_instructions                3076.0
# 27                  answer_type_procedure                1435.0
# 28         answer_type_reason_explanation                3352.0
# 29                    answer_well_written                4861.0
#
#     Fold 1 count (valid)  Fold 2 count (train)  Fold 2 count (valid)  \
# 0                 1218.0                4862.0                1217.0
# 1                 1218.0                4862.0                1217.0
# 2                  132.0                 521.0                 149.0
# 3                 1038.0                4207.0                1066.0
# 4                 1162.0                4618.0                1146.0
# 5                 1096.0                4360.0                1062.0
# 6                 1218.0                4862.0                1217.0
# 7                 1218.0                4862.0                1217.0
# 8                  482.0                1970.0                 492.0
# 9                   15.0                  60.0                   6.0
# 10                 814.0                3261.0                 854.0
# 11                 525.0                2156.0                 560.0
# 12                  91.0                 337.0                  90.0
# 13                  32.0                 107.0                  24.0
# 14                  82.0                 279.0                  65.0
# 15                 132.0                 590.0                 141.0
# 16                 785.0                3147.0                 761.0
# 17                 419.0                1674.0                 447.0
# 18                 732.0                2902.0                 721.0
# 19                   3.0                  10.0                   1.0
# 20                1218.0                4862.0                1217.0
# 21                1218.0                4862.0                1217.0
# 22                1218.0                4862.0                1217.0
# 23                1218.0                4862.0                1217.0
# 24                1218.0                4862.0                1217.0
# 25                1218.0                4862.0                1217.0
# 26                 759.0                3081.0                 754.0
# 27                 363.0                1426.0                 372.0
# 28                 835.0                3335.0                 852.0
# 29                1218.0                4862.0                1217.0
#
#     Fold 3 count (train)  Fold 3 count (valid)  Fold 4 count (train)  \
# 0                 4862.0                1217.0                4865.0
# 1                 4862.0                1217.0                4865.0
# 2                  543.0                 127.0                 531.0
# 3                 4228.0                1045.0                4207.0
# 4                 4617.0                1147.0                4611.0
# 5                 4335.0                1087.0                4335.0
# 6                 4862.0                1217.0                4865.0
# 7                 4862.0                1217.0                4865.0
# 8                 1961.0                 501.0                1958.0
# 9                   53.0                  13.0                  49.0
# 10                3314.0                 801.0                3289.0
# 11                2173.0                 543.0                2152.0
# 12                 344.0                  83.0                 346.0
# 13                 102.0                  29.0                 108.0
# 14                 279.0                  65.0                 278.0
# 15                 562.0                 169.0                 580.0
# 16                3142.0                 766.0                3122.0
# 17                1699.0                 422.0                1723.0
# 18                2892.0                 731.0                2905.0
# 19                  10.0                   1.0                  10.0
# 20                4862.0                1217.0                4865.0
# 21                4862.0                1217.0                4865.0
# 22                4862.0                1217.0                4865.0
# 23                4862.0                1217.0                4865.0
# 24                4862.0                1217.0                4865.0
# 25                4862.0                1217.0                4865.0
# 26                3057.0                 778.0                3087.0
# 27                1447.0                 351.0                1460.0
# 28                3353.0                 834.0                3348.0
# 29                4862.0                1217.0                4865.0
#
#     Fold 4 count (valid)  Fold 5 count (train)  Fold 5 count (valid)
# 0                 1214.0                4866.0                1213.0
# 1                 1214.0                4866.0                1213.0
# 2                  139.0                 547.0                 123.0
# 3                 1066.0                4215.0                1058.0
# 4                 1153.0                4608.0                1156.0
# 5                 1087.0                4332.0                1090.0
# 6                 1214.0                4866.0                1213.0
# 7                 1214.0                4866.0                1213.0
# 8                  504.0                1979.0                 483.0
# 9                   17.0                  51.0                  15.0
# 10                 826.0                3295.0                 820.0
# 11                 564.0                2192.0                 524.0
# 12                  81.0                 345.0                  82.0
# 13                  23.0                 108.0                  23.0
# 14                  66.0                 278.0                  66.0
# 15                 151.0                 593.0                 138.0
# 16                 786.0                3098.0                 810.0
# 17                 398.0                1686.0                 435.0
# 18                 718.0                2902.0                 721.0
# 19                   1.0                   6.0                   5.0
# 20                1214.0                4866.0                1213.0
# 21                1214.0                4866.0                1213.0
# 22                1214.0                4866.0                1213.0
# 23                1214.0                4866.0                1213.0
# 24                1214.0                4866.0                1213.0
# 25                1214.0                4866.0                1213.0
# 26                 748.0                3039.0                 796.0
# 27                 338.0                1424.0                 374.0
# 28                 839.0                3360.0                 827.0
# 29                1214.0                4866.0                1213.0

# %% [markdown]
# ## Duplicated question & answer

# %%
for fold_n in range(folds.n_splits):
    fold_n += 1
    train_unique_qt = set(train_df[train_df[('fold_%s' % fold_n)] == 'train']['question_title'].unique())
    validation_unique_qt = set(train_df[train_df[('fold_%s' % fold_n)] == 'validation']['question_title'].unique())
    
    print('Fold %d' % fold_n)
    print('Duplicated questions %s' % len(train_unique_qt & validation_unique_qt))
# Out:
# Fold 1
# Duplicated questions 683
# Fold 2
# Duplicated questions 686
# Fold 3
# Duplicated questions 674
# Fold 4
# Duplicated questions 659
# Fold 5
# Duplicated questions 668

# %% [markdown]
# ## Output 5-fold set

# %%
train_df.to_csv('5-fold.csv', index=False)
display(train_df.head())
# Out:
#    qa_id                                     question_title  \
# 0      0  What am I losing when using extension tubes in...
# 1      1  What is the distinction between a city and a s...
# 2      2  Maximum protusion length for through-hole comp...
# 3      3              Can an affidavit be used in Beit Din?
# 4      5       How do you make a binary image in Photoshop?
#
#                                        question_body question_user_name  \
# 0  After playing around with macro photography on...               ysap
# 1  I am trying to understand what kinds of places...      russellpierce
# 2  I'm working on a PCB that has through-hole com...          Joe Baker
# 3  An affidavit, from what i understand, is basic...         Scimonster
# 4  I am trying to make a binary image. I want mor...            leigero
#
#                                   question_user_page  \
# 0         https://photo.stackexchange.com/users/1024
# 1           https://rpg.stackexchange.com/users/8774
# 2  https://electronics.stackexchange.com/users/10157
# 3       https://judaism.stackexchange.com/users/5151
# 4  https://graphicdesign.stackexchange.com/users/...
#
#                                               answer answer_user_name  \
# 0  I just got extension tubes, so here's the skin...           rfusca
# 1  It might be helpful to look into the definitio...     Erik Schmidt
# 2  Do you even need grooves?  We make several pro...      Dwayne Reid
# 3  Sending an "affidavit" it is a dispute between...    Y     e     z
# 4  Check out Image Trace in Adobe Illustrator. \n...             q2ra
#
#                                     answer_user_page  \
# 0         https://photo.stackexchange.com/users/1917
# 1           https://rpg.stackexchange.com/users/1871
# 2  https://electronics.stackexchange.com/users/64754
# 3       https://judaism.stackexchange.com/users/4794
# 4  https://graphicdesign.stackexchange.com/users/...
#
#                                                  url   category  ...  \
# 0  http://photo.stackexchange.com/questions/9169/...  LIFE_ARTS  ...
# 1  http://rpg.stackexchange.com/questions/47820/w...    CULTURE  ...
# 2  http://electronics.stackexchange.com/questions...    SCIENCE  ...
# 3  http://judaism.stackexchange.com/questions/551...    CULTURE  ...
# 4  http://graphicdesign.stackexchange.com/questio...  LIFE_ARTS  ...
#
#   answer_satisfaction  answer_type_instructions  answer_type_procedure  \
# 0            0.800000                       1.0               0.000000
# 1            0.666667                       0.0               0.000000
# 2            0.666667                       0.0               0.333333
# 3            0.800000                       0.0               0.000000
# 4            0.800000                       1.0               0.000000
#
#    answer_type_reason_explanation  answer_well_written  fold_1      fold_2  \
# 0                        0.000000             1.000000   train       train
# 1                        0.666667             0.888889   train       train
# 2                        1.000000             0.888889   train       train
# 3                        1.000000             1.000000   train  validation
# 4                        1.000000             1.000000   train       train
#
#        fold_3      fold_4  fold_5
# 0       train  validation   train
# 1  validation       train   train
# 2       train  validation   train
# 3       train       train   train
# 4  validation       train   train
#
# [5 rows x 46 columns]
